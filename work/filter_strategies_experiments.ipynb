# %%
import os
import pandas as pd
from tqdm import tqdm
import logging
import requests
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import re
from collections import Counter

# %%
import json
from requests import get

def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.

    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids


try:
    organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
except json.decoder.JSONDecodeError:
    organization_subclass = []

try:
    country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
except json.decoder.JSONDecodeError:
    country_subclass = []

try:
    city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
except json.decoder.JSONDecodeError:
    city_subclass = []

try:
    capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
except json.decoder.JSONDecodeError:
    capitals_subclass = []

try:
    admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
except json.decoder.JSONDecodeError:
    admTerr_subclass = []

try:
    family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
except json.decoder.JSONDecodeError:
    family_subclass = []

try:
    sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
except json.decoder.JSONDecodeError:
    sportLeague_subclass = []

try:
    venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
except json.decoder.JSONDecodeError:
    venue_subclass = []

# Removing overlaps for organization_subclass
organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))

try:
    geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
except json.decoder.JSONDecodeError:
    geolocation_subclass = []

try:
    food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
except json.decoder.JSONDecodeError:
    food_subclass = []

try:
    edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
except json.decoder.JSONDecodeError:
    edInst_subclass = []

try:
    govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
except json.decoder.JSONDecodeError:
    govAgency_subclass = []

try:
    intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
except json.decoder.JSONDecodeError:
    intOrg_subclass = []

try:
    timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
except json.decoder.JSONDecodeError:
    timeZone_subclass = []

# Removing overlaps for geolocation_subclass
geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))

# %%
def split_entity_name(entity_name):
    """
    Splits the entity name into separate words if it has more than 2 uppercase letters.
    
    Args:
        entity_name (str): The input string to check and potentially split (e.g., 'VideoGame').
    
    Returns:
        str: The modified string with words split by spaces if necessary.
    """
    # Count uppercase letters
    uppercase_count = sum(1 for char in entity_name if char.isupper())
    
    # If more than 2 uppercase letters, split before every uppercase letter
    if uppercase_count >= 2:
        return re.sub(r'(?<!^)(?=[A-Z])', ' ', entity_name)
    
    return entity_name

def get_type_id(entity_name):
    """
    Queries the API to retrieve the QID of an entity based on its name.

    Args:
        entity_name (str): The name of the entity (e.g., 'Video Game').

    Returns:
        str: The QID associated with the given entity name, or None if an error occurs or no QID is found.
    """
    
    entity_name_split = split_entity_name(entity_name)

    url = f"https://lamapi.hel.sintef.cloud/lookup/entity-retrieval"
    params = {
        "name": entity_name_split,
        "kind": "type",
        "token": "lamapi_demo_2023"
    }
    headers = {
        "accept": "application/json"
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Raise an error for HTTP issues
        data = response.json()
        # Assuming the API returns the QID directly or within a key, adjust if structure differs
        #return max(data, key=lambda x: x.get('pos_score', 0))
        return data[0]['id']
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
def retrieve_superclasses(entity_id):
    """
    Retrieve all superclasses of a given Wikidata entity ID.

    Args:
        entity_id (str): The ID of the entity (e.g., "Q207784").

    Returns:
        dict: A dictionary where keys are superclass IDs, and values are their labels.
    """
    # Define the SPARQL endpoint and query
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?superclass ?superclassLabel WHERE {{
      wd:{entity_id} (wdt:P279)* ?superclass.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """

    # Function to query the SPARQL endpoint with retries
    def query_wikidata(sparql_client, query, retries=3, delay=5):
        for attempt in range(retries):
            try:
                sparql_client.setQuery(query)
                sparql_client.setReturnFormat(JSON)
                results = sparql_client.query().convert()
                return results
            except Exception as e:
                if "429" in str(e):  # Handle Too Many Requests error
                    print(f"Rate limit hit. Retrying in {delay} seconds... (Attempt {attempt + 1}/{retries})")
                    time.sleep(delay)
                else:
                    print(f"An error occurred: {e}")
                    break
        return None

    # Set up the SPARQL client
    sparql = SPARQLWrapper(endpoint_url)

    # Execute the query with retries
    results = query_wikidata(sparql, query)

    # Process results and return as a dictionary
    if results:
        superclass_dict = {}
        for result in results["results"]["bindings"]:
            superclass_id = result["superclass"]["value"].split("/")[-1]  # Extract entity ID from the URI
            label = result["superclassLabel"]["value"]
            superclass_dict[superclass_id] = label
        return superclass_dict
    else:
        print("Failed to retrieve data after multiple attempts.")
        return {}

# %%
def WD_types(entity_id):
    """
    Queries the API to retrieve the list of type IDs for a given entity ID.

    Args:
        entity_id (str): The Wikidata ID of the entity (e.g., 'Q30').

    Returns:
        list: A list of type IDs associated with the given entity, or an empty list if an error occurs.
    """

    url = "https://lamapi.hel.sintef.cloud/entity/types?token=lamapi_demo_2023"
    headers = {
        "accept": "application/json",
        "Content-Type": "application/json"
    }
    payload = {"json": [entity_id]}
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Raise an error for HTTP issues
        ids = response.json()
        return ids[entity_id]['types']['P31']  # Parse and return the JSON response
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return []
    except KeyError as e:
        # Handle missing keys in the JSON response
        return []

# %%
person_subclass=get_wikidata_item_tree_item_idsSPARQL([5], backward_properties=[279])

# %%
# hai un solo NER type per entità perchè lato query type hai associato un solo 
# explicit_WD_type da mappare


def NER_types(entity_id):

    """
    Given an entity it retrieves the list of the associated NER types making
    the NER type extension of all the WD_types associated to it.
    """
    if not entity_id:
        return None  

    match = re.search(r'Q(\d+)', entity_id)
    numeric_id = int(match.group(1))

    NERtype = []
    # Classify NER types
    if numeric_id in person_subclass:
        return 'PERS'
    elif numeric_id in geolocation_subclass:
        return 'LOC'
    elif numeric_id in organization_subclass:
        return 'ORG'
    else:
        return 'OTHERS'

# %%
def extended_WD_types(entity_id):

    """
    Given an entity it retrieves the list of the associated extended WD types making
    the type extension of all the WD_types associated to it.
    """
        
    if not entity_id:
        return None

    return list(retrieve_superclasses(entity_id).keys())

# %% [markdown]
# ## Dataset Reading

# %% [markdown]
# ### Babak ORG dataset

# %%
path = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Babak_Annotations_Github/alligator_annotations.json'
with open(path, 'r') as json_file:
    dictionary = json.load(json_file)


key_to_cell = {}
for el in dictionary['rows']:
    if el['ids'][0] != "NIL":
        key_to_cell[el['data'][0]] = el['ids'][0]

# Initialize an empty dictionary for NER_query_type
NER_query_type = {}

# Iterate over WD_query_type.keys() with a tqdm progress bar
for entity_name, entity_id in tqdm(key_to_cell.items(), desc="Processing Entities", unit="entity"):

    NER_query_type[entity_id] = "ORG"

with open('Babak_NER_query_type.json', 'w') as json_file:
    json.dump(NER_query_type, json_file, indent=4)
# Out:
# Processing Entities: 100%|██████████| 454/454 [00:00<00:00, 301156.73entity/s]

# %% [markdown]
# ### Round1 and Round3 datasets

# %%
tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/gt/CEA_Round1_gt_WD.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/gt/CTA_Round1_gt.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.keys()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {key: [cea_values_dict[key], cta_values_dict[key]] for key in common_keys}

# %%
DBpedia_results = []

# %%
DBpedia_results.extend(value.split('/')[-1] for value in cta_values_dict.values())

# %%
import requests
from tqdm import tqdm

DBpedia_results = list(set(DBpedia_results))
DB_mapping = {}

def map_dbpedia_to_wikidata(dbpedia_type):
    """
    Maps a DBpedia type to its corresponding Wikidata ID using the DBpedia API.

    Args:
        dbpedia_type (str): The DBpedia type to map.

    Returns:
        str: The corresponding Wikidata ID if found, else None.
    """
    endpoint = "http://dbpedia.org/sparql"
    query = f"""
    SELECT DISTINCT ?wikidata_concept WHERE {{
        dbr:{dbpedia_type} owl:sameAs ?wikidata_concept
    }}
    LIMIT 50
    """

    headers = {"Accept": "application/sparql-results+json"}

    try:
        response = requests.get(endpoint, params={"query": query}, headers=headers)
        response.raise_for_status()
        results = response.json()["results"]["bindings"]
        for el in results:
            if el["wikidata_concept"]["value"].split("//")[1].split("/")[0] == "www.wikidata.org":
                return el["wikidata_concept"]["value"]
        return None
    except requests.exceptions.RequestException as e:
        print(f"Error querying DBpedia API: {e}")
        return None

for el in tqdm(DBpedia_results, desc="Mapping DBpedia to Wikidata"):
    if map_dbpedia_to_wikidata(el) is not None:
        DB_mapping[el] = map_dbpedia_to_wikidata(el)
# Out:
# Mapping DBpedia to Wikidata: 100%|██████████| 274/274 [01:51<00:00,  2.46it/s]

# %%
len(DB_mapping)
# Out:
# 137

# %%
cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)
# Out:
# Processing tables: 100%|██████████| 2161/2161 [01:14<00:00, 28.93it/s]

# %% [markdown]
# ### Others datasets

# %%
tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.keys()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {key: [cea_values_dict[key], cta_values_dict[key]] for key in common_keys}

# %%
cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)

# %%
len(WD_query_types)
# Out:
# 45

# %%
WD_query_types = {}
for value in combined_dict.values():
    if value[1].split('/')[-1] in DB_mapping.keys():
        WD_query_types[value[0].split('/')[-1]] = DB_mapping[value[1].split('/')[-1]].split('/')[-1]
    
WD_query_types
# Out:
# {'Q1872524': 'Q11032',
#  'Q69581': 'Q729',
#  'Q1546823': 'Q23397',
#  'Q72538': 'Q901',
#  'Q2384003': 'Q5113',
#  'Q30315633': 'Q11032',
#  'Q503046': 'Q11424',
#  'Q639481': 'Q11424',
#  'Q487907': 'Q783794',
#  'Q6476027': 'Q23397',
#  'Q135465': 'Q11424',
#  'Q459477': 'Q783794',
#  'Q2078054': 'Q756',
#  'Q14429': 'Q23397',
#  'Q5782393': 'Q756',
#  'Q154538': 'Q215627',
#  'Q817': 'Q6256',
#  'Q575014': 'Q11424',
#  'Q208875': 'Q11032',
#  'Q25193623': 'Q11424',
#  'Q1033': 'Q6256',
#  'Q7626741': 'Q12299841',
#  'Q227': 'Q6256',
#  'Q199203': 'Q729',
#  'Q200396': 'Q11424',
#  'Q5181893': 'Q23397',
#  'Q193439': 'Q1248784',
#  'Q7194441': 'Q8502',
#  'Q725552': 'Q11424',
#  'Q181086': 'Q11424',
#  'Q46551': 'Q11424',
#  'Q4920755': 'Q8502',
#  'Q471169': 'Q11424',
#  'Q128518': 'Q11424',
#  'Q831445': 'Q783794',
#  'Q463832': 'Q11424',
#  'Q206319': 'Q8142',
#  'Q83495': 'Q11424',
#  'Q4390981': 'Q43115',
#  'Q1011': 'Q6256',
#  'Q178021': 'Q1248784',
#  'Q61620': 'Q43115',
#  'Q1781530': 'Q33506',
#  'Q214801': 'Q11424',
#  'Q104123': 'Q11424'}

# %%
WD_query_type = {
    value[0].split('/')[-1]: value[1].split('/')[-1]
    for value in combined_dict.values()
}

WD_query_type
# Out:
# {'Q42302919': 'Q604435',
#  'Q27253939': 'Q27253938',
#  'Q60193329': 'Q1435962',
#  'Q6655': 'Q17272482',
#  'Q186363': 'Q32880',
#  'Q20937': 'Q4925355',
#  'Q1143707': 'Q2919801',
#  'Q9671': 'Q5',
#  'Q30': 'Q3624078',
#  'Q28121405': 'Q1059407',
#  'Q34': 'Q3624078',
#  'Q5268834': 'Q268592',
#  'Q14545639': 'Q3679744',
#  'Q18888835': 'Q2417724',
#  'Q60052167': 'Q7694920',
#  'Q66531600': 'Q1153690',
#  'Q19652': 'Q50424085',
#  'Q86084984': 'Q11446',
#  'Q2269267': 'Q131436',
#  'Q587161': 'Q5',
#  'Q2240599': 'Q3950',
#  'Q66012487': 'Q56855534',
#  'Q22595594': 'Q23397',
#  'Q64623388': 'Q5',
#  'Q55621374': 'Q52721923',
#  'Q20201263': 'Q184296',
#  'Q56507068': 'Q5',
#  'Q17511685': 'Q1584134',
#  'Q55212121': 'Q18593264',
#  'Q914148': 'Q52193405',
#  'Q27055581': 'Q1674283',
#  'Q1134591': 'Q744913',
#  'Q38': 'Q3624078',
#  'Q222': 'Q3624078',
#  'Q135705': 'Q2990963',
#  'Q15537': 'Q33146843',
#  'Q881': 'Q3624078',
#  'Q28122364': 'Q3390872',
#  'Q183': 'Q3624078',
#  'Q58466778': 'Q11835431',
#  'Q19882906': 'Q3002150',
#  'Q19982739': 'Q13433827',
#  'Q44852419': 'Q5116010',
#  'Q18845364': 'Q1190183',
#  'Q68369': 'Q15127012',
#  'Q1784559': 'Q12042110',
#  'Q7874380': 'Q105999',
#  'Q1126715': 'Q22988604',
#  'Q24726959': 'Q417841',
#  'Q49803289': 'Q150784',
#  'Q10570': 'Q8928',
#  'Q61755867': 'Q39546',
#  'Q84376665': 'Q11276',
#  'Q8906': 'Q8928',
#  'Q148174': 'Q2276925',
#  'Q589079': 'Q27971968',
#  'Q20790': 'Q12308941',
#  'Q13829': 'Q24746',
#  'Q1106082': 'Q1931185',
#  'Q525672': 'Q3184121',
#  'Q42811297': 'Q28122896',
#  'Q441749': 'Q1051067',
#  'Q84027875': 'Q858439',
#  'Q188': 'Q34770',
#  'Q191': 'Q3624078',
#  'Q12627': 'Q33146843',
#  'Q7267693': 'Q1142192',
#  'Q137813': 'Q24764',
#  'Q273228': 'Q5',
#  'Q3832731': 'Q2516436',
#  'Q2744827': 'Q62447',
#  'Q676004': 'Q1154710',
#  'Q730757': 'Q49374',
#  'Q60236575': 'Q115518',
#  'Q57977596': 'Q1744497',
#  'Q6985': 'Q17272482',
#  'Q2086913': 'Q12143',
#  'Q979628': 'Q2074737',
#  'Q191559': 'Q20901295',
#  'Q16864593': 'Q1162560',
#  'Q26902528': 'Q55936923',
#  'Q67204121': 'Q187685',
#  'Q2352194': 'Q11183017',
#  'Q3315329': 'Q192350',
#  'Q51691712': 'Q786110',
#  'Q28797868': 'Q21281546',
#  'Q66741638': 'Q26269989',
#  'Q105237': 'Q5',
#  'Q10863504': 'Q841985',
#  'Q58950425': 'Q1847518',
#  'Q26515862': 'Q56822897',
#  'Q81666454': 'Q72803170',
#  'Q160552': 'Q35535',
#  'Q23468814': 'Q16466010',
#  'Q80496652': 'Q22247',
#  'Q56229026': 'Q29023906',
#  'Q18208472': 'Q27020041',
#  'Q1575489': 'Q1194951',
#  'Q6723': 'Q17272482',
#  'Q6574': 'Q17272482',
#  'Q4938518': 'Q215380',
#  'Q1195233': 'Q5185279',
#  'Q41754881': 'Q499337',
#  'Q3447401': 'Q79007',
#  'Q50437507': 'Q22231113',
#  'Q18147661': 'Q179700',
#  'Q19358610': 'Q1302249',
#  'Q56055327': 'Q1015163',
#  'Q19799435': 'Q20086260',
#  'Q18882887': 'Q28232',
#  'Q2066392': 'Q82794',
#  'Q361': 'Q103495',
#  'Q2607763': 'Q1353952',
#  'Q1885499': 'Q353027',
#  'Q2255962': 'Q969090',
#  'Q21097904': 'Q207934',
#  'Q77976513': 'Q72803426',
#  'Q58013292': 'Q59825643',
#  'Q61465713': 'Q1541041',
#  'Q21896266': 'Q24529780',
#  'Q115334': 'Q115291',
#  'Q103756': 'Q5',
#  'Q1734': 'Q31629',
#  'Q1198': 'Q1221156',
#  'Q27867414': 'Q57733494',
#  'Q6905323': 'Q284742',
#  'Q20193': 'Q747074',
#  'Q3668446': 'Q3918',
#  'Q7158524': 'Q64138263',
#  'Q65550382': 'Q57733494',
#  'Q40': 'Q3624078',
#  'Q405797': 'Q15303838',
#  'Q371803': 'Q33506',
#  'Q4663191': 'Q1529096',
#  'Q30738040': 'Q159321',
#  'Q153746': 'Q5',
#  'Q676923': 'Q18551781',
#  'Q399': 'Q3624078',
#  'Q687246': 'Q2554364',
#  'Q58659': 'Q5',
#  'Q6828': 'Q17272482',
#  'Q3435067': 'Q5',
#  'Q4234476': 'Q18867465',
#  'Q3788784': 'Q500834',
#  'Q241961': 'Q5',
#  'Q477809': 'Q1414426',
#  'Q16958879': 'Q9143',
#  'Q655813': 'Q15911738',
#  'Q28753394': 'Q152450',
#  'Q123': 'Q47018901',
#  'Q462240': 'Q14092',
#  'Q749265': 'Q5',
#  'Q49': 'Q5107',
#  'Q221': 'Q3624078',
#  'Q490344': 'Q13414358',
#  'Q145': 'Q3624078',
#  'Q14546922': 'Q13406463',
#  'Q63617': 'Q5',
#  'Q5652408': 'Q6243',
#  'Q38903': 'Q2442401',
#  'Q17509320': 'Q1066707',
#  'Q3689551': 'Q1128397',
#  'Q188791': 'Q6979593',
#  'Q388864': 'Q1047698',
#  'Q27288257': 'Q55662548',
#  'Q8688': 'Q1248784',
#  'Q2731868': 'Q375545',
#  'Q4930727': 'Q15056995',
#  'Q175517': 'Q7930989',
#  'Q4708205': 'Q726',
#  'Q5182820': 'Q787934',
#  'Q219': 'Q3624078',
#  'Q1902428': 'Q18760388',
#  'Q115': 'Q3624078',
#  'Q55401244': 'Q1630622',
#  'Q1023264': 'Q658986',
#  'Q21897086': 'Q55075651',
#  'Q15729116': 'Q3191695',
#  'Q974481': 'Q6671098',
#  'Q3399425': 'Q3305213',
#  'Q1560696': 'Q15298259',
#  'Q1869861': 'Q162602',
#  'Q29106473': 'Q357685',
#  'Q805971': 'Q2785216',
#  'Q81292194': 'Q10451997',
#  'Q3907532': 'Q1278452',
#  'Q7737': 'Q1288568',
#  'Q1913292': 'Q34023',
#  'Q1070194': 'Q1162835',
#  'Q57378': 'Q5',
#  'Q672658': 'Q2008050',
#  'Q1118696': 'Q423785',
#  'Q10409': 'Q8928',
#  'Q57830': 'Q5',
#  'Q49750': 'Q233591',
#  'Q2033697': 'Q13002315',
#  'Q7890': 'Q61980413',
#  'Q56511881': 'Q1607801',
#  'Q223107': 'Q11173',
#  'Q1852058': 'Q5',
#  'Q11052448': 'Q1155404',
#  'Q85319072': 'Q72053617',
#  'Q5045': 'Q558330',
#  'Q1588585': 'Q81917',
#  'Q77203834': 'Q691269',
#  'Q660568': 'Q902814',
#  'Q976898': 'Q15056993',
#  'Q847': 'Q31629',
#  'Q16617097': 'Q2297177',
#  'Q3632916': 'Q18219090',
#  'Q2394731': 'Q476028',
#  'Q847790': 'Q487654',
#  'Q1012297': 'Q23413',
#  'Q1242598': 'Q11303',
#  'Q1114693': 'Q185243',
#  'Q557260': 'Q5',
#  'Q1565828': 'Q2858704',
#  'Q10420': 'Q85482556',
#  'Q11399': 'Q188451',
#  'Q15055478': 'Q11424',
#  'Q69763': 'Q27020041',
#  'Q6525806': 'Q5',
#  'Q7291': 'Q31629',
#  'Q142': 'Q3624078',
#  'Q7869683': 'Q683570',
#  'Q3815850': 'Q25930813',
#  'Q6415771': 'Q170321',
#  'Q26481081': 'Q607241',
#  'Q1494461': 'Q81917',
#  'Q6940': 'Q17272482',
#  'Q241': 'Q3624078',
#  'Q83404496': 'Q1407562',
#  'Q2630628': 'Q2599457',
#  'Q9038446': 'Q28111',
#  'Q77400623': 'Q72803708',
#  'Q2941401': 'Q15720476',
#  'Q487255': 'Q67206691',
#  'Q164597': 'Q28819924',
#  'Q65704142': 'Q102496',
#  'Q23038981': 'Q22809610',
#  'Q1130054': 'Q47345468',
#  'Q13786094': 'Q2493450',
#  'Q4673584': 'Q736812',
#  'Q301918': 'Q5',
#  'Q27513121': 'Q429785',
#  'Q2959094': 'Q15632617',
#  'Q3688204': 'Q6999',
#  'Q66633823': 'Q55850643',
#  'Q21743265': 'Q860861',
#  'Q506557': 'Q13410438',
#  'Q71728557': 'Q121117',
#  'Q308928': 'Q35034452',
#  'Q531474': 'Q5',
#  'Q74976326': 'Q726242',
#  'Q1054813': 'Q15617994',
#  'Q15991008': 'Q245596',
#  'Q224563': 'Q11303',
#  'Q19911519': 'Q575759',
#  'Q291091': 'Q6882870',
#  'Q8613': 'Q159821',
#  'Q10344974': 'Q179049',
#  'Q2893630': 'Q15056995',
#  'Q4638936': 'Q273057',
#  'Q571177': 'Q5398426',
#  'Q26922391': 'Q505804',
#  'Q85231336': 'Q24452',
#  'Q2299064': 'Q7755',
#  'Q17': 'Q3624078',
#  'Q1438623': 'Q6019423',
#  'Q4883965': 'Q494829',
#  'Q10475': 'Q85482556',
#  'Q4241677': 'Q20019082',
#  'Q2873260': 'Q17202187',
#  'Q2097336': 'Q14752149',
#  'Q1107230': 'Q71965638',
#  'Q5097422': 'Q1332364',
#  'Q17123520': 'Q5',
#  'Q283895': 'Q534932',
#  'Q1517260': 'Q204613',
#  'Q373198': 'Q3327920',
#  'Q85469182': 'Q1059564',
#  'Q10867172': 'Q1500350',
#  'Q18888660': 'Q2352365',
#  'Q506250': 'Q127448',
#  'Q20100182': 'Q755125',
#  'Q1109699': 'Q13402009',
#  'Q3960': 'Q5107',
#  'Q1204': 'Q35657',
#  'Q15033447': 'Q645924',
#  'Q29': 'Q3624078',
#  'Q10341302': 'Q2003221',
#  'Q23817729': 'Q23817731',
#  'Q158106': 'Q821435',
#  'Q836605': 'Q37748',
#  'Q4601021': 'Q2990963',
#  'Q25250': 'Q68618328',
#  'Q160406': 'Q253019',
#  'Q18936220': 'Q79007',
#  'Q32': 'Q3624078',
#  'Q571372': 'Q559026',
#  'Q3773785': 'Q3773971',
#  'Q11908674': 'Q3253281',
#  'Q3711265': 'Q1931185',
#  'Q174247': 'Q484170',
#  'Q77364804': 'Q497654',
#  'Q661494': 'Q26132862',
#  'Q569833': 'Q21672098',
#  'Q442666': 'Q562061',
#  'Q15364': 'Q937876',
#  'Q3558444': 'Q3558430',
#  'Q2270528': 'Q12518',
#  'Q2692246': 'Q1233985',
#  'Q17537610': 'Q317557',
#  'Q2889503': 'Q582706',
#  'Q26933278': 'Q27968055',
#  'Q11920145': 'Q14659',
#  'Q2313560': 'Q785745',
#  'Q19870884': 'Q26213387',
#  'Q7845769': 'Q79602',
#  'Q2536608': 'Q28328984',
#  'Q694611': 'Q262166',
#  'Q1102007': 'Q285181',
#  'Q39790': 'Q747074',
#  'Q17267277': 'Q327365',
#  'Q15868125': 'Q1129743',
#  'Q3768697': 'Q510578',
#  'Q12254687': 'Q846659',
#  'Q3613127': 'Q1278452',
#  'Q528649': 'Q447523',
#  'Q1150837': 'Q196294',
#  'Q1406706': 'Q820254',
#  'Q5434322': 'Q203005',
#  'Q1124006': 'Q534932',
#  'Q753432': 'Q30129411',
#  'Q5812504': 'Q164240',
#  'Q43450': 'Q31629',
#  'Q757314': 'Q8072',
#  'Q262': 'Q3624078',
#  'Q3447486': 'Q781132',
#  'Q378848': 'Q5',
#  'Q2039374': 'Q175185',
#  'Q1458686': 'Q86622',
#  'Q20988546': 'Q372690',
#  'Q696097': 'Q253019',
#  'Q74713689': 'Q6243',
#  'Q28663630': 'Q487973',
#  'Q11920899': 'Q211302',
#  'Q77590463': 'Q797219',
#  'Q2274755': 'Q55488',
#  'Q74096652': 'Q5898',
#  'Q6766403': 'Q29154515',
#  'Q920057': 'Q1744559',
#  'Q66691418': 'Q1172284',
#  'Q641755': 'Q2074737',
#  'Q85317794': 'Q1341811',
#  'Q1018410': 'Q61089180',
#  'Q1112770': 'Q4438121',
#  'Q5173381': 'Q1993624',
#  'Q54565796': 'Q46686',
#  'Q967649': 'Q2001305',
#  'Q1743621': 'Q37002670',
#  'Q5811253': 'Q1107656',
#  'Q546302': 'Q208569',
#  'Q225': 'Q3624078',
#  'Q3609': 'Q2312410',
#  'Q1100862': 'Q191992',
#  'Q5196584': 'Q55102916',
#  'Q17366086': 'Q279118',
#  'Q3087189': 'Q281643',
#  'Q47483572': 'Q22231108',
#  'Q270165': 'Q5',
#  'Q5465': 'Q5119',
#  'Q10371626': 'Q10267336',
#  'Q2997050': 'Q1345234',
#  'Q523349': 'Q5',
#  'Q3072695': 'Q532',
#  'Q763': 'Q3624078',
#  'Q661625': 'Q3146899',
#  'Q8837': 'Q8928',
#  'Q1374222': 'Q15127012',
#  'Q26985369': 'Q55936923',
#  'Q999916': 'Q5153359',
#  'Q1876588': 'Q1149652',
#  'Q27489': 'Q786820',
#  'Q1042': 'Q3624078',
#  'Q50316220': 'Q25377652',
#  'Q23746973': 'Q207524',
#  'Q1715534': 'Q5',
#  'Q5909612': 'Q746369',
#  'Q20917436': 'Q2100967',
#  'Q2814611': 'Q18340514',
#  'Q12103077': 'Q15921247',
#  'Q213': 'Q3624078',
#  'Q318930': 'Q2298537',
#  'Q45429': 'Q29964144',
#  'Q2077307': 'Q33384',
#  'Q71202': 'Q13414757',
#  'Q2736': 'Q31629',
#  'Q1629636': 'Q5',
#  'Q2453038': 'Q7216840',
#  'Q1569965': 'Q15221373',
#  'Q3412634': 'Q3840711',
#  'Q5372': 'Q31629',
#  'Q690323': 'Q46831',
#  'Q1055023': 'Q34442',
#  'Q397872': 'Q1131296',
#  'Q76095435': 'Q5871',
#  'Q2638600': 'Q778129',
#  'Q20731684': 'Q1855011',
#  'Q907536': 'Q5',
#  'Q64862527': 'Q82794',
#  'Q1631090': 'Q188784',
#  'Q5909858': 'Q1088552',
#  'Q18883311': 'Q28223',
#  'Q43306051': 'Q43303440',
#  'Q3869775': 'Q3257686',
#  'Q2111988': 'Q58480509',
#  'Q148': 'Q3624078',
#  'Q71314043': 'Q189118',
#  'Q64643733': 'Q30612',
#  'Q15275286': 'Q2775236',
#  'Q3224': 'Q5852411',
#  'Q5087': 'Q18918041',
#  'Q2624468': 'Q120804',
#  'Q908192': 'Q39715',
#  'Q13720': 'Q2154519',
#  'Q17278671': 'Q5162954',
#  'Q2282274': 'Q646793',
#  'Q201117': 'Q1137833',
#  'Q24811970': 'Q13442814',
#  'Q19911559': 'Q79218',
#  'Q60247790': 'Q184348',
#  'Q30899434': 'Q23034859',
#  'Q55597482': 'Q210999',
#  'Q559080': 'Q5',
#  'Q212': 'Q3624078',
#  'Q707955': 'Q58911074',
#  'Q18458048': 'Q860861',
#  'Q3232779': 'Q15259995',
#  'Q12226346': 'Q12225020',
#  'Q17122854': 'Q23786',
#  'Q938642': 'Q208569',
#  'Q1664919': 'Q155271',
#  'Q898484': 'Q15127012',
#  'Q6932085': 'Q42034610',
#  'Q65951893': 'Q22231113',
#  'Q66613570': 'Q812800',
#  'Q17015721': 'Q679165',
#  'Q22237237': 'Q21191270',
#  'Q2982982': 'Q2088357',
#  'Q51792517': 'Q16363669',
#  'Q2747220': 'Q82794',
#  'Q78250561': 'Q72803622',
#  'Q107622': 'Q5',
#  'Q63891772': 'Q22936940',
#  'Q4274237': 'Q19886676',
#  'Q44758': 'Q44753',
#  'Q664167': 'Q18127',
#  'Q8842': 'Q8928',
#  'Q18881820': 'Q1377841',
#  'Q84596326': 'Q24050099',
#  'Q15839028': 'Q3375722',
#  'Q31872780': 'Q956214',
#  'Q743963': 'Q7366',
#  'Q664228': 'Q2389789',
#  'Q66439242': 'Q571',
#  'Q2568873': 'Q15727816',
#  'Q10863450': 'Q841985',
#  'Q837987': 'Q2122052',
#  'Q1201853': 'Q229390',
#  'Q941023': 'Q12143',
#  'Q83763107': 'Q11276',
#  'Q77855249': 'Q497654',
#  'Q1089538': 'Q2911266',
#  'Q2024293': 'Q2043199',
#  'Q1794': 'Q42744322',
#  'Q2851321': 'Q1529',
#  'Q4754084': 'Q12973014',
#  'Q22086878': 'Q83373',
#  'Q14216': 'Q2247863',
#  'Q2918763': 'Q2232001',
#  'Q663611': 'Q17334923',
#  'Q2117983': 'Q15640053',
#  'Q85451339': 'Q24319',
#  'Q3910322': 'Q4220917',
#  'Q9326630': 'Q3937',
#  'Q4532395': 'Q179049',
#  'Q8046687': 'Q56436498',
#  'Q3290551': 'Q63998451',
#  'Q299622': 'Q15259995',
#  'Q10649627': 'Q2593777',
#  'Q20747511': 'Q727379',
#  'Q29266998': 'Q1744497',
#  'Q51070407': 'Q10855061',
#  'Q4748609': 'Q618123',
#  'Q15700831': 'Q30634609',
#  'Q84279122': 'Q11387',
#  'Q15651503': 'Q673687',
#  'Q1085726': 'Q20089094',
#  'Q599422': 'Q653916',
#  'Q5645170': 'Q23002052',
#  'Q14277': 'Q5',
#  'Q1121188': 'Q67201586',
#  'Q321790': 'Q5',
#  'Q68814870': 'Q5124673',
#  'Q26250779': 'Q1371562',
#  'Q5056849': 'Q1076486',
#  'Q734335': 'Q4220917',
#  'Q240848': 'Q29964144',
#  'Q2092836': 'Q2043199',
#  'Q22977069': 'Q22231106',
#  'Q985359': 'Q2354973',
#  'Q730915': 'Q3231690',
#  'Q2418567': 'Q20893947',
#  'Q5098133': 'Q1774587',
#  'Q123067': 'Q76514543',
#  'Q40912': 'Q5',
#  'Q65273462': 'Q57733494',
#  'Q18883216': 'Q1321353',
#  'Q655383': 'Q1906268',
#  'Q437165': 'Q1499928',
#  'Q146926': 'Q23038290',
#  'Q539671': 'Q42744322',
#  'Q3702038': 'Q5',
#  'Q3020438': 'Q133067',
#  'Q686082': 'Q21857994',
#  'Q1295985': 'Q57831',
#  'Q8844': 'Q8928',
#  'Q2032799': 'Q5',
#  'Q30321348': 'Q260161',
#  'Q18882902': 'Q28232',
#  'Q1814990': 'Q184943',
#  'Q999967': 'Q1370324',
#  'Q910856': 'Q16913666',
#  'Q6366': 'Q253019',
#  'Q72': 'Q70208',
#  'Q1947973': 'Q509686',
#  'Q900366': 'Q131734',
#  'Q1679858': 'Q131436',
#  'Q45': 'Q3624078',
#  'Q1043284': 'Q5',
#  'Q27983075': 'Q473932',
#  'Q3111112': 'Q498162',
#  'Q444128': 'Q24354',
#  'Q56701899': 'Q1917626',
#  'Q1184898': 'Q777120',
#  'Q37432947': 'Q101352',
#  'Q11160262': 'Q534932',
#  'Q21614076': 'Q11060274',
#  'Q15732': 'Q494721',
#  'Q94673': 'Q13410496',
#  'Q708': 'Q11344',
#  'Q733998': 'Q62447',
#  'Q809706': 'Q852190',
#  'Q632674': 'Q29048322',
#  'Q23775471': 'Q23811269',
#  'Q10887575': 'Q735428',
#  'Q178970': 'Q131681',
#  'Q79037684': 'Q57733494',
#  'Q296955': 'Q3300034',
#  'Q1200304': 'Q15081032',
#  'Q1386': 'Q11344',
#  'Q5386': 'Q31629',
#  'Q31': 'Q3624078',
#  'Q58412': 'Q750215',
#  'Q18883317': 'Q28223',
#  'Q12069186': 'Q1457376',
#  'Q12752182': 'Q356055',
#  'Q1645063': 'Q751708',
#  'Q270756': 'Q169534',
#  'Q2001407': 'Q2001330',
#  'Q31920': 'Q31629',
#  'Q1544445': 'Q1589568',
#  'Q6787605': 'Q5',
#  'Q115006': 'Q486972',
#  'Q19001': 'Q226730',
#  'Q1140679': 'Q1140677',
#  'Q834726': 'Q15921247',
#  'Q951046': 'Q849095',
#  'Q2183888': 'Q15212722',
#  'Q876': 'Q21073024',
#  'Q2410375': 'Q478174',
#  'Q732390': 'Q23034867',
#  'Q132080': 'Q16913666',
#  'Q948442': 'Q4438121',
#  'Q58003162': 'Q3917681',
#  'Q37706100': 'Q672593',
#  'Q85495755': 'Q13890',
#  'Q911': 'Q7930989',
#  'Q606157': 'Q3504085',
#  'Q429041': 'Q23442',
#  'Q36': 'Q3624078',
#  'Q16': 'Q3624078',
#  'Q1687208': 'Q1162560',
#  'Q713135': 'Q493522',
#  'Q27': 'Q3624078',
#  'Q74358645': 'Q1195098',
#  'Q42058260': 'Q283202',
#  'Q15881868': 'Q23039057',
#  'Q2984382': 'Q2044538',
#  'Q2015': 'Q835714',
#  'Q1403751': 'Q317557',
#  'Q586596': 'Q532',
#  'Q32748': 'Q20642011',
#  'Q1193363': 'Q1428357',
#  'Q60249170': 'Q115518',
#  'Q489377': 'Q13414765',
#  'Q12097933': 'Q1572070',
#  'Q930545': 'Q32880',
#  'Q3877573': 'Q15711870',
#  'Q1608': 'Q15830667',
#  'Q7055590': 'Q21822439',
#  'Q205049': 'Q188451',
#  'Q207257': 'Q15060255',
#  'Q185392': 'Q179700',
#  'Q575282': 'Q726611',
#  'Q6773': 'Q17272482',
#  'Q5506124': 'Q811979',
#  'Q60807415': 'Q18219090',
#  'Q15218614': 'Q532',
#  'Q65553468': 'Q220505',
#  'Q74854653': 'Q1195098',
#  'Q908804': 'Q7889',
#  'Q765389': 'Q210167',
#  'Q790046': 'Q659103',
#  'Q2743016': 'Q16543169',
#  'Q3109628': 'Q30174902',
#  'Q19910800': 'Q7688',
#  'Q22046364': 'Q878223',
#  'Q70444756': 'Q208469',
#  'Q10431278': 'Q615980',
#  'Q3323994': 'Q860582',
#  'Q20071027': 'Q22231106',
#  'Q913790': 'Q534932',
#  'Q15909304': 'Q11204',
#  'Q60413920': 'Q1027879',
#  'Q2436663': 'Q867238',
#  'Q41': 'Q3624078',
#  'Q7718': 'Q31629',
#  'Q308439': 'Q20857065',
#  'Q475174': 'Q475061',
#  'Q57074026': 'Q18059293',
#  'Q1175030': 'Q192078',
#  'Q16655654': 'Q655851',
#  'Q987080': 'Q3320743',
#  'Q24639': 'Q902814',
#  'Q1546': 'Q35657',
#  'Q7325148': 'Q5',
#  'Q25989': 'Q12143',
#  'Q66401069': 'Q15975575',
#  'Q28060419': 'Q20646670',
#  'Q2047509': 'Q1306755',
#  'Q11761': 'Q15401699',
#  'Q54931488': 'Q11204',
#  'Q2442809': 'Q1122508',
#  'Q7057': 'Q2267870',
#  'Q1585045': 'Q3504085',
#  'Q16228215': 'Q5',
#  'Q3930': 'Q31629',
#  'Q17747401': 'Q1895097',
#  'Q19558994': 'Q3331189',
#  'Q796': 'Q3624078',
#  'Q1334381': 'Q25930733',
#  'Q18214731': 'Q8092',
#  'Q704394': 'Q1147171',
#  'Q7084503': 'Q16917',
#  'Q310375': 'Q5',
#  'Q2630196': 'Q47574',
#  'Q6373343': 'Q988108',
#  'Q57331': 'Q5',
#  'Q78250944': 'Q1062509',
#  'Q78': 'Q1187811',
#  'Q17140': 'Q120544',
#  'Q56322724': 'Q2120129',
#  'Q27502391': 'Q20646667',
#  'Q85296874': 'Q1407562',
#  'Q907308': 'Q33881',
#  'Q1102973': 'Q168845',
#  'Q281206': 'Q48336',
#  'Q314686': 'Q1549591',
#  'Q171348': 'Q1250464',
#  'Q5728362': 'Q534932',
#  'Q81664342': 'Q10451997',
#  'Q545351': 'Q5',
#  'Q68814919': 'Q5124673',
#  'Q76160293': 'Q7725310',
#  'Q66630479': 'Q1141054',
#  'Q216344': 'Q1241568',
#  'Q75612369': 'Q3302947',
#  'Q1141929': 'Q1371037',
#  'Q116485': 'Q23002039',
#  'Q623563': 'Q210707',
#  'Q852684': 'Q62049',
#  'Q24484288': 'Q2023000',
#  'Q6726595': 'Q17366755',
#  'Q176483': 'Q32880',
#  'Q255738': 'Q3231690',
#  'Q1609376': 'Q56242250',
#  'Q21837119': 'Q55075651',
#  'Q7843424': 'Q373899',
#  'Q21692389': 'Q101659',
#  'Q731616': 'Q17431399',
#  'Q1137795': 'Q56242215',
#  'Q20100203': 'Q755125',
#  'Q1506552': 'Q45400320',
#  'Q74717087': 'Q5871',
#  'Q64359861': 'Q87167',
#  'Q74156': 'Q32880',
#  'Q917716': 'Q783930',
#  'Q55759863': 'Q4006',
#  'Q1136118': 'Q1006876',
#  'Q158432': 'Q5153359',
#  'Q85476616': 'Q1457376',
#  'Q337022': 'Q19832486',
#  'Q362': 'Q103495',
#  'Q2417867': 'Q776396',
#  'Q6241947': 'Q54934129',
#  'Q1559512': 'Q124714',
#  'Q29008829': 'Q34508',
#  'Q42722': 'Q485258',
#  'Q5765813': 'Q1004',
#  'Q16240986': 'Q171043',
#  'Q1962777': 'Q20202352',
#  'Q14545608': 'Q3679744',
#  'Q291337': 'Q15056995',
#  'Q66631024': 'Q1392913',
#  'Q1077221': 'Q17517379',
#  'Q1735864': 'Q618779',
#  'Q64848307': 'Q101965',
#  'Q947296': 'Q174736',
#  'Q5395276': 'Q105999',
#  'Q55065701': 'Q16738862',
#  'Q134032': 'Q12132',
#  'Q276538': 'Q37726',
#  'Q568334': 'Q1863818',
#  'Q7866374': 'Q15720476',
#  'Q66245': 'Q5',
#  'Q3533536': 'Q183186',
#  'Q1433199': 'Q23002039',
#  'Q3759683': 'Q46190676',
#  'Q3314682': 'Q10267336',
#  'Q21527177': 'Q134161',
#  'Q164095': 'Q55818',
#  'Q85476550': 'Q15917122',
#  'Q238629': 'Q215655',
#  'Q1467901': 'Q46169',
#  'Q534836': 'Q751708',
#  'Q12935100': 'Q7694920',
#  'Q3000900': 'Q309250',
#  'Q821802': 'Q18127',
#  'Q729447': 'Q15584664',
#  'Q1278441': 'Q38048707',
#  'Q1808944': 'Q1048525',
#  'Q67622522': 'Q1491746',
#  'Q18384639': 'Q53534649',
#  'Q27798428': 'Q57733494',
#  'Q184': 'Q3624078',
#  'Q18883384': 'Q1372384',
#  'Q375252': 'Q7830213',
#  'Q947533': 'Q19953632',
#  'Q746359': 'Q268592',
#  'Q484644': 'Q140588',
#  'Q3353316': 'Q47345468',
#  'Q61868754': 'Q15280243',
#  'Q81675196': 'Q72803708',
#  'Q4906009': 'Q131093',
#  'Q10474': 'Q85482556',
#  'Q2610236': 'Q5',
#  'Q127623': 'Q856076',
#  'Q908841': 'Q27921916',
#  'Q71827339': 'Q188040',
#  'Q368176': 'Q4801521',
#  'Q167198': 'Q47154513',
#  'Q186220': 'Q179872',
#  'Q21927194': 'Q190928',
#  'Q782004': 'Q482994',
#  'Q1014024': 'Q1404207',
#  'Q237350': 'Q82673',
#  'Q15736443': 'Q79007',
#  'Q9134365': 'Q355567',
#  'Q190500': 'Q899192',
#  'Q2402864': 'Q523',
#  'Q1423528': 'Q604177',
#  'Q3462700': 'Q16560',
#  'Q20667095': 'Q18761202',
#  'Q27437591': 'Q20646668',
#  'Q414537': 'Q11173',
#  'Q15322': 'Q7930989',
#  'Q12301872': 'Q79007',
#  'Q19558910': 'Q30634609',
#  'Q77406483': 'Q72803170',
#  'Q1637781': 'Q1637740',
#  'Q1453471': 'Q22231109',
#  'Q5015253': 'Q828909',
#  'Q279246': 'Q262166',
#  'Q192023': 'Q7366',
#  'Q250113': 'Q17158079',
#  'Q505347': 'Q13410447',
#  'Q74128175': 'Q744691',
#  'Q39': 'Q3624078',
#  'Q33443124': 'Q677678',
#  'Q63341227': 'Q219577',
#  'Q2044944': 'Q2061186',
#  'Q20102005': 'Q26894053',
#  'Q76647881': 'Q115518',
#  'Q57896375': 'Q158626',
#  'Q3781805': 'Q50053',
#  'Q4117782': 'Q6617100',
#  'Q65973370': 'Q56855534',
#  'Q74172233': 'Q72803622',
#  'Q896697': 'Q12323',
#  'Q60239397': 'Q1931185',
#  'Q10688812': 'Q6621272',
#  'Q21098236': 'Q2026833',
#  'Q74004720': 'Q72803170',
#  'Q45303406': 'Q755707',
#  'Q2496906': 'Q12140',
#  'Q3693152': 'Q1931185',
#  'Q9286': 'Q8928',
#  'Q1233695': 'Q1244922',
#  'Q12596': 'Q33146843',
#  'Q737380': 'Q5055981',
#  'Q48734314': 'Q1230708',
#  'Q74716919': 'Q5871',
#  'Q225346': 'Q7366',
#  'Q5472265': 'Q46622',
#  'Q26215652': 'Q2467461',
#  'Q712797': 'Q159719',
#  'Q224145': 'Q27150479',
#  'Q81909709': 'Q272447',
#  'Q33608540': 'Q891854',
#  'Q61702591': 'Q19832486',
#  'Q1424033': 'Q169358',
#  'Q1959984': 'Q3345345',
#  'Q64578007': 'Q80228',
#  'Q28': 'Q3624078',
#  'Q2285': 'Q14795564',
#  'Q86388460': 'Q1493194',
#  'Q299119': 'Q5',
#  'Q11111484': 'Q15911738',
#  'Q1638948': 'Q50808536',
#  'Q5097645': 'Q2247863',
#  'Q2451610': 'Q394970',
#  'Q613671': 'Q134556',
#  'Q33': 'Q3624078',
#  'Q944574': 'Q1353952',
#  'Q23889044': 'Q655150',
#  'Q60467844': 'Q39614',
#  'Q38848': 'Q188451',
#  'Q64860124': 'Q152450',
#  'Q3654737': 'Q1169748',
#  'Q475708': 'Q41253',
#  'Q69047': 'Q27020041',
#  'Q24061613': 'Q6554910',
#  'Q138841': 'Q27676416',
#  'Q18882681': 'Q618200',
#  'Q193733': 'Q1371150',
#  'Q63869675': 'Q22936940',
#  'Q1055295': 'Q1112477',
#  'Q1261': 'Q35657',
#  'Q84129065': 'Q204107',
#  'Q2278195': 'Q62049',
#  'Q21739517': 'Q813672',
#  'Q20577872': 'Q20572322',
#  'Q3408024': 'Q1931185',
#  'Q605454': 'Q56557504',
#  'Q342968': 'Q187661',
#  'Q979': 'Q11344',
#  'Q656012': 'Q208569',
#  'Q49425547': 'Q1530022',
#  'Q7551387': 'Q659563',
#  'Q7646305': 'Q133156',
#  'Q12069780': 'Q50053',
#  'Q490473': 'Q19723444',
#  'Q41357561': 'Q25377652',
#  'Q3179381': 'Q46169',
#  'Q80040': 'Q41710',
#  'Q550457': 'Q58840819',
#  'Q159': 'Q3624078',
#  'Q20912': 'Q21191270',
#  'Q7592228': 'Q18247357',
#  'Q1077954': 'Q56242225',
#  'Q86238213': 'Q61663696',
#  'Q3716785': 'Q192078',
#  'Q823031': 'Q45400320',
#  'Q1399560': 'Q1630622',
#  'Q6973705': 'Q17072837',
#  'Q834993': 'Q47521',
#  'Q17454677': 'Q34023',
#  'Q67856812': 'Q204107',
#  'Q18845355': 'Q1190183',
#  'Q1120105': 'Q159321',
#  'Q77195662': 'Q1318295',
#  'Q20600677': 'Q49850',
#  'Q14706234': 'Q5773747',
#  'Q16957': 'Q3024240',
#  'Q804': 'Q3624078',
#  'Q76786': 'Q13626398',
#  'Q16246405': 'Q506240',
#  'Q56459313': 'Q5',
#  'Q7736760': 'Q20650761',
#  'Q3293266': 'Q2142152',
#  'Q6651574': 'Q45242174',
#  'Q5018660': 'Q15917122',
#  'Q20807479': 'Q59134440',
#  'Q26772': 'Q3863',
#  'Q4179462': 'Q2312410',
#  'Q223': 'Q192611',
#  'Q69415': 'Q27020041',
#  'Q2479493': 'Q32880',
#  'Q1588484': 'Q11755880',
#  'Q1158570': 'Q12308941',
#  'Q42900733': 'Q161524',
#  'Q218': 'Q3624078',
#  'Q3741131': 'Q2485448',
#  'Q6948915': 'Q15276',
#  'Q12476210': 'Q29154515',
#  'Q78243477': 'Q285400',
#  'Q63852433': 'Q1128324',
#  'Q5300251': 'Q281643',
#  'Q26675843': 'Q11832720',
#  'Q81375732': 'Q11276',
#  'Q367994': 'Q12140',
#  'Q114530': 'Q1115575',
#  'Q7866047': 'Q105999',
#  'Q81227901': 'Q72704237',
#  'Q754434': 'Q498162',
#  'Q2467939': 'Q2467831',
#  'Q785094': 'Q26792858',
#  'Q49154': 'Q748198',
#  'Q9355128': 'Q1273568',
#  'Q10018': 'Q2039348',
#  'Q84214366': 'Q1352333',
#  'Q33122214': 'Q5',
#  'Q614304': 'Q4671286',
#  'Q51376638': 'Q732577',
#  'Q2851932': 'Q39911',
#  'Q67506959': 'Q2080304',
#  'Q235': 'Q3624078',
#  'Q18883024': 'Q19529',
#  'Q14265': 'Q523',
#  'Q1421389': 'Q188509',
#  'Q13448': 'Q33146843',
#  'Q17603191': 'Q211302',
#  'Q171404': 'Q2338524',
#  'Q3996121': 'Q83261',
#  'Q13561112': 'Q47403752',
#  'Q77978139': 'Q72803426',
#  'Q83765921': 'Q1407562',
#  'Q4377073': 'Q38033430',
#  'Q28121675': 'Q28060956',
#  'Q79601288': 'Q195385',
#  'Q165713': 'Q24869',
#  'Q104374': 'Q7930989',
#  'Q6865862': 'Q294414',
#  'Q18845169': 'Q472211',
#  'Q496971': 'Q13410520',
#  'Q7994164': 'Q358',
#  'Q200528': 'Q707813',
#  'Q22693067': 'Q5',
#  'Q581570': 'Q17202187',
#  'Q63651558': 'Q7777570',
#  'Q76648230': 'Q71798532',
#  'Q4568459': 'Q26887310',
#  'Q8866': 'Q8928',
#  'Q933004': 'Q82117',
#  'Q5597398': 'Q82794',
#  'Q5695724': 'Q420962',
#  'Q6127997': 'Q2624046',
#  'Q1449780': 'Q106658',
#  'Q369466': 'Q3184121',
#  'Q11747555': 'Q744296',
#  'Q61782650': 'Q22583115',
#  'Q60130': 'Q15149663',
#  'Q78973281': 'Q318',
#  'Q10460': 'Q9262',
#  'Q8341': 'Q188451',
#  'Q6792': 'Q17272482',
#  'Q181220': 'Q158683',
#  'Q7723045': 'Q1110794',
#  'Q83494539': 'Q13890',
#  'Q314311': 'Q15893266',
#  'Q21918555': 'Q17018380',
#  'Q18001586': 'Q13406463',
#  'Q286183': 'Q5',
#  'Q221796': 'Q847109',
#  'Q83779231': 'Q66619774',
#  'Q12459': 'Q7854',
#  'Q19907536': 'Q13626398',
#  'Q1604598': 'Q506240',
#  'Q841822': 'Q67101749',
#  'Q1151196': 'Q2582669',
#  'Q572948': 'Q29643579',
#  'Q2616930': 'Q14660',
#  'Q16185866': 'Q7876',
#  'Q9178': 'Q876102',
#  'Q59822172': 'Q21848887',
#  'Q27206254': 'Q847017',
#  'Q5412730': 'Q3395377',
#  'Q66092266': 'Q56855534',
#  ...}

# %%
with open('R1_WD_query_type.json', 'w') as json_file:
    json.dump(WD_types, json_file, indent=4)

# %%
#print(f"{type_str}: {get_type_id(type_str)}")

entity_name = key_to_cell[list(WD_query_type.keys())[0]]
ext_query_types = list(set(retrieve_superclasses("Q31")))

# query a lamapi dove specifico nel filtro il tipo

#WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
print(ext_query_types)
# Out:
# ['Q31']

# %%
# Initialize an empty dictionary for NER_query_type
NER_query_type = {}

# Iterate over WD_query_type.keys() with a tqdm progress bar
for entity_name, entity_type in tqdm(WD_query_types.items(), desc="Processing Entities", unit="entity"):
    if entity_type is None:
        print("none")
        NER_query_type[entity_name] = None
    else:
        if entity_type in ["Q81096", "Q36180", "Q82955", "Q2066131", "Q4964182", "Q63532478", "Q12299841", "Q201788", "Q245068", "Q33231", "Q49757", "Q846750", "Q116", "Q132050", "Q373085", "Q42973", "Q11631", "Q11338576", "Q1979154", "Q215627", "Q901", "Q188094", "Q1930187", "Q483501", "Q15686806", "Q16533"]:
            NER_query_type[entity_name] = "PERS"
        else:
            NER_query_type[entity_name] = NER_types(entity_type)

with open('R1_NER_query_type.json', 'w') as json_file:
    json.dump(NER_query_type, json_file, indent=4)


# Display the resulting dictionary
NER_query_type
# Out:
# Processing Entities: 100%|██████████| 45/45 [00:00<00:00, 423.23entity/s]
# {'Q1872524': 'ORG',
#  'Q69581': 'OTHERS',
#  'Q1546823': 'LOC',
#  'Q72538': 'PERS',
#  'Q2384003': 'OTHERS',
#  'Q30315633': 'ORG',
#  'Q503046': 'OTHERS',
#  'Q639481': 'OTHERS',
#  'Q487907': 'ORG',
#  'Q6476027': 'LOC',
#  'Q135465': 'OTHERS',
#  'Q459477': 'ORG',
#  'Q2078054': 'OTHERS',
#  'Q14429': 'LOC',
#  'Q5782393': 'OTHERS',
#  'Q154538': 'PERS',
#  'Q817': 'OTHERS',
#  'Q575014': 'OTHERS',
#  'Q208875': 'ORG',
#  'Q25193623': 'OTHERS',
#  'Q1033': 'OTHERS',
#  'Q7626741': 'PERS',
#  'Q227': 'OTHERS',
#  'Q199203': 'OTHERS',
#  'Q200396': 'OTHERS',
#  'Q5181893': 'LOC',
#  'Q193439': 'ORG',
#  'Q7194441': 'LOC',
#  'Q725552': 'OTHERS',
#  'Q181086': 'OTHERS',
#  'Q46551': 'OTHERS',
#  'Q4920755': 'LOC',
#  'Q471169': 'OTHERS',
#  'Q128518': 'OTHERS',
#  'Q831445': 'ORG',
#  'Q463832': 'OTHERS',
#  'Q206319': 'OTHERS',
#  'Q83495': 'OTHERS',
#  'Q4390981': 'OTHERS',
#  'Q1011': 'OTHERS',
#  'Q178021': 'ORG',
#  'Q61620': 'OTHERS',
#  'Q1781530': 'ORG',
#  'Q214801': 'OTHERS',
#  'Q104123': 'OTHERS'}

# %%
# Initialize an empty dictionary for ext_WD_query_type
ext_WD_query_type = {}

# Iterate over WD_query_type.keys() with a tqdm progress bar
for entity_name, entity_type in tqdm(WD_query_types.items(), desc="Processing Superclasses", unit="entity"):
    #print(f"{el}: #superclasses {len(extended_WD_types(el))}")
    ext_WD_query_type[entity_name] = extended_WD_types(entity_type)

with open('R3_ext_WD_query_type.json', 'w') as json_file:
    json.dump(ext_WD_query_type, json_file, indent=4)


# Display the resulting dictionary
ext_WD_query_type
# Out:
# Processing Superclasses:  15%|█▍        | 421/2856 [02:12<14:54,  2.72entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  16%|█▌        | 451/2856 [02:32<22:08,  1.81entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  32%|███▏      | 922/2856 [05:55<06:50,  4.71entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  34%|███▍      | 971/2856 [06:12<06:04,  5.17entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  34%|███▍      | 984/2856 [06:20<08:32,  3.65entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  36%|███▌      | 1019/2856 [06:33<06:56,  4.41entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  36%|███▌      | 1023/2856 [06:40<25:59,  1.18entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  64%|██████▎   | 1819/2856 [10:34<04:18,  4.00entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  70%|██████▉   | 1996/2856 [12:13<05:09,  2.78entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  70%|███████   | 2001/2856 [12:20<10:26,  1.36entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 2518/2856 [15:15<02:29,  2.26entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▊ | 2534/2856 [15:26<02:24,  2.23entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▉ | 2548/2856 [15:35<01:23,  3.67entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses: 100%|██████████| 2856/2856 [17:20<00:00,  2.75entity/s]
# {'Q876441': ['Q29182',
#   'Q352507',
#   'Q831474',
#   'Q1423891',
#   'Q1638918',
#   'Q4164871',
#   'Q112074151',
#   'Q42603',
#   'Q3315492',
#   'Q105200223',
#   'Q214339',
#   'Q2259532',
#   'Q4897819',
#   'Q4504549',
#   'Q123241435',
#   'Q17573152',
#   'Q123240632',
#   'Q215627',
#   'Q103940464',
#   'Q795052',
#   'Q3778211',
#   'Q35120',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383'],
#  'Q6302456': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q490098': ['Q7365',
#   'Q27062223',
#   'Q28843519',
#   'Q66545292',
#   'Q112826975',
#   'Q104034697',
#   'Q66536017',
#   'Q28846468',
#   'Q4406616',
#   'Q488383',
#   'Q712378',
#   'Q66591980',
#   'Q4936952',
#   'Q35120',
#   'Q27043948',
#   'Q55568967',
#   'Q121770302',
#   'Q53617407',
#   'Q66394244',
#   'Q6671777',
#   'Q16686022',
#   'Q99527517',
#   'Q223557',
#   'Q1970309',
#   'Q53617489',
#   'Q27043950',
#   'Q103940464'],
#  'Q21924051': ['Q5113',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q4865393': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q19879866': ['Q188094',
#   'Q15319501',
#   'Q108289406',
#   'Q901',
#   'Q108289030',
#   'Q1650915',
#   'Q20826540',
#   'Q110281945',
#   'Q15980158',
#   'Q66666685',
#   'Q215627',
#   'Q12737077',
#   'Q795052',
#   'Q3778211',
#   'Q1807498',
#   'Q36180',
#   'Q1914017',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q7239',
#   'Q24229398',
#   'Q214339',
#   'Q4164871',
#   'Q327055',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q4897819',
#   'Q129586023',
#   'Q2500638',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q12777906',
#   'Q123241435',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q830077',
#   'Q35120',
#   'Q123240632'],
#  'Q99': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q487999': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q3787': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q1544913': ['Q34700'],
#  'Q3811584': ['Q201788',
#   'Q16727193',
#   'Q901',
#   'Q20826540',
#   'Q1650915',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q15980158',
#   'Q66666685',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q36180',
#   'Q1914017',
#   'Q223557',
#   'Q66394244',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q327055',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q129586023',
#   'Q2500638',
#   'Q103940464',
#   'Q27043950',
#   'Q12777906',
#   'Q488383',
#   'Q35120',
#   'Q830077'],
#  'Q47265': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q16149872': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q1758200': ['Q347210'],
#  'Q33': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q672513': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q1778752': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q1364441': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q3873339': ['Q347210'],
#  'Q2267961': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q2010682': ['Q216860',
#   'Q4797274',
#   'Q7366',
#   'Q9730',
#   'Q114586269',
#   'Q1583807',
#   'Q115484611',
#   'Q207628',
#   'Q7725634',
#   'Q105543609',
#   'Q2188189',
#   'Q47461344',
#   'Q15621286',
#   'Q11461',
#   'Q116474095',
#   'Q626707',
#   'Q3882459',
#   'Q838948',
#   'Q386724',
#   'Q1437361',
#   'Q21146257',
#   'Q16686448',
#   'Q4080565',
#   'Q17537576',
#   'Q2085518',
#   'Q3882429',
#   'Q16889133',
#   'Q1292119',
#   'Q6671777',
#   'Q1132631',
#   'Q37172',
#   'Q488383',
#   'Q5127848',
#   'Q7048977',
#   'Q170475',
#   'Q35120',
#   'Q1207505',
#   'Q99527517',
#   'Q1150070',
#   'Q937228',
#   'Q67518978',
#   'Q58415929'],
#  'Q198036': ['Q1248784',
#   'Q43229',
#   'Q62447',
#   'Q12819564',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q811979',
#   'Q20977775',
#   'Q41176',
#   'Q548662',
#   'Q55006986',
#   'Q228332',
#   'Q376799',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q58778',
#   'Q16334298',
#   'Q13226383',
#   'Q24229398',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q618123',
#   'Q121359',
#   'Q35145743',
#   'Q16686448',
#   'Q35120',
#   'Q8205328',
#   'Q15710813',
#   'Q27096235',
#   'Q61961344',
#   'Q53617489',
#   'Q6671777',
#   'Q27096213',
#   'Q223557',
#   'Q1454986',
#   'Q103940464',
#   'Q98119401',
#   'Q4406616',
#   'Q53617407',
#   'Q123349660'],
#  'Q991620': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q518502': ['Q5113',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q3002029': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q4924834': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q1093603': ['Q41291',
#   'Q42889',
#   'Q1194058',
#   'Q7194062',
#   'Q11019',
#   'Q106839123',
#   'Q115797408',
#   'Q1681365',
#   'Q1882685',
#   'Q116780996',
#   'Q1183543',
#   'Q35825432',
#   'Q28877',
#   'Q10273457',
#   'Q12774177',
#   'Q2424752',
#   'Q3406743',
#   'Q223557',
#   'Q2897903',
#   'Q4406616',
#   'Q53617407',
#   'Q39546',
#   'Q488383',
#   'Q1836700',
#   'Q26902962',
#   'Q35120',
#   'Q8205328',
#   'Q123691918',
#   'Q1485500',
#   'Q58415929',
#   'Q53617489',
#   'Q337060',
#   'Q386724',
#   'Q16686448',
#   'Q103940464'],
#  'Q953984': ['Q8072',
#   'Q8502',
#   'Q29025902',
#   'Q35145263',
#   'Q106589819',
#   'Q271669',
#   'Q618123',
#   'Q2221906',
#   'Q12766313',
#   'Q16686022',
#   'Q27096220',
#   'Q115385384',
#   'Q27096213',
#   'Q223557',
#   'Q1970309',
#   'Q15989253',
#   'Q4406616',
#   'Q53617407',
#   'Q488383',
#   'Q35120',
#   'Q123349660',
#   'Q53617489',
#   'Q103940464'],
#  'Q429027': ['Q4964182',
#   'Q16727193',
#   'Q901',
#   'Q20826540',
#   'Q1650915',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q15980158',
#   'Q66666685',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q36180',
#   'Q1914017',
#   'Q223557',
#   'Q66394244',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q327055',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q129586023',
#   'Q2500638',
#   'Q103940464',
#   'Q27043950',
#   'Q12777906',
#   'Q488383',
#   'Q35120',
#   'Q830077'],
#  'Q4856712': ['Q7377',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q1010436': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q3111243': ['Q347210'],
#  'Q6939162': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q53187': ['Q1247845'],
#  'Q4822930': ['Q41176',
#   'Q811979',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q16686448',
#   'Q618123',
#   'Q8205328',
#   'Q15710813',
#   'Q27096213',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q488383',
#   'Q4406616',
#   'Q53617407',
#   'Q35120',
#   'Q58778',
#   'Q99527517',
#   'Q123349660',
#   'Q53617489',
#   'Q103940464'],
#  'Q8652': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q188440': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q5255573': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q43': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q9681': ['Q82794',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q58415929',
#   'Q123349660',
#   'Q124711467',
#   'Q488383',
#   'Q53617407',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q40': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q14083901': ['Q82794',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q58415929',
#   'Q123349660',
#   'Q124711467',
#   'Q488383',
#   'Q53617407',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q7177068': ['Q33231',
#   'Q3391743',
#   'Q108289408',
#   'Q639669',
#   'Q108289030',
#   'Q483501',
#   'Q110281945',
#   'Q2500638',
#   'Q12737077',
#   'Q215627',
#   'Q12777906',
#   'Q1807498',
#   'Q795052',
#   'Q3778211',
#   'Q214339',
#   'Q4164871',
#   'Q830077',
#   'Q24229398',
#   'Q4897819',
#   'Q7239',
#   'Q53617489',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q123241435',
#   'Q103940464',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q35120',
#   'Q123240632',
#   'Q488383'],
#  'Q6309131': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q747801': ['Q347210'],
#  'Q746413': ['Q1320047',
#   'Q2085381',
#   'Q783794',
#   'Q105044823',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q171052': ['Q5113',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q100340': ['Q10908',
#   'Q19159',
#   'Q25241',
#   'Q777371',
#   'Q10915',
#   'Q729',
#   'Q159344',
#   'Q150866',
#   'Q3059449',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q5173',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q6309479': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q16012945': ['Q30185',
#   'Q174834',
#   'Q895526',
#   'Q2285706',
#   'Q10547393',
#   'Q17279032',
#   'Q116783387',
#   'Q214339',
#   'Q106559804',
#   'Q82955',
#   'Q294414',
#   'Q11997597',
#   'Q103838820',
#   'Q702269',
#   'Q4897819',
#   'Q4164871',
#   'Q24229398',
#   'Q327055',
#   'Q123241435',
#   'Q53617489',
#   'Q129586023',
#   'Q103940464',
#   'Q123240632',
#   'Q35120',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383'],
#  'Q7796018': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q1338895': ['Q11631',
#   'Q901',
#   'Q373021',
#   'Q22813352',
#   'Q1650915',
#   'Q20826540',
#   'Q5184855',
#   'Q11998775',
#   'Q120706493',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q15980158',
#   'Q66666685',
#   'Q327055',
#   'Q23640580',
#   'Q4897819',
#   'Q56148021',
#   'Q345844',
#   'Q129586023',
#   'Q874405',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q123241435',
#   'Q36180',
#   'Q12713481',
#   'Q99576475',
#   'Q1914017',
#   'Q223557',
#   'Q66394244',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q1639378',
#   'Q16334295',
#   'Q703534',
#   'Q1191714',
#   'Q53617489',
#   'Q28640',
#   'Q123240632',
#   'Q12737077',
#   'Q4406616',
#   'Q53617407',
#   'Q2500638',
#   'Q852998',
#   'Q58778',
#   'Q16334298',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q99527517',
#   'Q12777906',
#   'Q1807498',
#   'Q61961344',
#   'Q35120',
#   'Q214339',
#   'Q4164871',
#   'Q830077',
#   'Q98119401'],
#  'Q30': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q2061': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q2095567': ['Q12136',
#   'Q2057971',
#   'Q2996394',
#   'Q7189713',
#   'Q17320256',
#   'Q64732777',
#   'Q813912',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1322005',
#   'Q483247',
#   'Q937228',
#   'Q3249551',
#   'Q30241068',
#   'Q7048977',
#   'Q20937557',
#   'Q67518978',
#   'Q35120',
#   'Q16889133',
#   'Q58415929',
#   'Q5127848',
#   'Q488383',
#   'Q99527517'],
#  'Q863724': ['Q9655',
#   'Q66392784',
#   'Q112826975',
#   'Q27162539',
#   'Q4406616',
#   'Q488383',
#   'Q27162500',
#   'Q35120',
#   'Q27162596',
#   'Q4936952',
#   'Q27062218',
#   'Q27043948',
#   'Q55568967',
#   'Q20088819',
#   'Q16887380',
#   'Q53617407',
#   'Q66394244',
#   'Q6671777',
#   'Q16686022',
#   'Q99527517',
#   'Q223557',
#   'Q1970309',
#   'Q53617489',
#   'Q27043950',
#   'Q103940464'],
#  'Q3040392': ['Q347210'],
#  'Q240886': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q8019899': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q17593': ['Q1248784',
#   'Q43229',
#   'Q62447',
#   'Q12819564',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q811979',
#   'Q20977775',
#   'Q41176',
#   'Q548662',
#   'Q55006986',
#   'Q228332',
#   'Q376799',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q58778',
#   'Q16334298',
#   'Q13226383',
#   'Q24229398',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q618123',
#   'Q121359',
#   'Q35145743',
#   'Q16686448',
#   'Q35120',
#   'Q8205328',
#   'Q15710813',
#   'Q27096235',
#   'Q61961344',
#   'Q53617489',
#   'Q6671777',
#   'Q27096213',
#   'Q223557',
#   'Q1454986',
#   'Q103940464',
#   'Q98119401',
#   'Q4406616',
#   'Q53617407',
#   'Q123349660'],
#  'Q3088005': ['Q11338576',
#   'Q2066131',
#   'Q11124885',
#   'Q50995749',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q573113': ['Q347210'],
#  'Q17002172': ['Q347210'],
#  'Q25247528': ['Q8502',
#   'Q35145263',
#   'Q106589819',
#   'Q618123',
#   'Q16686022',
#   'Q27096220',
#   'Q115385384',
#   'Q271669',
#   'Q2221906',
#   'Q12766313',
#   'Q27096213',
#   'Q223557',
#   'Q1970309',
#   'Q15989253',
#   'Q4406616',
#   'Q53617407',
#   'Q488383',
#   'Q35120',
#   'Q123349660',
#   'Q53617489',
#   'Q103940464'],
#  'Q2264329': ['Q9655',
#   'Q66392784',
#   'Q112826975',
#   'Q27162539',
#   'Q4406616',
#   'Q488383',
#   'Q27162500',
#   'Q35120',
#   'Q27162596',
#   'Q4936952',
#   'Q27062218',
#   'Q27043948',
#   'Q55568967',
#   'Q20088819',
#   'Q16887380',
#   'Q53617407',
#   'Q66394244',
#   'Q6671777',
#   'Q16686022',
#   'Q99527517',
#   'Q223557',
#   'Q1970309',
#   'Q53617489',
#   'Q27043950',
#   'Q103940464'],
#  'Q302699': ['Q5113',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q15107219': ['Q347210'],
#  'Q1000240': ['Q29182',
#   'Q352507',
#   'Q831474',
#   'Q1423891',
#   'Q1638918',
#   'Q4164871',
#   'Q112074151',
#   'Q42603',
#   'Q3315492',
#   'Q105200223',
#   'Q214339',
#   'Q2259532',
#   'Q4897819',
#   'Q4504549',
#   'Q123241435',
#   'Q17573152',
#   'Q123240632',
#   'Q215627',
#   'Q103940464',
#   'Q795052',
#   'Q3778211',
#   'Q35120',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383'],
#  'Q2579107': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q2082964': ['Q34700'],
#  'Q457306': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q1365454': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q794': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q154957': ['Q634',
#   'Q400144',
#   'Q3132741',
#   'Q16873378',
#   'Q6999',
#   'Q16686022',
#   'Q15731960',
#   'Q223557',
#   'Q1970309',
#   'Q4406616',
#   'Q53617407',
#   'Q488383',
#   'Q35120',
#   'Q53617489',
#   'Q103940464'],
#  'Q2373666': ['Q34700'],
#  'Q11299': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q414': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q50054': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q46992817': ['Q1247845'],
#  'Q1367327': ['Q41298',
#   'Q11032',
#   'Q11033',
#   'Q340169',
#   'Q1002697',
#   'Q119648442',
#   'Q28877',
#   'Q43229',
#   'Q17172633',
#   'Q117208269',
#   'Q121182',
#   'Q12774177',
#   'Q732577',
#   'Q2217301',
#   'Q1261026',
#   'Q2897903',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q58778',
#   'Q2424752',
#   'Q49848',
#   'Q115668308',
#   'Q234460',
#   'Q7725310',
#   'Q28314507',
#   'Q35825432',
#   'Q1193236',
#   'Q117208263',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q488383',
#   'Q99527517',
#   'Q47461344',
#   'Q107435521',
#   'Q58415929',
#   'Q17489659',
#   'Q17537576',
#   'Q20937557',
#   'Q16334298',
#   'Q26907166',
#   'Q35120',
#   'Q24229398',
#   'Q131085629',
#   'Q386724',
#   'Q17538423',
#   'Q16686448',
#   'Q61961344',
#   'Q16887380',
#   'Q16889133',
#   'Q53617489',
#   'Q1554231',
#   'Q3523102',
#   'Q31464082',
#   'Q5127848',
#   'Q7048977',
#   'Q103940464',
#   'Q98119401'],
#  'Q1904': ['Q1247845'],
#  'Q25330': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q96390221': ['Q7257',
#   'Q49447',
#   'Q12558574',
#   'Q71966963',
#   'Q595523',
#   'Q2145290',
#   'Q1272626',
#   'Q3695082',
#   'Q386724',
#   'Q488383',
#   'Q16686448',
#   'Q35120'],
#  'Q406798': ['Q46970',
#   'Q1875615',
#   'Q740752',
#   'Q18019760',
#   'Q783794',
#   'Q4830453',
#   'Q29933786',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q43229',
#   'Q155076',
#   'Q167037',
#   'Q12569864',
#   'Q24229398',
#   'Q854457',
#   'Q1639378',
#   'Q106559804',
#   'Q106668099',
#   'Q16334298',
#   'Q53617489',
#   'Q58778',
#   'Q61961344',
#   'Q103940464',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q98119401'],
#  'Q1365283': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q2394382': ['Q482994',
#   'Q108346082',
#   'Q2188189',
#   'Q16887380',
#   'Q838948',
#   'Q99527517',
#   'Q17537576',
#   'Q35120',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q235589': ['Q10811',
#   'Q19159',
#   'Q25241',
#   'Q777371',
#   'Q10915',
#   'Q729',
#   'Q159344',
#   'Q150866',
#   'Q3059449',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q5173',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q4960824': ['Q2066131',
#   'Q50995749',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q38': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q1747456': ['Q1247845'],
#  'Q7817': ['Q1320047',
#   'Q2085381',
#   'Q783794',
#   'Q105044823',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q874260': ['Q29182',
#   'Q352507',
#   'Q831474',
#   'Q1423891',
#   'Q1638918',
#   'Q4164871',
#   'Q112074151',
#   'Q42603',
#   'Q3315492',
#   'Q105200223',
#   'Q214339',
#   'Q2259532',
#   'Q4897819',
#   'Q4504549',
#   'Q123241435',
#   'Q17573152',
#   'Q123240632',
#   'Q215627',
#   'Q103940464',
#   'Q795052',
#   'Q3778211',
#   'Q35120',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383'],
#  'Q79': ['Q1247845'],
#  'Q9535': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q31': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q7391737': ['Q11446',
#   'Q1229765',
#   'Q16391167',
#   'Q20980497',
#   'Q42889',
#   'Q106668099',
#   'Q8205328',
#   'Q11019',
#   'Q106839123',
#   'Q115797408',
#   'Q223557',
#   'Q386724',
#   'Q16686448',
#   'Q488383',
#   'Q131085629',
#   'Q1183543',
#   'Q35825432',
#   'Q4406616',
#   'Q53617407',
#   'Q35120',
#   'Q10273457',
#   'Q12774177',
#   'Q2424752',
#   'Q3406743',
#   'Q24229398',
#   'Q39546',
#   'Q1836700',
#   'Q26902962',
#   'Q53617489',
#   'Q123691918',
#   'Q1485500',
#   'Q2897903',
#   'Q103940464',
#   'Q28877',
#   'Q337060',
#   'Q58415929'],
#  'Q1272502': ['Q1320047',
#   'Q2085381',
#   'Q783794',
#   'Q105044823',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q44634': ['Q233765'],
#  'Q23093': ['Q34700'],
#  'Q3938324': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q7814966': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q7717493': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q11805': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q745967': ['Q3918',
#   'Q38723',
#   'Q4671277',
#   'Q123349660',
#   'Q2385804',
#   'Q31855',
#   'Q53617407',
#   'Q1664720',
#   'Q16519632',
#   'Q2169973',
#   'Q5341295',
#   'Q53617489',
#   'Q43229',
#   'Q13420330',
#   'Q103940464',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q1415187',
#   'Q35120',
#   'Q58778',
#   'Q12569864',
#   'Q24229398',
#   'Q16334298',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q1989': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q1517478': ['Q3918',
#   'Q38723',
#   'Q4671277',
#   'Q123349660',
#   'Q2385804',
#   'Q31855',
#   'Q53617407',
#   'Q1664720',
#   'Q16519632',
#   'Q2169973',
#   'Q5341295',
#   'Q53617489',
#   'Q43229',
#   'Q13420330',
#   'Q103940464',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q1415187',
#   'Q35120',
#   'Q58778',
#   'Q12569864',
#   'Q24229398',
#   'Q16334298',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q2743416': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q94992': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q6111118': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q16240662': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q844822': ['Q1320047',
#   'Q2085381',
#   'Q783794',
#   'Q105044823',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q6231': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q4788499': ['Q482994',
#   'Q108346082',
#   'Q2188189',
#   'Q16887380',
#   'Q838948',
#   'Q99527517',
#   'Q17537576',
#   'Q35120',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q237229': ['Q265868',
#   'Q629103',
#   'Q24060765',
#   'Q112826975',
#   'Q2424752',
#   'Q28969293',
#   'Q712378',
#   'Q25570959',
#   'Q4406616',
#   'Q4936952',
#   'Q488383',
#   'Q55568967',
#   'Q1783121',
#   'Q3405827',
#   'Q35120',
#   'Q10683158',
#   'Q214609',
#   'Q16686022',
#   'Q27043948',
#   'Q6671777',
#   'Q99527517',
#   'Q28555911',
#   'Q223557',
#   'Q1970309',
#   'Q53617407',
#   'Q66394244',
#   'Q6005984',
#   'Q53617489',
#   'Q27043950',
#   'Q10547012',
#   'Q103940464',
#   'Q35758',
#   'Q28732711',
#   'Q378078'],
#  'Q151093': ['Q634',
#   'Q400144',
#   'Q3132741',
#   'Q16873378',
#   'Q6999',
#   'Q16686022',
#   'Q15731960',
#   'Q223557',
#   'Q1970309',
#   'Q4406616',
#   'Q53617407',
#   'Q488383',
#   'Q35120',
#   'Q53617489',
#   'Q103940464'],
#  'Q80440': ['Q36180',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q2500638',
#   'Q215627',
#   'Q12777906',
#   'Q795052',
#   'Q3778211',
#   'Q830077',
#   'Q24229398',
#   'Q7239',
#   'Q53617489',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q103940464',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q35120',
#   'Q488383'],
#  'Q932601': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q7630977': ['Q9620',
#   'Q203850',
#   'Q66506231',
#   'Q112826975',
#   'Q40397',
#   'Q27162539',
#   'Q4406616',
#   'Q289472',
#   'Q4936952',
#   'Q27062218',
#   'Q28969293',
#   'Q488383',
#   'Q27162500',
#   'Q214609',
#   'Q35120',
#   'Q27043948',
#   'Q55568967',
#   'Q20088819',
#   'Q27162596',
#   'Q1783121',
#   'Q3405827',
#   'Q2424752',
#   'Q10683158',
#   'Q16686022',
#   'Q16887380',
#   'Q53617407',
#   'Q66394244',
#   'Q6671777',
#   'Q99527517',
#   'Q28555911',
#   'Q223557',
#   'Q1970309',
#   'Q53617489',
#   'Q27043950',
#   'Q6005984',
#   'Q103940464',
#   'Q10547012',
#   'Q35758',
#   'Q28732711',
#   'Q378078'],
#  'Q486704': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q193677': ['Q1247845'],
#  'Q11723186': ['Q216860',
#   'Q4797274',
#   'Q7366',
#   'Q9730',
#   'Q114586269',
#   'Q1583807',
#   'Q115484611',
#   'Q207628',
#   'Q7725634',
#   'Q105543609',
#   'Q2188189',
#   'Q47461344',
#   'Q15621286',
#   'Q11461',
#   'Q116474095',
#   'Q626707',
#   'Q3882459',
#   'Q838948',
#   'Q386724',
#   'Q1437361',
#   'Q21146257',
#   'Q16686448',
#   'Q4080565',
#   'Q17537576',
#   'Q2085518',
#   'Q3882429',
#   'Q16889133',
#   'Q1292119',
#   'Q6671777',
#   'Q1132631',
#   'Q37172',
#   'Q488383',
#   'Q5127848',
#   'Q7048977',
#   'Q170475',
#   'Q35120',
#   'Q1207505',
#   'Q99527517',
#   'Q1150070',
#   'Q937228',
#   'Q67518978',
#   'Q58415929'],
#  'Q960774': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q7989007': ['Q783794',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q28228463': ['Q1320047',
#   'Q2085381',
#   'Q783794',
#   'Q105044823',
#   'Q3778211',
#   'Q16334295',
#   'Q21980538',
#   'Q106559804',
#   'Q16334298',
#   'Q43229',
#   'Q854457',
#   'Q1639378',
#   'Q106668099',
#   'Q61961344',
#   'Q24229398',
#   'Q58778',
#   'Q53617489',
#   'Q98119401',
#   'Q488383',
#   'Q131085629',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q2003': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q2043896': ['Q43115',
#   'Q4120621',
#   'Q17573152',
#   'Q5127848',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7048977',
#   'Q99527517',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q35120',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383'],
#  'Q854': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
# ...
#   'Q16686448',
#   'Q488383'],
#  'Q579766': ['Q347210'],
#  'Q157305': ['Q634',
#   'Q400144',
#   'Q3132741',
#   'Q16873378',
#   'Q6999',
#   'Q16686022',
#   'Q15731960',
#   'Q223557',
#   'Q1970309',
#   'Q4406616',
#   'Q53617407',
#   'Q488383',
#   'Q35120',
#   'Q53617489',
#   'Q103940464'],
#  'Q157228': ['Q7377',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q646396': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q2746012': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q159': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q1364045': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q132204': ['Q233765'],
#  'Q1542805': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q7637091': ['Q482994',
#   'Q108346082',
#   'Q2188189',
#   'Q16887380',
#   'Q838948',
#   'Q99527517',
#   'Q17537576',
#   'Q35120',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q974': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q121842': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q2244260': ['Q43115',
#   'Q4120621',
#   'Q17573152',
#   'Q5127848',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7048977',
#   'Q99527517',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q35120',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383'],
#  'Q55415': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q385689': ['Q1247845'],
#  'Q188661': ['Q1247845'],
#  'Q872670': ['Q29182',
#   'Q352507',
#   'Q831474',
#   'Q1423891',
#   'Q1638918',
#   'Q4164871',
#   'Q112074151',
#   'Q42603',
#   'Q3315492',
#   'Q105200223',
#   'Q214339',
#   'Q2259532',
#   'Q4897819',
#   'Q4504549',
#   'Q123241435',
#   'Q17573152',
#   'Q123240632',
#   'Q215627',
#   'Q103940464',
#   'Q795052',
#   'Q3778211',
#   'Q35120',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383'],
#  'Q2028': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q1771432': ['Q43115',
#   'Q4120621',
#   'Q17573152',
#   'Q5127848',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7048977',
#   'Q99527517',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q35120',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383'],
#  'Q5604610': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q28198': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q188813': ['Q1247845'],
#  'Q4665228': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q134553': ['Q157114'],
#  'Q1877325': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q2436423': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q1055279': ['Q25326',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q32461': ['Q233765'],
#  'Q23159': ['Q82794',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q58415929',
#   'Q123349660',
#   'Q124711467',
#   'Q488383',
#   'Q53617407',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q3762059': ['Q43115',
#   'Q4120621',
#   'Q17573152',
#   'Q5127848',
#   'Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7048977',
#   'Q99527517',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q35120',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383'],
#  'Q148': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  'Q3759642': ['Q152',
#   'Q1230015',
#   'Q1756633',
#   'Q845214',
#   'Q729',
#   'Q11710365',
#   'Q159344',
#   'Q16334298',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q61961344',
#   'Q4406616',
#   'Q53617407',
#   'Q98119401',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q99527517',
#   'Q35120',
#   'Q103940464'],
#  'Q949879': ['Q36180',
#   'Q482980',
#   'Q483501',
#   'Q108762424',
#   'Q2500638',
#   'Q215627',
#   'Q12777906',
#   'Q795052',
#   'Q3778211',
#   'Q830077',
#   'Q24229398',
#   'Q7239',
#   'Q53617489',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q103940464',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q35120',
#   'Q488383'],
#  'Q2040970': ['Q11707',
#   'Q41176',
#   'Q13226383',
#   'Q27077054',
#   'Q811979',
#   'Q121359',
#   'Q8205328',
#   'Q27096235',
#   'Q27038993',
#   'Q62602544',
#   'Q6671777',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q223557',
#   'Q16686448',
#   'Q4830453',
#   'Q88985865',
#   'Q27096213',
#   'Q4406616',
#   'Q53617407',
#   'Q618123',
#   'Q43229',
#   'Q155076',
#   'Q167037',
#   'Q12569864',
#   'Q99527517',
#   'Q15710813',
#   'Q488383',
#   'Q123349660',
#   'Q12047291',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q3778211',
#   'Q783794',
#   'Q35120',
#   'Q1454986',
#   'Q53617489',
#   'Q21980538',
#   'Q58778',
#   'Q16334298',
#   'Q103940464',
#   'Q24229398',
#   'Q131085629',
#   'Q61961344',
#   'Q98119401'],
#  'Q380875': ['Q42973',
#   'Q255274',
#   'Q5322166',
#   'Q703534',
#   'Q483501',
#   'Q2500638',
#   'Q327055',
#   'Q852998',
#   'Q215627',
#   'Q12777906',
#   'Q795052',
#   'Q3778211',
#   'Q129586023',
#   'Q24229398',
#   'Q830077',
#   'Q7239',
#   'Q53617489',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q103940464',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q35120',
#   'Q488383'],
#  'Q7623335': ['Q25326',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q8057437': ['Q347210'],
#  'Q6135122': ['Q42973',
#   'Q255274',
#   'Q5322166',
#   'Q703534',
#   'Q483501',
#   'Q2500638',
#   'Q327055',
#   'Q852998',
#   'Q215627',
#   'Q12777906',
#   'Q795052',
#   'Q3778211',
#   'Q129586023',
#   'Q24229398',
#   'Q830077',
#   'Q7239',
#   'Q53617489',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q103940464',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q35120',
#   'Q488383'],
#  'Q15487229': ['Q7377',
#   'Q25241',
#   'Q10915',
#   'Q150866',
#   'Q3059449',
#   'Q5173',
#   'Q729',
#   'Q159344',
#   'Q7239',
#   'Q223557',
#   'Q66394244',
#   'Q4406616',
#   'Q53617407',
#   'Q27043950',
#   'Q488383',
#   'Q53617489',
#   'Q35120',
#   'Q103940464'],
#  'Q6246121': ['Q215627',
#   'Q795052',
#   'Q3778211',
#   'Q7239',
#   'Q24229398',
#   'Q106559804',
#   'Q223557',
#   'Q66394244',
#   'Q53617489',
#   'Q4406616',
#   'Q53617407',
#   'Q103940464',
#   'Q27043950',
#   'Q488383',
#   'Q35120'],
#  'Q7994924': ['Q41176',
#   'Q811979',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q16686448',
#   'Q618123',
#   'Q8205328',
#   'Q15710813',
#   'Q27096213',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q488383',
#   'Q4406616',
#   'Q53617407',
#   'Q35120',
#   'Q58778',
#   'Q99527517',
#   'Q123349660',
#   'Q53617489',
#   'Q103940464'],
#  'Q595995': ['Q571',
#   'Q49848',
#   'Q340169',
#   'Q732577',
#   'Q2424752',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q12774177',
#   'Q115668308',
#   'Q488383',
#   'Q16686448',
#   'Q35120',
#   'Q35825432',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q3708367': ['Q515',
#   'Q7930989',
#   'Q124250988',
#   'Q3257686',
#   'Q486972',
#   'Q702492',
#   'Q618123',
#   'Q18247357',
#   'Q123964505',
#   'Q82794',
#   'Q48907157',
#   'Q26713767',
#   'Q27096213',
#   'Q811979',
#   'Q17489659',
#   'Q66661745',
#   'Q99018632',
#   'Q15989253',
#   'Q27096235',
#   'Q386724',
#   'Q811430',
#   'Q11908691',
#   'Q35120',
#   'Q16887380',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q16686448',
#   'Q61961344',
#   'Q8205328',
#   'Q15710813',
#   'Q488383',
#   'Q99527517',
#   'Q58415929',
#   'Q98119401',
#   'Q53617407',
#   'Q124711467',
#   'Q223557',
#   'Q1454986',
#   'Q6671777',
#   'Q53617489',
#   'Q4406616',
#   'Q58778',
#   'Q103940464'],
#  'Q16693': ['Q34700'],
#  'Q1364278': ['Q34876',
#   'Q56061',
#   'Q15642541',
#   'Q16562419',
#   'Q82794',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q618123',
#   'Q26713767',
#   'Q7210356',
#   'Q1048835',
#   'Q18810687',
#   'Q16686448',
#   'Q27096213',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q58415929',
#   'Q53617407',
#   'Q124711467',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q845200': ['Q11446',
#   'Q1229765',
#   'Q16391167',
#   'Q20980497',
#   'Q42889',
#   'Q106668099',
#   'Q8205328',
#   'Q11019',
#   'Q106839123',
#   'Q115797408',
#   'Q223557',
#   'Q386724',
#   'Q16686448',
#   'Q488383',
#   'Q131085629',
#   'Q1183543',
#   'Q35825432',
#   'Q4406616',
#   'Q53617407',
#   'Q35120',
#   'Q10273457',
#   'Q12774177',
#   'Q2424752',
#   'Q3406743',
#   'Q24229398',
#   'Q39546',
#   'Q1836700',
#   'Q26902962',
#   'Q53617489',
#   'Q123691918',
#   'Q1485500',
#   'Q2897903',
#   'Q103940464',
#   'Q28877',
#   'Q337060',
#   'Q58415929'],
#  'Q212': ['Q6256',
#   'Q1048835',
#   'Q4835091',
#   'Q56061',
#   'Q82794',
#   'Q15642541',
#   'Q16562419',
#   'Q618123',
#   'Q26713767',
#   'Q27096213',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q7210356',
#   'Q18810687',
#   'Q58415929',
#   'Q123349660',
#   'Q16686448',
#   'Q124711467',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q53617407',
#   'Q53617489',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q103940464',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q61961344',
#   'Q98119401'],
#  ...}

# %%
from tqdm import tqdm


tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)



cea_values_dict = dict(zip(df_cea[3], df_cea["key_col"].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.values()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {}
for k,v in cea_values_dict.items():
    try:
        combined_dict[k] = cta_values_dict[v]
    except:
        pass


WD_query_type = {}

# Wrap the values of the dictionary in tqdm for a progress bar
for key, value in tqdm(combined_dict.items(), desc="Processing items"):
    key = key.split('/')[-1]
    result = None
    item_id = value.split('/')[-1]

    WD_query_type[key] = item_id  # Store the result (or None if no non-empty list found)

with open('HTR3_WD_query_type.json', 'w') as json_file:
    json.dump(WD_query_type, json_file, indent=4)
# Out:
# Processing items: 100%|██████████| 47171/47171 [00:00<00:00, 312960.92it/s]

# %%
def make_json_serializable(obj):
    """
    Recursively converts non-serializable objects in the dictionary
    to JSON-serializable formats.
    """
    if isinstance(obj, set):
        return list(obj)  # Convert sets to lists
    elif isinstance(obj, dict):
        return {k: make_json_serializable(v) for k, v in obj.items()}  # Recurse for nested dictionaries
    elif isinstance(obj, list):
        return [make_json_serializable(i) for i in obj]  # Recurse for lists
    else:
        return obj  # Return the object if it's already serializable

# Convert subsample to a JSON-serializable format
serializable_subsample = make_json_serializable(ext_WD_query_type)

# %%
with open('ext_WD_query_type.json', 'w') as json_file:
    json.dump(serializable_subsample, json_file, indent=4)

# %% [markdown]
# ## NER type vs NER type

# %%
import json 

json_file_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/_HTR2/HTR2_ext_WD_query_type.json"

with open(json_file_path, "r") as file:
    HTR2_type = json.load(file)


tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))

cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
HTR2_id_to_name = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    HTR2_id_to_name.update(local_key_to_cell)
# Out:
# Processing tables:   0%|          | 0/2692 [00:00<?, ?it/s]2025-01-27 17:10:29,461 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00CU42PU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,464 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00CYT0VB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,466 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00DZN9U3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,469 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00EDPHR0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,472 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00F4DDB8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,474 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00FMZR04.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,476 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GGKUQD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,479 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GNBCGP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,481 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GOZ03E.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,491 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00HPZYRV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,494 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00JE18BI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,496 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00K4PJEK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,498 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00KWWZMZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,500 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00L77STZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,504 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LFR1E5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,507 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LGNCH3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,510 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LS08FM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,513 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00MIIBFM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,516 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00MK33P9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,519 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00NSYDVX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,522 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00PGPISM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,525 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00QTPROV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,528 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00R2ATEA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,530 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00R7H94P.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,533 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00RCO58K.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,536 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00S6UHNA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,537 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SICZG9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,544 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SNTAT7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,548 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SUXIX5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,550 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SWQK0C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,554 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00TUX8XW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,556 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00U3XK6Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,560 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00VBFQFM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   1%|          | 33/2692 [00:00<00:08, 325.88it/s]2025-01-27 17:10:29,565 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00VRSGHB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,570 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00WWU6C1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,572 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00X3HWSL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,577 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00X5RZSX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,582 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YA2Y7C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,586 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YK6JKU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,589 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YVFD97.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,593 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00Z16W5U.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,597 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00ZCYS1R.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,601 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A0AS275.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,604 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A0XQ1B1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,608 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A2OYVSJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,613 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A2WQW7B.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,618 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A3X0RVB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,623 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A40SP59.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,626 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A47VEYU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,629 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A49Y1OZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,632 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A5XRYWU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,637 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A6SD2NW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,641 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A79T5C3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,647 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A7O05AT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,649 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A82DDWZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,652 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A8CQRPP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,655 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A8YOSGJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,664 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A957H2A.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,668 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AA6VXI0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,676 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AAAXONZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,679 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ABVZ7WS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,683 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AC7LR6S.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,689 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ADLUR97.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,692 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ADP4J7T.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,696 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AE5UUR4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,702 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AEBQS4Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   2%|▏         | 66/2692 [00:00<00:10, 249.00it/s]2025-01-27 17:10:29,733 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFMSPIX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,738 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFSK7PV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,742 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFV61HL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,746 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGFL0LE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,751 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGL72LH.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,759 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGXEWOY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,762 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AI297WG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,765 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AI6ZW9E.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,767 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AKRZY29.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,773 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ALSPPLR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,776 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AM28GPA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,780 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMA8HF3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,783 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMKG9SX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,786 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMPIB6Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,789 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AN2OB8N.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,792 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AN589PA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,795 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0APS6Q33.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,798 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0APW2YH4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,800 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQCSHWE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,804 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQG4N6O.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,808 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQV1YV2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,812 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASCCQQM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,814 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASWF8TB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,816 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASZDQYD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,818 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AULRJGX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,821 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AUQDLS2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   3%|▎         | 92/2692 [00:00<00:10, 247.13it/s]2025-01-27 17:10:29,825 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AUXAQPV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,829 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AWUAT0K.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,833 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AWZR9TN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,836 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AX5SV4Q.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,839 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AX7B6Z1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,842 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AXKNG2W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,844 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AXX6WNU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,847 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AY17XJZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,851 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AY9DYOB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,853 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AYKMIEM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,856 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AYNO7JO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,860 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AZ6T10W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,864 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AZ9UQJQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,867 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B1QKI5W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,871 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B5RKA93.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,873 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B6YGAWH.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,876 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B8IRSSE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,878 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B8THYJX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,880 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B9WJ1FD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,884 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BAJKOQO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,887 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BANNY8Z.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,890 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BARW1G0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,897 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BAWNWTP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,900 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BB4NJY1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,908 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BB5E6V7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,926 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BBBRYCD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   4%|▍         | 118/2692 [00:00<00:10, 247.21it/s]2025-01-27 17:10:29,933 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BC2M2VE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,946 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BCGHJ96.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,949 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BEFRNL7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,954 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BEMPYG9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,957 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHG6DQR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,962 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHHXTT1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,964 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHKN3H3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,966 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BKRY93H.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,969 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BMFKR9L.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,973 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BMJ7L65.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,976 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BN85228.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,978 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BNO82FL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,981 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BNZO6S6.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:29,984 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BPELMAE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,005 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQ46XMT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,010 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQKJMN4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,013 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQLMQY3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,015 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQZ5G1D.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,017 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQZ6MDX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,019 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BRZ7UTV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,024 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BTG9ZEG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,026 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BTPAK79.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,028 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BW9VXHN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,031 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BWE6ZO8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,035 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BY5XPBI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,039 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYE13JU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   5%|▌         | 144/2692 [00:00<00:10, 240.73it/s]2025-01-27 17:10:30,044 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYK1UP3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,046 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYP7QK9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,052 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYXE5G9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,055 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYY5ZHU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,057 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BZO0CNX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,059 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C2MERDT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,064 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C52KOJJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,067 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C7O7AF4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,070 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C8F8KJG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,074 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CA1IPHM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,077 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CBBWSUG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,079 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CD1MGB7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,081 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CDFFQWF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,083 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CESCQRE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,086 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CGHST2P.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,090 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CGLF62X.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,092 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CHHMIKE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,095 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CHKINC6.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,097 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CI4VFJ0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,101 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CI6HELZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,104 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CIBCE5G.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,107 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CJ0TTEJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,108 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CJJ6CGV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,111 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CMDZ939.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,114 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CMPE48Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,119 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CN96B6I.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,123 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CNDHSHN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,124 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CNVNHPL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,127 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CP17WG5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,130 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CP74NKC.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,136 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CPYJI4V.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,139 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CQG4XP7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   7%|▋         | 176/2692 [00:00<00:09, 264.59it/s]2025-01-27 17:10:30,143 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CRGR4RI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,146 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CRLOV5T.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,149 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CSQCPY5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,152 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CSY2BWG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,156 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CT6U7B9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,159 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CTDNYG5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,161 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CTQ4RR5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,163 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CVVLTV5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,165 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CWAVBMX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,167 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CWT5QSM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,169 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CYCQ67G.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,171 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D03T8F7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,173 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D0GKHTG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,176 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D0JRBCR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,177 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D1ZEOSI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,179 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D3DVCVY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,181 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D4OERRB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,183 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D5COVM8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,186 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D7LE2GF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,189 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D8TPEJV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,190 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DA1WOUR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,192 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DAQB4CK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,195 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DASDX1W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:30,198 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DBCG9M7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# ...
# 2025-01-27 17:10:32,386 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4E409TWU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,389 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4E4VQ5Y0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,394 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ECV2TGR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:  33%|███▎      | 879/2692 [00:02<00:05, 308.47it/s]2025-01-27 17:10:32,416 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EEB5JI0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,419 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EJEGCR0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,421 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EKILPI5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,427 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F20WVE5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,430 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F2FZH4N.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,433 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F5ZPLMK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,436 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FCQJD2D.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,439 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FGQTBA2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,441 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FJIKSI8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,443 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FMKABBS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,446 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FSUM1A0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,448 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FWYU9N4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,450 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FYVEARM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,487 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4G64HVKW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,491 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GHEPS9W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,493 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GUJGVT2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,495 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GVQFQ1F.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,497 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4H2CLYND.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,499 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HA0JUWY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,500 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HA6M87Z.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,502 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HR2K0KQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,505 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HRM34WT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,508 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HVVS5DC.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,510 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I3EOHAZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,512 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I5Z6FZT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,515 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I6TVFFO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,518 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IA0LVHR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,521 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ID21YJ5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,524 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IH24V21.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,527 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4II8ICTZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,529 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IMX1J20.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,532 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4J7QIUZD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,533 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JJIT8HP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:  34%|███▍      | 912/2692 [00:03<00:06, 293.83it/s]2025-01-27 17:10:32,537 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JKA8NCQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,539 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JKNJ1H7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,541 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JOMPIMS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,543 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JRY6P14.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,544 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JS4P1VA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,548 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JVTNJTW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,549 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4K40T4IL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,553 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4K9C7F7U.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,556 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4KYYIHUS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,558 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4KZ3TKWN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,560 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4L196DQA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,561 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4L2TORPT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,564 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LCE1UOV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,566 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LD9PGVF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,588 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LKMOFLR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,594 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LODO3MM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,596 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LR8KT7C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,600 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LUX91EA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,601 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LZ3MLAP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,604 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M0NMNAN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,606 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M1OB5QY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,608 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M533Y9W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,609 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MF6FUXO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,611 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ML8COI9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,613 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MN56JAB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,615 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MR41RNG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,619 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MTAJ87Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,623 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MVZ4KVA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,626 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4N8OGCD7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-27 17:10:32,629 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4NFRQ6R5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables: 100%|██████████| 2692/2692 [00:08<00:00, 319.94it/s]

# %% [markdown]
# ### CREATION OF THE QUERY HARD

# %%
def get_query(name, value):
    name = str(name).replace('"', ' ')
    if value is not None:
        # hard filtering constraint
        query_dict = {
            "query": {
                "bool": {
                    "must": [
                        {"match": {"name": {"query": name, "boost": 2.0}}},
                        {"terms": {"extended_WDtypes": value}}  # Ensures `value` matches at least one in the array
                    ]
                }
            }
        }
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 20,
            'query': json.dumps(query_dict),  # Convert the query dictionary to a JSON string
            'sort': [
                '{"popularity": {"order": "desc"}}'
            ]
        }
    
    return params


queries = []
for id, name in tqdm(HTR2_id_to_name.items()):
    if id in HTR2_type:
        types_list = HTR2_type[id]

        ########################################################
        ##  modificare se types_list è una lista di tipi
        ########################################################
    
        query = get_query(name, types_list)

        queries.append((query, id, types_list))
        if len(queries) == 4000:
            break
# Out:
#  14%|█▍        | 4012/28030 [00:00<00:00, 33134.42it/s]

# %% [markdown]
# ### CREATION OF THE QUERY SOFT

# %%
def get_query(name, value):
    name = str(name).replace('"', ' ')
    
    if value is not None:
        # Check if value is a list. If it's a list, create multiple `term` clauses; otherwise, use a single `terms` clause.
        should_clause = []
        if isinstance(value, list):
            should_clause = [{"term": {"ext_WD_type": v}} for v in value]
        else:
            should_clause = [{"terms": {"ext_WD_type": [value]}}]

        # Build the query dictionary
        query_dict = {
            "query": {
                "bool": {
                    "must": [
                        {"match": {"name": {"query": name, "boost": 2.0}}}
                    ],
                    "should": should_clause  # Add the dynamically generated should clause
                }
            }
        }

        # Build the parameters dictionary
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 20,
            'query': json.dumps(query_dict),  # Convert the query dictionary to a JSON string
            'sort': [
                '{"popularity": {"order": "desc"}}'
            ]
        }
    
        return params


queries = []
for id, name in tqdm(HTR2_id_to_name.items()):
    if id in HTR2_type:
        types_list = HTR2_type[id]

        ########################################################
        ##  modificare se types_list è una lista di tipi
        ########################################################
    
        query = get_query(name, types_list)

        queries.append((query, id, types_list))
        if len(queries) == 4000:
            break
# Out:
#   0%|          | 0/28030 [00:00<?, ?it/s]
#  14%|█▍        | 4012/28030 [00:00<00:00, 40476.52it/s]

# %%
import aiohttp
import asyncio
import backoff
import nest_asyncio
import random
from tqdm import tqdm
import numpy as np

# Assume queries is a list of tuples [(param1, id1), (param2, id2), ...]

failed_queries = {}
url = 'http://localhost:5000/lookup/entity-retrieval'

# Backoff decorator for handling retries with exponential backoff
@backoff.on_exception(
    backoff.expo, 
    (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError, asyncio.TimeoutError), 
    max_tries=10, 
    max_time=400
)
async def fetch(session, url, params, headers, semaphore):
    async with semaphore:
        # Convert all params to str, int, or float
        #params = {k: (int(v) if isinstance(v, np.integer) else str(v)) for k, v in params.items()}
        async with session.get(url, params=params, headers=headers, timeout=50) as response:
            try:
                response.raise_for_status()  # Raises an exception for 4XX/5XX status codes
                return await response.json()
            except asyncio.TimeoutError:
                print(f"Request timed out for params: {params}")
                return []  # Return an empty list to handle the timeout gracefully
            except aiohttp.ClientError as e:
                print(f"ClientError for params : {str(e)}")
                return []
            except Exception as e:
                print(f"Unexpected error for params {params}: {str(e)}")
                return []
async def process_item(session, url, id, headers, params, semaphore, pbar):
    try:
        data = await fetch(session, url, params, headers, semaphore)
    except aiohttp.ClientResponseError as e:
        if e.status == 404:
            print(f"404 Error: Resource not found for '{id}'")
            asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
            return 0, 0
        else:
            raise  # Re-raise the exception for other status codes

    num_result = len(data) if data else 0


    ###################################################
    ## scandisco il candidate set in cui ho già fatto 
    ## l'overlapping dei tipi
    ###################################################
    
    #print(f"------------>{eval(params['query'])['query']['bool']['must'][1]} - # candidate: {len(data)}")
    if data:
        for item in data:
            if id == item.get('id'):
                #print(f"{item.get('name')}: es_score({item.get('es_score', 0)}), pos_score({item.get('pos_score', 0)})-> {item.get('description')}")
                asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
                pos_score = item.get('pos_score', 0)
                if pos_score:
                    mrr_increment = (num_result - (pos_score * num_result)) / num_result
                else:
                    mrr_increment = 1 / num_result  # Assume worst case for MRR if pos_score is 0
                return mrr_increment, 1

    return 0, 0

async def main(queries, url, pbar, failed_queries):
    headers = {'accept': 'application/json'}
    semaphore = asyncio.Semaphore(50)  # Limit to 50 concurrent requests
    m_mrr = 0
    cont_el = 0

    async with aiohttp.ClientSession() as session:
        tasks = []
        for param, id, _ in queries:
            tasks.append(process_item(session, url, id, headers, param, semaphore, pbar))
        
        results = await asyncio.gather(*tasks)
        
        for (mrr_increment, count), (param, id, item_NERtype) in zip(results, queries):
            if mrr_increment == 0 and count == 0:
                failed_queries[id] = (id, item_NERtype)
                
                # redo the same query with the fuzzy
                name = param['name']
                
                # Parse the string into a Python dictionary
                query_dict = json.loads(param['query'])

                # Modify the "match" field
                if "query" in query_dict and "bool" in query_dict["query"] and "must" in query_dict["query"]["bool"]:
                    for condition in query_dict["query"]["bool"]["must"]:
                        if "match" in condition and "name" in condition["match"]:
                            condition["match"]["name"]["fuzziness"] = "AUTO"

                # Convert back to JSON string
                param['query'] = json.dumps(query_dict)
                print(param['query'])

                response = requests.get(url, params=param)
                if response.status_code == 200:
                    data = response.json()
                    #print("after call")
                    num_result = len(data) if data else 0
                    if data:
                        for item in data:
                            if id == item.get('id'):
                                pbar.update(1)  # No need to await here
                                pos_score = item.get('pos_score', 0)
                                if pos_score:
                                    mrr_increment = (num_result - (pos_score * num_result)) / num_result
                                else:
                                    mrr_increment = 1 / num_result  # Assume worst case for MRR if pos_score is 0
                            
                m_mrr += mrr_increment
                cont_el += count 
            else:
                m_mrr += mrr_increment
                cont_el += count

        asyncio.get_event_loop().call_soon_threadsafe(pbar.close)

    print(f"Coverage of 2T: {cont_el / len(queries)}")
    print(f"Measure Reciprocal Rank of 2T: {m_mrr / len(queries)}")

# Check if there's already a running event loop
if __name__ == "__main__":
    nest_asyncio.apply()  # Apply nest_asyncio
    try:
        pbar = tqdm(total=len(queries))
        asyncio.run(main(queries, url, pbar, failed_queries))
    except RuntimeError:  # For environments like Jupyter
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(queries, url, pbar, failed_queries))
# Out:
#   0%|          | 0/4000 [14:37<?, ?it/s]
# 2025-01-27 17:27:22,822 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,839 - INFO - Backing off fetch(...) for 0.7s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,858 - INFO - Backing off fetch(...) for 0.5s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,865 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,873 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,881 - INFO - Backing off fetch(...) for 0.7s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,891 - INFO - Backing off fetch(...) for 0.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,898 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,906 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,916 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,920 - INFO - Backing off fetch(...) for 0.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,926 - INFO - Backing off fetch(...) for 0.7s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,932 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,938 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,966 - INFO - Backing off fetch(...) for 0.5s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,971 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,976 - INFO - Backing off fetch(...) for 0.7s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:22,981 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,986 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,991 - INFO - Backing off fetch(...) for 0.8s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:22,996 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,002 - INFO - Backing off fetch(...) for 1.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,008 - INFO - Backing off fetch(...) for 1.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,035 - INFO - Backing off fetch(...) for 1.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,040 - INFO - Backing off fetch(...) for 0.5s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,045 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,050 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,055 - INFO - Backing off fetch(...) for 0.4s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,059 - INFO - Backing off fetch(...) for 0.6s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,065 - INFO - Backing off fetch(...) for 0.8s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,069 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,073 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,078 - INFO - Backing off fetch(...) for 0.8s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,083 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,086 - INFO - Backing off fetch(...) for 0.6s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,089 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,093 - INFO - Backing off fetch(...) for 0.4s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,097 - INFO - Backing off fetch(...) for 0.4s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,101 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,102 - INFO - Backing off fetch(...) for 0.9s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,106 - INFO - Backing off fetch(...) for 0.8s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,108 - INFO - Backing off fetch(...) for 0.3s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,110 - INFO - Backing off fetch(...) for 0.7s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,112 - INFO - Backing off fetch(...) for 0.6s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,116 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,118 - INFO - Backing off fetch(...) for 0.1s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,121 - INFO - Backing off fetch(...) for 0.2s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# 2025-01-27 17:27:23,124 - INFO - Backing off fetch(...) for 0.6s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,125 - INFO - Backing off fetch(...) for 1.0s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('::1', 5000, 0, 0)])
# 2025-01-27 17:27:23,128 - INFO - Backing off fetch(...) for 0.4s (aiohttp.client_exceptions.ClientConnectorError: Cannot connect to host localhost:5000 ssl:default [Connect call failed ('127.0.0.1', 5000)])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <cell line: 132>()
#     134 try:
#     135     pbar = tqdm(total=len(queries))
# --> 136     asyncio.run(main(queries, url, pbar, failed_queries))
#     137 except RuntimeError:  # For environments like Jupyter
#     138     loop = asyncio.get_event_loop()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      33 task = asyncio.ensure_future(main)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#      37     if not task.done():
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\nest_asyncio.py:83, in _patch_loop.<locals>.run_until_complete(self, future)
#      81     f._log_destroy_pending = False
#      82 while not f.done():
# ---> 83     self._run_once()
#      84     if self._stopping:
#      85         break
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\nest_asyncio.py:106, in _patch_loop.<locals>._run_once(self)
#      99     heappop(scheduled)
#     101 timeout = (
#     102     0 if ready or self._stopping
#     103     else min(max(
#     104         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     105     else None)
# --> 106 event_list = self._selector.select(timeout)
#     107 self._process_events(event_list)
#     109 end_time = self.time() + self._clock_resolution
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
# for each WD type inserted from the user (WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query

ext_query_types = []

for entity_id, type_str in WD_query_type.items():
    #print(f"{type_str}: {get_type_id(type_str)}")
    
    entity_name = key_to_cell[list(WD_query_type.keys())[0]]
    ext_query_types += list(set(retrieve_superclasses(get_type_id(type_str))))
    
    # query a lamapi dove specifico nel filtro il tipo

    # entity_id è il ground truth
    WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
print(ext_query_types)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:377, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376 try:  # Python 2.7, use buffering of HTTP responses
# --> 377     httplib_response = conn.getresponse(buffering=True)
#     378 except TypeError:  # Python 3
#
# TypeError: HTTPConnection.getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 6>()
#       6 for entity_id, type_str in WD_query_type.items():
#       7     #print(f"{type_str}: {get_type_id(type_str)}")
#       9     entity_name = key_to_cell[list(WD_query_type.keys())[0]]
# ---> 10     ext_query_types += list(set(retrieve_superclasses(get_type_id(type_str))))
#      12     # query a lamapi dove specifico nel filtro il tipo
#      14     WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
#
# Input In [3], in get_type_id(entity_name)
#      39 headers = {
#      40     "accept": "application/json"
#      41 }
#      43 try:
# ---> 44     response = requests.get(url, headers=headers, params=params)
#      45     response.raise_for_status()  # Raise an error for HTTP issues
#      46     data = response.json()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594     self._prepare_proxy(conn)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#     606 response_conn = conn if not release_conn else None
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:380, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378 except TypeError:  # Python 3
#     379     try:
# --> 380         httplib_response = conn.getresponse()
#     381     except Exception as e:
#     382         # Remove the TypeError from the exception chain in Python 3;
#     383         # otherwise it looks like a programming error was the cause.
#     384         six.raise_from(e, None)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ext_query_types
# Out:
# ['Q53617489',
#  'Q98119401',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q2217301',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q24229398',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q1554231',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q1193236',
#  'Q121182',
#  'Q61961344',
#  'Q7048977',
#  'Q58415929',
#  'Q1639378',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q35825432',
#  'Q115668308',
#  'Q854457',
#  'Q26907166',
#  'Q17538423',
#  'Q31464082',
#  'Q16686448',
#  'Q107435521',
#  'Q47461344',
#  'Q37866906',
#  'Q17172633',
#  'Q106559804',
#  'Q28314507',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q5127848',
#  'Q35120',
#  'Q17489659',
#  'Q340169',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q103940464',
#  'Q11033',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q103940464',
#  'Q53617489',
#  'Q98119401',
#  'Q7278',
#  'Q16334295',
#  'Q854457',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q155076',
#  'Q7210356',
#  'Q35120',
#  'Q61961344',
#  'Q1639378',
#  'Q131085629',
#  'Q16334298',
#  'Q488383',
#  'Q58778',
#  'Q53617489',
#  'Q830077',
#  'Q4197743',
#  'Q53617407',
#  'Q215627',
#  'Q2066131',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q18536342',
#  'Q27043950',
#  'Q66394244',
#  'Q50995749',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q223557',
#  'Q10871364',
#  'Q103940464',
#  'Q795052',
#  'Q88392887',
#  'Q1424805',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q58180476',
#  'Q58180068',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q1272626',
#  'Q3695082',
#  'Q3861158',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q483501',
#  'Q103940464',
#  'Q53617489',
#  'Q327055',
#  'Q53617407',
#  'Q830077',
#  'Q15980158',
#  'Q66666685',
#  'Q215627',
#  'Q1914017',
#  'Q108762424',
#  'Q24229398',
#  'Q12777906',
#  'Q36180',
#  'Q2500638',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q27043950',
#  'Q1650915',
#  'Q66394244',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q20826540',
#  'Q223557',
#  'Q482980',
#  'Q129586023',
#  'Q795052',
#  'Q901',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q88392887',
#  'Q1424805',
#  'Q350945',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q1272626',
#  'Q3695082',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q53617489',
#  'Q13226383',
#  'Q53617407',
#  'Q6671777',
#  'Q960648',
#  'Q18674739',
#  'Q2221906',
#  'Q99527517',
#  'Q8205328',
#  'Q24699794',
#  'Q123349660',
#  'Q121359',
#  'Q27096213',
#  'Q488383',
#  'Q58778',
#  'Q103940464',
#  'Q17350442',
#  'Q811979',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q570116',
#  'Q386724',
#  'Q57659484',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q811430',
#  'Q223557',
#  'Q1454986',
#  'Q4406616',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q107715',
#  'Q47574',
#  'Q2897903',
#  'Q38885242',
#  'Q71550118',
#  'Q99527517',
#  'Q246672',
#  'Q937228',
#  'Q181175',
#  'Q286583',
#  'Q1368',
#  'Q65240001',
#  'Q39875001',
#  'Q7048977',
#  'Q1659862',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q1207505',
#  'Q488383',
#  'Q4373292',
#  'Q1643989',
#  'Q190122',
#  'Q15809678',
#  'Q16686448',
#  'Q122375923',
#  'Q123691918',
#  'Q5127848',
#  'Q7598359',
#  'Q367293',
#  'Q35120',
#  'Q2912517',
#  'Q309314',
#  'Q11105360',
#  'Q16889133',
#  'Q8142',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q13226383',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q35145743',
#  'Q6671777',
#  'Q24229398',
#  'Q12819564',
#  'Q548662',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q8205328',
#  'Q228332',
#  'Q61961344',
#  'Q123349660',
#  'Q1248784',
#  'Q1639378',
#  'Q131085629',
#  'Q121359',
#  'Q27096213',
#  'Q376799',
#  'Q488383',
#  'Q58778',
#  'Q811979',
#  'Q62447',
#  'Q854457',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q20977775',
#  'Q106559804',
#  'Q386724',
#  'Q4406616',
#  'Q55006986',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q16334298',
#  'Q811430',
#  'Q223557',
#  'Q1454986',
#  'Q103940464',
#  'Q41298',
#  'Q53617489',
#  'Q98119401',
#  'Q2217301',
#  'Q24229398',
#  'Q1554231',
#  'Q106668099',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q121182',
#  'Q58415929',
#  'Q1639378',
#  'Q28877',
#  'Q488383',
#  'Q35825432',
#  'Q31464082',
#  'Q17538423',
#  'Q12042160',
#  'Q107435521',
#  'Q28314507',
#  'Q5633421',
#  'Q27801',
#  'Q591041',
#  'Q35120',
#  'Q17489659',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q11033',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q99527517',
#  'Q213051',
#  'Q1193236',
#  'Q7048977',
#  'Q61961344',
#  'Q49850',
#  'Q49848',
#  'Q131085629',
#  'Q2424752',
#  'Q685935',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q115668308',
#  'Q26907166',
#  'Q854457',
#  'Q737498',
#  'Q16686448',
#  'Q47461344',
#  'Q37866906',
#  'Q55915575',
#  'Q17172633',
#  'Q106559804',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q11826511',
#  'Q340169',
#  'Q1391420',
#  'Q103940464',
#  'Q5127848',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q98119401',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q2217301',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q24229398',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q1554231',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q1193236',
#  'Q121182',
#  'Q61961344',
#  'Q7048977',
#  'Q58415929',
#  'Q1639378',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q35825432',
#  'Q115668308',
#  'Q854457',
#  'Q26907166',
#  'Q17538423',
#  'Q31464082',
#  'Q16686448',
#  'Q107435521',
#  'Q47461344',
#  'Q37866906',
#  'Q17172633',
#  'Q106559804',
#  'Q28314507',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q5127848',
#  'Q35120',
#  'Q17489659',
#  'Q340169',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q103940464',
#  'Q11033',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q20937557',
#  'Q2897903',
#  'Q732577',
#  'Q1554231',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q99527517',
#  'Q110910970',
#  'Q3523102',
#  'Q286583',
#  'Q106213450',
#  'Q7048977',
#  'Q11578774',
#  'Q58415929',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q4502142',
#  'Q488383',
#  'Q194980',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q115668308',
#  'Q31464082',
#  'Q17538423',
#  'Q16686448',
#  'Q37866906',
#  'Q386724',
#  'Q17537576',
#  'Q110879246',
#  'Q5127848',
#  'Q35120',
#  'Q10301427',
#  'Q340169',
#  'Q15416',
#  'Q16889133',
#  'Q2431196',
#  'Q103940464',
#  'Q110879282',
#  'Q53617489',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q56061',
#  'Q3455524',
#  'Q6671777',
#  'Q24229398',
#  'Q106668099',
#  'Q2221906',
#  'Q99527517',
#  'Q43229',
#  'Q15642541',
#  'Q211606',
#  'Q61961344',
#  'Q123349660',
#  'Q58415929',
#  'Q1639378',
#  'Q25404640',
#  'Q27096213',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q6256',
#  'Q1063239',
#  'Q124711467',
#  'Q4835091',
#  'Q27096235',
#  'Q854457',
#  'Q23956024',
#  'Q16686448',
#  'Q178706',
#  'Q618123',
#  'Q124711484',
#  'Q106559804',
#  'Q82794',
#  'Q7210356',
#  'Q35120',
#  'Q1048835',
#  'Q26713767',
#  'Q16334298',
#  'Q16562419',
#  'Q18810687',
#  'Q103940464',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q53617489',
#  'Q830077',
#  'Q4197743',
#  'Q53617407',
#  'Q215627',
#  'Q2066131',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q18536342',
#  'Q27043950',
#  'Q66394244',
#  'Q50995749',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q223557',
#  'Q10871364',
#  'Q103940464',
#  'Q795052',
#  'Q88392887',
#  'Q1424805',
#  'Q350945',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q18408740',
#  'Q1272626',
#  'Q3695082',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q53617489',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q56061',
#  'Q3455524',
#  'Q6671777',
#  'Q24229398',
#  'Q106668099',
#  'Q2221906',
#  'Q99527517',
#  'Q43229',
#  'Q15642541',
#  'Q211606',
#  'Q4683593',
#  'Q61961344',
#  'Q123349660',
#  'Q58415929',
#  'Q1639378',
#  'Q25404640',
#  'Q27096213',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q1063239',
#  'Q124711467',
#  'Q4835091',
#  'Q27096235',
#  'Q854457',
#  'Q178706',
#  'Q16686448',
#  'Q23956024',
#  'Q618123',
#  'Q10374536',
#  'Q124711484',
#  'Q106559804',
#  'Q12076836',
#  'Q82794',
#  'Q7210356',
#  'Q35120',
#  'Q1048835',
#  'Q26713767',
#  'Q3976665',
#  'Q16334298',
#  'Q16562419',
#  'Q18810687',
#  'Q103940464',
#  'Q113137696',
#  'Q103940464',
#  'Q53617489',
#  'Q53617407',
#  'Q13415392',
#  'Q6671777',
#  'Q27043948',
#  'Q16686022',
#  'Q60960',
#  'Q25570959',
#  'Q99527517',
#  'Q55568967',
#  'Q66394244',
#  'Q27043950',
#  'Q35120',
#  'Q17781690',
#  'Q1970309',
#  'Q488383',
#  'Q112826975',
#  'Q223557',
#  'Q4406616',
#  'Q4936952',
#  'Q53617489',
#  'Q13226383',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q35145743',
#  'Q6671777',
#  'Q24229398',
#  'Q12819564',
#  'Q548662',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q8205328',
#  'Q228332',
#  'Q61961344',
#  'Q123349660',
#  'Q1248784',
#  'Q1639378',
#  'Q131085629',
#  'Q121359',
#  'Q27096213',
#  'Q376799',
#  'Q488383',
#  'Q58778',
#  'Q811979',
#  'Q62447',
#  'Q854457',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q20977775',
#  'Q106559804',
#  'Q386724',
#  'Q4406616',
#  'Q55006986',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q16334298',
#  'Q811430',
#  ...]

# %% [markdown]
# ## WD type vs NER type

# %%
# for each WD type inserted from the user (WD_WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query
# Out:
# False

# %%
retrieve_superclasses("Q12299841")
# Out:
# {'Q12299841': 'cricketer',
#  'Q2066131': 'athlete',
#  'Q18536342': 'competitive player',
#  'Q50995749': 'sportsperson',
#  'Q4197743': 'player',
#  'Q215627': 'person',
#  'Q830077': 'subject',
#  'Q795052': 'individual',
#  'Q3778211': 'legal person',
#  'Q53617489': 'independent continuant',
#  'Q7239': 'organism',
#  'Q24229398': 'agent',
#  'Q106559804': 'person or organization',
#  'Q103940464': 'continuant',
#  'Q223557': 'physical object',
#  'Q66394244': 'physical anatomical entity',
#  'Q4406616': 'concrete object',
#  'Q53617407': 'material entity',
#  'Q27043950': 'anatomical entity',
#  'Q488383': 'object',
#  'Q35120': 'entity'}

# %%
cta_values_dict
# Out:
# {'58891288_0_1117541047012405958 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 1': 'http://dbpedia.org/ontology/Lake',
#  '50245608_0_871275842592178099 0': 'http://dbpedia.org/ontology/Film',
#  '14067031_0_559833072073397908 1': 'http://dbpedia.org/ontology/Language',
#  '8286121_0_8471791395229161598 0': 'http://dbpedia.org/ontology/Country',
#  '39759273_0_1427898308030295194 1': 'http://dbpedia.org/ontology/Film',
#  '14380604_4_3329235705746762392 1': 'http://dbpedia.org/ontology/Company',
#  '20135078_0_7570343137119682530 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_6_8221428333921653560 1': 'http://dbpedia.org/ontology/VideoGame',
#  '34041816_1_4749054164534706977 2': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 7': 'http://dbpedia.org/ontology/Currency',
#  '71137051_0_8039724067857124984 0': 'http://dbpedia.org/ontology/Bird',
#  '29414811_2_4773219892816395776 1': 'http://dbpedia.org/ontology/VideoGame',
#  '99070098_0_2074872741302696997 1': 'http://dbpedia.org/ontology/Mountain',
#  '35188621_0_6058553107571275232 3': 'http://dbpedia.org/ontology/Person',
#  '43237185_1_3636357855502246981 3': 'http://dbpedia.org/ontology/Scientist',
#  '50245608_0_871275842592178099 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 0': 'http://dbpedia.org/ontology/VideoGame',
#  '29414811_6_8221428333921653560 4': 'http://dbpedia.org/ontology/Company',
#  '11833461_1_3811022039809817402 0': 'http://dbpedia.org/ontology/VideoGame',
#  '21245481_0_8730460088443117515 1': 'http://dbpedia.org/ontology/Lake',
#  '38428277_0_1311643810102462607 3': 'http://dbpedia.org/ontology/Person',
#  '13719111_1_5719401842463579519 0': 'http://dbpedia.org/ontology/Bird',
#  '77694908_0_6083291340991074532 1': 'http://dbpedia.org/ontology/Film',
#  '20135078_0_7570343137119682530 1': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 0': 'http://dbpedia.org/ontology/Scientist',
#  '88523363_0_8180214313099580515 0': 'http://dbpedia.org/ontology/Plant',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'http://dbpedia.org/ontology/Mountain',
#  '58891288_0_1117541047012405958 3': 'http://dbpedia.org/ontology/Person',
#  '25404227_0_2240631045609013057 3': 'http://dbpedia.org/ontology/Person',
#  '9475172_1_1023126399856690702 1': 'http://dbpedia.org/ontology/TelevisionShow',
#  '60319454_0_3938426910282115527 0': 'http://dbpedia.org/ontology/Animal',
#  '52299421_0_4473286348258170200 1': 'http://dbpedia.org/ontology/Country',
#  '37856682_0_6818907050314633217 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '77694908_0_6083291340991074532 3': 'http://dbpedia.org/ontology/Person',
#  '39759273_0_1427898308030295194 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_2_4773219892816395776 4': 'http://dbpedia.org/ontology/Company',
#  '29414811_13_8724394428539174350 2': 'http://dbpedia.org/ontology/Genre',
#  '33401079_0_9127583903019856402 0': 'http://dbpedia.org/ontology/Person',
#  '26310680_0_5150772059999313798 1': 'http://dbpedia.org/ontology/Currency',
#  '10579449_0_1681126353774891032 1': 'http://dbpedia.org/ontology/Newspaper',
#  '29414811_6_8221428333921653560 2': 'http://dbpedia.org/ontology/Genre',
#  '84548468_0_5955155464119382182 3': 'http://dbpedia.org/ontology/Person',
#  '55004961_0_2904467548072189860 0': 'http://dbpedia.org/ontology/Country',
#  '63450419_0_8012592961815711786 1': 'http://dbpedia.org/ontology/Plant',
#  '39107734_2_2329160387535788734 1': 'http://dbpedia.org/ontology/Airport',
#  '29414811_12_251152470253168163 4': 'http://dbpedia.org/ontology/Company',
#  '91959037_0_7907661684242014480 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 1': 'http://dbpedia.org/ontology/Company',
#  '84575189_0_6365692015941409487 2': 'http://dbpedia.org/ontology/AcademicJournal',
#  '14380604_4_3329235705746762392 2': 'http://dbpedia.org/ontology/PopulatedPlace',
#  '40534006_0_4617468856744635526 1': 'http://dbpedia.org/ontology/Wrestler',
#  '29414811_13_8724394428539174350 4': 'http://dbpedia.org/ontology/Company',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'http://dbpedia.org/ontology/PoliticalParty',
#  '84548468_0_5955155464119382182 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 2': 'http://dbpedia.org/ontology/Country',
#  '35188621_0_6058553107571275232 1': 'http://dbpedia.org/ontology/Film',
#  '22864497_0_8632623712684511496 0': 'http://dbpedia.org/ontology/VideoGame',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'http://dbpedia.org/ontology/Cricketer',
#  '14067031_0_559833072073397908 5': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 2': 'http://dbpedia.org/ontology/Genre',
#  '88523363_0_8180214313099580515 2': 'http://dbpedia.org/ontology/Eukaryote',
#  '28086084_0_3127660530989916727 0': 'http://dbpedia.org/ontology/Saint',
#  '50245608_0_871275842592178099 4': 'http://dbpedia.org/ontology/Writer',
#  '9834884_0_3871985887467090123 1': 'http://dbpedia.org/ontology/Museum',
#  '69881946_0_1105130426898457358 1': 'http://dbpedia.org/ontology/Film',
#  '25404227_0_2240631045609013057 1': 'http://dbpedia.org/ontology/Film',
#  '75367212_2_2745466355267233390 2': 'http://dbpedia.org/ontology/Company',
#  '39650055_5_7135804139753401681 1': 'http://dbpedia.org/ontology/Company',
#  '29414811_2_4773219892816395776 2': 'http://dbpedia.org/ontology/Genre',
#  '16767252_0_2409448375013995751 3': 'http://dbpedia.org/ontology/Person',
#  '71840765_0_6664391841933033844 0': 'http://dbpedia.org/ontology/Lake',
#  '36102169_0_7739454799295072814 1': 'http://dbpedia.org/ontology/Company',
#  '26310680_0_5150772059999313798 0': 'http://dbpedia.org/ontology/Country',
#  '45073662_0_3179937335063201739 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '11833461_1_3811022039809817402 1': 'http://dbpedia.org/ontology/Company',
#  '21245481_0_8730460088443117515 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '53822652_0_5767892317858575530 3': 'http://dbpedia.org/ontology/Person',
#  '39173938_0_7916056990138658530 1': 'http://dbpedia.org/ontology/Film',
#  '8286121_0_8471791395229161598 1': 'http://dbpedia.org/ontology/City',
#  '21362676_0_6854186738074119688 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 1': 'http://dbpedia.org/ontology/Genre',
#  '80588006_0_6965325215443683359 1': 'http://dbpedia.org/ontology/Newspaper',
#  '22864497_0_8632623712684511496 1': 'http://dbpedia.org/ontology/Company',
#  '61121469_0_6337620713408906340 0': 'http://dbpedia.org/ontology/Country',
#  '90196673_0_5458330029110291950 0': 'http://dbpedia.org/ontology/Animal',
#  '53989675_0_8697482470743954630 0': 'http://dbpedia.org/ontology/Lake',
#  '66009064_0_9148652238372261251 0': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '55004961_0_2904467548072189860 1': 'http://dbpedia.org/ontology/City',
#  '50270082_0_444360818941411589 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '24036779_0_5608105867560183058 0': 'http://dbpedia.org/ontology/Country',
#  '41336118_0_4331895026409635103 0': 'http://dbpedia.org/ontology/Company',
#  '69881946_0_1105130426898457358 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 3': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 2': 'http://dbpedia.org/ontology/EducationalInstitution',
#  '9834884_0_3871985887467090123 2': 'http://dbpedia.org/ontology/Country',
#  '16767252_0_2409448375013995751 1': 'http://dbpedia.org/ontology/Film',
#  '61121469_0_6337620713408906340 1': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 1': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 0': 'http://dbpedia.org/ontology/Country',
#  '41480166_0_6681239260286218499 0': 'http://dbpedia.org/ontology/Saint',
#  '57943722_0_8666078014685775876 0': 'http://dbpedia.org/ontology/Country',
#  '38428277_0_1311643810102462607 1': 'http://dbpedia.org/ontology/Film',
#  '36102169_0_7739454799295072814 2': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 1': 'http://dbpedia.org/ontology/City',
#  '9567241_0_5666388268510912770 1': 'http://dbpedia.org/ontology/Newspaper',
#  '69537082_0_7789694313271016902 1': 'http://dbpedia.org/ontology/Country',
#  '57943722_0_8666078014685775876 1': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 0': 'http://dbpedia.org/ontology/Country',
#  '53822652_0_5767892317858575530 1': 'http://dbpedia.org/ontology/Film',
#  '54719588_0_8417197176086756912 5': 'http://dbpedia.org/ontology/Person',
#  '24036779_0_5608105867560183058 5': 'http://dbpedia.org/ontology/GovernmentType',
#  '34041816_1_4749054164534706977 1': 'http://dbpedia.org/ontology/Airport',
#  '39173938_0_7916056990138658530 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 4': 'http://dbpedia.org/ontology/Country',
#  '66009064_0_9148652238372261251 2': 'http://dbpedia.org/ontology/SportsTeam',
#  '21362676_0_6854186738074119688 1': 'http://dbpedia.org/ontology/Film',
#  '39107734_2_2329160387535788734 2': 'http://dbpedia.org/ontology/City',
#  '29414811_13_8724394428539174350 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 0': 'http://dbpedia.org/ontology/VideoGame'}

# %%
cea_values_dict
# Out:
# {'50245608_0_871275842592178099 0': 'https://www.wikidata.org/entity/Q46551',
#  '22864497_0_8632623712684511496 0': 'https://www.wikidata.org/entity/Q6738126',
#  '66009064_0_9148652238372261251 0': 'https://www.wikidata.org/entity/Q1094988',
#  '21362676_0_6854186738074119688 1': 'https://www.wikidata.org/entity/Q463832',
#  '40534006_0_4617468856744635526 1': 'https://www.wikidata.org/entity/Q452590',
#  '36102169_0_7739454799295072814 2': 'https://www.wikidata.org/entity/Q1978200',
#  '53822652_0_5767892317858575530 1': 'https://www.wikidata.org/entity/Q200396',
#  '60319454_0_3938426910282115527 0': 'https://www.wikidata.org/entity/Q69581',
#  '8468806_0_4382447409703007384 1': 'https://www.wikidata.org/entity/Q1546823',
#  '33401079_0_9127583903019856402 0': 'https://www.wikidata.org/entity/Q154538',
#  '99070098_0_2074872741302696997 1': 'https://www.wikidata.org/entity/Q4920755',
#  '50270082_0_444360818941411589 1': 'https://www.wikidata.org/entity/Q114468',
#  '29414811_12_251152470253168163 1': 'https://www.wikidata.org/entity/Q1060323',
#  '39759273_0_1427898308030295194 1': 'https://www.wikidata.org/entity/Q104123',
#  '69537082_0_7789694313271016902 1': 'https://www.wikidata.org/entity/Q1011',
#  '88523363_0_8180214313099580515 0': 'https://www.wikidata.org/entity/Q5782393',
#  '41480166_0_6681239260286218499 0': 'https://www.wikidata.org/entity/Q4390981',
#  '9834884_0_3871985887467090123 1': 'https://www.wikidata.org/entity/Q1781530',
#  '26310680_0_5150772059999313798 1': 'https://www.wikidata.org/entity/Q206319',
#  '39173938_0_7916056990138658530 1': 'https://www.wikidata.org/entity/Q25193623',
#  '91959037_0_7907661684242014480 1': 'https://www.wikidata.org/entity/Q663665',
#  '13719111_1_5719401842463579519 0': 'https://www.wikidata.org/entity/Q2384003',
#  '54719588_0_8417197176086756912 3': 'https://www.wikidata.org/entity/Q575014',
#  '58891288_0_1117541047012405958 1': 'https://www.wikidata.org/entity/Q135465',
#  '28086084_0_3127660530989916727 0': 'https://www.wikidata.org/entity/Q61620',
#  '21245481_0_8730460088443117515 1': 'https://www.wikidata.org/entity/Q6476027',
#  '90196673_0_5458330029110291950 0': 'https://www.wikidata.org/entity/Q199203',
#  '35188621_0_6058553107571275232 1': 'https://www.wikidata.org/entity/Q214801',
#  '46671561_0_6122315295162029872 0': 'https://www.wikidata.org/entity/Q1408367',
#  '25404227_0_2240631045609013057 1': 'https://www.wikidata.org/entity/Q128518',
#  '63450419_0_8012592961815711786 1': 'https://www.wikidata.org/entity/Q2078054',
#  '39107734_2_2329160387535788734 1': 'https://www.wikidata.org/entity/Q193439',
#  '29414811_2_4773219892816395776 1': 'https://www.wikidata.org/entity/Q276217',
#  '20135078_0_7570343137119682530 1': 'https://www.wikidata.org/entity/Q639481',
#  '39650055_5_7135804139753401681 1': 'https://www.wikidata.org/entity/Q459477',
#  '16767252_0_2409448375013995751 1': 'https://www.wikidata.org/entity/Q503046',
#  '9475172_1_1023126399856690702 1': 'https://www.wikidata.org/entity/Q380519',
#  '24036779_0_5608105867560183058 0': 'https://www.wikidata.org/entity/Q817',
#  '69881946_0_1105130426898457358 1': 'https://www.wikidata.org/entity/Q471169',
#  '75367212_2_2745466355267233390 0': 'https://www.wikidata.org/entity/Q1205676',
#  '84575189_0_6365692015941409487 2': 'https://www.wikidata.org/entity/Q39379',
#  '84548468_0_5955155464119382182 1': 'https://www.wikidata.org/entity/Q181086',
#  '52299421_0_4473286348258170200 1': 'https://www.wikidata.org/entity/Q227',
#  '37856682_0_6818907050314633217 0': 'https://www.wikidata.org/entity/Q26',
#  '38428277_0_1311643810102462607 1': 'https://www.wikidata.org/entity/Q725552',
#  '41336118_0_4331895026409635103 0': 'https://www.wikidata.org/entity/Q831445',
#  '71840765_0_6664391841933033844 0': 'https://www.wikidata.org/entity/Q14429',
#  '77694908_0_6083291340991074532 1': 'https://www.wikidata.org/entity/Q83495',
#  '43237185_1_3636357855502246981 0': 'https://www.wikidata.org/entity/Q72538',
#  '45073662_0_3179937335063201739 1': 'https://www.wikidata.org/entity/Q375648',
#  '11833461_1_3811022039809817402 0': 'https://www.wikidata.org/entity/Q5285919',
#  '14067031_0_559833072073397908 0': 'https://www.wikidata.org/entity/Q1033',
#  '9567241_0_5666388268510912770 1': 'https://www.wikidata.org/entity/Q208875',
#  '34041816_1_4749054164534706977 1': 'https://www.wikidata.org/entity/Q178021',
#  '10579449_0_1681126353774891032 1': 'https://www.wikidata.org/entity/Q30315633',
#  '29414811_13_8724394428539174350 1': 'https://www.wikidata.org/entity/Q213911',
#  '14380604_4_3329235705746762392 1': 'https://www.wikidata.org/entity/Q487907',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'https://www.wikidata.org/entity/Q7626741',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'https://www.wikidata.org/entity/Q9669',
#  '80588006_0_6965325215443683359 1': 'https://www.wikidata.org/entity/Q1872524',
#  '29414811_6_8221428333921653560 1': 'https://www.wikidata.org/entity/Q1765733',
#  '53989675_0_8697482470743954630 0': 'https://www.wikidata.org/entity/Q5181893',
#  '1438042986423_95_20150728002306-00329-ip-10-236-191-2_805336391_10 1': 'https://www.wikidata.org/entity/Q6393870',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'https://www.wikidata.org/entity/Q7194441'}
