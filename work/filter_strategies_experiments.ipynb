# %%
import os
import pandas as pd
from tqdm import tqdm
import logging
import requests
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import re
from collections import Counter

# %%
import json
from requests import get

def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.

    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids


try:
    organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
except json.decoder.JSONDecodeError:
    organization_subclass = []

try:
    country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
except json.decoder.JSONDecodeError:
    country_subclass = []

try:
    city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
except json.decoder.JSONDecodeError:
    city_subclass = []

try:
    capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
except json.decoder.JSONDecodeError:
    capitals_subclass = []

try:
    admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
except json.decoder.JSONDecodeError:
    admTerr_subclass = []

try:
    family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
except json.decoder.JSONDecodeError:
    family_subclass = []

try:
    sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
except json.decoder.JSONDecodeError:
    sportLeague_subclass = []

try:
    venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
except json.decoder.JSONDecodeError:
    venue_subclass = []

# Removing overlaps for organization_subclass
organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))

try:
    geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
except json.decoder.JSONDecodeError:
    geolocation_subclass = []

try:
    food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
except json.decoder.JSONDecodeError:
    food_subclass = []

try:
    edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
except json.decoder.JSONDecodeError:
    edInst_subclass = []

try:
    govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
except json.decoder.JSONDecodeError:
    govAgency_subclass = []

try:
    intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
except json.decoder.JSONDecodeError:
    intOrg_subclass = []

try:
    timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
except json.decoder.JSONDecodeError:
    timeZone_subclass = []

# Removing overlaps for geolocation_subclass
geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))

# %%
def split_entity_name(entity_name):
    """
    Splits the entity name into separate words if it has more than 2 uppercase letters.
    
    Args:
        entity_name (str): The input string to check and potentially split (e.g., 'VideoGame').
    
    Returns:
        str: The modified string with words split by spaces if necessary.
    """
    # Count uppercase letters
    uppercase_count = sum(1 for char in entity_name if char.isupper())
    
    # If more than 2 uppercase letters, split before every uppercase letter
    if uppercase_count >= 2:
        return re.sub(r'(?<!^)(?=[A-Z])', ' ', entity_name)
    
    return entity_name

def get_type_id(entity_name):
    """
    Queries the API to retrieve the QID of an entity based on its name.

    Args:
        entity_name (str): The name of the entity (e.g., 'Video Game').

    Returns:
        str: The QID associated with the given entity name, or None if an error occurs or no QID is found.
    """
    
    entity_name_split = split_entity_name(entity_name)

    url = f"https://lamapi.hel.sintef.cloud/lookup/entity-retrieval"
    params = {
        "name": entity_name_split,
        "kind": "type",
        "token": "lamapi_demo_2023"
    }
    headers = {
        "accept": "application/json"
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Raise an error for HTTP issues
        data = response.json()
        # Assuming the API returns the QID directly or within a key, adjust if structure differs
        #return max(data, key=lambda x: x.get('pos_score', 0))
        return data[0]['id']
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
def retrieve_superclasses(entity_id):
    """
    Retrieve all superclasses of a given Wikidata entity ID.

    Args:
        entity_id (str): The ID of the entity (e.g., "Q207784").

    Returns:
        dict: A dictionary where keys are superclass IDs, and values are their labels.
    """
    # Define the SPARQL endpoint and query
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?superclass ?superclassLabel WHERE {{
      wd:{entity_id} (wdt:P279)* ?superclass.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """

    # Function to query the SPARQL endpoint with retries
    def query_wikidata(sparql_client, query, retries=3, delay=5):
        for attempt in range(retries):
            try:
                sparql_client.setQuery(query)
                sparql_client.setReturnFormat(JSON)
                results = sparql_client.query().convert()
                return results
            except Exception as e:
                if "429" in str(e):  # Handle Too Many Requests error
                    print(f"Rate limit hit. Retrying in {delay} seconds... (Attempt {attempt + 1}/{retries})")
                    time.sleep(delay)
                else:
                    print(f"An error occurred: {e}")
                    break
        return None

    # Set up the SPARQL client
    sparql = SPARQLWrapper(endpoint_url)

    # Execute the query with retries
    results = query_wikidata(sparql, query)

    # Process results and return as a dictionary
    if results:
        superclass_dict = {}
        for result in results["results"]["bindings"]:
            superclass_id = result["superclass"]["value"].split("/")[-1]  # Extract entity ID from the URI
            label = result["superclassLabel"]["value"]
            superclass_dict[superclass_id] = label
        return superclass_dict
    else:
        print("Failed to retrieve data after multiple attempts.")
        return {}

# %%
def WD_types(entity_id):
    """
    Queries the API to retrieve the list of type IDs for a given entity ID.

    Args:
        entity_id (str): The Wikidata ID of the entity (e.g., 'Q30').

    Returns:
        list: A list of type IDs associated with the given entity, or an empty list if an error occurs.
    """

    url = "https://lamapi.hel.sintef.cloud/entity/types?token=lamapi_demo_2023"
    headers = {
        "accept": "application/json",
        "Content-Type": "application/json"
    }
    payload = {"json": [entity_id]}
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Raise an error for HTTP issues
        ids = response.json()
        return ids[entity_id]['types']['P31']  # Parse and return the JSON response
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return []
    except KeyError as e:
        # Handle missing keys in the JSON response
        return []

# %%
# hai un solo NER type per entità perchè lato query type hai associato un solo 
# explicit_WD_type da mappare


def NER_types(entity_id):

    """
    Given an entity it retrieves the list of the associated NER types making
    the NER type extension of all the WD_types associated to it.
    """
    if not entity_id:
        return None  

    match = re.search(r'Q(\d+)', entity_id)
    numeric_id = int(match.group(1))

    NERtype = []
    # Classify NER types
    if numeric_id == 5:
        return 'PERS'
    elif numeric_id in geolocation_subclass:
        return 'LOC'
    elif numeric_id in organization_subclass:
        return 'ORG'
    else:
        return 'OTHERS'

# %%
def extended_WD_types(entity_id):

    """
    Given an entity it retrieves the list of the associated extended WD types making
    the type extension of all the WD_types associated to it.
    """
        
    if not entity_id:
        return None

    return list(retrieve_superclasses(entity_id).keys())

# %% [markdown]
# ## Dataset Reading

# %%
tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round4_2020/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.keys()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {key: [cea_values_dict[key], cta_values_dict[key]] for key in common_keys}

# %%
cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)
# Out:
# Processing tables: 100%|██████████| 22207/22207 [04:55<00:00, 75.23it/s]

# %%
WD_query_type = {
    value[0].split('/')[-1]: value[1].split('/')[-1]
    for value in combined_dict.values()
}

WD_query_type
# Out:
# {'Q78752723': 'Q1332364',
#  'Q1393651': 'Q11424',
#  'Q2269559': 'Q623109',
#  'Q1508': 'Q29946056',
#  'Q930314': 'Q32880',
#  'Q6723': 'Q17272482',
#  'Q110462': 'Q5',
#  'Q5963660': 'Q1366112',
#  'Q5963': 'Q85332736',
#  'Q76597335': 'Q83373',
#  'Q468161': 'Q1344',
#  'Q59341592': 'Q1980247',
#  'Q1216506': 'Q11424',
#  'Q13644': 'Q11276',
#  'Q488892': 'Q13410400',
#  'Q313404': 'Q1331380',
#  'Q75264907': 'Q1153392',
#  'Q61919529': 'Q1092832',
#  'Q73789987': 'Q19860854',
#  'Q652166': 'Q5',
#  'Q78241263': 'Q1352333',
#  'Q209373': 'Q21009057',
#  'Q63891772': 'Q22936940',
#  'Q738601': 'Q11387',
#  'Q64863410': 'Q101965',
#  'Q63869675': 'Q22936940',
#  'Q2659397': 'Q27968055',
#  'Q1536088': 'Q2633744',
#  'Q62102192': 'Q932825',
#  'Q80602795': 'Q217012',
#  'Q577598': 'Q5',
#  'Q14472988': 'Q1968122',
#  'Q4132669': 'Q21505397',
#  'Q3656721': 'Q15298259',
#  'Q85319072': 'Q72053617',
#  'Q749234': 'Q67206691',
#  'Q508153': 'Q127448',
#  'Q183': 'Q6256',
#  'Q7893054': 'Q858439',
#  'Q19652': 'Q50424085',
#  'Q79087327': 'Q7725310',
#  'Q3224202': 'Q482994',
#  'Q149016': 'Q12131640',
#  'Q222996': 'Q9135',
#  'Q15293558': 'Q27020041',
#  'Q751373': 'Q509686',
#  'Q321': 'Q2490',
#  'Q5728362': 'Q534932',
#  'Q20193': 'Q747074',
#  'Q42095': 'Q29045252',
#  'Q6655': 'Q17272482',
#  'Q6028852': 'Q179700',
#  'Q1814990': 'Q184943',
#  'Q762869': 'Q3456602',
#  'Q22506035': 'Q290588',
#  'Q680816': 'Q7889',
#  'Q407733': 'Q11173',
#  'Q19857856': 'Q2647254',
#  'Q80197841': 'Q785745',
#  'Q18882484': 'Q618193',
#  'Q6718206': 'Q2055880',
#  'Q26678395': 'Q36794',
#  'Q19228518': 'Q191067',
#  'Q76133': 'Q12143',
#  'Q2023270': 'Q428661',
#  'Q6434831': 'Q1348589',
#  'Q4594687': 'Q868291',
#  'Q50842170': 'Q21480300',
#  'Q11791': 'Q30634609',
#  'Q8842': 'Q8928',
#  'Q10464': 'Q8928',
#  'Q3498001': 'Q5',
#  'Q22915727': 'Q36794',
#  'Q948': 'Q3624078',
#  'Q3136309': 'Q532',
#  'Q34778': 'Q45762',
#  'Q26067': 'Q62326',
#  'Q582172': 'Q10855061',
#  'Q302': 'Q20643955',
#  'Q52323024': 'Q473932',
#  'Q9285': 'Q8928',
#  'Q18004156': 'Q585956',
#  'Q528435': 'Q106259',
#  'Q40970': 'Q11422536',
#  'Q82142703': 'Q1059564',
#  'Q60224303': 'Q28738741',
#  'Q61206609': 'Q5',
#  'Q20199600': 'Q163446',
#  'Q4047743': 'Q1193246',
#  'Q2742648': 'Q5084',
#  'Q4117518': 'Q6617100',
#  'Q115591': 'Q18618819',
#  'Q30201458': 'Q30227593',
#  'Q2773': 'Q42744322',
#  'Q57163630': 'Q34009',
#  'Q515544': 'Q6784672',
#  'Q6940': 'Q17272482',
#  'Q800701': 'Q1335652',
#  'Q5434322': 'Q203005',
#  'Q1329523': 'Q327333',
#  'Q1058903': 'Q16070115',
#  'Q53870397': 'Q185187',
#  'Q5676273': 'Q1195942',
#  'Q2697653': 'Q2179958',
#  'Q1552352': 'Q2056881',
#  'Q1547610': 'Q2389789',
#  'Q27049607': 'Q1644669',
#  'Q142064': 'Q27676416',
#  'Q4113609': 'Q12518',
#  'Q785094': 'Q26792858',
#  'Q61272519': 'Q971252',
#  'Q8366704': 'Q1970365',
#  'Q63887559': 'Q63975020',
#  'Q75033456': 'Q6251',
#  'Q3652557': 'Q80767',
#  'Q23651238': 'Q1400565',
#  'Q8546986': 'Q137535',
#  'Q3457589': 'Q15089606',
#  'Q877835': 'Q428661',
#  'Q799254': 'Q1202091',
#  'Q21608410': 'Q18333556',
#  'Q28123675': 'Q53532033',
#  'Q279278': 'Q76154857',
#  'Q2261284': 'Q623605',
#  'Q401741': 'Q2989398',
#  'Q602813': 'Q3305213',
#  'Q5389052': 'Q190928',
#  'Q30': 'Q3624078',
#  'Q27067881': 'Q5707594',
#  'Q29': 'Q3624078',
#  'Q14545620': 'Q3679744',
#  'Q58374986': 'Q644853',
#  'Q20680813': 'Q20646670',
#  'Q3214583': 'Q81066200',
#  'Q1406': 'Q9135',
#  'Q13526807': 'Q32880',
#  'Q94445': 'Q193622',
#  'Q41309': 'Q5',
#  'Q152979': 'Q543654',
#  'Q1764600': 'Q13219666',
#  'Q1583249': 'Q380093',
#  'Q83793419': 'Q836976',
#  'Q1520': 'Q10864048',
#  'Q5495720': 'Q3157041',
#  'Q20385': 'Q747074',
#  'Q3609': 'Q2312410',
#  'Q83430725': 'Q5848',
#  'Q1023264': 'Q658986',
#  'Q314284': 'Q5',
#  'Q1656153': 'Q1327578',
#  'Q660345': 'Q697175',
#  'Q11275993': 'Q21130185',
#  'Q3129358': 'Q15548076',
#  'Q69682': 'Q56061',
#  'Q847': 'Q31629',
#  'Q6738839': 'Q15966540',
#  'Q55759837': 'Q488053',
#  'Q183963': 'Q33837',
#  'Q6866884': 'Q19973795',
#  'Q132952': 'Q5',
#  'Q26520496': 'Q9842',
#  'Q18881759': 'Q559290',
#  'Q161176': 'Q494721',
#  'Q527449': 'Q32880',
#  'Q20935': 'Q7954',
#  'Q2565': 'Q1972',
#  'Q129112': 'Q11166728',
#  'Q28866800': 'Q187685',
#  'Q7665964': 'Q5',
#  'Q511253': 'Q127448',
#  'Q2925150': 'Q13741',
#  'Q18888850': 'Q2417724',
#  'Q30942': 'Q5',
#  'Q30288421': 'Q4287745',
#  'Q19979125': 'Q7379880',
#  'Q535055': 'Q5',
#  'Q5205214': 'Q2619673',
#  'Q1103845': 'Q644507',
#  'Q2838808': 'Q207934',
#  'Q16595867': 'Q18199879',
#  'Q743643': 'Q3305213',
#  'Q62396941': 'Q22231112',
#  'Q2942734': 'Q2577114',
#  'Q18845385': 'Q469900',
#  'Q478663': 'Q8502',
#  'Q2711224': 'Q3685462',
#  'Q160213': 'Q21070568',
#  'Q2972253': 'Q1344',
#  'Q391028': 'Q62078547',
#  'Q5182964': 'Q23010647',
#  'Q3058634': 'Q1872284',
#  'Q61927140': 'Q18131152',
#  'Q1851741': 'Q38720',
#  'Q1145815': 'Q11276',
#  'Q2516934': 'Q2187969',
#  'Q927422': 'Q7058673',
#  'Q27911': 'Q1063547',
#  'Q6943827': 'Q13005188',
#  'Q17640182': 'Q22231110',
#  'Q47496412': 'Q1965390',
#  'Q18844804': 'Q2220795',
#  'Q115404': 'Q11774149',
#  'Q3947833': 'Q10517054',
#  'Q13150307': 'Q3812392',
#  'Q13810': 'Q24746',
#  'Q125093': 'Q19832486',
#  'Q21452317': 'Q101352',
#  'Q28': 'Q3624078',
#  'Q154415': 'Q3863',
#  'Q8205': 'Q262166',
#  'Q2215435': 'Q3710488',
#  'Q5370408': 'Q1248784',
#  'Q19414899': 'Q868291',
#  'Q20547599': 'Q728904',
#  'Q24738794': 'Q898273',
#  'Q1131791': 'Q202866',
#  'Q20934': 'Q1637706',
#  'Q579865': 'Q26132862',
#  'Q414537': 'Q11173',
#  'Q614664': 'Q35034452',
#  'Q2188401': 'Q15911738',
#  'Q899940': 'Q1993624',
#  'Q17165362': 'Q31629',
#  'Q17530855': 'Q256020',
#  'Q44148': 'Q290',
#  'Q79143278': 'Q18393176',
#  'Q1261587': 'Q1402592',
#  'Q5601358': 'Q222910',
#  'Q173332': 'Q179872',
#  'Q59353996': 'Q11707',
#  'Q66631563': 'Q353834',
#  'Q724525': 'Q2992826',
#  'Q28863484': 'Q43229',
#  'Q2066925': 'Q53945096',
#  'Q6410945': 'Q103632',
#  'Q56066063': 'Q327365',
#  'Q210987': 'Q856076',
#  'Q458656': 'Q11424',
#  'Q2376527': 'Q18328097',
#  'Q4855095': 'Q2775236',
#  'Q626062': 'Q193556',
#  'Q16': 'Q3624078',
#  'Q1691347': 'Q853854',
#  'Q13104540': 'Q6881511',
#  'Q2811581': 'Q19723451',
#  'Q15764557': 'Q627517',
#  'Q145129': 'Q15642541',
#  'Q3342': 'Q6465',
#  'Q777162': 'Q13025342',
#  'Q3982188': 'Q24354',
#  'Q7675044': 'Q6017969',
#  'Q6462': 'Q15974307',
#  'Q72264828': 'Q1980247',
#  'Q12100': 'Q31629',
#  'Q1136368': 'Q39804',
#  'Q749072': 'Q5893',
#  'Q23301855': 'Q23790218',
#  'Q3403003': 'Q2750108',
#  'Q7867378': 'Q757587',
#  'Q17333758': 'Q15991303',
#  'Q63998197': 'Q63100595',
#  'Q877351': 'Q697196',
#  'Q1120105': 'Q159321',
#  'Q1388': 'Q11344',
#  'Q391496': 'Q1497375',
#  'Q20803731': 'Q2035477',
#  'Q390566': 'Q78782478',
#  'Q412260': 'Q21009058',
#  'Q78246458': 'Q41872',
#  'Q63718': 'Q13410496',
#  'Q1403707': 'Q19832486',
#  'Q1136118': 'Q1006876',
#  'Q21162316': 'Q24566025',
#  'Q816801': 'Q1055465',
#  'Q84480213': 'Q1142192',
#  'Q3985422': 'Q15416',
#  'Q1064719': 'Q2426029',
#  'Q733620': 'Q3464665',
#  'Q19601872': 'Q13226383',
#  'Q221600': 'Q7997',
#  'Q213': 'Q3624078',
#  'Q3196486': 'Q15081032',
#  'Q5299565': 'Q72996181',
#  'Q10432756': 'Q615980',
#  'Q4121778': 'Q14795564',
#  'Q5101742': 'Q12570',
#  'Q16896284': 'Q1071482',
#  'Q15736443': 'Q79007',
#  'Q150': 'Q34770',
#  'Q834003': 'Q14637321',
#  'Q586832': 'Q18536594',
#  'Q20': 'Q3624078',
#  'Q46186': 'Q55491',
#  'Q62286812': 'Q184296',
#  'Q23830576': 'Q23830575',
#  'Q9963': 'Q19776628',
#  'Q822919': 'Q35749',
#  'Q20953352': 'Q7835189',
#  'Q21098236': 'Q2026833',
#  'Q15700834': 'Q30634609',
#  'Q25422055': 'Q6592',
#  'Q12065240': 'Q1993624',
#  'Q1734': 'Q31629',
#  'Q161210': 'Q11173',
#  'Q11801540': 'Q46686',
#  'Q1455301': 'Q1455275',
#  'Q324814': 'Q25653',
#  'Q12038709': 'Q26789694',
#  'Q2736': 'Q31629',
#  'Q465795': 'Q15275719',
#  'Q18844853': 'Q1372202',
#  'Q4825172': 'Q29791211',
#  'Q1425630': 'Q47345468',
#  'Q848497': 'Q1369686',
#  'Q9321426': 'Q202866',
#  'Q78366736': 'Q1153690',
#  'Q1958516': 'Q18808440',
#  'Q10602645': 'Q10358588',
#  'Q1362956': 'Q2992500',
#  'Q1134734': 'Q134556',
#  'Q20727855': 'Q20639848',
#  'Q62032528': 'Q26869635',
#  'Q63892550': 'Q35054',
#  'Q17015369': 'Q3001412',
#  'Q2175046': 'Q181348',
#  'Q1913292': 'Q34023',
#  'Q31158009': 'Q193495',
#  'Q18883133': 'Q1330776',
#  'Q55763785': 'Q192425',
#  'Q2471': 'Q515',
#  'Q4383931': 'Q23847174',
#  'Q29623472': 'Q12043905',
#  'Q20071': 'Q42744322',
#  'Q62017614': 'Q39715',
#  'Q8844': 'Q8928',
#  'Q24906866': 'Q1195098',
#  'Q7291': 'Q31629',
#  'Q1067': 'Q5',
#  'Q53387558': 'Q30227593',
#  'Q130607': 'Q61089180',
#  'Q85803115': 'Q72802727',
#  'Q42030297': 'Q41253',
#  'Q4792174': 'Q24354',
#  'Q12225475': 'Q12225020',
#  'Q2418567': 'Q20893947',
#  'Q2630693': 'Q56557504',
#  'Q46': 'Q5107',
#  'Q20672087': 'Q21993397',
#  'Q1190264': 'Q952274',
#  'Q966226': 'Q852190',
#  'Q8352403': 'Q166620',
#  'Q5455716': 'Q45242174',
#  'Q18114004': 'Q6881511',
#  'Q3137': 'Q5',
#  'Q151701': 'Q4508',
#  'Q22977069': 'Q22231106',
#  'Q3702038': 'Q5',
#  'Q7749': 'Q188451',
#  'Q2097336': 'Q14752149',
#  'Q5174792': 'Q1993624',
#  'Q2017684': 'Q164142',
#  'Q2052922': 'Q1643932',
#  'Q1649382': 'Q2989398',
#  'Q60732988': 'Q4380246',
#  'Q912887': 'Q45400320',
#  'Q1086857': 'Q2911266',
#  'Q17583606': 'Q7366',
#  'Q3504783': 'Q6558431',
#  'Q4976031': 'Q1498804',
#  'Q1365037': 'Q618779',
#  'Q685390': 'Q34262807',
#  'Q55264082': 'Q11783626',
#  'Q225': 'Q3624078',
#  'Q18707032': 'Q3658341',
#  'Q142': 'Q3624078',
#  'Q874877': 'Q2389789',
#  'Q2551916': 'Q1785071',
#  'Q18008270': 'Q947103',
#  'Q63087656': 'Q63084210',
#  'Q81704734': 'Q836976',
#  'Q3395191': 'Q6065085',
#  'Q2500619': 'Q171318',
#  'Q1544251': 'Q4830453',
#  'Q955526': 'Q2088753',
#  'Q4786024': 'Q50393057',
#  'Q682966': 'Q50053',
#  'Q3102237': 'Q13632',
#  'Q214861': 'Q644371',
#  'Q7570313': 'Q19832486',
#  'Q6779': 'Q17272482',
#  'Q580711': 'Q46190676',
#  'Q1073823': 'Q6784672',
#  'Q1072834': 'Q11832860',
#  'Q377705': 'Q18043413',
#  'Q429971': 'Q35666',
#  'Q78753682': 'Q6232',
#  'Q1195626': 'Q878367',
#  'Q27577214': 'Q13626398',
#  'Q16977290': 'Q1852859',
#  'Q159': 'Q3624078',
#  'Q114026': 'Q11774097',
#  'Q678406': 'Q54117920',
#  'Q734167': 'Q18340514',
#  'Q10484': 'Q8928',
#  'Q29002318': 'Q7362268',
#  'Q3273333': 'Q11446',
#  'Q56551315': 'Q56551180',
#  'Q2000988': 'Q18536594',
#  'Q220451': 'Q719987',
#  'Q4241808': 'Q5',
#  'Q23822856': 'Q1825472',
#  'Q2682380': 'Q20646670',
#  'Q77405890': 'Q72803170',
#  'Q28155398': 'Q3157041',
#  'Q17603255': 'Q211302',
#  'Q18681579': 'Q550637',
#  'Q55383333': 'Q2035477',
#  'Q63087708': 'Q63084210',
#  'Q5199441': 'Q1401142',
#  'Q23559257': 'Q47521',
#  'Q1981512': 'Q1981535',
#  'Q894716': 'Q14970',
#  'Q7510327': 'Q180684',
#  'Q3443779': 'Q15911738',
#  'Q2624468': 'Q120804',
#  'Q387949': 'Q64138263',
#  'Q56245297': 'Q23015458',
#  'Q23305631': 'Q2190251',
#  'Q27': 'Q3624078',
#  'Q2706960': 'Q84582639',
#  'Q174193': 'Q3024240',
#  'Q550457': 'Q58840819',
#  'Q20897878': 'Q32880',
#  'Q840829': 'Q32880',
#  'Q75406741': 'Q5871',
#  'Q28441616': 'Q1329623',
#  'Q1568434': 'Q207694',
#  'Q11426682': 'Q56351315',
#  'Q85089830': 'Q2680861',
#  'Q20734262': 'Q5',
#  'Q63343611': 'Q66239912',
#  'Q264649': 'Q32880',
#  'Q7207': 'Q5',
#  'Q5355933': 'Q3032154',
#  'Q10948': 'Q15275719',
#  'Q1973074': 'Q785466',
#  'Q25572': 'Q16521',
#  'Q18883390': 'Q1372384',
#  'Q223818': 'Q2992500',
#  'Q7899116': 'Q7379880',
#  'Q4763521': 'Q665487',
#  'Q38': 'Q3624078',
#  'Q1803895': 'Q1156831',
#  'Q2564009': 'Q61883',
#  'Q11079799': 'Q55558200',
#  'Q145': 'Q3624078',
#  'Q1108829': 'Q1931185',
#  'Q405': 'Q2537',
#  'Q1192632': 'Q12912091',
#  'Q926826': 'Q5',
#  'Q2204': 'Q17272482',
#  'Q5365683': 'Q214519',
#  'Q15767464': 'Q21834496',
#  'Q7041': 'Q17272482',
#  'Q847463': 'Q4498974',
#  'Q18412760': 'Q18340514',
#  'Q178570': 'Q165194',
#  'Q491272': 'Q12262532',
#  'Q16864593': 'Q1162560',
#  'Q1400': 'Q35657',
#  'Q3664134': 'Q203958',
#  'Q12775724': 'Q727379',
#  'Q799356': 'Q1375518',
#  'Q751878': 'Q32880',
#  'Q213717': 'Q1248784',
#  'Q55011306': 'Q14514600',
#  'Q23060': 'Q7278',
#  'Q2705258': 'Q25930814',
#  'Q7846125': 'Q79602',
#  'Q21409347': 'Q60754876',
#  'Q6022507': 'Q40231',
#  'Q66531686': 'Q1153690',
#  'Q4470069': 'Q20650761',
#  'Q48921424': 'Q1965390',
#  'Q18358303': 'Q39594',
#  'Q2056431': 'Q5',
#  'Q367038': 'Q2074737',
#  'Q2549338': 'Q1931185',
#  'Q5921126': 'Q1321960',
#  'Q2557987': 'Q1274559',
#  'Q24196911': 'Q2387974',
#  'Q14838496': 'Q2493431',
#  'Q75177374': 'Q72802727',
#  'Q2566705': 'Q549792',
#  'Q78245280': 'Q1141054',
#  'Q3375596': 'Q15911738',
#  'Q600898': 'Q124734',
#  'Q8921': 'Q8928',
#  'Q641': 'Q515',
#  'Q6975735': 'Q13406463',
#  'Q12028829': 'Q23039057',
#  'Q12548': 'Q3024240',
#  'Q79089079': 'Q5',
#  'Q18881768': 'Q559290',
#  'Q55': 'Q6256',
#  'Q34': 'Q3624078',
#  'Q376106': 'Q13410444',
#  'Q6654960': 'Q1993624',
#  'Q77012995': 'Q2557101',
#  'Q35620': 'Q3249005',
#  'Q7549238': 'Q1242743',
#  'Q2986194': 'Q27560760',
#  'Q2294625': 'Q744296',
#  'Q45': 'Q6256',
#  'Q187528': 'Q476028',
#  'Q60193337': 'Q1435962',
#  'Q43295565': 'Q15727816',
#  'Q5253735': 'Q15079663',
#  'Q1262166': 'Q193622',
#  'Q84408051': 'Q4380244',
#  'Q16535072': 'Q934877',
#  'Q734020': 'Q11783626',
#  'Q56695': 'Q9035798',
#  'Q52749904': 'Q126807',
#  'Q82621665': 'Q66619666',
#  'Q4197461': 'Q3700011',
#  'Q7110870': 'Q9842',
#  'Q28231914': 'Q20646667',
#  'Q66626352': 'Q66436502',
#  'Q193555': 'Q5',
#  'Q1928529': 'Q3032114',
#  'Q495368': 'Q13414761',
#  'Q2631047': 'Q33125444',
#  'Q31': 'Q3624078',
#  'Q804': 'Q3624078',
#  'Q241510': 'Q5',
#  'Q9253': 'Q8928',
#  'Q4110': 'Q185113',
#  'Q32525': 'Q7830213',
#  'Q10433434': 'Q1523821',
#  'Q3906875': 'Q2292572',
#  'Q18214785': 'Q63100559',
#  'Q61776057': 'Q2990963',
#  'Q272228': 'Q493522',
#  'Q58954843': 'Q1744559',
#  'Q181209': 'Q1776764',
#  'Q244939': 'Q3199915',
#  'Q75260388': 'Q66619666',
#  'Q11230': 'Q9135',
#  'Q1004727': 'Q74047',
#  'Q11504054': 'Q52721923',
#  'Q29565378': 'Q21191270',
#  'Q30035239': 'Q214252',
#  'Q217208': 'Q1790144',
#  'Q19259801': 'Q5',
#  'Q18881779': 'Q559290',
#  'Q20858898': 'Q4229812',
#  'Q1466686': 'Q174736',
#  'Q68920959': 'Q856584',
#  'Q686056': 'Q1630622',
#  'Q173830': 'Q158683',
#  'Q9589': 'Q210337',
#  'Q60223356': 'Q67201574',
#  'Q363830': 'Q35034452',
#  'Q93204': 'Q201658',
#  'Q546774': 'Q952274',
#  'Q65916': 'Q7965',
#  'Q130010': 'Q3863',
#  'Q983763': 'Q213930',
#  'Q20685047': 'Q217327',
#  'Q73033992': 'Q73492292',
#  'Q20007242': 'Q63100559',
#  'Q60228128': 'Q60491487',
#  'Q1581608': 'Q47345468',
#  'Q488659': 'Q13410464',
#  'Q22999204': 'Q23058950',
#  'Q27020449': 'Q969090',
#  'Q15790719': 'Q1756006',
#  'Q1165067': 'Q1344',
#  'Q22337857': 'Q20437094',
#  'Q52698310': 'Q1138671',
#  'Q77919237': 'Q195385',
#  'Q1342630': 'Q1233985',
#  'Q3768698': 'Q510578',
#  'Q1672877': 'Q375545',
#  'Q9360362': 'Q549121',
#  'Q2072339': 'Q14750991',
#  'Q43304268': 'Q23726798',
#  'Q1865430': 'Q5741069',
#  'Q51333632': 'Q182084',
#  'Q19897601': 'Q178659',
#  'Q2564881': 'Q1190435',
#  'Q23644362': 'Q55678',
#  'Q4869783': 'Q240313',
#  'Q390166': 'Q3146899',
#  'Q996394': 'Q428759',
#  'Q2921991': 'Q54114',
#  'Q2922269': 'Q672593',
#  'Q8133': 'Q3199141',
#  'Q5598340': 'Q22713629',
#  'Q15967005': 'Q1349648',
#  'Q2889254': 'Q1261499',
#  'Q187035': 'Q3024240',
#  'Q10430474': 'Q24566025',
#  'Q6983067': 'Q2775236',
#  'Q66661038': 'Q55850643',
#  'Q15895633': 'Q969090',
#  'Q35715': 'Q5852411',
#  'Q10433171': 'Q615980',
#  'Q18845029': 'Q1373439',
#  'Q3188': 'Q5',
#  'Q6960881': 'Q2775236',
#  'Q22329420': 'Q5058355',
#  'Q2014236': 'Q40357',
#  'Q12071629': 'Q36728566',
#  'Q128239': 'Q5',
#  'Q28232858': 'Q1190554',
#  'Q12829733': 'Q1637706',
#  'Q5009563': 'Q14978',
#  'Q78250551': 'Q1141054',
#  'Q3504608': 'Q34262807',
#  'Q78792145': 'Q1993624',
#  'Q7995386': 'Q39715',
#  'Q31887872': 'Q1153392',
#  'Q1225307': 'Q1426271',
#  'Q542': 'Q31629',
#  'Q3540252': 'Q2516436',
#  'Q94552': 'Q1153408',
#  'Q18150340': 'Q240313',
#  'Q165844': 'Q192287',
#  'Q1753042': 'Q208569',
#  'Q21117876': 'Q43109',
#  'Q9256': 'Q8928',
#  'Q139390': 'Q523',
#  'Q4209622': 'Q15195406',
#  'Q894060': 'Q1849126',
#  'Q56244868': 'Q17558136',
#  'Q3216452': 'Q1132998',
#  'Q2993511': 'Q7216840',
#  'Q1895030': 'Q42211429',
#  'Q669802': 'Q27448',
#  'Q2092297': 'Q55983715',
#  'Q83618693': 'Q6251',
#  'Q14955366': 'Q5',
#  'Q18881966': 'Q550394',
#  'Q284033': 'Q3231690',
#  'Q75258': 'Q12377751',
#  'Q203337': 'Q930752',
#  'Q57749192': 'Q22936940',
#  'Q11399': 'Q188451',
#  'Q19964657': 'Q47521',
#  'Q573797': 'Q5',
#  'Q15853747': 'Q10832530',
#  'Q15180': 'Q3024240',
#  'Q7804770': 'Q21664088',
#  'Q7372345': 'Q5',
#  'Q1075076': 'Q1161185',
#  'Q2257793': 'Q37726',
#  'Q19896714': 'Q15727816',
#  'Q766954': 'Q18536594',
#  'Q1110': 'Q47537235',
#  'Q15879396': 'Q33951',
#  'Q79339': 'Q1093829',
#  'Q309031': 'Q1618899',
#  'Q751527': 'Q18608583',
#  'Q57297933': 'Q7138926',
#  'Q180717': 'Q41067667',
#  'Q62118627': 'Q386318',
#  'Q3413952': 'Q1076486',
#  'Q79508657': 'Q5898',
#  'Q11967583': 'Q3270632',
#  'Q19793959': 'Q12308941',
#  'Q2920430': 'Q756102',
#  'Q2702789': 'Q1762059',
#  'Q67633349': 'Q204107',
#  'Q1783232': 'Q14978',
#  'Q151777': 'Q3863',
#  'Q2493914': 'Q606986',
#  'Q1136': 'Q3220391',
#  'Q1047325': 'Q11387',
#  'Q22999992': 'Q23058950',
#  'Q63553353': 'Q1788582',
#  'Q10861661': 'Q20671381',
#  'Q2579762': 'Q520381',
#  'Q11347': 'Q33146843',
#  'Q900366': 'Q131734',
#  'Q4722824': 'Q5',
#  'Q749667': 'Q5',
#  'Q56218427': 'Q860861',
#  'Q582938': 'Q5',
#  'Q85293718': 'Q1457376',
#  'Q47484047': 'Q1007870',
#  'Q569833': 'Q21672098',
#  'Q81909709': 'Q272447',
#  'Q64228775': 'Q40231',
#  'Q339301': 'Q6784672',
#  'Q245275': 'Q15056993',
#  'Q285392': 'Q16905563',
#  'Q29364132': 'Q20646668',
#  'Q7707431': 'Q26895936',
#  'Q51586': 'Q1840161',
#  'Q494751': 'Q13415366',
#  'Q1661724': 'Q1661706',
#  'Q62140': 'Q755707',
#  'Q84005862': 'Q6458',
#  'Q4117347': 'Q6617100',
#  'Q23301856': 'Q23790218',
#  'Q78257068': 'Q1362543',
#  'Q1928672': 'Q207694',
#  'Q66023369': 'Q134307',
#  'Q14564217': 'Q54231557',
#  'Q7593996': 'Q233324',
#  'Q18028325': 'Q7187',
#  'Q236122': 'Q32880',
#  'Q8423208': 'Q2175765',
#  'Q2493319': 'Q1162560',
#  'Q47469419': 'Q7302866',
#  'Q648338': 'Q811979',
#  'Q484101': 'Q755707',
#  'Q78243770': 'Q1062509',
#  'Q18888136': 'Q1372372',
#  'Q4583': 'Q5',
#  'Q2310001': 'Q25930498',
#  'Q37058120': 'Q5185279',
#  'Q326205': 'Q47345468',
#  'Q23008384': 'Q93184',
#  'Q862538': 'Q1259759',
#  'Q84210802': 'Q72803622',
#  'Q59099656': 'Q595597',
#  'Q523811': 'Q3146899',
#  'Q2926321': 'Q532',
#  'Q56459180': 'Q5',
#  'Q1649487': 'Q605291',
#  'Q49385499': 'Q31615',
#  'Q80055770': 'Q57216',
#  'Q1860': 'Q1288568',
#  'Q59588177': 'Q893394',
#  'Q3205079': 'Q20667187',
#  'Q64647582': 'Q220659',
#  'Q10850292': 'Q830831',
#  'Q74279903': 'Q1457376',
#  'Q10493440': 'Q45364',
#  'Q7163494': 'Q398141',
#  'Q3598571': 'Q2292572',
#  'Q1021458': 'Q1333366',
#  'Q28829541': 'Q26849121',
#  'Q7393150': 'Q105999',
#  'Q6924389': 'Q5774403',
#  'Q56260842': 'Q1917626',
#  'Q171806': 'Q9109',
#  'Q13150981': 'Q3812392',
#  'Q2085364': 'Q1149652',
#  'Q1500544': 'Q207524',
#  'Q58626082': 'Q11253501',
#  'Q82667': 'Q5',
#  'Q64438489': 'Q25930493',
#  'Q12060810': 'Q18608583',
#  'Q86670998': 'Q860861',
#  'Q585264': 'Q55990535',
#  'Q75386085': 'Q5',
#  'Q5936611': 'Q15284',
#  'Q6989822': 'Q17318027',
#  'Q16064454': 'Q5',
#  'Q2010196': 'Q1985797',
#  'Q5055611': 'Q746549',
#  'Q19183328': 'Q858157',
#  'Q2272664': 'Q2739132',
#  'Q2237427': 'Q3773971',
#  'Q1172213': 'Q210167',
#  'Q3365190': 'Q33992',
#  'Q13341': 'Q2154519',
#  'Q10468': 'Q8928',
#  'Q232': 'Q3624078',
#  'Q3133': 'Q1075',
#  'Q18881811': 'Q1377841',
#  'Q6934542': 'Q5',
#  'Q19309602': 'Q1926218',
#  'Q837157': 'Q16858213',
#  'Q1434368': 'Q166620',
#  'Q2279903': 'Q188509',
#  'Q30158307': 'Q179049',
#  'Q296955': 'Q3300034',
#  'Q41357526': 'Q25377652',
#  'Q572887': 'Q11303',
#  'Q51226420': 'Q785745',
#  'Q2886555': 'Q33992',
#  'Q86709837': 'Q1048372',
#  'Q177422': 'Q253019',
#  'Q868761': 'Q1366112',
#  'Q748614': 'Q229390',
#  'Q866763': 'Q285181',
#  'Q44545': 'Q4174776',
#  'Q67492': 'Q5',
#  'Q25336679': 'Q25930495',
#  'Q279316': 'Q875583',
#  'Q74717087': 'Q5871',
#  'Q16320957': 'Q19832486',
#  'Q915185': 'Q158490',
#  'Q85193927': 'Q27150479',
#  'Q78241866': 'Q1352333',
#  'Q85263259': 'Q11282',
#  'Q14209673': 'Q1496967',
#  'Q60955876': 'Q55850593',
#  'Q2124442': 'Q697196',
#  'Q3441308': 'Q3088847',
#  'Q4461043': 'Q375336',
#  'Q80939555': 'Q72802508',
#  'Q1707602': 'Q3143713',
#  'Q79859770': 'Q812800',
#  'Q730948': 'Q22746',
#  'Q244173': 'Q39911',
#  'Q179920': 'Q428303',
#  'Q771404': 'Q12570',
#  'Q214': 'Q3624078',
#  'Q3497609': 'Q659396',
#  'Q739444': 'Q16858213',
#  'Q797124': 'Q811704',
#  'Q29385162': 'Q153988',
#  'Q20925': 'Q7954',
#  'Q3494880': 'Q2485448',
#  'Q155': 'Q3624078',
#  'Q85098865': 'Q856584',
#  'Q47090559': 'Q388602',
#  'Q66012577': 'Q56855534',
#  'Q6514537': 'Q1410668',
#  'Q3119562': 'Q5',
#  'Q190850': 'Q9299236',
#  'Q574624': 'Q5',
#  'Q1106429': 'Q1931185',
#  'Q66491280': 'Q50053',
#  'Q27952528': 'Q47018478',
#  'Q18208043': 'Q1788716',
#  'Q12225733': 'Q12225020',
#  'Q507149': 'Q2074737',
#  'Q44182002': 'Q26703203',
#  'Q6305770': 'Q1060829',
#  'Q43304617': 'Q23726798',
#  'Q19901267': 'Q171318',
#  'Q10849821': 'Q1993624',
#  'Q75275217': 'Q726242',
#  'Q537223': 'Q1057026',
#  'Q606060': 'Q22936940',
#  'Q3134801': 'Q606986',
#  'Q41323': 'Q31629',
#  'Q75211641': 'Q54231557',
#  'Q2410192': 'Q47345468',
#  'Q192680': 'Q1021645',
#  'Q4044993': 'Q7187',
#  'Q406': 'Q1200957',
#  'Q65103948': 'Q12131650',
#  'Q1193206': 'Q25930740',
#  'Q1012297': 'Q23413',
#  'Q1055317': 'Q43639983',
#  'Q822426': 'Q11424',
#  'Q3494837': 'Q2026833',
#  'Q18881859': 'Q549728',
#  'Q47605715': 'Q21246076',
#  'Q286183': 'Q5',
#  'Q60346': 'Q327333',
#  'Q28162': 'Q2537537',
#  'Q1436983': 'Q5',
#  'Q77364804': 'Q497654',
#  'Q3674392': 'Q1128397',
#  'Q198197': 'Q2989457',
#  'Q5386': 'Q31629',
#  'Q33': 'Q3624078',
#  'Q221457': 'Q3024240',
#  'Q3030': 'Q3863',
#  'Q321242': 'Q92026',
#  'Q7105792': 'Q1863818',
#  'Q47450550': 'Q212971',
#  'Q20947': 'Q7954',
#  'Q1607762': 'Q2276925',
#  'Q10850130': 'Q812800',
#  'Q754790': 'Q6784672',
#  'Q6932085': 'Q42034610',
#  'Q78133028': 'Q168845',
#  'Q62724565': 'Q1983265',
#  'Q1021739': 'Q17205621',
#  'Q484644': 'Q140588',
#  'Q3323': 'Q7930989',
#  'Q33259525': 'Q1065252',
#  'Q25336706': 'Q25930498',
#  'Q3533194': 'Q11755959',
#  'Q2208099': 'Q15219655',
#  'Q2533464': 'Q402092',
#  'Q75065815': 'Q71798532',
#  'Q18689636': 'Q93184',
#  'Q6813031': 'Q2582669',
#  'Q54806110': 'Q7302866',
#  'Q10076': 'Q2039348',
#  'Q2778352': 'Q917146',
#  'Q2397209': 'Q1363599',
#  'Q7821687': 'Q15911738',
#  'Q138955': 'Q37748',
#  'Q7555153': 'Q77115',
#  'Q28609936': 'Q15145593',
#  'Q1636819': 'Q2338524',
#  'Q1048036': 'Q11276',
#  'Q38848': 'Q188451',
#  'Q2085330': 'Q11276',
#  'Q841525': 'Q2039348',
#  'Q22341944': 'Q21191270',
#  'Q63457229': 'Q16152241',
#  'Q62760090': 'Q369183',
#  'Q5856459': 'Q39715',
#  'Q33946': 'Q3024240',
#  'Q22927640': 'Q17172602',
#  'Q1202754': 'Q1059478',
#  'Q85267597': 'Q18393176',
#  'Q27680328': 'Q26960982',
#  'Q1033': 'Q3624078',
#  'Q1150287': 'Q72802508',
#  'Q12179': 'Q6243',
#  'Q202703': 'Q5',
#  'Q18213370': 'Q39804',
#  'Q4932095': 'Q5',
#  'Q1177': 'Q13390680',
#  'Q79377719': 'Q57733494',
#  'Q17077904': 'Q15966540',
#  'Q383854': 'Q24869',
#  'Q2557992': 'Q1274559',
#  'Q1264884': 'Q5741069',
#  'Q12153480': 'Q15921247',
#  'Q273593': 'Q847027',
#  'Q47254810': 'Q212971',
#  'Q18681690': 'Q550637',
#  'Q27347921': 'Q2368579',
#  'Q56817618': 'Q56731284',
#  'Q1104105': 'Q15917122',
#  'Q171356': 'Q2338524',
#  'Q17514557': 'Q15276',
#  'Q1420169': 'Q19723444',
#  'Q18883125': 'Q1330776',
#  'Q1477975': 'Q2122052',
#  'Q25403118': 'Q4671277',
#  'Q84216313': 'Q72803622',
#  'Q86857750': 'Q10451997',
#  'Q1449561': 'Q12308941',
#  'Q15305586': 'Q37748',
#  'Q1630016': 'Q158438',
#  'Q56438722': 'Q207184',
#  'Q5174901': 'Q34228',
#  'Q1847762': 'Q63440326',
#  'Q155756': 'Q29048322',
#  'Q10501': 'Q5',
#  'Q527914': 'Q18618819',
#  'Q56677470': 'Q2668072',
#  'Q18640021': 'Q245016',
#  'Q15296456': 'Q868557',
#  'Q21644845': 'Q80793969',
#  'Q141903': 'Q27676416',
#  'Q26907192': 'Q56019',
#  'Q11322463': 'Q193955',
#  'Q83395': 'Q247073',
#  'Q4573416': 'Q16560',
#  'Q2084217': 'Q15145593',
#  'Q21199328': 'Q14860489',
#  'Q2257872': 'Q1503450',
#  'Q4029882': 'Q51977',
#  'Q11652435': 'Q370258',
#  'Q26346560': 'Q1402850',
#  'Q414': 'Q3624078',
#  'Q1716267': 'Q532',
#  'Q1200768': 'Q11424045',
#  'Q2986940': 'Q159321',
#  'Q625154': 'Q13218690',
#  'Q2150454': 'Q7889',
#  'Q588': 'Q925381',
#  'Q24056546': 'Q55558200',
#  'Q7559906': 'Q1595639',
#  'Q110084': 'Q1058795',
#  'Q506209': 'Q13415368',
#  'Q1282207': 'Q137535',
#  'Q252': 'Q3624078',
#  'Q13608': 'Q33146843',
#  'Q1988126': 'Q1853314',
#  'Q18845001': 'Q468008',
#  'Q293513': 'Q15056993',
#  'Q59784978': 'Q856713',
#  'Q3997333': 'Q3407658',
#  'Q171400': 'Q926439',
#  'Q772702': 'Q532',
#  'Q6378467': 'Q2775236',
#  'Q623417': 'Q14276458',
#  'Q15033976': 'Q645924',
#  'Q17038844': 'Q34228',
#  'Q23766764': 'Q11707',
#  'Q3415262': 'Q12859788',
#  'Q51381059': 'Q732577',
#  'Q56161260': 'Q1917626',
#  'Q3774425': 'Q2733412',
#  'Q21684685': 'Q18333556',
#  'Q5419858': 'Q1338798',
#  'Q220378': 'Q2983893',
#  'Q10481': 'Q8928',
#  'Q27712607': 'Q5633421',
#  'Q11613': 'Q5',
#  'Q25384504': 'Q33992',
#  'Q80027': 'Q62049',
#  ...}

# %%
with open('R4_WD_query_type.json', 'w') as json_file:
    json.dump(WD_query_type, json_file, indent=4)

# %%
#print(f"{type_str}: {get_type_id(type_str)}")

entity_name = key_to_cell[list(WD_query_type.keys())[0]]
ext_query_types = list(set(retrieve_superclasses("Q31")))

# query a lamapi dove specifico nel filtro il tipo

#WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
print(ext_query_types)
# Out:
# ['Q31']

# %%
# Initialize an empty dictionary for NER_query_type
NER_query_type = {}

# Iterate over WD_query_type.keys() with a tqdm progress bar
for entity_name, entity_type in tqdm(WD_query_type.items(), desc="Processing Entities", unit="entity"):
    if entity_type is None:
        print("none")
        NER_query_type[entity_name] = None
    else:
        NER_query_type[entity_name] = NER_types(entity_type)

with open('HTR3_NER_query_type.json', 'w') as json_file:
    json.dump(NER_query_type, json_file, indent=4)


# Display the resulting dictionary
NER_query_type
# Out:
# Processing Entities:   0%|          | 0/47171 [00:00<?, ?entity/s]
# Processing Entities: 100%|██████████| 47171/47171 [00:27<00:00, 1732.20entity/s]
# {'Q64618013': 'OTHERS',
#  'Q64617600': 'OTHERS',
#  'Q56682821': 'OTHERS',
#  'Q56612179': 'OTHERS',
#  'Q43221084': 'OTHERS',
#  'Q28890011': 'OTHERS',
#  'Q19818313': 'OTHERS',
#  'Q16941209': 'OTHERS',
#  'Q16941198': 'OTHERS',
#  'Q16941177': 'OTHERS',
#  'Q16941174': 'OTHERS',
#  'Q16941171': 'OTHERS',
#  'Q16941169': 'OTHERS',
#  'Q16941162': 'OTHERS',
#  'Q16941157': 'OTHERS',
#  'Q16941154': 'OTHERS',
#  'Q16941150': 'OTHERS',
#  'Q5856992': 'OTHERS',
#  'Q62422071': 'OTHERS',
#  'Q60999791': 'OTHERS',
#  'Q105554399': 'OTHERS',
#  'Q100250170': 'OTHERS',
#  'Q99701350': 'OTHERS',
#  'Q28096756': 'OTHERS',
#  'Q21198118': 'OTHERS',
#  'Q20546376': 'OTHERS',
#  'Q43339738': 'OTHERS',
#  'Q11390403': 'OTHERS',
#  'Q10920066': 'OTHERS',
#  'Q7074635': 'OTHERS',
#  'Q5366046': 'OTHERS',
#  'Q5362166': 'OTHERS',
#  'Q5360937': 'OTHERS',
#  'Q4145038': 'OTHERS',
#  'Q15905509': 'OTHERS',
#  'Q11886645': 'OTHERS',
#  'Q1376060': 'OTHERS',
#  'Q1213085': 'OTHERS',
#  'Q1164830': 'OTHERS',
#  'Q3761739': 'OTHERS',
#  'Q3289889': 'OTHERS',
#  'Q1042011': 'OTHERS',
#  'Q951587': 'OTHERS',
#  'Q634778': 'OTHERS',
#  'Q45192': 'OTHERS',
#  'Q2657795': 'OTHERS',
#  'Q2603313': 'OTHERS',
#  'Q1966961': 'OTHERS',
#  'Q1886719': 'OTHERS',
#  'Q732740': 'OTHERS',
#  'Q558904': 'OTHERS',
#  'Q376895': 'OTHERS',
#  'Q204656': 'OTHERS',
#  'Q202040': 'OTHERS',
#  'Q200759': 'OTHERS',
#  'Q200753': 'OTHERS',
#  'Q189097': 'OTHERS',
#  'Q98455775': 'OTHERS',
#  'Q97999616': 'OTHERS',
#  'Q33129408': 'OTHERS',
#  'Q33129398': 'OTHERS',
#  'Q33129395': 'OTHERS',
#  'Q28153817': 'OTHERS',
#  'Q21073913': 'OTHERS',
#  'Q19637802': 'OTHERS',
#  'Q19567333': 'OTHERS',
#  'Q18214785': 'OTHERS',
#  'Q18214731': 'OTHERS',
#  'Q10835425': 'OTHERS',
#  'Q7145355': 'OTHERS',
#  'Q5947103': 'OTHERS',
#  'Q3517882': 'OTHERS',
#  'Q3517879': 'OTHERS',
#  'Q3517875': 'OTHERS',
#  'Q3517869': 'OTHERS',
#  'Q3358417': 'OTHERS',
#  'Q3358402': 'OTHERS',
#  'Q3306096': 'OTHERS',
#  'Q3249186': 'OTHERS',
#  'Q3089803': 'OTHERS',
#  'Q3089461': 'OTHERS',
#  'Q2665633': 'OTHERS',
#  'Q1330558': 'LOC',
#  'Q805915': 'LOC',
#  'Q1638935': 'LOC',
#  'Q1550157': 'LOC',
#  'Q1053880': 'LOC',
#  'Q999791': 'LOC',
#  'Q799818': 'LOC',
#  'Q1427939': 'LOC',
#  'Q408217': 'LOC',
#  'Q2454241': 'LOC',
#  'Q578799': 'LOC',
#  'Q547770': 'LOC',
#  'Q422765': 'LOC',
#  'Q315110': 'LOC',
#  'Q312866': 'LOC',
#  'Q255010': 'LOC',
#  'Q214916': 'LOC',
#  'Q207284': 'LOC',
#  'Q188982': 'LOC',
#  'Q185847': 'LOC',
#  'Q183027': 'LOC',
#  'Q131230': 'LOC',
#  'Q131148': 'LOC',
#  'Q1026302': 'LOC',
#  'Q851232': 'LOC',
#  'Q814113': 'LOC',
#  'Q1552026': 'LOC',
#  'Q1478849': 'LOC',
#  'Q1373738': 'LOC',
#  'Q4070254': 'LOC',
#  'Q2827394': 'LOC',
#  'Q192541': 'LOC',
#  'Q182378': 'LOC',
#  'Q181056': 'OTHERS',
#  'Q178993': 'OTHERS',
#  'Q174461': 'LOC',
#  'Q172996': 'LOC',
#  'Q172512': 'OTHERS',
#  'Q170578': 'OTHERS',
#  'Q170454': 'LOC',
#  'Q168929': 'OTHERS',
#  'Q166065': 'LOC',
#  'Q165341': 'OTHERS',
#  'Q159273': 'LOC',
#  'Q146723': 'LOC',
#  'Q132754': 'LOC',
#  'Q131694': 'LOC',
#  'Q131620': 'OTHERS',
#  'Q112813': 'LOC',
#  'Q103717': 'LOC',
#  'Q83786': 'LOC',
#  'Q80989': 'ORG',
#  'Q80484': 'LOC',
#  'Q79281': 'LOC',
#  'Q69007': 'LOC',
#  'Q68286': 'LOC',
#  'Q68155': 'LOC',
#  'Q66485': 'LOC',
#  'Q63964': 'LOC',
#  'Q56037': 'LOC',
#  'Q52101': 'OTHERS',
#  'Q48329': 'LOC',
#  'Q47916': 'OTHERS',
#  'Q44215': 'LOC',
#  'Q44211': 'LOC',
#  'Q44059': 'LOC',
#  'Q43433': 'OTHERS',
#  'Q42800': 'LOC',
#  'Q41699': 'LOC',
#  'Q41295': 'LOC',
#  'Q40269': 'OTHERS',
#  'Q40236': 'OTHERS',
#  'Q38807': 'LOC',
#  'Q37701': 'LOC',
#  'Q36378': 'OTHERS',
#  'Q36262': 'LOC',
#  'Q36260': 'LOC',
#  'Q36168': 'LOC',
#  'Q35381': 'LOC',
#  'Q34820': 'OTHERS',
#  'Q34692': 'LOC',
#  'Q34261': 'LOC',
#  'Q34205': 'LOC',
#  'Q34126': 'LOC',
#  'Q30985': 'LOC',
#  'Q30970': 'LOC',
#  'Q30966': 'LOC',
#  'Q25390': 'OTHERS',
#  'Q475718': 'LOC',
#  'Q217610': 'LOC',
#  'Q173310': 'LOC',
#  'Q170482': 'LOC',
#  'Q167551': 'LOC',
#  'Q132679': 'LOC',
#  'Q83442': 'LOC',
#  'Q48338': 'LOC',
#  'Q42751': 'LOC',
#  'Q41547': 'LOC',
#  'Q41474': 'LOC',
#  'Q36281': 'LOC',
#  'Q31924457': 'LOC',
#  'Q31924170': 'LOC',
#  'Q31912265': 'LOC',
#  'Q31911550': 'LOC',
#  'Q31887734': 'LOC',
#  'Q31880915': 'LOC',
#  'Q3125978': 'LOC',
#  'Q5096': 'LOC',
#  'Q5095': 'LOC',
#  'Q5093': 'OTHERS',
#  'Q5067': 'LOC',
#  'Q3630': 'OTHERS',
#  'Q3540': 'LOC',
#  'Q2175': 'LOC',
#  'Q2110': 'LOC',
#  'Q2051': 'LOC',
#  'Q1890': 'LOC',
#  'Q1823': 'LOC',
#  'Q3518706': 'LOC',
#  'Q3461659': 'LOC',
#  'Q3460406': 'LOC',
#  'Q3459768': 'LOC',
#  'Q3419848': 'LOC',
#  'Q3314920': 'LOC',
#  'Q3300965': 'LOC',
#  'Q4155998': 'LOC',
#  'Q4154741': 'LOC',
#  'Q4154726': 'LOC',
#  'Q4153829': 'LOC',
#  'Q4153709': 'LOC',
#  'Q4152968': 'LOC',
#  'Q4152735': 'LOC',
#  'Q4152401': 'LOC',
#  'Q4151802': 'LOC',
#  'Q4151047': 'LOC',
#  'Q4150879': 'LOC',
#  'Q4150278': 'LOC',
#  'Q4149904': 'LOC',
#  'Q4149902': 'LOC',
#  'Q4149374': 'LOC',
#  'Q4149191': 'LOC',
#  'Q4148936': 'LOC',
#  'Q2946976': 'LOC',
#  'Q2913432': 'LOC',
#  'Q2855692': 'LOC',
#  'Q2800564': 'LOC',
#  'Q2797125': 'LOC',
#  'Q2752945': 'LOC',
#  'Q2742648': 'LOC',
#  'Q2683664': 'LOC',
#  'Q2681555': 'LOC',
#  'Q2671860': 'LOC',
#  'Q2671529': 'LOC',
#  'Q2671441': 'LOC',
#  'Q2671407': 'LOC',
#  'Q2634354': 'LOC',
#  'Q2595518': 'LOC',
#  'Q2594748': 'LOC',
#  'Q2583374': 'LOC',
#  'Q2582335': 'LOC',
#  'Q2582280': 'LOC',
#  'Q2582262': 'LOC',
#  'Q2582239': 'LOC',
#  'Q2582172': 'LOC',
#  'Q2582164': 'LOC',
#  'Q2582138': 'LOC',
#  'Q2581422': 'LOC',
#  'Q2581370': 'LOC',
#  'Q2581329': 'LOC',
#  'Q2580596': 'LOC',
#  'Q2580545': 'LOC',
#  'Q2571352': 'LOC',
#  'Q2571342': 'LOC',
#  'Q2571332': 'LOC',
#  'Q2571321': 'LOC',
#  'Q2571284': 'LOC',
#  'Q2571261': 'LOC',
#  'Q2571236': 'LOC',
#  'Q2571143': 'LOC',
#  'Q2571093': 'LOC',
#  'Q2570978': 'LOC',
#  'Q4131345': 'LOC',
#  'Q4131255': 'LOC',
#  'Q4130551': 'LOC',
#  'Q4130191': 'LOC',
#  'Q29388865': 'LOC',
#  'Q28816824': 'LOC',
#  'Q21671955': 'LOC',
#  'Q19866132': 'LOC',
#  'Q18797988': 'LOC',
#  'Q16081245': 'LOC',
#  'Q13664894': 'LOC',
#  'Q13664159': 'LOC',
#  'Q13664107': 'LOC',
#  'Q4537659': 'LOC',
#  'Q4484199': 'LOC',
#  'Q4246092': 'LOC',
#  'Q4144587': 'LOC',
#  'Q2222188': 'LOC',
#  'Q2205117': 'LOC',
#  'Q2088362': 'LOC',
#  'Q2049851': 'LOC',
#  'Q1942119': 'LOC',
#  'Q1929247': 'LOC',
#  'Q1883376': 'LOC',
#  'Q1850752': 'LOC',
#  'Q1542954': 'LOC',
#  'Q1538637': 'LOC',
#  'Q1415603': 'LOC',
#  'Q2485856': 'LOC',
#  'Q2336616': 'LOC',
#  'Q2262789': 'LOC',
#  'Q2229606': 'LOC',
#  'Q2224952': 'LOC',
#  'Q2224643': 'LOC',
#  'Q4078826': 'LOC',
#  'Q4074351': 'LOC',
#  'Q2595364': 'LOC',
#  'Q2566263': 'LOC',
#  'Q1092110': 'LOC',
#  'Q593657': 'LOC',
#  'Q564666': 'LOC',
#  'Q1027778': 'LOC',
#  'Q985341': 'LOC',
#  'Q957234': 'LOC',
#  'Q919404': 'LOC',
#  'Q66647574': 'OTHERS',
#  'Q32012250': 'OTHERS',
#  'Q10508756': 'OTHERS',
#  'Q21876782': 'OTHERS',
#  'Q878515': 'LOC',
#  'Q770034': 'OTHERS',
#  'Q516969': 'LOC',
#  'Q372495': 'OTHERS',
#  'Q80085704': 'OTHERS',
#  'Q60788436': 'OTHERS',
#  'Q7120753': 'OTHERS',
#  'Q1367579': 'OTHERS',
#  'Q92404930': 'OTHERS',
#  'Q4048736': 'OTHERS',
#  'Q3359876': 'OTHERS',
#  'Q1141601': 'OTHERS',
#  'Q18096': 'OTHERS',
#  'Q13053153': 'OTHERS',
#  'Q4389664': 'OTHERS',
#  'Q4359862': 'OTHERS',
#  'Q4266523': 'OTHERS',
#  'Q4233652': 'OTHERS',
#  'Q4231133': 'OTHERS',
#  'Q4231036': 'OTHERS',
#  'Q4222706': 'OTHERS',
#  'Q4173632': 'OTHERS',
#  'Q4125342': 'OTHERS',
#  'Q3721635': 'OTHERS',
#  'Q3565985': 'OTHERS',
#  'Q3359198': 'OTHERS',
#  'Q2263726': 'OTHERS',
#  'Q2016722': 'OTHERS',
#  'Q895230': 'OTHERS',
#  'Q874055': 'OTHERS',
#  'Q873782': 'OTHERS',
#  'Q872727': 'OTHERS',
#  'Q833005': 'OTHERS',
#  'Q828149': 'OTHERS',
#  'Q544649': 'OTHERS',
#  'Q314936': 'OTHERS',
#  'Q195364': 'OTHERS',
#  'Q185471': 'OTHERS',
#  'Q35398184': 'OTHERS',
#  'Q18751502': 'OTHERS',
#  'Q16929154': 'OTHERS',
#  'Q16636835': 'OTHERS',
#  'Q14915435': 'OTHERS',
#  'Q14915432': 'OTHERS',
#  'Q14714072': 'OTHERS',
#  'Q13133279': 'OTHERS',
#  'Q11728226': 'OTHERS',
#  'Q4506027': 'OTHERS',
#  'Q55499': 'OTHERS',
#  'Q26439': 'OTHERS',
#  'Q14372': 'OTHERS',
#  'Q13712': 'OTHERS',
#  'Q13696': 'OTHERS',
#  'Q3140': 'OTHERS',
#  'Q2237': 'OTHERS',
#  'Q1670': 'OTHERS',
#  'Q7996347': 'OTHERS',
#  'Q5459559': 'OTHERS',
#  'Q3981201': 'OTHERS',
#  'Q3388682': 'OTHERS',
#  'Q2092571': 'OTHERS',
#  'Q1823611': 'OTHERS',
#  'Q1515792': 'OTHERS',
#  'Q1369002': 'OTHERS',
#  'Q1131444': 'OTHERS',
#  'Q1092055': 'OTHERS',
#  'Q1084490': 'OTHERS',
#  'Q1046685': 'OTHERS',
#  'Q957787': 'OTHERS',
#  'Q882739': 'OTHERS',
#  'Q879904': 'OTHERS',
#  'Q875573': 'OTHERS',
#  'Q859238': 'OTHERS',
#  'Q848308': 'OTHERS',
#  'Q831383': 'OTHERS',
#  'Q644839': 'OTHERS',
#  'Q607546': 'OTHERS',
#  'Q386331': 'OTHERS',
#  'Q272074': 'OTHERS',
#  'Q271044': 'OTHERS',
#  'Q269710': 'OTHERS',
#  'Q239883': 'OTHERS',
#  'Q234004': 'OTHERS',
#  'Q193737': 'OTHERS',
#  'Q191832': 'OTHERS',
#  'Q171847': 'OTHERS',
#  'Q132726': 'OTHERS',
#  'Q79082': 'OTHERS',
#  'Q78879': 'OTHERS',
#  'Q26475': 'OTHERS',
#  'Q26428': 'OTHERS',
#  'Q26390': 'OTHERS',
#  'Q8168': 'OTHERS',
#  'Q7355': 'OTHERS',
#  'Q5419': 'OTHERS',
#  'Q3392': 'OTHERS',
#  'Q3292': 'OTHERS',
#  'Q2249': 'OTHERS',
#  'Q2220': 'OTHERS',
#  'Q1653': 'OTHERS',
#  'Q1437877': 'OTHERS',
#  'Q1435649': 'OTHERS',
#  'Q1433898': 'OTHERS',
#  'Q1427802': 'OTHERS',
#  'Q1426889': 'OTHERS',
#  'Q1419776': 'OTHERS',
#  'Q1419768': 'OTHERS',
#  'Q1419767': 'OTHERS',
#  'Q1410560': 'OTHERS',
#  'Q1406220': 'OTHERS',
#  'Q1404530': 'OTHERS',
#  'Q1402280': 'OTHERS',
#  'Q1401645': 'OTHERS',
#  'Q1401323': 'OTHERS',
#  'Q1399427': 'OTHERS',
#  'Q1398954': 'OTHERS',
#  'Q1396529': 'OTHERS',
#  'Q1394598': 'OTHERS',
#  'Q1385630': 'OTHERS',
#  'Q1384100': 'OTHERS',
#  'Q1380889': 'OTHERS',
#  'Q1379590': 'OTHERS',
#  'Q1379448': 'OTHERS',
#  'Q1377824': 'OTHERS',
#  'Q1373757': 'OTHERS',
#  'Q1373695': 'OTHERS',
#  'Q1367429': 'OTHERS',
#  'Q1366854': 'OTHERS',
#  'Q1361444': 'OTHERS',
#  'Q1361278': 'OTHERS',
#  'Q1355497': 'OTHERS',
#  'Q1348658': 'OTHERS',
#  'Q1347122': 'OTHERS',
#  'Q1345956': 'OTHERS',
#  'Q1344826': 'OTHERS',
#  'Q1340869': 'OTHERS',
#  'Q1493840': 'OTHERS',
#  'Q1493342': 'OTHERS',
#  'Q1474817': 'OTHERS',
#  'Q1473068': 'OTHERS',
#  'Q1472999': 'OTHERS',
#  'Q1472356': 'OTHERS',
#  'Q1334005': 'OTHERS',
#  'Q1331986': 'OTHERS',
#  'Q1331970': 'OTHERS',
#  'Q1324632': 'OTHERS',
#  'Q1324314': 'OTHERS',
#  'Q1323916': 'OTHERS',
#  'Q1318680': 'OTHERS',
#  'Q1309881': 'OTHERS',
#  'Q1304054': 'OTHERS',
#  'Q1302430': 'OTHERS',
#  'Q1296770': 'OTHERS',
#  'Q1280043': 'OTHERS',
#  'Q1279831': 'OTHERS',
#  'Q1278490': 'OTHERS',
#  'Q1278440': 'OTHERS',
#  'Q1267276': 'OTHERS',
#  'Q1266842': 'OTHERS',
#  'Q1264687': 'OTHERS',
#  'Q1264004': 'OTHERS',
#  'Q1261155': 'OTHERS',
#  'Q1260810': 'OTHERS',
#  'Q1259101': 'OTHERS',
#  'Q1258069': 'OTHERS',
#  'Q1255709': 'OTHERS',
#  'Q1255624': 'OTHERS',
#  'Q1255178': 'OTHERS',
#  'Q1254708': 'OTHERS',
#  'Q1252810': 'OTHERS',
#  'Q1251684': 'OTHERS',
#  'Q1251561': 'OTHERS',
#  'Q1246137': 'OTHERS',
#  'Q1245673': 'OTHERS',
#  'Q95562921': 'OTHERS',
#  'Q59602393': 'OTHERS',
#  'Q55763893': 'OTHERS',
#  'Q55763892': 'OTHERS',
#  'Q55763401': 'OTHERS',
#  'Q55763347': 'OTHERS',
#  'Q55760103': 'OTHERS',
#  'Q55759836': 'OTHERS',
#  'Q106874528': 'OTHERS',
#  'Q106874527': 'OTHERS',
#  'Q106874526': 'OTHERS',
#  'Q106874524': 'OTHERS',
#  'Q106874523': 'OTHERS',
#  'Q106874522': 'OTHERS',
#  'Q106874519': 'OTHERS',
#  'Q106874518': 'OTHERS',
#  'Q106874516': 'OTHERS',
#  'Q106874515': 'OTHERS',
#  'Q106874514': 'OTHERS',
#  'Q106874513': 'OTHERS',
#  'Q106874511': 'OTHERS',
#  'Q106874510': 'OTHERS',
#  'Q106874508': 'OTHERS',
#  'Q106874507': 'OTHERS',
#  'Q106874506': 'OTHERS',
#  'Q106874502': 'OTHERS',
#  'Q106874501': 'OTHERS',
#  'Q106874500': 'OTHERS',
#  'Q106874499': 'OTHERS',
#  'Q106874498': 'OTHERS',
#  'Q106874497': 'OTHERS',
#  'Q106874496': 'OTHERS',
#  'Q106874495': 'OTHERS',
#  'Q106874494': 'OTHERS',
#  'Q106874492': 'OTHERS',
#  'Q106874491': 'OTHERS',
#  'Q106874490': 'OTHERS',
#  'Q106874489': 'OTHERS',
#  'Q106874488': 'OTHERS',
#  'Q106874487': 'OTHERS',
#  'Q106874486': 'OTHERS',
#  'Q106874485': 'OTHERS',
#  'Q106874481': 'OTHERS',
#  'Q106874480': 'OTHERS',
#  'Q106874479': 'OTHERS',
#  'Q106874478': 'OTHERS',
#  'Q106874477': 'OTHERS',
#  'Q106874476': 'OTHERS',
#  'Q106874475': 'OTHERS',
#  'Q106874474': 'OTHERS',
#  'Q106874473': 'OTHERS',
#  'Q106874463': 'OTHERS',
#  'Q106874462': 'OTHERS',
#  'Q106874461': 'OTHERS',
#  'Q106874460': 'OTHERS',
#  'Q106874459': 'OTHERS',
#  'Q106874458': 'OTHERS',
#  'Q106874457': 'OTHERS',
#  'Q106874456': 'OTHERS',
#  'Q106874455': 'OTHERS',
#  'Q106874454': 'OTHERS',
#  'Q106874453': 'OTHERS',
#  'Q106874317': 'OTHERS',
#  'Q106874316': 'OTHERS',
#  'Q106874315': 'OTHERS',
#  'Q106874314': 'OTHERS',
#  'Q106874313': 'OTHERS',
#  'Q106874312': 'OTHERS',
#  'Q106874311': 'OTHERS',
#  'Q106874310': 'OTHERS',
#  'Q106874308': 'OTHERS',
#  'Q106874307': 'OTHERS',
#  'Q106874306': 'OTHERS',
#  'Q106874305': 'OTHERS',
#  'Q106874304': 'OTHERS',
#  'Q106874303': 'OTHERS',
#  'Q106874449': 'OTHERS',
#  'Q106874448': 'OTHERS',
#  'Q106874447': 'OTHERS',
#  'Q106874446': 'OTHERS',
#  'Q106874445': 'OTHERS',
#  'Q106874444': 'OTHERS',
#  'Q106874443': 'OTHERS',
#  'Q106874442': 'OTHERS',
#  'Q106874439': 'OTHERS',
#  'Q106874438': 'OTHERS',
#  'Q106874437': 'OTHERS',
#  'Q106874436': 'OTHERS',
#  'Q7962155': 'OTHERS',
#  'Q3635462': 'OTHERS',
#  'Q3428254': 'OTHERS',
#  'Q3425864': 'LOC',
#  'Q3237124': 'OTHERS',
#  'Q6015866': 'OTHERS',
#  'Q5305676': 'OTHERS',
#  'Q1922560': 'OTHERS',
#  'Q1912688': 'OTHERS',
#  'Q1773030': 'OTHERS',
#  'Q1773006': 'OTHERS',
#  'Q1772992': 'OTHERS',
#  'Q1770960': 'OTHERS',
#  'Q1757471': 'OTHERS',
#  'Q1751469': 'OTHERS',
#  'Q1648589': 'OTHERS',
#  'Q1648554': 'OTHERS',
#  'Q1648542': 'OTHERS',
#  'Q1648483': 'OTHERS',
#  'Q1648451': 'OTHERS',
#  'Q1648019': 'OTHERS',
#  'Q1647994': 'OTHERS',
#  'Q1647956': 'OTHERS',
#  'Q1647936': 'OTHERS',
#  'Q1647913': 'OTHERS',
#  'Q1647541': 'OTHERS',
#  'Q2115226': 'OTHERS',
#  'Q492744': 'OTHERS',
#  'Q490906': 'LOC',
#  'Q473914': 'OTHERS',
#  'Q379516': 'LOC',
#  'Q371790': 'OTHERS',
#  'Q322437': 'OTHERS',
#  'Q303366': 'OTHERS',
#  'Q253672': 'OTHERS',
#  'Q202565': 'OTHERS',
#  'Q180611': 'OTHERS',
#  'Q142476': 'OTHERS',
#  'Q1647359': 'OTHERS',
#  'Q1645811': 'OTHERS',
#  'Q1645791': 'OTHERS',
#  'Q1645760': 'OTHERS',
#  'Q1442461': 'OTHERS',
#  'Q1441219': 'OTHERS',
#  'Q1383990': 'OTHERS',
#  'Q984886': 'LOC',
#  'Q984882': 'LOC',
#  'Q976610': 'OTHERS',
#  'Q965529': 'OTHERS',
#  'Q1343166': 'OTHERS',
#  'Q1018597': 'OTHERS',
#  'Q1014699': 'OTHERS',
#  'Q1005913': 'OTHERS',
#  'Q931985': 'OTHERS',
#  'Q931116': 'OTHERS',
#  'Q928405': 'OTHERS',
#  'Q24012255': 'OTHERS',
#  'Q24012254': 'OTHERS',
#  'Q24012251': 'OTHERS',
#  'Q21923426': 'OTHERS',
#  'Q21913425': 'OTHERS',
#  'Q21911566': 'OTHERS',
#  'Q21910728': 'OTHERS',
#  'Q21909995': 'OTHERS',
#  'Q21907356': 'OTHERS',
#  'Q21907312': 'OTHERS',
#  'Q21906887': 'OTHERS',
#  'Q21894494': 'OTHERS',
#  'Q21892480': 'OTHERS',
#  'Q21888227': 'OTHERS',
#  'Q21716833': 'OTHERS',
#  'Q19873997': 'OTHERS',
#  'Q19461784': 'OTHERS',
#  'Q17002551': 'OTHERS',
#  'Q16967461': 'OTHERS',
#  'Q16892030': 'OTHERS',
#  'Q16891166': 'OTHERS',
#  'Q16646451': 'OTHERS',
#  'Q14935722': 'OTHERS',
#  'Q14935613': 'OTHERS',
#  'Q14935191': 'OTHERS',
#  'Q14934984': 'OTHERS',
#  'Q14934811': 'OTHERS',
#  'Q14218357': 'OTHERS',
#  'Q14208816': 'OTHERS',
#  'Q14206163': 'OTHERS',
#  'Q14202724': 'OTHERS',
#  'Q13902505': 'OTHERS',
#  'Q7637709': 'OTHERS',
#  'Q7622017': 'OTHERS',
#  'Q7618272': 'OTHERS',
#  'Q7600174': 'OTHERS',
#  'Q7592432': 'OTHERS',
#  'Q7592430': 'OTHERS',
#  'Q7581207': 'OTHERS',
#  'Q66030057': 'OTHERS',
#  'Q18420699': 'OTHERS',
#  'Q61774968': 'OTHERS',
#  'Q61034660': 'OTHERS',
#  'Q49594726': 'OTHERS',
#  'Q47374838': 'OTHERS',
#  'Q30889585': 'OTHERS',
#  'Q4012002': 'OTHERS',
#  'Q19626667': 'LOC',
#  'Q1585931': 'ORG',
#  'Q1311566': 'OTHERS',
#  'Q14753869': 'OTHERS',
#  'Q63313652': 'OTHERS',
#  'Q2000387': 'OTHERS',
#  'Q1808591': 'OTHERS',
#  'Q734970': 'OTHERS',
#  'Q474857': 'OTHERS',
#  'Q457453': 'ORG',
#  'Q206365': 'OTHERS',
#  'Q56042899': 'ORG',
#  'Q26660990': 'OTHERS',
#  'Q26644197': 'OTHERS',
#  'Q26618141': 'OTHERS',
#  'Q26604216': 'OTHERS',
#  'Q26563408': 'OTHERS',
#  'Q26563315': 'OTHERS',
#  'Q20712085': 'OTHERS',
#  'Q17547858': 'OTHERS',
#  'Q17547541': 'OTHERS',
#  'Q17533706': 'OTHERS',
#  'Q67225533': 'OTHERS',
#  'Q48814015': 'OTHERS',
#  'Q34805661': 'OTHERS',
#  'Q26397883': 'OTHERS',
#  'Q105712557': 'OTHERS',
#  'Q102423542': 'OTHERS',
#  'Q98960635': 'OTHERS',
#  'Q90291511': 'OTHERS',
#  'Q38051147': 'OTHERS',
#  'Q30609933': 'OTHERS',
#  'Q18354147': 'OTHERS',
#  'Q6886483': 'OTHERS',
#  'Q5588889': 'OTHERS',
#  'Q4799733': 'ORG',
#  'Q4792265': 'OTHERS',
#  'Q26656288': 'OTHERS',
#  'Q26501451': 'OTHERS',
#  'Q5447368': 'OTHERS',
#  'Q56116535': 'OTHERS',
#  'Q7633480': 'OTHERS',
#  'Q7521231': 'OTHERS',
#  'Q6226197': 'OTHERS',
#  'Q26463732': 'OTHERS',
#  'Q26463701': 'OTHERS',
#  'Q26398040': 'OTHERS',
#  'Q26397961': 'OTHERS',
#  'Q26397909': 'OTHERS',
#  'Q26280583': 'OTHERS',
#  'Q25209591': 'OTHERS',
#  'Q5081532': 'OTHERS',
#  'Q4956885': 'OTHERS',
#  'Q4850758': 'OTHERS',
#  'Q11849938': 'ORG',
#  'Q102482536': 'OTHERS',
#  'Q102425801': 'OTHERS',
#  'Q102422815': 'OTHERS',
#  'Q60763532': 'OTHERS',
#  'Q60763485': 'OTHERS',
#  'Q48850600': 'OTHERS',
#  'Q29497660': 'OTHERS',
#  'Q29497541': 'OTHERS',
#  'Q29497523': 'OTHERS',
#  'Q29497515': 'OTHERS',
#  'Q29497475': 'OTHERS',
#  'Q29497372': 'OTHERS',
#  'Q29497317': 'OTHERS',
#  'Q29497309': 'OTHERS',
#  'Q29497287': 'OTHERS',
#  'Q29497266': 'OTHERS',
#  'Q29497209': 'OTHERS',
#  'Q29497143': 'OTHERS',
#  'Q29487616': 'OTHERS',
#  'Q29487588': 'OTHERS',
#  'Q29487562': 'OTHERS',
#  'Q29487558': 'OTHERS',
#  'Q29487538': 'OTHERS',
#  'Q29487093': 'OTHERS',
#  'Q29487058': 'OTHERS',
#  'Q29487027': 'OTHERS',
#  'Q29487011': 'OTHERS',
#  'Q29486965': 'OTHERS',
#  'Q29486871': 'OTHERS',
#  'Q29486870': 'OTHERS',
#  'Q29486853': 'OTHERS',
#  'Q29486841': 'OTHERS',
#  'Q29486831': 'OTHERS',
#  'Q29486800': 'OTHERS',
#  'Q29486759': 'OTHERS',
#  'Q29486754': 'OTHERS',
#  'Q29486746': 'OTHERS',
#  'Q29486709': 'OTHERS',
#  'Q29486693': 'OTHERS',
#  'Q29486689': 'OTHERS',
#  'Q29486670': 'OTHERS',
#  'Q29486662': 'OTHERS',
#  'Q29486646': 'OTHERS',
#  'Q29505273': 'OTHERS',
#  'Q29505250': 'OTHERS',
#  'Q29505244': 'OTHERS',
#  'Q29505222': 'OTHERS',
#  'Q29505220': 'OTHERS',
#  'Q48816231': 'ORG',
#  'Q23746441': 'ORG',
#  'Q7622587': 'ORG',
#  'Q6156516': 'ORG',
#  'Q1889100': 'ORG',
#  'Q1817686': 'ORG',
#  'Q1760438': 'ORG',
#  'Q1733433': 'ORG',
#  'Q5041723': 'ORG',
#  'Q4475847': 'ORG',
#  'Q1587312': 'ORG',
#  'Q1584459': 'ORG',
#  'Q1252428': 'ORG',
#  'Q1165215': 'ORG',
#  'Q2323376': 'ORG',
#  'Q2212977': 'ORG',
#  'Q3181122': 'ORG',
#  'Q1465437': 'ORG',
#  'Q1420239': 'ORG',
#  'Q1420038': 'ORG',
#  'Q1364550': 'ORG',
#  'Q632891': 'ORG',
#  'Q630226': 'ORG',
#  'Q924318': 'ORG',
#  'Q849751': 'ORG',
#  'Q1146856': 'ORG',
#  'Q1146435': 'ORG',
#  'Q1144673': 'ORG',
#  'Q1143226': 'ORG',
#  'Q1138374': 'ORG',
#  'Q1126179': 'ORG',
#  'Q1474624': 'ORG',
#  'Q432475': 'ORG',
#  'Q427677': 'ORG',
#  'Q414221': 'ORG',
#  'Q392774': 'ORG',
#  'Q746153': 'ORG',
#  'Q737835': 'ORG',
#  'Q995265': 'ORG',
#  'Q958886': 'ORG',
#  'Q309350': 'ORG',
#  'Q274486': 'ORG',
#  'Q219564': 'ORG',
#  'Q216273': 'ORG',
#  'Q204457': 'ORG',
#  'Q196559': 'ORG',
#  'Q194445': 'ORG',
#  'Q178972': 'ORG',
#  'Q174158': 'ORG',
#  'Q170027': 'ORG',
#  'Q161562': 'ORG',
#  'Q49212': 'ORG',
#  'Q49205': 'ORG',
#  'Q734774': 'ORG',
#  'Q534643': 'ORG',
#  'Q2495922': 'ORG',
#  'Q1138080': 'ORG',
#  'Q492318': 'ORG',
#  'Q149990': 'ORG',
#  'Q32219300': 'ORG',
#  'Q32000604': 'ORG',
#  'Q31943212': 'ORG',
#  'Q26761476': 'ORG',
#  'Q23717587': 'ORG',
#  'Q23659699': 'ORG',
#  'Q22584861': 'ORG',
#  'Q21847993': 'ORG',
#  'Q74454254': 'ORG',
#  'Q99998594': 'ORG',
#  'Q99998277': 'ORG',
#  'Q99998245': 'ORG',
#  'Q99996454': 'ORG',
#  'Q99996443': 'ORG',
#  'Q106235153': 'ORG',
#  'Q106235071': 'ORG',
#  'Q106235066': 'ORG',
#  'Q106235065': 'ORG',
#  'Q106235061': 'ORG',
#  'Q106235060': 'ORG',
#  'Q106235059': 'ORG',
#  'Q106235055': 'ORG',
#  'Q106235054': 'ORG',
#  'Q106235052': 'ORG',
#  'Q106235051': 'ORG',
#  'Q106235050': 'ORG',
#  'Q106235049': 'ORG',
#  'Q106235047': 'ORG',
#  'Q106235046': 'ORG',
#  'Q106235043': 'ORG',
#  'Q106235042': 'ORG',
#  'Q106235041': 'ORG',
#  'Q106235040': 'ORG',
#  'Q106235039': 'ORG',
#  'Q106235038': 'ORG',
#  'Q106235037': 'ORG',
#  'Q106235036': 'ORG',
#  'Q106235034': 'ORG',
#  'Q106235032': 'ORG',
#  'Q106235031': 'ORG',
#  'Q106235030': 'ORG',
#  'Q99950052': 'ORG',
#  'Q99950050': 'ORG',
#  'Q99950046': 'ORG',
#  'Q99950044': 'ORG',
#  'Q106202705': 'ORG',
#  'Q106202658': 'ORG',
#  'Q106202122': 'ORG',
#  'Q106201949': 'ORG',
#  'Q106203543': 'ORG',
#  'Q106203413': 'ORG',
#  'Q106203411': 'ORG',
#  'Q106203194': 'ORG',
#  'Q106203178': 'ORG',
#  'Q106203158': 'ORG',
#  'Q106211293': 'ORG',
#  'Q106210513': 'ORG',
#  'Q106201896': 'ORG',
#  'Q106201705': 'ORG',
#  'Q106201649': 'ORG',
#  'Q106201000': 'ORG',
#  'Q99593653': 'ORG',
#  'Q99593618': 'ORG',
#  'Q97686762': 'ORG',
#  'Q106200786': 'ORG',
#  'Q106200608': 'ORG',
#  'Q106200601': 'ORG',
#  'Q60556910': 'ORG',
#  'Q60556606': 'ORG',
#  'Q60190829': 'ORG',
#  'Q61988006': 'ORG',
#  'Q6715569': 'OTHERS',
#  'Q19300810': 'OTHERS',
#  'Q390070': 'OTHERS',
#  'Q1086237': 'OTHERS',
#  'Q102279': 'OTHERS',
#  'Q19398984': 'OTHERS',
#  'Q7571807': 'OTHERS',
#  'Q2654556': 'OTHERS',
#  'Q2595056': 'OTHERS',
#  'Q2495365': 'OTHERS',
#  'Q2299493': 'OTHERS',
#  'Q2207366': 'OTHERS',
#  'Q2207354': 'OTHERS',
#  'Q1126601': 'OTHERS',
#  'Q878801': 'OTHERS',
#  'Q753378': 'OTHERS',
#  'Q735198': 'OTHERS',
#  'Q679770': 'OTHERS',
#  'Q412301': 'OTHERS',
#  'Q2207255': 'OTHERS',
#  'Q2207238': 'OTHERS',
#  'Q1583620': 'OTHERS',
#  'Q1565536': 'OTHERS',
#  'Q3314902': 'OTHERS',
#  'Q1542168': 'OTHERS',
#  'Q19891926': 'OTHERS',
#  'Q46074691': 'OTHERS',
#  'Q43541058': 'OTHERS',
#  'Q2679797': 'OTHERS',
#  'Q2529074': 'OTHERS',
#  'Q1471287': 'OTHERS',
#  'Q495094': 'OTHERS',
#  'Q405497': 'OTHERS',
#  'Q1065959': 'OTHERS',
#  'Q5025884': 'OTHERS',
#  'Q797941': 'OTHERS',
#  'Q537261': 'OTHERS',
#  'Q1603162': 'OTHERS',
#  'Q28163962': 'ORG',
#  'Q487520': 'ORG',
#  'Q239539': 'ORG',
#  'Q903822': 'ORG',
#  'Q332739': 'ORG',
#  'Q275441': 'ORG',
#  'Q212101': 'ORG',
#  'Q130765': 'ORG',
#  'Q29552': 'ORG',
#  'Q29468': 'ORG',
#  'Q21892': 'ORG',
#  'Q19079': 'ORG',
#  'Q849580': 'ORG',
#  'Q663535': 'ORG',
#  'Q23060': 'ORG',
#  'Q824489': 'OTHERS',
#  'Q34754': 'OTHERS',
#  'Q1049': 'LOC',
#  'Q1045': 'LOC',
#  'Q1044': 'LOC',
#  'Q1042': 'LOC',
#  'Q1041': 'LOC',
#  'Q1037': 'OTHERS',
#  'Q1036': 'OTHERS',
#  'Q1032': 'OTHERS',
#  'Q1030': 'OTHERS',
#  'Q1029': 'OTHERS',
#  'Q1027': 'OTHERS',
#  'Q1020': 'OTHERS',
#  'Q3880173': 'OTHERS',
#  'Q3688549': 'OTHERS',
#  'Q1168662': 'OTHERS',
#  'Q604603': 'OTHERS',
#  'Q12816': 'LOC',
#  'Q12804': 'LOC',
#  'Q12792': 'LOC',
#  'Q12789': 'LOC',
#  'Q12772': 'LOC',
#  'Q12770': 'LOC',
#  'Q12745': 'LOC',
#  'Q12740': 'LOC',
#  'Q12689': 'LOC',
#  'Q12679': 'LOC',
#  'Q12675': 'LOC',
#  'Q12661': 'LOC',
#  'Q12652': 'LOC',
#  'Q12642': 'LOC',
#  'Q12631': 'LOC',
#  'Q12620': 'LOC',
#  'Q12594': 'LOC',
#  'Q12589': 'LOC',
#  'Q12576': 'LOC',
#  ...}

# %%
extended_WD_types("Q23397")
# Out:
# ['Q23397',
#  'Q271669',
#  'Q337567',
#  'Q2479431',
#  'Q3391202',
#  'Q618123',
#  'Q2221906',
#  'Q12766313',
#  'Q15324',
#  'Q863944',
#  'Q1389310',
#  'Q52105',
#  'Q82794',
#  'Q20719696',
#  'Q27096213',
#  'Q2507626',
#  'Q4835091',
#  'Q35145263',
#  'Q43619',
#  'Q26713767',
#  'Q15989253',
#  'Q223557',
#  'Q123349660',
#  'Q16686022',
#  'Q27096220',
#  'Q115385384',
#  'Q2920644',
#  'Q4406616',
#  'Q53617407',
#  'Q35120',
#  'Q1970309',
#  'Q23956024',
#  'Q25404640',
#  'Q124711484',
#  'Q488383',
#  'Q58778',
#  'Q58415929',
#  'Q53617489',
#  'Q124711467',
#  'Q99527517',
#  'Q103940464']

# %%
# Initialize an empty dictionary for ext_WD_query_type
ext_WD_query_type = {}

# Iterate over WD_query_type.keys() with a tqdm progress bar
for entity_name, entity_type in tqdm(WD_query_type.items(), desc="Processing Superclasses", unit="entity"):
    #print(f"{el}: #superclasses {len(extended_WD_types(el))}")
    ext_WD_query_type[entity_name] = extended_WD_types(entity_type)

with open('HTR3_ext_WD_query_type.json', 'w') as json_file:
    json.dump(ext_WD_query_type, json_file, indent=4)


# Display the resulting dictionary
ext_WD_query_type
# Out:
# Processing Superclasses:   0%|          | 35/47171 [00:09<3:07:55,  4.18entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:   0%|          | 68/47171 [00:26<5:59:43,  2.18entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:   7%|▋         | 3386/47171 [09:36<3:00:17,  4.05entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:   8%|▊         | 3984/47171 [11:17<1:11:21, 10.09entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:   8%|▊         | 3997/47171 [11:27<2:55:18,  4.10entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  15%|█▍        | 7032/47171 [19:35<3:24:48,  3.27entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  15%|█▍        | 7054/47171 [19:46<3:15:28,  3.42entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  15%|█▌        | 7083/47171 [19:56<1:27:41,  7.62entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  15%|█▌        | 7117/47171 [20:08<3:28:23,  3.20entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Processing Superclasses:  15%|█▌        | 7118/47171 [20:19<39:23:14,  3.54s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  15%|█▌        | 7120/47171 [20:25<33:57:31,  3.05s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  22%|██▏       | 10418/47171 [29:07<4:22:15,  2.34entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  22%|██▏       | 10477/47171 [29:29<1:23:11,  7.35entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  22%|██▏       | 10509/47171 [29:40<1:04:54,  9.41entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  22%|██▏       | 10559/47171 [29:51<1:41:09,  6.03entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  29%|██▉       | 13882/47171 [41:13<1:02:09,  8.93entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  30%|██▉       | 13922/47171 [41:25<1:36:00,  5.77entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  35%|███▌      | 16583/47171 [49:32<56:12,  9.07entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  41%|████▏     | 19558/47171 [59:19<2:17:16,  3.35entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  41%|████▏     | 19562/47171 [59:25<6:22:17,  1.20entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  48%|████▊     | 22835/47171 [1:09:39<54:07,  7.49entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  48%|████▊     | 22846/47171 [1:09:46<2:06:39,  3.20entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  55%|█████▍    | 25812/47171 [1:19:36<1:08:08,  5.22entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  55%|█████▍    | 25813/47171 [1:19:42<10:13:55,  1.72s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  55%|█████▍    | 25825/47171 [1:19:48<57:07,  6.23entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  61%|██████    | 28723/47171 [1:29:36<1:07:35,  4.55entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  64%|██████▎   | 29988/47171 [1:39:39<3:06:51,  1.53entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  64%|██████▎   | 29992/47171 [1:39:45<4:33:33,  1.05entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  66%|██████▌   | 31220/47171 [1:49:07<3:56:06,  1.13entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  74%|███████▎  | 34734/47171 [2:19:18<1:13:27,  2.82entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  76%|███████▌  | 35966/47171 [2:29:15<1:32:32,  2.02entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  76%|███████▋  | 35978/47171 [2:29:28<1:23:19,  2.24entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  76%|███████▋  | 35983/47171 [2:29:35<2:30:31,  1.24entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Processing Superclasses:  76%|███████▋  | 35990/47171 [2:29:49<2:32:07,  1.23entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  76%|███████▋  | 35994/47171 [2:29:56<3:36:26,  1.16s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38675/47171 [2:39:04<34:54,  4.06entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38676/47171 [2:39:10<3:58:28,  1.68s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 3/3)
# Processing Superclasses:  82%|████████▏ | 38677/47171 [2:39:26<13:17:19,  5.63s/entity]
# Failed to retrieve data after multiple attempts.
# Processing Superclasses:  82%|████████▏ | 38684/47171 [2:39:28<2:02:44,  1.15entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38695/47171 [2:39:36<41:45,  3.38entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38696/47171 [2:39:42<4:33:53,  1.94s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38697/47171 [2:39:47<7:09:38,  3.04s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 3/3)
# Processing Superclasses:  82%|████████▏ | 38698/47171 [2:40:03<16:01:10,  6.81s/entity]
# Failed to retrieve data after multiple attempts.
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38699/47171 [2:40:09<15:04:11,  6.40s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38720/47171 [2:40:19<33:48,  4.17entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Processing Superclasses:  82%|████████▏ | 38898/47171 [2:41:10<1:04:46,  2.13entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38899/47171 [2:41:16<4:59:27,  2.17s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38906/47171 [2:41:24<1:21:25,  1.69entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38911/47171 [2:41:30<1:33:13,  1.48entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  82%|████████▏ | 38914/47171 [2:41:36<2:40:02,  1.16s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  83%|████████▎ | 39031/47171 [2:42:00<22:11,  6.11entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  83%|████████▎ | 39117/47171 [2:42:19<12:37, 10.63entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  83%|████████▎ | 39121/47171 [2:42:26<1:51:42,  1.20entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41321/47171 [2:49:07<19:48,  4.92entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41322/47171 [2:49:13<2:35:40,  1.60s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41327/47171 [2:49:19<1:17:53,  1.25entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41334/47171 [2:49:27<45:51,  2.12entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41338/47171 [2:49:33<1:13:14,  1.33entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41342/47171 [2:49:39<1:21:37,  1.19entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41355/47171 [2:49:47<26:18,  3.68entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41366/47171 [2:49:56<25:26,  3.80entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41720/47171 [2:51:11<25:33,  3.55entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41722/47171 [2:51:16<2:01:40,  1.34s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  88%|████████▊ | 41725/47171 [2:51:23<2:10:05,  1.43s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▊ | 41847/47171 [2:51:51<31:42,  2.80entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▊ | 41849/47171 [2:51:57<2:14:24,  1.52s/entity]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▊ | 41863/47171 [2:52:06<17:25,  5.08entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▉ | 41900/47171 [2:52:21<23:13,  3.78entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  89%|████████▉ | 41926/47171 [2:52:34<19:17,  4.53entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  93%|█████████▎| 43841/47171 [2:59:06<20:05,  2.76entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Rate limit hit. Retrying in 5 seconds... (Attempt 2/3)
# Processing Superclasses:  93%|█████████▎| 43859/47171 [2:59:21<13:30,  4.08entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  93%|█████████▎| 43877/47171 [2:59:30<15:17,  3.59entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  99%|█████████▉| 46848/47171 [3:09:44<01:36,  3.35entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses:  99%|█████████▉| 46853/47171 [3:09:51<03:34,  1.48entity/s]
# Rate limit hit. Retrying in 5 seconds... (Attempt 1/3)
# Processing Superclasses: 100%|██████████| 47171/47171 [3:11:11<00:00,  4.11entity/s]
# {'Q64618013': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q64617600': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q56682821': ['Q87167',
#   'Q49848',
#   'Q18593264',
#   'Q110304307',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q386724',
#   'Q2342494',
#   'Q4502142',
#   'Q16686448',
#   'Q488383',
#   'Q2424752',
#   'Q838948',
#   'Q110910970',
#   'Q1554231',
#   'Q3523102',
#   'Q35120',
#   'Q17537576',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q56612179': ['Q87167',
#   'Q49848',
#   'Q18593264',
#   'Q110304307',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q386724',
#   'Q2342494',
#   'Q4502142',
#   'Q16686448',
#   'Q488383',
#   'Q2424752',
#   'Q838948',
#   'Q110910970',
#   'Q1554231',
#   'Q3523102',
#   'Q35120',
#   'Q17537576',
#   'Q31464082',
#   'Q53617489',
#   'Q103940464'],
#  'Q43221084': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q28890011': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q19818313': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941209': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941198': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941177': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941174': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941171': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941169': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941162': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941157': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941154': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q16941150': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q5856992': ['Q8362',
#   'Q93184',
#   'Q178659',
#   'Q3305213',
#   'Q116691808',
#   'Q8205328',
#   'Q110304307',
#   'Q478798',
#   'Q4502142',
#   'Q6575414',
#   'Q16686448',
#   'Q118870638',
#   'Q838948',
#   'Q110910970',
#   'Q111907565',
#   'Q223557',
#   'Q386724',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q488383',
#   'Q123410745',
#   'Q35120',
#   'Q15621286',
#   'Q53617489',
#   'Q246672',
#   'Q7048977',
#   'Q103940464'],
#  'Q62422071': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q60999791': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q105554399': ['Q7725634',
#   'Q47461344',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383',
#   'Q35120'],
#  'Q100250170': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q99701350': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q28096756': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q21198118': ['Q7725634',
#   'Q47461344',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383',
#   'Q35120'],
#  'Q20546376': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q43339738': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q11390403': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q10920066': ['Q11419619',
#   'Q207961',
#   'Q211548',
#   'Q937228',
#   'Q36161',
#   'Q123410745',
#   'Q7048977',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q35120',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q930933',
#   'Q16686448',
#   'Q488383'],
#  'Q7074635': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q5366046': ['Q11419619',
#   'Q207961',
#   'Q211548',
#   'Q937228',
#   'Q36161',
#   'Q123410745',
#   'Q7048977',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q35120',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q930933',
#   'Q16686448',
#   'Q488383'],
#  'Q5362166': ['Q11419619',
#   'Q207961',
#   'Q211548',
#   'Q937228',
#   'Q36161',
#   'Q123410745',
#   'Q7048977',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q35120',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q930933',
#   'Q16686448',
#   'Q488383'],
#  'Q5360937': ['Q193955',
#   'Q11396303',
#   'Q1261026',
#   'Q53731850',
#   'Q49848',
#   'Q732577',
#   'Q2424752',
#   'Q571',
#   'Q1836700',
#   'Q2342494',
#   'Q114055128',
#   'Q340169',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q115668308',
#   'Q1485500',
#   'Q8205328',
#   'Q488383',
#   'Q1784021',
#   'Q16686448',
#   'Q12774177',
#   'Q35120',
#   'Q28877',
#   'Q337060',
#   'Q836950',
#   'Q838948',
#   'Q1232589',
#   'Q223557',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q2897903',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q31464082',
#   'Q53617489',
#   'Q35825432',
#   'Q58415929',
#   'Q103940464'],
#  'Q4145038': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q15905509': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q11886645': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q1376060': ['Q193955',
#   'Q11396303',
#   'Q1261026',
#   'Q53731850',
#   'Q49848',
#   'Q732577',
#   'Q2424752',
#   'Q571',
#   'Q1836700',
#   'Q2342494',
#   'Q114055128',
#   'Q340169',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q115668308',
#   'Q1485500',
#   'Q8205328',
#   'Q488383',
#   'Q1784021',
#   'Q16686448',
#   'Q12774177',
#   'Q35120',
#   'Q28877',
#   'Q337060',
#   'Q836950',
#   'Q838948',
#   'Q1232589',
#   'Q223557',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q2897903',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q31464082',
#   'Q53617489',
#   'Q35825432',
#   'Q58415929',
#   'Q103940464'],
#  'Q1213085': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q1164830': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q3761739': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q3289889': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q1042011': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q951587': ['Q193955',
#   'Q11396303',
#   'Q1261026',
#   'Q53731850',
#   'Q49848',
#   'Q732577',
#   'Q2424752',
#   'Q571',
#   'Q1836700',
#   'Q2342494',
#   'Q114055128',
#   'Q340169',
#   'Q286583',
#   'Q15621286',
#   'Q37866906',
#   'Q115668308',
#   'Q1485500',
#   'Q8205328',
#   'Q488383',
#   'Q1784021',
#   'Q16686448',
#   'Q12774177',
#   'Q35120',
#   'Q28877',
#   'Q337060',
#   'Q836950',
#   'Q838948',
#   'Q1232589',
#   'Q223557',
#   'Q386724',
#   'Q1554231',
#   'Q3523102',
#   'Q17538423',
#   'Q2897903',
#   'Q4406616',
#   'Q53617407',
#   'Q17537576',
#   'Q31464082',
#   'Q53617489',
#   'Q35825432',
#   'Q58415929',
#   'Q103940464'],
#  'Q634778': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q45192': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q2657795': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q2603313': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q1966961': ['Q7725634',
#   'Q47461344',
#   'Q15621286',
#   'Q386724',
#   'Q16686448',
#   'Q488383',
#   'Q35120'],
#  'Q1886719': ['Q8261',
#   'Q3328821',
#   'Q87482979',
#   'Q1318295',
#   'Q7725634',
#   'Q838948',
#   'Q17537576',
#   'Q11028',
#   'Q47461344',
#   'Q7048977',
#   'Q15621286',
#   'Q35120',
#   'Q386724',
#   'Q16686448',
#   'Q488383'],
#  'Q732740': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q558904': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q376895': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q204656': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q202040': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q200759': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q200753': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q189097': ['Q8142',
#   'Q1368',
#   'Q47574',
#   'Q11105360',
#   'Q65240001',
#   'Q1643989',
#   'Q1659862',
#   'Q7598359',
#   'Q181175',
#   'Q39875001',
#   'Q71550118',
#   'Q286583',
#   'Q123691918',
#   'Q107715',
#   'Q16686448',
#   'Q190122',
#   'Q28877',
#   'Q367293',
#   'Q1207505',
#   'Q309314',
#   'Q488383',
#   'Q2897903',
#   'Q4373292',
#   'Q15809678',
#   'Q937228',
#   'Q2912517',
#   'Q16889133',
#   'Q35120',
#   'Q7048977',
#   'Q2424752',
#   'Q58415929',
#   'Q246672',
#   'Q38885242',
#   'Q5127848',
#   'Q99527517'],
#  'Q98455775': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q97999616': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q33129408': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q33129398': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q33129395': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q28153817': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q21073913': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q19637802': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q19567333': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q18214785': ['Q63100559',
#   'Q2547976',
#   'Q3306242',
#   'Q8092',
#   'Q1277161',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q1190554',
#   'Q1656682',
#   'Q28314507',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q67518978',
#   'Q1132455',
#   'Q5422048',
#   'Q8065',
#   'Q1322005',
#   'Q26907166',
#   'Q3839081',
#   'Q86923152',
#   'Q122355536',
#   'Q2615451',
#   'Q12142910',
#   'Q2141565',
#   'Q483247',
#   'Q104493',
#   'Q58415929',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q488383',
#   'Q18603648',
#   'Q31464082',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q35120',
#   'Q3505845',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q1207505',
#   'Q2995644',
#   'Q128602303',
#   'Q937228',
#   'Q1293220',
#   'Q111752858',
#   'Q7048977',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q18214731': ['Q63100595',
#   'Q2547976',
#   'Q3306242',
#   'Q8092',
#   'Q1277161',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q1190554',
#   'Q1656682',
#   'Q28314507',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q67518978',
#   'Q1132455',
#   'Q5422048',
#   'Q8065',
#   'Q1322005',
#   'Q26907166',
#   'Q3839081',
#   'Q86923152',
#   'Q122355536',
#   'Q2615451',
#   'Q12142910',
#   'Q2141565',
#   'Q483247',
#   'Q104493',
#   'Q58415929',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q488383',
#   'Q18603648',
#   'Q31464082',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q35120',
#   'Q3505845',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q1207505',
#   'Q2995644',
#   'Q128602303',
#   'Q937228',
#   'Q1293220',
#   'Q111752858',
#   'Q7048977',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q10835425': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q7145355': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q5947103': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3517882': ['Q3157041',
#   'Q1277161',
#   'Q2547976',
#   'Q3306242',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8092',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1656682',
#   'Q28314507',
#   'Q1322005',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q104493',
#   'Q8065',
#   'Q26907166',
#   'Q3839081',
#   'Q122355536',
#   'Q2615451',
#   'Q21170479',
#   'Q30241068',
#   'Q12142910',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q937228',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q7048977',
#   'Q2995644',
#   'Q128602303',
#   'Q1293220',
#   'Q111752858',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q3517879': ['Q3157041',
#   'Q1277161',
#   'Q2547976',
#   'Q3306242',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8092',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1656682',
#   'Q28314507',
#   'Q1322005',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q104493',
#   'Q8065',
#   'Q26907166',
#   'Q3839081',
#   'Q122355536',
#   'Q2615451',
#   'Q21170479',
#   'Q30241068',
#   'Q12142910',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q937228',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q7048977',
#   'Q2995644',
#   'Q128602303',
#   'Q1293220',
#   'Q111752858',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q3517875': ['Q3157041',
#   'Q1277161',
#   'Q2547976',
#   'Q3306242',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8092',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1656682',
#   'Q28314507',
#   'Q1322005',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q104493',
#   'Q8065',
#   'Q26907166',
#   'Q3839081',
#   'Q122355536',
#   'Q2615451',
#   'Q21170479',
#   'Q30241068',
#   'Q12142910',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q937228',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q7048977',
#   'Q2995644',
#   'Q128602303',
#   'Q1293220',
#   'Q111752858',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q3517869': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3358417': ['Q63100584',
#   'Q2547976',
#   'Q3306242',
#   'Q8092',
#   'Q1277161',
#   'Q15275719',
#   'Q25999041',
#   'Q34439356',
#   'Q63100492',
#   'Q79602',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q1190554',
#   'Q1656682',
#   'Q28314507',
#   'Q8094',
#   'Q6823473',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q67518978',
#   'Q1132455',
#   'Q5422048',
#   'Q8065',
#   'Q1322005',
#   'Q26907166',
#   'Q3839081',
#   'Q86923152',
#   'Q122355536',
#   'Q2615451',
#   'Q12142910',
#   'Q2141565',
#   'Q483247',
#   'Q104493',
#   'Q58415929',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q205879',
#   'Q4698318',
#   'Q1689296',
#   'Q1920219',
#   'Q1931388',
#   'Q79782',
#   'Q488383',
#   'Q18603648',
#   'Q31464082',
#   'Q2956685',
#   'Q16934857',
#   'Q1150070',
#   'Q17320256',
#   'Q35120',
#   'Q3505845',
#   'Q1121708',
#   'Q621184',
#   'Q2574811',
#   'Q1207505',
#   'Q2995644',
#   'Q128602303',
#   'Q937228',
#   'Q1293220',
#   'Q111752858',
#   'Q7048977',
#   'Q3249551',
#   'Q12559209',
#   'Q20937557',
#   'Q4516355',
#   'Q11348',
#   'Q133250',
#   'Q16889133',
#   'Q130901',
#   'Q5127848',
#   'Q203066',
#   'Q99527517',
#   'Q36161',
#   'Q107223533',
#   'Q217594',
#   'Q864377',
#   'Q5469988',
#   'Q930933',
#   'Q246672',
#   'Q748349',
#   'Q4393498',
#   'Q4833865',
#   'Q16686448'],
#  'Q3358402': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3306096': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3249186': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3089803': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
#   'Q732722',
#   'Q741507',
#   'Q3433179',
#   'Q16332653',
#   'Q8094',
#   'Q2615451',
#   'Q12142910',
#   'Q1190554',
#   'Q1132455',
#   'Q5422048',
#   'Q1322005',
#   'Q2141565',
#   'Q86923152',
#   'Q67518978',
#   'Q483247',
#   'Q205879',
#   'Q4698318',
#   'Q104493',
#   'Q79782',
#   'Q1150070',
#   'Q17320256',
#   'Q21170479',
#   'Q30241068',
#   'Q813912',
#   'Q58415929',
#   'Q18603648',
#   'Q31464082',
#   'Q3505845',
#   'Q1293220',
#   'Q111752858',
#   'Q1207505',
#   'Q35120',
#   'Q488383',
#   'Q937228',
#   'Q3249551',
#   'Q7048977',
#   'Q20937557',
#   'Q16889133',
#   'Q5127848',
#   'Q99527517'],
#  'Q3089461': ['Q8092',
#   'Q79602',
#   'Q1277161',
#   'Q81054',
#   'Q209190',
# ...
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12804': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12792': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12789': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12772': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12770': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12745': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12740': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12689': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12679': ['Q192611',
#   'Q56061',
#   'Q1048835',
#   'Q15642541',
#   'Q16562419',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q58415929',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q124711467',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q12675': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12661': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12652': ['Q192611',
#   'Q56061',
#   'Q1048835',
#   'Q15642541',
#   'Q16562419',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q43229',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q211606',
#   'Q35120',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58778',
#   'Q16334298',
#   'Q58415929',
#   'Q53617489',
#   'Q24229398',
#   'Q131085629',
#   'Q124711467',
#   'Q99527517',
#   'Q61961344',
#   'Q103940464',
#   'Q98119401'],
#  'Q12642': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12631': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12620': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12594': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12589': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  'Q12576': ['Q6465',
#   'Q192611',
#   'Q583865',
#   'Q643589',
#   'Q13220204',
#   'Q13221722',
#   'Q41773366',
#   'Q56061',
#   'Q1048835',
#   'Q192498',
#   'Q837766',
#   'Q1799794',
#   'Q15042037',
#   'Q15642541',
#   'Q16562419',
#   'Q12076836',
#   'Q155076',
#   'Q167037',
#   'Q6501447',
#   'Q3778211',
#   'Q783794',
#   'Q7188',
#   'Q43229',
#   'Q2221906',
#   'Q4835091',
#   'Q27096235',
#   'Q1063239',
#   'Q3455524',
#   'Q895526',
#   'Q854457',
#   'Q1639378',
#   'Q16334295',
#   'Q106559804',
#   'Q106668099',
#   'Q21980538',
#   'Q7210356',
#   'Q27096213',
#   'Q18810687',
#   'Q82794',
#   'Q16686448',
#   'Q618123',
#   'Q26713767',
#   'Q58778',
#   'Q16334298',
#   'Q488383',
#   'Q178706',
#   'Q123349660',
#   'Q24229398',
#   'Q131085629',
#   'Q99527517',
#   'Q211606',
#   'Q35120',
#   'Q61961344',
#   'Q53617489',
#   'Q23956024',
#   'Q25404640',
#   'Q124711484',
#   'Q53617407',
#   'Q6671777',
#   'Q58415929',
#   'Q103940464',
#   'Q98119401',
#   'Q124711467'],
#  ...}

# %%
from tqdm import tqdm


tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR3/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)



cea_values_dict = dict(zip(df_cea[3], df_cea["key_col"].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.values()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {}
for k,v in cea_values_dict.items():
    try:
        combined_dict[k] = cta_values_dict[v]
    except:
        pass


WD_query_type = {}

# Wrap the values of the dictionary in tqdm for a progress bar
for key, value in tqdm(combined_dict.items(), desc="Processing items"):
    key = key.split('/')[-1]
    result = None
    item_id = value.split('/')[-1]

    WD_query_type[key] = item_id  # Store the result (or None if no non-empty list found)

with open('HTR3_WD_query_type.json', 'w') as json_file:
    json.dump(WD_query_type, json_file, indent=4)
# Out:
# Processing items: 100%|██████████| 47171/47171 [00:00<00:00, 312960.92it/s]

# %%
def make_json_serializable(obj):
    """
    Recursively converts non-serializable objects in the dictionary
    to JSON-serializable formats.
    """
    if isinstance(obj, set):
        return list(obj)  # Convert sets to lists
    elif isinstance(obj, dict):
        return {k: make_json_serializable(v) for k, v in obj.items()}  # Recurse for nested dictionaries
    elif isinstance(obj, list):
        return [make_json_serializable(i) for i in obj]  # Recurse for lists
    else:
        return obj  # Return the object if it's already serializable

# Convert subsample to a JSON-serializable format
serializable_subsample = make_json_serializable(ext_WD_query_type)

# %%
with open('ext_WD_query_type.json', 'w') as json_file:
    json.dump(serializable_subsample, json_file, indent=4)

# %% [markdown]
# ## NER type vs NER type

# %%
json_file_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/_HTR2/HTR2_NER_query_type.json"

with open(json_file_path, "r") as file:
    HTR2_type = json.load(file)


tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cta.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))

cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
HTR2_id_to_name = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    HTR2_id_to_name.update(local_key_to_cell)
# Out:
# Processing tables:   0%|          | 0/2692 [00:00<?, ?it/s]2025-01-18 10:34:12,914 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00CU42PU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,917 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00CYT0VB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,921 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00DZN9U3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,925 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00EDPHR0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,930 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00F4DDB8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,935 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00FMZR04.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,941 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GGKUQD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,944 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GNBCGP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,946 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00GOZ03E.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,950 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00HPZYRV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,954 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00JE18BI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,962 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00K4PJEK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,964 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00KWWZMZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,966 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00L77STZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,969 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LFR1E5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,971 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LGNCH3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,976 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00LS08FM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,978 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00MIIBFM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,980 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00MK33P9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,982 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00NSYDVX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,984 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00PGPISM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,988 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00QTPROV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,991 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00R2ATEA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,994 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00R7H94P.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,995 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00RCO58K.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:12,997 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00S6UHNA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,000 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SICZG9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,002 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SNTAT7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,008 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SUXIX5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,012 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00SWQK0C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   1%|          | 30/2692 [00:00<00:08, 298.70it/s]2025-01-18 10:34:13,016 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00TUX8XW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,019 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00U3XK6Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,022 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00VBFQFM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,025 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00VRSGHB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,029 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00WWU6C1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,032 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00X3HWSL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,034 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00X5RZSX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,039 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YA2Y7C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,043 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YK6JKU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,046 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00YVFD97.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,048 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00Z16W5U.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,051 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._00ZCYS1R.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,053 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A0AS275.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,058 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A0XQ1B1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,061 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A2OYVSJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,063 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A2WQW7B.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,065 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A3X0RVB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,068 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A40SP59.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,070 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A47VEYU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,073 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A49Y1OZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,075 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A5XRYWU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,079 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A6SD2NW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,081 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A79T5C3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,084 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A7O05AT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,087 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A82DDWZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,090 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A8CQRPP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,094 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A8YOSGJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,097 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0A957H2A.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,100 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AA6VXI0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,102 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AAAXONZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,106 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ABVZ7WS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,109 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AC7LR6S.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,112 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ADLUR97.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,115 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ADP4J7T.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   2%|▏         | 64/2692 [00:00<00:08, 317.77it/s]2025-01-18 10:34:13,119 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AE5UUR4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,122 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AEBQS4Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,125 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFMSPIX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,130 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFSK7PV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,133 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AFV61HL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,136 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGFL0LE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,138 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGL72LH.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,141 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AGXEWOY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,144 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AI297WG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,147 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AI6ZW9E.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,150 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AKRZY29.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,152 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ALSPPLR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,156 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AM28GPA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,159 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMA8HF3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,163 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMKG9SX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,166 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AMPIB6Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,169 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AN2OB8N.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,172 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AN589PA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,175 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0APS6Q33.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,179 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0APW2YH4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,182 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQCSHWE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,185 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQG4N6O.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,187 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AQV1YV2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,191 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASCCQQM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,195 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASWF8TB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,199 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0ASZDQYD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,201 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AULRJGX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,204 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AUQDLS2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,209 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AUXAQPV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,212 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AWUAT0K.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,215 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AWZR9TN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,219 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AX5SV4Q.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   4%|▎         | 96/2692 [00:00<00:08, 312.58it/s]2025-01-18 10:34:13,224 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AX7B6Z1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,227 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AXKNG2W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,230 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AXX6WNU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,232 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AY17XJZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,236 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AY9DYOB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,239 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AYKMIEM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,244 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AYNO7JO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,247 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AZ6T10W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,250 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0AZ9UQJQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,252 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B1QKI5W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,255 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B5RKA93.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,260 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B6YGAWH.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,262 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B8IRSSE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,264 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B8THYJX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,266 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0B9WJ1FD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,268 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BAJKOQO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,271 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BANNY8Z.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,276 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BARW1G0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,279 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BAWNWTP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,281 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BB4NJY1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,284 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BB5E6V7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,286 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BBBRYCD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,290 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BC2M2VE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,293 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BCGHJ96.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,298 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BEFRNL7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,301 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BEMPYG9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,303 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHG6DQR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,306 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHHXTT1.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,309 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BHKN3H3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,315 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BKRY93H.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,318 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BMFKR9L.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,320 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BMJ7L65.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   5%|▍         | 128/2692 [00:00<00:08, 314.15it/s]2025-01-18 10:34:13,328 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BN85228.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,331 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BNO82FL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,333 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BNZO6S6.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,335 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BPELMAE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,337 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQ46XMT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,341 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQKJMN4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,345 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQLMQY3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,348 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQZ5G1D.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,350 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BQZ6MDX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,352 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BRZ7UTV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,355 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BTG9ZEG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,359 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BTPAK79.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,361 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BW9VXHN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,363 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BWE6ZO8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,365 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BY5XPBI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,368 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYE13JU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,370 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYK1UP3.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,375 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYP7QK9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,378 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYXE5G9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,380 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BYY5ZHU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,383 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0BZO0CNX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,386 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C2MERDT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,388 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C52KOJJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,392 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C7O7AF4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,396 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0C8F8KJG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,399 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CA1IPHM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,402 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CBBWSUG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,406 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CD1MGB7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,409 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CDFFQWF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,412 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CESCQRE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,417 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CGHST2P.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,420 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CGLF62X.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,423 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CHHMIKE.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   6%|▌         | 161/2692 [00:00<00:07, 316.92it/s]2025-01-18 10:34:13,429 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CHKINC6.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,432 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CI4VFJ0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,435 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CI6HELZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,437 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CIBCE5G.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,442 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CJ0TTEJ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,445 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CJJ6CGV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,448 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CMDZ939.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,454 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CMPE48Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,463 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CN96B6I.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,473 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CNDHSHN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,483 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CNVNHPL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,506 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CP17WG5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,511 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CP74NKC.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,514 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CPYJI4V.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,517 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CQG4XP7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,520 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CRGR4RI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,525 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CRLOV5T.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,528 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CSQCPY5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,530 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CSY2BWG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,533 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CT6U7B9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,535 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CTDNYG5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,539 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CTQ4RR5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,543 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CVVLTV5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,546 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CWAVBMX.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,551 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CWT5QSM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,555 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0CYCQ67G.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,559 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D03T8F7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,562 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D0GKHTG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,566 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D0JRBCR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,570 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D1ZEOSI.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,573 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D3DVCVY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,606 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D4OERRB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:   7%|▋         | 193/2692 [00:00<00:10, 248.80it/s]2025-01-18 10:34:13,610 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D5COVM8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,619 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D7LE2GF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,632 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0D8TPEJV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,637 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DA1WOUR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,645 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DAQB4CK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,648 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DASDX1W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:13,653 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._0DBCG9M7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# ...
# 2025-01-18 10:34:16,163 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4E409TWU.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,166 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4E4VQ5Y0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,168 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ECV2TGR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,171 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EEB5JI0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,174 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EJEGCR0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,176 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4EKILPI5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,179 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F20WVE5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,181 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F2FZH4N.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,184 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4F5ZPLMK.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,186 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FCQJD2D.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,189 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FGQTBA2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,192 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FJIKSI8.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,194 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FMKABBS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,196 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FSUM1A0.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,198 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FWYU9N4.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,200 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4FYVEARM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,202 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4G64HVKW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,204 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GHEPS9W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,207 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GUJGVT2.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,210 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4GVQFQ1F.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,213 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4H2CLYND.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,216 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HA0JUWY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,218 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HA6M87Z.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,220 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HR2K0KQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,224 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HRM34WT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,227 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4HVVS5DC.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,229 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I3EOHAZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,231 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I5Z6FZT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:  34%|███▎      | 904/2692 [00:03<00:05, 323.53it/s]2025-01-18 10:34:16,235 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4I6TVFFO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,237 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IA0LVHR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,240 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ID21YJ5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,243 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IH24V21.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,245 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4II8ICTZ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,248 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4IMX1J20.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,250 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4J7QIUZD.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,251 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JJIT8HP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,255 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JKA8NCQ.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,259 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JKNJ1H7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,262 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JOMPIMS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,265 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JRY6P14.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,268 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JS4P1VA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,270 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4JVTNJTW.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,274 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4K40T4IL.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,277 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4K9C7F7U.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,279 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4KYYIHUS.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,281 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4KZ3TKWN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,284 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4L196DQA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,286 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4L2TORPT.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,289 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LCE1UOV.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,292 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LD9PGVF.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,296 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LKMOFLR.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,298 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LODO3MM.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,301 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LR8KT7C.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,303 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LUX91EA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,306 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4LZ3MLAP.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,309 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M0NMNAN.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,311 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M1OB5QY.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,313 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4M533Y9W.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,315 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MF6FUXO.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,319 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4ML8COI9.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,322 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MN56JAB.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,326 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MR41RNG.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,329 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MTAJ87Y.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,332 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4MVZ4KVA.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# 2025-01-18 10:34:16,334 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4N8OGCD7.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables:  35%|███▍      | 941/2692 [00:03<00:05, 334.44it/s]2025-01-18 10:34:16,338 - ERROR - Error processing C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/._4NFRQ6R5.csv: 'utf-8' codec can't decode byte 0xa2 in position 37: invalid start byte
# Processing tables: 100%|██████████| 2692/2692 [00:17<00:00, 151.13it/s]

# %%
def get_query(name, value):
    name = str(name).replace('"', ' ')
    if value is not None:
        # Soft filtering constraint
        query_dict = {
            "query": {
                "bool": {
                    "must": [
                        {"match": {"name": {"query": name, "boost": 2.0}}}
                    ],
                    "should": [
                        {"term": {"NERtype": value}}
                    ]
                }
            }
        }
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 50,
            'query': json.dumps(query_dict),  # Convert the query dictionary to a JSON string
            'sort': [
                '{"popularity": {"order": "desc"}}'
            ]
        }
    
    return params

url = 'https://lamapi.hel.sintef.cloud/entity/labels?token=lamapi_demo_2023'

# Define the headers
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

queries = []
key_to_cell_sample = {}
for id, name in tqdm(HTR2_id_to_name.items()):
    if id in HTR2_type:
        types_list = HTR2_type[id]

        ########################################################
        ##  modificare se types_list è una lista di tipi
        ########################################################
    
        query = get_query(name, types_list)

        queries.append((query, id, types_list))
        if len(queries) == 4000:
            break
# Out:
#  14%|█▍        | 4012/28030 [00:00<00:00, 60249.22it/s]

# %%
queries
# Out:
# [({'name': 'Royal Gwent Hospital Library',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Royal Gwent Hospital Library", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q50228603',
#   'ORG'),
#  ({'name': 'Rowland Isaac Library',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Rowland Isaac Library", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q50228595',
#   'ORG'),
#  ({'name': "Miners' Library, Ysbyty Ystrad Fawr",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Miners\' Library, Ysbyty Ystrad Fawr", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q50228591',
#   'ORG'),
#  ({'name': 'Singleton Hospital Library',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Singleton Hospital Library", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q50228487',
#   'ORG'),
#  ({'name': 'Liriomyza trifolii',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Liriomyza trifolii", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q4285103',
#   'OTHERS'),
#  ({'name': 'Enterobacter cloacae',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Enterobacter cloacae", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q4038096',
#   'OTHERS'),
#  ({'name': 'Colletotrichum gloeosporioides',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Colletotrichum gloeosporioides", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3683010',
#   'OTHERS'),
#  ({'name': 'Tomato yellow leaf curl virus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Tomato yellow leaf curl virus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3560937',
#   'OTHERS'),
#  ({'name': 'Potato yellow mosaic virus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Potato yellow mosaic virus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3560934',
#   'OTHERS'),
#  ({'name': 'Tomato mosaic virus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Tomato mosaic virus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3560928',
#   'OTHERS'),
#  ({'name': 'Potato virus M',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Potato virus M", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3560889',
#   'OTHERS'),
#  ({'name': 'Liriomyza huidobrensis',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Liriomyza huidobrensis", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3242346',
#   'OTHERS'),
#  ({'name': 'Clavibacter michiganensis',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Clavibacter michiganensis", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2978666',
#   'OTHERS'),
#  ({'name': 'Alfamovirus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Alfamovirus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2834777',
#   'OTHERS'),
#  ({'name': 'Leptoglossus phyllopus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Leptoglossus phyllopus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2742175',
#   'OTHERS'),
#  ({'name': 'Pseudomonas putida',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Pseudomonas putida", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2738168',
#   'OTHERS'),
#  ({'name': 'Alternaria solani',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Alternaria solani", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2715597',
#   'OTHERS'),
#  ({'name': 'Aphis gossypii',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Aphis gossypii", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2557995',
#   'OTHERS'),
#  ({'name': 'Cotesia congregata',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Cotesia congregata", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2415647',
#   'OTHERS'),
#  ({'name': 'Potato virus X',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Potato virus X", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2414314',
#   'OTHERS'),
#  ({'name': 'Azotobacter vinelandii',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Azotobacter vinelandii", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2157875',
#   'OTHERS'),
#  ({'name': 'Septoria lycopersici',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Septoria lycopersici", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2084213',
#   'OTHERS'),
#  ({'name': 'Mycovellosiella fulva',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Mycovellosiella fulva", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2084190',
#   'OTHERS'),
#  ({'name': 'Epitrix fasciata',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Epitrix fasciata", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2042787',
#   'OTHERS'),
#  ({'name': 'cucumber mosaic virus',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "cucumber mosaic virus", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1518692',
#   'OTHERS'),
#  ({'name': 'East Baton Rouge Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "East Baton Rouge Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q491949',
#   'LOC'),
#  ({'name': 'Terrebonne Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Terrebonne Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q387555',
#   'LOC'),
#  ({'name': 'DeSoto Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "DeSoto Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q383739',
#   'LOC'),
#  ({'name': 'Bienville Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Bienville Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q369211',
#   'LOC'),
#  ({'name': 'Acadia Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Acadia Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q337402',
#   'LOC'),
#  ({'name': 'Caldwell Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Caldwell Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q205715',
#   'LOC'),
#  ({'name': 'Caddo Parish',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Caddo Parish", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q177562',
#   'LOC'),
#  ({'name': 'Juzafinopĺ',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Juzafinop\\u013a", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515865',
#   'OTHERS'),
#  ({'name': 'Šyĺva',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "\\u0160y\\u013ava", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515839',
#   'OTHERS'),
#  ({'name': 'Cianiatniki',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Cianiatniki", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515716',
#   'OTHERS'),
#  ({'name': 'Sviebliaŭščyna',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Svieblia\\u016d\\u0161\\u010dyna", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515493',
#   'OTHERS'),
#  ({'name': 'Piova',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Piova", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515264',
#   'OTHERS'),
#  ({'name': 'Padaiachniški',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Padaiachni\\u0161ki", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20515182',
#   'OTHERS'),
#  ({'name': 'Celery',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Celery", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q5057824',
#   'OTHERS'),
#  ({'name': 'ZXing',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "ZXing", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q4859991',
#   'OTHERS'),
#  ({'name': 'HarfBuzz',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "HarfBuzz", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q4119352',
#   'OTHERS'),
#  ({'name': 'Underscore.js',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Underscore.js", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q4052375',
#   'OTHERS'),
#  ({'name': 'Oghma',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Oghma", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7886543',
#   'OTHERS'),
#  ({'name': 'Venere',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Venere", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q55001929',
#   'OTHERS'),
#  ({'name': 'Pallade',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Pallade", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q55001922',
#   'OTHERS'),
#  ({'name': 'demogorgon',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "demogorgon", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q5255934',
#   'OTHERS'),
#  ({'name': 'Orange Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Orange Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7099752',
#   'LOC'),
#  ({'name': 'Orange Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Orange Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7099749',
#   'LOC'),
#  ({'name': 'Orange Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Orange Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7099740',
#   'LOC'),
#  ({'name': 'Olive Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Olive Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7087220',
#   'LOC'),
#  ({'name': 'Olive Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Olive Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7087208',
#   'LOC'),
#  ({'name': 'Oil Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Oil Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7081367',
#   'LOC'),
#  ({'name': 'Ohio Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Ohio Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7081003',
#   'LOC'),
#  ({'name': 'Ohio Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Ohio Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7080993',
#   'LOC'),
#  ({'name': 'Ohio Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Ohio Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7080988',
#   'LOC'),
#  ({'name': 'Oak Grove Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Oak Grove Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7073528',
#   'LOC'),
#  ({'name': 'Nottingham Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Nottingham Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7063703',
#   'LOC'),
#  ({'name': 'Northwest Township',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Northwest Township", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7060252',
#   'LOC'),
#  ({'name': 'Andrea Chénier',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Andrea Ch\\u00e9nier", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q47001667',
#   'OTHERS'),
#  ({'name': 'I masnadieri',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "I masnadieri", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q52240024',
#   'OTHERS'),
#  ({'name': 'Orphée',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Orph\\u00e9e", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q51138260',
#   'OTHERS'),
#  ({'name': 'La traviata',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "La traviata", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q47467254',
#   'OTHERS'),
#  ({'name': 'La traviata',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "La traviata", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q47466815',
#   'OTHERS'),
#  ({'name': 'Jakob Lenz (2005-2006)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Jakob Lenz (2005-2006)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q57502953',
#   'OTHERS'),
#  ({'name': 'Agrippina (2016-2017)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Agrippina (2016-2017)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q57503963',
#   'OTHERS'),
#  ({'name': 'Shaun the Sheep, season 4',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Shaun the Sheep, season 4", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20427429',
#   'OTHERS'),
#  ({'name': 'Shaun the Sheep, season 3',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Shaun the Sheep, season 3", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20427427',
#   'OTHERS'),
#  ({'name': "America's Next Top Model, season 22",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "America\'s Next Top Model, season 22", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20312584',
#   'OTHERS'),
#  ({'name': 'Arthur, season 19',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Arthur, season 19", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20312123',
#   'OTHERS'),
#  ({'name': 'Bachelor in Paradise, season 2',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Bachelor in Paradise, season 2", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20311922',
#   'OTHERS'),
#  ({'name': 'Aqua Teen Hunger Force Forever',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Aqua Teen Hunger Force Forever", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20311549',
#   'OTHERS'),
#  ({'name': 'Supernatural, season 11',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Supernatural, season 11", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20047867',
#   'OTHERS'),
#  ({'name': 'Bang Kruai',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Bang Kruai", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q15199204',
#   'LOC'),
#  ({'name': 'Chum Het',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Chum Het", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q13025352',
#   'LOC'),
#  ({'name': 'Betong',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Betong", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2900126',
#   'OTHERS'),
#  ({'name': 'Surin',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Surin", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1207067',
#   'LOC'),
#  ({'name': 'Buri Ram',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Buri Ram", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1026460',
#   'LOC'),
#  ({'name': 'Roi Et',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Roi Et", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1017738',
#   'LOC'),
#  ({'name': 'Trang',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Trang", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1014322',
#   'LOC'),
#  ({'name': 'SFK Lyn',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "SFK Lyn", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7389964',
#   'ORG'),
#  ({'name': 'IF Frisk Asker',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "IF Frisk Asker", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q5970894',
#   'ORG'),
#  ({'name': 'Real Madrid',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Real Madrid", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q6362982',
#   'ORG'),
#  ({'name': 'SK Falk',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "SK Falk", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7390668',
#   'ORG'),
#  ({'name': 'Tharrawaddy Min Bell',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Tharrawaddy Min Bell", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q16063676',
#   'OTHERS'),
#  ({'name': 'Singu Min Bell',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Singu Min Bell", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q13064843',
#   'OTHERS'),
#  ({'name': 'Tsar Bell',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Tsar Bell", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q147875',
#   'OTHERS'),
#  ({'name': 'Klang Bell',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Klang Bell", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q16995723',
#   'OTHERS'),
#  ({'name': 'Siege ramparts i Kunratice (Prague)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Siege ramparts i Kunratice (Prague)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q37448746',
#   'OTHERS'),
#  ({'name': 'Small multivallate hillfort on Bury Down, 530m north-easu of South Park',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Small multivallate hillfort on Bury Down, 530m north-easu of South Park", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17643962',
#   'OTHERS'),
#  ({'name': 'Low Mire (milefortlet 20) 50m north of Heather Bank, part of the Roman frontier defhnces along the Cumbrian coast',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Low Mire (milefortlet 20) 50m north of Heather Bank, part of the Roman frontier defhnces along the Cumbrian coast", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17673565',
#   'OTHERS'),
#  ({'name': 'Castle Acre Castle, town defences nd Bailey Gbte',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Castle Acre Castle, town defences nd Bailey Gbte", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17677383',
#   'OTHERS'),
#  ({'name': 'arracks Platform, Presely View (w Side)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "arracks Platform, Presely View (w Side)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17743199',
#   'OTHERS'),
#  ({'name': 'Heavy Anti-aircraft gunsite, 170m south west of the juntion of Cedar Road and West Crescent',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Heavy Anti-aircraft gunsite, 170m south west of the juntion of Cedar Road and West Crescent", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17674012',
#   'OTHERS'),
#  ({'name': 'Heavy Anti-circraft gunsite on Sandpit Hill',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Heavy Anti-circraft gunsite on Sandpit Hill", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17663405',
#   'OTHERS'),
#  ({'name': "Caer Caradoc large multivallate hillfort, associated causeway and Caractacus' Cave on the summit of aer Caradoc Hill",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Caer Caradoc large multivallate hillfort, associated causeway and Caractacus\' Cave on the summit of aer Caradoc Hill", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17648762',
#   'OTHERS'),
#  ({'name': 'Redute Bakoven',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Redute Bakoven", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17614485',
#   'OTHERS'),
#  ({'name': 'atansää',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "atans\\u00e4\\u00e4", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q18681960',
#   'OTHERS'),
#  ({'name': 'Castle#Röthelstein in Hainburg',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Castle#R\\u00f6thelstein in Hainburg", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q37770137',
#   'OTHERS'),
#  ({'name': 'Flèche de Leehe',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Fl\\u00e8che de Leehe", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17614487',
#   'OTHERS'),
#  ({'name': 'Raikuup salpa-asema',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Raikuup salpa-asema", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q18661599',
#   'OTHERS'),
#  ({'name': 'Sea Brows (milefortlet 23), 500m south west of Bank End parw of the Roman frontier defences along the Cumbrian coast',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Sea Brows (milefortlet 23), 500m south west of Bank End parw of the Roman frontier defences along the Cumbrian coast", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17673577',
#   'OTHERS'),
#  ({'name': 'Stadthafen Rostock',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Stadthafen Rostock", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1746091',
#   'LOC'),
#  ({'name': 'Fokhaven (Rotterdam)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Fokhaven (Rotterdam)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1816897',
#   'LOC'),
#  ({'name': 'Vuosaari Harbour',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Vuosaari Harbour", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7943692',
#   'LOC'),
#  ({'name': 'Garlieston Harbour, Granary',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Garlieston Harbour, Granary", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q17793253',
#   'LOC'),
#  ({'name': 'UCAC3 216-17835',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "UCAC3 216-17835", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q90884615',
#   'OTHERS'),
#  ({'name': 'TYC 765-527-1',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "TYC 765-527-1", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q90884604',
#   'OTHERS'),
#  ({'name': 'UCAC3 189-22930',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "UCAC3 189-22930", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q90884599',
#   'OTHERS'),
#  ({'name': 'TYC 1190-66-1',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "TYC 1190-66-1", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q90884594',
#   'OTHERS'),
#  ({'name': 'UCAC3 188-363',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "UCAC3 188-363", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q90884555',
#   'OTHERS'),
#  ({'name': 'TYC 4835-25-1',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "TYC 4835-25-1", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93802224',
#   'OTHERS'),
#  ({'name': 'ROTSE1 J184706.07+434032.7',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "ROTSE1 J184706.07+434032.7", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93801701',
#   'OTHERS'),
#  ({'name': 'ROTSE1 J164703.37+094601.4',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "ROTSE1 J164703.37+094601.4", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93801698',
#   'OTHERS'),
#  ({'name': 'V* LR Boo',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* LR Boo", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93801573',
#   'OTHERS'),
#  ({'name': 'V* V379 Cas',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* V379 Cas", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93498132',
#   'OTHERS'),
#  ({'name': 'V* DL Cas',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* DL Cas", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93498090',
#   'OTHERS'),
#  ({'name': 'V* OZ Cas',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* OZ Cas", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93480589',
#   'OTHERS'),
#  ({'name': 'V* VW Cru',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* VW Cru", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93475019',
#   'OTHERS'),
#  ({'name': 'V* AE Vel',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* AE Vel", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93438628',
#   'OTHERS'),
#  ({'name': 'V* GU Nor',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* GU Nor", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q93744274',
#   'OTHERS'),
#  ({'name': 'V* CV Mon',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "V* CV Mon", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q91849618',
#   'OTHERS'),
#  ({'name': 'The Fung Brothers',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "The Fung Brothers", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q7735466',
#   'ORG'),
#  ({'name': 'SOFFet',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "SOFFet", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q11243836',
#   'ORG'),
#  ({'name': '0930',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "0930", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q11184874',
#   'ORG'),
#  ({'name': 'Gamble and Huff',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Gamble and Huff", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q15839121',
#   'ORG'),
#  ({'name': 'Lunam Docs',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Lunam Docs", "boost": 2.0}}}], "should": [{"term": {"NERtype": "ORG"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q16728600',
#   'ORG'),
#  ({'name': 'Baghdad District',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Baghdad District", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3710677',
#   'LOC'),
#  ({'name': 'Angor District',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Angor District", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3710624',
#   'LOC'),
#  ({'name': 'Kurgontepa District',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Kurgontepa District", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2671584',
#   'LOC'),
#  ({'name': 'Sariosiyo District',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Sariosiyo District", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q2639206',
#   'LOC'),
#  ({'name': 'Roker Park',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Roker Park", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q1541691',
#   'OTHERS'),
#  ({'name': 'Boleyn Ground',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Boleyn Ground", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q330731',
#   'OTHERS'),
#  ({'name': 'Charmilles Stadium',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Charmilles Stadium", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q259827',
#   'OTHERS'),
#  ({'name': 'Arsenal Stadium',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Arsenal Stadium", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q205309',
#   'OTHERS'),
#  ({'name': 'Fürstenstollen (Sankt Andreasberg)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "F\\u00fcrstenstollen (Sankt Andreasberg)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21821419',
#   'OTHERS'),
#  ({'name': 'Grünhirscher Stollen',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Gr\\u00fcnhirscher Stollen", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21707224',
#   'OTHERS'),
#  ({'name': 'Grubschwart',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Grubschwart", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21037223',
#   'OTHERS'),
#  ({'name': 'Besucherbergwerke Goldkronach',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Besucherbergwerke Goldkronach", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20170698',
#   'OTHERS'),
#  ({'name': 'Sieberstollen',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Sieberstollen", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q19921168',
#   'OTHERS'),
#  ({'name': 'Deep Tunnel',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Deep Tunnel", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q18350934',
#   'OTHERS'),
#  ({'name': 'Frankenscharrn-Stollen',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
# ...
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q22129191',
#   'OTHERS'),
#  ({'name': 'Le souci de soi',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Le souci de soi", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q22084670',
#   'OTHERS'),
#  ({'name': "L'emploi est mort, vive le travail!",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "L\'emploi est mort, vive le travail!", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q22083785',
#   'OTHERS'),
#  ({'name': "L'avenir du travail",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "L\'avenir du travail", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q22083784',
#   'OTHERS'),
#  ({'name': "Five Nights at Freddy's: The Silver Eyes",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Five Nights at Freddy\'s: The Silver Eyes", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21864313',
#   'OTHERS'),
#  ({'name': 'Dictionnaire de management de projet',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Dictionnaire de management de projet", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21396052',
#   'OTHERS'),
#  ({'name': "War's Unwomanly Face",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "War\'s Unwomanly Face", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21088242',
#   'OTHERS'),
#  ({'name': 'Masochism: Coldness and Cruelty',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Masochism: Coldness and Cruelty", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21055175',
#   'OTHERS'),
#  ({'name': 'Additifs alimentaires, danger : le guide indispensable pour ne plus vous empoisonner',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Additifs alimentaires, danger : le guide indispensable pour ne plus vous empoisonner", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20644345',
#   'OTHERS'),
#  ({'name': 'Yr wythnos honno : cyfres o fyfyrdodau yn canolbwyntio ar yr Wythnos Fawr',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Yr wythnos honno : cyfres o fyfyrdodau yn canolbwyntio ar yr Wythnos Fawr", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602516',
#   'OTHERS'),
#  ({'name': 'Parlwr bach',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Parlwr bach", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602512',
#   'OTHERS'),
#  ({'name': 'Paris',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Paris", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602506',
#   'OTHERS'),
#  ({'name': 'Yr Ergyd Olaf',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Yr Ergyd Olaf", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602482',
#   'OTHERS'),
#  ({'name': "Yr Elyrch - Dathlu'r 100",
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Yr Elyrch - Dathlu\'r 100", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602479',
#   'OTHERS'),
#  ({'name': 'Yr Argraff Gyntaf',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Yr Argraff Gyntaf", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602464',
#   'OTHERS'),
#  ({'name': 'Yr anweledig',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Yr anweledig", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20602458',
#   'OTHERS'),
#  ({'name': 'Sothover Wiuhout',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Sothover Wiuhout", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q69791586',
#   'LOC'),
#  ({'name': 'South Trwmpington',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "South Trwmpington", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q38726274',
#   'LOC'),
#  ({'name': 'Kigston Urban',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Kigston Urban", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q69792447',
#   'LOC'),
#  ({'name': 'Barnham and Estergate',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Barnham and Estergate", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q65617844',
#   'LOC'),
#  ({'name': 'Shilton and Barnacl',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Shilton and Barnacl", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q24521454',
#   'LOC'),
#  ({'name': 'itherslack, Meathop and Ulpha',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "itherslack, Meathop and Ulpha", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q24450668',
#   'LOC'),
#  ({'name': 'Tushingham-cum-tindley, Macefen and Bradley',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Tushingham-cum-tindley, Macefen and Bradley", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q24450450',
#   'LOC'),
#  ({'name': 'Worth',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Worth", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q24667584',
#   'LOC'),
#  ({'name': 'Kilton ith Lilstock',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Kilton ith Lilstock", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q86704159',
#   'LOC'),
#  ({'name': 'Foxton and Shoton',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Foxton and Shoton", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q100898368',
#   'LOC'),
#  ({'name': 'Abdon bnd Heath',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Abdon bnd Heath", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q29884754',
#   'LOC'),
#  ({'name': 'Aldcliffe-with-Stoddy',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Aldcliffe-with-Stoddy", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q29949477',
#   'LOC'),
#  ({'name': 'Durley',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Durley", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21971261',
#   'LOC'),
#  ({'name': 'Afpuddle and Turnerspuddle',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Afpuddle and Turnerspuddle", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q21978954',
#   'LOC'),
#  ({'name': 'Stcunton',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Stcunton", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q19845737',
#   'LOC'),
#  ({'name': 'Holyxll-dum-Needingworth',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Holyxll-dum-Needingworth", "boost": 2.0}}}], "should": [{"term": {"NERtype": "LOC"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q20023066',
#   'LOC'),
#  ({'name': '2013 Apia International Sydney (men)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2013 Apia International Sydney (men)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q15241737',
#   'OTHERS'),
#  ({'name': '1980 Seiko Classic',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "1980 Seiko Classic", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3534763',
#   'OTHERS'),
#  ({'name': '2001 Idea Prokom Open (women)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2001 Idea Prokom Open (women)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3353765',
#   'OTHERS'),
#  ({'name': '2000 Tashkent Open',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2000 Tashkent Open", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3353818',
#   'OTHERS'),
#  ({'name': '2002 Idea Prokom Open (women)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2002 Idea Prokom Open (women)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3353768',
#   'OTHERS'),
#  ({'name': '2005 Pilot Pen Tennis (women)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2005 Pilot Pen Tennis (women)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3534959',
#   'OTHERS'),
#  ({'name': '2003 AIG Japan Open – Women',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2003 AIG Japan Open \\u2013 Women", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3353996',
#   'OTHERS'),
#  ({'name': '2004 AIG Japan Open – Women',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "2004 AIG Japan Open \\u2013 Women", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q3353997',
#   'OTHERS'),
#  ({'name': 'Monument to Ostap Bender',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Monument to Ostap Bender", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q25396029',
#   'OTHERS'),
#  ({'name': 'Schillerdenkmal auf dem Schillerplatz (Stuttgart)',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Schillerdenkmal auf dem Schillerplatz (Stuttgart)", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q25392031',
#   'OTHERS'),
#  ({'name': 'Monument to Lenin in Zaporizhzhia',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Monument to Lenin in Zaporizhzhia", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q15825603',
#   'OTHERS'),
#  ({'name': 'Monumento al Sagrado Corazón de Jesús, Bilbao',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Monumento al Sagrado Coraz\\u00f3n de Jes\\u00fas, Bilbao", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q12260369',
#   'OTHERS'),
#  ({'name': 'Mesier 83',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Mesier 83", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q14030',
#   'OTHERS'),
#  ({'name': 'Messier 82',
#    'token': 'lamapi_demo_2023',
#    'kg': 'wikidata',
#    'limit': 50,
#    'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Messier 82", "boost": 2.0}}}], "should": [{"term": {"NERtype": "OTHERS"}}]}}}',
#    'sort': ['{"popularity": {"order": "desc"}}']},
#   'Q14026',
#   'OTHERS'),
#  ...]

# %%
import aiohttp
import asyncio
import backoff
import nest_asyncio
import random
from tqdm import tqdm
import numpy as np

# Assume queries is a list of tuples [(param1, id1), (param2, id2), ...]

failed_queries = {}
url = 'https://lamapi.hel.sintef.cloud/lookup/entity-retrieval'

# Backoff decorator for handling retries with exponential backoff
@backoff.on_exception(
    backoff.expo, 
    (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError, asyncio.TimeoutError), 
    max_tries=10, 
    max_time=400
)
async def fetch(session, url, params, headers, semaphore):
    async with semaphore:
        # Convert all params to str, int, or float
        #params = {k: (int(v) if isinstance(v, np.integer) else str(v)) for k, v in params.items()}
        async with session.get(url, params=params, headers=headers, timeout=50) as response:
            try:
                response.raise_for_status()  # Raises an exception for 4XX/5XX status codes
                return await response.json()
            except asyncio.TimeoutError:
                print(f"Request timed out for params: {params}")
                return []  # Return an empty list to handle the timeout gracefully
            except aiohttp.ClientError as e:
                print(f"ClientError for params {params}: {str(e)}")
                return []
            except Exception as e:
                print(f"Unexpected error for params {params}: {str(e)}")
                return []
async def process_item(session, url, id, headers, params, semaphore, pbar):
    try:
        data = await fetch(session, url, params, headers, semaphore)
    except aiohttp.ClientResponseError as e:
        if e.status == 404:
            print(f"404 Error: Resource not found for '{id}'")
            asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
            return 0, 0
        else:
            raise  # Re-raise the exception for other status codes

    num_result = len(data) if data else 0


    ###################################################
    ## scandisco il candidate set in cui ho già fatto 
    ## l'overlapping dei tipi
    ###################################################
    if data:
        for item in data:
            #print(f"{id} vs {item.get('id')}")
            if id == item.get('id'):
                asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
                pos_score = item.get('pos_score', 0)
                if pos_score:
                    mrr_increment = (num_result - (pos_score * num_result)) / num_result
                else:
                    mrr_increment = 1 / num_result  # Assume worst case for MRR if pos_score is 0
                return mrr_increment, 1

    return 0, 0

async def main(queries, url, pbar, failed_queries):
    headers = {'accept': 'application/json'}
    semaphore = asyncio.Semaphore(50)  # Limit to 50 concurrent requests
    m_mrr = 0
    cont_el = 0

    async with aiohttp.ClientSession() as session:
        tasks = []
        for param, id, _ in queries:
            tasks.append(process_item(session, url, id, headers, param, semaphore, pbar))
        
        results = await asyncio.gather(*tasks)

        ###  overlapping Q e T_i
        
        for (mrr_increment, count), (param, id, item_NERtype) in zip(results, queries):
            if mrr_increment == 0 and count == 0:
                failed_queries[id] = (id, item_NERtype)
            else:
                m_mrr += mrr_increment
                cont_el += count

        asyncio.get_event_loop().call_soon_threadsafe(pbar.close)

    print(f"Coverage of 2T: {cont_el / len(queries)}")
    print(f"Measure Reciprocal Rank of 2T: {m_mrr / len(queries)}")

# Check if there's already a running event loop
if __name__ == "__main__":
    nest_asyncio.apply()  # Apply nest_asyncio
    try:
        pbar = tqdm(total=len(queries))
        asyncio.run(main(queries, url, pbar, failed_queries))
    except RuntimeError:  # For environments like Jupyter
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(queries, url, pbar, failed_queries))

# %%
# for each WD type inserted from the user (WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query

ext_query_types = []

for entity_id, type_str in WD_query_type.items():
    #print(f"{type_str}: {get_type_id(type_str)}")
    
    entity_name = key_to_cell[list(WD_query_type.keys())[0]]
    ext_query_types += list(set(retrieve_superclasses(get_type_id(type_str))))
    
    # query a lamapi dove specifico nel filtro il tipo

    # entity_id è il ground truth
    WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
print(ext_query_types)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:377, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376 try:  # Python 2.7, use buffering of HTTP responses
# --> 377     httplib_response = conn.getresponse(buffering=True)
#     378 except TypeError:  # Python 3
#
# TypeError: HTTPConnection.getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 6>()
#       6 for entity_id, type_str in WD_query_type.items():
#       7     #print(f"{type_str}: {get_type_id(type_str)}")
#       9     entity_name = key_to_cell[list(WD_query_type.keys())[0]]
# ---> 10     ext_query_types += list(set(retrieve_superclasses(get_type_id(type_str))))
#      12     # query a lamapi dove specifico nel filtro il tipo
#      14     WD_candidate_types = WD_types(entity_id)  # WD_types() interroga il servizio types() ma forse è sbagliato (da implementare lato server non client)
#
# Input In [3], in get_type_id(entity_name)
#      39 headers = {
#      40     "accept": "application/json"
#      41 }
#      43 try:
# ---> 44     response = requests.get(url, headers=headers, params=params)
#      45     response.raise_for_status()  # Raise an error for HTTP issues
#      46     data = response.json()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594     self._prepare_proxy(conn)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#     606 response_conn = conn if not release_conn else None
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\connectionpool.py:380, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378 except TypeError:  # Python 3
#     379     try:
# --> 380         httplib_response = conn.getresponse()
#     381     except Exception as e:
#     382         # Remove the TypeError from the exception chain in Python 3;
#     383         # otherwise it looks like a programming error was the cause.
#     384         six.raise_from(e, None)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ext_query_types
# Out:
# ['Q53617489',
#  'Q98119401',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q2217301',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q24229398',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q1554231',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q1193236',
#  'Q121182',
#  'Q61961344',
#  'Q7048977',
#  'Q58415929',
#  'Q1639378',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q35825432',
#  'Q115668308',
#  'Q854457',
#  'Q26907166',
#  'Q17538423',
#  'Q31464082',
#  'Q16686448',
#  'Q107435521',
#  'Q47461344',
#  'Q37866906',
#  'Q17172633',
#  'Q106559804',
#  'Q28314507',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q5127848',
#  'Q35120',
#  'Q17489659',
#  'Q340169',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q103940464',
#  'Q11033',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q103940464',
#  'Q53617489',
#  'Q98119401',
#  'Q7278',
#  'Q16334295',
#  'Q854457',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q155076',
#  'Q7210356',
#  'Q35120',
#  'Q61961344',
#  'Q1639378',
#  'Q131085629',
#  'Q16334298',
#  'Q488383',
#  'Q58778',
#  'Q53617489',
#  'Q830077',
#  'Q4197743',
#  'Q53617407',
#  'Q215627',
#  'Q2066131',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q18536342',
#  'Q27043950',
#  'Q66394244',
#  'Q50995749',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q223557',
#  'Q10871364',
#  'Q103940464',
#  'Q795052',
#  'Q88392887',
#  'Q1424805',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q58180476',
#  'Q58180068',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q1272626',
#  'Q3695082',
#  'Q3861158',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q483501',
#  'Q103940464',
#  'Q53617489',
#  'Q327055',
#  'Q53617407',
#  'Q830077',
#  'Q15980158',
#  'Q66666685',
#  'Q215627',
#  'Q1914017',
#  'Q108762424',
#  'Q24229398',
#  'Q12777906',
#  'Q36180',
#  'Q2500638',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q27043950',
#  'Q1650915',
#  'Q66394244',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q20826540',
#  'Q223557',
#  'Q482980',
#  'Q129586023',
#  'Q795052',
#  'Q901',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q88392887',
#  'Q1424805',
#  'Q350945',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q1272626',
#  'Q3695082',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q53617489',
#  'Q13226383',
#  'Q53617407',
#  'Q6671777',
#  'Q960648',
#  'Q18674739',
#  'Q2221906',
#  'Q99527517',
#  'Q8205328',
#  'Q24699794',
#  'Q123349660',
#  'Q121359',
#  'Q27096213',
#  'Q488383',
#  'Q58778',
#  'Q103940464',
#  'Q17350442',
#  'Q811979',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q570116',
#  'Q386724',
#  'Q57659484',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q811430',
#  'Q223557',
#  'Q1454986',
#  'Q4406616',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q107715',
#  'Q47574',
#  'Q2897903',
#  'Q38885242',
#  'Q71550118',
#  'Q99527517',
#  'Q246672',
#  'Q937228',
#  'Q181175',
#  'Q286583',
#  'Q1368',
#  'Q65240001',
#  'Q39875001',
#  'Q7048977',
#  'Q1659862',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q1207505',
#  'Q488383',
#  'Q4373292',
#  'Q1643989',
#  'Q190122',
#  'Q15809678',
#  'Q16686448',
#  'Q122375923',
#  'Q123691918',
#  'Q5127848',
#  'Q7598359',
#  'Q367293',
#  'Q35120',
#  'Q2912517',
#  'Q309314',
#  'Q11105360',
#  'Q16889133',
#  'Q8142',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q13226383',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q35145743',
#  'Q6671777',
#  'Q24229398',
#  'Q12819564',
#  'Q548662',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q8205328',
#  'Q228332',
#  'Q61961344',
#  'Q123349660',
#  'Q1248784',
#  'Q1639378',
#  'Q131085629',
#  'Q121359',
#  'Q27096213',
#  'Q376799',
#  'Q488383',
#  'Q58778',
#  'Q811979',
#  'Q62447',
#  'Q854457',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q20977775',
#  'Q106559804',
#  'Q386724',
#  'Q4406616',
#  'Q55006986',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q16334298',
#  'Q811430',
#  'Q223557',
#  'Q1454986',
#  'Q103940464',
#  'Q41298',
#  'Q53617489',
#  'Q98119401',
#  'Q2217301',
#  'Q24229398',
#  'Q1554231',
#  'Q106668099',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q121182',
#  'Q58415929',
#  'Q1639378',
#  'Q28877',
#  'Q488383',
#  'Q35825432',
#  'Q31464082',
#  'Q17538423',
#  'Q12042160',
#  'Q107435521',
#  'Q28314507',
#  'Q5633421',
#  'Q27801',
#  'Q591041',
#  'Q35120',
#  'Q17489659',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q11033',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q99527517',
#  'Q213051',
#  'Q1193236',
#  'Q7048977',
#  'Q61961344',
#  'Q49850',
#  'Q49848',
#  'Q131085629',
#  'Q2424752',
#  'Q685935',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q115668308',
#  'Q26907166',
#  'Q854457',
#  'Q737498',
#  'Q16686448',
#  'Q47461344',
#  'Q37866906',
#  'Q55915575',
#  'Q17172633',
#  'Q106559804',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q11826511',
#  'Q340169',
#  'Q1391420',
#  'Q103940464',
#  'Q5127848',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q98119401',
#  'Q16334295',
#  'Q20937557',
#  'Q2897903',
#  'Q2217301',
#  'Q7725310',
#  'Q1002697',
#  'Q117208263',
#  'Q732577',
#  'Q24229398',
#  'Q16887380',
#  'Q15621286',
#  'Q11032',
#  'Q1554231',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q3523102',
#  'Q286583',
#  'Q1193236',
#  'Q121182',
#  'Q61961344',
#  'Q7048977',
#  'Q58415929',
#  'Q1639378',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q117208269',
#  'Q12774177',
#  'Q35825432',
#  'Q115668308',
#  'Q854457',
#  'Q26907166',
#  'Q17538423',
#  'Q31464082',
#  'Q16686448',
#  'Q107435521',
#  'Q47461344',
#  'Q37866906',
#  'Q17172633',
#  'Q106559804',
#  'Q28314507',
#  'Q386724',
#  'Q17537576',
#  'Q119648442',
#  'Q234460',
#  'Q5127848',
#  'Q35120',
#  'Q17489659',
#  'Q340169',
#  'Q16334298',
#  'Q1261026',
#  'Q16889133',
#  'Q103940464',
#  'Q11033',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q51938570',
#  'Q2897903',
#  'Q16686448',
#  'Q47461344',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q110879282',
#  'Q386724',
#  'Q110910970',
#  'Q17537576',
#  'Q7889',
#  'Q115920686',
#  'Q7397',
#  'Q110879246',
#  'Q2249149',
#  'Q286583',
#  'Q106213450',
#  'Q17538258',
#  'Q35120',
#  'Q4502142',
#  'Q58415929',
#  'Q28877',
#  'Q2424752',
#  'Q11410',
#  'Q2431196',
#  'Q488383',
#  'Q194980',
#  'Q53617489',
#  'Q20937557',
#  'Q2897903',
#  'Q732577',
#  'Q1554231',
#  'Q15621286',
#  'Q838948',
#  'Q110775916',
#  'Q99527517',
#  'Q110910970',
#  'Q3523102',
#  'Q286583',
#  'Q106213450',
#  'Q7048977',
#  'Q11578774',
#  'Q58415929',
#  'Q49848',
#  'Q28877',
#  'Q2424752',
#  'Q4502142',
#  'Q488383',
#  'Q194980',
#  'Q12774177',
#  'Q110879422',
#  'Q35825432',
#  'Q115668308',
#  'Q31464082',
#  'Q17538423',
#  'Q16686448',
#  'Q37866906',
#  'Q386724',
#  'Q17537576',
#  'Q110879246',
#  'Q5127848',
#  'Q35120',
#  'Q10301427',
#  'Q340169',
#  'Q15416',
#  'Q16889133',
#  'Q2431196',
#  'Q103940464',
#  'Q110879282',
#  'Q53617489',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q56061',
#  'Q3455524',
#  'Q6671777',
#  'Q24229398',
#  'Q106668099',
#  'Q2221906',
#  'Q99527517',
#  'Q43229',
#  'Q15642541',
#  'Q211606',
#  'Q61961344',
#  'Q123349660',
#  'Q58415929',
#  'Q1639378',
#  'Q25404640',
#  'Q27096213',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q6256',
#  'Q1063239',
#  'Q124711467',
#  'Q4835091',
#  'Q27096235',
#  'Q854457',
#  'Q23956024',
#  'Q16686448',
#  'Q178706',
#  'Q618123',
#  'Q124711484',
#  'Q106559804',
#  'Q82794',
#  'Q7210356',
#  'Q35120',
#  'Q1048835',
#  'Q26713767',
#  'Q16334298',
#  'Q16562419',
#  'Q18810687',
#  'Q103940464',
#  'Q11474',
#  'Q53617489',
#  'Q53617407',
#  'Q193395',
#  'Q28555911',
#  'Q2897903',
#  'Q9158768',
#  'Q6671777',
#  'Q10683158',
#  'Q251473',
#  'Q99527517',
#  'Q96791170',
#  'Q337060',
#  'Q8205328',
#  'Q104450446',
#  'Q6293',
#  'Q1183543',
#  'Q214609',
#  'Q1736298',
#  'Q167676',
#  'Q1439598',
#  'Q58415929',
#  'Q117207320',
#  'Q28877',
#  'Q2424752',
#  'Q10547012',
#  'Q1047213',
#  'Q488383',
#  'Q103940464',
#  'Q12774177',
#  'Q317088',
#  'Q15141646',
#  'Q35825432',
#  'Q28732711',
#  'Q6005984',
#  'Q17538423',
#  'Q16686448',
#  'Q2041172',
#  'Q10273457',
#  'Q115797427',
#  'Q386724',
#  'Q378078',
#  'Q123691918',
#  'Q117207331',
#  'Q35758',
#  'Q35120',
#  'Q340169',
#  'Q2066909',
#  'Q223557',
#  'Q96792464',
#  'Q39546',
#  'Q4406616',
#  'Q130941907',
#  'Q53617489',
#  'Q830077',
#  'Q4197743',
#  'Q53617407',
#  'Q215627',
#  'Q2066131',
#  'Q24229398',
#  'Q3778211',
#  'Q106559804',
#  'Q4406616',
#  'Q18536342',
#  'Q27043950',
#  'Q66394244',
#  'Q50995749',
#  'Q35120',
#  'Q7239',
#  'Q488383',
#  'Q223557',
#  'Q10871364',
#  'Q103940464',
#  'Q795052',
#  'Q88392887',
#  'Q1424805',
#  'Q350945',
#  'Q16686448',
#  'Q15621286',
#  'Q386724',
#  'Q1229071',
#  'Q4184950',
#  'Q17537576',
#  'Q7048977',
#  'Q68614425',
#  'Q2083958',
#  'Q35120',
#  'Q56324329',
#  'Q55412936',
#  'Q18408740',
#  'Q1272626',
#  'Q3695082',
#  'Q15989253',
#  'Q80071',
#  'Q3744880',
#  'Q488383',
#  'Q3744866',
#  'Q53617489',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q56061',
#  'Q3455524',
#  'Q6671777',
#  'Q24229398',
#  'Q106668099',
#  'Q2221906',
#  'Q99527517',
#  'Q43229',
#  'Q15642541',
#  'Q211606',
#  'Q4683593',
#  'Q61961344',
#  'Q123349660',
#  'Q58415929',
#  'Q1639378',
#  'Q25404640',
#  'Q27096213',
#  'Q131085629',
#  'Q488383',
#  'Q58778',
#  'Q1063239',
#  'Q124711467',
#  'Q4835091',
#  'Q27096235',
#  'Q854457',
#  'Q178706',
#  'Q16686448',
#  'Q23956024',
#  'Q618123',
#  'Q10374536',
#  'Q124711484',
#  'Q106559804',
#  'Q12076836',
#  'Q82794',
#  'Q7210356',
#  'Q35120',
#  'Q1048835',
#  'Q26713767',
#  'Q3976665',
#  'Q16334298',
#  'Q16562419',
#  'Q18810687',
#  'Q103940464',
#  'Q113137696',
#  'Q103940464',
#  'Q53617489',
#  'Q53617407',
#  'Q13415392',
#  'Q6671777',
#  'Q27043948',
#  'Q16686022',
#  'Q60960',
#  'Q25570959',
#  'Q99527517',
#  'Q55568967',
#  'Q66394244',
#  'Q27043950',
#  'Q35120',
#  'Q17781690',
#  'Q1970309',
#  'Q488383',
#  'Q112826975',
#  'Q223557',
#  'Q4406616',
#  'Q4936952',
#  'Q53617489',
#  'Q13226383',
#  'Q98119401',
#  'Q53617407',
#  'Q16334295',
#  'Q35145743',
#  'Q6671777',
#  'Q24229398',
#  'Q12819564',
#  'Q548662',
#  'Q106668099',
#  'Q99527517',
#  'Q43229',
#  'Q8205328',
#  'Q228332',
#  'Q61961344',
#  'Q123349660',
#  'Q1248784',
#  'Q1639378',
#  'Q131085629',
#  'Q121359',
#  'Q27096213',
#  'Q376799',
#  'Q488383',
#  'Q58778',
#  'Q811979',
#  'Q62447',
#  'Q854457',
#  'Q27096235',
#  'Q16686448',
#  'Q618123',
#  'Q41176',
#  'Q20977775',
#  'Q106559804',
#  'Q386724',
#  'Q4406616',
#  'Q55006986',
#  'Q11908691',
#  'Q15710813',
#  'Q35120',
#  'Q16334298',
#  'Q811430',
#  ...]

# %% [markdown]
# ## WD type vs NER type

# %%
# for each WD type inserted from the user (WD_WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query
# Out:
# False

# %%
retrieve_superclasses("Q12299841")
# Out:
# {'Q12299841': 'cricketer',
#  'Q2066131': 'athlete',
#  'Q18536342': 'competitive player',
#  'Q50995749': 'sportsperson',
#  'Q4197743': 'player',
#  'Q215627': 'person',
#  'Q830077': 'subject',
#  'Q795052': 'individual',
#  'Q3778211': 'legal person',
#  'Q53617489': 'independent continuant',
#  'Q7239': 'organism',
#  'Q24229398': 'agent',
#  'Q106559804': 'person or organization',
#  'Q103940464': 'continuant',
#  'Q223557': 'physical object',
#  'Q66394244': 'physical anatomical entity',
#  'Q4406616': 'concrete object',
#  'Q53617407': 'material entity',
#  'Q27043950': 'anatomical entity',
#  'Q488383': 'object',
#  'Q35120': 'entity'}

# %%
cta_values_dict
# Out:
# {'58891288_0_1117541047012405958 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 1': 'http://dbpedia.org/ontology/Lake',
#  '50245608_0_871275842592178099 0': 'http://dbpedia.org/ontology/Film',
#  '14067031_0_559833072073397908 1': 'http://dbpedia.org/ontology/Language',
#  '8286121_0_8471791395229161598 0': 'http://dbpedia.org/ontology/Country',
#  '39759273_0_1427898308030295194 1': 'http://dbpedia.org/ontology/Film',
#  '14380604_4_3329235705746762392 1': 'http://dbpedia.org/ontology/Company',
#  '20135078_0_7570343137119682530 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_6_8221428333921653560 1': 'http://dbpedia.org/ontology/VideoGame',
#  '34041816_1_4749054164534706977 2': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 7': 'http://dbpedia.org/ontology/Currency',
#  '71137051_0_8039724067857124984 0': 'http://dbpedia.org/ontology/Bird',
#  '29414811_2_4773219892816395776 1': 'http://dbpedia.org/ontology/VideoGame',
#  '99070098_0_2074872741302696997 1': 'http://dbpedia.org/ontology/Mountain',
#  '35188621_0_6058553107571275232 3': 'http://dbpedia.org/ontology/Person',
#  '43237185_1_3636357855502246981 3': 'http://dbpedia.org/ontology/Scientist',
#  '50245608_0_871275842592178099 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 0': 'http://dbpedia.org/ontology/VideoGame',
#  '29414811_6_8221428333921653560 4': 'http://dbpedia.org/ontology/Company',
#  '11833461_1_3811022039809817402 0': 'http://dbpedia.org/ontology/VideoGame',
#  '21245481_0_8730460088443117515 1': 'http://dbpedia.org/ontology/Lake',
#  '38428277_0_1311643810102462607 3': 'http://dbpedia.org/ontology/Person',
#  '13719111_1_5719401842463579519 0': 'http://dbpedia.org/ontology/Bird',
#  '77694908_0_6083291340991074532 1': 'http://dbpedia.org/ontology/Film',
#  '20135078_0_7570343137119682530 1': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 0': 'http://dbpedia.org/ontology/Scientist',
#  '88523363_0_8180214313099580515 0': 'http://dbpedia.org/ontology/Plant',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'http://dbpedia.org/ontology/Mountain',
#  '58891288_0_1117541047012405958 3': 'http://dbpedia.org/ontology/Person',
#  '25404227_0_2240631045609013057 3': 'http://dbpedia.org/ontology/Person',
#  '9475172_1_1023126399856690702 1': 'http://dbpedia.org/ontology/TelevisionShow',
#  '60319454_0_3938426910282115527 0': 'http://dbpedia.org/ontology/Animal',
#  '52299421_0_4473286348258170200 1': 'http://dbpedia.org/ontology/Country',
#  '37856682_0_6818907050314633217 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '77694908_0_6083291340991074532 3': 'http://dbpedia.org/ontology/Person',
#  '39759273_0_1427898308030295194 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_2_4773219892816395776 4': 'http://dbpedia.org/ontology/Company',
#  '29414811_13_8724394428539174350 2': 'http://dbpedia.org/ontology/Genre',
#  '33401079_0_9127583903019856402 0': 'http://dbpedia.org/ontology/Person',
#  '26310680_0_5150772059999313798 1': 'http://dbpedia.org/ontology/Currency',
#  '10579449_0_1681126353774891032 1': 'http://dbpedia.org/ontology/Newspaper',
#  '29414811_6_8221428333921653560 2': 'http://dbpedia.org/ontology/Genre',
#  '84548468_0_5955155464119382182 3': 'http://dbpedia.org/ontology/Person',
#  '55004961_0_2904467548072189860 0': 'http://dbpedia.org/ontology/Country',
#  '63450419_0_8012592961815711786 1': 'http://dbpedia.org/ontology/Plant',
#  '39107734_2_2329160387535788734 1': 'http://dbpedia.org/ontology/Airport',
#  '29414811_12_251152470253168163 4': 'http://dbpedia.org/ontology/Company',
#  '91959037_0_7907661684242014480 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 1': 'http://dbpedia.org/ontology/Company',
#  '84575189_0_6365692015941409487 2': 'http://dbpedia.org/ontology/AcademicJournal',
#  '14380604_4_3329235705746762392 2': 'http://dbpedia.org/ontology/PopulatedPlace',
#  '40534006_0_4617468856744635526 1': 'http://dbpedia.org/ontology/Wrestler',
#  '29414811_13_8724394428539174350 4': 'http://dbpedia.org/ontology/Company',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'http://dbpedia.org/ontology/PoliticalParty',
#  '84548468_0_5955155464119382182 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 2': 'http://dbpedia.org/ontology/Country',
#  '35188621_0_6058553107571275232 1': 'http://dbpedia.org/ontology/Film',
#  '22864497_0_8632623712684511496 0': 'http://dbpedia.org/ontology/VideoGame',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'http://dbpedia.org/ontology/Cricketer',
#  '14067031_0_559833072073397908 5': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 2': 'http://dbpedia.org/ontology/Genre',
#  '88523363_0_8180214313099580515 2': 'http://dbpedia.org/ontology/Eukaryote',
#  '28086084_0_3127660530989916727 0': 'http://dbpedia.org/ontology/Saint',
#  '50245608_0_871275842592178099 4': 'http://dbpedia.org/ontology/Writer',
#  '9834884_0_3871985887467090123 1': 'http://dbpedia.org/ontology/Museum',
#  '69881946_0_1105130426898457358 1': 'http://dbpedia.org/ontology/Film',
#  '25404227_0_2240631045609013057 1': 'http://dbpedia.org/ontology/Film',
#  '75367212_2_2745466355267233390 2': 'http://dbpedia.org/ontology/Company',
#  '39650055_5_7135804139753401681 1': 'http://dbpedia.org/ontology/Company',
#  '29414811_2_4773219892816395776 2': 'http://dbpedia.org/ontology/Genre',
#  '16767252_0_2409448375013995751 3': 'http://dbpedia.org/ontology/Person',
#  '71840765_0_6664391841933033844 0': 'http://dbpedia.org/ontology/Lake',
#  '36102169_0_7739454799295072814 1': 'http://dbpedia.org/ontology/Company',
#  '26310680_0_5150772059999313798 0': 'http://dbpedia.org/ontology/Country',
#  '45073662_0_3179937335063201739 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '11833461_1_3811022039809817402 1': 'http://dbpedia.org/ontology/Company',
#  '21245481_0_8730460088443117515 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '53822652_0_5767892317858575530 3': 'http://dbpedia.org/ontology/Person',
#  '39173938_0_7916056990138658530 1': 'http://dbpedia.org/ontology/Film',
#  '8286121_0_8471791395229161598 1': 'http://dbpedia.org/ontology/City',
#  '21362676_0_6854186738074119688 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 1': 'http://dbpedia.org/ontology/Genre',
#  '80588006_0_6965325215443683359 1': 'http://dbpedia.org/ontology/Newspaper',
#  '22864497_0_8632623712684511496 1': 'http://dbpedia.org/ontology/Company',
#  '61121469_0_6337620713408906340 0': 'http://dbpedia.org/ontology/Country',
#  '90196673_0_5458330029110291950 0': 'http://dbpedia.org/ontology/Animal',
#  '53989675_0_8697482470743954630 0': 'http://dbpedia.org/ontology/Lake',
#  '66009064_0_9148652238372261251 0': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '55004961_0_2904467548072189860 1': 'http://dbpedia.org/ontology/City',
#  '50270082_0_444360818941411589 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '24036779_0_5608105867560183058 0': 'http://dbpedia.org/ontology/Country',
#  '41336118_0_4331895026409635103 0': 'http://dbpedia.org/ontology/Company',
#  '69881946_0_1105130426898457358 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 3': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 2': 'http://dbpedia.org/ontology/EducationalInstitution',
#  '9834884_0_3871985887467090123 2': 'http://dbpedia.org/ontology/Country',
#  '16767252_0_2409448375013995751 1': 'http://dbpedia.org/ontology/Film',
#  '61121469_0_6337620713408906340 1': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 1': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 0': 'http://dbpedia.org/ontology/Country',
#  '41480166_0_6681239260286218499 0': 'http://dbpedia.org/ontology/Saint',
#  '57943722_0_8666078014685775876 0': 'http://dbpedia.org/ontology/Country',
#  '38428277_0_1311643810102462607 1': 'http://dbpedia.org/ontology/Film',
#  '36102169_0_7739454799295072814 2': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 1': 'http://dbpedia.org/ontology/City',
#  '9567241_0_5666388268510912770 1': 'http://dbpedia.org/ontology/Newspaper',
#  '69537082_0_7789694313271016902 1': 'http://dbpedia.org/ontology/Country',
#  '57943722_0_8666078014685775876 1': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 0': 'http://dbpedia.org/ontology/Country',
#  '53822652_0_5767892317858575530 1': 'http://dbpedia.org/ontology/Film',
#  '54719588_0_8417197176086756912 5': 'http://dbpedia.org/ontology/Person',
#  '24036779_0_5608105867560183058 5': 'http://dbpedia.org/ontology/GovernmentType',
#  '34041816_1_4749054164534706977 1': 'http://dbpedia.org/ontology/Airport',
#  '39173938_0_7916056990138658530 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 4': 'http://dbpedia.org/ontology/Country',
#  '66009064_0_9148652238372261251 2': 'http://dbpedia.org/ontology/SportsTeam',
#  '21362676_0_6854186738074119688 1': 'http://dbpedia.org/ontology/Film',
#  '39107734_2_2329160387535788734 2': 'http://dbpedia.org/ontology/City',
#  '29414811_13_8724394428539174350 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 0': 'http://dbpedia.org/ontology/VideoGame'}

# %%
cea_values_dict
# Out:
# {'50245608_0_871275842592178099 0': 'https://www.wikidata.org/entity/Q46551',
#  '22864497_0_8632623712684511496 0': 'https://www.wikidata.org/entity/Q6738126',
#  '66009064_0_9148652238372261251 0': 'https://www.wikidata.org/entity/Q1094988',
#  '21362676_0_6854186738074119688 1': 'https://www.wikidata.org/entity/Q463832',
#  '40534006_0_4617468856744635526 1': 'https://www.wikidata.org/entity/Q452590',
#  '36102169_0_7739454799295072814 2': 'https://www.wikidata.org/entity/Q1978200',
#  '53822652_0_5767892317858575530 1': 'https://www.wikidata.org/entity/Q200396',
#  '60319454_0_3938426910282115527 0': 'https://www.wikidata.org/entity/Q69581',
#  '8468806_0_4382447409703007384 1': 'https://www.wikidata.org/entity/Q1546823',
#  '33401079_0_9127583903019856402 0': 'https://www.wikidata.org/entity/Q154538',
#  '99070098_0_2074872741302696997 1': 'https://www.wikidata.org/entity/Q4920755',
#  '50270082_0_444360818941411589 1': 'https://www.wikidata.org/entity/Q114468',
#  '29414811_12_251152470253168163 1': 'https://www.wikidata.org/entity/Q1060323',
#  '39759273_0_1427898308030295194 1': 'https://www.wikidata.org/entity/Q104123',
#  '69537082_0_7789694313271016902 1': 'https://www.wikidata.org/entity/Q1011',
#  '88523363_0_8180214313099580515 0': 'https://www.wikidata.org/entity/Q5782393',
#  '41480166_0_6681239260286218499 0': 'https://www.wikidata.org/entity/Q4390981',
#  '9834884_0_3871985887467090123 1': 'https://www.wikidata.org/entity/Q1781530',
#  '26310680_0_5150772059999313798 1': 'https://www.wikidata.org/entity/Q206319',
#  '39173938_0_7916056990138658530 1': 'https://www.wikidata.org/entity/Q25193623',
#  '91959037_0_7907661684242014480 1': 'https://www.wikidata.org/entity/Q663665',
#  '13719111_1_5719401842463579519 0': 'https://www.wikidata.org/entity/Q2384003',
#  '54719588_0_8417197176086756912 3': 'https://www.wikidata.org/entity/Q575014',
#  '58891288_0_1117541047012405958 1': 'https://www.wikidata.org/entity/Q135465',
#  '28086084_0_3127660530989916727 0': 'https://www.wikidata.org/entity/Q61620',
#  '21245481_0_8730460088443117515 1': 'https://www.wikidata.org/entity/Q6476027',
#  '90196673_0_5458330029110291950 0': 'https://www.wikidata.org/entity/Q199203',
#  '35188621_0_6058553107571275232 1': 'https://www.wikidata.org/entity/Q214801',
#  '46671561_0_6122315295162029872 0': 'https://www.wikidata.org/entity/Q1408367',
#  '25404227_0_2240631045609013057 1': 'https://www.wikidata.org/entity/Q128518',
#  '63450419_0_8012592961815711786 1': 'https://www.wikidata.org/entity/Q2078054',
#  '39107734_2_2329160387535788734 1': 'https://www.wikidata.org/entity/Q193439',
#  '29414811_2_4773219892816395776 1': 'https://www.wikidata.org/entity/Q276217',
#  '20135078_0_7570343137119682530 1': 'https://www.wikidata.org/entity/Q639481',
#  '39650055_5_7135804139753401681 1': 'https://www.wikidata.org/entity/Q459477',
#  '16767252_0_2409448375013995751 1': 'https://www.wikidata.org/entity/Q503046',
#  '9475172_1_1023126399856690702 1': 'https://www.wikidata.org/entity/Q380519',
#  '24036779_0_5608105867560183058 0': 'https://www.wikidata.org/entity/Q817',
#  '69881946_0_1105130426898457358 1': 'https://www.wikidata.org/entity/Q471169',
#  '75367212_2_2745466355267233390 0': 'https://www.wikidata.org/entity/Q1205676',
#  '84575189_0_6365692015941409487 2': 'https://www.wikidata.org/entity/Q39379',
#  '84548468_0_5955155464119382182 1': 'https://www.wikidata.org/entity/Q181086',
#  '52299421_0_4473286348258170200 1': 'https://www.wikidata.org/entity/Q227',
#  '37856682_0_6818907050314633217 0': 'https://www.wikidata.org/entity/Q26',
#  '38428277_0_1311643810102462607 1': 'https://www.wikidata.org/entity/Q725552',
#  '41336118_0_4331895026409635103 0': 'https://www.wikidata.org/entity/Q831445',
#  '71840765_0_6664391841933033844 0': 'https://www.wikidata.org/entity/Q14429',
#  '77694908_0_6083291340991074532 1': 'https://www.wikidata.org/entity/Q83495',
#  '43237185_1_3636357855502246981 0': 'https://www.wikidata.org/entity/Q72538',
#  '45073662_0_3179937335063201739 1': 'https://www.wikidata.org/entity/Q375648',
#  '11833461_1_3811022039809817402 0': 'https://www.wikidata.org/entity/Q5285919',
#  '14067031_0_559833072073397908 0': 'https://www.wikidata.org/entity/Q1033',
#  '9567241_0_5666388268510912770 1': 'https://www.wikidata.org/entity/Q208875',
#  '34041816_1_4749054164534706977 1': 'https://www.wikidata.org/entity/Q178021',
#  '10579449_0_1681126353774891032 1': 'https://www.wikidata.org/entity/Q30315633',
#  '29414811_13_8724394428539174350 1': 'https://www.wikidata.org/entity/Q213911',
#  '14380604_4_3329235705746762392 1': 'https://www.wikidata.org/entity/Q487907',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'https://www.wikidata.org/entity/Q7626741',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'https://www.wikidata.org/entity/Q9669',
#  '80588006_0_6965325215443683359 1': 'https://www.wikidata.org/entity/Q1872524',
#  '29414811_6_8221428333921653560 1': 'https://www.wikidata.org/entity/Q1765733',
#  '53989675_0_8697482470743954630 0': 'https://www.wikidata.org/entity/Q5181893',
#  '1438042986423_95_20150728002306-00329-ip-10-236-191-2_805336391_10 1': 'https://www.wikidata.org/entity/Q6393870',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'https://www.wikidata.org/entity/Q7194441'}
