# %%
import os
import pandas as pd
from tqdm import tqdm
import logging
import requests
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import re

# %%
def WD_types(entity_id):
    """
    Queries the API to retrieve the list of type IDs for a given entity ID.

    Args:
        entity_id (str): The Wikidata ID of the entity (e.g., 'Q30').

    Returns:
        list: A list of type IDs associated with the given entity, or an empty list if an error occurs.
    """

    url = "https://lamapi.hel.sintef.cloud/entity/types?token=lamapi_demo_2023"
    headers = {
        "accept": "application/json",
        "Content-Type": "application/json"
    }
    payload = {"json": [entity_id]}
    
    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()  # Raise an error for HTTP issues
        ids = response.json()
        return ids[entity_id]['types']['P31']  # Parse and return the JSON response
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return []

# %%
def split_entity_name(entity_name):
    """
    Splits the entity name into separate words if it has more than 2 uppercase letters.
    
    Args:
        entity_name (str): The input string to check and potentially split (e.g., 'VideoGame').
    
    Returns:
        str: The modified string with words split by spaces if necessary.
    """
    # Count uppercase letters
    uppercase_count = sum(1 for char in entity_name if char.isupper())
    
    # If more than 2 uppercase letters, split before every uppercase letter
    if uppercase_count >= 2:
        return re.sub(r'(?<!^)(?=[A-Z])', ' ', entity_name)
    
    return entity_name

def get_type_id(entity_name):
    """
    Queries the API to retrieve the QID of an entity based on its name.

    Args:
        entity_name (str): The name of the entity (e.g., 'Video Game').

    Returns:
        str: The QID associated with the given entity name, or None if an error occurs or no QID is found.
    """
    
    entity_name_split = split_entity_name(entity_name)

    url = f"https://lamapi.hel.sintef.cloud/lookup/entity-retrieval"
    params = {
        "name": entity_name_split,
        "kind": "type",
        "token": "lamapi_demo_2023"
    }
    headers = {
        "accept": "application/json"
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()  # Raise an error for HTTP issues
        data = response.json()
        # Assuming the API returns the QID directly or within a key, adjust if structure differs
        return data[0]['id']
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

# %%
def retrieve_superclasses(entity_id):
    """
    Retrieve all superclasses of a given Wikidata entity ID.

    Args:
        entity_id (str): The ID of the entity (e.g., "Q207784").

    Returns:
        dict: A dictionary where keys are superclass IDs, and values are their labels.
    """
    # Define the SPARQL endpoint and query
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?superclass ?superclassLabel WHERE {{
      wd:{entity_id} (wdt:P279)* ?superclass.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """

    # Function to query the SPARQL endpoint with retries
    def query_wikidata(sparql_client, query, retries=3, delay=5):
        for attempt in range(retries):
            try:
                sparql_client.setQuery(query)
                sparql_client.setReturnFormat(JSON)
                results = sparql_client.query().convert()
                return results
            except Exception as e:
                if "429" in str(e):  # Handle Too Many Requests error
                    print(f"Rate limit hit. Retrying in {delay} seconds... (Attempt {attempt + 1}/{retries})")
                    time.sleep(delay)
                else:
                    print(f"An error occurred: {e}")
                    break
        return None

    # Set up the SPARQL client
    sparql = SPARQLWrapper(endpoint_url)

    # Execute the query with retries
    results = query_wikidata(sparql, query)

    # Process results and return as a dictionary
    if results:
        superclass_dict = {}
        for result in results["results"]["bindings"]:
            superclass_id = result["superclass"]["value"].split("/")[-1]  # Extract entity ID from the URI
            label = result["superclassLabel"]["value"]
            superclass_dict[superclass_id] = label
        return superclass_dict
    else:
        print("Failed to retrieve data after multiple attempts.")
        return {}

# %% [markdown]
# ## Dataset Reading

# %%
tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/gt/CEA_Round1_gt_wd.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/Round1_T2D/gt/CTA_Round1_gt.csv'


os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df_cea = pd.read_csv(cea_file, header=None)
df_cea["key"] = df_cea[0] + " " + df_cea[1].astype(str) + " " + df_cea[2].astype(str)
df_cea["key_col"] = df_cea[0] + " " + df_cea[2].astype(str)
cea_values_dict = dict(zip(df_cea["key_col"].values, df_cea[3].values))


df_cta = pd.read_csv(cta_file, header=None)
df_cta["key"] = df_cta[0] + " " + df_cta[1].astype(str)
cta_values_dict = dict(zip(df_cta["key"].values, df_cta[2].values))


# Find the intersection of keys between the two dictionaries
common_keys = set(cea_values_dict.keys()).intersection(cta_values_dict.keys())

# Create a new dictionary with combined values
combined_dict = {key: [cea_values_dict[key], cta_values_dict[key]] for key in common_keys}

# %%
cea_keys_set = set(df_cea["key"].values)
cea_values_dict_cell = dict(zip(df_cea["key"].values, df_cea[3].values))

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        qid_to_value = {}

        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    qid = cea_values_dict_cell[key].split('/')[-1]  # Extract the QID from the URL
                    qid_to_value[qid] = cell_value
                    break  # Exit inner loop early as only one match per row/col is needed

        return qid_to_value
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)
# Out:
# Processing tables: 100%|██████████| 64/64 [00:00<00:00, 97.70it/s]

# %%
key_to_cell
# Out:
# {'Q1318465': 'Dainik Jagran',
#  'Q1872524': 'Dainik Bhaskar',
#  'Q2191913': 'Dinakaran',
#  'Q2732186': 'Malayala Manorama',
#  'Q2760832': 'Divya Bhaskar',
#  'Q3246100': 'Dinamalar',
#  'Q18049522': 'Huffington Post',
#  'Q30315633': 'foxnews',
#  'Q423289': 'bbc Hindi',
#  'Q1440347': 'Softpedia',
#  'Q3522186': 'Dina Thanthi',
#  'Q54340': "People's Daily (Renmin Ri Bao)",
#  'Q39681': 'USA Today',
#  'Q3595638': 'Navbharat Times',
#  'Q3630070': 'Punjab Kesari',
#  'Q518987': 'Donkey Kong Country',
#  'Q6720878': 'F-Zero',
#  'Q7798922': 'SimCity',
#  'Q389254': 'Super Castlevania IV',
#  'Q1133204': 'Street Fighter II',
#  'Q1368099': 'Super Probotector: Alien Rebels',
#  'Q853143': 'Super Mario World: Super Mario Advance 2',
#  'Q619025': 'R-Type III: The Third Lightning',
#  'Q275122': "Super Ghouls'n Ghosts",
#  'Q370055': 'The Legend of Zelda: A Link to the Past',
#  'Q343033': 'ActRaiser',
#  'Q2716989': 'Final Fight',
#  'Q1072051': "Donkey Kong Country 2: Diddy's Kong Quest",
#  'Q2619370': "Kirby's Dream Course",
#  'Q196255': "Street Fighter II' Turbo: Hyper Fighting",
#  'Q2986962': "Kirby's Ghost Trap",
#  'Q2414743': 'Breath of Fire II',
#  'Q4009249': 'Vegas Stakes',
#  'Q1026590': "Mario's Super Picross (900 Wii Points)",
#  'Q1194133': 'Gradius III (900 Wii Points)',
#  'Q2414296': 'Axelay',
#  'Q1194825': 'Super Metroid',
#  'Q910467': 'Cybernator',
#  'Q1241664': "Donkey Kong Country 3: Dixie Kong's Double Trouble",
#  'Q7146181': 'Harvest Moon',
#  'Q2913706': 'Super Street Fighter II: The New Challengers',
#  'Q92824844': 'Super Turrican',
#  'Q846203': 'Super R-Type',
#  'Q3282001': 'Pac-Attack',
#  'Q1063119': 'Super Mario RPG: Legend of the Seven Stars (900 Wii Points)',
#  'Q5285919': "DoReMi Fantasy: Milon's DokiDoki Adventure (900 Wii Points)",
#  'Q220665': 'Space Invaders: The Original Game',
#  'Q1800173': 'Secret Of Mana',
#  'Q2002093': 'Super Punch-Out!!',
#  'Q2734372': 'Ogre Battle: The March of the Black Queen (900 Wii Points)',
#  'Q1202713': "Kirby's Dream Land 3 (900 Wii Points)",
#  'Q2480306': 'Pilotwings',
#  'Q54322': 'Super Star Wars',
#  'Q54330': 'Super Star Wars: The Empire Strikes Back',
#  'Q1321249': 'Final Fight 2',
#  'Q54335': 'Super Star Wars: Return of the Jedi',
#  'Q8073789': 'Zombies',
#  'Q2422795': 'Street Fighter Alpha 2',
#  'Q2601047': 'Final Fight 3',
#  'Q1061560': 'Super Mario Kart',
#  'Q1661310': "Indiana Jones' Greatest Adventures",
#  'Q3284282': 'Ghoul Patrol',
#  'Q1871848': "Kirby's Fun Pak",
#  'Q921957': 'Final Fantasy II (900 Wii Points)',
#  'Q2708224': 'Aero the Acro-Bat',
#  'Q2629633': 'Aero the Acro-Bat 2',
#  'Q682463': 'Wild Guns',
#  'Q1249187': 'Mystic Quest Legend',
#  'Q7336963': 'Rival Turf!',
#  'Q5327066': 'Super E.D.F.: Earth Defense Force',
#  'Q582662': 'Super Bonk (900 Wii Points)',
#  'Q11389993': 'Natsume Championship Wrestling (900 Wii Points)',
#  'Q687559': 'Final Fantasy III (900 Wii Points)',
#  'Q3777241': 'Brawl Brothers',
#  'Q5846885': 'The Ignition Factor (900 Wii Points)',
#  'Q2440904': 'Super Adventure Island',
#  'Q761815': 'Chrono Trigger',
#  'Q3504101': 'Super Adventure Island II',
#  'Q157387': 'Prince of Persia',
#  'Q527830': 'Pink-backed pelican',
#  'Q25421': 'Little grebe',
#  'Q25440': 'Great cormorant',
#  'Q59492': 'Long-tailed cormorant',
#  'Q387379': 'African darter',
#  'Q261286': 'African finfoot',
#  'Q26129': 'Little bittern',
#  'Q126216': 'BLACK-CROWNED NIGHT-HERON',
#  'Q966356': 'CATTLE EGRET',
#  'Q191394': 'Common squacco heron',
#  'Q498169': 'Madagascar pond-heron',
#  'Q270722': 'Striated heron',
#  'Q498158': 'Rufous-bellied heron',
#  'Q131709': 'Little egret',
#  'Q27074615': 'Intermediate egret',
#  'Q130730': 'GREAT EGRET',
#  'Q118608': 'Goliath heron',
#  'Q160488': 'Purple heron',
#  'Q25273': 'Grey heron',
#  'Q220578': 'Black-headed heron',
#  'Q652151': 'Hamerkop',
#  'Q655510': 'Yellow-billed stork',
#  'Q44327': 'Wooly-necked stork',
#  'Q26902': 'African open-billed stork',
#  'Q1219291': 'Saddle-billed stork',
#  'Q512737': 'Marabou stork',
#  'Q18700': 'Shoebill',
#  'Q208763': 'Sacred ibis',
#  'Q301777': 'Hadada ibis',
#  'Q178811': 'Glossy ibis',
#  'Q512348': 'African spoonbill',
#  'Q274179': 'Egyptian goose',
#  'Q247412': 'Spur-winged goose',
#  'Q3473539': 'Knob-billed duck',
#  'Q386949': 'African pygmy-goose',
#  'Q742574': 'White-faced whistling-duck',
#  'Q535206': 'Yellow-billed duck',
#  'Q80362': 'Black kite',
#  'Q594328': 'Black-shouldered kite',
#  'Q217497': 'African fish-eagle',
#  'Q732523': 'Palm-nut vulture',
#  'Q25332': 'OSPREY',
#  'Q177386': 'Hooded vulture',
#  'Q755006': 'White-headed vulture',
#  'Q281874': 'African white-backed vulture',
#  'Q838162': 'Lappet-faced vulture',
#  'Q264142': 'Black-chested snake-eagle',
#  'Q549126': 'Brown snake-eagle',
#  'Q937849': 'Western banded snake-eagle',
#  'Q17556': 'African marsh harrier',
#  'Q26431': 'Eurasian marsh harrier',
#  'Q1081454': 'Eastern chanting-goshawk',
#  'Q843278': 'Dark chanting-goshawk',
#  'Q1261504': 'Lizard buzzard',
#  'Q715710': 'Shikra',
#  'Q128037': 'African goshawk',
#  'Q1264152': 'Great sparrowhawk',
#  'Q48431': 'Bat hawk',
#  'Q512792': 'African harrier-hawk',
#  'Q760623': 'Augur buzzard',
#  'Q819471': 'Mountain buzzard',
#  'Q374141': 'Tawny eagle',
#  'Q609369': "Wahlberg's eagle",
#  'Q1260400': "Ayre's hawk-eagle",
#  'Q726387': 'Bateleur',
#  'Q285522': 'Long-crested eagle',
#  'Q501733': 'Martial eagle',
#  'Q591640': 'African crowned eagle',
#  'Q26490': 'Common kestrel',
#  'Q925768': 'Grey kestrel',
#  'Q266813': 'African hobby',
#  'Q25876': 'Eurasian hobby',
#  'Q33554': 'Lanner falcon',
#  'Q30535': 'PEREGRINE FALCON',
#  'Q251842': 'Helmeted guineafowl',
#  'Q854855': 'Crested guineafowl',
#  'Q27074553': "Nahan's francolin",
#  'Q27074556': 'Coqui francolin',
#  'Q27074564': 'Crested francolin',
#  'Q27074582': 'Red-necked spurfowl',
#  'Q606076': 'Harlequin quail',
#  'Q1123824': 'Blue quail',
#  'Q18836': 'Common button-quail',
#  'Q1271563': 'White-spotted flufftail',
#  'Q1267654': 'African crake',
#  'Q669074': 'Black crake',
#  'Q25036531': 'Purple swamphen',
#  'Q18847': 'COMMON MOORHEN',
#  'Q132201': 'African jacana',
#  'Q335992': 'Grey crowned crane',
#  'Q429477': 'Black-bellied bustard',
#  'Q263426': 'Water thick-knee',
#  'Q922125': 'Senegal thick-knee',
#  'Q330310': 'Collared pratincole',
#  'Q1303318': 'Rock pratincole',
#  'Q749126': 'Spur-winged lapwing',
#  'Q686769': 'Long-toed lapwing',
#  'Q875949': 'African wattled lapwing',
#  'Q369800': 'Crowned lapwing',
#  'Q948863': 'Black-headed lapwing',
#  'Q972384': 'Senegal lapwing',
#  'Q1263241': 'Brown-chested lapwing',
#  'Q774208': "Kittlitz's plover",
#  'Q121596': 'Three-banded plover',
#  'Q18850': 'Common sandpiper',
#  'Q18837': 'Wood sandpiper',
#  'Q18840': 'Common greenshank',
#  'Q652348': 'Grey-headed gull',
#  'Q18766': 'African skimmer',
#  'Q241753': 'White-winged tern',
#  'Q512566': 'African green pigeon',
#  'Q855618': 'Speckled pigeon',
#  'Q665742': 'Afep pigeon',
#  'Q512840': 'Olive pigeon',
#  'Q1942487': 'Feral pigeon',
#  'Q849991': 'Emerald-spotted wood-dove',
#  'Q482088': 'Blue-spotted wood-dove',
#  'Q240318': 'Black-billed wood-dove',
#  'Q1272497': 'Tambourine dove',
#  'Q151851': 'Namaqua dove',
#  'Q1270179': 'Ring-necked dove',
#  'Q1072609': 'Red-eyed dove',
#  'Q113218': 'African mourning dove',
#  'Q1265602': 'Vinaceous dove',
#  'Q391198': 'Laughing dove',
#  'Q1030039': 'Dusky turtle dove',
#  'Q1048800': 'Brown parrot',
#  'Q220328': 'Grey parrot',
#  'Q845949': 'Red-headed lovebird',
#  'Q847182': 'Great blue turaco',
#  'Q1076784': "Ross's turaco",
#  'Q677291': 'White-crested turaco',
#  'Q998480': 'Black-billed turaco',
#  'Q1078923': 'Bare-faced go-away-bird',
#  'Q1061037': 'Eastern grey plantain-eater',
#  'Q839535': 'Black-and-white cuckoo',
#  'Q631863': 'Madagascar lesser cuckoo',
#  'Q639053': 'Red-chested cuckoo',
#  'Q998279': 'Black cuckoo',
#  'Q891067': 'Barred long-tailed cuckoo',
#  'Q859626': 'Dusky long-tailed cuckoo',
#  'Q519634': 'Diederik cuckoo',
#  'Q1189720': "Klaas's cuckoo",
#  'Q18956': 'African emerald cuckoo',
#  'Q1976419': 'Yellowbill',
#  'Q386116': 'White-browed coucal',
#  'Q1123893': 'Blue-headed coucal',
#  'Q749711': 'Senegal coucal',
#  'Q1263546': '[Black-throated coucal]',
#  'Q385170': 'African wood-owl',
#  'Q25317': 'BARN OWL',
#  'Q1270188': 'African scops-owl',
#  'Q675783': "Verreaux's eagle-owl",
#  'Q513224': 'Spotted eagle-owl',
#  'Q305090': 'Square-tailed nightjar',
#  'Q1186108': 'Long-tailed nightjar',
#  'Q1266857': 'Swamp nightjar',
#  'Q1259957': 'Rwenzori nightjar',
#  'Q1273020': 'Black-shouldered nightjar',
#  'Q27074770': 'Pennant-winged nightjar',
#  'Q611324': 'Little swift',
#  'Q179356': 'White-rumped swift',
#  'Q1270680': 'Horus swift',
#  'Q1261658': 'Mottled swift',
#  'Q321267': 'Alpine swift',
#  'Q25377': 'Eurasian swift',
#  'Q1266075': 'Scarce swift',
#  'Q772286': 'African palm swift',
#  'Q1263917': "Sabine's spinetail",
#  'Q1258908': "Cassin's spinetail",
#  'Q875885': 'Speckled mousebird',
#  'Q883001': 'Blue-naped mousebird',
#  'Q370629': 'Narina trogon',
#  'Q685237': 'Bar-tailed trogon',
#  'Q320043': 'Pied kingfisher',
#  'Q1269164': 'Striped kingfisher',
#  'Q1270808': 'Grey-headed kingfisher',
#  'Q731910': 'Giant kingfisher',
#  'Q838793': 'Woodland kingfisher',
#  'Q247996': 'Blue-breasted kingfisher',
#  'Q1274112': 'Chocolate-backed kingfisher',
#  'Q1072218': 'Malachite kingfisher',
#  'Q244227': 'African pygmy-kingfisher',
#  'Q27074797': 'African dwarf-kingfisher',
#  'Q143155': 'Shining-blue kingfisher',
#  'Q244368': 'Little bee-eater',
#  'Q572042': 'Cinnamon-chested bee-eater',
#  'Q1123941': 'Blue-breasted bee-eater',
#  'Q746422': 'White-throated bee-eater',
#  'Q576802': 'Swallow-tailed bee-eater',
#  'Q512931': 'Black bee-eater',
#  'Q738736': 'Madagascar bee-eater',
#  'Q569251': 'Red-throated bee-eater',
#  'Q1071843': 'Northern carmine bee-eater',
#  'Q204154': 'Broad-billed roller',
#  'Q546599': 'Blue-throated roller',
#  'Q44023': 'Lilac-breasted roller',
#  'Q811583': 'Green wood-hoopoe',
#  'Q285978': 'Forest wood-hoopoe',
#  'Q839945': 'Black scimitarbill',
#  'Q27074817': 'African grey hornbill',
#  'Q27074811': 'Crowned hornbill',
#  'Q226128': 'African pied hornbill',
#  'Q746019': 'Piping hornbill',
#  'Q27074818': 'Red-billed dwarf hornbill',
#  'Q27074823': 'White-crested hornbill',
#  'Q1083466': 'Black-and-white casqued hornbill',
#  'Q797575': 'White-thighed hornbill',
#  'Q998706': 'Black-casqued wattled hornbill',
#  'Q480086': 'Abyssinian ground-hornbill',
#  'Q1305169': 'Yellow-rumped tinkerbird',
#  'Q1262157': 'Yellow-throated tinkerbird',
#  'Q971880': 'Red-rumped tinkerbird',
#  'Q1162850': 'Western green tinkerbird',
#  'Q978052': 'Speckled tinkerbird',
#  'Q578615': 'Grey-throated barbet',
#  'Q592146': 'Yellow-fronted tinkerbird',
#  'Q1208057': 'Spot-flanked barbet',
#  'Q1261981': 'Hairy-breasted barbet',
#  'Q5734788': 'Yellow-spotted barbet',
#  'Q220061': 'White-headed barbet',
#  'Q1266242': 'Black-billed barbet',
#  'Q767501': 'Red-faced barbet',
#  'Q1243481': 'Double-toothed barbet',
#  'Q978817': 'Yellow-billed barbet',
#  'Q593582': 'Greater honeyguide',
#  'Q1260894': 'Lesser honeyguide',
#  'Q1264511': "Willcock's honeyguide",
#  'Q1259052': 'Least honeyguide',
#  'Q1261971': "Tullberg's woodpecker",
#  'Q1262753': 'Buff-spotted woodpecker',
#  'Q901647': 'Brown-eared woodpecker',
#  'Q1268301': 'Nubian woodpecker',
#  'Q606886': 'Cardinal woodpecker',
#  'Q973779': 'Speckle-breasted woodpecker',
#  'Q903962': 'Yellow-crested woodpecker',
#  'Q25037273': 'Grey woodpecker',
#  'Q1263488': 'Olive woodpecker',
#  'Q1061425': 'African broadbill',
#  'Q902125': 'Rufous-sided broadbill',
#  'Q941526': '[African green broadbill]',
#  'Q1060851': 'Rufous-naped lark',
#  'Q1591286': 'Flappet lark',
#  'Q1591642': 'Red-capped lark',
#  'Q25252247': 'Rock martin',
#  'Q675850': 'Plain martin',
#  'Q1589557': 'Banded martin',
#  'Q3136315': 'Mosque swallow',
#  'Q781535': 'Rufous-chested swallow',
#  'Q1589215': 'Lesser striped swallow',
#  'Q25429': 'BARN SWALLOW',
#  'Q547224': 'Angola swallow',
#  'Q375793': 'Wire-tailed swallow',
#  'Q1589225': 'Black saw-wing',
#  'Q3136337': 'White-headed saw-wing',
#  'Q530069': 'African pied wagtail',
#  'Q386467': 'Cape wagtail',
#  'Q902416': 'Yellow-throated longclaw',
#  'Q995602': 'Grassland pipit',
#  'Q3726273': 'Plain-backed pipit',
#  'Q1306580': 'Black cuckoo-shrike',
#  'Q1587203': 'Red-shouldered cuckoo-shrike',
#  'Q3233149': 'Purple-throated cuckoo-shrike',
#  'Q3233100': "Petit's cuckoo-shrike",
#  'Q869051': 'Grey cuckoo-shrike',
#  'Q2225082': 'Western nicator',
#  'Q2225220': '[Yellow-throated nicator]',
#  'Q221999': 'Common bulbul',
#  'Q1923208': 'Yellow-whiskered greenbul',
#  'Q25249305': 'Little greenbul',
#  'Q2225392': 'Mountain greenbul',
#  'Q509595': 'Slender-billed greenbul',
#  'Q745569': "Shelley's greenbul",
#  'Q1589185': 'Yellow-streaked greenbul',
#  'Q2927894': "Cabanis's greenbul",
#  'Q514517': "Ansorge's greenbul",
#  'Q27075431': 'Little grey greenbul',
#  'Q2927902': 'Toro olive greenbul',
#  'Q2224205': 'Cameroon sombre greenbul',
#  'Q2927906': 'Icterine greenbul',
#  'Q1588687': "Xavier's greenbul",
#  'Q2927908': 'Joyful greenbul',
#  'Q765614': 'Red-tailed bristlebill',
#  'Q2387330': '[Green-tailed bristlebill]',
#  'Q2224861': 'Red-tailed greenbul',
#  'Q2235459': 'White-throated greenbul',
#  'Q55643932': 'Yellow-throated greenbul',
#  'Q2384003': 'Swamp palm bulbul',
#  'Q2927922': 'Honeyguide greenbul',
#  'Q1587108': 'Spotted greenbul',
#  'Q1585695': 'White-starred robin',
#  'Q1923517': 'Equatorial akalat',
#  'Q15198021': 'Forest robin',
#  'Q28807860': 'Brown-chested alethe',
#  'Q28808096': 'Red-throated alethe',
#  'Q4763250': 'Fire-crested alethe',
#  'Q2673576': 'Cape robin-chat',
#  'Q222081': 'White-browed robin-chat',
#  'Q3314657': 'Blue-shouldered robin-chat',
#  'Q3315420': 'Snowy-headed robin-chat',
#  'Q1589176': 'Red-capped robin-chat',
#  'Q3728578': "Archer's robin",
#  'Q1300873': 'White-bellied robin-chat',
#  'Q1002576': 'Olive thrush',
#  'Q513026': 'African thrush',
#  'Q4752804': 'Kivu ground-thrush',
#  'Q2226198': 'White-tailed ant-thrush',
#  'Q2226078': 'Red-tailed ant-thrush',
#  'Q3729315': 'Sooty chat',
#  'Q1315689': 'African stonechat',
#  'Q2225549': 'White-browed scrub-robin',
#  'Q2827233': 'Brown-backed scrub-robin',
#  'Q3315817': 'Spotted mourning-thrush',
#  'Q2667934': 'Dark-capped yellow warbler',
#  'Q2225880': 'Mountain yellow warbler',
#  'Q3727635': 'Lesser reed warbler',
#  'Q1589801': '[Greater swamp warbler]',
#  'Q2667981': 'African reed warbler',
#  'Q529238': 'White-winged warbler',
#  'Q735178': 'Cinnamon bracken warbler',
#  'Q1587032': 'Little rush warbler',
#  'Q3726967': 'Buff-bellied warbler',
#  'Q2667807': 'Uganda woodland warbler',
#  'Q3049757': 'Red-faced woodland warbler',
#  'Q2668148': 'Green hylia',
#  'Q1304946': 'White-browed crombec',
#  'Q1311190': 'Green crombec',
#  'Q1310521': 'Lemon-bellied crombec',
#  'Q1923030': 'Yellow longbill',
#  'Q1310302': 'Grey longbill',
#  'Q1304970': 'Northern crombec',
#  'Q2225479': 'Red-faced crombec',
#  'Q1315461': 'Rufous-crowned eromomela',
#  'Q2667998': 'Black-faced rufous warbler',
#  'Q788834': 'African moustached warbler',
#  'Q2100563': "Grauer's warbler",
#  'Q210791': 'Zitting cisticola',
#  'Q2226487': 'Stout cisticola',
#  'Q3726434': 'Croaking cisticola',
#  'Q2225630': 'Rattling cisticola',
#  'Q12255852': 'Winding cisticola',
#  'Q2669965': "Carruther's cisticola",
#  'Q3726427': 'Singing cisticola',
#  'Q1590193': 'Red-faced cisticola',
#  'Q3319526': "Chubb's cisticola",
#  'Q2225357': 'Trilling cisticola',
#  'Q3726447': 'Whistling cisticola',
#  'Q2225661': 'Siffling cisticola',
#  'Q1923463': 'Foxy cisticola',
#  'Q2470259': 'Red-winged grey warbler',
#  'Q3726284': 'Tawny-flanked prinia',
#  'Q1923187': 'White-chinned prinia',
#  'Q2226833': 'Banded prinia',
#  'Q2512467': 'Grey-capped warbler',
#  'Q2934644': 'Grey-backed camaroptera',
#  'Q3314790': 'Olive-green camaroptera',
#  'Q2667896': 'Yellow-browed camaroptera',
#  'Q2225511': 'Yellow-breasted apalis',
#  'Q2225165': 'Grey apalis',
#  'Q3318122': 'Chestnut-throated apalis',
#  'Q2225602': 'Buff-throated apalis',
#  'Q2225589': 'Black-throated apalis',
#  'Q2225525': 'Mountain masked apalis',
#  'Q1310915': 'Black-capped apalis',
#  'Q681674': 'White-eyed slaty flycatcher',
#  'Q1315514': 'Northern black flycatcher',
#  'Q1306151': 'Yellow-eyed black-flycatcher',
#  'Q1318056': 'Pale flycatcher',
#  'Q2229871': 'Ashy flycatcher',
#  'Q841997': 'African dusky flycatcher',
#  'Q907188': 'Swamp flycatcher',
#  'Q905975': "Cassin's grey flycatcher",
#  'Q2226068': 'Dusky-blue flycatcher',
#  'Q1311755': 'Sooty flycatcher',
#  'Q1305836': 'Forest flycatcher',
#  'Q1317349': 'Chin-spot batis',
#  'Q55643630': 'Black-headed batis',
#  'Q1308363': 'African shrike-flycatcher',
#  'Q3575048': 'Black-and-white shrike-flycatcher',
#  'Q1923019': 'Brown-throated wattle-eye',
#  'Q1315092': 'Chestnut wattle-eye',
#  'Q1317426': "Jameson's wattle-eye",
#  'Q3729668': 'Yellow-bellied wattle-eye',
#  'Q541440': 'African paradise flycatcher',
#  'Q165856': 'Red-bellied paradise-flycatcher',
#  'Q1302067': 'Silverbird',
#  'Q1308728': 'White-tailed crested-flycatcher',
#  'Q2224805': 'White-bellied crested-flycatcher',
#  'Q3051593': 'African blue-flycatcher',
#  'Q840098': 'White-tailed blue-flycatcher',
#  'Q1305790': 'Chestnut-capped flycatcher',
#  'Q2828924': 'Scaly-breasted illadopsis',
#  'Q2828919': 'Mountain illadopsis',
#  'Q2828915': 'Brown illadopsis',
#  'Q2828923': 'Pale-breasted illadopsis',
#  'Q1303267': "Puvel's illadopsis",
#  'Q1588046': 'African hill-babbler',
#  'Q900701': 'Arrow-marked babbler',
#  'Q1091324': 'Brown babbler',
#  'Q2226307': 'Black-lored babbler',
#  'Q27075381': 'Dusky tit',
#  'Q27075368': 'White-shouldered tit',
#  'Q27075389': 'Stripe-breasted tit',
#  'Q108303244': 'Yellow-white-eye',
#  'Q849992': 'Bronze sunbird',
#  'Q767069': 'Green-headed sunbird',
#  'Q1923333': 'Blue-throated brown sunbird',
#  'Q1312406': 'Blue-headed sunbird',
#  'Q3180327': 'Northern double-collared sunbird',
#  'Q2226012': 'Olive-bellied sunbird',
#  'Q2668527': 'Regal sunbird',
#  'Q2226121': 'Green-throated sunbird',
#  'Q31874225': 'Green sunbird',
#  'Q1083204': 'Olive sunbird',
#  'Q1930587': 'Little green sunbird',
#  'Q1923685': 'Grey-headed sunbird',
#  'Q3182685': 'Copper sunbird',
#  'Q1924045': 'Superb sunbird',
#  'Q1302897': 'Marico sunbird',
#  'Q2669185': 'Purple-banded sunbird',
#  'Q854678': 'Scarlet-chested sunbird',
#  'Q2225977': 'Beautiful sunbird',
#  'Q3175616': 'Red-chested sunbird',
#  'Q2209523': 'Variable sunbird',
#  'Q839914': 'Collared sunbird',
#  'Q15946831': 'Common fiscal',
#  'Q1087308': 'Grey-backed fiscal',
#  'Q944057': "Mackinnon's fiscal",
#  'Q16069857': 'Tropical boubou',
#  'Q1029743': 'Black-headed gonolek',
#  'Q1313273': 'Papyrus gonolek',
#  'Q267852': 'Mountain black boubou',
#  'Q1304928': 'Sooty boubou',
#  'Q1302770': 'Northern puffback',
#  'Q1028431': 'Pink-footed puffback',
#  'Q1317767': 'Black-crowned tchagra',
#  'Q1317356': 'Brown-crowned tchagra',
#  'Q27075300': 'Marsh tchagra',
#  'Q27075295': 'Sulphur-breasted bush-shrike',
#  'Q570351': 'Grey-headed bush-shrike',
#  'Q1304987': "[Lagden's bush-shrike]",
#  'Q1305539': "Doherty's bush-shrike",
#  'Q742259': 'Fork-tailed drongo',
#  'Q10638791': 'Velvet-mantled drongo',
#  'Q386672': 'Piapiac',
#  'Q949603': 'Pied crow',
#  'Q907903': 'White-naped raven',
#  'Q1589193': 'African black-headed oriole',
#  'Q1585741': 'Western black-headed oriole',
#  'Q923010': 'African golden oriole',
#  'Q1466229': 'Yellow-billed oxpecker',
#  'Q3315578': "Stuhlmann's starling",
#  'Q3316811': 'Narrow-tailed starling',
#  'Q3315211': "Waller's starling",
#  'Q240445': 'Greater blue-eared starling',
#  'Q948103': 'Lesser blue-eared starling',
#  'Q21283067': 'Purple-headed starling',
#  'Q694756': 'Violet-backed starling',
#  'Q27075613': "Sharpe's starling",
#  'Q301731': 'Wattled starling',
#  'Q1316034': 'Rufous sparrow',
#  'Q264067': 'Speckle-fronted weaver',
#  'Q1316022': 'Grey-headed sparrow',
#  'Q687079': 'White-browed sparrow-weaver',
#  'Q1930599': 'Chestnut-crowned sparrow-weaver',
#  'Q998572': 'Yellow-backed weaver',
#  'Q842532': 'Lesser masked weaver',
#  'Q787215': 'Vitelline weaver',
#  'Q1310295': 'Northern masked weaver',
#  'Q769979': 'Spectacled weaver',
#  'Q789977': 'Black-necked weaver',
#  'Q743623': 'Baglafecht weaver',
#  'Q426384': 'Grosbeak weaver',
#  'Q244430': 'Little weaver',
#  'Q842317': 'Slender-billed weaver',
#  'Q1310015': 'Northern brown-throated weaver',
#  'Q1307705': 'Compact weaver',
#  'Q906551': "Holub's golden weaver",
#  'Q1311031': "Weyn's weaver",
#  'Q374831': 'Strange weaver',
#  'Q1311967': 'Brown-capped weaver',
#  'Q1304413': 'Yellow-mantled weaver',
#  'Q1303370': 'Black-billed weaver',
#  'Q639676': "Viellot's black weaver",
#  'Q367327': 'Red-billed quelea',
#  'Q1301031': 'Cardinal quelea',
#  'Q1301039': 'Red-headed quelea',
#  'Q727989': 'Red-headed weaver',
#  'Q1305588': 'Red-headed malimbe',
#  'Q917082': 'Crested malimbe',
#  'Q771580': 'Blue-billed malimbe',
#  'Q1304745': 'Red-collared widowbird',
#  'Q1304712': 'Fan-tailed widowbird',
#  'Q1304641': 'Black bishop',
#  'Q1305603': 'Yellow bishop',
#  'Q1305633': 'Yellow-mantled widowbird',
#  'Q183396': 'Red bishop',
#  'Q645528': 'Northern red bishop',
#  'Q1303122': 'Black-winged red bishop',
#  'Q1049477': 'Grey-headed negro-finch',
#  'Q572702': 'White-breasted negrofinch',
#  'Q603124': 'Green-winged pytilia',
#  'Q777355': 'Red-winged pytilia',
#  'Q930595': 'Grey-headed oliveback',
#  'Q681730': 'Brown twinspot',
#  'Q582282': 'Dusky crimsonwing',
#  'Q539591': 'Red-headed bluebill',
#  'Q854633': 'Black-bellied seedcracker',
#  'Q1070293': 'Red-cheeked cordonbleu',
#  'Q560326': 'Red-billed firefinch',
#  'Q1077355': 'African firefinch',
#  'Q1049505': 'Bar-breasted firefinch',
#  'Q27075727': 'Yellow-bellied waxbill',
#  'Q583220': 'Common waxbill',
#  'Q720648': 'Black-rumped waxbill',
#  'Q1049513': 'Fawn-breasted waxbill',
#  'Q774288': 'Black-crowned waxbill',
#  'Q998690': 'Black-headed waxbill',
#  'Q56899': 'Black-faced waxbill',
#  'Q1300907': 'Bronze mannikin',
#  'Q1300584': 'Black-and-white mannikin',
#  'Q932447': 'Magpie mannikin',
#  'Q908340': 'Pin-tailed whydah',
#  'Q941573': 'Village indigobird',
#  'Q27075838': 'Brimstone canary',
#  'Q27075822': 'Yellow-fronted canary',
#  'Q1061889': 'Yellow-crowned canary',
#  'Q27075844': 'Thick-billed seedeater',
#  'Q27075797': 'African citril',
#  'Q27075807': 'White-rumped seedeater',
#  'Q27075845': 'Streaky seedeater',
#  'Q1302206': 'Oriole finch',
#  'Q1034950': 'Cinnamon-breasted rock bunting',
#  'Q901933': 'African golden-breasted bunting',
#  'Q1302962': 'Brown-rumped bunting',
#  'Q2668354': "Cabanis's bunting",
#  'Q262': 'Algeria',
#  'Q916': 'Angola',
#  'Q962': 'Benin',
#  'Q963': 'Botswana',
#  'Q965': 'Burkina Faso',
#  'Q967': 'Burundi',
#  'Q1009': 'Cameroon',
#  'Q1011': 'Cape Verde',
#  'Q929': 'Central African Republic',
#  'Q657': 'Chad',
#  'Q970': 'Comoros',
#  'Q974': 'Congo, Democratic Republic of the',
#  'Q971': 'Congo, Republic of the',
#  'Q1008': "Cote d'Ivoire",
#  'Q977': 'Djibouti',
#  'Q79': 'Egypt',
#  'Q983': 'Equatorial Guinea',
#  'Q986': 'Eritrea',
#  'Q115': 'Ethiopia',
#  'Q1000': 'Gabon',
#  'Q1005': 'Gambia, The',
#  'Q117': 'Ghana',
#  'Q1006': 'Guinea',
#  'Q1007': 'Guinea-Bissau',
#  'Q114': 'Kenya',
#  'Q1013': 'Lesotho',
#  'Q1014': 'Liberia',
#  'Q1016': 'Libya',
#  'Q1019': 'Madagascar',
#  'Q1020': 'Malawi',
#  'Q912': 'Mali',
#  'Q1025': 'Mauritania',
#  'Q1027': 'Mauritius',
#  'Q1028': 'Morocco',
#  'Q1029': 'Mozambique',
#  'Q1030': 'Namibia',
#  'Q1032': 'Niger',
#  'Q1033': 'Nigeria',
#  'Q1037': 'Rwanda',
#  'Q1041': 'Senegal',
#  'Q1042': 'Seychelles',
#  'Q1044': 'Sierra Leone',
#  'Q1045': 'Somalia',
#  'Q258': 'South Africa',
#  'Q1049': 'Sudan',
#  'Q924': 'Tanzania',
#  'Q945': 'Togo',
#  'Q948': 'Tunisia',
#  'Q1036': 'Uganda',
#  'Q953': 'Zambia',
#  'Q954': 'Zimbabwe',
#  'Q9626': 'Conservative',
#  'Q9630': 'Labour',
#  'Q6540612': 'Lib-Dem',
#  'Q10658': 'SNP',
#  'Q10691': 'PC',
#  'Q9669': 'Green',
#  'Q161269': 'BNP',
#  'Q10647': 'UKIP',
#  'Q6393870': 'Keri L Hehn',
#  'Q3526438': 'Newport',
#  'Q16213808': 'Thomas',
#  'Q5528173': 'Haynes',
#  'Q7626741': 'Lampitt',
#  'Q12989015': 'Solanki',
#  'Q7182539': 'Weston',
#  'Q7194441': 'Pilot Mountain',
#  'Q219508': 'Citigroup',
#  'Q487907': 'Bank of America',
#  'Q190464': 'HSBC Holdings',
#  'Q54173': 'General Electric',
#  'Q192314': 'JP Morgan',
#  'Q212235': 'AIG',
#  'Q156238': 'ExxonMobil',
#  'Q50579513': 'Royal Dutch Shell',
#  'Q193199': 'UBS',
#  'Q645708': 'ING',
#  'Q152057': 'BP',
#  'Q53268': 'Toyota Motor',
#  'Q160126': 'Royal Bank of Scotland',
#  'Q499707': 'BNP Paribas',
#  'Q487292': 'Allianz',
#  'Q217583': 'Berkshire Hathaway',
#  'Q483551': 'Wal-Mart Stores',
#  'Q245343': 'Barclays',
#  'Q319642': 'Chevron',
#  'Q2345': '12 Angry Men',
#  'Q103474': '2001: A Space Odyssey',
#  'Q501105': 'The 39 Steps',
#  'Q162331': 'The 400 Blows',
#  'Q201234': 'The Adventures of Robin Hood',
#  'Q384397': 'The African Queen',
#  'Q325662': 'Aguirre: The Wrath of God',
#  'Q497256': 'Airplane!',
#  'Q215518': 'Aladdin',
#  'Q103569': 'Alien',
#  'Q104814': 'Aliens',
#  'Q200299': 'All about Eve',
#  'Q272599': 'All Quiet on the Western Front',
#  'Q466781': "All the President's Men",
#  'Q726294': 'Almost Famous',
#  'Q190956': 'Amadeus',
#  'Q18428': 'Amarcord',
#  'Q1774631': 'American Beauty',
#  'Q375855': 'American Graffiti',
#  'Q208572': 'American History X',
#  'Q474098': 'Amores perros',
#  'Q503046': 'Andrei Rublev',
#  'Q960125': 'Animal House',
#  'Q233464': 'Annie Hall',
#  'Q270510': 'The Apartment',
#  'Q182692': 'Apocalypse Now',
#  'Q106428': 'Apollo 13',
#  'Q208344': 'Armageddon',
#  'Q471992': 'Army of Darkness',
#  'Q59317': 'Arsenic and Old Lace',
#  'Q221594': 'As Good as It Gets',
#  'Q780016': "L'Atalante",
#  'Q501703': 'Austin Powers: International Man Of Mystery',
#  'Q514531': "L'Avventura",
#  'Q720724': 'Babe',
#  'Q91540': 'Back to the Future',
#  'Q109331': 'Back to the Future Part II',
#  'Q230552': 'Back to the Future Part III',
#  'Q799202': 'Badlands',
#  'Q471716': 'Barry Lyndon',
#  'Q237215': 'Barton Fink',
#  'Q116852': 'Batman',
#  'Q166262': 'Batman Begins',
#  'Q189054': 'Batman Returns',
#  'Q152350': 'The Battleship Potemkin',
#  'Q164103': 'A Beautiful Mind',
#  'Q179673': 'Beauty and the Beast',
#  'Q649165': 'Being John Malkovich',
#  'Q945074': 'Being There',
#  'Q470375': 'Belle de Jour',
#  'Q180098': 'Ben-Hur',
#  'Q645094': 'The Best Years of Our Lives',
#  'Q172837': 'The Bicycle Thief',
#  'Q278997': 'Big Fish',
#  'Q337078': 'The Big Lebowski',
#  'Q1137931': 'The Big Sleep',
#  'Q110043': 'The Birds',
#  'Q220394': 'The Birth of a Nation',
#  'Q221384': 'Black Hawk Down',
#  'Q184843': 'Blade Runner',
#  'Q644554': 'Blair Witch Project',
#  'Q957323': 'Blazing Saddles',
#  'Q237222': 'Blood Simple',
#  'Q658204': 'Blow-Up',
#  'Q660950': 'Blue Velvet',
#  'Q109767': 'The Blues Brothers',
#  'Q181776': 'Bonnie and Clyde',
#  'Q291170': 'Boogie Nights',
#  'Q62730': 'Das Boot',
#  'Q471159': 'Born On The Fourth Of July',
#  'Q165394': 'Bowling For Columbine',
#  'Q896103': 'Boyz N the Hood',
#  'Q162729': 'Braveheart',
#  'Q25057': 'Brazil',
#  'Q193066': "Breakfast at Tiffany's",
#  'Q499152': 'The Breakfast Club',
#  'Q538412': 'Breaking the Waves',
#  'Q86427': 'Breathless',
#  'Q875904': 'Bride of Frankenstein',
#  'Q188718': 'The Bridge on the River Kwai',
#  'Q814296': 'Brief Encounter',
#  'Q179743': 'Bringing Up Baby',
#  'Q232000': 'Butch Cassidy and the Sundance Kid',
#  'Q251559': 'The Treasure of the Sierra Madre',
#  'Q488655': 'Groundhog Day',
#  'Q217189': 'The Seventh Seal',
#  'Q135465': 'Rash?mon',
#  'Q1125566': 'Duck Soup',
#  'Q238211': 'City Lights',
#  'Q1141252': 'Do the Right Thing',
#  'Q273978': 'Crouching Tiger, Hidden Dragon',
#  'Q731310': 'Manhattan',
#  'Q175038': 'Twelve Monkeys',
#  'Q109135': 'Trainspotting',
#  'Q747936': 'Paths of Glory',
#  'Q487181': 'Requiem For A Dream',
#  'Q188845': 'Rain Man',
#  'Q7810384': 'This Is Spinal Tap',
#  'Q20456': 'Dances with Wolves',
#  'Q565231': 'Ran',
#  'Q866120': 'Mr. Smith Goes to Washington',
#  'Q272608': 'Mulholland Drive',
#  'Q245208': 'High Noon',
#  'Q151599': 'Metropolis',
#  'Q110354': 'Great Escape',
#  'Q185658': 'Indiana Jones And The Last Crusade',
#  'Q62665': 'The Sting',
#  'Q45602': 'Modern Times',
#  'Q193835': 'Good Will Hunting',
#  'Q458656': 'Dog Day Afternoon',
#  'Q309048': 'King Kong',
#  'Q107871488': 'Clerks.',
#  'Q212129': 'A Streetcar Named Desire',
#  'Q19355': 'Life Is Beautiful',
#  'Q426346': 'Rebel without a Cause',
#  'Q639481': 'Ed Wood',
#  'Q214801': 'Truman Show , The',
#  'Q651923': 'Young Frankenstein',
#  'Q684150': 'Cool Hand Luke',
#  'Q272860': 'The Elephant Man',
#  'Q108525': 'Untouchables, The',
#  'Q217220': 'Patton',
#  'Q498906': "Ferris Bueller's Day Off",
#  'Q208632': 'It Happened One Night',
#  'Q1009788': 'The Conversation',
#  'Q498822': 'The Philadelphia Story',
#  'Q862317': 'Glory',
#  'Q206388': 'Once Upon a Time in America',
#  'Q676039': 'The Grapes of Wrath',
#  'Q670439': 'Raising Arizona',
#  'Q1132629': 'The Night of the Hunter',
#  'Q494722': 'Stand by Me',
#  'Q499639': 'Strangers on a Train',
#  'Q587419': 'Notorious',
#  'Q60072': 'The Sound of Music',
#  'Q204212': 'Rebecca',
#  'Q220910': 'Casino',
#  'Q208263': 'The Green Mile',
#  'Q841335': 'Mean Streets',
#  'Q193573': 'Moulin Rouge!',
#  'Q24953': "Monty Python's Life of Brian",
#  'Q221103': 'Halloween',
#  'Q108745': 'Ghostbusters',
#  'Q165325': 'Kill Bill: Vol. 1',
#  'Q156309': 'The Fugitive',
#  'Q220741': 'City of God',
#  'Q59534': 'Planet of the Apes',
#  'Q192656': 'Fantasia',
#  'Q517958': 'Field of Dreams',
#  'Q220735': 'The French Connection',
#  'Q468697': 'Run Lola Run',
#  'Q748599': 'The Rules of the Game',
#  'Q108297': 'Spartacus',
#  'Q426828': 'Donnie Darko',
#  'Q217182': 'Edward Scissorhands',
#  'Q695255': 'Persona',
#  'Q51520': 'The Passion of Joan of Arc',
#  'Q18407': 'La Dolce Vita',
#  'Q6986833': 'H Neely Henry Lake *',
#  'Q6667090': 'Logan Martin Lake',
#  'Q7356569': 'Weiss Lake',
#  'Q5568564': 'Gleniffer Lake',
#  'Q23902089': 'Alamo Lake',
#  'Q809448': 'Bartlett Reservoir',
#  'Q4929737': 'Blue Ridge Reservoir',
#  'Q4878104': 'Beaver Lake',
#  'Q5243909': 'DeGray Lake',
#  'Q5605148': 'Greers Ferry Lake',
#  'Q6476037': 'Greeson, Lake',
#  'Q5049578': 'Castaic Lake Also includes Pyramid Lake, CA',
#  'Q3026102': 'Diamond Valley Lake',
#  'Q5350930': 'El Capitan Lake',
#  'Q964060': 'Isabella Lake',
#  'Q6676191': 'Lopez Lake * Also includes Santa Margarita Lake, CA',
#  'Q14683212': 'Loveland Reservoir *',
#  'Q6477350': 'Perris Reservoir',
#  'Q7263254': 'Pyramid Lake (updated 04/18/2005) Also includes Castaic Lake, CA',
#  'Q7361593': 'San Vicente Reservoir *',
#  'Q7335181': 'Santa Margarita Lake * Also includes Lopez Lake, CA',
#  'Q885767': 'Blue Mesa Reservoir Also includes Morrow Point Reservoir, CO',
#  'Q5276944': 'Dillon Reservoir *',
#  'Q1915342': 'McPhee Reservoir',
#  'Q6914209': 'Morrow Point Reservoir Also includes Blue Mesa Reservoir, CO',
#  'Q6476633': 'Lillinonah, Lake',
#  'Q1793276': 'Istokpoga, Lake Also includes Lake Jackson, FL, Lake June In Winter, FL, and Lake Huntley, FL',
#  'Q6665139': 'Lochloosa Lake Also includes most of Orange Lake, FL',
#  'Q7347900': 'Monroe, Lake',
#  'Q6477148': 'Nottely Lake *',
#  'Q6477167': 'Oconee, Lake',
#  'Q6477788': 'Sinclair, Lake',
#  'Q3295796': 'Sydney Lanier, Lake',
#  'Q6478054': 'Tobesofkee, Lake *',
#  'Q5134179': 'Clinton Lake',
#  'Q4905822': 'Big Hill Lake * (updated 01/23/2006)',
#  'Q7334450': 'Tuttle Creek Lake',
#  'Q6499960': 'Laurel River Lake',
#  'Q7333347': 'Taylorsville Lake',
#  'Q1124827': 'Quabbin Reservoir',
#  'Q5617732': 'Gull Lake',
#  'Q2229019': 'Moose Lake',
#  'Q4791648': 'Arkabutla Lake',
#  'Q768090': 'Enid Lake',
#  'Q7332416': 'Truman Reservoir',
#  'Q6475743': 'Elwell, Lake',
#  'Q5658289': 'Harlan County Lake',
#  'Q6476575': 'Las Vegas, Lake',
#  'Q6820181': 'Merrill Creek Reservoir',
#  'Q4667899': 'Abiquiu Reservoir',
#  'Q3825751': 'Onondaga Lake',
#  'Q4491409': 'Falls Lake',
#  'Q1485910': 'James, Lake * NEW',
#  'Q1794421': 'Wylie, Lake *',
#  'Q4737332': 'Alum Creek Lake Also includes Delaware Lake, OH and Hoover Reservoir, OH',
#  'Q4818871': 'Atwood Lake Also includes Leesville Lake, OH',
#  'Q4884386': 'Belmont Lake',
#  'Q5000329': 'Burr Oak Lake',
#  'Q5080941': 'Charles Mill Lake',
#  'Q14716460': 'Hoover Reservoir Also includes Alum Creek Lake, OH and Delaware Lake, OH',
#  'Q977342': 'Indian Lake',
#  'Q6460706': 'LaDue Reservoir Also includes Punderson Lake, OH',
#  'Q6516488': 'Leesville Lake Also includes Atwood Lake, OH',
#  'Q6477796': 'Snowden, Lake',
#  'Q7619267': 'Stonelick Lake',
#  'Q6474755': 'Altus Lugert Lake',
#  'Q7331349': 'Arbuckle Reservoir',
#  'Q4785154': 'Arcadia Lake',
#  'Q6474858': 'Atoka Reservoir * Also includes McGee Creek Reservoir, OK',
#  'Q4915674': 'Birch Lake',
#  'Q4973329': 'Broken Bow Lake',
#  'Q22829014': 'Canton Lake',
#  'Q6475794': 'Eucha, Lake',
#  'Q5470942': 'Fort Cobb Reservoir',
#  'Q14708421': 'Foss Lake',
#  'Q8009398': 'Frederick Lake',
#  'Q81295': 'Hefner, Lake',
#  'Q14708456': 'Hulah Lake',
#  'Q5934117': 'Hugo Lake',
#  'Q7331172': 'Kaw lake',
#  'Q7348418': 'Kerr Reservoir',
#  'Q6398477': 'Keystone Lake *',
#  'Q7331388': 'Konawa Reservoir',
#  'Q6801233': 'McGee Creek Reservoir (updated 06/08/2005) Also includes Atoka Reservoir, OK',
#  'Q7095321': 'Oologah Lake * (updated 08/16/2004)',
#  'Q6477258': 'Overholser, Lake',
#  'Q7195113': 'Pine Creek Lake',
#  'Q7348439': 'Sardis Lake',
#  'Q7332880': 'Skiatook Lake * (updated 08/16/2004)',
#  'Q14708681': 'Sooner Lake',
#  'Q7372589': 'Spavinaw Lake',
#  'Q6477830': 'Stanley Draper Lake',
#  'Q7331354': 'Tenkiller Lake',
#  'Q6478032': 'Thunderbird, Lake',
#  'Q7331395': 'Tom Steed Reservoir',
#  'Q14708706': 'Webbers Falls Reservoir',
#  'Q7331396': 'Wes Watkins Reservoir',
#  'Q3457703': 'Wickiup Reservoir',
#  'Q6476437': 'Keowee, Lake',
#  'Q859342': 'Big Stone Lake',
#  'Q5471549': 'Fort Loudoun Lake (updated 06/07/2004)',
#  'Q7167526': 'J Percy Priest Reservoir (updated 06/07/2004)',
#  'Q4737878': 'Alvarado Park Lake',
#  'Q1634424': 'Amistad, Lake *',
#  'Q7352879': 'Arrowhead, Lake',
#  'Q6474929': 'Bastrop, Lake *',
#  'Q4884777': 'Belton Lake Also includes Stillhouse Hollow Lake, TX',
#  'Q4955178': 'Brady Creek Reservoir *',
#  'Q6475066': 'Bridgeport, Lake',
#  'Q4985715': 'Buffalo Creek Reservoir *',
#  'Q6475197': 'Casa Blanca, Lake *',
#  'Q5056639': 'Cedar Creek Reservoir *',
#  'Q178970': 'Cherokee, Lake',
#  'Q5628067': 'Clyde, Lake',
#  'Q6194143': 'Cooper Lake',
#  'Q6475467': 'Corpus Christi, Lake',
#  'Q5321673': 'E V Spence, Lake *',
#  'Q5325169': 'Eagle Mountain Lake',
#  'Q6475983': 'Georgetown, Lake',
#  'Q5558905': 'Gibbons Creek Reservoir',
#  'Q6476027': 'Granbury, Lake *',
#  'Q6476187': 'Holbrook, Lake * Also includes Lake Fork Reservoir, TX and Lake Quitman, TX',
#  'Q6476449': 'Kickapoo, Lake',
#  'Q7332263': 'Lake Fork Reservoir * (updated 05/02/2005) Also includes Lake Holbrook, TX and Lake Quitman, TX',
#  'Q7331563': 'Limestone, Lake',
#  'Q6683977': 'Lost Creek Lake *',
#  'Q1800987': 'Lyndon B Johnson, Lake *',
#  'Q7331509': 'McQueeney, Lake *',
#  'Q6477074': 'Nasworthy, Lake * Also includes Twin Buttes Reservoir, TX',
#  'Q6477123': 'Nocona, Lake',
#  'Q6477163': "O' the Pines, Lake (updated on 06/07/2004)",
#  'Q7143711': 'Pat Mayse Lake',
#  'Q7303773': 'Red Bluff Reservoir *',
#  'Q7330607': 'Richland Chambers Reservoir',
#  'Q2277870': 'Sheldon Reservoir *',
#  'Q7331554': 'Somerville Lake',
#  'Q7336801': 'Stillhouse Hollow Lake Also includes Belton Lake, TX',
#  'Q6478013': 'Texana, Lake',
#  'Q7361482': 'Twin Buttes Reservoir Also includes Lake Nasworthy, TX',
#  'Q491288': 'Tyler, Lake',
#  'Q6478348': 'Waco Lake',
#  ...}

# %%
WD_query_type = {
    value[0].split('/')[-1]: value[1].split('/')[-1]
    for value in combined_dict.values()
}

WD_query_type
# Out:
# {'Q663665': 'VideoGame',
#  'Q4390981': 'Saint',
#  'Q1781530': 'Museum',
#  'Q25193623': 'Film',
#  'Q459477': 'Company',
#  'Q817': 'Country',
#  'Q9669': 'PoliticalParty',
#  'Q208875': 'Newspaper',
#  'Q7626741': 'Cricketer',
#  'Q831445': 'Company',
#  'Q69581': 'Animal',
#  'Q135465': 'Film',
#  'Q575014': 'Film',
#  'Q5285919': 'VideoGame',
#  'Q5181893': 'Lake',
#  'Q463832': 'Film',
#  'Q276217': 'VideoGame',
#  'Q1033': 'Country',
#  'Q487907': 'Company',
#  'Q104123': 'Film',
#  'Q206319': 'Currency',
#  'Q2384003': 'Bird',
#  'Q114468': 'BaseballPlayer',
#  'Q375648': 'BaseballPlayer',
#  'Q1094988': 'BaseballPlayer',
#  'Q83495': 'Film',
#  'Q1546823': 'Lake',
#  'Q1011': 'Country',
#  'Q14429': 'Lake',
#  'Q154538': 'Person',
#  'Q72538': 'Scientist',
#  'Q227': 'Country',
#  'Q214801': 'Film',
#  'Q725552': 'Film',
#  'Q200396': 'Film',
#  'Q178021': 'Airport',
#  'Q213911': 'VideoGame',
#  'Q46551': 'Film',
#  'Q452590': 'Wrestler',
#  'Q639481': 'Film',
#  'Q26': 'AdministrativeRegion',
#  'Q61620': 'Saint',
#  'Q30315633': 'Newspaper',
#  'Q6738126': 'VideoGame',
#  'Q471169': 'Film',
#  'Q1872524': 'Newspaper',
#  'Q503046': 'Film',
#  'Q1765733': 'VideoGame',
#  'Q1978200': 'VideoGame',
#  'Q39379': 'AcademicJournal',
#  'Q4920755': 'Mountain',
#  'Q6476027': 'Lake',
#  'Q199203': 'Animal',
#  'Q193439': 'Airport',
#  'Q1060323': 'VideoGame',
#  'Q380519': 'TelevisionShow',
#  'Q1408367': 'VideoGame',
#  'Q5782393': 'Plant',
#  'Q1205676': 'VideoGame',
#  'Q181086': 'Film',
#  'Q128518': 'Film',
#  'Q7194441': 'Mountain',
#  'Q2078054': 'Plant'}

# %% [markdown]
# ## Extended WD type vs WD type

# %%
# for each WD type inserted from the user (WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query

for entity_id, type_str in WD_query_type.items():
    #print(f"{type_str}: {get_type_id(type_str)}")
    
    entity_name = key_to_cell[list(WD_query_type.keys())[0]]
    ext_query_types = list(set(retrieve_superclasses(get_type_id(type_str))))
    
    WD_candidate_types = WD_types(entity_id)
    print(ext_query_types)
# Out:
# ['Q51938570', 'Q838948', 'Q47461344', 'Q35120', 'Q386724', 'Q7397', 'Q11410', 'Q17538258', 'Q58415929', 'Q110775916', 'Q2431196', 'Q110879422', 'Q286583', 'Q7889', 'Q110879246', 'Q115920686', 'Q17537576', 'Q15621286', 'Q2424752', 'Q106213450', 'Q16686448', 'Q4502142', 'Q2249149', 'Q194980', 'Q2897903', 'Q12774177', 'Q488383', 'Q28877', 'Q110910970', 'Q110879282']
# ['Q215627', 'Q53617489', 'Q223557', 'Q4120621', 'Q35120', 'Q27043950', 'Q106559804', 'Q7048977', 'Q3778211', 'Q24229398', 'Q103940464', 'Q5127848', 'Q99527517', 'Q795052', 'Q7239', 'Q66394244', 'Q43115', 'Q53617407', 'Q488383', 'Q4406616', 'Q17573152']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [72], in <cell line: 4>()
#       1 # for each WD type inserted from the user (WD_query_type taken from CEA) now we retrieve the extended WD types until the root
#       2 # given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query
#       4 for entity_id, type_str in WD_query_type.items():
#       5     #print(f"{type_str}: {get_type_id(type_str)}")
# ----> 7     ext_query_types = list(set(retrieve_superclasses(get_type_id(type_str))))
#       8     WD_candidate_types = WD_types(entity_id)
#       9     print(ext_query_types)
#
# Input In [63], in get_type_id(entity_name)
#      39 headers = {
#      40     "accept": "application/json"
#      41 }
#      43 try:
# ---> 44     response = requests.get(url, headers=headers, params=params)
#      45     response.raise_for_status()  # Raise an error for HTTP issues
#      46     data = response.json()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\response.py:496, in HTTPResponse.stream(self, amt, decode_content)
#     494 else:
#     495     while not is_fp_closed(self._fp):
# --> 496         data = self.read(amt=amt, decode_content=decode_content)
#     498         if data:
#     499             yield data
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\urllib3\response.py:444, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     442 else:
#     443     cache_content = False
# --> 444     data = self._fp.read(amt)
#     445     if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     446         # Close the connection when no data is returned
#     447         #
#    (...)
#     451         # not properly close the connection in all cases. There is
#     452         # no harm in redundantly calling close.
#     453         self._fp.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## WD type vs NER type

# %%
# for each WD type inserted from the user (WD_WD_query_type taken from CEA) now we retrieve the extended WD types until the root
# given the list of the ext_types we do the overlap with the ext_types taken from lamAPI with HARD and SOFT query
# Out:
# False

# %%
retrieve_superclasses("Q12299841")
# Out:
# {'Q12299841': 'cricketer',
#  'Q2066131': 'athlete',
#  'Q18536342': 'competitive player',
#  'Q50995749': 'sportsperson',
#  'Q4197743': 'player',
#  'Q215627': 'person',
#  'Q830077': 'subject',
#  'Q795052': 'individual',
#  'Q3778211': 'legal person',
#  'Q53617489': 'independent continuant',
#  'Q7239': 'organism',
#  'Q24229398': 'agent',
#  'Q106559804': 'person or organization',
#  'Q103940464': 'continuant',
#  'Q223557': 'physical object',
#  'Q66394244': 'physical anatomical entity',
#  'Q4406616': 'concrete object',
#  'Q53617407': 'material entity',
#  'Q27043950': 'anatomical entity',
#  'Q488383': 'object',
#  'Q35120': 'entity'}

# %%
cta_values_dict
# Out:
# {'58891288_0_1117541047012405958 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 1': 'http://dbpedia.org/ontology/Lake',
#  '50245608_0_871275842592178099 0': 'http://dbpedia.org/ontology/Film',
#  '14067031_0_559833072073397908 1': 'http://dbpedia.org/ontology/Language',
#  '8286121_0_8471791395229161598 0': 'http://dbpedia.org/ontology/Country',
#  '39759273_0_1427898308030295194 1': 'http://dbpedia.org/ontology/Film',
#  '14380604_4_3329235705746762392 1': 'http://dbpedia.org/ontology/Company',
#  '20135078_0_7570343137119682530 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_6_8221428333921653560 1': 'http://dbpedia.org/ontology/VideoGame',
#  '34041816_1_4749054164534706977 2': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 7': 'http://dbpedia.org/ontology/Currency',
#  '71137051_0_8039724067857124984 0': 'http://dbpedia.org/ontology/Bird',
#  '29414811_2_4773219892816395776 1': 'http://dbpedia.org/ontology/VideoGame',
#  '99070098_0_2074872741302696997 1': 'http://dbpedia.org/ontology/Mountain',
#  '35188621_0_6058553107571275232 3': 'http://dbpedia.org/ontology/Person',
#  '43237185_1_3636357855502246981 3': 'http://dbpedia.org/ontology/Scientist',
#  '50245608_0_871275842592178099 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 0': 'http://dbpedia.org/ontology/VideoGame',
#  '29414811_6_8221428333921653560 4': 'http://dbpedia.org/ontology/Company',
#  '11833461_1_3811022039809817402 0': 'http://dbpedia.org/ontology/VideoGame',
#  '21245481_0_8730460088443117515 1': 'http://dbpedia.org/ontology/Lake',
#  '38428277_0_1311643810102462607 3': 'http://dbpedia.org/ontology/Person',
#  '13719111_1_5719401842463579519 0': 'http://dbpedia.org/ontology/Bird',
#  '77694908_0_6083291340991074532 1': 'http://dbpedia.org/ontology/Film',
#  '20135078_0_7570343137119682530 1': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 0': 'http://dbpedia.org/ontology/Scientist',
#  '88523363_0_8180214313099580515 0': 'http://dbpedia.org/ontology/Plant',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'http://dbpedia.org/ontology/Mountain',
#  '58891288_0_1117541047012405958 3': 'http://dbpedia.org/ontology/Person',
#  '25404227_0_2240631045609013057 3': 'http://dbpedia.org/ontology/Person',
#  '9475172_1_1023126399856690702 1': 'http://dbpedia.org/ontology/TelevisionShow',
#  '60319454_0_3938426910282115527 0': 'http://dbpedia.org/ontology/Animal',
#  '52299421_0_4473286348258170200 1': 'http://dbpedia.org/ontology/Country',
#  '37856682_0_6818907050314633217 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '77694908_0_6083291340991074532 3': 'http://dbpedia.org/ontology/Person',
#  '39759273_0_1427898308030295194 3': 'http://dbpedia.org/ontology/Person',
#  '29414811_2_4773219892816395776 4': 'http://dbpedia.org/ontology/Company',
#  '29414811_13_8724394428539174350 2': 'http://dbpedia.org/ontology/Genre',
#  '33401079_0_9127583903019856402 0': 'http://dbpedia.org/ontology/Person',
#  '26310680_0_5150772059999313798 1': 'http://dbpedia.org/ontology/Currency',
#  '10579449_0_1681126353774891032 1': 'http://dbpedia.org/ontology/Newspaper',
#  '29414811_6_8221428333921653560 2': 'http://dbpedia.org/ontology/Genre',
#  '84548468_0_5955155464119382182 3': 'http://dbpedia.org/ontology/Person',
#  '55004961_0_2904467548072189860 0': 'http://dbpedia.org/ontology/Country',
#  '63450419_0_8012592961815711786 1': 'http://dbpedia.org/ontology/Plant',
#  '39107734_2_2329160387535788734 1': 'http://dbpedia.org/ontology/Airport',
#  '29414811_12_251152470253168163 4': 'http://dbpedia.org/ontology/Company',
#  '91959037_0_7907661684242014480 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 1': 'http://dbpedia.org/ontology/Company',
#  '84575189_0_6365692015941409487 2': 'http://dbpedia.org/ontology/AcademicJournal',
#  '14380604_4_3329235705746762392 2': 'http://dbpedia.org/ontology/PopulatedPlace',
#  '40534006_0_4617468856744635526 1': 'http://dbpedia.org/ontology/Wrestler',
#  '29414811_13_8724394428539174350 4': 'http://dbpedia.org/ontology/Company',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'http://dbpedia.org/ontology/PoliticalParty',
#  '84548468_0_5955155464119382182 1': 'http://dbpedia.org/ontology/Film',
#  '8468806_0_4382447409703007384 2': 'http://dbpedia.org/ontology/Country',
#  '35188621_0_6058553107571275232 1': 'http://dbpedia.org/ontology/Film',
#  '22864497_0_8632623712684511496 0': 'http://dbpedia.org/ontology/VideoGame',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'http://dbpedia.org/ontology/Cricketer',
#  '14067031_0_559833072073397908 5': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 2': 'http://dbpedia.org/ontology/Genre',
#  '88523363_0_8180214313099580515 2': 'http://dbpedia.org/ontology/Eukaryote',
#  '28086084_0_3127660530989916727 0': 'http://dbpedia.org/ontology/Saint',
#  '50245608_0_871275842592178099 4': 'http://dbpedia.org/ontology/Writer',
#  '9834884_0_3871985887467090123 1': 'http://dbpedia.org/ontology/Museum',
#  '69881946_0_1105130426898457358 1': 'http://dbpedia.org/ontology/Film',
#  '25404227_0_2240631045609013057 1': 'http://dbpedia.org/ontology/Film',
#  '75367212_2_2745466355267233390 2': 'http://dbpedia.org/ontology/Company',
#  '39650055_5_7135804139753401681 1': 'http://dbpedia.org/ontology/Company',
#  '29414811_2_4773219892816395776 2': 'http://dbpedia.org/ontology/Genre',
#  '16767252_0_2409448375013995751 3': 'http://dbpedia.org/ontology/Person',
#  '71840765_0_6664391841933033844 0': 'http://dbpedia.org/ontology/Lake',
#  '36102169_0_7739454799295072814 1': 'http://dbpedia.org/ontology/Company',
#  '26310680_0_5150772059999313798 0': 'http://dbpedia.org/ontology/Country',
#  '45073662_0_3179937335063201739 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '11833461_1_3811022039809817402 1': 'http://dbpedia.org/ontology/Company',
#  '21245481_0_8730460088443117515 0': 'http://dbpedia.org/ontology/AdministrativeRegion',
#  '53822652_0_5767892317858575530 3': 'http://dbpedia.org/ontology/Person',
#  '39173938_0_7916056990138658530 1': 'http://dbpedia.org/ontology/Film',
#  '8286121_0_8471791395229161598 1': 'http://dbpedia.org/ontology/City',
#  '21362676_0_6854186738074119688 3': 'http://dbpedia.org/ontology/Person',
#  '46671561_0_6122315295162029872 1': 'http://dbpedia.org/ontology/Genre',
#  '80588006_0_6965325215443683359 1': 'http://dbpedia.org/ontology/Newspaper',
#  '22864497_0_8632623712684511496 1': 'http://dbpedia.org/ontology/Company',
#  '61121469_0_6337620713408906340 0': 'http://dbpedia.org/ontology/Country',
#  '90196673_0_5458330029110291950 0': 'http://dbpedia.org/ontology/Animal',
#  '53989675_0_8697482470743954630 0': 'http://dbpedia.org/ontology/Lake',
#  '66009064_0_9148652238372261251 0': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '55004961_0_2904467548072189860 1': 'http://dbpedia.org/ontology/City',
#  '50270082_0_444360818941411589 1': 'http://dbpedia.org/ontology/BaseballPlayer',
#  '24036779_0_5608105867560183058 0': 'http://dbpedia.org/ontology/Country',
#  '41336118_0_4331895026409635103 0': 'http://dbpedia.org/ontology/Company',
#  '69881946_0_1105130426898457358 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 3': 'http://dbpedia.org/ontology/Film',
#  '43237185_1_3636357855502246981 2': 'http://dbpedia.org/ontology/EducationalInstitution',
#  '9834884_0_3871985887467090123 2': 'http://dbpedia.org/ontology/Country',
#  '16767252_0_2409448375013995751 1': 'http://dbpedia.org/ontology/Film',
#  '61121469_0_6337620713408906340 1': 'http://dbpedia.org/ontology/City',
#  '29414811_12_251152470253168163 1': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 0': 'http://dbpedia.org/ontology/Country',
#  '41480166_0_6681239260286218499 0': 'http://dbpedia.org/ontology/Saint',
#  '57943722_0_8666078014685775876 0': 'http://dbpedia.org/ontology/Country',
#  '38428277_0_1311643810102462607 1': 'http://dbpedia.org/ontology/Film',
#  '36102169_0_7739454799295072814 2': 'http://dbpedia.org/ontology/VideoGame',
#  '55238374_0_3379409961751009152 1': 'http://dbpedia.org/ontology/City',
#  '9567241_0_5666388268510912770 1': 'http://dbpedia.org/ontology/Newspaper',
#  '69537082_0_7789694313271016902 1': 'http://dbpedia.org/ontology/Country',
#  '57943722_0_8666078014685775876 1': 'http://dbpedia.org/ontology/City',
#  '14067031_0_559833072073397908 0': 'http://dbpedia.org/ontology/Country',
#  '53822652_0_5767892317858575530 1': 'http://dbpedia.org/ontology/Film',
#  '54719588_0_8417197176086756912 5': 'http://dbpedia.org/ontology/Person',
#  '24036779_0_5608105867560183058 5': 'http://dbpedia.org/ontology/GovernmentType',
#  '34041816_1_4749054164534706977 1': 'http://dbpedia.org/ontology/Airport',
#  '39173938_0_7916056990138658530 3': 'http://dbpedia.org/ontology/Person',
#  '54719588_0_8417197176086756912 4': 'http://dbpedia.org/ontology/Country',
#  '66009064_0_9148652238372261251 2': 'http://dbpedia.org/ontology/SportsTeam',
#  '21362676_0_6854186738074119688 1': 'http://dbpedia.org/ontology/Film',
#  '39107734_2_2329160387535788734 2': 'http://dbpedia.org/ontology/City',
#  '29414811_13_8724394428539174350 1': 'http://dbpedia.org/ontology/VideoGame',
#  '75367212_2_2745466355267233390 0': 'http://dbpedia.org/ontology/VideoGame'}

# %%
cea_values_dict
# Out:
# {'50245608_0_871275842592178099 0': 'https://www.wikidata.org/entity/Q46551',
#  '22864497_0_8632623712684511496 0': 'https://www.wikidata.org/entity/Q6738126',
#  '66009064_0_9148652238372261251 0': 'https://www.wikidata.org/entity/Q1094988',
#  '21362676_0_6854186738074119688 1': 'https://www.wikidata.org/entity/Q463832',
#  '40534006_0_4617468856744635526 1': 'https://www.wikidata.org/entity/Q452590',
#  '36102169_0_7739454799295072814 2': 'https://www.wikidata.org/entity/Q1978200',
#  '53822652_0_5767892317858575530 1': 'https://www.wikidata.org/entity/Q200396',
#  '60319454_0_3938426910282115527 0': 'https://www.wikidata.org/entity/Q69581',
#  '8468806_0_4382447409703007384 1': 'https://www.wikidata.org/entity/Q1546823',
#  '33401079_0_9127583903019856402 0': 'https://www.wikidata.org/entity/Q154538',
#  '99070098_0_2074872741302696997 1': 'https://www.wikidata.org/entity/Q4920755',
#  '50270082_0_444360818941411589 1': 'https://www.wikidata.org/entity/Q114468',
#  '29414811_12_251152470253168163 1': 'https://www.wikidata.org/entity/Q1060323',
#  '39759273_0_1427898308030295194 1': 'https://www.wikidata.org/entity/Q104123',
#  '69537082_0_7789694313271016902 1': 'https://www.wikidata.org/entity/Q1011',
#  '88523363_0_8180214313099580515 0': 'https://www.wikidata.org/entity/Q5782393',
#  '41480166_0_6681239260286218499 0': 'https://www.wikidata.org/entity/Q4390981',
#  '9834884_0_3871985887467090123 1': 'https://www.wikidata.org/entity/Q1781530',
#  '26310680_0_5150772059999313798 1': 'https://www.wikidata.org/entity/Q206319',
#  '39173938_0_7916056990138658530 1': 'https://www.wikidata.org/entity/Q25193623',
#  '91959037_0_7907661684242014480 1': 'https://www.wikidata.org/entity/Q663665',
#  '13719111_1_5719401842463579519 0': 'https://www.wikidata.org/entity/Q2384003',
#  '54719588_0_8417197176086756912 3': 'https://www.wikidata.org/entity/Q575014',
#  '58891288_0_1117541047012405958 1': 'https://www.wikidata.org/entity/Q135465',
#  '28086084_0_3127660530989916727 0': 'https://www.wikidata.org/entity/Q61620',
#  '21245481_0_8730460088443117515 1': 'https://www.wikidata.org/entity/Q6476027',
#  '90196673_0_5458330029110291950 0': 'https://www.wikidata.org/entity/Q199203',
#  '35188621_0_6058553107571275232 1': 'https://www.wikidata.org/entity/Q214801',
#  '46671561_0_6122315295162029872 0': 'https://www.wikidata.org/entity/Q1408367',
#  '25404227_0_2240631045609013057 1': 'https://www.wikidata.org/entity/Q128518',
#  '63450419_0_8012592961815711786 1': 'https://www.wikidata.org/entity/Q2078054',
#  '39107734_2_2329160387535788734 1': 'https://www.wikidata.org/entity/Q193439',
#  '29414811_2_4773219892816395776 1': 'https://www.wikidata.org/entity/Q276217',
#  '20135078_0_7570343137119682530 1': 'https://www.wikidata.org/entity/Q639481',
#  '39650055_5_7135804139753401681 1': 'https://www.wikidata.org/entity/Q459477',
#  '16767252_0_2409448375013995751 1': 'https://www.wikidata.org/entity/Q503046',
#  '9475172_1_1023126399856690702 1': 'https://www.wikidata.org/entity/Q380519',
#  '24036779_0_5608105867560183058 0': 'https://www.wikidata.org/entity/Q817',
#  '69881946_0_1105130426898457358 1': 'https://www.wikidata.org/entity/Q471169',
#  '75367212_2_2745466355267233390 0': 'https://www.wikidata.org/entity/Q1205676',
#  '84575189_0_6365692015941409487 2': 'https://www.wikidata.org/entity/Q39379',
#  '84548468_0_5955155464119382182 1': 'https://www.wikidata.org/entity/Q181086',
#  '52299421_0_4473286348258170200 1': 'https://www.wikidata.org/entity/Q227',
#  '37856682_0_6818907050314633217 0': 'https://www.wikidata.org/entity/Q26',
#  '38428277_0_1311643810102462607 1': 'https://www.wikidata.org/entity/Q725552',
#  '41336118_0_4331895026409635103 0': 'https://www.wikidata.org/entity/Q831445',
#  '71840765_0_6664391841933033844 0': 'https://www.wikidata.org/entity/Q14429',
#  '77694908_0_6083291340991074532 1': 'https://www.wikidata.org/entity/Q83495',
#  '43237185_1_3636357855502246981 0': 'https://www.wikidata.org/entity/Q72538',
#  '45073662_0_3179937335063201739 1': 'https://www.wikidata.org/entity/Q375648',
#  '11833461_1_3811022039809817402 0': 'https://www.wikidata.org/entity/Q5285919',
#  '14067031_0_559833072073397908 0': 'https://www.wikidata.org/entity/Q1033',
#  '9567241_0_5666388268510912770 1': 'https://www.wikidata.org/entity/Q208875',
#  '34041816_1_4749054164534706977 1': 'https://www.wikidata.org/entity/Q178021',
#  '10579449_0_1681126353774891032 1': 'https://www.wikidata.org/entity/Q30315633',
#  '29414811_13_8724394428539174350 1': 'https://www.wikidata.org/entity/Q213911',
#  '14380604_4_3329235705746762392 1': 'https://www.wikidata.org/entity/Q487907',
#  '1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2 0': 'https://www.wikidata.org/entity/Q7626741',
#  '1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5 0': 'https://www.wikidata.org/entity/Q9669',
#  '80588006_0_6965325215443683359 1': 'https://www.wikidata.org/entity/Q1872524',
#  '29414811_6_8221428333921653560 1': 'https://www.wikidata.org/entity/Q1765733',
#  '53989675_0_8697482470743954630 0': 'https://www.wikidata.org/entity/Q5181893',
#  '1438042986423_95_20150728002306-00329-ip-10-236-191-2_805336391_10 1': 'https://www.wikidata.org/entity/Q6393870',
#  '1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2 0': 'https://www.wikidata.org/entity/Q7194441'}
