# %%
# Step 2: Import required libraries
import json
import bz2
from elasticsearch import Elasticsearch, helpers
import pandas as pd

# Step 3: Connect to Elasticsearch
es = Elasticsearch(['http://elastic:9200'])

# Step 4: Create the Index with Zero Replicas
def create_index():
    es.options(ignore_status=[400]).indices.create(
        index='wikidata',
        body={
            'settings': {
                'number_of_shards': 1,
                'number_of_replicas': 0
            }
        }
    )

# Step 5: Function to parse the Wikidata JSON dump and extract labels
def parse_wikidata_dump(file_path, limit):
    count = 0
    with bz2.open(file_path, 'rt', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line.endswith(','):
                line = line[:-1]
            if line in ['[', ']']:
                continue

            try:
                item = json.loads(line)
                if 'labels' in item:
                    labels = item['labels']
                    if 'en' in labels:  # Extract English labels
                        yield {
                            '_index': 'wikidata',
                            '_source': {
                                'id': item['id'],
                                'label': labels['en']['value']
                            }
                        }
                        count += 1
                        if count >= limit:
                            break
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

# Step 6: Index data into Elasticsearch
def index_wikidata(file_path, limit):
    actions = parse_wikidata_dump(file_path, limit)
    helpers.bulk(es, actions)

# Step 7: Create the index, load, and index the data
create_index()
wikidata_dump_file = 'my-data/latest-all.json.bz2'
sample_size = 1000  # Number of items to index
index_wikidata(wikidata_dump_file, sample_size)

# Step 8: Verify the indexed data
res = es.search(index="wikidata", body={"query": {"match_all": {}}, "size": sample_size})
for hit in res['hits']['hits']:
    print(hit['_source'])
# Out:
# {'id': 'Q31', 'label': 'Belgium'}
# {'id': 'Q8', 'label': 'happiness'}
# {'id': 'Q23', 'label': 'George Washington'}
# {'id': 'Q24', 'label': 'Jack Bauer'}
# {'id': 'Q42', 'label': 'Douglas Adams'}
# {'id': 'Q1868', 'label': 'Paul Otlet'}
# {'id': 'Q2013', 'label': 'Wikidata'}
# {'id': 'Q45', 'label': 'Portugal'}
# {'id': 'Q51', 'label': 'Antarctica'}
# {'id': 'Q58', 'label': 'penis'}
# {'id': 'Q68', 'label': 'computer'}
# {'id': 'Q75', 'label': 'Internet'}
# {'id': 'Q102', 'label': 'pneumonoultramicroscopicsilicovolcanoconiosis'}
# {'id': 'Q103', 'label': 'Supercalifragilisticexpialidocious'}
# {'id': 'Q125', 'label': 'November'}
# {'id': 'Q140', 'label': 'lion'}
# {'id': 'Q144', 'label': 'dog'}
# {'id': 'Q147', 'label': 'kitten'}
# {'id': 'Q148', 'label': "People's Republic of China"}
# {'id': 'Q155', 'label': 'Brazil'}
# {'id': 'Q163', 'label': 'Yorkshire'}
# {'id': 'Q177', 'label': 'pizza'}
# {'id': 'Q178', 'label': 'pasta'}
# {'id': 'Q183', 'label': 'Germany'}
# {'id': 'Q207', 'label': 'George W. Bush'}
# {'id': 'Q210', 'label': 'right angle'}
# {'id': 'Q233', 'label': 'Malta'}
# {'id': 'Q278', 'label': 'Talisker distillery'}
# {'id': 'Q288', 'label': 'Tours'}
# {'id': 'Q297', 'label': 'Diego Velázquez'}
# {'id': 'Q298', 'label': 'Chile'}
# {'id': 'Q317', 'label': 'dictatorship'}
# {'id': 'Q328', 'label': 'English Wikipedia'}
# {'id': 'Q362', 'label': 'World War II'}
# {'id': 'Q368', 'label': 'Augusto Pinochet'}
# {'id': 'Q398', 'label': 'Bahrain'}
# {'id': 'Q411', 'label': 'astrobiology'}
# {'id': 'Q412', 'label': 'Pioneer plaque'}
# {'id': 'Q431', 'label': 'zoology'}
# {'id': 'Q433', 'label': 'Gmina Kurów'}
# {'id': 'Q443', 'label': 'Ich bin ein Berliner'}
# {'id': 'Q447', 'label': 'Encyclopédie'}
# {'id': 'Q463', 'label': 'Rhône-Alpes'}
# {'id': 'Q497', 'label': 'anus'}
# {'id': 'Q501', 'label': 'Charles Baudelaire'}
# {'id': 'Q506', 'label': 'flower'}
# {'id': 'Q511', 'label': 'Museum of Fine Arts of Lyon'}
# {'id': 'Q514', 'label': 'anatomy'}
# {'id': 'Q524', 'label': 'Mount Vesuvius'}
# {'id': 'Q544', 'label': 'Solar System'}
# {'id': 'Q550', 'label': 'avenue des Champs-Élysées'}
# {'id': 'Q556', 'label': 'hydrogen'}
# {'id': 'Q585', 'label': 'Oslo'}
# {'id': 'Q586', 'label': 'Bonn'}
# {'id': 'Q587', 'label': "All Saints' Day"}
# {'id': 'Q595', 'label': 'The Intouchables'}
# {'id': 'Q597', 'label': 'Lisbon'}
# {'id': 'Q616', 'label': 'Beaujolais wine'}
# {'id': 'Q619', 'label': 'Nicolaus Copernicus'}
# {'id': 'Q633', 'label': 'Neil Young'}
# {'id': 'Q634', 'label': 'planet'}
# {'id': 'Q640', 'label': 'Harald Krichel'}
# {'id': 'Q643', 'label': 'Po'}
# {'id': 'Q647', 'label': 'Rennes'}
# {'id': 'Q648', 'label': 'Lille'}
# {'id': 'Q659', 'label': 'north'}
# {'id': 'Q661', 'label': 'hydraulic ram'}
# {'id': 'Q676', 'label': 'prose'}
# {'id': 'Q686', 'label': 'Vanuatu'}
# {'id': 'Q688', 'label': 'chlorine'}
# {'id': 'Q694', 'label': 'South Holland'}
# {'id': 'Q716', 'label': 'titanium'}
# {'id': 'Q722', 'label': 'vanadium'}
# {'id': 'Q732', 'label': 'Francesinha'}
# {'id': 'Q746', 'label': 'croque-madame'}
# {'id': 'Q747', 'label': 'Pierre Corneille'}
# {'id': 'Q749', 'label': 'Groningen'}
# {'id': 'Q764', 'label': 'fungus'}
# {'id': 'Q771', 'label': 'Massachusetts'}
# {'id': 'Q801', 'label': 'Israel'}
# {'id': 'Q807', 'label': 'Lausanne'}
# {'id': 'Q815', 'label': 'Gabriel Gonzáles Videla'}
# {'id': 'Q819', 'label': 'Laos'}
# {'id': 'Q844', 'label': 'James Bond'}
# {'id': 'Q853', 'label': 'Andrei Tarkovsky'}
# {'id': 'Q859', 'label': 'Plato'}
# {'id': 'Q863', 'label': 'Tajikistan'}
# {'id': 'Q869', 'label': 'Thailand'}
# {'id': 'Q873', 'label': 'Meryl Streep'}
# {'id': 'Q878', 'label': 'United Arab Emirates'}
# {'id': 'Q880', 'label': 'platinum'}
# {'id': 'Q883', 'label': 'Novosibirsk'}
# {'id': 'Q891', 'label': 'Nizhny Novgorod'}
# {'id': 'Q898', 'label': 'Omsk'}
# {'id': 'Q899', 'label': 'Suez Canal'}
# {'id': 'Q901', 'label': 'scientist'}
# {'id': 'Q903', 'label': 'Erta Ale'}
# {'id': 'Q907', 'label': 'Gordon Freeman'}
# {'id': 'Q912', 'label': 'Mali'}
# {'id': 'Q916', 'label': 'Angola'}
# {'id': 'Q922', 'label': 'Brač'}
# {'id': 'Q943', 'label': 'yellow'}
# {'id': 'Q946', 'label': 'Donald Tusk'}
# {'id': 'Q951', 'label': 'toilet paper orientation'}
# {'id': 'Q952', 'label': 'Reggiolo'}
# {'id': 'Q957', 'label': 'list of lists of lists'}
# {'id': 'Q961', 'label': 'More Than Life at Stake'}
# {'id': 'Q966', 'label': 'Hermann Brunner'}
# {'id': 'Q968', 'label': 'Warburg'}
# {'id': 'Q973', 'label': 'Ob'}
# {'id': 'Q978', 'label': 'meme'}
# {'id': 'Q982', 'label': 'FIS Alpine Ski World Cup'}
# {'id': 'Q990', 'label': 'Czterej pancerni i pies'}
# {'id': 'Q997', 'label': 'Andrei Sakharov'}
# {'id': 'Q1044', 'label': 'Sierra Leone'}
# {'id': 'Q1049', 'label': 'Sudan'}
# {'id': 'Q1056', 'label': 'Italo Balbo'}
# {'id': 'Q1057', 'label': 'metabolism'}
# {'id': 'Q1058', 'label': 'Narendra Modi'}
# {'id': 'Q1071', 'label': 'geography'}
# {'id': 'Q1092', 'label': 'Star Trek'}
# {'id': 'Q1093', 'label': 'Limburg'}
# {'id': 'Q1099', 'label': 'antimony'}
# {'id': 'Q1146', 'label': 'unbinilium'}
# {'id': 'Q1149', 'label': 'Indira Gandhi'}
# {'id': 'Q1151', 'label': 'Hector Berlioz'}
# {'id': 'Q1161', 'label': 'Limburg'}
# {'id': 'Q1172', 'label': 'Groß Borstel'}
# {'id': 'Q1181', 'label': 'Hoheluft-Ost'}
# {'id': 'Q1183', 'label': 'Puerto Rico'}
# {'id': 'Q1201', 'label': 'Saarland'}
# {'id': 'Q1204', 'label': 'Illinois'}
# {'id': 'Q1228', 'label': 'Oscar Luigi Scalfaro'}
# {'id': 'Q1232', 'label': 'dubnium'}
# {'id': 'Q1251', 'label': 'Cottian Alps'}
# {'id': 'Q1253', 'label': 'Ban Ki-moon'}
# {'id': 'Q1254', 'label': 'Kofi Annan'}
# {'id': 'Q1258', 'label': 'meitnerium'}
# {'id': 'Q1269', 'label': 'jam'}
# {'id': 'Q1270', 'label': 'Pennine Alps'}
# {'id': 'Q1276', 'label': 'Leonard Cohen'}
# {'id': 'Q1277', 'label': 'Rhaetian Alps'}
# {'id': 'Q1281', 'label': 'Category:Contents'}
# {'id': 'Q1297', 'label': 'Chicago'}
# {'id': 'Q1301', 'label': 'nihonium'}
# {'id': 'Q1317', 'label': 'Osama bin Laden'}
# {'id': 'Q1325', 'label': 'Friedrich Hayek'}
# {'id': 'Q1330', 'label': 'José Joaquín Prieto'}
# {'id': 'Q1358', 'label': 'Arachnida'}
# {'id': 'Q1363', 'label': 'Tripura'}
# {'id': 'Q1381', 'label': 'Dave Arneson'}
# {'id': 'Q1404', 'label': 'Uetersen'}
# {'id': 'Q1416', 'label': 'Otho'}
# {'id': 'Q1421', 'label': 'Titus'}
# {'id': 'Q1455', 'label': 'field hockey'}
# {'id': 'Q1468', 'label': 'Eschwege'}
# {'id': 'Q1469', 'label': 'Loire'}
# {'id': 'Q1487', 'label': 'hacker'}
# {'id': 'Q1489', 'label': 'Mexico City'}
# {'id': 'Q1494', 'label': 'Mississippi'}
# {'id': 'Q1499', 'label': 'Uttarakhand'}
# {'id': 'Q1504', 'label': 'Cublize'}
# {'id': 'Q1511', 'label': 'Richard Wagner'}
# {'id': 'Q1513', 'label': 'Nagpur'}
# {'id': 'Q1521', 'label': 'Lyon Cathedral'}
# {'id': 'Q1522', 'label': 'New Mexico'}
# {'id': 'Q1525', 'label': 'roundabout'}
# {'id': 'Q1526', 'label': 'Ramesses I'}
# {'id': 'Q1533', 'label': 'Caracas'}
# {'id': 'Q1562', 'label': 'Finkenwerder'}
# {'id': 'Q1565', 'label': 'Billstedt'}
# {'id': 'Q1574', 'label': 'Avast Antivirus'}
# {'id': 'Q1607', 'label': 'Blankenese'}
# {'id': 'Q1611', 'label': 'Eimsbüttel'}
# {'id': 'Q1623', 'label': 'Valenzuela'}
# {'id': 'Q1636', 'label': 'Antipolo'}
# {'id': 'Q1638', 'label': 'Primo Nebiolo'}
# {'id': 'Q1641', 'label': 'Bergstedt'}
# {'id': 'Q1644', 'label': 'Elbe'}
# {'id': 'Q1672', 'label': 'Dejen Gebremeskel'}
# {'id': 'Q1673', 'label': 'Neckar'}
# {'id': 'Q1681', 'label': 'Abel Mutai'}
# {'id': 'Q1693', 'label': 'North Sea'}
# {'id': 'Q1706', 'label': 'Tabaco'}
# {'id': 'Q1707', 'label': 'Kiel'}
# {'id': 'Q1711', 'label': 'Potsdam'}
# {'id': 'Q1712', 'label': 'Erick Barrondo'}
# {'id': 'Q1718', 'label': 'Düsseldorf'}
# {'id': 'Q1721', 'label': 'Wiesbaden'}
# {'id': 'Q1724', 'label': 'Saarbrücken'}
# {'id': 'Q1738', 'label': 'Robert Grabarz'}
# {'id': 'Q1746', 'label': 'Samara Governorate'}
# {'id': 'Q1749', 'label': 'Kaliningrad Oblast'}
# {'id': 'Q1755', 'label': 'Tomasz Majewski'}
# {'id': 'Q1757', 'label': 'Helsinki'}
# {'id': 'Q1759', 'label': 'Murmansk Oblast'}
# {'id': 'Q1789', 'label': 'Ashton Eaton'}
# {'id': 'Q1807', 'label': 'Eilbek'}
# {'id': 'Q1812', 'label': 'Gordian III'}
# {'id': 'Q1818', 'label': 'Poppenbüttel'}
# {'id': 'Q1820', 'label': 'Rahlstedt'}
# {'id': 'Q1832', 'label': 'gadolinium'}
# {'id': 'Q1837', 'label': 'Wohldorf-Ohlstedt'}
# {'id': 'Q1860', 'label': 'English'}
# {'id': 'Q1866', 'label': 'Bangka Belitung Islands'}
# {'id': 'Q1871', 'label': 'Diplomacy'}
# {'id': 'Q1890', 'label': 'Bengkulu'}
# {'id': 'Q1911', 'label': 'Olivier Giroud'}
# {'id': 'Q1925', 'label': "Yann M'Vila"}
# {'id': 'Q1934', 'label': 'Sidney Govou'}
# {'id': 'Q1936', 'label': 'Djibril Cissé'}
# {'id': 'Q1938', 'label': 'Bacary Sagna'}
# {'id': 'Q1946', 'label': 'list of moons of Jupiter'}
# {'id': 'Q1956', 'label': 'Hermann Maier'}
# {'id': 'Q1976', 'label': 'Givors'}
# {'id': 'Q1977', 'label': 'Rivolet'}
# {'id': 'Q1987', 'label': '2002'}
# {'id': 'Q1996', 'label': '2009'}
# {'id': 'Q2003', 'label': 'Newfoundland and Labrador'}
# {'id': 'Q2011', 'label': 'Gare de Lyon-Vaise'}
# {'id': 'Q2019', 'label': '2005'}
# {'id': 'Q2026', 'label': 'Chambost-Allières'}
# {'id': 'Q2029', 'label': 'history of Lyon'}
# {'id': 'Q2032', 'label': 'Luxembourg District'}
# {'id': 'Q2041', 'label': 'bridges of Lyon'}
# {'id': 'Q2048', 'label': '1907'}
# {'id': 'Q2049', 'label': '1906'}
# {'id': 'Q2052', 'label': 'ACF Fiorentina'}
# {'id': 'Q2057', 'label': '1909'}
# {'id': 'Q2059', 'label': 'Gare de Lyon-Gorge-de-Loup'}
# {'id': 'Q2065', 'label': '1993'}
# {'id': 'Q2070', 'label': '1996'}
# {'id': 'Q2073', 'label': 'Komi Republic'}
# {'id': 'Q2077', 'label': '1912'}
# {'id': 'Q2091', 'label': '1999'}
# {'id': 'Q2096', 'label': 'Edmonton'}
# {'id': 'Q2100', 'label': 'Duisburg'}
# {'id': 'Q2105', 'label': 'Jacques Chirac'}
# {'id': 'Q2109', 'label': 'Arica y Parinacota Region'}
# {'id': 'Q2114', 'label': 'Tarapacá Region'}
# {'id': 'Q2119', 'label': 'Mannheim'}
# {'id': 'Q2132', 'label': 'Victoria'}
# {'id': 'Q2137', 'label': 'Totma'}
# {'id': 'Q2142', 'label': 'Goku'}
# {'id': 'Q2148', 'label': 'Government of the Soviet Union'}
# {'id': 'Q2149', 'label': 'XXX'}
# {'id': 'Q2151', 'label': 'January 2'}
# {'id': 'Q2165', 'label': '1922'}
# {'id': 'Q2174', 'label': 'Naryan-Mar'}
# {'id': 'Q2185', 'label': 'Georges Pompidou'}
# {'id': 'Q2190', 'label': 'Coluche'}
# {'id': 'Q2192', 'label': 'GIF'}
# {'id': 'Q2205', 'label': 'Iriga'}
# {'id': 'Q2207', 'label': 'Naga'}
# {'id': 'Q2217', 'label': 'Alto Hospicio'}
# {'id': 'Q2229', 'label': 'Nissedal'}
# {'id': 'Q2230', 'label': 'Langenzenn'}
# {'id': 'Q2236', 'label': 'Seljord'}
# {'id': 'Q2238', 'label': 'January 9'}
# {'id': 'Q2239', 'label': 'Kongens Lyngby'}
# {'id': 'Q2241', 'label': 'Tokke Municipality'}
# {'id': 'Q2243', 'label': 'January 10'}
# {'id': 'Q2255', 'label': 'January 13'}
# {'id': 'Q2264', 'label': 'January 17'}
# {'id': 'Q2272', 'label': 'Skien'}
# {'id': 'Q2276', 'label': 'January 23'}
# {'id': 'Q2281', 'label': 'Sauron'}
# {'id': 'Q2294', 'label': 'proton'}
# {'id': 'Q2301', 'label': 'December 8'}
# {'id': 'Q2319', 'label': 'February 5'}
# {'id': 'Q2336', 'label': 'February 12'}
# {'id': 'Q2345', 'label': '12 Angry Men'}
# {'id': 'Q2362', 'label': 'February 28'}
# {'id': 'Q2380', 'label': 'Altengamme'}
# {'id': 'Q2396', 'label': 'March 4'}
# {'id': 'Q2397', 'label': 'March 10'}
# {'id': 'Q2406', 'label': '¿Dónde Están Corazón?'}
# {'id': 'Q2418', 'label': 'Reitbrook'}
# {'id': 'Q2423', 'label': 'Yaroslavl'}
# {'id': 'Q2424', 'label': 'March 19'}
# {'id': 'Q2435', 'label': 'March 22'}
# {'id': 'Q2470', 'label': 'Heroes of Might and Magic V: Hammers of Fate'}
# {'id': 'Q2471', 'label': 'Sanaa'}
# {'id': 'Q2474', 'label': '1970'}
# {'id': 'Q2475', 'label': '1971'}
# {'id': 'Q2477', 'label': '1973'}
# {'id': 'Q2487', 'label': "Thirty Years' War"}
# {'id': 'Q2496', 'label': 'Ludwig Erhard'}
# {'id': 'Q2498', 'label': 'April 13'}
# {'id': 'Q2515', 'label': 'Kick-Ass'}
# {'id': 'Q2518', 'label': 'Helmut Kohl'}
# {'id': 'Q2546', 'label': 'potassium bromide'}
# {'id': 'Q2562', 'label': 'May 15'}
# {'id': 'Q2567', 'label': 'Richard von Weizsäcker'}
# {'id': 'Q2574', 'label': 'May 16'}
# {'id': 'Q2610', 'label': 'Willi Stoph'}
# {'id': 'Q2622', 'label': 'June 5'}
# {'id': 'Q2636', 'label': 'December 22'}
# {'id': 'Q2640', 'label': '10 Hygiea'}
# {'id': 'Q2644', 'label': '1968'}
# {'id': 'Q2650', 'label': '1965'}
# {'id': 'Q2651', 'label': 'arithmetic coding'}
# {'id': 'Q2662', 'label': 'June 25'}
# {'id': 'Q2668', 'label': 'June 23'}
# {'id': 'Q2674', 'label': 'Palermo F.C.'}
# {'id': 'Q2677', 'label': 'Wilhelm II'}
# {'id': 'Q2683', 'label': 'Parma'}
# {'id': 'Q2700', 'label': 'July 1'}
# {'id': 'Q2703', 'label': 'epoch'}
# {'id': 'Q2711', 'label': 'Implode'}
# {'id': 'Q2715', 'label': 'July 31'}
# {'id': 'Q2751', 'label': 'Siena'}
# {'id': 'Q2756', 'label': 'ACR Siena 1904'}
# {'id': 'Q2774', 'label': 'August 15'}
# {'id': 'Q2780', 'label': 'August 8'}
# {'id': 'Q2789', 'label': 'Telgte'}
# {'id': 'Q2800', 'label': 'December 27'}
# {'id': 'Q2809', 'label': 'Everswinkel'}
# {'id': 'Q2810', 'label': 'Bryansk Oblast'}
# {'id': 'Q2821', 'label': 'August 23'}
# {'id': 'Q2853', 'label': 'September 10'}
# {'id': 'Q2857', 'label': 'September 2'}
# {'id': 'Q2859', 'label': 'September 1'}
# {'id': 'Q2860', 'label': 'September 3'}
# {'id': 'Q2876', 'label': 'Nordwestmecklenburg District'}
# {'id': 'Q2883', 'label': 'September 28'}
# {'id': 'Q2884', 'label': 'September 27'}
# {'id': 'Q2889', 'label': 'September 22'}
# {'id': 'Q2901', 'label': 'December 30'}
# {'id': 'Q2902', 'label': 'Mecklenburgische Seenplatte District'}
# {'id': 'Q2903', 'label': 'Tram line 1 (Lyon)'}
# {'id': 'Q2927', 'label': 'October 11'}
# {'id': 'Q2928', 'label': 'October 6'}
# {'id': 'Q2930', 'label': 'October 5'}
# {'id': 'Q2933', 'label': 'Asunción'}
# {'id': 'Q2935', 'label': 'calf'}
# {'id': 'Q2947', 'label': 'Dithmarschen'}
# {'id': 'Q2952', 'label': 'October 28'}
# {'id': 'Q2970', 'label': 'Plön District'}
# {'id': 'Q2979', 'label': 'liberty'}
# {'id': 'Q2984', 'label': 'November 13'}
# {'id': 'Q2997', 'label': 'November 1'}
# {'id': 'Q3001', 'label': 'Paramaribo'}
# {'id': 'Q3011', 'label': 'Steinburg'}
# {'id': 'Q3016', 'label': 'November 29'}
# {'id': 'Q3024', 'label': 'November 20'}
# {'id': 'Q3025', 'label': 'November 22'}
# {'id': 'Q3029', 'label': 'November 16'}
# {'id': 'Q3036', 'label': 'Mack Wilberg'}
# {'id': 'Q3039', 'label': 'cassoulet'}
# {'id': 'Q3067', 'label': 'Aqueduct of the Gier'}
# {'id': 'Q3078', 'label': "Aqueduc de l'Yzeron"}
# {'id': 'Q3093', 'label': 'Aisne'}
# {'id': 'Q3098', 'label': 'Georg Henrik Lybecker'}
# {'id': 'Q3108', 'label': 'Lyon Tablet'}
# {'id': 'Q3155', 'label': 'Circus Mosaic from Lyon'}
# {'id': 'Q3181', 'label': 'Protestant church in Ozimek'}
# {'id': 'Q3190', 'label': '2012 Rhythmic Gymnastics European Championships'}
# {'id': 'Q3202', 'label': 'Barcaldine Castle'}
# {'id': 'Q3213', 'label': 'Covões'}
# {'id': 'Q3240', 'label': 'Bouches-du-Rhône'}
# {'id': 'Q3251', 'label': 'Elisha E. Meredith'}
# {'id': 'Q3255', 'label': 'Usedom'}
# {'id': 'Q3260', 'label': 'Hubert Clifford'}
# {'id': 'Q3262', 'label': "St Munn's Parish Church, Kilmun"}
# {'id': 'Q3263', 'label': 'Robert Rose'}
# {'id': 'Q3276', 'label': 'exploration of Jupiter'}
# {'id': 'Q3313', 'label': 'Category:Slovak architects'}
# {'id': 'Q3314', 'label': 'Eider'}
# {'id': 'Q3319', 'label': 'Yukiko Kobayashi'}
# {'id': 'Q3323', 'label': 'Belgorod'}
# {'id': 'Q3327', 'label': 'Lourdes'}
# {'id': 'Q3329', 'label': 'Belgorod Oblast'}
# {'id': 'Q3331', 'label': 'tunnel de la Croix-Rousse'}
# {'id': 'Q3344', 'label': '2nd arrondissement of Lyon'}
# {'id': 'Q3359', 'label': 'Triton'}
# {'id': 'Q3374', 'label': 'Anne-Sophie Mutter'}
# {'id': 'Q3377', 'label': 'Eure-et-Loir'}
# {'id': 'Q3439', 'label': 'North Nahanni River'}
# {'id': 'Q3460', 'label': 'Chaetobranchus'}
# {'id': 'Q3489', 'label': 'Harburg'}
# {'id': 'Q3493', 'label': 'Category:R.E.M. albums'}
# {'id': 'Q3502', 'label': 'Grauno'}
# {'id': 'Q3503', 'label': 'Congo'}
# {'id': 'Q3516', 'label': 'Crenicichla tigrina'}
# {'id': 'Q3534', 'label': 'Sinstorf'}
# {'id': 'Q3543', 'label': 'Potenza'}
# {'id': 'Q3547', 'label': 'Franciszek Karpiński'}
# {'id': 'Q3549', 'label': 'Šibenik'}
# {'id': 'Q3553', 'label': 'Mileanca'}
# {'id': 'Q3563', 'label': 'Monteferrante'}
# {'id': 'Q3569', 'label': 'Senegal River'}
# {'id': 'Q3571', 'label': 'Category:Slovenia in the Eurovision Song Contest'}
# {'id': 'Q3586', 'label': 'East Java'}
# {'id': 'Q3592', 'label': 'Velezzo Lomellina'}
# {'id': 'Q3595', 'label': 'Chazelles'}
# {'id': 'Q3601', 'label': 'Calvignano'}
# {'id': 'Q3602', 'label': 'Andacollo'}
# {'id': 'Q3603', 'label': 'Jack Angel'}
# {'id': 'Q3614', 'label': 'occipital nerve stimulation'}
# {'id': 'Q3618', 'label': 'Remuh Synagogue'}
# {'id': 'Q3626', 'label': 'Chilean Antarctic Territory'}
# {'id': 'Q3671', 'label': 'Justin Chadwick'}
# {'id': 'Q3675', 'label': 'Kashi Vishwanath Temple'}
# {'id': 'Q3679', 'label': 'Anceriz'}
# {'id': 'Q3680', 'label': 'Krasnodar Krai'}
# {'id': 'Q3708', 'label': 'Caldera'}
# {'id': 'Q3736', 'label': 'Carahue'}
# {'id': 'Q3742', 'label': 'Casablanca'}
# {'id': 'Q3749', 'label': 'Cauquenes'}
# {'id': 'Q3750', 'label': 'Gera'}
# {'id': 'Q3751', 'label': 'Praia'}
# {'id': 'Q3752', 'label': 'Maykop'}
# {'id': 'Q3761', 'label': 'Accra'}
# {'id': 'Q3769', 'label': 'French Guiana'}
# {'id': 'Q3794', 'label': 'Laurent Dauthuille'}
# {'id': 'Q3796', 'label': 'Cobquecura'}
# {'id': 'Q3799', 'label': 'Porto-Novo'}
# {'id': 'Q3802', 'label': 'Hanau'}
# {'id': 'Q3811', 'label': 'Category:Sports templates'}
# {'id': 'Q3823', 'label': 'Neustadt-Nord'}
# {'id': 'Q3825', 'label': 'Libreville'}
# {'id': 'Q3830', 'label': 'Neustadt-Süd'}
# {'id': 'Q3838', 'label': 'Kinshasa'}
# {'id': 'Q3843', 'label': 'Collipulli'}
# {'id': 'Q3851', 'label': 'Conchalí'}
# {'id': 'Q3863', 'label': 'asteroid'}
# {'id': 'Q3874', 'label': 'Giessen'}
# {'id': 'Q3875', 'label': 'Corral'}
# {'id': 'Q3881', 'label': 'Lusaka'}
# {'id': 'Q3886', 'label': 'Dorsten'}
# {'id': 'Q3908', 'label': 'Galicia'}
# {'id': 'Q3913', 'label': 'binary numeral system'}
# {'id': 'Q3936', 'label': 'Bamberg'}
# {'id': 'Q3941', 'label': 'Astrakhan Oblast'}
# {'id': 'Q3942', 'label': 'Aschaffenburg'}
# {'id': 'Q3949', 'label': 'Unna'}
# {'id': 'Q3954', 'label': 'Neptune'}
# {'id': 'Q3955', 'label': 'Weimar'}
# {'id': 'Q3996', 'label': 'V. P. Kalairajan'}
# {'id': 'Q3997', 'label': 'Nalai Manithan'}
# {'id': 'Q4000', 'label': 'Mahajana College'}
# {'id': 'Q4002', 'label': 'Rozpor'}
# {'id': 'Q4003', 'label': 'Category:Armenian genocide memorials'}
# {'id': 'Q4006', 'label': 'map'}
# {'id': 'Q4009', 'label': 'Ramesses IX'}
# {'id': 'Q4053', 'label': 'Mravenečník'}
# {'id': 'Q4074', 'label': 'Euskirchen'}
# {'id': 'Q4075', 'label': 'Lyon OU'}
# {'id': 'Q4094', 'label': 'Hilden'}
# {'id': 'Q4097', 'label': 'pion'}
# {'id': 'Q4100', 'label': 'Baden-Baden'}
# {'id': 'Q4101', 'label': '15 BC'}
# {'id': 'Q4102', 'label': 'Lyon-Bron Airport'}
# {'id': 'Q4112', 'label': 'Stoneyburn'}
# {'id': 'Q4114', 'label': 'Dechmont'}
# {'id': 'Q4126', 'label': 'Schweinfurt'}
# {'id': 'Q4128', 'label': 'Louis Aragon'}
# {'id': 'Q4131', 'label': 'Hamilton'}
# {'id': 'Q4152', 'label': 'Neuschwanstein Castle'}
# {'id': 'Q4153', 'label': 'George Bournoutian'}
# {'id': 'Q4161', 'label': 'Category:Universities and colleges by continent'}
# {'id': 'Q4166', 'label': 'Category:Tajik Soviet Socialist Republic'}
# {'id': 'Q4190', 'label': 'Passau'}
# {'id': 'Q4194', 'label': 'Sauerland'}
# {'id': 'Q4201', 'label': '42 BC'}
# {'id': 'Q4209', 'label': '47 BC'}
# {'id': 'Q4219', 'label': 'Rothaar Mountains'}
# {'id': 'Q4230', 'label': 'Union of South American Nations'}
# {'id': 'Q4246', 'label': 'Category:Moldavian Soviet Socialist Republic'}
# {'id': 'Q4258', 'label': 'Place Carnot'}
# {'id': 'Q4261', 'label': 'Michel Platini'}
# {'id': 'Q4265', 'label': 'Category:History of Benin'}
# {'id': 'Q4267', 'label': 'Adémar de Chabannes'}
# {'id': 'Q4270', 'label': 'Tom DeLonge'}
# {'id': 'Q4280', 'label': 'Democratic Party'}
# {'id': 'Q4284', 'label': 'Lake Tarawera'}
# {'id': 'Q4290', 'label': 'investment'}
# {'id': 'Q4291', 'label': 'Ante Bilobrk'}
# {'id': 'Q4293', 'label': 'Jon Abrahams'}
# {'id': 'Q4299', 'label': 'Coheed and Cambria'}
# {'id': 'Q4312', 'label': 'Category:Colleges of music'}
# {'id': 'Q4318', 'label': 'Theopompus'}
# {'id': 'Q4319', 'label': 'list of languages by number of native speakers'}
# {'id': 'Q4328', 'label': 'Alberich of Reims'}
# {'id': 'Q4334', 'label': 'grace note'}
# {'id': 'Q4352', 'label': 'Category:Sweden stubs'}
# {'id': 'Q4357', 'label': 'Category:Estonian Soviet Socialist Republic'}
# {'id': 'Q4358', 'label': '2012 Ukrainian parliamentary election'}
# {'id': 'Q4359', 'label': 'DMG'}
# {'id': 'Q4360', 'label': 'pulsar'}
# {'id': 'Q4378', 'label': 'Titilupe'}
# {'id': 'Q4382', 'label': 'ice hockey at the 2014 Winter Olympics'}
# {'id': 'Q4388', 'label': 'Red squirrel'}
# {'id': 'Q4436', 'label': 'LX'}
# {'id': 'Q4441', 'label': 'Emily Dickinson'}
# {'id': 'Q4445', 'label': 'Category:Even-toed ungulates'}
# {'id': 'Q4459', 'label': 'Category:World Heritage Sites in Indonesia'}
# {'id': 'Q4466', 'label': 'Titanic II'}
# {'id': 'Q4467', 'label': 'Category:Soviet people'}
# {'id': 'Q4475', 'label': '10018 Lykawka'}
# {'id': 'Q4489', 'label': 'Stefanie Heinzmann'}
# {'id': 'Q4491', 'label': 'Anna Faris'}
# {'id': 'Q4496', 'label': 'Mitt Romney'}
# {'id': 'Q4497', 'label': 'Category:1421 births'}
# {'id': 'Q4498', 'label': 'Comtesse de Die'}
# {'id': 'Q4515', 'label': 'Category:Tunisian people'}
# {'id': 'Q4520', 'label': 'Komodo National Park'}
# {'id': 'Q4559', 'label': 'Category:Political parties by ideology'}
# {'id': 'Q4568', 'label': 'Berlin Recycling Volleys'}
# {'id': 'Q4575', 'label': 'flag of the Faroe Islands'}
# {'id': 'Q4582', 'label': 'Rancagua'}
# {'id': 'Q4597', 'label': 'Solomon Islands dollar'}
# {'id': 'Q4614', 'label': 'University of Southern California'}
# {'id': 'Q4624', 'label': 'Kölsch'}
# {'id': 'Q4637', 'label': 'Category:History of the Philippines'}
# {'id': 'Q4652', 'label': 'Mary Stewart'}
# {'id': 'Q4665', 'label': 'Colombian Championship 1962'}
# {'id': 'Q4671', 'label': 'Matthew Kneale'}
# {'id': 'Q4696', 'label': 'Pilot'}
# {'id': 'Q4700', 'label': 'Claude Debussy'}
# {'id': 'Q4705', 'label': 'C/2006 P1'}
# {'id': 'Q4708', 'label': 'Colombian Championship 1967'}
# {'id': 'Q4720', 'label': 'Colombian Championship 1991'}
# {'id': 'Q4721', 'label': 'Colombian Championship 1993'}
# {'id': 'Q4723', 'label': 'Charles II de Croÿ'}
# {'id': 'Q4740', 'label': 'Júnior César Moreira da Cunha'}
# {'id': 'Q4760', 'label': '2012 Major League Baseball season'}
# {'id': 'Q4761', 'label': 'Ernst Mielck'}
# {'id': 'Q4762', 'label': 'Roy Budd'}
# {'id': 'Q4767', 'label': 'Hawthornden Prize'}
# {'id': 'Q4769', 'label': 'Anthony Sweijs'}
# {'id': 'Q4817', 'label': 'column'}
# {'id': 'Q4820', 'label': 'Template:New Wave (Contest)'}
# {'id': 'Q4824', 'label': 'Yefimovsky'}
# {'id': 'Q4829', 'label': 'Category:Struma basin'}
# {'id': 'Q4834', 'label': 'Category:1888 births'}
# {'id': 'Q4835', 'label': 'Rafał Bigus'}
# {'id': 'Q4840', 'label': 'Spur Battery'}
# {'id': 'Q4847', 'label': 'Colombian Championship 1973'}
# {'id': 'Q4851', 'label': 'Kúty railway station'}
# {'id': 'Q4865', 'label': 'Colombian Championship 1986'}
# {'id': 'Q4874', 'label': 'Template:Arrondissements of Paris (navigational box)'}
# {'id': 'Q4876', 'label': 'Jan de Kreek'}
# {'id': 'Q4896', 'label': 'William Hamilton, 3rd Duke of Hamilton'}
# {'id': 'Q4911', 'label': '(6427) 1995 FY'}
# {'id': 'Q4926', 'label': 'Birger Kildal'}
# {'id': 'Q4929', 'label': 'Category:Popular music'}
# {'id': 'Q4930', 'label': 'e-health'}
# {'id': 'Q4937', 'label': 'Matachí'}
# {'id': 'Q4940', 'label': 'Macedonian mafia'}
# {'id': 'Q4949', 'label': 'Category:Geography of New Zealand'}
# {'id': 'Q4950', 'label': 'Category:Islands of New Zealand'}
# {'id': 'Q4955', 'label': 'Arleuf'}
# {'id': 'Q4957', 'label': 'NML Cygni'}
# {'id': 'Q4962', 'label': 'Georgia'}
# {'id': 'Q4969', 'label': 'Category:Radio stations in Italy'}
# {'id': 'Q4995', 'label': 'SABMiller'}
# {'id': 'Q5003', 'label': 'Ranchuelo'}
# {'id': 'Q5025', 'label': 'Category:19th century in the United Kingdom'}
# {'id': 'Q5029', 'label': 'Colón'}
# {'id': 'Q5035', 'label': 'Sjömarken'}
# {'id': 'Q5039', 'label': 'Category:Populated places in Gaziantep Province'}
# {'id': 'Q5045', 'label': 'Lajas'}
# {'id': 'Q5056', 'label': 'Template:Support'}
# {'id': 'Q5063', 'label': 'Not That Far Away'}
# {'id': 'Q5071', 'label': 'Emperor Xizong of Jin'}
# {'id': 'Q5072', 'label': 'Emperor Hailingwang of Jin'}
# {'id': 'Q5093', 'label': 'Maluku'}
# {'id': 'Q5114', 'label': "Stephan's Quintet"}
# {'id': 'Q5126', 'label': 'Category:Haan'}
# {'id': 'Q5134', 'label': 'Template:Lang-tr'}
# {'id': 'Q5142', 'label': 'deaths in 2012'}
# {'id': 'Q5146', 'label': 'Portuguese'}
# {'id': 'Q5156', 'label': 'Template:Footy-stub'}
# {'id': 'Q5164', 'label': '2007 Alpine Skiing World Cup'}
# {'id': 'Q5170', 'label': 'Blondel de Nesle'}
# {'id': 'Q5182', 'label': 'Kinorhyncha'}
# {'id': 'Q5191', 'label': 'Onychophora'}
# {'id': 'Q5198', 'label': 'Walter of Châtillon'}
# {'id': 'Q5206', 'label': 'Stavropol'}
# {'id': 'Q5221', 'label': '1956'}
# {'id': 'Q5233', 'label': 'François-Édouard Picot'}
# {'id': 'Q5250', 'label': '1210'}
# {'id': 'Q5255', 'label': '1212'}
# {'id': 'Q5257', 'label': 'Satavahana dynasty'}
# {'id': 'Q5259', 'label': '1926'}
# {'id': 'Q5275', 'label': 'astronomical clock'}
# {'id': 'Q5279', 'label': 'Nachrodt-Wiblingwerde'}
# {'id': 'Q5280', 'label': 'Laurent Mourguet'}
# {'id': 'Q5285', 'label': 'Tarlac City'}
# {'id': 'Q5300', 'label': 'central processing unit'}
# {'id': 'Q5301', 'label': 'TeX'}
# {'id': 'Q5317', 'label': 'Space Needle'}
# {'id': 'Q5321', 'label': 'resistor'}
# {'id': 'Q5322', 'label': 'capacitor'}
# {'id': 'Q5329', 'label': 'decibel'}
# {'id': 'Q5335', 'label': 'Harm Wiersma'}
# {'id': 'Q5345', 'label': 'Boris Sket'}
# {'id': 'Q5351', 'label': 'Guillaume IX'}
# {'id': 'Q5362', 'label': 'Narcis Mršić'}
# {'id': 'Q5363', 'label': 'Maria de Ventadorn'}
# {'id': 'Q5380', 'label': 'Robert de Boron'}
# {'id': 'Q5381', 'label': '1218'}
# {'id': 'Q5383', 'label': 'David Bowie'}
# {'id': 'Q5386', 'label': 'auto racing'}
# {'id': 'Q5389', 'label': 'Olympic Games'}
# {'id': 'Q5414', 'label': 'Great Dane'}
# {'id': 'Q5417', 'label': '1231'}
# {'id': 'Q5449', 'label': 'Yoshkar-Ola'}
# {'id': 'Q5453', 'label': 'Ars Magica'}
# {'id': 'Q5454', 'label': 'Isabella Teotochi Albrizzi'}
# {'id': 'Q5482', 'label': '1247'}
# {'id': 'Q5500', 'label': '1254'}
# {'id': 'Q5502', 'label': '1256'}
# {'id': 'Q5506', 'label': '1258'}
# {'id': 'Q5507', 'label': '1259'}
# {'id': 'Q5527', 'label': '1274'}
# {'id': 'Q5529', 'label': '1275'}
# {'id': 'Q5533', 'label': '1278'}
# {'id': 'Q5552', 'label': '1290'}
# {'id': 'Q5558', 'label': 'Bartolomeo Coghetto'}
# {'id': 'Q5563', 'label': '1298'}
# {'id': 'Q5565', 'label': 'Palazzo dei Trecento'}
# {'id': 'Q5571', 'label': 'Andrea del Sarto'}
# {'id': 'Q5578', 'label': 'Porta Santi Quaranta'}
# {'id': 'Q5580', 'label': 'Albrecht Dürer'}
# {'id': 'Q5583', 'label': 'Canale dei Buranelli'}
# {'id': 'Q5586', 'label': 'Katsushika Hokusai'}
# {'id': 'Q5587', 'label': 'Marloes Horst'}
# {'id': 'Q5594', 'label': 'Antonello da Messina'}
# {'id': 'Q5595', 'label': 'Curonian Spit'}
# {'id': 'Q5622', 'label': 'Neman'}
# {'id': 'Q5624', 'label': '1305'}
# {'id': 'Q5630', 'label': 'Fulcher of Chartres'}
# {'id': 'Q5632', 'label': 'Meschede'}
# {'id': 'Q5659', 'label': 'Conon de Béthune'}
# {'id': 'Q5664', 'label': 'Fra Angelico'}
# {'id': 'Q5670', 'label': 'Abu Nuwas'}
# {'id': 'Q5676', 'label': 'Matsuo Bashō'}
# {'id': 'Q5693', 'label': 'South Savo'}
# {'id': 'Q5699', 'label': 'Ur'}
# {'id': 'Q5707', 'label': 'Bjelovar'}
# {'id': 'Q5710', 'label': 'Bashkortostan'}
# {'id': 'Q5711', 'label': 'Uusimaa'}
# {'id': 'Q5713', 'label': 'Mary'}
# {'id': 'Q5721', 'label': 'Philippe Pétain'}
# {'id': 'Q5724', 'label': 'Anuradhapura'}
# {'id': 'Q5774', 'label': '1325'}
# {'id': 'Q5778', 'label': 'West Aceh'}
# {'id': 'Q5779', 'label': 'Banda Aceh City'}
# {'id': 'Q5786', 'label': 'Arch of Constantine'}
# {'id': 'Q5804', 'label': 'Deli Serdang'}
# {'id': 'Q5808', 'label': 'Humbang Hasundutan'}
# {'id': 'Q5811', 'label': 'Masaccio'}
# {'id': 'Q5813', 'label': 'Canary Islands'}
# {'id': 'Q5816', 'label': 'Mao Zedong'}
# {'id': 'Q5820', 'label': 'Mariya Savinova'}
# {'id': 'Q5826', 'label': "Xi'an"}
# {'id': 'Q5833', 'label': 'Langkat'}
# {'id': 'Q5836', 'label': 'Toledo'}
# {'id': 'Q5842', 'label': 'North Labuhanbatu'}
# {'id': 'Q5845', 'label': 'Actinopodidae'}
# {'id': 'Q5848', 'label': 'blue straggler'}
# {'id': 'Q5849', 'label': 'rugby union'}
# {'id': 'Q5857', 'label': 'North Padang Lawas'}
# {'id': 'Q5869', 'label': 'Lhasa'}
# {'id': 'Q5875', 'label': 'giant star'}
# {'id': 'Q5893', 'label': 'red dwarf'}
# {'id': 'Q5902', 'label': 'Red Dwarf'}
# {'id': 'Q5908', 'label': 'Aachen Cathedral'}
# {'id': 'Q5909', 'label': 'West Nias'}
# {'id': 'Q5916', 'label': 'spaceflight'}
# {'id': 'Q5921', 'label': 'Chuck Berry'}
# {'id': 'Q5940', 'label': 'Osnabrück'}
# {'id': 'Q5948', 'label': 'Wesermarsch'}
# {'id': 'Q5951', 'label': 'list of iCarly episodes'}
# {'id': 'Q5959', 'label': 'Quintus Curtius Rufus'}
# {'id': 'Q5960', 'label': 'Premiership Rugby'}
# {'id': 'Q5973', 'label': 'Holzminden'}
# {'id': 'Q5976', 'label': 'black dwarf'}
# {'id': 'Q5982', 'label': 'Siegen-Wittgenstein'}
# {'id': 'Q6010', 'label': 'rapping'}
# {'id': 'Q6015', 'label': 'Sundern'}
# {'id': 'Q6020', 'label': 'Lappajärvi'}
# {'id': 'Q6069', 'label': '1342'}
# {'id': 'Q6093', 'label': 'Tanah Datar'}
# {'id': 'Q6105', 'label': 'Hebe Camargo'}
# {'id': 'Q6106', 'label': 'Portland'}
# {'id': 'Q6119', 'label': 'Oberhavel District'}
# {'id': 'Q6123', 'label': '1355'}
# {'id': 'Q6126', 'label': '1500'}
# {'id': 'Q6130', 'label': '1356'}
# {'id': 'Q6135', 'label': '1357'}
# {'id': 'Q6138', 'label': '1408'}
# {'id': 'Q6140', 'label': '1358'}
# {'id': 'Q6143', 'label': '1359'}
# {'id': 'Q6149', 'label': 'Soest'}
# {'id': 'Q6152', 'label': 'Elbe-Elster District'}
# {'id': 'Q6154', 'label': '1506'}
# {'id': 'Q6167', 'label': 'Teuva'}
# {'id': 'Q6177', 'label': '1509'}
# {'id': 'Q6183', 'label': '1415'}
# {'id': 'Q6184', 'label': 'Plotius Tucca'}
# {'id': 'Q6187', 'label': 'Steinfurt'}
# {'id': 'Q6212', 'label': '1516'}
# {'id': 'Q6225', 'label': 'Coventry'}
# {'id': 'Q6230', 'label': 'Lippe'}
# {'id': 'Q6253', 'label': 'Rhein-Kreis Neuss'}
# {'id': 'Q6254', 'label': 'Kitos War'}
# {'id': 'Q6259', 'label': 'Pavia'}
# {'id': 'Q6263', 'label': '1517'}
# {'id': 'Q6267', 'label': '1423'}
# {'id': 'Q6282', 'label': '1376'}
# {'id': 'Q6283', 'label': '1425'}
# {'id': 'Q6284', 'label': '1520'}
# {'id': 'Q6318', 'label': 'Fiat G.55 Centauro'}
# {'id': 'Q6348', 'label': 'Caterine Ibargüen'}
# {'id': 'Q6360', 'label': '1434'}
# {'id': 'Q6361', 'label': 'Photoevaporation'}
# {'id': 'Q6363', 'label': 'Yevgeniya Kolodko'}
# {'id': 'Q6376', 'label': 'Somsdorf'}
# {'id': 'Q6378', 'label': '1391'}
# {'id': 'Q6382', 'label': '1392'}
# {'id': 'Q6388', 'label': 'swimming'}
# {'id': 'Q6393', 'label': 'Brive-la-Gaillarde'}
# {'id': 'Q6398', 'label': '1394'}
# {'id': 'Q6405', 'label': '1396'}
# {'id': 'Q6419', 'label': 'Barbora Špotáková'}
# {'id': 'Q6427', 'label': 'Christina Obergföll'}
# {'id': 'Q6434', 'label': 'Fulda'}
# {'id': 'Q6435', 'label': 'Reggiane Re.2004'}
# {'id': 'Q6438', 'label': 'Bahretal'}
# {'id': 'Q6439', 'label': '1448'}
# {'id': 'Q6441', 'label': 'Montpellier'}
# {'id': 'Q6443', 'label': '1533'}
# {'id': 'Q6455', 'label': '1451'}
# {'id': 'Q6460', 'label': '1452'}
# {'id': 'Q6477', 'label': 'Pirna'}
# {'id': 'Q6499', 'label': 'C-295'}
# {'id': 'Q6503', 'label': 'Caravelle'}
# {'id': 'Q6504', 'label': 'BAC One-Eleven'}
# {'id': 'Q6507', 'label': 'Finnegans Wake'}
# {'id': 'Q6512', 'label': 'Søren Kierkegaard'}
# {'id': 'Q6542', 'label': 'Herpesvirales'}
# {'id': 'Q6543', 'label': 'Khakassia'}
# {'id': 'Q6557', 'label': '1550'}
# {'id': 'Q6562', 'label': 'Category:Astronomers'}
# {'id': 'Q6569', 'label': '1470'}
# {'id': 'Q6584', 'label': 'mulled wine'}
# {'id': 'Q6592', 'label': 'trans-Neptunian object'}
# {'id': 'Q6594', 'label': '1473'}
# {'id': 'Q6596', 'label': 'Gorizia'}
# {'id': 'Q6599', 'label': 'plutino'}
# {'id': 'Q6603', 'label': 'Steenvoorde'}
# {'id': 'Q6615', 'label': 'Maçanet de Cabrenys'}
# {'id': 'Q6632', 'label': '1564'}
# {'id': 'Q6640', 'label': 'Pokhara'}
# {'id': 'Q6650', 'label': 'Canigou'}
# {'id': 'Q6653', 'label': '1569'}
# {'id': 'Q6654', 'label': 'Croatian'}
# {'id': 'Q6685', 'label': 'Dorfhain'}
# {'id': 'Q6706', 'label': 'UTC+01:30'}
# {'id': 'Q6710', 'label': 'Hartmannsdorf-Reichenau'}
# {'id': 'Q6716', 'label': 'Grosseto'}
# {'id': 'Q6735', 'label': '1603'}
# {'id': 'Q6744', 'label': '1587'}
# {'id': 'Q6747', 'label': '1606'}
# {'id': 'Q6750', 'label': 'Berliet'}
# {'id': 'Q6753', 'label': 'Banyuls-sur-Mer'}
# {'id': 'Q6756', 'label': '1607'}
# {'id': 'Q6758', 'label': '1608'}
# {'id': 'Q6767', 'label': 'U.S. Livorno 1915'}
# {'id': 'Q6772', 'label': '1593'}
# {'id': 'Q6775', 'label': 'Höckendorf'}
# {'id': 'Q6784', 'label': '1615'}
# {'id': 'Q6785', 'label': '1596'}
# {'id': 'Q6786', 'label': 'bottom quark'}
# {'id': 'Q6799', 'label': 'Neunkirchen'}
# {'id': 'Q6802', 'label': 'Merzig-Wadern'}
# {'id': 'Q6816', 'label': 'Ulan-Ude'}
# {'id': 'Q6820', 'label': 'Zauckerode'}
# {'id': 'Q6834', 'label': "Men's European Volleyball Championship"}
# {'id': 'Q6840', 'label': '1628'}
# {'id': 'Q6844', 'label': 'Hepatitis B virus'}
# {'id': 'Q6848', 'label': 'European Beach Volleyball Championships'}
# {'id': 'Q6857', 'label': '1709'}
# {'id': 'Q6865', 'label': '1632'}
# {'id': 'Q6867', 'label': 'International Astronomical Union'}
# {'id': 'Q6871', 'label': '1712'}
# {'id': 'Q6880', 'label': 'Neunkirchen'}
# {'id': 'Q6891', 'label': 'Battle of Bagradas'}
# {'id': 'Q6898', 'label': '1805'}
# {'id': 'Q6901', 'label': '1640'}
# {'id': 'Q6906', 'label': 'UTC+06:00'}
# {'id': 'Q6912', 'label': '1642'}
# {'id': 'Q6914', 'label': '1808'}
# {'id': 'Q6923', 'label': 'UTC+06:30'}
# {'id': 'Q6930', 'label': '1646'}
# {'id': 'Q6937', 'label': '1813'}
# {'id': 'Q6950', 'label': 'Tess Gerritsen'}
# {'id': 'Q6962', 'label': '1652'}
# {'id': 'Q6966', 'label': '1732'}
# {'id': 'Q6971', 'label': 'UTC+07:30'}
# {'id': 'Q6974', 'label': 'Human herpesvirus 6'}
# {'id': 'Q6976', 'label': '1821'}
# {'id': 'Q6980', 'label': 'Franxault'}
# {'id': 'Q6982', 'label': '1656'}
# {'id': 'Q6992', 'label': 'Alsdorf'}
# {'id': 'Q6998', 'label': 'Freising'}
# {'id': 'Q7007', 'label': 'Bitterfeld-Wolfen'}
# {'id': 'Q7015', 'label': '18th century'}
# {'id': 'Q7018', 'label': '15th century'}
# {'id': 'Q7024', 'label': 'Lugano'}
# {'id': 'Q7036', 'label': 'Brühl'}
# {'id': 'Q7043', 'label': 'Botifarra'}
# {'id': 'Q7044', 'label': 'Oberursel (Taunus)'}
# {'id': 'Q7048', 'label': 'UTC+09:30'}
# {'id': 'Q7064', 'label': 'hedonism'}
# {'id': 'Q7088', 'label': 'Kaarst'}
# {'id': 'Q7092', 'label': 'Eschenbach'}
# {'id': 'Q7102', 'label': 'Hochdorf'}
# {'id': 'Q7116', 'label': 'Altwis'}
# {'id': 'Q7130', 'label': 'UTC+14:00'}
# {'id': 'Q7150', 'label': 'ecology'}
# {'id': 'Q7162', 'label': 'genetics'}
# {'id': 'Q7183', 'label': 'Qin dynasty'}
# {'id': 'Q7186', 'label': 'Marie Curie'}
# {'id': 'Q7194', 'label': 'Province of Girona'}
# {'id': 'Q7197', 'label': 'Simone de Beauvoir'}
# {'id': 'Q7203', 'label': 'Ziying'}
# {'id': 'Q7216', 'label': "Pirates II: Stagnetti's Revenge"}
# {'id': 'Q7227', 'label': 'Emperor Zhao of Han'}
# {'id': 'Q7235', 'label': 'Sophocles'}
# {'id': 'Q7237', 'label': 'Emperor Ai of Han'}
# {'id': 'Q7239', 'label': 'organism'}
# {'id': 'Q7249', 'label': 'Agnes Pockels'}
# {'id': 'Q7262', 'label': 'Emperor Gengshi of Han'}
# {'id': 'Q7270', 'label': 'republic'}
# {'id': 'Q7277', 'label': 'Emperor Zhang of Han'}
# {'id': 'Q7290', 'label': 'Annette Salmeen'}
# {'id': 'Q7301', 'label': 'Prince of Hongnong'}
# {'id': 'Q7318', 'label': 'Nazi Germany'}
# {'id': 'Q7320', 'label': 'Nazi Party'}
# {'id': 'Q7329', 'label': 'Cheetoh'}
# {'id': 'Q7336', 'label': 'Otto Heinrich Frank'}
# {'id': 'Q7338', 'label': 'Kurilian Bobtail'}
# {'id': 'Q7339', 'label': 'Margot Frank'}
# {'id': 'Q7346', 'label': 'John Coltrane'}
# {'id': 'Q7348', 'label': 'Indus River'}
# {'id': 'Q7357', 'label': 'Emperor Hui of Jin'}
# {'id': 'Q7365', 'label': 'muscle'}
# {'id': 'Q7368', 'label': 'sheep'}
# {'id': 'Q7381', 'label': 'Muaro Jambi'}
# {'id': 'Q7383', 'label': 'Sarolangun'}
# {'id': 'Q7392', 'label': 'Emperor Yuan of Jin'}
# {'id': 'Q7394', 'label': 'Emperor Cheng of Jin'}
# {'id': 'Q7396', 'label': 'Emperor Mu of Jin'}
# {'id': 'Q7421', 'label': 'Kathryn Uhrich'}
# {'id': 'Q7458', 'label': 'Emperor Xianzong of Western Xia'}
# {'id': 'Q7464', 'label': 'Tenderloin'}
# {'id': 'Q7487', 'label': 'Dorothy Hodgkin'}
# {'id': 'Q7507', 'label': 'Wermelskirchen'}
# {'id': 'Q7511', 'label': 'Jing Li'}
# {'id': 'Q7514', 'label': 'Olivia Lum'}
# {'id': 'Q7519', 'label': 'Ögedei Khan'}
# {'id': 'Q7525', 'label': 'Sevastopol'}
# {'id': 'Q7529', 'label': 'Ashkenaz'}
# {'id': 'Q7530', 'label': 'Volhynia'}
# {'id': 'Q7534', 'label': 'Elizabeth J. Feinler'}
# {'id': 'Q7546', 'label': 'Ingmar Bergman'}
# {'id': 'Q7549', 'label': 'Sandra Lerner'}
# {'id': 'Q7550', 'label': 'Lutsk'}
# {'id': 'Q7560', 'label': 'mother'}
# {'id': 'Q7561', 'label': 'snow'}
# {'id': 'Q7573', 'label': '1741'}
# {'id': 'Q7579', 'label': '1831'}
# {'id': 'Q7580', 'label': '1743'}
# {'id': 'Q7584', 'label': '1832'}
# {'id': 'Q7585', 'label': '1666'}
# {'id': 'Q7588', 'label': '1667'}
# {'id': 'Q7589', 'label': '1746'}
# {'id': 'Q7600', 'label': '1748'}
# {'id': 'Q7607', 'label': '1749'}
# {'id': 'Q7610', 'label': '1671'}
# {'id': 'Q7611', 'label': '1750'}
# {'id': 'Q7618', 'label': '1752'}
# {'id': 'Q7620', 'label': '1674'}
# {'id': 'Q7621', 'label': '1753'}
# {'id': 'Q7638', 'label': '1679'}
# {'id': 'Q7640', 'label': '1846'}
# {'id': 'Q7657', 'label': 'Boksitogorsky District'}
# {'id': 'Q7658', 'label': 'Heidi Weng'}
# {'id': 'Q7665', 'label': '1765'}
# {'id': 'Q7683', 'label': '1770'}
# {'id': 'Q7685', 'label': '1692'}
# {'id': 'Q7692', 'label': '1773'}
# {'id': 'Q7707', 'label': 'water polo'}
# {'id': 'Q7710', 'label': '1699'}
# {'id': 'Q7728', 'label': 'Grazia Deledda'}
# {'id': 'Q7744', 'label': 'Rokan Hulu'}
# {'id': 'Q7765', 'label': '1788'}
# {'id': 'Q7766', 'label': '1876'}
# {'id': 'Q7769', 'label': 'Birobidzhan'}
# {'id': 'Q7772', 'label': '1789'}
# {'id': 'Q7778', 'label': 'history of France'}
# {'id': 'Q7788', 'label': 'Khabarovsk Krai'}
# {'id': 'Q7789', 'label': 'Ambrogio Bergognone'}
# {'id': 'Q7795', 'label': 'Organization of the Petroleum Exporting Countries'}
# {'id': 'Q7801', 'label': 'International Court of Justice'}
# {'id': 'Q7806', 'label': '1880'}
# {'id': 'Q7810', 'label': 'Homer Simpson'}
# {'id': 'Q7813', 'label': 'Universal Declaration of Human Rights'}
# {'id': 'Q7815', 'label': '1795'}
# {'id': 'Q7830', 'label': 'Sudak'}
# {'id': 'Q7844', 'label': '1895'}
# {'id': 'Q7847', 'label': '1897'}
# {'id': 'Q7856', 'label': 'rallying'}
# {'id': 'Q7858', 'label': 'Nordhausen district'}
# {'id': 'Q7863', 'label': 'shower'}
# {'id': 'Q7866', 'label': 'Wartburgkreis'}
# {'id': 'Q7869', 'label': 'Gotha'}
# {'id': 'Q7882', 'label': 'Landkreis Saalfeld-Rudolstadt'}
# {'id': 'Q7887', 'label': 'Greiz'}
# {'id': 'Q7899', 'label': 'Fulda'}
# {'id': 'Q7911', 'label': 'Main-Kinzig-Kreis'}
# {'id': 'Q7917', 'label': 'Landkreis Bergstraße'}
# {'id': 'Q7918', 'label': 'Bulgarian'}
# {'id': 'Q7922', 'label': 'pedagogy'}
# {'id': 'Q7926', 'label': 'Düsseldorf Government Region'}
# {'id': 'Q7941', 'label': 'Kirovsky District'}
# {'id': 'Q7949', 'label': 'truth'}
# {'id': 'Q7959', 'label': 'Luzhsky District'}
# {'id': 'Q7971', 'label': 'Magadan Oblast'}
# {'id': 'Q7987', 'label': 'mouse'}
# {'id': 'Q7996', 'label': 'Ivan IV Vasilyevich'}
# {'id': 'Q8017', 'label': 'MHRA Style Guide'}
# {'id': 'Q8025', 'label': 'Indian Grand Prix'}
# {'id': 'Q8028', 'label': 'fairy'}
# {'id': 'Q8032', 'label': 'Indianapolis 500'}
# {'id': 'Q8033', 'label': 'Muko Muko'}
# {'id': 'Q8040', 'label': 'South Bengkulu'}
# {'id': 'Q8056', 'label': 'Louis Antoine de Pardaillan de Gondrin'}
# {'id': 'Q8062', 'label': 'economy of the Republic of Ireland'}
# {'id': 'Q8093', 'label': 'Nintendo'}
# {'id': 'Q8094', 'label': 'wind'}
# {'id': 'Q8112', 'label': 'Empat Lawang'}
# {'id': 'Q8113', 'label': 'Järviseutu sub-region'}
# {'id': 'Q8116', 'label': 'Suupohja'}
# {'id': 'Q8121', 'label': 'Musi Rawas'}
# {'id': 'Q8131', 'label': 'Palembang'}
# {'id': 'Q8145', 'label': 'Pringsewu'}
# {'id': 'Q8161', 'label': 'tax'}
# {'id': 'Q8163', 'label': 'Bangka Regency'}
# {'id': 'Q8167', 'label': 'Freiburg Government Region'}
# {'id': 'Q8169', 'label': 'East Belitung'}
# {'id': 'Q8170', 'label': 'Tübingen Government Region'}
# {'id': 'Q8179', 'label': 'Pangkal Pinang City'}
# {'id': 'Q8184', 'label': 'Enz'}
# {'id': 'Q8191', 'label': 'Ortenau'}
# {'id': 'Q8194', 'label': 'Iława'}
# {'id': 'Q8207', 'label': 'Les Cordeliers'}
# {'id': 'Q8209', 'label': 'Cyrillic script'}
# {'id': 'Q8234', 'label': 'Rosenthal-Bielatal'}
# {'id': 'Q8244', 'label': 'Struppen'}
# {'id': 'Q8247', 'label': 'Biratnagar'}
# {'id': 'Q8259', 'label': 'Category:Literature'}
# {'id': 'Q8269', 'label': 'The Tale of Genji'}
# {'id': 'Q8277', 'label': 'multiple sclerosis'}
# {'id': 'Q8283', 'label': 'Verwaltungsgemeinschaft Tharandt'}
# {'id': 'Q8285', 'label': 'myasthenia gravis'}
# {'id': 'Q8288', 'label': 'Wikimedia Deutschland'}
# {'id': 'Q8289', 'label': 'Jamie Selkirk'}
# {'id': 'Q8292', 'label': 'Moncloa Pacts'}
# {'id': 'Q8303', 'label': 'Kuolema'}
# {'id': 'Q8319', 'label': 'Arkansas River'}
# {'id': 'Q8331', 'label': 'fox'}
# {'id': 'Q8336', 'label': 'Hockenheim'}
# {'id': 'Q8340', 'label': 'Matte World Digital'}
# {'id': 'Q8341', 'label': 'jazz'}
# {'id': 'Q8364', 'label': '( )'}
# {'id': 'Q8365', 'label': 'Dardilly'}
# {'id': 'Q8367', 'label': 'Hans Schmidt'}
# {'id': 'Q8383', 'label': 'Maison de la danse'}
# {'id': 'Q8387', 'label': 'Grand Parc de Miribel-Jonage'}
# {'id': 'Q8390', 'label': 'Visual Effects Society Awards 2002'}
# {'id': 'Q8404', 'label': 'John I of France'}
# {'id': 'Q8413', 'label': 'Constantine the Great'}
# {'id': 'Q8419', 'label': 'rue du Bœuf'}
# {'id': 'Q8445', 'label': 'marriage'}
# {'id': 'Q8449', 'label': 'Spanish Wikipedia'}
# {'id': 'Q8458', 'label': 'human rights'}
# {'id': 'Q8477', 'label': 'Highway 1'}
# {'id': 'Q8479', 'label': 'Peter the Great'}
# {'id': 'Q8480', 'label': 'Logar River'}
# {'id': 'Q8483', 'label': '1st Chess Olympiad'}
# {'id': 'Q8485', 'label': 'Ghorband River'}
# {'id': 'Q8488', 'label': '1992 Summer Olympics'}
# {'id': 'Q8497', 'label': 'Visual Effects Society Awards 2008'}
# {'id': 'Q8499', 'label': 'Visual Effects Society Awards 2009'}

# %%
import pandas as pd
df = next(pd.read_csv("./my-data/organization_descriptions.csv", chunksize=100))

# %%
df
# Out:
#                                     uuid             name          type  \
# 0   e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1   bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2   5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3   f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4   df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
# ..                                   ...              ...           ...
# 95  b7c000b8-0b00-9936-7e3f-7954f1af2949        Flybridge  organization
# 96  93ef5a7c-8369-f255-8533-0861c3ad43ad  CriticalMetrics  organization
# 97  424cedf8-20ac-2ffe-8a09-689a76f69e3c           ZenZui  organization
# 98  d68fcedd-3a0d-28f9-4805-9f22211c364f            Spock  organization
# 99  42d01582-809b-095a-6576-886cbb6dce51             Wize  organization
#
#             permalink                                             cb_url  \
# 0            wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1                zoho       https://www.crunchbase.com/organization/zoho
# 2                digg       https://www.crunchbase.com/organization/digg
# 3     omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4            facebook   https://www.crunchbase.com/organization/facebook
# ..                ...                                                ...
# 95  flybridge-capital  https://www.crunchbase.com/organization/flybri...
# 96    criticalmetrics  https://www.crunchbase.com/organization/critic...
# 97             zenzui     https://www.crunchbase.com/organization/zenzui
# 98              spock      https://www.crunchbase.com/organization/spock
# 99               wize       https://www.crunchbase.com/organization/wize
#
#        rank           created_at           updated_at  \
# 0    178728  2007-05-25 13:51:27  2024-03-21 11:01:38
# 1    181583  2007-05-26 02:30:28  2024-04-16 03:23:50
# 2     31367  2007-05-26 03:03:23  2024-01-26 08:06:40
# 3     79998  2007-05-26 03:21:34  2024-06-06 16:26:51
# 4     12068  2007-05-26 04:22:15  2023-11-27 12:05:27
# ..      ...                  ...                  ...
# 95   248279  2007-06-28 15:32:52  2024-06-06 09:37:48
# 96  2840402  2007-06-28 15:48:04  2019-06-24 21:22:32
# 97  1764950  2007-06-28 15:51:40  2020-07-08 03:12:53
# 98   333083  2007-06-28 16:02:56  2023-12-05 10:11:05
# 99   345538  2007-06-28 16:08:16  2023-12-13 10:19:23
#
#                                           description
# 0   Wetpaint is a technology platform company that...
# 1   Zoho offers a suite of business, collaboration...
# 2   Digg Inc. operates a website that enables its ...
# 3   Pierre Omidyar, the founder of eBay, and his w...
# 4   Meta is a social technology company that enabl...
# ..                                                ...
# 95  Flybridge is a seed-stage VC investing with en...
# 96  A startup by Suck.com alum, Joey Anuff, Critic...
# 97  ZenZui a new mobile browser that aims to make ...
# 98  Spock is a people search engine which collects...
# 99  Finding the products that are right for you an...
#
# [100 rows x 9 columns]

# %%
import pandas as pd
df = next(pd.read_csv("./my-data/organizations.csv", chunksize=100))
df
# Out:
#                                     uuid                 name          type  \
# 0   e1393508-30ea-8a36-3f96-dd3226033abd             Wetpaint  organization
# 1   bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                 Zoho  organization
# 2   5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                 Digg  organization
# 3   f4d5ab44-058b-298b-ea81-380e6e9a8eec      Omidyar Network  organization
# 4   df662812-7f97-0b43-9d3e-12f64f504fbb                 Meta  organization
# ..                                   ...                  ...           ...
# 95  3d02b92f-668f-1a97-5c12-5d7646ae3ffe  Aggregate Knowledge  organization
# 96  74cb3f14-aac0-d2a7-df71-0fd6236cda6b         Zing Systems  organization
# 97  b7c000b8-0b00-9936-7e3f-7954f1af2949            Flybridge  organization
# 98  93ef5a7c-8369-f255-8533-0861c3ad43ad      CriticalMetrics  organization
# 99  424cedf8-20ac-2ffe-8a09-689a76f69e3c               ZenZui  organization
#
#              permalink                                             cb_url  \
# 0             wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1                 zoho       https://www.crunchbase.com/organization/zoho
# 2                 digg       https://www.crunchbase.com/organization/digg
# 3      omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4             facebook   https://www.crunchbase.com/organization/facebook
# ..                 ...                                                ...
# 95  aggregateknowledge  https://www.crunchbase.com/organization/aggreg...
# 96                zing       https://www.crunchbase.com/organization/zing
# 97   flybridge-capital  https://www.crunchbase.com/organization/flybri...
# 98     criticalmetrics  https://www.crunchbase.com/organization/critic...
# 99              zenzui     https://www.crunchbase.com/organization/zenzui
#
#        rank           created_at           updated_at  \
# 0    178728  2007-05-25 13:51:27  2024-03-21 11:01:38
# 1    181583  2007-05-26 02:30:28  2024-04-16 03:23:50
# 2     31367  2007-05-26 03:03:23  2024-01-26 08:06:40
# 3     79998  2007-05-26 03:21:34  2024-06-06 16:26:51
# 4     12068  2007-05-26 04:22:15  2023-11-27 12:05:27
# ..      ...                  ...                  ...
# 95   198144  2007-06-28 15:04:25  2021-09-20 12:24:55
# 96   377344  2007-06-28 15:27:24  2024-01-09 18:29:37
# 97   248279  2007-06-28 15:32:52  2024-06-06 09:37:48
# 98  2840402  2007-06-28 15:48:04  2019-06-24 21:22:32
# 99  1764950  2007-06-28 15:51:40  2020-07-08 03:12:53
#
#                       legal_name             roles  ...  \
# 0                            NaN           company  ...
# 1     Zoho Corporation Pvt. Ltd.  investor,company  ...
# 2             Digg Holdings, LLC           company  ...
# 3   Omidyar Network Services LLC  investor,company  ...
# 4           Meta Platforms, Inc.  investor,company  ...
# ..                           ...               ...  ...
# 95     Aggregate Knowledge, Inc.           company  ...
# 96                           NaN           company  ...
# 97    Flybridge Capital Partners  investor,company  ...
# 98                           NaN           company  ...
# 99                           NaN           company  ...
#
#                            phone                            facebook_url  \
# 0                   206-859-6300       https://www.facebook.com/Wetpaint
# 1   1800 103 1123 /1800 572 3535            http://www.facebook.com/zoho
# 2                            NaN            http://www.facebook.com/digg
# 3                   650.482.2500  http://www.facebook.com/OmidyarNetwork
# 4                            NaN           https://www.facebook.com/Meta
# ..                           ...                                     ...
# 95                (877) 245-5277                                     NaN
# 96                 (650)267-2400                                     NaN
# 97                  617.307.9292                                     NaN
# 98                           NaN                                     NaN
# 99                           NaN                                     NaN
#
#                                          linkedin_url  \
# 0   https://www.linkedin.com/company/recruitment-c...
# 1               https://www.linkedin.com/company/zoho
# 2                http://www.linkedin.com/company/digg
# 3               http://www.linkedin.com/company/22806
# 4               https://www.linkedin.com/company/meta
# ..                                                ...
# 95  https://www.linkedin.com/company/aggregate-kno...
# 96                                                NaN
# 97  https://www.linkedin.com/company/flybridge-cap...
# 98                                                NaN
# 99                                                NaN
#
#                           twitter_url  \
# 0      https://twitter.com/wetpainttv
# 1             http://twitter.com/zoho
# 2             http://twitter.com/digg
# 3   http://twitter.com/OmidyarNetwork
# 4        https://www.twitter.com/Meta
# ..                                ...
# 95  http://twitter.com/akIntelligence
# 96                                NaN
# 97       http://twitter.com/flybridge
# 98                                NaN
# 99                                NaN
#
#                                              logo_url               alias1  \
# 0   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 1   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 2   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 3   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 4   https://images.crunchbase.com/image/upload/t_c...             Facebook
# ..                                                ...                  ...
# 95  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 96  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 97  https://images.crunchbase.com/image/upload/t_c...  IDG Ventures Boston
# 98  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 99  https://images.crunchbase.com/image/upload/t_c...                  NaN
#
#             alias2 alias3 primary_role num_exits
# 0              NaN    NaN      company       NaN
# 1              NaN    NaN      company       2.0
# 2              NaN    NaN      company       NaN
# 3              NaN    NaN     investor      63.0
# 4   Facebook, Inc.     FB      company       1.0
# ..             ...    ...          ...       ...
# 95             NaN    NaN      company       NaN
# 96             NaN    NaN      company       NaN
# 97             NaN    NaN     investor      74.0
# 98             NaN    NaN      company       NaN
# 99             NaN    NaN      company       NaN
#
# [100 rows x 41 columns]

# %%
import bz2
import json
import os
import sys
import traceback
from pymongo import MongoClient
from tqdm import tqdm
from datetime import datetime


def create_indexes(db):
    # Specify the collections and their respective fields to be indexed
    index_specs = {
        'cache': ['cell', 'lastAccessed', "limit"],  # Example: Indexing 'cell' and 'type' fields in 'cache' collection
        'items': ['id_entity', 'entity', 'category', 'popularity'],
        'literals': ['id_entity', 'entity'],
        'types': ['id_entity', 'entity']
    }

    for collection, fields in index_specs.items():
        if collection == "cache":
            db[collection].create_index(
                [
                    ("name", 1),
                    ("limit", 1),
                    ("kg", 1),
                    ("fuzzy", 1),
                    ("types", 1),
                    ("kind", 1),
                    ("NERtype", 1),
                    ("language", 1),
                ],
                unique=True,
                background=True,  # Create the index in the background
            )
        elif collection == "items":
            db[collection].create_index([('entity', 1), ('kind', 1)], unique=True)    
        for field in fields:
            db[collection].create_index([(field, 1)])  # 1 for ascending order


# MongoDB connection setup
MONGO_ENDPOINT, MONGO_ENDPOINT_PORT = os.environ["MONGO_ENDPOINT"].split(":")
MONGO_ENDPOINT_PORT = int(MONGO_ENDPOINT_PORT)
current_date = datetime.now()
formatted_date = current_date.strftime("%d%m%Y")
DB_NAME = f"crunchbase"

client = MongoClient(MONGO_ENDPOINT, MONGO_ENDPOINT_PORT)
log_c = client[DB_NAME].log
items_c = client[DB_NAME].items
literals_c = client[DB_NAME].literals
types_c = client[DB_NAME].types

c_ref = {
    "items": items_c,
    "literals":literals_c, 
    "types":types_c
}

create_indexes(client[DB_NAME])

buffer = {
    "items": [],
    "literals": [], 
    "types": []
}


def flush_buffer(buffer):
    for key in buffer:
        if len(buffer[key]) > 0:
            c_ref[key].insert_many(buffer[key])
            buffer[key] = []
            

def classify_value(value):
    try:
        # Check if value is a datetime
        dateutil.parser.isoparse(value)
        return 'DATETIME'
    except (ValueError, TypeError):
        pass
    try:
        # Check if value is a number
        float(value)
        return 'NUMBER'
    except (ValueError, TypeError):
        pass
    # If neither, it's a string
    return 'STRING'
    
def parse_data(index, columns, data, addional_data):
    objects = {}
    literals = {datatype: {} for datatype in ["STRING", "DATETIME", "NUMBER"]}
    types = {"P31": ["Organization"]}
    join = {
        "items": {
            "id_entity": i,
            "entity": entity,
            "description": description,
            "labels": all_labels,
            "aliases": all_aliases,
            "types": types,
            "popularity": popularity,
            "kind": "entity",
            "NERtype": "ORG"
        },
        "objects": { 
            "id_entity": i,
            "entity": entity,
            "objects":objects
        },
        "literals": { 
            "id_entity": i,
            "entity": entity,
            "literals": literals
        },
        "types": { 
            "id_entity": i,
            "entity": entity,
            "types": types
        },
    }

    

    for key in buffer:
        buffer[key].append(join[key])            

    if len(buffer["items"]) == BATCH_SIZE:
        flush_buffer(buffer)


           
# Read large CSV file in chunks
chunk_size = 1000  # Adjust chunk size as needed
file_path = './my-data/organizations.csv'  # Update with your file path

# Determine the number of chunks for progress bar
total_lines = sum(1 for _ in open(file_path))
total_chunks = total_lines // chunk_size + (1 if total_lines % chunk_size != 0 else 0)
index = 0
# Process the file in chunks
with tqdm(total=total_chunks, desc="Processing") as pbar:
    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        #process_and_insert(chunk, items)
        columns = chunk.columns
        for _, data in chunk.iterrows():
            for column in columns:
                print(data[column])  
        pbar.update(1)

print("Finished processing and inserting documents.")
# Out:
# Processing: 100%|█████████▉| 3493/3494 [00:24<00:00, 141.00it/s]
# Finished processing and inserting documents.

# %%
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
columns = chunk.columns
for _, data in chunk.iterrows():
    for column in columns:
        print(data[column])   
    break

# %%
import pandas as pd
df = next(pd.read_csv("../data/organizations.csv", chunksize=100))
df
# Out:
#                                     uuid                 name          type  \
# 0   e1393508-30ea-8a36-3f96-dd3226033abd             Wetpaint  organization
# 1   bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                 Zoho  organization
# 2   5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                 Digg  organization
# 3   f4d5ab44-058b-298b-ea81-380e6e9a8eec      Omidyar Network  organization
# 4   df662812-7f97-0b43-9d3e-12f64f504fbb                 Meta  organization
# ..                                   ...                  ...           ...
# 95  3d02b92f-668f-1a97-5c12-5d7646ae3ffe  Aggregate Knowledge  organization
# 96  74cb3f14-aac0-d2a7-df71-0fd6236cda6b         Zing Systems  organization
# 97  b7c000b8-0b00-9936-7e3f-7954f1af2949            Flybridge  organization
# 98  93ef5a7c-8369-f255-8533-0861c3ad43ad      CriticalMetrics  organization
# 99  424cedf8-20ac-2ffe-8a09-689a76f69e3c               ZenZui  organization
#
#              permalink                                             cb_url  \
# 0             wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1                 zoho       https://www.crunchbase.com/organization/zoho
# 2                 digg       https://www.crunchbase.com/organization/digg
# 3      omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4             facebook   https://www.crunchbase.com/organization/facebook
# ..                 ...                                                ...
# 95  aggregateknowledge  https://www.crunchbase.com/organization/aggreg...
# 96                zing       https://www.crunchbase.com/organization/zing
# 97   flybridge-capital  https://www.crunchbase.com/organization/flybri...
# 98     criticalmetrics  https://www.crunchbase.com/organization/critic...
# 99              zenzui     https://www.crunchbase.com/organization/zenzui
#
#        rank           created_at           updated_at  \
# 0    178728  2007-05-25 13:51:27  2024-03-21 11:01:38
# 1    181583  2007-05-26 02:30:28  2024-04-16 03:23:50
# 2     31367  2007-05-26 03:03:23  2024-01-26 08:06:40
# 3     79998  2007-05-26 03:21:34  2024-06-06 16:26:51
# 4     12068  2007-05-26 04:22:15  2023-11-27 12:05:27
# ..      ...                  ...                  ...
# 95   198144  2007-06-28 15:04:25  2021-09-20 12:24:55
# 96   377344  2007-06-28 15:27:24  2024-01-09 18:29:37
# 97   248279  2007-06-28 15:32:52  2024-06-06 09:37:48
# 98  2840402  2007-06-28 15:48:04  2019-06-24 21:22:32
# 99  1764950  2007-06-28 15:51:40  2020-07-08 03:12:53
#
#                       legal_name             roles  ...  \
# 0                            NaN           company  ...
# 1     Zoho Corporation Pvt. Ltd.  investor,company  ...
# 2             Digg Holdings, LLC           company  ...
# 3   Omidyar Network Services LLC  investor,company  ...
# 4           Meta Platforms, Inc.  investor,company  ...
# ..                           ...               ...  ...
# 95     Aggregate Knowledge, Inc.           company  ...
# 96                           NaN           company  ...
# 97    Flybridge Capital Partners  investor,company  ...
# 98                           NaN           company  ...
# 99                           NaN           company  ...
#
#                            phone                            facebook_url  \
# 0                   206-859-6300       https://www.facebook.com/Wetpaint
# 1   1800 103 1123 /1800 572 3535            http://www.facebook.com/zoho
# 2                            NaN            http://www.facebook.com/digg
# 3                   650.482.2500  http://www.facebook.com/OmidyarNetwork
# 4                            NaN           https://www.facebook.com/Meta
# ..                           ...                                     ...
# 95                (877) 245-5277                                     NaN
# 96                 (650)267-2400                                     NaN
# 97                  617.307.9292                                     NaN
# 98                           NaN                                     NaN
# 99                           NaN                                     NaN
#
#                                          linkedin_url  \
# 0   https://www.linkedin.com/company/recruitment-c...
# 1               https://www.linkedin.com/company/zoho
# 2                http://www.linkedin.com/company/digg
# 3               http://www.linkedin.com/company/22806
# 4               https://www.linkedin.com/company/meta
# ..                                                ...
# 95  https://www.linkedin.com/company/aggregate-kno...
# 96                                                NaN
# 97  https://www.linkedin.com/company/flybridge-cap...
# 98                                                NaN
# 99                                                NaN
#
#                           twitter_url  \
# 0      https://twitter.com/wetpainttv
# 1             http://twitter.com/zoho
# 2             http://twitter.com/digg
# 3   http://twitter.com/OmidyarNetwork
# 4        https://www.twitter.com/Meta
# ..                                ...
# 95  http://twitter.com/akIntelligence
# 96                                NaN
# 97       http://twitter.com/flybridge
# 98                                NaN
# 99                                NaN
#
#                                              logo_url               alias1  \
# 0   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 1   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 2   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 3   https://images.crunchbase.com/image/upload/t_c...                  NaN
# 4   https://images.crunchbase.com/image/upload/t_c...             Facebook
# ..                                                ...                  ...
# 95  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 96  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 97  https://images.crunchbase.com/image/upload/t_c...  IDG Ventures Boston
# 98  https://images.crunchbase.com/image/upload/t_c...                  NaN
# 99  https://images.crunchbase.com/image/upload/t_c...                  NaN
#
#             alias2 alias3 primary_role num_exits
# 0              NaN    NaN      company       NaN
# 1              NaN    NaN      company       2.0
# 2              NaN    NaN      company       NaN
# 3              NaN    NaN     investor      63.0
# 4   Facebook, Inc.     FB      company       1.0
# ..             ...    ...          ...       ...
# 95             NaN    NaN      company       NaN
# 96             NaN    NaN      company       NaN
# 97             NaN    NaN     investor      74.0
# 98             NaN    NaN      company       NaN
# 99             NaN    NaN      company       NaN
#
# [100 rows x 41 columns]

# %%
import pandas as pd
df = next(pd.read_csv("./my-data/organization_descriptions.csv", chunksize=100))
df
# Out:
#                                     uuid             name          type  \
# 0   e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint  organization
# 1   bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  organization
# 2   5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg  organization
# 3   f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  organization
# 4   df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  organization
# ..                                   ...              ...           ...
# 95  b7c000b8-0b00-9936-7e3f-7954f1af2949        Flybridge  organization
# 96  93ef5a7c-8369-f255-8533-0861c3ad43ad  CriticalMetrics  organization
# 97  424cedf8-20ac-2ffe-8a09-689a76f69e3c           ZenZui  organization
# 98  d68fcedd-3a0d-28f9-4805-9f22211c364f            Spock  organization
# 99  42d01582-809b-095a-6576-886cbb6dce51             Wize  organization
#
#             permalink                                             cb_url  \
# 0            wetpaint   https://www.crunchbase.com/organization/wetpaint
# 1                zoho       https://www.crunchbase.com/organization/zoho
# 2                digg       https://www.crunchbase.com/organization/digg
# 3     omidyar-network  https://www.crunchbase.com/organization/omidya...
# 4            facebook   https://www.crunchbase.com/organization/facebook
# ..                ...                                                ...
# 95  flybridge-capital  https://www.crunchbase.com/organization/flybri...
# 96    criticalmetrics  https://www.crunchbase.com/organization/critic...
# 97             zenzui     https://www.crunchbase.com/organization/zenzui
# 98              spock      https://www.crunchbase.com/organization/spock
# 99               wize       https://www.crunchbase.com/organization/wize
#
#        rank           created_at           updated_at  \
# 0    178728  2007-05-25 13:51:27  2024-03-21 11:01:38
# 1    181583  2007-05-26 02:30:28  2024-04-16 03:23:50
# 2     31367  2007-05-26 03:03:23  2024-01-26 08:06:40
# 3     79998  2007-05-26 03:21:34  2024-06-06 16:26:51
# 4     12068  2007-05-26 04:22:15  2023-11-27 12:05:27
# ..      ...                  ...                  ...
# 95   248279  2007-06-28 15:32:52  2024-06-06 09:37:48
# 96  2840402  2007-06-28 15:48:04  2019-06-24 21:22:32
# 97  1764950  2007-06-28 15:51:40  2020-07-08 03:12:53
# 98   333083  2007-06-28 16:02:56  2023-12-05 10:11:05
# 99   345538  2007-06-28 16:08:16  2023-12-13 10:19:23
#
#                                           description
# 0   Wetpaint is a technology platform company that...
# 1   Zoho offers a suite of business, collaboration...
# 2   Digg Inc. operates a website that enables its ...
# 3   Pierre Omidyar, the founder of eBay, and his w...
# 4   Meta is a social technology company that enabl...
# ..                                                ...
# 95  Flybridge is a seed-stage VC investing with en...
# 96  A startup by Suck.com alum, Joey Anuff, Critic...
# 97  ZenZui a new mobile browser that aims to make ...
# 98  Spock is a people search engine which collects...
# 99  Finding the products that are right for you an...
#
# [100 rows x 9 columns]

# %%
# Read large CSV file in chunks
chunk_size = 1000  # Adjust chunk size as needed
file_path = './my-data/organization_descriptions.csv'  # Update with your file path

# Determine the number of chunks for progress bar
total_lines = sum(1 for _ in open(file_path))
total_chunks = total_lines // chunk_size + (1 if total_lines % chunk_size != 0 else 0)
index = 0
data = {}
# Process the file in chunks
with tqdm(total=total_chunks, desc="Processing") as pbar:
    for chunk in pd.read_csv(file_path, chunksize=chunk_size):
        columns = chunk.columns
        for _, data in chunk.iterrows():
            id = data["uuid"]
            url = data["cb_url"]
            popularity = data["rank"]
            description = data["description"]
            data[id] = {
                "url": url,  
                "description": description,
                "popularity": popularity
            }
        pbar.update(1)

# %%
import pandas as pd
df = pd.read_csv("../data/organizations.csv")

# %%
df["rank"]
# Out:
# 0          178728.0
# 1          181583.0
# 2           31367.0
# 3           79998.0
# 4           12068.0
#              ...
# 3492519         NaN
# 3492520         NaN
# 3492521         NaN
# 3492522         NaN
# 3492523         NaN
# Name: rank, Length: 3492524, dtype: float64

# %%
int(df["rank"].mean())
# Out:
# 1670122
