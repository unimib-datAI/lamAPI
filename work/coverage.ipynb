# %%
import pandas as pd

def find_id_in_list(dict_list, target_id):
    for group_name, items in dict_list.items():
        for item in items:
            #print(f"{item['id']} --> {target_id}")
            if item['id'] == target_id:
                return item, group_name
    return None, None  # Return None if id is not found

def edit_distance(str1, str2):
    # Create a 2D list to store edit distances
    dp = [[0] * (len(str2) + 1) for _ in range(len(str1) + 1)]

    # Initialize the first row and column
    for i in range(len(str1) + 1):
        dp[i][0] = i
    for j in range(len(str2) + 1):
        dp[0][j] = j

    # Fill in the rest of the dp table
    for i in range(1, len(str1) + 1):
        for j in range(1, len(str2) + 1):
            if str1[i - 1] == str2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]  # No operation needed
            else:
                dp[i][j] = 1 + min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1])

    # The bottom-right corner of the dp table contains the edit distance
    edit_dist = dp[len(str1)][len(str2)]
    
    # Normalize the edit distance between 0 and 1
    max_len = max(len(str1), len(str2))
    normalized_edit_dist = 1 - (edit_dist / max_len)
    
    return normalized_edit_dist

def jaccard_similarity(str1, str2):
    # Convert strings to sets of characters (or tokens)
    set1 = set(str1)
    set2 = set(str2)
    
    # Compute intersection and union of the sets
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    
    # Calculate Jaccard similarity
    if len(union) == 0:
        return 0.0  # Handle the case where both sets are empty
    else:
        jaccard_score = len(intersection) / len(union)
        return jaccard_score

# %%
cea_file = './my-data/Dataset/Dataset/Round1_T2D/gt/CEA_Round1_gt_WD.csv'
mentions = {}
chunk_size = 1000
column_names = ["table_name", "row", "col", "url"] 

for chunk_cea in pd.read_csv(cea_file, chunksize=chunk_size):
        chunk_cea.columns = column_names
        for _, row in chunk_cea.iterrows():
            parts = row['url'].split('/')
            wikidata_id = parts[-1]
            
            # find the mention in the table
            table_file = './my-data/Dataset/Dataset/Round1_T2D/tables/' + row['table_name'] + '.csv'
            df = pd.read_csv(table_file)
            num_rows, num_columns = df.shape
            if row['row'] < num_rows and row['col'] < num_columns:
                cell_value = df.iloc[row['row'], row['col']]
                if cell_value not in mentions:
                    mentions[cell_value] = [row['url']]
                else:
                    mentions[cell_value].append(row['url'])

print(mentions)

# %%
GT_file = './my-data/dataset_GT/Round1_T2D_f3.csv'

chunk_size = 1000  # Adjust this based on your memory constraints

ids = {}
column_names = ["table_name", "row", "col", "url"] 

# Iterate over the CSV file in chunks
for chunk_GT in pd.read_csv(GT_file, chunksize=chunk_size):
    for _, row in chunk_GT.iterrows():
        if row['target'] == 1:
            ids['https://www.wikidata.org/entity/' + row['id']] = {"name": row['name'],"ed_score": row['ed_score'],"jaccard_score": row['jaccard_score']}


print(ids)

# %%
mapp_def = {}

for key, value in mentions.items():        
    tmp = []
    for el in value:
        try:
            if el not in mapp_def:
                #mapp_def[el] = [{ids[el]['name']: key, "ed_score": ids[el]['ed_score'],"jaccard_score": ids[el]['jaccard_score']}]
                mapp_def[el] = [{ids[el]['name']: key, "ed_score": edit_distance(ids[el]['name'], key),"jaccard_score": jaccard_similarity(ids[el]['name'], key)}]
            else:
                #mapp_def[el].append({ids[el]['name']: key, "ed_score": ids[el]['ed_score'],"jaccard_score": ids[el]['jaccard_score']})
                mapp_def[el].append({ids[el]['name']: key, "ed_score": edit_distance(ids[el]['name'], key),"jaccard_score": jaccard_similarity(ids[el]['name'], key)})
        except:
            pass

# %%
mapp_def
# Out:
# {'https://www.wikidata.org/entity/Q219795': [{'need for speed: carbon': 'Need for Speed: Hot Pursuit',
#    'ed_score': 0.5555555555555556,
#    'jaccard_score': 0.45},
#   {'need for speed: carbon': 'Sim City',
#    'ed_score': 0.045454545454545414,
#    'jaccard_score': 0.05263157894736842},
#   {'need for speed: carbon': 'Little Big Planet',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.2},
#   {'need for speed: carbon': 'Need for Speed ProStreet',
#    'ed_score': 0.5416666666666667,
#    'jaccard_score': 0.4117647058823529},
#   {'need for speed: carbon': 'Wario Ware: Smooth Moves',
#    'ed_score': 0.125,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q558664': [{'alex rodriguez': 'Alex Ochoa',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.375},
#   {'alex rodriguez': 'Cal Ripken Jr.',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.3157894736842105}],
#  'https://www.wikidata.org/entity/Q309048': [{'king kong': 'The King of Comedy',
#    'ed_score': 0.2777777777777778,
#    'jaccard_score': 0.3333333333333333},
#   {'king kong': 'The Bridge on the River Kwai',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2777777777777778},
#   {'king kong': 'Clerks.',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.08333333333333333}],
#  'https://www.wikidata.org/entity/Q820753': [{'school of rock': 'Se7en',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0}],
#  'https://www.wikidata.org/entity/Q5639157': [{'haiku tunnel': 'Se7en',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.16666666666666666},
#   {'haiku tunnel': 'Nineteen Eighty-Four',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.3888888888888889}],
#  'https://www.wikidata.org/entity/Q6072725': [{'iron monkey': 'Se7en',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.18181818181818182}],
#  'https://www.wikidata.org/entity/Q115347': [{'lex luger': 'Ric Flair',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q597808': [{'crash bash': 'Twisted Metal',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.2},
#   {'crash bash': 'Tomb Raider IV: Die letzte Offenbarung',
#    'ed_score': 0.10526315789473684,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q216995': [{'super mario 64': 'Twisted Metal',
#    'ed_score': 0.0,
#    'jaccard_score': 0.2777777777777778},
#   {'super mario 64': 'GoldenEye 007', 'ed_score': 0.0, 'jaccard_score': 0.15},
#   {'super mario 64': 'Chrono Trigger',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.29411764705882354},
#   {'super mario 64': 'Mario Kart 64',
#    'ed_score': 0.4285714285714286,
#    'jaccard_score': 0.4666666666666667},
#   {'super mario 64': 'Mario Kart 64',
#    'ed_score': 0.4285714285714286,
#    'jaccard_score': 0.4666666666666667}],
#  'https://www.wikidata.org/entity/Q183066': [{'the hurt locker': 'Avatar',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q187278': [{'toy story 3': 'Avatar',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.2},
#   {'toy story 3': 'Rango',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.09090909090909091}],
#  'https://www.wikidata.org/entity/Q140': [{'lion': 'Mandrill',
#    'ed_score': 0.125,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q958928': [{'lac seul': "Lac-a-l'eau-Claire",
#    'ed_score': 0.2777777777777778,
#    'jaccard_score': 0.38461538461538464}],
#  'https://www.wikidata.org/entity/Q23395': [{'fear and loathing in las vegas': "Ferris Bueller's Day Off",
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.36363636363636365},
#   {'fear and loathing in las vegas': "Ferris Bueller's Day Off",
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.36363636363636365}],
#  'https://www.wikidata.org/entity/Q109767': [{'the blues brothers': "Ferris Bueller's Day Off",
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.3157894736842105},
#   {'the blues brothers': 'Bonnie and Clyde',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.23529411764705882},
#   {'the blues brothers': 'Rushmore',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q217220': [{'patton': "Ferris Bueller's Day Off",
#    'ed_score': 0.04166666666666663,
#    'jaccard_score': 0.05263157894736842},
#   {'patton': 'Peeping Tom',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q9387': [{'max weber': 'Richard Strauss',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q1630654': [{'kidsty pike': 'Dow Crag',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.0625}],
#  'https://www.wikidata.org/entity/Q123682': [{'randy johnson': 'Lefty Grove?',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.23529411764705882}],
#  'https://www.wikidata.org/entity/Q1759045': [{'timeshift': 'Time Leap',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.25},
#   {'timeshift': 'TNA iMPACT',
#    'ed_score': 0.0,
#    'jaccard_score': 0.07142857142857142}],
#  'https://www.wikidata.org/entity/Q288811': [{'batman: arkham city': 'Super Mario Galaxy 2',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.21739130434782608},
#   {'batman: arkham city': 'Super Mario Galaxy 2[132]',
#    'ed_score': 0.12,
#    'jaccard_score': 0.18518518518518517}],
#  'https://www.wikidata.org/entity/Q370055': [{'the legend of zelda: a link to the past': 'Super Mario Galaxy 2',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.28},
#   {'the legend of zelda: a link to the past': 'The Legend of the Mystical Ninja',
#    'ed_score': 0.3846153846153846,
#    'jaccard_score': 0.5416666666666666},
#   {'the legend of zelda: a link to the past': 'The Elder Scrolls III: Morrowind',
#    'ed_score': 0.23076923076923073,
#    'jaccard_score': 0.4},
#   {'the legend of zelda: a link to the past': 'Sonic the Hedgehog[130]',
#    'ed_score': 0.10256410256410253,
#    'jaccard_score': 0.36}],
#  'https://www.wikidata.org/entity/Q1179317': [{'dazzy vance': 'Claude Osteen',
#    'ed_score': 0.23076923076923073,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q181086': [{'a clockwork orange': 'Easy Rider',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.23529411764705882},
#   {'a clockwork orange': 'All about Eve',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.29411764705882354},
#   {'a clockwork orange': 'Jaws',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.15384615384615385},
#   {'a clockwork orange': 'Close Encounters of the Third Kind',
#    'ed_score': 0.17647058823529416,
#    'jaccard_score': 0.3181818181818182},
#   {'a clockwork orange': 'Closer',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.3076923076923077}],
#  'https://www.wikidata.org/entity/Q11621': [{'e.t. the extra-terrestrial': 'Easy Rider',
#    'ed_score': 0.11538461538461542,
#    'jaccard_score': 0.375},
#   {'e.t. the extra-terrestrial': 'Blade Runner',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.29411764705882354},
#   {'e.t. the extra-terrestrial': 'The Good, the Bad and the Ugly',
#    'ed_score': 0.23333333333333328,
#    'jaccard_score': 0.2727272727272727},
#   {'e.t. the extra-terrestrial': 'Annie Hall',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.3333333333333333},
#   {'e.t. the extra-terrestrial': 'The Searchers',
#    'ed_score': 0.2692307692307693,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q577221': [{'session 9': 'Easy Rider',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.3076923076923077}],
#  'https://www.wikidata.org/entity/Q202211': [{'gandhi': 'Easy Rider',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.23076923076923078},
#   {'gandhi': 'Gangs of New York',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.17647058823529413},
#   {'gandhi': 'Gattaca',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.1111111111111111}],
#  'https://www.wikidata.org/entity/Q4908526': [{'bill collins': 'Danny Murphy',
#    'ed_score': 0.0,
#    'jaccard_score': 0.125}],
#  'https://www.wikidata.org/entity/Q223': [{'greenland': 'Faroe Islands',
#    'ed_score': 0.46153846153846156,
#    'jaccard_score': 0.5},
#   {'greenland': 'Saudi Arabia',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q138397': [{'thunbergia grandiflora': 'Thunbergia laurifolia',
#    'ed_score': 0.6363636363636364,
#    'jaccard_score': 0.8125}],
#  'https://www.wikidata.org/entity/Q6201201': [{'jimmy ryan': 'John Reilly',
#    'ed_score': 0.0,
#    'jaccard_score': 0.2857142857142857},
#   {'jimmy ryan': 'Fred Carroll',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.21428571428571427}],
#  'https://www.wikidata.org/entity/Q132783': [{'state hermitage museum': 'Brooklyn Museum of Art',
#    'ed_score': 0.045454545454545414,
#    'jaccard_score': 0.35}],
#  'https://www.wikidata.org/entity/Q6707803': [{'lygodium palmatum': 'Maesopsis eminii',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q208526': [{'new taiwan dollar': 'Somoni',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q209170': [{'mary poppins': 'A Night at the Opera',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.29411764705882354},
#   {'mary poppins': 'The Matrix',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1137217': [{'the curse of monkey island': 'DTM Race Driver 3',
#    'ed_score': 0.1923076923076923,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1058903': [{'super mario all-stars + super mario world': 'Final Fantasy VII',
#    'ed_score': 0.14634146341463417,
#    'jaccard_score': 0.2857142857142857},
#   {'super mario all-stars + super mario world': 'Pok?mon - Crystal Edition',
#    'ed_score': 0.19512195121951215,
#    'jaccard_score': 0.4782608695652174}],
#  'https://www.wikidata.org/entity/Q838162': [{'lappet-faced vulture': 'Black-chested snake-eagle',
#    'ed_score': 0.24,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q598983': [{'contender': 'Spiderman',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q1087308': [{'grey-backed fiscal': "Mackinnon's fiscal",
#    'ed_score': 0.38888888888888884,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q42198': [{'heat': 'Paths of Glory',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.23076923076923078},
#   {'heat': 'Toy Story', 'ed_score': 0.11111111111111116, 'jaccard_score': 0.1},
#   {'heat': 'Dark Days', 'ed_score': 0.11111111111111116, 'jaccard_score': 0.1},
#   {'heat': 'Heathers', 'ed_score': 0.375, 'jaccard_score': 0.5714285714285714},
#   {'heat': 'Once Upon a Time in the West',
#    'ed_score': 0.1071428571428571,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q622380': [{'pather panchali': 'Paths of Glory',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.35294117647058826}],
#  'https://www.wikidata.org/entity/Q109135': [{'trainspotting': 'Paths of Glory',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.3125},
#   {'trainspotting': 'The Treasure of the Sierra Madre',
#    'ed_score': 0.15625,
#    'jaccard_score': 0.3333333333333333},
#   {'trainspotting': 'The Seventh Seal',
#    'ed_score': 0.0625,
#    'jaccard_score': 0.1875}],
#  'https://www.wikidata.org/entity/Q47144': [{'pope linus': 'Lorenzo Ruiz[?]',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.375},
#   {'pope linus': 'Lorenzo Ruiz[?]',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q4973329': [{'broken bow lake': 'Canton Lake',
#    'ed_score': 0.4,
#    'jaccard_score': 0.46153846153846156}],
#  'https://www.wikidata.org/entity/Q922192': [{'tree swallow': 'NORTHERN ROUGH-WINGED SWALLOW',
#    'ed_score': 0.03448275862068961,
#    'jaccard_score': 0.041666666666666664}],
#  'https://www.wikidata.org/entity/Q994481': [{'the wild bunch': 'Wild Strawberries',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.47058823529411764},
#   {'the wild bunch': 'Jurassic Park',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.2222222222222222}],
#  'https://www.wikidata.org/entity/Q957323': [{'blazing saddles': 'Wild Strawberries',
#    'ed_score': 0.17647058823529416,
#    'jaccard_score': 0.5},
#   {'blazing saddles': 'Madagascar',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.2857142857142857},
#   {'blazing saddles': 'Blood Diamond',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.4},
#   {'blazing saddles': 'Blood Simple',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.3125},
#   {'blazing saddles': 'Ninotchka',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q575014': [{'sanjuro': 'Wild Strawberries',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q842259': [{'fifa 08': 'Battlefield 2',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.3333333333333333},
#   {'fifa 08': 'Fight Night Round 3',
#    'ed_score': 0.10526315789473684,
#    'jaccard_score': 0.11764705882352941},
#   {'fifa 08': 'Duke Nukem 3D',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.07692307692307693}],
#  'https://www.wikidata.org/entity/Q213911': [{'the legend of zelda: ocarina of time': 'GoldenEye 007',
#    'ed_score': 0.13888888888888884,
#    'jaccard_score': 0.2727272727272727},
#   {'the legend of zelda: ocarina of time': 'GoldenEye 007',
#    'ed_score': 0.13888888888888884,
#    'jaccard_score': 0.2727272727272727},
#   {'the legend of zelda: ocarina of time': 'Goldeneye 007',
#    'ed_score': 0.13888888888888884,
#    'jaccard_score': 0.2857142857142857},
#   {'the legend of zelda: ocarina of time': "The Legend of Zelda: Majora's Mask",
#    'ed_score': 0.5833333333333333,
#    'jaccard_score': 0.48},
#   {'the legend of zelda: ocarina of time': 'Star Fox 64',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.22727272727272727},
#   {'the legend of zelda: ocarina of time': 'Donkey Kong 64',
#    'ed_score': 0.13888888888888884,
#    'jaccard_score': 0.21739130434782608}],
#  'https://www.wikidata.org/entity/Q5442444': [{'fellbarrow': 'Grange Fell',
#    'ed_score': 0.0,
#    'jaccard_score': 0.3076923076923077}],
#  'https://www.wikidata.org/entity/Q249854': [{'sim city': 'Pok?mon Pinball',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.2},
#   {'sim city': 'Age Of Empires III',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1816048': [{'asparagus densiflorus': 'Austroeupatorium inulaefolium',
#    'ed_score': 0.24137931034482762,
#    'jaccard_score': 0.7058823529411765}],
#  'https://www.wikidata.org/entity/Q190388': [{'john of the cross': 'John of Damascus',
#    'ed_score': 0.47058823529411764,
#    'jaccard_score': 0.4375},
#   {'john of the cross': 'John of Damascus',
#    'ed_score': 0.47058823529411764,
#    'jaccard_score': 0.4375}],
#  'https://www.wikidata.org/entity/Q3294145': [{'mark langston': 'Hippo Vaughn',
#    'ed_score': 0.23076923076923073,
#    'jaccard_score': 0.29411764705882354}],
#  'https://www.wikidata.org/entity/Q2535021': [{'soldier of fortune: pay back': 'Sonic the Hedgehog',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.34782608695652173}],
#  'https://www.wikidata.org/entity/Q1133204': [{'street fighter ii': 'Sonic the Hedgehog',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.4},
#   {'street fighter ii': 'The Secret of Monkey Island',
#    'ed_score': 0.2592592592592593,
#    'jaccard_score': 0.3333333333333333},
#   {'street fighter ii': 'Super Probotector: Alien Rebels',
#    'ed_score': 0.19354838709677424,
#    'jaccard_score': 0.2857142857142857},
#   {'street fighter ii': 'Stronghold',
#    'ed_score': 0.23529411764705888,
#    'jaccard_score': 0.2857142857142857}],
#  'https://www.wikidata.org/entity/Q786099': [{'life as a house': 'One Hour Photo',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.3125}],
#  'https://www.wikidata.org/entity/Q1048800': [{'brown parrot': 'Grey parrot',
#    'ed_score': 0.6666666666666667,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q838154': [{'my cousin vinny': 'Mystery, Alaska',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.15789473684210525}],
#  'https://www.wikidata.org/entity/Q274529': [{'the book of eli': "She's Out of My League",
#    'ed_score': 0.31818181818181823,
#    'jaccard_score': 0.3}],
#  'https://www.wikidata.org/entity/Q7331172': [{'kaw lake': 'Kerr Reservoir',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q132473': [{'paulinus of nola': 'Perpetua and her companions',
#    'ed_score': 0.2592592592592593,
#    'jaccard_score': 0.4444444444444444},
#   {'paulinus of nola': 'Perpetua and her companions',
#    'ed_score': 0.2592592592592593,
#    'jaccard_score': 0.4444444444444444}],
#  'https://www.wikidata.org/entity/Q1357016': [{'three kings': 'The Man Who Would be King',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.3},
#   {'three kings': 'Throne of Blood',
#    'ed_score': 0.2666666666666667,
#    'jaccard_score': 0.3125}],
#  'https://www.wikidata.org/entity/Q1586976': [{'orchard oriole': 'BALTIMORE ORIOLE',
#    'ed_score': 0.0625,
#    'jaccard_score': 0.05263157894736842}],
#  'https://www.wikidata.org/entity/Q2062140': [{'swingers': 'Taxi Driver',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q127367': [{'lord of the rings: the fellowship of the ring': 'Taxi Driver',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.19047619047619047},
#   {'lord of the rings: the fellowship of the ring': 'Titanic',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.15789473684210525},
#   {'lord of the rings: the fellowship of the ring': 'Am?lie',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.15789473684210525},
#   {'lord of the rings: the fellowship of the ring': 'The Lord of the Rings: The Return of the King',
#    'ed_score': 0.6222222222222222,
#    'jaccard_score': 0.6190476190476191},
#   {'lord of the rings: the fellowship of the ring': 'The Night of the Hunter',
#    'ed_score': 0.28888888888888886,
#    'jaccard_score': 0.5},
#   {'lord of the rings: the fellowship of the ring': 'Braveheart',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.21052631578947367},
#   {'lord of the rings: the fellowship of the ring': 'Super Troopers',
#    'ed_score': 0.15555555555555556,
#    'jaccard_score': 0.3157894736842105}],
#  'https://www.wikidata.org/entity/Q220780': [{'raging bull': 'Taxi Driver',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.2857142857142857},
#   {'raging bull': 'American Beauty',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.375},
#   {'raging bull': 'Raiders of the Lost Ark',
#    'ed_score': 0.08695652173913049,
#    'jaccard_score': 0.2},
#   {'raging bull': 'Rain Man',
#    'ed_score': 0.36363636363636365,
#    'jaccard_score': 0.36363636363636365}],
#  'https://www.wikidata.org/entity/Q233464': [{'annie hall': 'Taxi Driver',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.3333333333333333},
#   {'annie hall': 'Goodfellas',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.25},
#   {'annie hall': 'The Seven Samurai',
#    'ed_score': 0.17647058823529416,
#    'jaccard_score': 0.46153846153846156},
#   {'annie hall': 'The Apartment',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.38461538461538464},
#   {'annie hall': 'The Graduate',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.3076923076923077}],
#  'https://www.wikidata.org/entity/Q132689': [{'casablanca': 'Taxi Driver',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.07142857142857142},
#   {'casablanca': 'Lawrence of Arabia',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.26666666666666666},
#   {'casablanca': 'Casino Royale',
#    'ed_score': 0.23076923076923073,
#    'jaccard_score': 0.3076923076923077},
#   {'casablanca': 'Casino',
#    'ed_score': 0.30000000000000004,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q7206132': [{'poa cusickii': 'Poa pratensis',
#    'ed_score': 0.3076923076923077,
#    'jaccard_score': 0.42857142857142855}],
#  'https://www.wikidata.org/entity/Q784116': [{'ice harvest': 'Surviving Christmas',
#    'ed_score': 0.21052631578947367,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q10743709': [{'litsea glutinosa': 'Lobelia zeylanica',
#    'ed_score': 0.23529411764705888,
#    'jaccard_score': 0.4375}],
#  'https://www.wikidata.org/entity/Q4897444': [{'die sims': 'Mario Party 4',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.14285714285714285},
#   {'die sims': 'NCAA Football 2003',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.05555555555555555},
#   {'die sims': 'Age of Empires II',
#    'ed_score': 0.23529411764705888,
#    'jaccard_score': 0.35714285714285715}],
#  'https://www.wikidata.org/entity/Q518987': [{'donkey kong country': 'Donkey Kong Country 2',
#    'ed_score': 0.7619047619047619,
#    'jaccard_score': 0.625},
#   {'donkey kong country': 'Super Smash Bros. Melee',
#    'ed_score': 0.13043478260869568,
#    'jaccard_score': 0.22727272727272727},
#   {'donkey kong country': 'Super Mario Land',
#    'ed_score': 0.1578947368421053,
#    'jaccard_score': 0.3888888888888889},
#   {'donkey kong country': 'F-Zero',
#    'ed_score': 0.10526315789473684,
#    'jaccard_score': 0.2},
#   {'donkey kong country': 'Samurai Shodown',
#    'ed_score': 0.10526315789473684,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q18840': [{'common greenshank': 'Grey-headed gull',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q733738': [{'melbourne airport': 'Paris-Orly Airport',
#    'ed_score': 0.4444444444444444,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q5019563': [{'calf crag': 'Great Mell Fell',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q469839': [{'mexican': 'Smoke Signals',
#    'ed_score': 0.3076923076923077,
#    'jaccard_score': 0.35714285714285715}],
#  'https://www.wikidata.org/entity/Q3315420': [{'snowy-headed robin-chat': 'Red-capped robin-chat',
#    'ed_score': 0.6086956521739131,
#    'jaccard_score': 0.7222222222222222}],
#  'https://www.wikidata.org/entity/Q2827233': [{'brown-backed scrub-robin': 'Spotted mourning-thrush',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.47619047619047616}],
#  'https://www.wikidata.org/entity/Q1765733': [{'metroid prime': 'Halo Combat Evolved',
#    'ed_score': 0.1578947368421053,
#    'jaccard_score': 0.375},
#   {'metroid prime': 'Grand Theft Auto III',
#    'ed_score': 0.050000000000000044,
#    'jaccard_score': 0.3333333333333333},
#   {'metroid prime': 'Grand Theft Auto III',
#    'ed_score': 0.050000000000000044,
#    'jaccard_score': 0.3333333333333333},
#   {'metroid prime': 'Halo: Combat Evolved',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.35294117647058826},
#   {'metroid prime': 'Pokemon Colosseum',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1368166': [{'san diego museum of art': 'Mauritshuis',
#    'ed_score': 0.17391304347826086,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q6553901': [{'lingmoor fell': 'Barf',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.16666666666666666}],
#  'https://www.wikidata.org/entity/Q1462437': [{"james cameron's avatar: the game": 'Juiced 2: Hot Import Nights',
#    'ed_score': 0.1875,
#    'jaccard_score': 0.44}],
#  'https://www.wikidata.org/entity/Q392698': [{'john woo presents stranglehold': 'Juiced 2: Hot Import Nights',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q2225630': [{'rattling cisticola': 'Winding cisticola',
#    'ed_score': 0.7222222222222222,
#    'jaccard_score': 0.7692307692307693}],
#  'https://www.wikidata.org/entity/Q152350': [{'the battleship potemkin': 'Breathless',
#    'ed_score': 0.26086956521739135,
#    'jaccard_score': 0.375},
#   {'the battleship potemkin': 'Brazil',
#    'ed_score': 0.08695652173913049,
#    'jaccard_score': 0.17647058823529413},
#   {'the battleship potemkin': 'A Beautiful Mind',
#    'ed_score': 0.17391304347826086,
#    'jaccard_score': 0.35}],
#  'https://www.wikidata.org/entity/Q538412': [{'breaking the waves': 'Breathless',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q190804': [{'rijksmuseum': 'Museo Nacional del Prado',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.2777777777777778}],
#  'https://www.wikidata.org/entity/Q2267775': [{'andropogon hallii': 'Andropogon ternarius',
#    'ed_score': 0.55,
#    'jaccard_score': 0.5625}],
#  'https://www.wikidata.org/entity/Q62730': [{'das boot': 'Born on the Fourth of July',
#    'ed_score': 0.11538461538461542,
#    'jaccard_score': 0.16666666666666666},
#   {'das boot': 'The African Queen',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.1111111111111111},
#   {'das boot': 'Super Troopers',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q616313': [{'star wars: clone wars': 'Superman: The Animated Series',
#    'ed_score': 0.24137931034482762,
#    'jaccard_score': 0.38095238095238093}],
#  'https://www.wikidata.org/entity/Q225': [{'bosnia and herzegovina': 'Brazil',
#    'ed_score': 0.13636363636363635,
#    'jaccard_score': 0.25},
#   {'bosnia and herzegovina': 'South Carolina',
#    'ed_score': 0.31818181818181823,
#    'jaccard_score': 0.3684210526315789},
#   {'bosnia and herzegovina': 'Singapore',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.4375},
#   {'bosnia and herzegovina': 'India',
#    'ed_score': 0.18181818181818177,
#    'jaccard_score': 0.26666666666666666}],
#  'https://www.wikidata.org/entity/Q162729': [{'braveheart': 'Brazil',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.18181818181818182},
#   {'braveheart': 'Gone with the Wind',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.2},
#   {'braveheart': 'Trainspotting',
#    'ed_score': 0.23076923076923073,
#    'jaccard_score': 0.21428571428571427},
#   {'braveheart': 'Heat',
#    'ed_score': 0.30000000000000004,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q252': [{'indonesia': 'Brazil',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.18181818181818182},
#   {'indonesia': 'Croatia',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.3},
#   {'indonesia': 'Iran',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.2222222222222222},
#   {'indonesia': 'Mexico (country)',
#    'ed_score': 0.1875,
#    'jaccard_score': 0.23529411764705882}],
#  'https://www.wikidata.org/entity/Q165394': [{'bowling for columbine': 'Brazil',
#    'ed_score': 0.09523809523809523,
#    'jaccard_score': 0.17647058823529413},
#   {'bowling for columbine': 'Femme Fatale',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.23529411764705882},
#   {'bowling for columbine': 'Boyz N the Hood',
#    'ed_score': 0.19047619047619047,
#    'jaccard_score': 0.13636363636363635},
#   {'bowling for columbine': 'Koyaanisqatsi',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.15}],
#  'https://www.wikidata.org/entity/Q408': [{'australia': 'Brazil',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.4444444444444444},
#   {'australia': 'Austria',
#    'ed_score': 0.6666666666666667,
#    'jaccard_score': 0.75},
#   {'australia': 'Austria',
#    'ed_score': 0.6666666666666667,
#    'jaccard_score': 0.75},
#   {'australia': 'Sri Lanka',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q191': [{'estonia': 'Brazil',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.18181818181818182},
#   {'estonia': 'Bhutan', 'ed_score': 0.1428571428571429, 'jaccard_score': 0.3},
#   {'estonia': 'Mauritius',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q274167': [{'the exorcist': 'Brazil',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.14285714285714285},
#   {'the exorcist': 'Eyes Wide Shut',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q975773': [{'gran turismo 3 a-spec': 'Super Mario World',
#    'ed_score': 0.19047619047619047,
#    'jaccard_score': 0.38095238095238093},
#   {'gran turismo 3 a-spec': 'SOCOM: U.S. Navy Seals',
#    'ed_score': 0.045454545454545414,
#    'jaccard_score': 0.14814814814814814}],
#  'https://www.wikidata.org/entity/Q1368099': [{'super probotector: alien rebels': 'Super Mario World',
#    'ed_score': 0.29032258064516125,
#    'jaccard_score': 0.47368421052631576}],
#  'https://www.wikidata.org/entity/Q106316': [{'dead poets society': "Rosemary's Baby",
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.35294117647058826},
#   {'dead poets society': 'The Decalogue',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.29411764705882354},
#   {'dead poets society': 'Deja Vu',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q109564': [{'rope': "Rosemary's Baby",
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q2016661': [{"say it isn't so": "Rosemary's Baby",
#    'ed_score': 0.0,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q221249': [{'tootsie': 'Top Gun',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.09090909090909091},
#   {'tootsie': 'American Graffiti',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.21428571428571427},
#   {'tootsie': 'Yojimbo',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2222222222222222}],
#  'https://www.wikidata.org/entity/Q240318': [{'black-billed wood-dove': 'Tambourine dove',
#    'ed_score': 0.31818181818181823,
#    'jaccard_score': 0.4444444444444444}],
#  'https://www.wikidata.org/entity/Q732943': [{"the legend of zelda: majora's mask": 'Super Smash Bros.',
#    'ed_score': 0.1470588235294118,
#    'jaccard_score': 0.3333333333333333},
#   {"the legend of zelda: majora's mask": 'Wii Sports Resort',
#    'ed_score': 0.1470588235294118,
#    'jaccard_score': 0.25},
#   {"the legend of zelda: majora's mask": 'Cruisin USA',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.16}],
#  'https://www.wikidata.org/entity/Q639619': [{'super mario bros. 3': 'Super Smash Bros.',
#    'ed_score': 0.5789473684210527,
#    'jaccard_score': 0.625}],
#  'https://www.wikidata.org/entity/Q692664': [{'eastern chipmunk': 'WOODCHUCK',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0}],
#  'https://www.wikidata.org/entity/Q134694': [{'pope innocent i': 'Irenaeus of Lyons',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.25},
#   {'pope innocent i': 'Irenaeus of Lyons',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q177428': [{'archives of internal medicine': 'white dwarf',
#    'ed_score': 0.2068965517241379,
#    'jaccard_score': 0.5294117647058824}],
#  'https://www.wikidata.org/entity/Q374453': [{'st helena pounds': 'East Caribbean Dollar',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.4444444444444444}],
#  'https://www.wikidata.org/entity/Q184172': [{'french franc': 'East Caribbean Dollar',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.29411764705882354},
#   {'french franc': 'French Franc',
#    'ed_score': 0.8333333333333334,
#    'jaccard_score': 0.7777777777777778},
#   {'french franc': 'US Dollar',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.23076923076923078},
#   {'french franc': 'Leu',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.1},
#   {'french franc': 'CFA Franc BEAC',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.38461538461538464},
#   {'french franc': 'CFP Franc',
#    'ed_score': 0.41666666666666663,
#    'jaccard_score': 0.45454545454545453},
#   {'french franc': 'Tugrik',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.07692307692307693},
#   {'french franc': 'Ouguiya',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.07692307692307693}],
#  'https://www.wikidata.org/entity/Q183435': [{'tugrik': 'East Caribbean Dollar',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q26365': [{'east caribbean dollar': 'East Caribbean Dollar',
#    'ed_score': 0.8571428571428572,
#    'jaccard_score': 0.6875},
#   {'east caribbean dollar': 'French Franc',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.4},
#   {'east caribbean dollar': 'French Franc',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.4},
#   {'east caribbean dollar': 'Tala',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.14285714285714285},
#   {'east caribbean dollar': 'Dominican Peso',
#    'ed_score': 0.19047619047619047,
#    'jaccard_score': 0.5},
#   {'east caribbean dollar': 'Moroccan Dirham',
#    'ed_score': 0.23809523809523814,
#    'jaccard_score': 0.4117647058823529},
#   {'east caribbean dollar': 'No universal currency',
#    'ed_score': 0.04761904761904767,
#    'jaccard_score': 0.5882352941176471},
#   {'east caribbean dollar': 'Argentine Peso',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q4594': [{'djibouti franc': 'East Caribbean Dollar',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q25417': [{'danish krone': 'East Caribbean Dollar',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.47058823529411764},
#   {'danish krone': 'Djibouti Franc',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q6478032': [{'lake thunderbird': 'Tom Steed Reservoir',
#    'ed_score': 0.21052631578947367,
#    'jaccard_score': 0.3}],
#  'https://www.wikidata.org/entity/Q5658289': [{'harlan county lake': 'Chimney Reservoir',
#    'ed_score': 0.05555555555555558,
#    'jaccard_score': 0.3684210526315789}],
#  'https://www.wikidata.org/entity/Q47703': [{'the godfather': 'Gone in Sixty Seconds',
#    'ed_score': 0.19047619047619047,
#    'jaccard_score': 0.2777777777777778},
#   {'the godfather': 'Citizen Kane',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.26666666666666666},
#   {'the godfather': 'A Clockwork Orange',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.3333333333333333},
#   {'the godfather': 'The Godfather: Part II',
#    'ed_score': 0.5,
#    'jaccard_score': 0.6},
#   {'the godfather': 'Pulp Fiction',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.16666666666666666}],
#  'https://www.wikidata.org/entity/Q2314853': [{'midnight club ii': 'Midnight Club 3: Dub Edition',
#    'ed_score': 0.5,
#    'jaccard_score': 0.5263157894736842},
#   {'midnight club ii': "SingStar '90s",
#    'ed_score': 0.25,
#    'jaccard_score': 0.2631578947368421}],
#  'https://www.wikidata.org/entity/Q2701053': [{'acacia longifolia': 'Acacia mangium',
#    'ed_score': 0.5294117647058824,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q223887': [{'face/off': 'Fanny and Alexander',
#    'ed_score': 0.10526315789473684,
#    'jaccard_score': 0.13333333333333333}],
#  'https://www.wikidata.org/entity/Q3278831': [{'singstar rocks!': 'Grand Theft Auto III',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.2857142857142857},
#   {'singstar rocks!': "Tony Hawk's Underground",
#    'ed_score': 0.17391304347826086,
#    'jaccard_score': 0.38095238095238093},
#   {'singstar rocks!': 'Spider-Man 2',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.2631578947368421},
#   {'singstar rocks!': 'Tekken Tag Tournament',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.5},
#   {'singstar rocks!': 'Ratchet & Clank',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.3333333333333333},
#   {'singstar rocks!': 'James Bond 007 - Nightfire',
#    'ed_score': 0.11538461538461542,
#    'jaccard_score': 0.391304347826087},
#   {'singstar rocks!': "Assassin's Creed 2",
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.3333333333333333}],
#  'https://www.wikidata.org/entity/Q2079604': [{'burnout 3 takedown': 'Grand Theft Auto III',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.47368421052631576}],
#  'https://www.wikidata.org/entity/Q770677': [{'sega rally revo': 'Shaun White Snowboarding',
#    'ed_score': 0.125,
#    'jaccard_score': 0.3},
#   {'sega rally revo': 'Sega Superstars Tennis',
#    'ed_score': 0.31818181818181823,
#    'jaccard_score': 0.35294117647058826}],
#  'https://www.wikidata.org/entity/Q7491001': [{'shaun white skateboarding': 'Shaun White Snowboarding',
#    'ed_score': 0.72,
#    'jaccard_score': 0.7777777777777778}],
#  'https://www.wikidata.org/entity/Q1030': [{'namibia': 'Jamaica',
#    'ed_score': 0.4285714285714286,
#    'jaccard_score': 0.42857142857142855},
#   {'namibia': 'Niger',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.1111111111111111},
#   {'namibia': 'Slovenia', 'ed_score': 0.25, 'jaccard_score': 0.3},
#   {'namibia': 'Venezuela',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q801': [{'israel': 'Jamaica',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2222222222222222},
#   {'israel': 'Qatar', 'ed_score': 0.16666666666666663, 'jaccard_score': 0.25},
#   {'israel': 'Laos', 'ed_score': 0.16666666666666663, 'jaccard_score': 0.25},
#   {'israel': 'Djibouti',
#    'ed_score': 0.125,
#    'jaccard_score': 0.08333333333333333}],
#  'https://www.wikidata.org/entity/Q822': [{'lebanon': 'Jamaica',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.1},
#   {'lebanon': 'Libya',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2222222222222222},
#   {'lebanon': 'Congo, Republic of the',
#    'ed_score': 0.13636363636363635,
#    'jaccard_score': 0.2777777777777778},
#   {'lebanon': 'Ecuador',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.18181818181818182}],
#  'https://www.wikidata.org/entity/Q711': [{'mongolia': 'Jamaica',
#    'ed_score': 0.125,
#    'jaccard_score': 0.3333333333333333},
#   {'mongolia': 'Iran', 'ed_score': 0.0, 'jaccard_score': 0.2222222222222222}],
#  'https://www.wikidata.org/entity/Q715719': [{'world of warcraft: wrath of the lich king': 'Der Herr der Ringe: Die Gef?hrten',
#    'ed_score': 0.2195121951219512,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q1292819': [{'abraham the syrian': 'Adalbert of Magdeburg',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.3},
#   {'abraham the syrian': 'Adalbert of Magdeburg',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.3}],
#  'https://www.wikidata.org/entity/Q210298': [{'call of duty 2': 'Call of Duty 3',
#    'ed_score': 0.7857142857142857,
#    'jaccard_score': 0.5714285714285714},
#   {'call of duty 2': 'Guitar Hero II',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.29411764705882354}],
#  'https://www.wikidata.org/entity/Q1016838': [{'burnout paradise': 'Call of Duty 3',
#    'ed_score': 0.0625,
#    'jaccard_score': 0.2631578947368421},
#   {'burnout paradise': 'Counterstrike Source',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.5294117647058824},
#   {'burnout paradise': 'Burnout Revenge',
#    'ed_score': 0.5,
#    'jaccard_score': 0.4117647058823529}],
#  'https://www.wikidata.org/entity/Q2337304': [{'marvel: ultimate alliance': 'Call of Duty 3',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.2631578947368421},
#   {'marvel: ultimate alliance': 'Marvel: Ultimate Alliance 2',
#    'ed_score': 0.8148148148148149,
#    'jaccard_score': 0.7058823529411765}],
#  'https://www.wikidata.org/entity/Q41483': [{'the good, the bad and the ugly': 'Goodfellas',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.29411764705882354},
#   {'the good, the bad and the ugly': 'Some Like It Hot',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.19047619047619047},
#   {'the good, the bad and the ugly': 'Psycho',
#    'ed_score': 0.033333333333333326,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q17738': [{'star wars': 'Goodfellas',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.16666666666666666},
#   {'star wars': 'Lawrence of Arabia',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.26666666666666666},
#   {'star wars': 'Star Wars: Episode V - The Empire Strikes Back',
#    'ed_score': 0.15217391304347827,
#    'jaccard_score': 0.21739130434782608},
#   {'star wars': 'Annie Hall',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.16666666666666666},
#   {'star wars': 'Star Wars: Episode I - The Phantom Menace',
#    'ed_score': 0.1707317073170732,
#    'jaccard_score': 0.20833333333333334}],
#  'https://www.wikidata.org/entity/Q133654': [{'silence of the lambs': 'Goodfellas',
#    'ed_score': 0.25,
#    'jaccard_score': 0.375},
#   {'silence of the lambs': 'Skulls, The',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.2631578947368421},
#   {'silence of the lambs': "One Flew over the Cuckoo's Nest",
#    'ed_score': 0.29032258064516125,
#    'jaccard_score': 0.375},
#   {'silence of the lambs': 'A Simple Plan',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.3888888888888889},
#   {'silence of the lambs': 'Mulholland Drive',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q193835': [{'good will hunting': 'Goodfellas',
#    'ed_score': 0.2941176470588235,
#    'jaccard_score': 0.1875},
#   {'good will hunting': 'West Side Story',
#    'ed_score': 0.23529411764705888,
#    'jaccard_score': 0.29411764705882354},
#   {'good will hunting': 'The Good, the Bad and the Ugly',
#    'ed_score': 0.23333333333333328,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q6538093': [{'leymus innovatus': 'Leymus salinus',
#    'ed_score': 0.5,
#    'jaccard_score': 0.7142857142857143}],
#  'https://www.wikidata.org/entity/Q6933051': [{'muhlenbergia cuspidata': 'Muhlenbergia glomerata',
#    'ed_score': 0.6818181818181819,
#    'jaccard_score': 0.6842105263157895}],
#  'https://www.wikidata.org/entity/Q490294': [{'brown creeper': 'CAROLINA WREN',
#    'ed_score': 0.0,
#    'jaccard_score': 0.05555555555555555},
#   {'brown creeper': 'BROWN CREEPER',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.058823529411764705}],
#  'https://www.wikidata.org/entity/Q1585636': [{'carolina wren': 'CAROLINA WREN',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.05263157894736842},
#   {'carolina wren': "BEWICK'S WREN",
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.05}],
#  'https://www.wikidata.org/entity/Q4737332': [{'alum creek lake': 'Atwood Lake Also includes Leesville Lake, OH',
#    'ed_score': 0.2272727272727273,
#    'jaccard_score': 0.3181818181818182}],
#  'https://www.wikidata.org/entity/Q139326': [{'the wrestler': 'X-Men',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.08333333333333333},
#   {'the wrestler': 'Baby Mama',
#    'ed_score': 0.0,
#    'jaccard_score': 0.07142857142857142}],
#  'https://www.wikidata.org/entity/Q219776': [{'x2': 'X-Men',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0}],
#  'https://www.wikidata.org/entity/Q40': [{'austria': 'Haiti',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.42857142857142855},
#   {'austria': 'United Kingdom',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.13333333333333333},
#   {'austria': 'Bahamas', 'ed_score': 0.0, 'jaccard_score': 0.2222222222222222},
#   {'austria': 'Azerbaijan',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q771': [{'massachusetts': 'Haiti',
#    'ed_score': 0.15384615384615385,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q1419797': [{'tommy': 'Tommy Boy',
#    'ed_score': 0.4444444444444444,
#    'jaccard_score': 0.42857142857142855}],
#  'https://www.wikidata.org/entity/Q289811': [{'cestrum parqui': 'Chamaecrista mimosoides',
#    'ed_score': 0.17391304347826086,
#    'jaccard_score': 0.5625}],
#  'https://www.wikidata.org/entity/Q370549': [{'resistance: fall of man': 'Ridge Racer 7',
#    'ed_score': 0.21739130434782605,
#    'jaccard_score': 0.3333333333333333},
#   {'resistance: fall of man': 'Need For Speed Most Wanted 5-1-0',
#    'ed_score': 0.15625,
#    'jaccard_score': 0.32},
#   {'resistance: fall of man': 'Daxter',
#    'ed_score': 0.08695652173913049,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q11181633': [{'ziziphus jujuba': 'Ziziphus mauritiana',
#    'ed_score': 0.5263157894736843,
#    'jaccard_score': 0.5333333333333333}],
#  'https://www.wikidata.org/entity/Q32': [{'luxembourg': 'Samoa',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.18181818181818182},
#   {'luxembourg': 'Macedonia, Republic of',
#    'ed_score': 0.09090909090909094,
#    'jaccard_score': 0.25},
#   {'luxembourg': 'Macau',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.08333333333333333}],
#  'https://www.wikidata.org/entity/Q152105': [{'ikiru': 'In the Heat of the Night',
#    'ed_score': 0.04166666666666663,
#    'jaccard_score': 0.0625},
#   {'ikiru': 'Wings of Desire',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q11703': [{'us virgin islands': 'Micronesia, Federated States of',
#    'ed_score': 0.16129032258064513,
#    'jaccard_score': 0.35},
#   {'us virgin islands': 'St Vincent and the Grenadines',
#    'ed_score': 0.24137931034482762,
#    'jaccard_score': 0.3888888888888889}],
#  'https://www.wikidata.org/entity/Q503313': [{'ordinary people': 'The Others',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.1875}],
#  'https://www.wikidata.org/entity/Q6478013': [{'texana lake': 'Tradinghouse Creek Reservoir',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1953433': [{'carex lenticularis': 'Carex livida',
#    'ed_score': 0.4444444444444444,
#    'jaccard_score': 0.4666666666666667}],
#  'https://www.wikidata.org/entity/Q577669': [{'chrysobalanus icaco': 'Chrysophyllum oliviforme',
#    'ed_score': 0.375,
#    'jaccard_score': 0.47368421052631576}],
#  'https://www.wikidata.org/entity/Q3334272': [{'ncaa football 2004': 'Lord of the Rings: Return of the King',
#    'ed_score': 0.10810810810810811,
#    'jaccard_score': 0.20833333333333334}],
#  'https://www.wikidata.org/entity/Q582728': [{'new england journal of medicine': 'The Astrophysical Journal',
#    'ed_score': 0.12903225806451613,
#    'jaccard_score': 0.4166666666666667}],
#  'https://www.wikidata.org/entity/Q221048': [{'jackie robinson': 'Wally Westlake',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.3125}],
#  'https://www.wikidata.org/entity/Q515894': [{'gil hodges': 'Wally Westlake',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2857142857142857}],
#  'https://www.wikidata.org/entity/Q6720312': [{'mx vs atv untamed': 'MySims SkyHeroes',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.21052631578947367},
#   {'mx vs atv untamed': 'NASCAR 08',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.05555555555555555}],
#  'https://www.wikidata.org/entity/Q1294680': [{'metro 2033': 'Michael Jackson: The Experience',
#    'ed_score': 0.09677419354838712,
#    'jaccard_score': 0.16666666666666666}],
#  'https://www.wikidata.org/entity/Q206886': [{'a civil action': 'Clerks',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.07142857142857142}],
#  'https://www.wikidata.org/entity/Q167057': [{'coal skink': 'FIVE-LINED SKINK',
#    'ed_score': 0.0625,
#    'jaccard_score': 0.05263157894736842}],
#  'https://www.wikidata.org/entity/Q209282': [{'frasier': 'Oz',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0},
#   {'frasier': 'Battlestar Galactica',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.4166666666666667},
#   {'frasier': "That '70s Show",
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.125},
#   {'frasier': 'Home Improvement',
# ...
#    'ed_score': 0.20833333333333337,
#    'jaccard_score': 0.4117647058823529},
#   {'strangers on a train': 'Notorious',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.4166666666666667}],
#  'https://www.wikidata.org/entity/Q928134': [{'brown thrasher': 'CEDAR WAXWING',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.047619047619047616},
#   {'brown thrasher': 'BROWN THRASHER',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.047619047619047616}],
#  'https://www.wikidata.org/entity/Q184314': [{'cedar waxwing': 'CEDAR WAXWING',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.047619047619047616},
#   {'cedar waxwing': 'LOGGERHEAD SHRIKE',
#    'ed_score': 0.0,
#    'jaccard_score': 0.045454545454545456}],
#  'https://www.wikidata.org/entity/Q79503': [{'juno': 'Karate Kid, The',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0},
#   {'juno': '2 Days in Paris',
#    'ed_score': 0.06666666666666665,
#    'jaccard_score': 0.07692307692307693}],
#  'https://www.wikidata.org/entity/Q2181155': [{'eastern narrowmouth toad': 'EASTERN SPADEFOOT',
#    'ed_score': 0.04166666666666663,
#    'jaccard_score': 0.043478260869565216}],
#  'https://www.wikidata.org/entity/Q1463730': [{"tony hawk's pro skater 3": 'Spider-Man: The Movie',
#    'ed_score': 0.125,
#    'jaccard_score': 0.34782608695652173},
#   {"tony hawk's pro skater 3": 'Spider-Man',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q811': [{'nicaragua': 'Greece',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.2222222222222222},
#   {'nicaragua': 'Denmark',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.2727272727272727}],
#  'https://www.wikidata.org/entity/Q398': [{'bahrain': 'Greece',
#    'ed_score': 0.0,
#    'jaccard_score': 0.1111111111111111},
#   {'bahrain': 'Comoros', 'ed_score': 0.0, 'jaccard_score': 0.1},
#   {'bahrain': 'Singapore',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.36363636363636365}],
#  'https://www.wikidata.org/entity/Q37024': [{'serbia and montenegro': 'Greece',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.13333333333333333}],
#  'https://www.wikidata.org/entity/Q183': [{'germany': 'Greece',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.2222222222222222},
#   {'germany': 'Egypt', 'ed_score': 0.0, 'jaccard_score': 0.2},
#   {'germany': 'Finland',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.18181818181818182},
#   {'germany': 'North Carolina',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q466428': [{'philomena': 'Piran',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.2727272727272727},
#   {'philomena': 'Piran',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.2727272727272727}],
#  'https://www.wikidata.org/entity/Q208266': [{'out of africa': 'Spider-Man',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.1875}],
#  'https://www.wikidata.org/entity/Q108006': [{'speed': 'Spider-Man',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.2727272727272727}],
#  'https://www.wikidata.org/entity/Q161114': [{'arundo donax': 'Asclepias curassavica',
#    'ed_score': 0.09523809523809523,
#    'jaccard_score': 0.25},
#   {'arundo donax': 'Arundinaria gigantea',
#    'ed_score': 0.30000000000000004,
#    'jaccard_score': 0.46153846153846156}],
#  'https://www.wikidata.org/entity/Q194626': [{'kunstmuseum basel': 'Staatliche Kunstsammlungen Dresden',
#    'ed_score': 0.2647058823529411,
#    'jaccard_score': 0.45}],
#  'https://www.wikidata.org/entity/Q4957164': [{'brandreth': 'Branstree',
#    'ed_score': 0.4444444444444444,
#    'jaccard_score': 0.5}],
#  'https://www.wikidata.org/entity/Q374320': [{'hercules': 'Theme Park Manager',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.1875}],
#  'https://www.wikidata.org/entity/Q507994': [{'the hunt for red october': 'The Hustler',
#    'ed_score': 0.29166666666666663,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q471169': [{'when harry met sally…': 'The Hustler',
#    'ed_score': 0.23809523809523814,
#    'jaccard_score': 0.4375},
#   {'when harry met sally…': 'Who Framed Roger Rabbit',
#    'ed_score': 0.26086956521739135,
#    'jaccard_score': 0.3333333333333333},
#   {'when harry met sally…': 'Kind Hearts and Coronets',
#    'ed_score': 0.20833333333333337,
#    'jaccard_score': 0.3684210526315789}],
#  'https://www.wikidata.org/entity/Q311632': [{'kunzea ericoides': 'Kyllinga melanosperma',
#    'ed_score': 0.23809523809523814,
#    'jaccard_score': 0.42105263157894735}],
#  'https://www.wikidata.org/entity/Q3026100': [{'eric davis': 'Kelly Gruber',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q655510': [{'yellow-billed stork': 'Wooly-necked stork',
#    'ed_score': 0.5263157894736843,
#    'jaccard_score': 0.6470588235294118}],
#  'https://www.wikidata.org/entity/Q851': [{'saudi arabia': 'Slovenia',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.14285714285714285},
#   {'saudi arabia': 'Democratic Republic of the Congo',
#    'ed_score': 0.125,
#    'jaccard_score': 0.2727272727272727},
#   {'saudi arabia': 'Seychelles',
#    'ed_score': 0.0,
#    'jaccard_score': 0.07142857142857142},
#   {'saudi arabia': 'Iraq',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.2}],
#  'https://www.wikidata.org/entity/Q712': [{'fiji': 'Slovenia',
#    'ed_score': 0.125,
#    'jaccard_score': 0.1},
#   {'fiji': 'Qatar', 'ed_score': 0.0, 'jaccard_score': 0.0}],
#  'https://www.wikidata.org/entity/Q2293972': [{"pee-wee's big adventure": 'Phantom of the Opera, The',
#    'ed_score': 0.12,
#    'jaccard_score': 0.28}],
#  'https://www.wikidata.org/entity/Q4796993': [{'art nehf': 'Red Ames',
#    'ed_score': 0.125,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q483815': [{'shrek': 'Signs',
#    'ed_score': 0.0,
#    'jaccard_score': 0.1111111111111111},
#   {'shrek': 'Snatch.', 'ed_score': 0.0, 'jaccard_score': 0.09090909090909091},
#   {'shrek': 'Rushmore',
#    'ed_score': 0.375,
#    'jaccard_score': 0.4444444444444444},
#   {'shrek': 'The Road Warrior',
#    'ed_score': 0.125,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q2351784': [{'stop making sense': 'Signs',
#    'ed_score': 0.23529411764705888,
#    'jaccard_score': 0.3076923076923077}],
#  'https://www.wikidata.org/entity/Q17': [{'japan': 'Mexico',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0},
#   {'japan': 'Jordan', 'ed_score': 0.33333333333333337, 'jaccard_score': 0.25},
#   {'japan': 'U. A. Emirates',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.06666666666666667},
#   {'japan': 'Montana',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.2857142857142857}],
#  'https://www.wikidata.org/entity/Q842': [{'oman': 'Mexico',
#    'ed_score': 0.0,
#    'jaccard_score': 0.1111111111111111},
#   {'oman': 'Kansas',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.3333333333333333},
#   {'oman': 'Armenia', 'ed_score': 0.2857142857142857, 'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q233': [{'malta': 'Mexico',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0},
#   {'malta': 'Brunei', 'ed_score': 0.0, 'jaccard_score': 0.0},
#   {'malta': 'Grenada',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.1111111111111111}],
#  'https://www.wikidata.org/entity/Q868177': [{'battle los angeles': 'The Taking of Pelham 123',
#    'ed_score': 0.125,
#    'jaccard_score': 0.35}],
#  'https://www.wikidata.org/entity/Q4905822': [{'big hill lake': 'Coffey County Lake',
#    'ed_score': 0.2777777777777778,
#    'jaccard_score': 0.23529411764705882}],
#  'https://www.wikidata.org/entity/Q3643223': [{'pretoria art museum': 'Cheltenham Art Gallery and Museum',
#    'ed_score': 0.36363636363636365,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q921957': [{'final fantasy ii': 'Aero the Acro-Bat',
#    'ed_score': 0.0,
#    'jaccard_score': 0.17647058823529413}],
#  'https://www.wikidata.org/entity/Q588420': [{'magnolia': 'Malcolm X',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.36363636363636365},
#   {'magnolia': 'The Searchers',
#    'ed_score': 0.07692307692307687,
#    'jaccard_score': 0.06666666666666667}],
#  'https://www.wikidata.org/entity/Q727989': [{'red-headed weaver': 'Red-headed malimbe',
#    'ed_score': 0.5555555555555556,
#    'jaccard_score': 0.42857142857142855}],
#  'https://www.wikidata.org/entity/Q285522': [{'long-crested eagle': 'Martial eagle',
#    'ed_score': 0.38888888888888884,
#    'jaccard_score': 0.4666666666666667}],
#  'https://www.wikidata.org/entity/Q773771': [{'armored core: for answer': 'Army of Two',
#    'ed_score': 0.29166666666666663,
#    'jaccard_score': 0.375}],
#  'https://www.wikidata.org/entity/Q665785': [{'tomb raider legend': 'Tomb Raider: Underworld',
#    'ed_score': 0.5217391304347826,
#    'jaccard_score': 0.6111111111111112},
#   {'tomb raider legend': 'Resident Evil 4',
#    'ed_score': 0.16666666666666663,
#    'jaccard_score': 0.3888888888888889}],
#  'https://www.wikidata.org/entity/Q319885': [{'cayman islands dollar': 'CFA Franc BEAC',
#    'ed_score': 0.19047619047619047,
#    'jaccard_score': 0.29411764705882354}],
#  'https://www.wikidata.org/entity/Q829043': [{'el salvador colon': 'CFA Franc BEAC',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.3125}],
#  'https://www.wikidata.org/entity/Q204737': [{'riel': 'CFA Franc BEAC',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.07692307692307693}],
#  'https://www.wikidata.org/entity/Q847739': [{'cfa franc beac': 'CFA Franc BEAC',
#    'ed_score': 0.4285714285714286,
#    'jaccard_score': 0.38461538461538464},
#   {'cfa franc beac': 'Chilean Peso',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.26666666666666666},
#   {'cfa franc beac': 'Canadian Dollar',
#    'ed_score': 0.19999999999999996,
#    'jaccard_score': 0.2857142857142857},
#   {'cfa franc beac': 'Franc Congolais',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.3333333333333333},
#   {'cfa franc beac': 'Kroon',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.2},
#   {'cfa franc beac': 'Dalasi',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.08333333333333333}],
#  'https://www.wikidata.org/entity/Q267264': [{'comoro franc': 'CFA Franc BEAC',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.38461538461538464}],
#  'https://www.wikidata.org/entity/Q1142527': [{'tekken tag tournament': 'The Legend Of Zelda - Oracle Of Seasons',
#    'ed_score': 0.20512820512820518,
#    'jaccard_score': 0.30434782608695654},
#   {'tekken tag tournament': 'Namco Museum',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q6986505': [{'need for speed most wanted': 'Need for Speed: ProStreet',
#    'ed_score': 0.5384615384615384,
#    'jaccard_score': 0.47058823529411764},
#   {'need for speed most wanted': 'SingStar - The Dome',
#    'ed_score': 0.1923076923076923,
#    'jaccard_score': 0.4},
#   {'need for speed most wanted': 'Dr. Kawashimas Mehr Gehirn-Jogging',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.391304347826087},
#   {'need for speed most wanted': 'NBA Live 06',
#    'ed_score': 0.11538461538461542,
#    'jaccard_score': 0.09523809523809523}],
#  'https://www.wikidata.org/entity/Q2024612': [{'wwe smackdown! here comes the pain': 'Need for Speed: ProStreet',
#    'ed_score': 0.17647058823529416,
#    'jaccard_score': 0.3181818181818182},
#   {'wwe smackdown! here comes the pain': 'WWE Smackdown vs Raw 2006',
#    'ed_score': 0.38235294117647056,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q779': [{'connecticut': 'Swaziland',
#    'ed_score': 0.0,
#    'jaccard_score': 0.15384615384615385}],
#  'https://www.wikidata.org/entity/Q29': [{'spain': 'Swaziland',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.3},
#   {'spain': 'Thailand',
#    'ed_score': 0.375,
#    'jaccard_score': 0.3333333333333333},
#   {'spain': 'Portugal', 'ed_score': 0.0, 'jaccard_score': 0.08333333333333333},
#   {'spain': 'Sudan', 'ed_score': 0.19999999999999996, 'jaccard_score': 0.25}],
#  'https://www.wikidata.org/entity/Q1027': [{'mauritius': 'Swaziland',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.15384615384615385},
#   {'mauritius': 'Morocco',
#    'ed_score': 0.11111111111111116,
#    'jaccard_score': 0.1},
#   {'mauritius': 'Saudi Arabia',
#    'ed_score': 0.25,
#    'jaccard_score': 0.3333333333333333},
#   {'mauritius': 'Luxembourg',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.23076923076923078}],
#  'https://www.wikidata.org/entity/Q854': [{'sri lanka': 'Swaziland',
#    'ed_score': 0.2222222222222222,
#    'jaccard_score': 0.3333333333333333},
#   {'sri lanka': 'Mozambique', 'ed_score': 0.0, 'jaccard_score': 0.125},
#   {'sri lanka': 'Tasmania',
#    'ed_score': 0.33333333333333337,
#    'jaccard_score': 0.4}],
#  'https://www.wikidata.org/entity/Q297142': [{'joe dimaggio': 'Vic Wertz',
#    'ed_score': 0.08333333333333337,
#    'jaccard_score': 0.2},
#   {'joe dimaggio': 'Gee Walker',
#    'ed_score': 0.25,
#    'jaccard_score': 0.21428571428571427}],
#  'https://www.wikidata.org/entity/Q621082': [{'flacourtia indica': 'Flacourtia rukam',
#    'ed_score': 0.5882352941176471,
#    'jaccard_score': 0.6}],
#  'https://www.wikidata.org/entity/Q1832323': [{'evening bat': "TOWNSEND'S BIG-EARED BAT",
#    'ed_score': 0.04166666666666663,
#    'jaccard_score': 0.043478260869565216}],
#  'https://www.wikidata.org/entity/Q131564': [{'fennec fox': 'Giraffe',
#    'ed_score': 0.09999999999999998,
#    'jaccard_score': 0.18181818181818182}],
#  'https://www.wikidata.org/entity/Q1013': [{'lesotho': 'Namibia',
#    'ed_score': 0.0,
#    'jaccard_score': 0.0},
#   {'lesotho': 'Belgium',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.18181818181818182},
#   {'lesotho': 'Liberia',
#    'ed_score': 0.0,
#    'jaccard_score': 0.09090909090909091}],
#  'https://www.wikidata.org/entity/Q3224': [{'new south wales, australia': 'Namibia',
#    'ed_score': 0.11538461538461542,
#    'jaccard_score': 0.11764705882352941}],
#  'https://www.wikidata.org/entity/Q77': [{'uruguay': 'Thailand',
#    'ed_score': 0.125,
#    'jaccard_score': 0.09090909090909091},
#   {'uruguay': 'Panama',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.125},
#   {'uruguay': 'Missouri',
#    'ed_score': 0.125,
#    'jaccard_score': 0.2222222222222222}],
#  'https://www.wikidata.org/entity/Q1816301': [{'seattle art museum': 'Saint Louis Art Museum (SLAM)',
#    'ed_score': 0.3448275862068966,
#    'jaccard_score': 0.4444444444444444}],
#  'https://www.wikidata.org/entity/Q4049247': [{'section 8': 'Sega Rally Revo',
#    'ed_score': 0.1333333333333333,
#    'jaccard_score': 0.1875}],
#  'https://www.wikidata.org/entity/Q1473804': [{'high fidelity': 'High Noon',
#    'ed_score': 0.3076923076923077,
#    'jaccard_score': 0.2857142857142857},
#   {'high fidelity': 'I Heart Huckabees',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.15789473684210525}],
#  'https://www.wikidata.org/entity/Q188718': [{'the bridge on the river kwai': 'High Noon',
#    'ed_score': 0.1428571428571429,
#    'jaccard_score': 0.35294117647058826},
#   {'the bridge on the river kwai': 'Brief Encounter',
#    'ed_score': 0.2142857142857143,
#    'jaccard_score': 0.35},
#   {'the bridge on the river kwai': 'The Lord of the Rings: The Fellowship of the Ring',
#    'ed_score': 0.2857142857142857,
#    'jaccard_score': 0.4583333333333333},
#   {'the bridge on the river kwai': 'Amadeus',
#    'ed_score': 0.0714285714285714,
#    'jaccard_score': 0.15789473684210525}],
#  'https://www.wikidata.org/entity/Q172837': [{'the bicycle thief': 'High Noon',
#    'ed_score': 0.11764705882352944,
#    'jaccard_score': 0.2},
#   {'the bicycle thief': 'City Lights',
#    'ed_score': 0.17647058823529416,
#    'jaccard_score': 0.35714285714285715},
#   {'the bicycle thief': 'Natural',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.14285714285714285},
#   {'the bicycle thief': 'Big',
#    'ed_score': 0.05882352941176472,
#    'jaccard_score': 0.08333333333333333}],
#  'https://www.wikidata.org/entity/Q1209690': [{'paederia foetida': 'Panicum decompositum',
#    'ed_score': 0.15000000000000002,
#    'jaccard_score': 0.5}],
#  ...}

# %%
count = 0
print("First 10 values of the dictionary:")
for key, value in mentions.items():
    print(f"{key}: {value}")
    count += 1
    if count == 10:
        break
# Out:
# First 10 values of the dictionary:
# Need for Speed: Hot Pursuit: ['https://www.wikidata.org/entity/Q219795']
# Alex Ochoa: ['https://www.wikidata.org/entity/Q558664']
# The King of Comedy: ['https://www.wikidata.org/entity/Q309048']
# Se7en: ['https://www.wikidata.org/entity/Q820753', 'https://www.wikidata.org/entity/Q5639157', 'https://www.wikidata.org/entity/Q6072725']
# Ric Flair: ['https://www.wikidata.org/entity/Q115347']
# Twisted Metal: ['https://www.wikidata.org/entity/Q597808', 'https://www.wikidata.org/entity/Q216995']
# Avatar: ['https://www.wikidata.org/entity/Q183066', 'https://www.wikidata.org/entity/Q187278']
# Mandrill: ['https://www.wikidata.org/entity/Q140']
# Lac-a-l'eau-Claire: ['https://www.wikidata.org/entity/Q958928']
# Ferris Bueller's Day Off: ['https://www.wikidata.org/entity/Q23395', 'https://www.wikidata.org/entity/Q23395', 'https://www.wikidata.org/entity/Q109767', 'https://www.wikidata.org/entity/Q217220']

# %%
count = 0
print("First 10 values of the dictionary:")
for key, value in ids.items():
    print(f"{key}: {value}")
    count += 1
    if count == 10:
        break
# Out:
# First 10 values of the dictionary:
# https://www.wikidata.org/entity/Q9626: {'name': 'uk conservative', 'ed_score': 0.8, 'jaccard_score': 0.5}
# https://www.wikidata.org/entity/Q9630: {'name': 'labour', 'ed_score': 1.0, 'jaccard_score': 1.0}
# https://www.wikidata.org/entity/Q6540612: {'name': 'liberal democrat', 'ed_score': 0.38, 'jaccard_score': 0.0}
# https://www.wikidata.org/entity/Q10658: {'name': 'snp', 'ed_score': 1.0, 'jaccard_score': 1.0}
# https://www.wikidata.org/entity/Q10691: {'name': 'plaid', 'ed_score': 0.2, 'jaccard_score': 0.0}
# https://www.wikidata.org/entity/Q9669: {'name': 'green party', 'ed_score': 0.45, 'jaccard_score': 0.5}
# https://www.wikidata.org/entity/Q161269: {'name': 'bnp', 'ed_score': 1.0, 'jaccard_score': 1.0}
# https://www.wikidata.org/entity/Q10647: {'name': 'ukip', 'ed_score': 1.0, 'jaccard_score': 1.0}
# https://www.wikidata.org/entity/Q6393870: {'name': 'keri hehn', 'ed_score': 0.82, 'jaccard_score': 0.67}
# https://www.wikidata.org/entity/Q237: {'name': 'holy see', 'ed_score': 0.79, 'jaccard_score': 0.6}

# %%
ids
# Out:
# {'https://www.wikidata.org/entity/Q9626': {'name': 'uk conservative',
#   'ed_score': 0.8,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q9630': {'name': 'labour',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q6540612': {'name': 'liberal democrat',
#   'ed_score': 0.38,
#   'jaccard_score': 0.0},
#  'https://www.wikidata.org/entity/Q10658': {'name': 'snp',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q10691': {'name': 'plaid',
#   'ed_score': 0.2,
#   'jaccard_score': 0.0},
#  'https://www.wikidata.org/entity/Q9669': {'name': 'green party',
#   'ed_score': 0.45,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q161269': {'name': 'bnp',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q10647': {'name': 'ukip',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q6393870': {'name': 'keri hehn',
#   'ed_score': 0.82,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q237': {'name': 'holy see',
#   'ed_score': 0.79,
#   'jaccard_score': 0.6},
#  'https://www.wikidata.org/entity/Q235': {'name': 'monaco',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q697': {'name': 'nauru',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q672': {'name': 'tuvalu',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q238': {'name': 'san marino',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q347': {'name': 'liechtenstein',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q61': {'name': 'washington dc',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q709': {'name': 'marshall islands',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16641': {'name': 'american samoa',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q763': {'name': 'saint kitts and nevis',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q826': {'name': 'maldives',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q233': {'name': 'malta',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q769': {'name': 'grenada',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q11703': {'name': 'us virgin islands',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q757': {'name': 'saint vincent and the grenadines',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q244': {'name': 'barbados',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q781': {'name': 'antigua and barbuda',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1042': {'name': 'seychelles',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q228': {'name': 'andorra',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16644': {'name': 'northern mariana islands',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16635': {'name': 'guam',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q760': {'name': 'saint lucia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q398': {'name': 'bahrain',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q334': {'name': 'singapore',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3359409': {'name': 'micronesia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q678': {'name': 'tonga',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q784': {'name': 'dominica',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q710': {'name': 'kiribati',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q970': {'name': 'comoros',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1027': {'name': 'mauritius',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q32': {'name': 'luxembourg',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q683': {'name': 'samoa',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1387': {'name': 'rhode island',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1011': {'name': 'cape verde',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q754': {'name': 'trinidad and tobago',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1978': {'name': 'prince edward island',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q921': {'name': 'brunei',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1393': {'name': 'delaware',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1183': {'name': 'puerto rico',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q229': {'name': 'cyprus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q822': {'name': 'lebanon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q766': {'name': 'jamaica',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1005': {'name': 'gambia, the',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q846': {'name': 'qatar',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q686': {'name': 'vanuatu',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q26': {'name': 'northern ireland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q236': {'name': 'montenegro',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q778': {'name': 'bahamas',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q779': {'name': 'connecticut',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1569649': {'name': 'eagle lake',
#   'ed_score': 0.62,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q6961569': {'name': 'namekagon lake',
#   'ed_score': 0.47,
#   'jaccard_score': 0.33},
#  'https://www.wikidata.org/entity/Q1007': {'name': 'guinea-bissau',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q39': {'name': 'switzerland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q55': {'name': 'netherlands',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q35': {'name': 'denmark',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q191': {'name': 'estonia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q917': {'name': 'bhutan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q786': {'name': 'dominican rep',
#   'ed_score': 0.93,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q214': {'name': 'slovakia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q800': {'name': 'costa rica',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1952': {'name': 'nova scotia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q224': {'name': 'croatia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q945': {'name': 'togo',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1371': {'name': 'west virginia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q211': {'name': 'latvia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q37': {'name': 'lithuania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q854': {'name': 'sri lanka',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q34366': {'name': 'tasmania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27': {'name': 'ireland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1044': {'name': 'sierra leone',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1965': {'name': 'new brunswick',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q804': {'name': 'panama',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q22': {'name': 'scotland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q878': {'name': 'u.a. emirates',
#   'ed_score': 0.93,
#   'jaccard_score': 0.33},
#  'https://www.wikidata.org/entity/Q213': {'name': 'czech republic',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q225': {'name': 'bosnia and herzegovina',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1456': {'name': 'south carolina',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q40': {'name': 'austria',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q227': {'name': 'azerbaijan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q403': {'name': 'serbia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q810': {'name': 'jordan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3769': {'name': 'french guiana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q724': {'name': 'maine',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q45': {'name': 'portugal',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q28': {'name': 'hungary',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1415': {'name': 'indiana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1014': {'name': 'liberia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q884': {'name': 'korea, south',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q189': {'name': 'iceland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1603': {'name': 'kentucky',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q774': {'name': 'guatemala',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1509': {'name': 'tennessee',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q241': {'name': 'cuba',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q219': {'name': 'bulgaria',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q783': {'name': 'honduras',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q962': {'name': 'benin',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q118863': {'name': 'north island, new zealand',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1397': {'name': 'ohio',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q817': {'name': 'kuwait',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q712': {'name': 'fiji',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q215': {'name': 'slovenia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25': {'name': 'wales',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q792': {'name': 'el salvador',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q801': {'name': 'israel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q977': {'name': 'djibouti',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1408': {'name': 'new jersey',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q242': {'name': 'belize',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q759': {'name': 'new hampshire',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16551': {'name': 'vermont',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1037': {'name': 'rwanda',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q771': {'name': 'massachusetts',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q790': {'name': 'haiti',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q967': {'name': 'burundi',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q983': {'name': 'equatorial guinea',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q782': {'name': 'hawaii',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q685': {'name': 'solomon islands',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q222': {'name': 'albania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q399': {'name': 'armenia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1013': {'name': 'lesotho',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q31': {'name': 'belgium',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1391': {'name': 'maryland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q217': {'name': 'moldova',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q70991': {'name': 'hildegard frá bingen',
#   'ed_score': 0.95,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q76365': {'name': 'johannes regiomontanus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9554': {'name': 'martin luther',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q153981': {'name': 'thomas munzer',
#   'ed_score': 0.92,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q19543': {'name': 'hans sachs',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q48319': {'name': 'hans holbein d.y.',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q8963': {'name': 'johannes kepler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9047': {'name': 'gottfried wilhelm leibniz',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1339': {'name': 'johann sebastian bach',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q7302': {'name': 'georg friedrich handel',
#   'ed_score': 0.95,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q9312': {'name': 'immanuel kant',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q155547': {'name': 'johann gottfried von herder',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q5879': {'name': 'johann wolfgang von goethe',
#   'ed_score': 0.96,
#   'jaccard_score': 0.75},
#  'https://www.wikidata.org/entity/Q22670': {'name': 'friedrich von schiller',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q77888': {'name': 'wilhelm von humboldt',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q6694': {'name': 'alexander von humboldt',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q255': {'name': 'ludwig van beethoven',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9235': {'name': 'georg wilhelm friedrich hegel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q104884': {'name': 'caspar david friedrich',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q150471': {'name': 'e. t. a. hoffmann',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q28494': {'name': 'heinrich von kleist',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q6722': {'name': 'carl friedrich gauss',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q151759': {'name': 'karl friedrich schinkel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q63030': {'name': 'friedrich krupp',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q38193': {'name': 'arthur schopenhauer',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q44205': {'name': 'helmuth carl bernhard moltke',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16571': {'name': 'justus von liebig',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q46096': {'name': 'felix mendelssohn-bartholdy',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q7351': {'name': 'robert schumann',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1511': {'name': 'richard wagner',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q8442': {'name': 'otto von bismarck',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25351': {'name': 'theodor mommsen',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9061': {'name': 'karl marx',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q132232': {'name': 'clara schumann trean',
#   'ed_score': 0.64,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q34787': {'name': 'friedrich engels',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q57106': {'name': 'heinrich schliemann',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q76410': {'name': 'leopold kronecker',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q60052': {'name': 'gustav robert kirchhoff',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q42299': {'name': 'georg friedrich bernhard riemann',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q7294': {'name': 'johannes brahms',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q57098': {'name': 'gottlieb daimler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q48246': {'name': 'ernst haeckel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9358': {'name': 'friedrich wilhelm nietzsche',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q40224': {'name': 'carl friedrich benz',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q76420': {'name': 'georg cantor',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q35149': {'name': 'wilhelm von rontgen',
#   'ed_score': 0.95,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q9021': {'name': 'max karl ernst ludwig planck',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q41585': {'name': 'david hilbert',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9387': {'name': 'max weber',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q13894': {'name': 'richard strauss',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q7231': {'name': 'rosa luxemburg',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q37030': {'name': 'thomas mann',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q937': {'name': 'albert einstein',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q61071': {'name': 'walter gropius',
#   'ed_score': 0.93,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q41508': {'name': 'ludwig mies van der rohe',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q60060': {'name': 'karl von frisch',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q55412': {'name': 'friedrich wilhelm murnau',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q48301': {'name': 'martin heidegger',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q61078': {'name': 'walter benjamin',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q159946': {'name': 'wilhelm kempff',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q38757': {'name': 'bertolt brecht',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q55004': {'name': 'kurt weill',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q40904': {'name': 'werner karl heisenberg',
#   'ed_score': 0.95,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q4612': {'name': 'marlene dietrich',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q152388': {'name': 'theodor adorno',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q78496': {'name': 'konrad lorenz',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q57384': {'name': 'wernher von braun',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2514': {'name': 'willy brandt',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q76412': {'name': 'siegfried lenz',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q57382': {'name': 'christa wolf',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q4457': {'name': 'franz beckenbauer',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q170344': {'name': 'anselm kiefer',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q44426': {'name': 'rainer werner fassbinder',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q154538': {'name': 'daniel libeskind',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q57344': {'name': 'joschka fischer',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q9671': {'name': 'michael schumacher',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1020': {'name': 'malawi',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1400': {'name': 'pennsylvania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q423': {'name': 'korea, north',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q986': {'name': 'eritrea',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1494': {'name': 'mississippi',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q21': {'name': 'england',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q811': {'name': 'nicaragua',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q41': {'name': 'greece',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1588': {'name': 'louisiana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q173': {'name': 'alabama',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1612': {'name': 'arkansas',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q837': {'name': 'nepal',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q863': {'name': 'tajikistan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q902': {'name': 'bangladesh',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1546': {'name': 'iowa',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1204': {'name': 'illinois',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q120755': {'name': 'south island, new zealand',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1428': {'name': 'georgia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q730': {'name': 'suriname',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q948': {'name': 'tunisia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1537': {'name': 'wisconsin',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q812': {'name': 'florida',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q77': {'name': 'uruguay',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1581': {'name': 'missouri',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q424': {'name': 'cambodia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1649': {'name': 'oklahoma',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1207': {'name': 'north dakota',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1223': {'name': 'washington state',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q858': {'name': 'syria',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1041': {'name': 'senegal',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q813': {'name': 'kyrgyzstan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1211': {'name': 'south dakota',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1553': {'name': 'nebraska',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q184': {'name': 'belarus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q842': {'name': 'oman',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1558': {'name': 'kansas',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q734': {'name': 'guyana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1221': {'name': 'idaho',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q829': {'name': 'utah',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1527': {'name': 'minnesota',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q36687': {'name': 'victoria, australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q819': {'name': 'laos',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q218': {'name': 'romania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q117': {'name': 'ghana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1036': {'name': 'uganda',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q145': {'name': 'united kingdom',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1006': {'name': 'guinea',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1166': {'name': 'michigan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1214': {'name': 'wyoming',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q127216': {'name': 'bald eagle',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q133006': {'name': 'asiatic elephant',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q180960': {'name': 'asiatic wild ass',
#   'ed_score': 0.67,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q132922': {'name': 'bactrian camel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q247142': {'name': 'black-tailed prairie dog',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q210070': {'name': 'brush-tailed bettong',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q131538': {'name': 'capybara',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q732477': {'name': 'common brushtail possum',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q216815': {'name': 'common eland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q18764': {'name': 'common palm civet',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q309200': {'name': 'squirrel monkey',
#   'ed_score': 0.68,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q3901247': {'name': 'cormorant',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q214293': {'name': 'eagle owl',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q754983': {'name': 'egyptian rousette',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q93208': {'name': 'emu',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q131564': {'name': 'fennec fox',
#   'ed_score': 0.5,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q862089': {'name': 'giraffe',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1369327': {'name': "grant's zebra",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q134015': {'name': 'black meerkat',
#   'ed_score': 0.62,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q209134': {'name': 'ground cuscus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q26913': {'name': 'harbour seal',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q124410': {'name': 'himalayan black bear',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q34505': {'name': 'hippopotamus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q244813': {'name': 'jackass penguin',
#   'ed_score': 0.93,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q753853': {'name': 'lama',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q41960': {'name': 'lesser panda',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q140': {'name': 'lion',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q189868': {'name': 'mandrill',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q41050': {'name': 'orang-utan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2576337': {'name': 'ostrich',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q469636': {'name': 'owl monkey',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q194313': {'name': 'patagonian cavy',
#   'ed_score': 0.65,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q33609': {'name': 'polar bear',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q53462': {'name': 'red kangaroo',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q39624': {'name': 'reindeer',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q148462': {'name': 'ring-tailed coati',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q185385': {'name': 'ring-tailed lemur',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q189484': {'name': 'sacred baboon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q213889': {'name': 'siamang',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q69581': {'name': 'siberian tiger',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3027980': {'name': 'springhare',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q159918': {'name': 'square-lipped rhinoceros',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q510022': {'name': 'western grey kangaroo',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q876500': {'name': 'western lowland gorilla',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q18498': {'name': 'wolf',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q824': {'name': 'oregon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1000': {'name': 'gabon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1261': {'name': 'colorado',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q664': {'name': 'new zealand',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q736': {'name': 'ecuador',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q965': {'name': 'burkina faso',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1227': {'name': 'nevada',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q816': {'name': 'arizona',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q928': {'name': 'philippines',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q38': {'name': 'italy',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q36': {'name': 'poland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1522': {'name': 'new mexico',
#   'ed_score': 0.91,
#   'jaccard_score': 0.75},
#  'https://www.wikidata.org/entity/Q107694204': {'name': 'windward coast',
#   'ed_score': 0.07,
#   'jaccard_score': 0.0},
#  'https://www.wikidata.org/entity/Q20': {'name': 'norway',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q833': {'name': 'malaysia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q881': {'name': 'vietnam',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q33': {'name': 'finland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q971': {'name': 'congo, republic of the',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q183': {'name': 'germany',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1454': {'name': 'north carolina',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q17': {'name': 'japan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1212': {'name': 'montana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q954': {'name': 'zimbabwe',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2003': {'name': 'newfoundland and labrador',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q733': {'name': 'paraguay',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q99': {'name': 'california',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q796': {'name': 'iraq',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1028': {'name': 'morocco',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q265': {'name': 'uzbekistan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q34': {'name': 'sweden',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q691': {'name': 'papua new guinea',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1009': {'name': 'cameroon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2009': {'name': 'yukon territory',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q874': {'name': 'turkmenistan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q29': {'name': 'spain',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q869': {'name': 'thailand',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q805': {'name': 'yemen',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q142': {'name': 'france',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q963': {'name': 'botswana',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q114': {'name': 'kenya',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1019': {'name': 'madagascar',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q212': {'name': 'ukraine',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q929': {'name': 'central african republic',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1045': {'name': 'somalia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q889': {'name': 'afghanistan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1948': {'name': 'manitoba',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1989': {'name': 'saskatchewan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1951': {'name': 'alberta',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q836': {'name': 'burma',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1439': {'name': 'texas',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2007': {'name': 'northwest territories',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q176': {'name': 'quebec',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q711': {'name': 'mongolia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q794': {'name': 'iran',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q797': {'name': 'alaska',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q36074': {'name': 'queensland, australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1016': {'name': 'libya',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q252': {'name': 'indonesia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q96': {'name': 'mexico',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q2023': {'name': 'nunavut',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q223': {'name': 'greenland',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q851': {'name': 'saudi arabia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q974': {'name': 'congo, democratic republic of the',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q262': {'name': 'algeria',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1049': {'name': 'sudan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3206': {'name': 'western australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q232': {'name': 'kazakhstan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q414': {'name': 'argentina',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q668': {'name': 'india',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q408': {'name': 'australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q155': {'name': 'brazil',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q148': {'name': "china, people's republic of",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q16': {'name': 'canada',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q159': {'name': 'russia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q953': {'name': 'zambia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q298': {'name': 'chile',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q43': {'name': 'turkey',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q843': {'name': 'pakistan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1029': {'name': 'mozambique',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3224': {'name': 'new south wales, australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1030': {'name': 'namibia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q717': {'name': 'venezuela',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1033': {'name': 'nigeria',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q924': {'name': 'tanzania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1973': {'name': 'british columbia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q35715': {'name': 'south australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q79': {'name': 'egypt',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1025': {'name': 'mauritania',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1904': {'name': 'ontario',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q750': {'name': 'bolivia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q115': {'name': 'ethiopia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q739': {'name': 'colombia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q258': {'name': 'south africa',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q916': {'name': 'angola',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1032': {'name': 'niger',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q657': {'name': 'chad',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q419': {'name': 'peru',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3235': {'name': 'northern territory, australia',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q183240': {'name': 'lucy of syracuse',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q128538': {'name': 'luke the evangelist',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q160373': {'name': 'pope marcellinus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q102131': {'name': 'pope marcellus i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q132797': {'name': 'pope marcus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q230507': {'name': 'margaret of scotland',
#   'ed_score': 0.87,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q31966': {'name': 'mark the evangelist',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q133704': {'name': 'martin of tours',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q172390': {'name': 'pope martin i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1938795': {'name': 'blessed virgin mary',
#   'ed_score': 0.68,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q63070': {'name': 'mary magdalene',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q43600': {'name': 'matthæus',
#   'ed_score': 0.75,
#   'jaccard_score': 0.0},
#  'https://www.wikidata.org/entity/Q44020': {'name': 'matthias',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q153850': {'name': 'maximillian kolbe',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q162090': {'name': 'pope miltiades',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q116639': {'name': 'saint nicephorus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q44269': {'name': 'nicholas of myra',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q170503': {'name': 'pope nicholas i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1269112': {'name': 'ninian',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q243787': {'name': 'gregory palamas',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q103308': {'name': 'pope paschal i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q3245490': {'name': 'james the less',
#   'ed_score': 0.82,
#   'jaccard_score': 0.67},
#  'https://www.wikidata.org/entity/Q44248': {'name': 'jerome',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q40662': {'name': 'john the baptist',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q312758': {'name': 'john baptist de la salle',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q146183': {'name': 'john bosco',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q43706': {'name': 'john chrysostom',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q317072': {'name': 'john climacus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q190388': {'name': 'john of the cross',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q51884': {'name': 'john of damascus',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q328804': {'name': 'john the evangelist',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1292207': {'name': 'john maron',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q160916': {'name': 'pope john i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q103101': {'name': 'pope julius i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
# ...
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075934': {'name': 'yellow-throated warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075932': {'name': 'pine warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075937': {'name': 'prairie warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q309153': {'name': "singin' in the rain",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q190086': {'name': 'some like it hot',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q105702': {'name': 'dr. strangelove or: how i learned to stop worrying and love the bomb',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q233464': {'name': 'annie hall',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q217627': {'name': 'graduate',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q179743': {'name': 'bringing up baby',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1125566': {'name': 'duck soup',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q171048': {'name': 'toy story',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q238211': {'name': 'city lights',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q208632': {'name': 'it happened one night',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q748599': {'name': 'the rules of the game',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1066714': {'name': 'his girl friday',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q7810384': {'name': 'this is spinal tap',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q134773': {'name': 'forrest gump',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q214723': {'name': 'the gold rush',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q45602': {'name': 'modern times',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q498822': {'name': 'the philadelphia story',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1065711': {'name': "sullivan's travels",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q270510': {'name': 'the apartment',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q494085': {'name': 'm*a*s*h',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q488655': {'name': 'groundhog day',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q506418': {'name': 'the princess bride',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25043': {'name': 'monty python and the holy grail',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q18407': {'name': 'la dolce vita',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q731310': {'name': 'manhattan',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1212344': {'name': 'the lady eve',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q24953': {'name': 'life of brian',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q913311': {'name': "a hard day's night",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q471169': {'name': 'when harry met sally…',
#   'ed_score': 0.95,
#   'jaccard_score': 0.75},
#  'https://www.wikidata.org/entity/Q353753': {'name': 'kind hearts and coronets',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1139031': {'name': 'top hat',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q337078': {'name': 'big lebowski',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q497256': {'name': 'airplane!',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1756560': {'name': 'withnail & i',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q464032': {'name': 'cinema paradiso',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q221249': {'name': 'tootsie',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q375855': {'name': 'american graffiti',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q193066': {'name': "breakfast at tiffany's",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q957323': {'name': 'blazing saddles',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q589894': {'name': 'ninotchka',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q182944': {'name': 'shakespeare in love',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q209170': {'name': 'mary poppins',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q943992': {'name': 'a night at the opera',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q368577': {'name': 'harold and maude',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q651923': {'name': 'young frankenstein',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1569918': {'name': 'sherlock, jr.',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25066647': {'name': 'cerulean warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q669888': {'name': 'black-and-white warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q922772': {'name': 'american redstart',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q206535': {'name': 'prothonotary warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q269463': {'name': 'worm-eating warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q783095': {'name': "swainson's warbler",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q796672': {'name': 'ovenbird',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075882': {'name': 'louisiana waterthrush',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075899': {'name': 'kentucky warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q281555': {'name': 'common yellowthroat',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075904': {'name': 'hooded warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27076004': {'name': 'canada warbler',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q787047': {'name': 'yellow-breasted chat',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1078246': {'name': 'summer tanager',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1193366': {'name': 'scarlet tanager',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q726389': {'name': 'northern cardinal',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q839834': {'name': 'rose-breasted grosbeak',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q794337': {'name': 'blue grosbeak',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1049642': {'name': 'indigo bunting',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1210224': {'name': 'dickcissel',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1541137': {'name': 'eastern towhee',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q55644390': {'name': 'rufous-sided towhee',
#   'ed_score': 0.42,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q2229917': {'name': "bachman's sparrow",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q135913': {'name': 'american tree sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1424486': {'name': 'common grackle',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q901568': {'name': 'brown-headed cowbird',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1586976': {'name': 'orchard oriole',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q805774': {'name': 'baltimore oriole',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075782': {'name': 'purple finch',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q26847063': {'name': 'pine siskin',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q27075861': {'name': 'american goldfinch',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25167830': {'name': 'evening grosbeak',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q147267': {'name': 'virginia opossum',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q469038': {'name': 'masked shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1769703': {'name': 'southeastern shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1769712': {'name': 'smoky shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1770338': {'name': 'long-tailed shrew',
#   'ed_score': 0.68,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q469606': {'name': 'pygmy shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1766543': {'name': 'northern short-tailed shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1769360': {'name': 'southern short-tailed shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1764011': {'name': 'least shrew',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1470645': {'name': 'hairy-tailed mole',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1353759': {'name': 'eastern mole',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q746127': {'name': 'little brown myotis',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1829574': {'name': 'southeastern myotis',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1834518': {'name': 'gray myotis',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q281343': {'name': 'indiana myotis',
#   'ed_score': 0.58,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q645203': {'name': 'chipping sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q611926': {'name': 'field sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1528805': {'name': 'lark sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q10804319': {'name': 'passerculus',
#   'ed_score': 0.06,
#   'jaccard_score': 0.0},
#  'https://www.wikidata.org/entity/Q1588210': {'name': 'grasshopper sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1588203': {'name': "henslow's sparrow",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q422873': {'name': 'fox sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q842599': {'name': 'song sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q742826': {'name': 'swamp sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q754880': {'name': 'white-throated sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q686673': {'name': 'white-crowned sparrow',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q525818': {'name': 'dark-eyed junco',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q208703': {'name': 'lapland longspur',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q591831': {'name': 'bobolink',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q754043': {'name': 'red-winged blackbird',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1589550': {'name': 'eastern meadowlark',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1314688': {'name': 'rusty blackbird',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q339139': {'name': "brewer's blackbird",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q750028': {'name': 'evil dead ii',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q18428': {'name': 'amarcord',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q775970': {'name': 'the full monty',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q379873': {'name': 'who framed roger rabbit',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q109116': {'name': 'the great dictator',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q720724': {'name': 'babe',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q132863': {'name': 'finding nemo',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q500044': {'name': 'the lady vanishes',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1454574': {'name': 'playtime',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1508130': {'name': 'the band wagon',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q391172': {'name': 'secrets & lies',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q25193623': {'name': 'swing time',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q44662': {'name': '42nd street',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q858724': {'name': 'shaun of the dead',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q501703': {'name': 'austin powers: international man of mystery',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1198497': {'name': 'the thin man',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q731082': {'name': 'breaking away',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q909816': {'name': 'day for night',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q177374': {'name': "there's something about mary",
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q1302846': {'name': 'fast times at ridgemont high',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  'https://www.wikidata.org/entity/Q946849': {'name': "l'âge d'or",
#   'ed_score': 0.9,
#   'jaccard_score': 0.5},
#  'https://www.wikidata.org/entity/Q2481316': {'name': 'the bank dick',
#   'ed_score': 1.0,
#   'jaccard_score': 1.0},
#  ...}

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = './Dataset/Dataset/Round1_T2D/gt/CEA_Round1_gt_WD.csv'

# Define the chunk size (number of rows per chunk)
chunk_size = 100  # Adjust this based on your memory constraints

# Initialize an empty list to store processed chunks
chunk_list = []

# Iterate over the CSV file in chunks
first_chunk = pd.read_csv(csv_file_path, nrows=1)
column_names = ["table_name", "row", "col", "url"]
result_df = pd.DataFrame()

for chunk in pd.read_csv(csv_file_path, chunksize=chunk_size):
    
    result_df = pd.concat([result_df, chunk], ignore_index=True)
    result_df.columns = column_names
    print(result_df.columns)
    break
    print(chunk.iloc[:,0])   # name of the table file
    print(chunk.iloc[:,1])   # row of the table in the middle
    print(chunk.iloc[:,2])   # col of the table in the middle
    print(chunk.iloc[:,3])   #  Qid for the GT
    break

# Display the combined DataFrame or perform further operations
#print(combined_df.iloc[:, 2:10])  # Display the first few rows of the combined DataFrame
#print(combined_df[['name','id','target']])
