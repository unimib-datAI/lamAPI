# %% [markdown]
# # Prove per extended type

# %%
! pip install SPARQLWrapper
# Out:
# Requirement already satisfied: SPARQLWrapper in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: six in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.12.0)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import bz2
import json
from collections import Counter
from tqdm import tqdm

# %%
def retrieve_superclasses(entity_id):
    """
    Retrieve all superclasses of a given Wikidata entity ID.

    Args:
        entity_id (str): The ID of the entity (e.g., "Q207784").

    Returns:
        dict: A dictionary where keys are superclass IDs, and values are their labels.
    """
    # Define the SPARQL endpoint and query
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?superclass ?superclassLabel WHERE {{
      wd:{entity_id} (wdt:P279)* ?superclass.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """

    # Function to query the SPARQL endpoint with retries
    def query_wikidata(sparql_client, query, retries=3, delay=5):
        for attempt in range(retries):
            try:
                sparql_client.setQuery(query)
                sparql_client.setReturnFormat(JSON)
                results = sparql_client.query().convert()
                return results
            except Exception as e:
                if "429" in str(e):  # Handle Too Many Requests error
                    print(f"Rate limit hit. Retrying in {delay} seconds... (Attempt {attempt + 1}/{retries})")
                    time.sleep(delay)
                else:
                    print(f"An error occurred: {e}")
                    break
        return None

    # Set up the SPARQL client
    sparql = SPARQLWrapper(endpoint_url)

    # Execute the query with retries
    results = query_wikidata(sparql, query)

    # Process results and return as a dictionary
    if results:
        superclass_dict = {}
        for result in results["results"]["bindings"]:
            superclass_id = result["superclass"]["value"].split("/")[-1]  # Extract entity ID from the URI
            label = result["superclassLabel"]["value"]
            superclass_dict[superclass_id] = label
        return superclass_dict
    else:
        print("Failed to retrieve data after multiple attempts.")
        return {}

# %%
#video game developer (Q210167)
# book publisher (Q1320047)
# video game publisher (Q1137109)

dictio = retrieve_superclasses("Q210167") | retrieve_superclasses("Q1320047") | retrieve_superclasses("Q1137109") 
print(len(dictio))
# Out:
# 35

# %%
dictio.values()
# Out:
# dict_values(['video game developer', 'video game company', 'software company', 'company', 'business', 'technology company', 'legal person', 'group of humans', 'commercial organization', 'organization', 'juridical person', 'corporation', 'economic entity', 'enterprise', 'complex system', 'social system', 'person or organization', 'corporate body', 'group of living things', 'system', 'group of physical objects', 'agent', 'object', 'collective agent', 'collective entity', 'entity', 'independent continuant', 'group or class of physical objects', 'continuant', 'book publisher', 'publishing company', 'publisher', 'video game publisher', 'board game publishing company', 'software publisher'])

# %%
len(set(dictio.values()))
# Out:
# 35

# %%
wikidata_dump_path = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/latest-all.json.bz2'
SIZE_PROC = 1000
chunk_size = 1000  # Number of rows per chunk


def process_entity(item):
    try:
        entity = item['id']
        labels = item.get("labels", {})
        english_label = labels.get("en", {}).get("value", "")
        description = item.get('descriptions', {}).get('en', {})
        NERtype = None

        if item.get("type") == "item" and "claims" in item:
            p31_claims = item["claims"].get("P279", [])

            types_list = []

            for claim in p31_claims:
                mainsnak = claim.get("mainsnak", {})
                datavalue = mainsnak.get("datavalue", {})
                numeric_id = datavalue.get("value", {}).get("numeric-id")
                types_list.append("Q"+str(numeric_id))

            return [entity, english_label, types_list]
        

    except json.decoder.JSONDecodeError:
        pass

# Initial setup for data processing
counter = 0

# Process data and print relevant details
try:
    with bz2.open(wikidata_dump_path, 'rt', encoding='utf-8') as f:
        pbar = tqdm(total=SIZE_PROC)
        
        for line in f:
            try:
                item = json.loads(line[:-2])

                if item.get("type") == "item" and "claims" in item:
                    p31_claims = item["claims"].get("P31", [])
                    entity = item['id']
                    labels = item.get("labels", {})
                    english_label = labels.get("en", {}).get("value", "")

                    types_list = []

                    for claim in p31_claims:
                        mainsnak = claim.get("mainsnak", {})
                        datavalue = mainsnak.get("datavalue", {})
                        type_numeric_id = datavalue.get("value", {}).get("numeric-id")
                        types_list.append("Q"+str(type_numeric_id))

                total = []
                extended_WDtypes = []

                for el in types_list:
                    total += retrieve_superclasses(el)
                    superclasses = retrieve_superclasses(el)  # Replace with your entity ID
                    #print(f"[{el}] - # superclasses: {len(superclasses)}")
                extended_WDtypes = set(total)




                #entity, english_label, types_list = process_entity(item)

                print(english_label)

                for el in types_list:
                    superclasses = retrieve_superclasses(el)  # Replace with your entity ID
                    
                    print(f"[{el}] - Number of Superclasses: {(superclasses)}")
                    if el == "Q3624078":  # soveraign state
                        print("Q2221906" in superclasses)   # geographical location
                    if el == "Q6256":  # country
                        print("Q2221906" in superclasses)   # geographical location

                print("_______________________")

            
            except json.decoder.JSONDecodeError:
                continue

            if counter == SIZE_PROC:
                break
            counter += 1
        pbar.close()

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   0%|          | 0/1000 [04:35<?, ?it/s]
# Belgium
# [Q3624078] - Number of Superclasses: {'Q3624078': 'sovereign state', 'Q6256': 'country', 'Q7275': 'state', 'Q1048835': 'political territorial entity', 'Q4835091': 'territory', 'Q155076': 'juridical person', 'Q177634': 'community', 'Q1896989': 'subject of international law', 'Q96196009': 'former or current state', 'Q3778211': 'legal person', 'Q874405': 'human social group', 'Q21157127': 'cluster', 'Q56061': 'administrative territorial entity', 'Q82794': 'geographic region', 'Q1063239': 'polity', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q7210356': 'political organization', 'Q106559804': 'person or organization', 'Q16887380': 'group', 'Q27096213': 'geographic entity', 'Q58778': 'system', 'Q43229': 'organization', 'Q2221906': 'geographic location', 'Q27096235': 'artificial geographic entity', 'Q16334298': 'group of living things', 'Q3455524': 'administrative region', 'Q99527517': 'collective entity', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q24229398': 'agent', 'Q854457': 'complex system', 'Q106668099': 'corporate body', 'Q488383': 'object', 'Q18810687': 'political institution', 'Q61961344': 'group of physical objects', 'Q58415929': 'spatio-temporal entity', 'Q53617489': 'independent continuant', 'Q123349660': 'geolocatable entity', 'Q16686448': 'artificial object', 'Q35120': 'entity', 'Q124711467': 'immaterial entity', 'Q178706': 'institution', 'Q103940464': 'continuant', 'Q98119401': 'group or class of physical objects', 'Q131085629': 'collective agent', 'Q53617407': 'material entity', 'Q211606': 'social structure', 'Q6671777': 'structure'}
# True
# [Q43702] - Number of Superclasses: {'Q43702': 'federation', 'Q1140229': 'political union', 'Q22676603': 'federal system', 'Q484652': 'international organization', 'Q1048835': 'political territorial entity', 'Q28108': 'political system', 'Q1639378': 'social system', 'Q43229': 'organization', 'Q56061': 'administrative territorial entity', 'Q854457': 'complex system', 'Q16334295': 'group of humans', 'Q106559804': 'person or organization', 'Q106668099': 'corporate body', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q58778': 'system', 'Q488383': 'object', 'Q99527517': 'collective entity', 'Q2221906': 'geographic location', 'Q4835091': 'territory', 'Q27096235': 'artificial geographic entity', 'Q16334298': 'group of living things', 'Q1063239': 'polity', 'Q3455524': 'administrative region', 'Q24229398': 'agent', 'Q131085629': 'collective agent', 'Q35120': 'entity', 'Q7210356': 'political organization', 'Q27096213': 'geographic entity', 'Q18810687': 'political institution', 'Q82794': 'geographic region', 'Q61961344': 'group of physical objects', 'Q53617489': 'independent continuant', 'Q16686448': 'artificial object', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q178706': 'institution', 'Q123349660': 'geolocatable entity', 'Q103940464': 'continuant', 'Q98119401': 'group or class of physical objects', 'Q211606': 'social structure', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q53617407': 'material entity', 'Q6671777': 'structure', 'Q58415929': 'spatio-temporal entity', 'Q124711467': 'immaterial entity'}
# [Q6256] - Number of Superclasses: {'Q6256': 'country', 'Q1048835': 'political territorial entity', 'Q4835091': 'territory', 'Q56061': 'administrative territorial entity', 'Q82794': 'geographic region', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q27096213': 'geographic entity', 'Q2221906': 'geographic location', 'Q27096235': 'artificial geographic entity', 'Q1063239': 'polity', 'Q3455524': 'administrative region', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q7210356': 'political organization', 'Q18810687': 'political institution', 'Q58415929': 'spatio-temporal entity', 'Q123349660': 'geolocatable entity', 'Q16686448': 'artificial object', 'Q124711467': 'immaterial entity', 'Q43229': 'organization', 'Q488383': 'object', 'Q178706': 'institution', 'Q53617407': 'material entity', 'Q53617489': 'independent continuant', 'Q854457': 'complex system', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q106559804': 'person or organization', 'Q106668099': 'corporate body', 'Q211606': 'social structure', 'Q35120': 'entity', 'Q103940464': 'continuant', 'Q6671777': 'structure', 'Q58778': 'system', 'Q16334298': 'group of living things', 'Q24229398': 'agent', 'Q131085629': 'collective agent', 'Q99527517': 'collective entity', 'Q61961344': 'group of physical objects', 'Q98119401': 'group or class of physical objects'}
# True
# [Q20181813] - Number of Superclasses: {'Q20181813': 'colonial power', 'Q3624078': 'sovereign state', 'Q6256': 'country', 'Q7275': 'state', 'Q1048835': 'political territorial entity', 'Q4835091': 'territory', 'Q155076': 'juridical person', 'Q177634': 'community', 'Q1896989': 'subject of international law', 'Q96196009': 'former or current state', 'Q3778211': 'legal person', 'Q874405': 'human social group', 'Q21157127': 'cluster', 'Q56061': 'administrative territorial entity', 'Q82794': 'geographic region', 'Q1063239': 'polity', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q7210356': 'political organization', 'Q106559804': 'person or organization', 'Q16887380': 'group', 'Q27096213': 'geographic entity', 'Q58778': 'system', 'Q43229': 'organization', 'Q2221906': 'geographic location', 'Q27096235': 'artificial geographic entity', 'Q16334298': 'group of living things', 'Q3455524': 'administrative region', 'Q99527517': 'collective entity', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q24229398': 'agent', 'Q854457': 'complex system', 'Q106668099': 'corporate body', 'Q488383': 'object', 'Q18810687': 'political institution', 'Q61961344': 'group of physical objects', 'Q58415929': 'spatio-temporal entity', 'Q53617489': 'independent continuant', 'Q123349660': 'geolocatable entity', 'Q16686448': 'artificial object', 'Q35120': 'entity', 'Q124711467': 'immaterial entity', 'Q178706': 'institution', 'Q103940464': 'continuant', 'Q98119401': 'group or class of physical objects', 'Q131085629': 'collective agent', 'Q53617407': 'material entity', 'Q211606': 'social structure', 'Q6671777': 'structure'}
# [Q185441] - Number of Superclasses: {'Q185441': 'member state of the European Union', 'Q1646605': 'member state', 'Q7275': 'state', 'Q8191099': 'member', 'Q155076': 'juridical person', 'Q177634': 'community', 'Q1048835': 'political territorial entity', 'Q1896989': 'subject of international law', 'Q96196009': 'former or current state', 'Q3778211': 'legal person', 'Q874405': 'human social group', 'Q21157127': 'cluster', 'Q56061': 'administrative territorial entity', 'Q106559804': 'person or organization', 'Q1063239': 'polity', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q7210356': 'political organization', 'Q16887380': 'group', 'Q24229398': 'agent', 'Q58778': 'system', 'Q43229': 'organization', 'Q2221906': 'geographic location', 'Q4835091': 'territory', 'Q27096235': 'artificial geographic entity', 'Q16334298': 'group of living things', 'Q3455524': 'administrative region', 'Q99527517': 'collective entity', 'Q53617489': 'independent continuant', 'Q854457': 'complex system', 'Q106668099': 'corporate body', 'Q488383': 'object', 'Q27096213': 'geographic entity', 'Q18810687': 'political institution', 'Q82794': 'geographic region', 'Q61961344': 'group of physical objects', 'Q16686448': 'artificial object', 'Q103940464': 'continuant', 'Q35120': 'entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q178706': 'institution', 'Q123349660': 'geolocatable entity', 'Q98119401': 'group or class of physical objects', 'Q131085629': 'collective agent', 'Q211606': 'social structure', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q53617407': 'material entity', 'Q6671777': 'structure', 'Q58415929': 'spatio-temporal entity', 'Q124711467': 'immaterial entity'}
# [Q1250464] - Number of Superclasses: {'Q1250464': 'realm', 'Q7275': 'state', 'Q183366': 'territory', 'Q155076': 'juridical person', 'Q177634': 'community', 'Q1048835': 'political territorial entity', 'Q1896989': 'subject of international law', 'Q96196009': 'former or current state', 'Q56061': 'administrative territorial entity', 'Q82794': 'geographic region', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q3778211': 'legal person', 'Q874405': 'human social group', 'Q21157127': 'cluster', 'Q1063239': 'polity', 'Q27096213': 'geographic entity', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q7210356': 'political organization', 'Q106559804': 'person or organization', 'Q2221906': 'geographic location', 'Q4835091': 'territory', 'Q27096235': 'artificial geographic entity', 'Q3455524': 'administrative region', 'Q16887380': 'group', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q58778': 'system', 'Q18810687': 'political institution', 'Q43229': 'organization', 'Q16334298': 'group of living things', 'Q99527517': 'collective entity', 'Q58415929': 'spatio-temporal entity', 'Q123349660': 'geolocatable entity', 'Q16686448': 'artificial object', 'Q24229398': 'agent', 'Q124711467': 'immaterial entity', 'Q854457': 'complex system', 'Q106668099': 'corporate body', 'Q488383': 'object', 'Q61961344': 'group of physical objects', 'Q178706': 'institution', 'Q53617489': 'independent continuant', 'Q35120': 'entity', 'Q53617407': 'material entity', 'Q211606': 'social structure', 'Q103940464': 'continuant', 'Q98119401': 'group or class of physical objects', 'Q131085629': 'collective agent', 'Q6671777': 'structure'}
# [Q113489728] - Number of Superclasses: {'Q113489728': 'OECD country', 'Q1646605': 'member state', 'Q7275': 'state', 'Q8191099': 'member', 'Q155076': 'juridical person', 'Q177634': 'community', 'Q1048835': 'political territorial entity', 'Q1896989': 'subject of international law', 'Q96196009': 'former or current state', 'Q3778211': 'legal person', 'Q874405': 'human social group', 'Q21157127': 'cluster', 'Q56061': 'administrative territorial entity', 'Q106559804': 'person or organization', 'Q1063239': 'polity', 'Q15642541': 'human-geographic territorial entity', 'Q16562419': 'political entity', 'Q1639378': 'social system', 'Q16334295': 'group of humans', 'Q7210356': 'political organization', 'Q16887380': 'group', 'Q24229398': 'agent', 'Q58778': 'system', 'Q43229': 'organization', 'Q2221906': 'geographic location', 'Q4835091': 'territory', 'Q27096235': 'artificial geographic entity', 'Q16334298': 'group of living things', 'Q3455524': 'administrative region', 'Q99527517': 'collective entity', 'Q53617489': 'independent continuant', 'Q854457': 'complex system', 'Q106668099': 'corporate body', 'Q488383': 'object', 'Q27096213': 'geographic entity', 'Q18810687': 'political institution', 'Q82794': 'geographic region', 'Q61961344': 'group of physical objects', 'Q16686448': 'artificial object', 'Q103940464': 'continuant', 'Q35120': 'entity', 'Q618123': 'geographical feature', 'Q26713767': 'region of space', 'Q178706': 'institution', 'Q123349660': 'geolocatable entity', 'Q98119401': 'group or class of physical objects', 'Q131085629': 'collective agent', 'Q211606': 'social structure', 'Q23956024': 'spacetime region', 'Q25404640': 'spatial object', 'Q124711484': 'spatial region', 'Q53617407': 'material entity', 'Q6671777': 'structure', 'Q58415929': 'spatio-temporal entity', 'Q124711467': 'immaterial entity'}
# _______________________
# happiness
# [Q331769] - Number of Superclasses: {'Q331769': 'mood', 'Q781413': 'cognitive process', 'Q41537118': 'emotional state', 'Q2996394': 'biological process', 'Q12047512': 'psychological phenomenon', 'Q12047513': 'mental process', 'Q3968640': 'mental state', 'Q17320256': 'physical process', 'Q64732777': 'biological phenomenon', 'Q813912': 'condition', 'Q1190554': 'occurrence', 'Q3505845': 'state', 'Q483247': 'phenomenon', 'Q30241068': 'observable entity', 'Q67518978': 'occurrent', 'Q937228': 'property', 'Q1293220': 'physical phenomenon', 'Q111752858': 'physicochemical process', 'Q1322005': 'natural phenomenon', 'Q7048977': 'abstract entity', 'Q35120': 'entity', 'Q58415929': 'spatio-temporal entity', 'Q3249551': 'process', 'Q20937557': 'sequence', 'Q488383': 'object', 'Q16889133': 'class', 'Q5127848': 'class', 'Q99527517': 'collective entity'}
# [Q60539479] - Number of Superclasses: {'Q60539479': 'positive emotion', 'Q9415': 'emotions', 'Q282250': 'qualia', 'Q3968640': 'mental state', 'Q7268708': 'qualitative property', 'Q813912': 'condition', 'Q1190554': 'occurrence', 'Q3505845': 'state', 'Q12047512': 'psychological phenomenon', 'Q67518978': 'occurrent', 'Q483247': 'phenomenon', 'Q937228': 'property', 'Q30241068': 'observable entity', 'Q7048977': 'abstract entity', 'Q58415929': 'spatio-temporal entity', 'Q35120': 'entity', 'Q488383': 'object'}
# _______________________
# George Washington
# [Q5] - Number of Superclasses: {'Q5': 'human', 'Q154954': 'natural person', 'Q164509': 'omnivore', 'Q215627': 'person', 'Q26401003': 'individual animal', 'Q110551885': 'mammal', 'Q3778211': 'legal person', 'Q106559804': 'person or organization', 'Q729': 'animal', 'Q72638': 'consumer', 'Q795052': 'individual', 'Q10855152': 'individual organism', 'Q12898224': 'vertebrate', 'Q159344': 'heterotroph', 'Q7239': 'organism', 'Q24229398': 'agent', 'Q223557': 'physical object', 'Q66394244': 'physical anatomical entity', 'Q21871294': 'group or class of organisms', 'Q53617489': 'independent continuant', 'Q4406616': 'concrete object', 'Q53617407': 'material entity', 'Q16889133': 'class', 'Q98119401': 'group or class of physical objects', 'Q103940464': 'continuant', 'Q27043950': 'anatomical entity', 'Q488383': 'object', 'Q5127848': 'class', 'Q7048977': 'abstract entity', 'Q99527517': 'collective entity', 'Q35120': 'entity'}
# _______________________
# Jack Bauer
# [Q15632617] - Number of Superclasses: {'Q15632617': 'fictional human', 'Q28020127': 'fictional humanoid', 'Q96789464': 'fictional primate', 'Q97498056': 'fictional person', 'Q122192387': 'imaginary human', 'Q2593744': 'fictional creature', 'Q30017383': 'fictional organism', 'Q27277631': 'fictional mammal', 'Q115537581': 'imaginary character', 'Q95074': 'fictional character', 'Q3542731': 'fictional animal character', 'Q115257598': 'imaginary mammal', 'Q24229398': 'agent', 'Q14897293': 'fictional entity', 'Q53617489': 'independent continuant', 'Q7048977': 'abstract entity', 'Q16686448': 'artificial object', 'Q64728693': 'non-existent entity', 'Q103940464': 'continuant', 'Q35120': 'entity', 'Q488383': 'object'}
# [Q15773317] - Number of Superclasses: {'Q15773317': 'television character', 'Q95074': 'fictional character', 'Q14897293': 'fictional entity', 'Q115537581': 'imaginary character', 'Q7048977': 'abstract entity', 'Q16686448': 'artificial object', 'Q64728693': 'non-existent entity', 'Q24229398': 'agent', 'Q35120': 'entity', 'Q488383': 'object', 'Q53617489': 'independent continuant', 'Q103940464': 'continuant'}
# [Q20085850] - Number of Superclasses: {'Q20085850': 'fictional vigilante', 'Q95074': 'fictional character', 'Q14897293': 'fictional entity', 'Q115537581': 'imaginary character', 'Q7048977': 'abstract entity', 'Q16686448': 'artificial object', 'Q64728693': 'non-existent entity', 'Q24229398': 'agent', 'Q35120': 'entity', 'Q488383': 'object', 'Q53617489': 'independent continuant', 'Q103940464': 'continuant'}
# _______________________
# Douglas Adams
# [Q5] - Number of Superclasses: {'Q5': 'human', 'Q154954': 'natural person', 'Q164509': 'omnivore', 'Q215627': 'person', 'Q26401003': 'individual animal', 'Q110551885': 'mammal', 'Q3778211': 'legal person', 'Q106559804': 'person or organization', 'Q729': 'animal', 'Q72638': 'consumer', 'Q795052': 'individual', 'Q10855152': 'individual organism', 'Q12898224': 'vertebrate', 'Q159344': 'heterotroph', 'Q7239': 'organism', 'Q24229398': 'agent', 'Q223557': 'physical object', 'Q66394244': 'physical anatomical entity', 'Q21871294': 'group or class of organisms', 'Q53617489': 'independent continuant', 'Q4406616': 'concrete object', 'Q53617407': 'material entity', 'Q16889133': 'class', 'Q98119401': 'group or class of physical objects', 'Q103940464': 'continuant', 'Q27043950': 'anatomical entity', 'Q488383': 'object', 'Q5127848': 'class', 'Q7048977': 'abstract entity', 'Q99527517': 'collective entity', 'Q35120': 'entity'}
# _______________________
# Paul Otlet
# [Q5] - Number of Superclasses: {'Q5': 'human', 'Q154954': 'natural person', 'Q164509': 'omnivore', 'Q215627': 'person', 'Q26401003': 'individual animal', 'Q110551885': 'mammal', 'Q3778211': 'legal person', 'Q106559804': 'person or organization', 'Q729': 'animal', 'Q72638': 'consumer', 'Q795052': 'individual', 'Q10855152': 'individual organism', 'Q12898224': 'vertebrate', 'Q159344': 'heterotroph', 'Q7239': 'organism', 'Q24229398': 'agent', 'Q223557': 'physical object', 'Q66394244': 'physical anatomical entity', 'Q21871294': 'group or class of organisms', 'Q53617489': 'independent continuant', 'Q4406616': 'concrete object', 'Q53617407': 'material entity', 'Q16889133': 'class', 'Q98119401': 'group or class of physical objects', 'Q103940464': 'continuant', 'Q27043950': 'anatomical entity', 'Q488383': 'object', 'Q5127848': 'class', 'Q7048977': 'abstract entity', 'Q99527517': 'collective entity', 'Q35120': 'entity'}
# _______________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 35>()
#      60 for el in types_list:
#      61     total += retrieve_superclasses(el)
# ---> 62     superclasses = retrieve_superclasses(el)  # Replace with your entity ID
#      63     #print(f"[{el}] - # superclasses: {len(superclasses)}")
#      64 extended_WDtypes = set(total)
#
# Input In [5], in retrieve_superclasses(entity_id)
#      38 sparql = SPARQLWrapper(endpoint_url)
#      40 # Execute the query with retries
# ---> 41 results = query_wikidata(sparql, query)
#      43 # Process results and return as a dictionary
#      44 if results:
#
# Input In [5], in retrieve_superclasses.<locals>.query_wikidata(sparql_client, query, retries, delay)
#      24     sparql_client.setQuery(query)
#      25     sparql_client.setReturnFormat(JSON)
# ---> 26     results = sparql_client.query().convert()
#      27     return results
#      28 except Exception as e:
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Example usage
superclasses = retrieve_superclasses("Q1320047")  # Replace with your entity ID
print("Number of Superclasses:", len(superclasses))
print("Superclass Dictionary:")
print(superclasses)

# %% [markdown]
# # Esperimenti fatti con Riccardo

# %%
import bz2
import json
from tqdm import tqdm
import traceback
import os
from pymongo import MongoClient
from pymongo import *
from pymongo import errors
import configparser
from json.decoder import JSONDecodeError
from requests import get

# %%
# MongoDB connection setup
MONGO_ENDPOINT, MONGO_ENDPOINT_PORT = os.environ["MONGO_ENDPOINT"].split(":")
MONGO_ENDPOINT_PORT = int(MONGO_ENDPOINT_PORT)
MONGO_ENDPOINT_USERNAME = os.environ["MONGO_INITDB_ROOT_USERNAME"]
MONGO_ENDPOINT_PASSWORD = os.environ["MONGO_INITDB_ROOT_PASSWORD"]
DB_NAME = f"wikidata"

client = MongoClient(MONGO_ENDPOINT, MONGO_ENDPOINT_PORT, username=MONGO_ENDPOINT_USERNAME, password=MONGO_ENDPOINT_PASSWORD)
print(client)

log_c = client.wikidata.log
items_c = client[DB_NAME].items
objects_c = client[DB_NAME].objects
literals_c = client[DB_NAME].literals
types_c = client[DB_NAME].types

c_ref = {
    "items": items_c,
    "objects":objects_c, 
    "literals":literals_c, 
    "types":types_c
}

def flush_buffer(buffer):
    for key in buffer:
        if len(buffer[key]) > 0:
            c_ref[key].insert_many(buffer[key])
            buffer[key] = []

# %%
def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.
    --------------------------------------------
    For example, if you have an item with types A, B, and C, and you specify a forward property that applies to type B, the item will 
    be included in the result because it has type B, even if it also has types A and C
    --------------------------------------------  
    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids

# %%
# example with "capital city"

list = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
for el in list:
    data = {
        "json": [
            "Q"+(str(el))
        ]
    }
    response = requests.post(url, headers=headers, json=data)

    try:
        result = response.json()
        label = result["Q"+(str(el))]['labels']['en']
        print(label)  # Print the label or ID with indentation
    except:
        pass

# %%
# Function to fetch the necessary subclass sets with individual try-except blocks
def fetch_wikidata_subclasses():
    try:
        organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        organization_subclass = []
    
    try:
        country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        country_subclass = []
    
    try:
        city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        city_subclass = []
    
    try:
        capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        capitals_subclass = []
    
    try:
        admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        admTerr_subclass = []
    
    try:
        family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        family_subclass = []
    
    try:
        sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        sportLeague_subclass = []
    
    try:
        venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        venue_subclass = []
    
    # Removing overlaps for organization_subclass
    organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))
    
    try:
        geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        geolocation_subclass = []
    
    try:
        food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        food_subclass = []
    
    try:
        edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        edInst_subclass = []
    
    try:
        govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        govAgency_subclass = []
    
    try:
        intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        intOrg_subclass = []
    
    try:
        timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        timeZone_subclass = []

    # Removing overlaps for geolocation_subclass
    geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))
    
    return organization_subclass, geolocation_subclass

# %%
with open("./organization_subclass.txt", "w") as file:
    for item in organization_subclass:
        file.write(f"{item}\n")  # Write each item on a new line

# %%
from collections import Counter


wikidata_dump_path = './data/latest-all.json.bz2'
SIZE_PROC = 1000
chunk_size = 1000  # Number of rows per chunk

organization_subclass, geolocation_subclass = fetch_wikidata_subclasses()

def process_entity(item):
    try:
        entity = item['id']
        labels = item.get("labels", {})
        english_label = labels.get("en", {}).get("value", "")
        description = item.get('descriptions', {}).get('en', {})
        NERtype = None

        if item.get("type") == "item" and "claims" in item:
            p31_claims = item["claims"].get("P31", [])

            # Initialize a counter to track occurrences of NER types
            ner_counter = Counter()

            for claim in p31_claims:
                mainsnak = claim.get("mainsnak", {})
                datavalue = mainsnak.get("datavalue", {})
                numeric_id = datavalue.get("value", {}).get("numeric-id")

                # Classify NER types
                if numeric_id == 5:
                    ner_counter['PERS'] += 1
                elif numeric_id in geolocation_subclass or any(k.lower() in description.get('value', '').lower().split() for k in ["district", "city", "country", "capital", "state"]):
                    ner_counter['LOC'] += 1
                elif numeric_id in organization_subclass:
                    ner_counter['ORG'] += 1
                else:
                    ner_counter['OTHERS'] += 1
                    
            # Get the most common NER type
            if ner_counter:
                NERtype, _ = ner_counter.most_common(1)[0]  # Get the most common type

            # Print label, ID, type, and NER classification
            print(f"{english_label} - {entity}: (NER type: {NERtype})")

    except json.decoder.JSONDecodeError:
        pass

# Initial setup for data processing
counter = 0

# Process data and print relevant details
try:
    with bz2.open(wikidata_dump_path, 'rt', encoding='utf-8') as f:
        pbar = tqdm(total=SIZE_PROC)
        
        for line in f:
            try:
                item = json.loads(line[:-2])
                process_entity(item)
            except json.decoder.JSONDecodeError:
                continue

            if counter == SIZE_PROC:
                break
            counter += 1
        pbar.close()

except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# # Test query chiusura transitiva

# %%
! pip install SPARQLWrapper

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def get_subclasses(Qid):
    # Initialize the SPARQL endpoint (Wikidata in this case)
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    
    # Define the SPARQL query with the provided QID
    query = f"""
    SELECT DISTINCT ?item ?desc WHERE {{
      wd:{Qid} wdt:P279* ?item.
      # ?item rdfs:label ?desc FILTER (lang(?desc) = "en").
    }}
    """
    
    # Set the query and the return format (JSON)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get results
    results = sparql.query().convert()
    
    # Parse the results
    subclasses = []
    for result in results["results"]["bindings"]:
        item = result["item"]["value"]
        desc = result["desc"]["value"]
        subclasses.append({"item": item, "description": desc})
    
    return subclasses

# Example usage
Qid = "Q64027599" 
subclasses = get_subclasses(Qid)

for subclass in subclasses:
    print(f"Item: {subclass['item']}, Description: {subclass['description']}")

# %%
query_data = {
    "query": {
        "bool": {
            "must": [
                {
                    "match": {
                        "name": {
                            "query": "Belgium",
                            "boost": 2.0
                        }
                    }
                }
            ],
            "should": [
                {"term": {"type": "realm"}},
                {"term": {"type": "soverign state"}},
                {"term": {"type": "country"}}
            ],
            "minimum_should_match": 1
        }
    }
}

# %%
import requests
import json

# Define the URL
url = 'https://lamapi.hel.sintef.cloud/lookup/entity-retrieval'

# Define the query data (decoded for readability)
query_data = {
  "query": {
    "bool": {
      "must": [
        {
          "query_string": {
            "default_field":"types",  "query": "Q6881511"
          }
        },
        {
          "match": {
            "name": {"query":"sinopec","boost":2.0}
          }
        }
      ]
    }
  }
}

# Define the parameters and token
params = {
    'name': 'sinopec',
    #'query': json.dumps(query_data),  # JSON encoded query data
    'token': 'lamapi_demo_2023'
}

# Send the GET request
response = requests.get(url, params=params, headers={'accept': 'application/json'})

# Print the response
if response.status_code == 200:
    res = response.json()
    for el in res:
        print(f"{el['name']} ({el['id']}) with type:")
        for type in el['types']:
            print(f"                {type['name']}")  # Assuming the response is JSON formatted
else:
    print(f"Request failed with status code {response.status_code}")
