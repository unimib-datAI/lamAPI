# %% [markdown]
# # Prove per extended type

# %%
! pip install SPARQLWrapper
# Out:
# Requirement already satisfied: SPARQLWrapper in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.9)
# Requirement already satisfied: six in c:\users\abelo\anaconda3\envs\v_env\lib\site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.12.0)

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import bz2
import json
from collections import Counter
from tqdm import tqdm

# %%
def retrieve_superclasses(entity_id):
    """
    Retrieve all superclasses of a given Wikidata entity ID.

    Args:
        entity_id (str): The ID of the entity (e.g., "Q207784").

    Returns:
        dict: A dictionary where keys are superclass IDs, and values are their labels.
    """
    # Define the SPARQL endpoint and query
    endpoint_url = "https://query.wikidata.org/sparql"
    query = f"""
    SELECT ?superclass ?superclassLabel WHERE {{
      wd:{entity_id} (wdt:P279)* ?superclass.
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    """

    # Function to query the SPARQL endpoint with retries
    def query_wikidata(sparql_client, query, retries=3, delay=5):
        for attempt in range(retries):
            try:
                sparql_client.setQuery(query)
                sparql_client.setReturnFormat(JSON)
                results = sparql_client.query().convert()
                return results
            except Exception as e:
                if "429" in str(e):  # Handle Too Many Requests error
                    print(f"Rate limit hit. Retrying in {delay} seconds... (Attempt {attempt + 1}/{retries})")
                    time.sleep(delay)
                else:
                    print(f"An error occurred: {e}")
                    break
        return None

    # Set up the SPARQL client
    sparql = SPARQLWrapper(endpoint_url)

    # Execute the query with retries
    results = query_wikidata(sparql, query)

    # Process results and return as a dictionary
    if results:
        superclass_dict = {}
        for result in results["results"]["bindings"]:
            superclass_id = result["superclass"]["value"].split("/")[-1]  # Extract entity ID from the URI
            label = result["superclassLabel"]["value"]
            superclass_dict[superclass_id] = label
        return superclass_dict
    else:
        print("Failed to retrieve data after multiple attempts.")
        return {}

# %%
wikidata_dump_path = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/latest-all.json.bz2'
SIZE_PROC = 1000
chunk_size = 1000  # Number of rows per chunk


def process_entity(item):
    try:
        entity = item['id']
        labels = item.get("labels", {})
        english_label = labels.get("en", {}).get("value", "")
        description = item.get('descriptions', {}).get('en', {})
        NERtype = None

        if item.get("type") == "item" and "claims" in item:
            p31_claims = item["claims"].get("P279", [])

            types_list = []

            for claim in p31_claims:
                mainsnak = claim.get("mainsnak", {})
                datavalue = mainsnak.get("datavalue", {})
                numeric_id = datavalue.get("value", {}).get("numeric-id")
                types_list.append("Q"+str(numeric_id))

            return [entity, english_label, types_list]
        

    except json.decoder.JSONDecodeError:
        pass

# Initial setup for data processing
counter = 0

# Process data and print relevant details
try:
    with bz2.open(wikidata_dump_path, 'rt', encoding='utf-8') as f:
        pbar = tqdm(total=SIZE_PROC)
        
        for line in f:
            try:
                item = json.loads(line[:-2])
                print(item)
                entity, english_label, types_list = process_entity(item)

                print(entity)
                print(types_list)
                for el in types_list:
                    superclasses = retrieve_superclasses(el)  # Replace with your entity ID
                    
                    print(f"[{el}] - Number of Superclasses: {len(superclasses)}")

                print("_______________________")

            
            except json.decoder.JSONDecodeError:
                continue

            if counter == SIZE_PROC:
                break
            counter += 1
        pbar.close()

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#   0%|          | 0/1000 [00:49<?, ?it/s]
# {'type': 'item', 'id': 'Q31', 'labels': {'el': {'language': 'el', 'value': 'Βέλγιο'}, 'ay': {'language': 'ay', 'value': 'Bilkiya'}, 'pnb': {'language': 'pnb', 'value': 'بیلجیئم'}, 'na': {'language': 'na', 'value': 'Berdjiyum'}, 'mk': {'language': 'mk', 'value': 'Белгија'}, 'bn': {'language': 'bn', 'value': 'বেলজিয়াম'}, 'bpy': {'language': 'bpy', 'value': 'বেলজিয়াম'}, 'lt': {'language': 'lt', 'value': 'Belgija'}, 'jam': {'language': 'jam', 'value': 'Beljiom'}, 'sk': {'language': 'sk', 'value': 'Belgicko'}, 'so': {'language': 'so', 'value': 'Beljim'}, 'tl': {'language': 'tl', 'value': 'Belgium'}, 'uk': {'language': 'uk', 'value': 'Бельгія'}, 'tt': {'language': 'tt', 'value': 'Бельгия'}, 'sc': {'language': 'sc', 'value': 'Bèlgiu'}, 'bxr': {'language': 'bxr', 'value': 'Бельги'}, 'ff': {'language': 'ff', 'value': 'Beljik'}, 'za': {'language': 'za', 'value': 'Bijliswz'}, 'yo': {'language': 'yo', 'value': 'Bẹ́ljíọ̀m'}, 'ext': {'language': 'ext', 'value': 'Bélgica'}, 'zea': {'language': 'zea', 'value': 'Belhië'}, 'es': {'language': 'es', 'value': 'Bélgica'}, 'or': {'language': 'or', 'value': 'ବେଲଜିଅମ'}, 'myv': {'language': 'myv', 'value': 'Бельгия Мастор'}, 'yi': {'language': 'yi', 'value': 'בעלגיע'}, 'ga': {'language': 'ga', 'value': 'an Bheilg'}, 'csb': {'language': 'csb', 'value': 'Belgijskô'}, 'gag': {'language': 'gag', 'value': 'Belgiya'}, 'oc': {'language': 'oc', 'value': 'Belgica'}, 'pfl': {'language': 'pfl', 'value': 'Belgje'}, 'rw': {'language': 'rw', 'value': 'Ububiligi'}, 'sco': {'language': 'sco', 'value': 'Belgium'}, 'sgs': {'language': 'sgs', 'value': 'Belgėjė'}, 'ltg': {'language': 'ltg', 'value': 'Beļgeja'}, 'zh-sg': {'language': 'zh-sg', 'value': '比利时'}, 'tet': {'language': 'tet', 'value': 'Béljika'}, 'az': {'language': 'az', 'value': 'Belçika'}, 'mzn': {'language': 'mzn', 'value': 'بلژیک'}, 'zh-hk': {'language': 'zh-hk', 'value': '比利時'}, 'bar': {'language': 'bar', 'value': 'Bäigien'}, 'zh': {'language': 'zh', 'value': '比利時'}, 'nl': {'language': 'nl', 'value': 'België'}, 'lez': {'language': 'lez', 'value': 'Бельгия'}, 'ast': {'language': 'ast', 'value': 'Bélxica'}, 'bm': {'language': 'bm', 'value': 'Bɛliziki'}, 'ta': {'language': 'ta', 'value': 'பெல்ஜியம்'}, 'jv': {'language': 'jv', 'value': 'Bélgié'}, 'inh': {'language': 'inh', 'value': 'Бельги'}, 'hi': {'language': 'hi', 'value': 'बेल्जियम'}, 'co': {'language': 'co', 'value': 'Belgiu'}, 'mn': {'language': 'mn', 'value': 'Бельги'}, 'pms': {'language': 'pms', 'value': 'Belgi'}, 'om': {'language': 'om', 'value': 'Beeljiyeem'}, 'sl': {'language': 'sl', 'value': 'Belgija'}, 'crh': {'language': 'crh', 'value': 'Belçika'}, 'ms': {'language': 'ms', 'value': 'Belgium'}, 'ro': {'language': 'ro', 'value': 'Belgia'}, 'bho': {'language': 'bho', 'value': 'बेल्जियम'}, 'av': {'language': 'av', 'value': 'Бельгия'}, 'lb': {'language': 'lb', 'value': 'Belsch'}, 'en-gb': {'language': 'en-gb', 'value': 'Belgium'}, 'kaa': {'language': 'kaa', 'value': 'Belgiya'}, 'ps': {'language': 'ps', 'value': 'بلجیم'}, 'stq': {'language': 'stq', 'value': 'Belgien'}, 'aeb-arab': {'language': 'aeb-arab', 'value': 'بلجيكيا'}, 'lo': {'language': 'lo', 'value': 'ປະເທດແບນຊິກ'}, 'sw': {'language': 'sw', 'value': 'Ubelgiji'}, 'nds': {'language': 'nds', 'value': 'Belgien'}, 'ksh': {'language': 'ksh', 'value': 'Belgien'}, 'bcl': {'language': 'bcl', 'value': 'Belhika'}, 'pag': {'language': 'pag', 'value': 'Belhika'}, 'da': {'language': 'da', 'value': 'Belgien'}, 'ca': {'language': 'ca', 'value': 'Bèlgica'}, 'crh-latn': {'language': 'crh-latn', 'value': 'Belçika'}, 'lv': {'language': 'lv', 'value': 'Beļģija'}, 'rup': {'language': 'rup', 'value': 'Belghia'}, 'ady': {'language': 'ady', 'value': 'Белгие'}, 'ty': {'language': 'ty', 'value': 'Peretita'}, 'gv': {'language': 'gv', 'value': 'y Velg'}, 'kbp': {'language': 'kbp', 'value': 'Pɛliziki'}, 'pt-br': {'language': 'pt-br', 'value': 'Bélgica'}, 'ar': {'language': 'ar', 'value': 'بلجيكا'}, 'srn': {'language': 'srn', 'value': 'Belgikondre'}, 'ch': {'language': 'ch' ...
# Q31
# []
# _______________________
# {'type': 'item', 'id': 'Q8', 'labels': {'en': {'language': 'en', 'value': 'happiness'}, 'fr': {'language': 'fr', 'value': 'bonheur'}, 'eo': {'language': 'eo', 'value': 'feliĉo'}, 'it': {'language': 'it', 'value': 'felicità'}, 'pl': {'language': 'pl', 'value': 'szczęście'}, 'ru': {'language': 'ru', 'value': 'счастье'}, 'de': {'language': 'de', 'value': 'Glück'}, 'en-gb': {'language': 'en-gb', 'value': 'happiness'}, 'nb': {'language': 'nb', 'value': 'lykke'}, 'ja': {'language': 'ja', 'value': '幸福'}, 'zh-hant': {'language': 'zh-hant', 'value': '快樂'}, 'es': {'language': 'es', 'value': 'felicidad'}, 'fi': {'language': 'fi', 'value': 'onnellisuus'}, 'hr': {'language': 'hr', 'value': 'sreća'}, 'pt': {'language': 'pt', 'value': 'felicidade'}, 'nl': {'language': 'nl', 'value': 'geluk'}, 'ar': {'language': 'ar', 'value': 'سعادة'}, 'be': {'language': 'be', 'value': 'шчасце'}, 'bg': {'language': 'bg', 'value': 'щастие'}, 'bn': {'language': 'bn', 'value': 'সুখ'}, 'bo': {'language': 'bo', 'value': 'དགའ་སྐྱིད།'}, 'ca': {'language': 'ca', 'value': 'felicitat'}, 'cs': {'language': 'cs', 'value': 'štěstí'}, 'da': {'language': 'da', 'value': 'lykke'}, 'el': {'language': 'el', 'value': 'ευτυχία'}, 'eu': {'language': 'eu', 'value': 'zorion'}, 'fa': {'language': 'fa', 'value': 'خوشحالی'}, 'gan': {'language': 'gan', 'value': '幸福'}, 'gl': {'language': 'gl', 'value': 'felicidade'}, 'gn': {'language': 'gn', 'value': "vy'apavẽ"}, 'he': {'language': 'he', 'value': 'אושר'}, 'hu': {'language': 'hu', 'value': 'boldogság'}, 'ia': {'language': 'ia', 'value': 'felicitate'}, 'id': {'language': 'id', 'value': 'kebahagiaan'}, 'is': {'language': 'is', 'value': 'hamingja'}, 'ka': {'language': 'ka', 'value': 'ბედნიერება'}, 'ko': {'language': 'ko', 'value': '행복'}, 'ky': {'language': 'ky', 'value': 'бакыт'}, 'lt': {'language': 'lt', 'value': 'laimė'}, 'lv': {'language': 'lv', 'value': 'laime'}, 'mk': {'language': 'mk', 'value': 'среќа'}, 'ms': {'language': 'ms', 'value': 'kebahagiaan'}, 'mwl': {'language': 'mwl', 'value': 'felcidade'}, 'new': {'language': 'new', 'value': 'लेताईगु'}, 'nn': {'language': 'nn', 'value': 'lukke'}, 'qu': {'language': 'qu', 'value': 'kusikuy'}, 'ro': {'language': 'ro', 'value': 'fericire'}, 'rue': {'language': 'rue', 'value': 'щастя'}, 'sk': {'language': 'sk', 'value': 'šťastie'}, 'sl': {'language': 'sl', 'value': 'sreča'}, 'sq': {'language': 'sq', 'value': 'lumturia'}, 'sr': {'language': 'sr', 'value': 'срећа'}, 'sv': {'language': 'sv', 'value': 'lycka'}, 'ta': {'language': 'ta', 'value': 'இன்பம்'}, 'te': {'language': 'te', 'value': 'సంతోషం'}, 'tg': {'language': 'tg', 'value': 'бахт'}, 'th': {'language': 'th', 'value': 'ความสุข'}, 'tk': {'language': 'tk', 'value': 'bagt'}, 'tr': {'language': 'tr', 'value': 'mutluluk'}, 'uk': {'language': 'uk', 'value': 'щастя'}, 'ur': {'language': 'ur', 'value': 'خوشی'}, 'vi': {'language': 'vi', 'value': 'hạnh phúc'}, 'wuu': {'language': 'wuu', 'value': '欢喜'}, 'yi': {'language': 'yi', 'value': 'פרייד'}, 'zh': {'language': 'zh', 'value': '快樂'}, 'en-ca': {'language': 'en-ca', 'value': 'happiness'}, 'de-ch': {'language': 'de-ch', 'value': 'Glück'}, 'pt-br': {'language': 'pt-br', 'value': 'felicidade'}, 'yue': {'language': 'yue', 'value': '開心'}, 'zh-hans': {'language': 'zh-hans', 'value': '快乐'}, 'zh-cn': {'language': 'zh-cn', 'value': '快乐'}, 'zh-sg': {'language': 'zh-sg', 'value': '快乐'}, 'zh-my': {'language': 'zh-my', 'value': '快乐'}, 'zh-hk': {'language': 'zh-hk', 'value': '快樂'}, 'zh-tw': {'language': 'zh-tw', 'value': '快樂'}, 'zh-mo': {'language': 'zh-mo', 'value': '快樂'}, 'kk': {'language': 'kk', 'value': 'бақыт'}, 'vep': {'language': 'vep', 'value': 'oza'}, 'tt': {'language': 'tt', 'value': 'бәхет'}, 'ml': {'language': 'ml', 'value': 'സന്തോഷം'}, 'oc': {'language': 'oc', 'value': 'felicitat'}, 'uz': {'language': 'uz', 'value': 'baxt'}, 'jbo': {'language': 'jbo', 'value': 'gleki'}, 'gu': {'language': 'gu', 'value': 'ખુશી'}, 'la': {'language': 'la', 'value': 'felicitas'}, 'pa': {'language': 'pa', 'value': 'ਖੁਸ਼ੀ' ...
# Q8
# ['Q16748867']
# [Q16748867] - Number of Superclasses: 18
# _______________________
# {'type': 'item', 'id': 'Q23', 'labels': {'eo': {'language': 'eo', 'value': 'George Washington'}, 'pl': {'language': 'pl', 'value': 'George Washington'}, 'fr': {'language': 'fr', 'value': 'George Washington'}, 'br': {'language': 'br', 'value': 'George Washington'}, 'ru': {'language': 'ru', 'value': 'Джордж Вашингтон'}, 'de': {'language': 'de', 'value': 'George Washington'}, 'it': {'language': 'it', 'value': 'George Washington'}, 'en-gb': {'language': 'en-gb', 'value': 'George Washington'}, 'ja': {'language': 'ja', 'value': 'ジョージ・ワシントン'}, 'ilo': {'language': 'ilo', 'value': 'George Washington'}, 'zh-hant': {'language': 'zh-hant', 'value': '佐治·華盛頓'}, 'es': {'language': 'es', 'value': 'George Washington'}, 'en-ca': {'language': 'en-ca', 'value': 'George Washington'}, 'hr': {'language': 'hr', 'value': 'George Washington'}, 'uz': {'language': 'uz', 'value': 'George Washington'}, 'af': {'language': 'af', 'value': 'George Washington'}, 'am': {'language': 'am', 'value': 'ጆርጅ ዋሽንግተን'}, 'an': {'language': 'an', 'value': 'George Washington'}, 'ang': {'language': 'ang', 'value': 'George Washington'}, 'ar': {'language': 'ar', 'value': 'جورج واشنطن'}, 'arc': {'language': 'arc', 'value': 'ܓܘܪܓ ܘܐܫܝܢܓܛܘܢ'}, 'arz': {'language': 'arz', 'value': 'جورج واشينطون'}, 'ast': {'language': 'ast', 'value': 'George Washington'}, 'ay': {'language': 'ay', 'value': 'George Washington'}, 'az': {'language': 'az', 'value': 'Corc Vaşinqton'}, 'ba': {'language': 'ba', 'value': 'Джордж Вашингтон'}, 'bar': {'language': 'bar', 'value': 'George Washington'}, 'bcl': {'language': 'bcl', 'value': 'George Washington'}, 'be': {'language': 'be', 'value': 'Джордж Вашынгтон'}, 'bg': {'language': 'bg', 'value': 'Джордж Вашингтон'}, 'bn': {'language': 'bn', 'value': 'জর্জ ওয়াশিংটন'}, 'bs': {'language': 'bs', 'value': 'George Washington'}, 'ca': {'language': 'ca', 'value': 'George Washington'}, 'cdo': {'language': 'cdo', 'value': 'George Washington'}, 'ceb': {'language': 'ceb', 'value': 'George Washington'}, 'chr': {'language': 'chr', 'value': 'ᏣᏥ ᏩᏒᏓᎾ'}, 'ckb': {'language': 'ckb', 'value': 'جۆرج واشینگتن'}, 'co': {'language': 'co', 'value': 'George Washington'}, 'cs': {'language': 'cs', 'value': 'George Washington'}, 'cy': {'language': 'cy', 'value': 'George Washington'}, 'da': {'language': 'da', 'value': 'George Washington'}, 'dv': {'language': 'dv', 'value': 'ޖޯޖް ވޮޝިންގޓަން'}, 'el': {'language': 'el', 'value': 'Τζορτζ Ουάσινγκτον'}, 'et': {'language': 'et', 'value': 'George Washington'}, 'eu': {'language': 'eu', 'value': 'George Washington'}, 'fa': {'language': 'fa', 'value': 'جورج واشنگتن'}, 'fi': {'language': 'fi', 'value': 'George Washington'}, 'fo': {'language': 'fo', 'value': 'George Washington'}, 'fy': {'language': 'fy', 'value': 'George Washington'}, 'ga': {'language': 'ga', 'value': 'George Washington'}, 'gan': {'language': 'gan', 'value': '喬治·華盛頓'}, 'gd': {'language': 'gd', 'value': 'George Washington'}, 'gl': {'language': 'gl', 'value': 'George Washington'}, 'haw': {'language': 'haw', 'value': 'Keoki Wakinekona'}, 'he': {'language': 'he', 'value': "ג'ורג' וושינגטון"}, 'hi': {'language': 'hi', 'value': 'जॉर्ज वॉशिंगटन'}, 'hif': {'language': 'hif', 'value': 'George Washington'}, 'hu': {'language': 'hu', 'value': 'George Washington'}, 'hy': {'language': 'hy', 'value': 'Ջորջ Վաշինգտոն'}, 'id': {'language': 'id', 'value': 'George Washington'}, 'io': {'language': 'io', 'value': 'George Washington'}, 'is': {'language': 'is', 'value': 'George Washington'}, 'iu': {'language': 'iu', 'value': 'ᔫᕐᒋ ᕚᓯᖕᑐᓐ'}, 'jv': {'language': 'jv', 'value': 'George Washington'}, 'ka': {'language': 'ka', 'value': 'ჯორჯ ვაშინგტონი'}, 'kk': {'language': 'kk', 'value': 'Джордж Вашингтон'}, 'kn': {'language': 'kn', 'value': 'ಜಾರ್ಜ್ ವಾಷಿಂಗ್ಟನ್'}, 'ko': {'language': 'ko', 'value': '조지 워싱턴'}, 'ksh': {'language': 'ksh', 'value': 'George Washington'}, 'ku': {'language': 'ku', 'value': 'George Washington'}, 'kw': {'language': 'kw', 'value': 'George Washington'}, 'ky': {'language': 'ky', 'value': 'Ваши ...
# Q23
# []
# _______________________
# {'type': 'item', 'id': 'Q24', 'labels': {'en': {'language': 'en', 'value': 'Jack Bauer'}, 'fr': {'language': 'fr', 'value': 'Jack Bauer'}, 'it': {'language': 'it', 'value': 'Jack Bauer'}, 'pl': {'language': 'pl', 'value': 'Jack Bauer'}, 'eo': {'language': 'eo', 'value': 'Jack Bauer'}, 'de': {'language': 'de', 'value': 'Jack Bauer'}, 'en-gb': {'language': 'en-gb', 'value': 'Jack Bauer'}, 'ru': {'language': 'ru', 'value': 'Джек Бауэр'}, 'ja': {'language': 'ja', 'value': 'ジャック・バウアー'}, 'zh-hant': {'language': 'zh-hant', 'value': '傑克·鮑爾'}, 'es': {'language': 'es', 'value': 'Jack Bauer'}, 'en-ca': {'language': 'en-ca', 'value': 'Jack Bauer'}, 'da': {'language': 'da', 'value': 'Jack Bauer'}, 'fa': {'language': 'fa', 'value': 'جک باور'}, 'fi': {'language': 'fi', 'value': 'Jack Bauer'}, 'he': {'language': 'he', 'value': "ג'ק באואר"}, 'hu': {'language': 'hu', 'value': 'Jack Bauer'}, 'is': {'language': 'is', 'value': 'Jack Bauer'}, 'lt': {'language': 'lt', 'value': 'Jack Bauer'}, 'mk': {'language': 'mk', 'value': 'Џек Бауер'}, 'nl': {'language': 'nl', 'value': 'Jack Bauer'}, 'pt': {'language': 'pt', 'value': 'Jack Bauer'}, 'sv': {'language': 'sv', 'value': 'Jack Bauer'}, 'sw': {'language': 'sw', 'value': 'Jack Bauer'}, 'tr': {'language': 'tr', 'value': 'Jack Bauer'}, 'zh': {'language': 'zh', 'value': '傑克·鮑爾'}, 'zh-cn': {'language': 'zh-cn', 'value': '杰克·鲍尔'}, 'zh-hans': {'language': 'zh-hans', 'value': '杰克·鲍尔'}, 'nb': {'language': 'nb', 'value': 'Jack Bauer'}, 'zh-sg': {'language': 'zh-sg', 'value': '杰克·鲍尔'}, 'zh-my': {'language': 'zh-my', 'value': '杰克·鲍尔'}, 'zh-hk': {'language': 'zh-hk', 'value': '包智傑'}, 'zh-tw': {'language': 'zh-tw', 'value': '傑克·鮑爾'}, 'zh-mo': {'language': 'zh-mo', 'value': '包智傑'}, 'pt-br': {'language': 'pt-br', 'value': 'Jack Bauer'}, 'ca': {'language': 'ca', 'value': 'Jack Bauer'}, 'ko': {'language': 'ko', 'value': '잭 바우어'}, 'be': {'language': 'be', 'value': 'Джэк Баўэр'}, 'ta': {'language': 'ta', 'value': 'ஜாக் பாவ்வர்'}, 'oc': {'language': 'oc', 'value': 'Jack Bauer'}, 'af': {'language': 'af', 'value': 'Jack Bauer'}, 'an': {'language': 'an', 'value': 'Jack Bauer'}, 'br': {'language': 'br', 'value': 'Jack Bauer'}, 'bs': {'language': 'bs', 'value': 'Jack Bauer'}, 'cs': {'language': 'cs', 'value': 'Jack Bauer'}, 'cy': {'language': 'cy', 'value': 'Jack Bauer'}, 'et': {'language': 'et', 'value': 'Jack Bauer'}, 'eu': {'language': 'eu', 'value': 'Jack Bauer'}, 'ga': {'language': 'ga', 'value': 'Jack Bauer'}, 'gl': {'language': 'gl', 'value': 'Jack Bauer'}, 'hr': {'language': 'hr', 'value': 'Jack Bauer'}, 'lb': {'language': 'lb', 'value': 'Jack Bauer'}, 'lmo': {'language': 'lmo', 'value': 'Jack Bauer'}, 'nds': {'language': 'nds', 'value': 'Jack Bauer'}, 'nds-nl': {'language': 'nds-nl', 'value': 'Jack Bauer'}, 'nn': {'language': 'nn', 'value': 'Jack Bauer'}, 'pms': {'language': 'pms', 'value': 'Jack Bauer'}, 'ro': {'language': 'ro', 'value': 'Jack Bauer'}, 'sk': {'language': 'sk', 'value': 'Jack Bauer'}, 'sl': {'language': 'sl', 'value': 'Jack Bauer'}, 'sq': {'language': 'sq', 'value': 'Jack Bauer'}, 'vec': {'language': 'vec', 'value': 'Jack Bauer'}, 'wa': {'language': 'wa', 'value': 'Jack Bauer'}, 'el': {'language': 'el', 'value': 'Τζακ Μπάουερ'}, 'gsw': {'language': 'gsw', 'value': 'Jack Bauer'}, 'lv': {'language': 'lv', 'value': 'Džeks Bauers'}, 'uk': {'language': 'uk', 'value': 'Джек Бауер'}, 'ur': {'language': 'ur', 'value': 'جیک باور'}, 'sco': {'language': 'sco', 'value': 'Jack Bauer'}, 'ne': {'language': 'ne', 'value': 'ज्याक बाउएर'}, 'fo': {'language': 'fo', 'value': 'Jack Bauer'}, 'kl': {'language': 'kl', 'value': 'Jack Bauer'}, 'hy': {'language': 'hy', 'value': 'Ջեք  Բաուեր'}, 'kn': {'language': 'kn', 'value': 'ಜ್ಯಾಕ್ ಬಾಯೆರ್'}, 'vi': {'language': 'vi', 'value': 'Jack Bauer'}, 'ar': {'language': 'ar', 'value': 'جاك باور'}, 'bg': {'language': 'bg', 'value': 'Джак Бауър'}, 'th': {'language': 'th', 'value': 'แจ็ก บาวเออร์'}, 'sr': {'language': 'sr', 'value': 'Џек Бауер'}, 'bho': {'language': 'bho', 'value': 'जैक बॉवर ...
# Q24
# []
# _______________________
# {'type': 'item', 'id': 'Q42', 'labels': {'en': {'language': 'en', 'value': 'Douglas Adams'}, 'fr': {'language': 'fr', 'value': 'Douglas Adams'}, 'ru': {'language': 'ru', 'value': 'Дуглас Адамс'}, 'pl': {'language': 'pl', 'value': 'Douglas Adams'}, 'it': {'language': 'it', 'value': 'Douglas Adams'}, 'en-gb': {'language': 'en-gb', 'value': 'Douglas Adams'}, 'nb': {'language': 'nb', 'value': 'Douglas Adams'}, 'es': {'language': 'es', 'value': 'Douglas Adams'}, 'en-ca': {'language': 'en-ca', 'value': 'Douglas Adams'}, 'hr': {'language': 'hr', 'value': 'Douglas Adams'}, 'pt': {'language': 'pt', 'value': 'Douglas Adams'}, 'ko': {'language': 'ko', 'value': '더글러스 애덤스'}, 'nl': {'language': 'nl', 'value': 'Douglas Adams'}, 'el': {'language': 'el', 'value': 'Ντάγκλας Άνταμς'}, 'ar': {'language': 'ar', 'value': 'دوغلاس آدمز'}, 'arz': {'language': 'arz', 'value': 'دوجلاس ادامز'}, 'bar': {'language': 'bar', 'value': 'Douglas Adams'}, 'be': {'language': 'be', 'value': 'Дуглас Адамс'}, 'bg': {'language': 'bg', 'value': 'Дъглас Адамс'}, 'bs': {'language': 'bs', 'value': 'Douglas Adams'}, 'ca': {'language': 'ca', 'value': 'Douglas Adams'}, 'cs': {'language': 'cs', 'value': 'Douglas Adams'}, 'cy': {'language': 'cy', 'value': 'Douglas Adams'}, 'da': {'language': 'da', 'value': 'Douglas Adams'}, 'eo': {'language': 'eo', 'value': 'Douglas Adams'}, 'et': {'language': 'et', 'value': 'Douglas Adams'}, 'fa': {'language': 'fa', 'value': 'داگلاس آدامز'}, 'fi': {'language': 'fi', 'value': 'Douglas Adams'}, 'ga': {'language': 'ga', 'value': 'Douglas Adams'}, 'gl': {'language': 'gl', 'value': 'Douglas Adams'}, 'he': {'language': 'he', 'value': 'דאגלס אדמס'}, 'hu': {'language': 'hu', 'value': 'Douglas Adams'}, 'id': {'language': 'id', 'value': 'Douglas Adams'}, 'io': {'language': 'io', 'value': 'Douglas Adams'}, 'is': {'language': 'is', 'value': 'Douglas Adams'}, 'ja': {'language': 'ja', 'value': 'ダグラス・アダムズ'}, 'jv': {'language': 'jv', 'value': 'Douglas Adams'}, 'ka': {'language': 'ka', 'value': 'დაგლას ადამსი'}, 'la': {'language': 'la', 'value': 'Duglassius Adams'}, 'lv': {'language': 'lv', 'value': 'Duglass Adamss'}, 'mk': {'language': 'mk', 'value': 'Даглас Адамс'}, 'mr': {'language': 'mr', 'value': 'डग्लस अॅडम्स'}, 'nn': {'language': 'nn', 'value': 'Douglas Adams'}, 'ro': {'language': 'ro', 'value': 'Douglas Adams'}, 'sco': {'language': 'sco', 'value': 'Douglas Adams'}, 'sh': {'language': 'sh', 'value': 'Douglas Adams'}, 'sk': {'language': 'sk', 'value': 'Douglas Adams'}, 'sl': {'language': 'sl', 'value': 'Douglas Adams'}, 'sq': {'language': 'sq', 'value': 'Douglas Adams'}, 'sr': {'language': 'sr', 'value': 'Даглас Адамс'}, 'sv': {'language': 'sv', 'value': 'Douglas Adams'}, 'ta': {'language': 'ta', 'value': 'டக்ளஸ் ஆடம்ஸ்'}, 'tr': {'language': 'tr', 'value': 'Douglas Adams'}, 'uk': {'language': 'uk', 'value': 'Дуглас Адамс'}, 'vi': {'language': 'vi', 'value': 'Douglas Adams'}, 'zh': {'language': 'zh', 'value': '道格拉斯·亞當斯'}, 'zh-cn': {'language': 'zh-cn', 'value': '道格拉斯·亚当斯'}, 'zh-hans': {'language': 'zh-hans', 'value': '道格拉斯·亚当斯'}, 'zh-hant': {'language': 'zh-hant', 'value': '道格拉斯·亞當斯'}, 'de-ch': {'language': 'de-ch', 'value': 'Douglas Adams'}, 'pt-br': {'language': 'pt-br', 'value': 'Douglas Adams'}, 'zh-sg': {'language': 'zh-sg', 'value': '道格拉斯·亚当斯'}, 'zh-my': {'language': 'zh-my', 'value': '道格拉斯·亚当斯'}, 'zh-hk': {'language': 'zh-hk', 'value': '道格拉斯·亞當斯'}, 'zh-tw': {'language': 'zh-tw', 'value': '道格拉斯·亞當斯'}, 'zh-mo': {'language': 'zh-mo', 'value': '道格拉斯·亞當斯'}, 'war': {'language': 'war', 'value': 'Douglas Adams'}, 'be-tarask': {'language': 'be-tarask', 'value': 'Дуглас Адамз'}, 'vep': {'language': 'vep', 'value': 'Adams Duglas'}, 'ur': {'language': 'ur', 'value': 'ڈگلس ایڈم'}, 'oc': {'language': 'oc', 'value': 'Douglas Adams'}, 'af': {'language': 'af', 'value': 'Douglas Adams'}, 'an': {'language': 'an', 'value': 'Douglas Adams'}, 'br': {'language': 'br', 'value': 'Douglas Adams'}, 'eu': {'language': 'eu', 'value': 'Douglas Adams'}, 'lb': {'language': 'lb' ...
# Q42
# []
# _______________________
# {'type': 'item', 'id': 'Q1868', 'labels': {'en': {'language': 'en', 'value': 'Paul Otlet'}, 'fr': {'language': 'fr', 'value': 'Paul Otlet'}, 'pl': {'language': 'pl', 'value': 'Paul Otlet'}, 'es': {'language': 'es', 'value': 'Paul Otlet'}, 'en-ca': {'language': 'en-ca', 'value': 'Paul Otlet'}, 'en-gb': {'language': 'en-gb', 'value': 'Paul Otlet'}, 'de': {'language': 'de', 'value': 'Paul Otlet'}, 'de-ch': {'language': 'de-ch', 'value': 'Paul Otlet'}, 'pt': {'language': 'pt', 'value': 'Paul Otlet'}, 'pt-br': {'language': 'pt-br', 'value': 'Paul Otlet'}, 'bg': {'language': 'bg', 'value': 'Пол Отле'}, 'ca': {'language': 'ca', 'value': 'Paul Otlet'}, 'eo': {'language': 'eo', 'value': 'Paul Otlet'}, 'it': {'language': 'it', 'value': 'Paul Otlet'}, 'ja': {'language': 'ja', 'value': 'ポール・オトレ'}, 'lb': {'language': 'lb', 'value': 'Paul Otlet'}, 'nl': {'language': 'nl', 'value': 'Paul Otlet'}, 'ru': {'language': 'ru', 'value': 'Поль Отле'}, 'ta': {'language': 'ta', 'value': 'பவுல் ஓட்லெட்'}, 'be': {'language': 'be', 'value': 'Поль Атле'}, 'cs': {'language': 'cs', 'value': 'Paul Otlet'}, 'oc': {'language': 'oc', 'value': 'Paul Otlet'}, 'af': {'language': 'af', 'value': 'Paul Otlet'}, 'an': {'language': 'an', 'value': 'Paul Otlet'}, 'br': {'language': 'br', 'value': 'Paul Otlet'}, 'bs': {'language': 'bs', 'value': 'Paul Otlet'}, 'cy': {'language': 'cy', 'value': 'Paul Otlet'}, 'da': {'language': 'da', 'value': 'Paul Otlet'}, 'et': {'language': 'et', 'value': 'Paul Otlet'}, 'eu': {'language': 'eu', 'value': 'Paul Otlet'}, 'fi': {'language': 'fi', 'value': 'Paul Otlet'}, 'ga': {'language': 'ga', 'value': 'Paul Otlet'}, 'gl': {'language': 'gl', 'value': 'Paul Otlet'}, 'hr': {'language': 'hr', 'value': 'Paul Otlet'}, 'hu': {'language': 'hu', 'value': 'Paul Otlet'}, 'is': {'language': 'is', 'value': 'Paul Otlet'}, 'lmo': {'language': 'lmo', 'value': 'Paul Otlet'}, 'lt': {'language': 'lt', 'value': 'Paul Otlet'}, 'nds': {'language': 'nds', 'value': 'Paul Otlet'}, 'nds-nl': {'language': 'nds-nl', 'value': 'Paul Otlet'}, 'nn': {'language': 'nn', 'value': 'Paul Otlet'}, 'pms': {'language': 'pms', 'value': 'Paul Otlet'}, 'ro': {'language': 'ro', 'value': 'Paul Otlet'}, 'sk': {'language': 'sk', 'value': 'Paul Otlet'}, 'sl': {'language': 'sl', 'value': 'Paul Otlet'}, 'sq': {'language': 'sq', 'value': 'Paul Otlet'}, 'sv': {'language': 'sv', 'value': 'Paul Otlet'}, 'tr': {'language': 'tr', 'value': 'Paul Otlet'}, 'vec': {'language': 'vec', 'value': 'Paul Otlet'}, 'wa': {'language': 'wa', 'value': 'Paul Otlet'}, 'nb': {'language': 'nb', 'value': 'Paul Otlet'}, 'gsw': {'language': 'gsw', 'value': 'Paul Otlet'}, 'ar': {'language': 'ar', 'value': 'بول اوتليه'}, 'fa': {'language': 'fa', 'value': 'پل اوتله'}, 'mg': {'language': 'mg', 'value': 'Paul Otlet'}, 'id': {'language': 'id', 'value': 'Paul Otlet'}, 'zh': {'language': 'zh', 'value': '保羅·奧特勒'}, 'ast': {'language': 'ast', 'value': 'Paul Otlet'}, 'ext': {'language': 'ext', 'value': 'Paul Otlet'}, 'hy': {'language': 'hy', 'value': 'Պոլ Օտլե'}, 'uk': {'language': 'uk', 'value': 'Поль Отле'}, 'azb': {'language': 'azb', 'value': 'پل اوتله'}, 'he': {'language': 'he', 'value': 'פול אוטלט'}, 'arz': {'language': 'arz', 'value': 'بول اوتليه'}, 'la': {'language': 'la', 'value': 'Paulus Otlet'}, 'ko': {'language': 'ko', 'value': '폴 오틀레'}, 'de-at': {'language': 'de-at', 'value': 'Paul Otlet'}, 'io': {'language': 'io', 'value': 'Paul Otlet'}, 'jut': {'language': 'jut', 'value': 'Paul Otlet'}, 'sc': {'language': 'sc', 'value': 'Paul Otlet'}, 'sco': {'language': 'sco', 'value': 'Paul Otlet'}, 'sje': {'language': 'sje', 'value': 'Paul Otlet'}, 'vi': {'language': 'vi', 'value': 'Paul Otlet'}, 'pa': {'language': 'pa', 'value': 'ਪਾਲ ਓਟਲੇਟ'}}, 'descriptions': {'en': {'language': 'en', 'value': 'Belgian author, librarian and anti-colonial thinker'}, 'es': {'language': 'es', 'value': 'bibliográfo, jurista y científico de la información belga'}, 'it': {'language': 'it', 'value': 'bibliografo belga'}, 'de': {'language': 'de', 'val ...
# Q1868
# []
# _______________________
# {'type': 'item', 'id': 'Q2013', 'labels': {'en': {'language': 'en', 'value': 'Wikidata'}, 'fr': {'language': 'fr', 'value': 'Wikidata'}, 'eo': {'language': 'eo', 'value': 'Vikidatumoj'}, 'it': {'language': 'it', 'value': 'Wikidata'}, 'be-tarask': {'language': 'be-tarask', 'value': 'Вікізьвесткі'}, 'ru': {'language': 'ru', 'value': 'Викиданные'}, 'de': {'language': 'de', 'value': 'Wikidata'}, 'pl': {'language': 'pl', 'value': 'Wikidane'}, 'nl': {'language': 'nl', 'value': 'Wikidata'}, 'es': {'language': 'es', 'value': 'Wikidata'}, 'pt': {'language': 'pt', 'value': 'Wikidata'}, 'ilo': {'language': 'ilo', 'value': 'Wikidata'}, 'ja': {'language': 'ja', 'value': 'ウィキデータ'}, 'mk': {'language': 'mk', 'value': 'Википодатоци'}, 'ar': {'language': 'ar', 'value': 'ويكي بيانات'}, 'fi': {'language': 'fi', 'value': 'Wikidata'}, 'zh': {'language': 'zh', 'value': '维基数据'}, 'vi': {'language': 'vi', 'value': 'Wikidata'}, 'cs': {'language': 'cs', 'value': 'Wikidata'}, 'fa': {'language': 'fa', 'value': 'ویکی\u200cداده'}, 'ko': {'language': 'ko', 'value': '위키데이터'}, 'uk': {'language': 'uk', 'value': 'Вікідані'}, 'tr': {'language': 'tr', 'value': 'Vikiveri'}, 'sk': {'language': 'sk', 'value': 'Wikiúdaje'}, 'id': {'language': 'id', 'value': 'Wikidata'}, 'vec': {'language': 'vec', 'value': 'Wikidata'}, 'zh-hans': {'language': 'zh-hans', 'value': '维基数据'}, 'zh-hant': {'language': 'zh-hant', 'value': '維基數據'}, 'zh-cn': {'language': 'zh-cn', 'value': '维基数据'}, 'zh-sg': {'language': 'zh-sg', 'value': '维基数据'}, 'zh-my': {'language': 'zh-my', 'value': '维基数据'}, 'zh-hk': {'language': 'zh-hk', 'value': '維基數據'}, 'zh-tw': {'language': 'zh-tw', 'value': '維基數據'}, 'zh-mo': {'language': 'zh-mo', 'value': '維基數據'}, 'hu': {'language': 'hu', 'value': 'Wikidata'}, 'pt-br': {'language': 'pt-br', 'value': 'Wikidata'}, 'de-ch': {'language': 'de-ch', 'value': 'Wikidata'}, 'en-ca': {'language': 'en-ca', 'value': 'Wikidata'}, 'en-gb': {'language': 'en-gb', 'value': 'Wikidata'}, 'is': {'language': 'is', 'value': 'Wikidata'}, 'af': {'language': 'af', 'value': 'Wikidata'}, 'he': {'language': 'he', 'value': 'ויקינתונים'}, 'arz': {'language': 'arz', 'value': 'ويكى داتا'}, 'th': {'language': 'th', 'value': 'วิกิสนเทศ'}, 'war': {'language': 'war', 'value': 'Wikidata'}, 'et': {'language': 'et', 'value': 'Wikidata'}, 'uz': {'language': 'uz', 'value': "Vikima'lumot"}, 'lv': {'language': 'lv', 'value': 'Vikidati'}, 'cy': {'language': 'cy', 'value': 'Wicidata'}, 'ur': {'language': 'ur', 'value': 'ویکیڈیٹا'}, 'be': {'language': 'be', 'value': 'Вікіданыя'}, 'min': {'language': 'min', 'value': 'Wikidata'}, 'ml': {'language': 'ml', 'value': 'വിക്കിഡാറ്റ'}, 'eu': {'language': 'eu', 'value': 'Wikidata'}, 'sh': {'language': 'sh', 'value': 'Wikidata'}, 'ca': {'language': 'ca', 'value': 'Wikidata'}, 'bs': {'language': 'bs', 'value': 'Wikipodaci'}, 'gl': {'language': 'gl', 'value': 'Wikidata'}, 'nb': {'language': 'nb', 'value': 'Wikidata'}, 'br': {'language': 'br', 'value': 'Wikidata'}, 'ms': {'language': 'ms', 'value': 'Wikidata'}, 'ro': {'language': 'ro', 'value': 'Wikidata'}, 'sv': {'language': 'sv', 'value': 'Wikidata'}, 'ast': {'language': 'ast', 'value': 'Wikidata'}, 'ne': {'language': 'ne', 'value': 'विकिडेटा'}, 'bn': {'language': 'bn', 'value': 'উইকিউপাত্ত'}, 'ka': {'language': 'ka', 'value': 'ვიკიმონაცემები'}, 'bg': {'language': 'bg', 'value': 'Уикиданни'}, 'hy': {'language': 'hy', 'value': 'Վիքիտվյալներ'}, 'pam': {'language': 'pam', 'value': 'Wikidata'}, 'hr': {'language': 'hr', 'value': 'Wikipodatci'}, 'oc': {'language': 'oc', 'value': 'Wikidata'}, 'da': {'language': 'da', 'value': 'Wikidata'}, 'cdo': {'language': 'cdo', 'value': '維基數據'}, 'el': {'language': 'el', 'value': 'Wikidata'}, 'sr': {'language': 'sr', 'value': 'Википодаци'}, 'sr-ec': {'language': 'sr-ec', 'value': 'Википодаци'}, 'sr-el': {'language': 'sr-el', 'value': 'Vikipodaci'}, 'or': {'language': 'or', 'value': 'ଉଇକିଡାଟା'}, 'hi': {'language': 'hi', 'value': 'विकिडेटा'}, 'fo': {'language': 'fo', 'value': 'Wikidata'}, 'kl': {'langua ...
# Q2013
# []
# _______________________
# {'type': 'item', 'id': 'Q45', 'labels': {'en': {'language': 'en', 'value': 'Portugal'}, 'fr': {'language': 'fr', 'value': 'Portugal'}, 'nb': {'language': 'nb', 'value': 'Portugal'}, 'it': {'language': 'it', 'value': 'Portogallo'}, 'ru': {'language': 'ru', 'value': 'Португалия'}, 'nl': {'language': 'nl', 'value': 'Portugal'}, 'es': {'language': 'es', 'value': 'Portugal'}, 'de': {'language': 'de', 'value': 'Portugal'}, 'pl': {'language': 'pl', 'value': 'Portugalia'}, 'be-tarask': {'language': 'be-tarask', 'value': 'Партугалія'}, 'nan': {'language': 'nan', 'value': 'Phû-tô-gâ'}, 'en-gb': {'language': 'en-gb', 'value': 'Portugal'}, 'ja': {'language': 'ja', 'value': 'ポルトガル'}, 'en-ca': {'language': 'en-ca', 'value': 'Portugal'}, 'ace': {'language': 'ace', 'value': 'Portugéh'}, 'af': {'language': 'af', 'value': 'Portugal'}, 'fi': {'language': 'fi', 'value': 'Portugali'}, 'zh': {'language': 'zh', 'value': '葡萄牙'}, 'zh-cn': {'language': 'zh-cn', 'value': '葡萄牙'}, 'zh-hans': {'language': 'zh-hans', 'value': '葡萄牙'}, 'zh-hant': {'language': 'zh-hant', 'value': '葡萄牙'}, 'am': {'language': 'am', 'value': 'ፖርቱጋል'}, 'mk': {'language': 'mk', 'value': 'Португалија'}, 'pt': {'language': 'pt', 'value': 'Portugal'}, 'ca': {'language': 'ca', 'value': 'Portugal'}, 'sr': {'language': 'sr', 'value': 'Португалија'}, 'hr': {'language': 'hr', 'value': 'Portugal'}, 'sw': {'language': 'sw', 'value': 'Ureno'}, 'an': {'language': 'an', 'value': 'Portugal'}, 'ang': {'language': 'ang', 'value': 'Portugal'}, 'ar': {'language': 'ar', 'value': 'البرتغال'}, 'arc': {'language': 'arc', 'value': 'ܦܘܪܛܘܓܠ'}, 'arz': {'language': 'arz', 'value': 'پورتوجال'}, 'ast': {'language': 'ast', 'value': 'Portugal'}, 'ay': {'language': 'ay', 'value': 'Purtuwal'}, 'az': {'language': 'az', 'value': 'Portuqaliya'}, 'ba': {'language': 'ba', 'value': 'Португалия'}, 'bar': {'language': 'bar', 'value': 'Portugal'}, 'bcl': {'language': 'bcl', 'value': 'Portugal'}, 'be': {'language': 'be', 'value': 'Партугалія'}, 'bg': {'language': 'bg', 'value': 'Португалия'}, 'bi': {'language': 'bi', 'value': 'Portugal'}, 'bn': {'language': 'bn', 'value': 'পর্তুগাল'}, 'bo': {'language': 'bo', 'value': 'པོ་ཅུ་གྷལ།'}, 'bpy': {'language': 'bpy', 'value': 'পর্তুগাল'}, 'br': {'language': 'br', 'value': 'Portugal'}, 'bs': {'language': 'bs', 'value': 'Portugal'}, 'cbk-zam': {'language': 'cbk-zam', 'value': 'Portugal'}, 'cdo': {'language': 'cdo', 'value': 'Buò-dò̤-ngà'}, 'ce': {'language': 'ce', 'value': 'Португали'}, 'ceb': {'language': 'ceb', 'value': 'Portugal'}, 'chr': {'language': 'chr', 'value': 'ᏉᏧᎦᎵ'}, 'ckb': {'language': 'ckb', 'value': 'پورتوگال'}, 'co': {'language': 'co', 'value': 'Portugallu'}, 'cs': {'language': 'cs', 'value': 'Portugalsko'}, 'csb': {'language': 'csb', 'value': 'Pòrtugalskô'}, 'cu': {'language': 'cu', 'value': 'Портогалїꙗ'}, 'cv': {'language': 'cv', 'value': 'Португали'}, 'cy': {'language': 'cy', 'value': 'Portiwgal'}, 'da': {'language': 'da', 'value': 'Portugal'}, 'diq': {'language': 'diq', 'value': 'Portekiz'}, 'dsb': {'language': 'dsb', 'value': 'Portugalska'}, 'dv': {'language': 'dv', 'value': 'ޕޯޗުގަލް'}, 'dz': {'language': 'dz', 'value': 'པོར་ཅུ་གལ་'}, 'ee': {'language': 'ee', 'value': 'Portugal'}, 'el': {'language': 'el', 'value': 'Πορτογαλία'}, 'eo': {'language': 'eo', 'value': 'Portugalio'}, 'et': {'language': 'et', 'value': 'Portugal'}, 'eu': {'language': 'eu', 'value': 'Portugal'}, 'ext': {'language': 'ext', 'value': 'Portugal'}, 'fa': {'language': 'fa', 'value': 'پرتغال'}, 'fo': {'language': 'fo', 'value': 'Portugal'}, 'frp': {'language': 'frp', 'value': 'Portugal'}, 'frr': {'language': 'frr', 'value': 'Portugal'}, 'fur': {'language': 'fur', 'value': 'Portugal'}, 'fy': {'language': 'fy', 'value': 'Portegal'}, 'ga': {'language': 'ga', 'value': 'an Phortaingéil'}, 'gag': {'language': 'gag', 'value': 'Portugaliya'}, 'gd': {'language': 'gd', 'value': "A' Phortagail"}, 'gl': {'language': 'gl', 'value': 'Portugal'}, 'gn': {'language': 'gn', 'value': 'Poytuga'}, 'got': {'language' ...
# Q45
# []
# _______________________
# {'type': 'item', 'id': 'Q51', 'labels': {'tg': {'language': 'tg', 'value': 'Антарктида'}, 'sk': {'language': 'sk', 'value': 'Antarktída'}, 'pnb': {'language': 'pnb', 'value': 'انٹارکٹکا'}, 'mk': {'language': 'mk', 'value': 'Антарктик'}, 'zu': {'language': 'zu', 'value': 'I-Antatika'}, 'bpy': {'language': 'bpy', 'value': 'এন্টার্কটিকা'}, 'hi': {'language': 'hi', 'value': 'अंटार्कटिका'}, 'ur': {'language': 'ur', 'value': 'انٹارکٹکا'}, 'so': {'language': 'so', 'value': 'Antiarktis'}, 'diq': {'language': 'diq', 'value': 'Antarktika'}, 'jam': {'language': 'jam', 'value': 'Antaatika'}, 'uk': {'language': 'uk', 'value': 'Антарктида'}, 'sc': {'language': 'sc', 'value': 'Antàrticu'}, 'bxr': {'language': 'bxr', 'value': 'Антарктика'}, 'za': {'language': 'za', 'value': 'Namzgigcouh'}, 'yo': {'language': 'yo', 'value': 'Antárktìkà'}, 'ext': {'language': 'ext', 'value': 'Antáltia'}, 'zea': {'language': 'zea', 'value': 'Antartica'}, 'es': {'language': 'es', 'value': 'Antártida'}, 'or': {'language': 'or', 'value': 'ଆଣ୍ଟର୍କଟିକା'}, 'yi': {'language': 'yi', 'value': 'אנטארקטיקע'}, 'ga': {'language': 'ga', 'value': 'An Antartaice'}, 'eo': {'language': 'eo', 'value': 'Antarkto'}, 'kl': {'language': 'kl', 'value': 'Qalasersuaq Kujalleq'}, 'oc': {'language': 'oc', 'value': 'Antartida'}, 'glk': {'language': 'glk', 'value': 'نسا توک'}, 'rw': {'language': 'rw', 'value': 'Antarigitika'}, 'sco': {'language': 'sco', 'value': 'Antarcticae'}, 'sgs': {'language': 'sgs', 'value': 'Antarktėda'}, 'nv': {'language': 'nv', 'value': 'Shádiʼááhjí kéyah yistinígíí'}, 'zh-sg': {'language': 'zh-sg', 'value': '南极洲'}, 'tet': {'language': 'tet', 'value': 'Antártida'}, 'az': {'language': 'az', 'value': 'Antarktida'}, 'zh': {'language': 'zh', 'value': '南極洲'}, 'kn': {'language': 'kn', 'value': 'ಅಂಟಾರ್ಕ್ಟಿಕ'}, 'lez': {'language': 'lez', 'value': 'Антарктида'}, 'ast': {'language': 'ast', 'value': "L'Antártida"}, 'ta': {'language': 'ta', 'value': 'அன்டார்க்டிக்கா'}, 'jv': {'language': 'jv', 'value': 'Antartika'}, 'inh': {'language': 'inh', 'value': 'Антарктида'}, 'lt': {'language': 'lt', 'value': 'Antarktida'}, 'tt': {'language': 'tt', 'value': 'Антарктида'}, 'pms': {'language': 'pms', 'value': 'Antàrtide'}, 'sl': {'language': 'sl', 'value': 'Antarktika'}, 'crh': {'language': 'crh', 'value': 'Antarktida'}, 'ms': {'language': 'ms', 'value': 'Antartika'}, 'ro': {'language': 'ro', 'value': 'Antarctida'}, 'bho': {'language': 'bho', 'value': 'अंटार्कटिका'}, 'lb': {'language': 'lb', 'value': 'Antarktika'}, 'kaa': {'language': 'kaa', 'value': 'Antarktika'}, 'vro': {'language': 'vro', 'value': 'Antarktis'}, 'lo': {'language': 'lo', 'value': 'ທະວີບອັງຕາກຕິກ'}, 'sw': {'language': 'sw', 'value': 'Bara la Antaktiki'}, 'nds': {'language': 'nds', 'value': 'Antarktis'}, 'ksh': {'language': 'ksh', 'value': 'Süüdpool'}, 'bcl': {'language': 'bcl', 'value': 'Antartika'}, 'da': {'language': 'da', 'value': 'Antarktis'}, 'ca': {'language': 'ca', 'value': 'Antàrtida'}, 'lv': {'language': 'lv', 'value': 'Antarktīda'}, 'nan': {'language': 'nan', 'value': 'Lâm-ke̍k Tāi-lio̍k'}, 'mi': {'language': 'mi', 'value': 'Tiri o te Moana'}, 'tcy': {'language': 'tcy', 'value': 'ಅಂಟಾರ್ಕ್ಟಿಕ'}, 'kbp': {'language': 'kbp', 'value': 'Antarɩtiki tɛtʋ wandamm'}, 'gv': {'language': 'gv', 'value': 'Yn Antarctagh'}, 'mai': {'language': 'mai', 'value': 'अंटार्कटिका'}, 'bn': {'language': 'bn', 'value': 'অ্যান্টার্কটিকা'}, 'pih': {'language': 'pih', 'value': 'Antartica'}, 'szl': {'language': 'szl', 'value': 'Antarktyda'}, 'xal': {'language': 'xal', 'value': 'Антарктик'}, 'cv': {'language': 'cv', 'value': 'Антарктида'}, 'pt': {'language': 'pt', 'value': 'Antártida'}, 'kk': {'language': 'kk', 'value': 'Антарктида'}, 'zh-my': {'language': 'zh-my', 'value': '南极洲'}, 'ru': {'language': 'ru', 'value': 'Антарктида'}, 'de-ch': {'language': 'de-ch', 'value': 'Antarktika'}, 'tl': {'language': 'tl', 'value': 'Antarctica'}, 'azb': {'language': 'azb', 'value': 'آنتارکتیکا'}, 'an': {'language': 'an', 'value': 'Antarctida'}, 'hy': {'languag ...
# Q51
# []
# _______________________
# {'type': 'item', 'id': 'Q58', 'labels': {'en': {'language': 'en', 'value': 'penis'}, 'it': {'language': 'it', 'value': 'pene'}, 'nb': {'language': 'nb', 'value': 'penis'}, 'fi': {'language': 'fi', 'value': 'siitin'}, 'fr': {'language': 'fr', 'value': 'pénis'}, 'de': {'language': 'de', 'value': 'Penis'}, 'es': {'language': 'es', 'value': 'pene'}, 'en-ca': {'language': 'en-ca', 'value': 'Penis'}, 'en-gb': {'language': 'en-gb', 'value': 'penis'}, 'nl': {'language': 'nl', 'value': 'penis'}, 'af': {'language': 'af', 'value': 'penis'}, 'an': {'language': 'an', 'value': 'Pene'}, 'ar': {'language': 'ar', 'value': 'قضيب'}, 'arz': {'language': 'arz', 'value': 'دكر الراجل'}, 'ast': {'language': 'ast', 'value': 'Pene'}, 'ay': {'language': 'ay', 'value': 'Allu'}, 'az': {'language': 'az', 'value': 'Penis'}, 'bar': {'language': 'bar', 'value': 'Zipfe'}, 'bcl': {'language': 'bcl', 'value': 'Putoy'}, 'be': {'language': 'be', 'value': 'пеніс'}, 'bg': {'language': 'bg', 'value': 'пенис'}, 'bjn': {'language': 'bjn', 'value': 'Palir'}, 'bn': {'language': 'bn', 'value': 'শিশ্ন'}, 'br': {'language': 'br', 'value': "Kalc'h"}, 'bs': {'language': 'bs', 'value': 'penis'}, 'ca': {'language': 'ca', 'value': 'penis'}, 'ceb': {'language': 'ceb', 'value': 'Utin'}, 'chr': {'language': 'chr', 'value': 'ᏩᏙᎵ'}, 'ckb': {'language': 'ckb', 'value': 'کێر'}, 'cs': {'language': 'cs', 'value': 'penis'}, 'cy': {'language': 'cy', 'value': 'pidyn'}, 'da': {'language': 'da', 'value': 'penis'}, 'dv': {'language': 'dv', 'value': 'ފިރިހެން ހަށި'}, 'el': {'language': 'el', 'value': 'πέος'}, 'eo': {'language': 'eo', 'value': 'peniso'}, 'et': {'language': 'et', 'value': 'Suguti'}, 'eu': {'language': 'eu', 'value': 'zakil'}, 'fa': {'language': 'fa', 'value': 'آلت نری'}, 'ga': {'language': 'ga', 'value': 'péineas'}, 'gan': {'language': 'gan', 'value': '卵'}, 'gd': {'language': 'gd', 'value': 'Bod'}, 'gl': {'language': 'gl', 'value': 'Pene'}, 'gn': {'language': 'gn', 'value': 'Tembo'}, 'he': {'language': 'he', 'value': 'פין'}, 'hi': {'language': 'hi', 'value': 'शिश्न'}, 'hr': {'language': 'hr', 'value': 'Spolni ud'}, 'hsb': {'language': 'hsb', 'value': 'penis'}, 'hu': {'language': 'hu', 'value': 'hímvessző'}, 'hy': {'language': 'hy', 'value': 'առնանդամ'}, 'id': {'language': 'id', 'value': 'penis'}, 'ik': {'language': 'ik', 'value': 'Usuk'}, 'ilo': {'language': 'ilo', 'value': 'Buto'}, 'io': {'language': 'io', 'value': 'peniso'}, 'is': {'language': 'is', 'value': 'Getnaðarlimur'}, 'iu': {'language': 'iu', 'value': 'ᐅᓱᒃ'}, 'ja': {'language': 'ja', 'value': '陰茎'}, 'jbo': {'language': 'jbo', 'value': 'pinji'}, 'jv': {'language': 'jv', 'value': 'Penis'}, 'kk': {'language': 'kk', 'value': 'Жыныстық қатынас мүшесі'}, 'kn': {'language': 'kn', 'value': 'ತುಣ್ಣಿ'}, 'ko': {'language': 'ko', 'value': '음경'}, 'ksh': {'language': 'ksh', 'value': 'Pimel'}, 'ku': {'language': 'ku', 'value': 'Kîr'}, 'la': {'language': 'la', 'value': 'Mentula'}, 'ln': {'language': 'ln', 'value': 'Nsɔ́ka'}, 'lt': {'language': 'lt', 'value': 'Varpa'}, 'lv': {'language': 'lv', 'value': 'dzimumloceklis'}, 'mk': {'language': 'mk', 'value': 'Пенис'}, 'ml': {'language': 'ml', 'value': 'ലിംഗം'}, 'mr': {'language': 'mr', 'value': 'शिश्न'}, 'ms': {'language': 'ms', 'value': 'Zakar'}, 'my': {'language': 'my', 'value': 'လိင်တံ'}, 'mzn': {'language': 'mzn', 'value': 'دول'}, 'nah': {'language': 'nah', 'value': 'Tepōlli'}, 'nds': {'language': 'nds', 'value': 'Pint'}, 'ne': {'language': 'ne', 'value': 'लिङ्ग'}, 'nn': {'language': 'nn', 'value': 'penis'}, 'nov': {'language': 'nov', 'value': 'penise'}, 'oc': {'language': 'oc', 'value': 'Pènis'}, 'pa': {'language': 'pa', 'value': 'ਸ਼ਿਸ਼ਨ'}, 'pl': {'language': 'pl', 'value': 'prącie'}, 'pt': {'language': 'pt', 'value': 'pénis'}, 'pt-br': {'language': 'pt-br', 'value': 'pênis'}, 'qu': {'language': 'qu', 'value': 'Ullu'}, 'rmy': {'language': 'rmy', 'value': 'car'}, 'ro': {'language': 'ro', 'value': 'penis'}, 'rw': {'language': 'rw', 'value': 'Igitsina cy’umugabo'}, 'sa': {'language': 'sa', ...
# Q58
# ['Q4620674', 'Q168552']
# [Q4620674] - Number of Superclasses: 25
# [Q168552] - Number of Superclasses: 4
# _______________________
# {'type': 'item', 'id': 'Q68', 'labels': {'en': {'language': 'en', 'value': 'computer'}, 'fr': {'language': 'fr', 'value': 'ordinateur'}, 'it': {'language': 'it', 'value': 'computer'}, 'pl': {'language': 'pl', 'value': 'komputer'}, 'be-tarask': {'language': 'be-tarask', 'value': 'кампутар'}, 'nan': {'language': 'nan', 'value': 'tiān-náu'}, 'de': {'language': 'de', 'value': 'Computer'}, 'ja': {'language': 'ja', 'value': 'コンピュータ'}, 'en-ca': {'language': 'en-ca', 'value': 'computer'}, 'en-gb': {'language': 'en-gb', 'value': 'computer'}, 'ar': {'language': 'ar', 'value': 'حاسوب'}, 'sco': {'language': 'sco', 'value': 'computer'}, 'wa': {'language': 'wa', 'value': 'copiutrece'}, 'ace': {'language': 'ace', 'value': 'komputer'}, 'af': {'language': 'af', 'value': 'rekenaar'}, 'am': {'language': 'am', 'value': 'ኮምፒዩተር'}, 'an': {'language': 'an', 'value': 'ordinador'}, 'ang': {'language': 'ang', 'value': 'spearctelle'}, 'arc': {'language': 'arc', 'value': 'ܚܫܘܒܐ'}, 'arz': {'language': 'arz', 'value': 'كومبيوتر'}, 'as': {'language': 'as', 'value': 'কম্পিউটাৰ'}, 'ast': {'language': 'ast', 'value': 'ordenador'}, 'az': {'language': 'az', 'value': 'kompüter'}, 'ba': {'language': 'ba', 'value': 'компьютер'}, 'bar': {'language': 'bar', 'value': 'Computer'}, 'be': {'language': 'be', 'value': 'камп’ютар'}, 'bg': {'language': 'bg', 'value': 'компютър'}, 'bn': {'language': 'bn', 'value': 'কম্পিউটার'}, 'bo': {'language': 'bo', 'value': 'གློག་ཀླད།'}, 'bpy': {'language': 'bpy', 'value': 'কম্পিউটার'}, 'br': {'language': 'br', 'value': 'urzhiataer'}, 'bs': {'language': 'bs', 'value': 'računar'}, 'bug': {'language': 'bug', 'value': 'komputer'}, 'ca': {'language': 'ca', 'value': 'ordinador'}, 'ce': {'language': 'ce', 'value': 'гIулкхдириг'}, 'ceb': {'language': 'ceb', 'value': 'kompiyuter'}, 'chy': {'language': 'chy', 'value': 'tséohketoetanóto'}, 'cs': {'language': 'cs', 'value': 'počítač'}, 'cu': {'language': 'cu', 'value': 'съмѣтатєл҄ь'}, 'cv': {'language': 'cv', 'value': 'компьютер'}, 'cy': {'language': 'cy', 'value': 'cyfrifiadur'}, 'da': {'language': 'da', 'value': 'computer'}, 'diq': {'language': 'diq', 'value': 'komputer'}, 'el': {'language': 'el', 'value': 'ηλεκτρονικός υπολογιστής'}, 'eml': {'language': 'eml', 'value': 'zarvlån'}, 'eo': {'language': 'eo', 'value': 'komputilo'}, 'et': {'language': 'et', 'value': 'arvuti'}, 'eu': {'language': 'eu', 'value': 'ordenagailu'}, 'fa': {'language': 'fa', 'value': 'رایانه'}, 'fi': {'language': 'fi', 'value': 'tietokone'}, 'fo': {'language': 'fo', 'value': 'teldur'}, 'fur': {'language': 'fur', 'value': 'ordenadôr'}, 'fy': {'language': 'fy', 'value': 'kompjûter'}, 'ga': {'language': 'ga', 'value': 'ríomhaire'}, 'gan': {'language': 'gan', 'value': '電腦'}, 'gd': {'language': 'gd', 'value': 'coimpiutair'}, 'gl': {'language': 'gl', 'value': 'ordenador'}, 'got': {'language': 'got', 'value': '𐍅𐌹𐍄𐌹𐍂𐌰𐌷𐌽𐌾𐌰𐌽𐌳𐍃'}, 'gu': {'language': 'gu', 'value': 'કમ્પ્યૂટર'}, 'gv': {'language': 'gv', 'value': 'co-earrooder'}, 'ha': {'language': 'ha', 'value': "na'ura"}, 'hak': {'language': 'hak', 'value': 'thien-nó'}, 'he': {'language': 'he', 'value': 'מחשב'}, 'hi': {'language': 'hi', 'value': 'कंप्यूटर'}, 'hif': {'language': 'hif', 'value': 'computer'}, 'hr': {'language': 'hr', 'value': 'računalo'}, 'ht': {'language': 'ht', 'value': 'òdinatè'}, 'hu': {'language': 'hu', 'value': 'számítógép'}, 'hy': {'language': 'hy', 'value': 'համակարգիչ'}, 'ia': {'language': 'ia', 'value': 'computator'}, 'id': {'language': 'id', 'value': 'komputer'}, 'ig': {'language': 'ig', 'value': 'orunotu'}, 'ilo': {'language': 'ilo', 'value': 'kompiuter'}, 'io': {'language': 'io', 'value': 'komputero'}, 'is': {'language': 'is', 'value': 'tölva'}, 'iu': {'language': 'iu', 'value': 'ᖃᕋᓴᐅᔭᖅ'}, 'jbo': {'language': 'jbo', 'value': 'skami'}, 'jv': {'language': 'jv', 'value': 'komputer'}, 'ka': {'language': 'ka', 'value': 'კომპიუტერი'}, 'kg': {'language': 'kg', 'value': 'ludinatelo'}, 'kk': {'language': 'kk', 'value': 'компьютер'}, 'km': {'language': 'km', 'value': 'ក ...
# Q68
# ['Q11019', 'Q241317', 'Q1662611', 'Q115517465', 'Q3181395', 'Q1172400', 'Q1327500']
# [Q11019] - Number of Superclasses: 17
# [Q241317] - Number of Superclasses: 8
# [Q1662611] - Number of Superclasses: 7
# [Q115517465] - Number of Superclasses: 3
# [Q3181395] - Number of Superclasses: 7
# [Q1172400] - Number of Superclasses: 16
# [Q1327500] - Number of Superclasses: 23
# _______________________
# ...
# Q125
# ['Q18602249']
# [Q18602249] - Number of Superclasses: 7
# _______________________
# {'type': 'item', 'id': 'Q140', 'labels': {'fr': {'language': 'fr', 'value': 'lion'}, 'it': {'language': 'it', 'value': 'leone'}, 'nb': {'language': 'nb', 'value': 'løve'}, 'ru': {'language': 'ru', 'value': 'лев'}, 'de': {'language': 'de', 'value': 'Löwe'}, 'es': {'language': 'es', 'value': 'león'}, 'nn': {'language': 'nn', 'value': 'løve'}, 'da': {'language': 'da', 'value': 'løve'}, 'af': {'language': 'af', 'value': 'leeu'}, 'ar': {'language': 'ar', 'value': 'أسد'}, 'bg': {'language': 'bg', 'value': 'лъв'}, 'bn': {'language': 'bn', 'value': 'সিংহ'}, 'br': {'language': 'br', 'value': 'leon'}, 'bs': {'language': 'bs', 'value': 'lav'}, 'ca': {'language': 'ca', 'value': 'lleó'}, 'cs': {'language': 'cs', 'value': 'lev'}, 'el': {'language': 'el', 'value': 'λιοντάρι'}, 'fi': {'language': 'fi', 'value': 'leijona'}, 'ga': {'language': 'ga', 'value': 'leon'}, 'gl': {'language': 'gl', 'value': 'león'}, 'gu': {'language': 'gu', 'value': 'સિંહ'}, 'he': {'language': 'he', 'value': 'אריה'}, 'hi': {'language': 'hi', 'value': 'सिंह'}, 'hu': {'language': 'hu', 'value': 'oroszlán'}, 'id': {'language': 'id', 'value': 'Singa'}, 'ja': {'language': 'ja', 'value': 'ライオン'}, 'ko': {'language': 'ko', 'value': '사자'}, 'mk': {'language': 'mk', 'value': 'лав'}, 'ml': {'language': 'ml', 'value': 'സിംഹം'}, 'mr': {'language': 'mr', 'value': 'सिंह'}, 'my': {'language': 'my', 'value': 'ခြင်္သေ့'}, 'ne': {'language': 'ne', 'value': 'सिंह'}, 'nl': {'language': 'nl', 'value': 'leeuw'}, 'pl': {'language': 'pl', 'value': 'lew afrykański'}, 'pt': {'language': 'pt', 'value': 'leão'}, 'pt-br': {'language': 'pt-br', 'value': 'leão'}, 'scn': {'language': 'scn', 'value': 'liuni'}, 'sq': {'language': 'sq', 'value': 'Luani'}, 'sr': {'language': 'sr', 'value': 'лав'}, 'sw': {'language': 'sw', 'value': 'simba'}, 'ta': {'language': 'ta', 'value': 'சிங்கம்'}, 'te': {'language': 'te', 'value': 'సింహం'}, 'th': {'language': 'th', 'value': 'สิงโต'}, 'tr': {'language': 'tr', 'value': 'aslan'}, 'uk': {'language': 'uk', 'value': 'лев'}, 'vi': {'language': 'vi', 'value': 'sư tử'}, 'zh': {'language': 'zh', 'value': '獅'}, 'sco': {'language': 'sco', 'value': 'lion'}, 'zh-hant': {'language': 'zh-hant', 'value': '獅'}, 'fa': {'language': 'fa', 'value': 'شیر'}, 'zh-hans': {'language': 'zh-hans', 'value': '狮'}, 'ee': {'language': 'ee', 'value': 'Dzata'}, 'ilo': {'language': 'ilo', 'value': 'leon'}, 'ksh': {'language': 'ksh', 'value': 'Löhv'}, 'zh-hk': {'language': 'zh-hk', 'value': '獅'}, 'as': {'language': 'as', 'value': 'সিংহ'}, 'zh-cn': {'language': 'zh-cn', 'value': '狮'}, 'zh-mo': {'language': 'zh-mo', 'value': '獅'}, 'zh-my': {'language': 'zh-my', 'value': '狮'}, 'zh-sg': {'language': 'zh-sg', 'value': '狮'}, 'zh-tw': {'language': 'zh-tw', 'value': '獅'}, 'ast': {'language': 'ast', 'value': 'Panthera leo'}, 'sat': {'language': 'sat', 'value': 'ᱡᱟᱴᱟᱠᱩᱞ'}, 'bho': {'language': 'bho', 'value': 'सिंह'}, 'en': {'language': 'en', 'value': 'lion'}, 'ks': {'language': 'ks', 'value': 'پادَر سٕہہ'}, 'be-tarask': {'language': 'be-tarask', 'value': 'леў'}, 'nan': {'language': 'nan', 'value': 'Sai'}, 'la': {'language': 'la', 'value': 'leo'}, 'en-ca': {'language': 'en-ca', 'value': 'Lion'}, 'en-gb': {'language': 'en-gb', 'value': 'lion'}, 'ab': {'language': 'ab', 'value': 'Алым'}, 'am': {'language': 'am', 'value': 'አንበሳ'}, 'an': {'language': 'an', 'value': 'Panthera leo'}, 'ang': {'language': 'ang', 'value': 'Lēo'}, 'arc': {'language': 'arc', 'value': 'ܐܪܝܐ'}, 'arz': {'language': 'arz', 'value': 'سبع'}, 'av': {'language': 'av', 'value': 'ГъалбацӀ'}, 'az': {'language': 'az', 'value': 'Şir'}, 'ba': {'language': 'ba', 'value': 'Арыҫлан'}, 'be': {'language': 'be', 'value': 'леў'}, 'bo': {'language': 'bo', 'value': 'སེང་གེ།'}, 'bpy': {'language': 'bpy', 'value': 'নংসা'}, 'bxr': {'language': 'bxr', 'value': 'Арсалан'}, 'ce': {'language': 'ce', 'value': 'Лом'}, 'chr': {'language': 'chr', 'value': 'ᏢᏓᏥ ᎤᏍᏆᎴᏂ'}, 'chy': {'language': 'chy', 'value': "Péhpe'énanóse'hame"}, 'ckb': {'language': 'ckb', 'value': 'شێر'}, 'co' ...
# Q140
# ['Q6667323']
# [Q6667323] - Number of Superclasses: 26
# _______________________
# {'type': 'item', 'id': 'Q144', 'labels': {'en': {'language': 'en', 'value': 'dog'}, 'fr': {'language': 'fr', 'value': 'chien'}, 'it': {'language': 'it', 'value': 'cane'}, 'nb': {'language': 'nb', 'value': 'hund'}, 'be-tarask': {'language': 'be-tarask', 'value': 'сабака'}, 'yue': {'language': 'yue', 'value': '狗'}, 'sgs': {'language': 'sgs', 'value': 'Šova'}, 'nan': {'language': 'nan', 'value': 'Káu'}, 'nds-nl': {'language': 'nds-nl', 'value': 'hond'}, 'vro': {'language': 'vro', 'value': 'Pini'}, 'de': {'language': 'de', 'value': 'Hund'}, 'br': {'language': 'br', 'value': 'ki'}, 'ru': {'language': 'ru', 'value': 'собака'}, 'hif': {'language': 'hif', 'value': 'Kuttaa'}, 'es': {'language': 'es', 'value': 'perro'}, 'ab': {'language': 'ab', 'value': 'Ала'}, 'ace': {'language': 'ace', 'value': 'Asèë'}, 'af': {'language': 'af', 'value': 'hond'}, 'am': {'language': 'am', 'value': 'ውሻ'}, 'an': {'language': 'an', 'value': 'Canis lupus familiaris'}, 'arc': {'language': 'arc', 'value': 'ܟܠܒܐ'}, 'ar': {'language': 'ar', 'value': 'كلب'}, 'arz': {'language': 'arz', 'value': 'كلب'}, 'ast': {'language': 'ast', 'value': 'perru'}, 'av': {'language': 'av', 'value': 'Гьой'}, 'ay': {'language': 'ay', 'value': 'Anu'}, 'az': {'language': 'az', 'value': 'Köpək'}, 'bar': {'language': 'bar', 'value': 'Hund'}, 'ba': {'language': 'ba', 'value': 'Эт'}, 'bcl': {'language': 'bcl', 'value': 'Ayam'}, 'be': {'language': 'be', 'value': 'сабака свойскі'}, 'bg': {'language': 'bg', 'value': 'куче'}, 'bjn': {'language': 'bjn', 'value': 'Hadupan'}, 'bm': {'language': 'bm', 'value': 'Wùlù'}, 'bn': {'language': 'bn', 'value': 'কুকুর'}, 'bo': {'language': 'bo', 'value': 'ཁྱི།'}, 'bs': {'language': 'bs', 'value': 'pas'}, 'ca': {'language': 'ca', 'value': 'gos'}, 'cdo': {'language': 'cdo', 'value': 'Kēng'}, 'chr': {'language': 'chr', 'value': 'ᎩᏟ'}, 'chy': {'language': 'chy', 'value': 'Oeškese'}, 'ckb': {'language': 'ckb', 'value': 'سەگ'}, 'co': {'language': 'co', 'value': 'Ghjacaru'}, 'cr': {'language': 'cr', 'value': 'Atimw'}, 'csb': {'language': 'csb', 'value': 'Pies'}, 'cs': {'language': 'cs', 'value': 'pes domácí'}, 'cv': {'language': 'cv', 'value': 'Йытă'}, 'cy': {'language': 'cy', 'value': 'ci'}, 'da': {'language': 'da', 'value': 'hund'}, 'diq': {'language': 'diq', 'value': 'Kutık'}, 'dsb': {'language': 'dsb', 'value': 'Domacny pjas'}, 'ee': {'language': 'ee', 'value': 'Avoo'}, 'el': {'language': 'el', 'value': 'σκύλος'}, 'eml': {'language': 'eml', 'value': 'Can'}, 'eo': {'language': 'eo', 'value': 'hundo'}, 'et': {'language': 'et', 'value': 'koer'}, 'eu': {'language': 'eu', 'value': 'txakur'}, 'ext': {'language': 'ext', 'value': 'Canis Lupus Familiaris'}, 'fa': {'language': 'fa', 'value': 'سگ'}, 'fi': {'language': 'fi', 'value': 'koira'}, 'fj': {'language': 'fj', 'value': 'Koli'}, 'fo': {'language': 'fo', 'value': 'Hundur'}, 'frp': {'language': 'frp', 'value': 'Chin'}, 'frr': {'language': 'frr', 'value': 'Hüshünj'}, 'fur': {'language': 'fur', 'value': 'Cjan'}, 'fy': {'language': 'fy', 'value': 'hûn'}, 'gan': {'language': 'gan', 'value': '狗'}, 'ga': {'language': 'ga', 'value': 'madra'}, 'gd': {'language': 'gd', 'value': 'Cù'}, 'gl': {'language': 'gl', 'value': 'can'}, 'gn': {'language': 'gn', 'value': 'jagua'}, 'got': {'language': 'got', 'value': '𐌷𐌿𐌽𐌳𐍃'}, 'gv': {'language': 'gv', 'value': 'Moddey'}, 'hak': {'language': 'hak', 'value': 'kiéu-è'}, 'ha': {'language': 'ha', 'value': 'Kare'}, 'he': {'language': 'he', 'value': 'כלב'}, 'hi': {'language': 'hi', 'value': 'कुत्ता'}, 'hr': {'language': 'hr', 'value': 'pas'}, 'hsb': {'language': 'hsb', 'value': 'domjacy pos'}, 'hu': {'language': 'hu', 'value': 'kutya'}, 'hy': {'language': 'hy', 'value': 'շուն'}, 'id': {'language': 'id', 'value': 'anjing'}, 'ik': {'language': 'ik', 'value': 'Qimmiq'}, 'ilo': {'language': 'ilo', 'value': 'aso'}, 'io': {'language': 'io', 'value': 'hundo'}, 'is': {'language': 'is', 'value': 'Hundur'}, 'iu': {'language': 'iu', 'value': 'ᕿᖕᒥᖅ'}, 'ja': {'language': 'ja', 'value': 'イヌ'}, 'jbo': {'lang ...
# Q144
# ['Q57814795', 'Q39201']
# [Q57814795] - Number of Superclasses: 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 35>()
#      46 print(types_list)
#      47 for el in types_list:
# ---> 48     superclasses = retrieve_superclasses(el)  # Replace with your entity ID
#      50     print(f"[{el}] - Number of Superclasses: {len(superclasses)}")
#      52 print("_______________________")
#
# Input In [7], in retrieve_superclasses(entity_id)
#      38 sparql = SPARQLWrapper(endpoint_url)
#      40 # Execute the query with retries
# ---> 41 results = query_wikidata(sparql, query)
#      43 # Process results and return as a dictionary
#      44 if results:
#
# Input In [7], in retrieve_superclasses.<locals>.query_wikidata(sparql_client, query, retries, delay)
#      24     sparql_client.setQuery(query)
#      25     sparql_client.setReturnFormat(JSON)
# ---> 26     results = sparql_client.query().convert()
#      27     return results
#      28 except Exception as e:
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\site-packages\SPARQLWrapper\Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\abelo\anaconda3\envs\v_env\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Example usage
superclasses = retrieve_superclasses("Q1320047")  # Replace with your entity ID
print("Number of Superclasses:", len(superclasses))
print("Superclass Dictionary:")
print(superclasses)

# %% [markdown]
# # Esperimenti fatti con Riccardo

# %%
import bz2
import json
from tqdm import tqdm
import traceback
import os
from pymongo import MongoClient
from pymongo import *
from pymongo import errors
import configparser
from json.decoder import JSONDecodeError
from requests import get

# %%
# MongoDB connection setup
MONGO_ENDPOINT, MONGO_ENDPOINT_PORT = os.environ["MONGO_ENDPOINT"].split(":")
MONGO_ENDPOINT_PORT = int(MONGO_ENDPOINT_PORT)
MONGO_ENDPOINT_USERNAME = os.environ["MONGO_INITDB_ROOT_USERNAME"]
MONGO_ENDPOINT_PASSWORD = os.environ["MONGO_INITDB_ROOT_PASSWORD"]
DB_NAME = f"wikidata"

client = MongoClient(MONGO_ENDPOINT, MONGO_ENDPOINT_PORT, username=MONGO_ENDPOINT_USERNAME, password=MONGO_ENDPOINT_PASSWORD)
print(client)

log_c = client.wikidata.log
items_c = client[DB_NAME].items
objects_c = client[DB_NAME].objects
literals_c = client[DB_NAME].literals
types_c = client[DB_NAME].types

c_ref = {
    "items": items_c,
    "objects":objects_c, 
    "literals":literals_c, 
    "types":types_c
}

def flush_buffer(buffer):
    for key in buffer:
        if len(buffer[key]) > 0:
            c_ref[key].insert_many(buffer[key])
            buffer[key] = []

# %%
def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.
    --------------------------------------------
    For example, if you have an item with types A, B, and C, and you specify a forward property that applies to type B, the item will 
    be included in the result because it has type B, even if it also has types A and C
    --------------------------------------------  
    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids

# %%
# example with "capital city"

list = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
for el in list:
    data = {
        "json": [
            "Q"+(str(el))
        ]
    }
    response = requests.post(url, headers=headers, json=data)

    try:
        result = response.json()
        label = result["Q"+(str(el))]['labels']['en']
        print(label)  # Print the label or ID with indentation
    except:
        pass

# %%
# Function to fetch the necessary subclass sets with individual try-except blocks
def fetch_wikidata_subclasses():
    try:
        organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        organization_subclass = []
    
    try:
        country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        country_subclass = []
    
    try:
        city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        city_subclass = []
    
    try:
        capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        capitals_subclass = []
    
    try:
        admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        admTerr_subclass = []
    
    try:
        family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        family_subclass = []
    
    try:
        sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        sportLeague_subclass = []
    
    try:
        venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        venue_subclass = []
    
    # Removing overlaps for organization_subclass
    organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))
    
    try:
        geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        geolocation_subclass = []
    
    try:
        food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        food_subclass = []
    
    try:
        edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        edInst_subclass = []
    
    try:
        govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        govAgency_subclass = []
    
    try:
        intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        intOrg_subclass = []
    
    try:
        timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
    except json.decoder.JSONDecodeError:
        timeZone_subclass = []

    # Removing overlaps for geolocation_subclass
    geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))
    
    return organization_subclass, geolocation_subclass

# %%
with open("./organization_subclass.txt", "w") as file:
    for item in organization_subclass:
        file.write(f"{item}\n")  # Write each item on a new line

# %%
from collections import Counter


wikidata_dump_path = './data/latest-all.json.bz2'
SIZE_PROC = 1000
chunk_size = 1000  # Number of rows per chunk

organization_subclass, geolocation_subclass = fetch_wikidata_subclasses()

def process_entity(item):
    try:
        entity = item['id']
        labels = item.get("labels", {})
        english_label = labels.get("en", {}).get("value", "")
        description = item.get('descriptions', {}).get('en', {})
        NERtype = None

        if item.get("type") == "item" and "claims" in item:
            p31_claims = item["claims"].get("P31", [])

            # Initialize a counter to track occurrences of NER types
            ner_counter = Counter()

            for claim in p31_claims:
                mainsnak = claim.get("mainsnak", {})
                datavalue = mainsnak.get("datavalue", {})
                numeric_id = datavalue.get("value", {}).get("numeric-id")

                # Classify NER types
                if numeric_id == 5:
                    ner_counter['PERS'] += 1
                elif numeric_id in geolocation_subclass or any(k.lower() in description.get('value', '').lower().split() for k in ["district", "city", "country", "capital", "state"]):
                    ner_counter['LOC'] += 1
                elif numeric_id in organization_subclass:
                    ner_counter['ORG'] += 1
                else:
                    ner_counter['OTHERS'] += 1
                    
            # Get the most common NER type
            if ner_counter:
                NERtype, _ = ner_counter.most_common(1)[0]  # Get the most common type

            # Print label, ID, type, and NER classification
            print(f"{english_label} - {entity}: (NER type: {NERtype})")

    except json.decoder.JSONDecodeError:
        pass

# Initial setup for data processing
counter = 0

# Process data and print relevant details
try:
    with bz2.open(wikidata_dump_path, 'rt', encoding='utf-8') as f:
        pbar = tqdm(total=SIZE_PROC)
        
        for line in f:
            try:
                item = json.loads(line[:-2])
                process_entity(item)
            except json.decoder.JSONDecodeError:
                continue

            if counter == SIZE_PROC:
                break
            counter += 1
        pbar.close()

except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# # Test query chiusura transitiva

# %%
! pip install SPARQLWrapper

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def get_subclasses(Qid):
    # Initialize the SPARQL endpoint (Wikidata in this case)
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    
    # Define the SPARQL query with the provided QID
    query = f"""
    SELECT DISTINCT ?item ?desc WHERE {{
      wd:{Qid} wdt:P279* ?item.
      # ?item rdfs:label ?desc FILTER (lang(?desc) = "en").
    }}
    """
    
    # Set the query and the return format (JSON)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Execute the query and get results
    results = sparql.query().convert()
    
    # Parse the results
    subclasses = []
    for result in results["results"]["bindings"]:
        item = result["item"]["value"]
        desc = result["desc"]["value"]
        subclasses.append({"item": item, "description": desc})
    
    return subclasses

# Example usage
Qid = "Q64027599" 
subclasses = get_subclasses(Qid)

for subclass in subclasses:
    print(f"Item: {subclass['item']}, Description: {subclass['description']}")

# %%
query_data = {
    "query": {
        "bool": {
            "must": [
                {
                    "match": {
                        "name": {
                            "query": "Belgium",
                            "boost": 2.0
                        }
                    }
                }
            ],
            "should": [
                {"term": {"type": "realm"}},
                {"term": {"type": "soverign state"}},
                {"term": {"type": "country"}}
            ],
            "minimum_should_match": 1
        }
    }
}

# %%
import requests
import json

# Define the URL
url = 'https://lamapi.hel.sintef.cloud/lookup/entity-retrieval'

# Define the query data (decoded for readability)
query_data = {
  "query": {
    "bool": {
      "must": [
        {
          "query_string": {
            "default_field":"types",  "query": "Q6881511"
          }
        },
        {
          "match": {
            "name": {"query":"sinopec","boost":2.0}
          }
        }
      ]
    }
  }
}

# Define the parameters and token
params = {
    'name': 'sinopec',
    #'query': json.dumps(query_data),  # JSON encoded query data
    'token': 'lamapi_demo_2023'
}

# Send the GET request
response = requests.get(url, params=params, headers={'accept': 'application/json'})

# Print the response
if response.status_code == 200:
    res = response.json()
    for el in res:
        print(f"{el['name']} ({el['id']}) with type:")
        for type in el['types']:
            print(f"                {type['name']}")  # Assuming the response is JSON formatted
else:
    print(f"Request failed with status code {response.status_code}")
