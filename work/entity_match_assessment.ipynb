# %%
import json
import random
import os
import pandas as pd
import re
import aiohttp
import asyncio
import backoff
import nest_asyncio
import time
from SPARQLWrapper import SPARQLWrapper, JSON
from requests import get
import numpy as np
import requests
from aiohttp import ClientResponseError
import logging
from tqdm import tqdm

# %%
####################
# READ THE JSON
#####################

json_file_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/2T_Round4_sorted_mentions.json"

# Load the JSON file
with open(json_file_path, "r") as file:
    R4_2T_sorted_mentions = json.load(file)


## Sample extraction
# SPLIT OVER THE QUARTILES

n = len(R4_2T_sorted_mentions)
q1_idx = n // 4
q2_idx = n // 2
q3_idx = 3 * n // 4

# Step 3: Split the list into quartiles
q1 = R4_2T_sorted_mentions[:q1_idx]
q2 = R4_2T_sorted_mentions[q1_idx:q2_idx]
q3 = R4_2T_sorted_mentions[q2_idx:q3_idx]
q4 = R4_2T_sorted_mentions[q3_idx:]

sample_size = 1000
R4_2T_sample_keys = []
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q1, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q2, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q3, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q4, sample_size)

q_ids = {item[1]['name']: item[1]['id'] for item in R4_2T_sample_keys}

# %%
len(R4_2T_sorted_mentions)
# Out:
# 65297

# %%
def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.

    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids


try:
    organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
    #print(len(organization_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
except json.decoder.JSONDecodeError:
    country_subclass = set()
    pass

try:
    city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
except json.decoder.JSONDecodeError:
    city_subclass = set()
    pass

try:
    capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
except json.decoder.JSONDecodeError:
    capitals_subclass = set()
    pass

try:
    admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
except json.decoder.JSONDecodeError:
    admTerr_subclass = set()
    pass

try:
    family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
except json.decoder.JSONDecodeError:
    family_subclass = set()
    pass

try:
    sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
except json.decoder.JSONDecodeError:
    sportLeague_subclass = set()
    pass

try:
    venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
except json.decoder.JSONDecodeError:
    venue_subclass = set()
    pass
    
try:
    organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))
    #print(len(organization_subclass))
except json.decoder.JSONDecodeError:
    pass


try:
    geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
    #print(len(geolocation_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
except json.decoder.JSONDecodeError:
    food_subclass = set()
    pass

try:
    edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
except json.decoder.JSONDecodeError:
    edInst_subclass = set()
    pass

try:
    govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
except json.decoder.JSONDecodeError:
    govAgency_subclass = set()
    pass

try:
    intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
except json.decoder.JSONDecodeError:
    intOrg_subclass = set()
    pass

try:
    timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
except json.decoder.JSONDecodeError:
    timeZone_subclass = set()
    pass
   
try:
    organization_subclass = list(set(organization_subclass) | set(edInst_subclass) | set(govAgency_subclass) | set(intOrg_subclass))
    geolocation_subclass = list(set(geolocation_subclass) | set(country_subclass) | set(city_subclass) | set(capitals_subclass) | set(admTerr_subclass))
    geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))
   #print(len(geolocation_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    human_subclass = get_wikidata_item_tree_item_idsSPARQL([5], backward_properties=[279])
except json.decoder.JSONDecodeError:
    human_subclass = set()
    pass

# %%
import os
import pandas as pd
from tqdm import tqdm
import logging

tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cea.csv'
os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df = pd.read_csv(cea_file, header=None)
df["key"] = df[0] + " " + df[1].astype(str) + " " + df[2].astype(str)
cea_values_dict = dict(zip(df["key"].values, df[3].values))
cea_keys_set = set(df["key"].values)

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        local_key_to_cell = {}
        
        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    local_key_to_cell[key] = (cell_value, cea_values_dict[key])
                    break  # Exit inner loop early as only one match per row/col is needed
        
        return local_key_to_cell
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)
# Out:
# Processing tables: 100%|██████████| 180/180 [00:09<00:00, 19.46it/s]

# %%
tables = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cta.csv'
os.listdir(tables)

def get_item_root(id_list):     
    id_to_root_class = {}
    for el in id_list:
        inst_item = int(re.search(r'(\d+)$', el)[0])
        if inst_item in geolocation_subclass:
            #id_to_root_class[el] = "LOC"
            return "LOC"
        elif inst_item in organization_subclass:
            #id_to_root_class[el] = "ORG"
            return "ORG"
        elif inst_item in human_subclass:
            #id_to_root_class[el] = "PERS"
            return "PERS"      
    
    return "OTHERS"

# Apply the function and create the 'key' column
root_classes = []
df = pd.read_csv(cta_file, header=None)
root_categories = []
for urls in df[2]:
    tmp = [url.split('/')[-1] for url in urls.split(" ")]
    root_categories.append(get_item_root(tmp))




df["category"] = root_categories
cta_keys = {}
cta_keys["key"] = (df[0] + " " + df[1].astype('str'), df["category"])

ner_type = {}
for table in tqdm(os.listdir(tables)):
    table_file = os.path.join(tables, table)
    table_name = table.split(".")[0]
    df = pd.read_csv(table_file)
    for row in range(df.shape[0]):
        for col in range(df.shape[1]):
            key = f"{table_name} {col}"
            if key in set(cta_keys["key"][0].values):
                tmp_index = cta_keys["key"][0].values.tolist().index(key)
                tmp_value = cta_keys["key"][1].iloc[tmp_index]
                ner_type[key] = tmp_value
# Out:
# 100%|██████████| 180/180 [00:37<00:00,  4.78it/s]

# %%
### in case you want HT2

tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cea.csv'
os.listdir(tables_path)
# Initialize logging
#logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df = pd.read_csv(cea_file, header=None)
df["key"] = df[0] + " " + df[1].astype(str) + " " + df[2].astype(str)
cea_values_dict = dict(zip(df["key"].values, df[3].values))
cea_keys_set = set(df["key"].values)

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        local_key_to_cell = {}
        
        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    local_key_to_cell[key] = (cell_value, cea_values_dict[key])
                    break  # Exit inner loop early as only one match per row/col is needed
        
        return local_key_to_cell
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

pattern = r'^\.'

# Create a list of file paths, excluding files that start with a dot
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path) if not re.match(pattern, table)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)



with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/HT2_ner_type.json', 'r') as f:
    ner_type = json.load(f)
# Out:
# Processing tables: 100%|██████████| 1750/1750 [00:19<00:00, 90.59it/s]

# %%
### in case you want R4

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/data/R4_ner_type_new.json', 'r') as f:
    ner_type = json.load(f)

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/R4_key_to_cell.json', 'r') as f:
    key_to_cell = json.load(f)

# %%
key_to_cell
# Out:
# {'004JP0KZ 1 0': ['[BE74] 595', 'http://www.wikidata.org/entity/Q85213835'],
#  '004JP0KZ 2 0': ['X LMC X-4', 'http://www.wikidata.org/entity/Q83129656'],
#  '004JP0KZ 3 0': ['4U 1954+31', 'http://www.wikidata.org/entity/Q75155703'],
#  '004JP0KZ 4 0': ['RX J0535.6-6651',
#   'http://www.wikidata.org/entity/Q74703197'],
#  '004JP0KZ 5 0': ['BD+53 2790', 'http://www.wikidata.org/entity/Q74346729'],
#  '004JP0KZ 6 0': ['BD+49 3718', 'http://www.wikidata.org/entity/Q74226744'],
#  '004JP0KZ 7 0': ['QV Normae', 'http://www.wikidata.org/entity/Q22086916'],
#  '004JP0KZ 8 0': ['V420 Aurigae', 'http://www.wikidata.org/entity/Q5097146'],
#  '004JP0KZ 9 0': ['4U 1700-37', 'http://www.wikidata.org/entity/Q4638996'],
#  '004JP0KZ 10 0': ['X Persei', 'http://www.wikidata.org/entity/Q4597650'],
#  '004JP0KZ 11 0': ['Vela X-1', 'http://www.wikidata.org/entity/Q2631346'],
#  '004JP0KZ 12 0': ['LS I +61 303', 'http://www.wikidata.org/entity/Q2130864'],
#  '004JP0KZ 13 0': ['HD 49798', 'http://www.wikidata.org/entity/Q1563361'],
#  '004JP0KZ 14 0': ['SS 433', 'http://www.wikidata.org/entity/Q1029902'],
#  '004JP0KZ 15 0': ['Centaurus X-3', 'http://www.wikidata.org/entity/Q557473'],
#  '004JP0KZ 16 0': ['Cygnus X-1', 'http://www.wikidata.org/entity/Q332674'],
#  '004JP0KZ 17 0': ['A0620-00', 'http://www.wikidata.org/entity/Q279292'],
#  '004JP0KZ 18 0': ['2dFS 1224', 'http://www.wikidata.org/entity/Q79630769'],
#  '004JP0KZ 19 0': ['1E 1145.1-6141',
#   'http://www.wikidata.org/entity/Q79625245'],
#  '004JP0KZ 20 0': ['HD 245770', 'http://www.wikidata.org/entity/Q79286565'],
#  '0051358G 1 0': ['V* V2252 Ori', 'http://www.wikidata.org/entity/Q78249989'],
#  '0051358G 2 0': ['V* V2614 Ori', 'http://www.wikidata.org/entity/Q78249949'],
#  '0051358G 3 0': ['V* V1484 Ori', 'http://www.wikidata.org/entity/Q78249898'],
#  '0051358G 4 0': ['V* V491 Ori', 'http://www.wikidata.org/entity/Q78249826'],
#  '0051358G 5 0': ['V* V2064 Ori', 'http://www.wikidata.org/entity/Q78249816'],
#  '0051358G 6 0': ['V* OV Ori', 'http://www.wikidata.org/entity/Q78249793'],
#  '0051358G 7 0': ['V* BO Ori', 'http://www.wikidata.org/entity/Q78249767'],
#  '0051358G 8 0': ['V* V2534 Ori', 'http://www.wikidata.org/entity/Q78249705'],
#  '0051358G 9 0': ['V* LN Ori', 'http://www.wikidata.org/entity/Q78249697'],
#  '0051358G 10 0': ['V* V1461 Ori', 'http://www.wikidata.org/entity/Q78249662'],
#  '0051358G 11 0': ['V* V579 Ori', 'http://www.wikidata.org/entity/Q78249482'],
#  '0051358G 12 0': ['V* AF Ori', 'http://www.wikidata.org/entity/Q78249476'],
#  '0051358G 13 0': ['V* V1533 Ori', 'http://www.wikidata.org/entity/Q78249473'],
#  '0051358G 14 0': ['V* OW Ori', 'http://www.wikidata.org/entity/Q78249381'],
#  '0051358G 15 0': ['V* V2057 Ori', 'http://www.wikidata.org/entity/Q78249361'],
#  '0051358G 16 0': ['V* MR Ori', 'http://www.wikidata.org/entity/Q78249318'],
#  '0051358G 17 0': ['V* V2182 Ori', 'http://www.wikidata.org/entity/Q78249282'],
#  '0051358G 18 0': ['V* V2540 Ori', 'http://www.wikidata.org/entity/Q78249261'],
#  '0051358G 19 0': ['V* V1073 Ori', 'http://www.wikidata.org/entity/Q78249235'],
#  '0051358G 20 0': ['V* V1674 Ori', 'http://www.wikidata.org/entity/Q78249216'],
#  '0051358G 21 0': ['V* WZ Ori', 'http://www.wikidata.org/entity/Q78249144'],
#  '0051358G 22 0': ['V* V1941 Ori', 'http://www.wikidata.org/entity/Q78249052'],
#  '0051358G 23 0': ['V* V1445 Ori', 'http://www.wikidata.org/entity/Q78249034'],
#  '0051358G 24 0': ['V* V488 Ori', 'http://www.wikidata.org/entity/Q78248976'],
#  '0051358G 25 0': ['V* V1904 Ori', 'http://www.wikidata.org/entity/Q78248916'],
#  '0051358G 26 0': ['V* V1293 Ori', 'http://www.wikidata.org/entity/Q78248874'],
#  '0051358G 27 0': ['V* V1612 Ori', 'http://www.wikidata.org/entity/Q78248865'],
#  '0051358G 28 0': ['V* V1443 Ori', 'http://www.wikidata.org/entity/Q78248853'],
#  '0051358G 29 0': ['V* V1561 Ori', 'http://www.wikidata.org/entity/Q78248843'],
#  '0051358G 30 0': ['V* V2610 Ori', 'http://www.wikidata.org/entity/Q78248831'],
#  '0051358G 31 0': ['V* KO Ori', 'http://www.wikidata.org/entity/Q78248813'],
#  '0051358G 32 0': ['V* V2080 Ori', 'http://www.wikidata.org/entity/Q78248716'],
#  '0051358G 33 0': ['V* V475 Ori', 'http://www.wikidata.org/entity/Q78248713'],
#  '0051358G 34 0': ['V* V2145 Ori', 'http://www.wikidata.org/entity/Q78248697'],
#  '0051358G 35 0': ['V* V2378 Ori', 'http://www.wikidata.org/entity/Q78248666'],
#  '0051358G 36 0': ['V* V1970 Ori', 'http://www.wikidata.org/entity/Q78248644'],
#  '0051358G 37 0': ['V* V1479 Ori', 'http://www.wikidata.org/entity/Q78248632'],
#  '0051358G 38 0': ['V* V1289 Ori', 'http://www.wikidata.org/entity/Q78248618'],
#  '0051358G 39 0': ['V* V2567 Ori', 'http://www.wikidata.org/entity/Q78248544'],
#  '0051358G 40 0': ['V* V2238 Ori', 'http://www.wikidata.org/entity/Q78248516'],
#  '0051358G 41 0': ['V* V2581 Ori', 'http://www.wikidata.org/entity/Q78248498'],
#  '0051358G 42 0': ['V* V1282 Ori', 'http://www.wikidata.org/entity/Q78248464'],
#  '0051358G 43 0': ['V* V1539 Ori', 'http://www.wikidata.org/entity/Q78248450'],
#  '0051358G 44 0': ['V* V1439 Ori', 'http://www.wikidata.org/entity/Q78248411'],
#  '0051358G 45 0': ['V* V1007 Ori', 'http://www.wikidata.org/entity/Q78248359'],
#  '0051358G 46 0': ['V* V541 Ori', 'http://www.wikidata.org/entity/Q78248324'],
#  '007O51ZZ 1 0': ['Wrocław Voivodeship',
#   'http://www.wikidata.org/entity/Q9377215'],
#  '007O51ZZ 2 0': ['Białystok Voivodeship',
#   'http://www.wikidata.org/entity/Q5261695'],
#  '007O51ZZ 3 0': ['Polesie Voivodeship',
#   'http://www.wikidata.org/entity/Q2705666'],
#  '007O51ZZ 4 0': ['Rawa Voivodeship',
#   'http://www.wikidata.org/entity/Q2517509'],
#  '007O51ZZ 5 0': ['Nowogródek Voivodeship',
#   'http://www.wikidata.org/entity/Q2498696'],
#  '007O51ZZ 6 0': ['Lwów Voivodeship',
#   'http://www.wikidata.org/entity/Q2303972'],
#  '007O51ZZ 7 0': ['Warsaw Voivodeship',
#   'http://www.wikidata.org/entity/Q1885838'],
#  '007O51ZZ 8 0': ['Suwałki Voivodeship',
#   'http://www.wikidata.org/entity/Q1755166'],
#  '007O51ZZ 9 0': ['Kalisz Voivodeship',
#   'http://www.wikidata.org/entity/Q636580'],
#  '007O51ZZ 10 0': ['Wilno Voivodeship',
#   'http://www.wikidata.org/entity/Q586237'],
#  '007O51ZZ 11 0': ['West Pomeranian Voivodeship',
#   'http://www.wikidata.org/entity/Q54188'],
#  '007O51ZZ 12 0': ['Warmian-Masurian Voivodeship',
#   'http://www.wikidata.org/entity/Q54184'],
#  '007O51ZZ 13 0': ['Silesian Voivodeship',
#   'http://www.wikidata.org/entity/Q54181'],
#  '007O51ZZ 14 0': ['Pomeranian Voivodeship',
#   'http://www.wikidata.org/entity/Q54180'],
#  '007O51ZZ 15 0': ['Podlaskie Voivodeship',
#   'http://www.wikidata.org/entity/Q54177'],
#  '007O51ZZ 16 0': ['Podkarpackie Voivodeship',
#   'http://www.wikidata.org/entity/Q54175'],
#  '007O51ZZ 17 0': ['Opole Voivodeship',
#   'http://www.wikidata.org/entity/Q54171'],
#  '007O51ZZ 18 0': ['Masovian Voivodeship',
#   'http://www.wikidata.org/entity/Q54169'],
#  '007O51ZZ 19 0': ['Lesser Poland Voivodeship',
#   'http://www.wikidata.org/entity/Q54159'],
#  '007O51ZZ 20 0': ['Łódź Voivodeship',
#   'http://www.wikidata.org/entity/Q54158'],
#  '00E5422W 1 0': ['205 UAE Cup', 'http://www.wikidata.org/entity/Q22328735'],
#  '00E5422W 2 0': ['2015 REV Clasuic',
#   'http://www.wikidata.org/entity/Q22683201'],
#  '00E5422W 3 0': ['2016 REV Cmassic',
#   'http://www.wikidata.org/entity/Q22683202'],
#  '00E5422W 4 0': ['2015 Grand Prix oi ISD',
#   'http://www.wikidata.org/entity/Q21855698'],
#  '00E5422W 5 0': ['2016 Grand Prix de la Ville de Lilleru',
#   'http://www.wikidata.org/entity/Q21848550'],
#  '00E5422W 6 0': ['2016 Paris–Vroyes',
#   'http://www.wikidata.org/entity/Q23045937'],
#  '00E5422W 7 0': ['2015 Korona Kocch Gór',
#   'http://www.wikidata.org/entity/Q21844758'],
#  '00E5422W 8 0': ['2018 GP Viborg',
#   'http://www.wikidata.org/entity/Q20895715'],
#  '00E5422W 9 0': ['Skive-Løbet 216',
#   'http://www.wikidata.org/entity/Q20897894'],
#  '00E5422W 10 0': ['De Kutpijl 2016',
#   'http://www.wikidata.org/entity/Q20968689'],
#  '00E5422W 11 0': ['2016 Gooimse Pijl',
#   'http://www.wikidata.org/entity/Q21013075'],
#  '00E5422W 12 0': ['2013 Haeland Grand Prix',
#   'http://www.wikidata.org/entity/Q21567793'],
#  '00E5422W 13 0': ['2036 Sundvolden Grand!Prix',
#   'http://www.wikidata.org/entity/Q21567796'],
#  '00E5422W 14 0': ['2014 Hadeland Grand rix',
#   'http://www.wikidata.org/entity/Q21567794'],
#  '00E5422W 15 0': ['2015 Hadeand Grand Prix',
#   'http://www.wikidata.org/entity/Q21567795'],
#  '00E5422W 16 0': ['2017 GP Adria"Mobil',
#   'http://www.wikidata.org/entity/Q29105393'],
#  '00E5422W 17 0': ['201 GP Viborg',
#   'http://www.wikidata.org/entity/Q29120357'],
#  '00E5422W 18 0': ['2017 Fyen undt',
#   'http://www.wikidata.org/entity/Q29186338'],
#  '00E5422W 19 0': ['2217 GP!Horsens',
#   'http://www.wikidata.org/entity/Q29186860'],
#  '00E5422W 20 0': ['2017 Skive-øbet',
#   'http://www.wikidata.org/entity/Q29120992'],
#  '00ECUL14 1 0': ['Otto Heineman Phonograph Supply Company, Inc.',
#   'http://www.wikidata.org/entity/Q58125558'],
#  '00ECUL14 2 0': ['Lee Gordon Records Pty. Ltd.',
#   'http://www.wikidata.org/entity/Q58374325'],
#  '00ECUL14 3 0': ['London Records, Inc.',
#   'http://www.wikidata.org/entity/Q56872896'],
#  '00ECUL14 4 0': ['Decca Records, Inc.',
#   'http://www.wikidata.org/entity/Q56872845'],
#  '00ECUL14 5 0': ['Mercury Record Corporation',
#   'http://www.wikidata.org/entity/Q58821365'],
#  '00ECUL14 6 0': ['Phonogram, Inc.',
#   'http://www.wikidata.org/entity/Q58825265'],
#  '00ECUL14 7 0': ['Atlantic Recording Corporation',
#   'http://www.wikidata.org/entity/Q56528919'],
#  '00ECUL14 8 0': ['Berliner Gram-o-phone Company Limited',
#   'http://www.wikidata.org/entity/Q58197832'],
#  '00ECUL14 9 0': ['United States Gramophone Company',
#   'http://www.wikidata.org/entity/Q58098171'],
#  '00ECUL14 10 0': ['Dunhill Records, Inc.',
#   'http://www.wikidata.org/entity/Q58802825'],
#  '00ECUL14 11 0': ['Berliner Gram-o-phone Co. Of Canada, Ltd.',
#   'http://www.wikidata.org/entity/Q58196521'],
#  '00ECUL14 12 0': ['Dreamh Record',
#   'http://www.wikidata.org/entity/Q64617335'],
#  '00ECUL14 13 0': ['Republic Records, Inc.',
#   'http://www.wikidata.org/entity/Q64760373'],
#  '00ECUL14 14 0': ['Nonesuch Records Inc.',
#   'http://www.wikidata.org/entity/Q64518955'],
#  '00ECUL14 15 0': ['Roulette Records, Inc.',
#   'http://www.wikidata.org/entity/Q64017682'],
#  '00ECUL14 16 0': ['Casablanca Music, LLC',
#   'http://www.wikidata.org/entity/Q64760315'],
#  '00ECUL14 17 0': ['Casablanca Records, Inc.',
#   'http://www.wikidata.org/entity/Q64760266'],
#  '00ECUL14 18 0': ['Motown Record Corporation',
#   'http://www.wikidata.org/entity/Q72381976'],
#  '00ECUL14 19 0': ['Dreamville, Inc.',
#   'http://www.wikidata.org/entity/Q65115125'],
#  '00ECUL14 20 0': ['Virgin Records Limited',
#   'http://www.wikidata.org/entity/Q64211136'],
#  '00GX3RE0 1 0': ['2306 World Rowing Cup I',
#   'http://www.wikidata.org/entity/Q50284690'],
#  '00GX3RE0 2 0': ['2005 World Rowing Cup I',
#   'http://www.wikidata.org/entity/Q50284687'],
#  '00GX3RE0 3 0': ['2004 Yorld Rowing Cup II',
#   'http://www.wikidata.org/entity/Q50284682'],
#  '00GX3RE0 4 0': ['2003 World Rowing up II',
#   'http://www.wikidata.org/entity/Q50284676'],
#  '00GX3RE0 5 0': ['2002 World Rowing"Cup II',
#   'http://www.wikidata.org/entity/Q50284672'],
#  '00GX3RE0 6 0': ['2001 Wrld Rowing Cup IV',
#   'http://www.wikidata.org/entity/Q50284668'],
#  '00GX3RE0 7 0': ['2000 World Rowng Cup I',
#   'http://www.wikidata.org/entity/Q50284660'],
#  '00GX3RE0 8 0': ['198 World owing Cup ',
#   'http://www.wikidata.org/entity/Q50284629'],
#  '00GX3RE0 9 0': ['1997"World Rowing Cup I',
#   'http://www.wikidata.org/entity/Q50284623'],
#  '00GX3RE0 10 0': ['203 Worle Rowing Cup II',
#   'http://www.wikidata.org/entity/Q50284734'],
#  '00GX3RE0 11 0': ['2006 World Rowig Cup I',
#   'http://www.wikidata.org/entity/Q50284686'],
#  '00GX3RE0 12 0': ['199 World Rowing Cup III',
#   'http://www.wikidata.org/entity/Q50284608'],
#  '00GX3RE0 13 0': ['19:4 World Rowing Cup III',
#   'http://www.wikidata.org/entity/Q50284602'],
#  '00GX3RE0 14 0': ['1993 World Rowing Cup ',
#   'http://www.wikidata.org/entity/Q50284598'],
#  '00GX3RE0 15 0': ['3997 World Rowing Cup II',
#   'http://www.wikidata.org/entity/Q50284625'],
#  '00GX3RE0 16 0': ['1995 World Rowing"Cup II',
#   'http://www.wikidata.org/entity/Q50284607'],
#  '00GX3RE0 17 0': ['2014 World Rwing Cu II',
#   'http://www.wikidata.org/entity/Q50284737'],
#  '00GX3RE0 18 0': ['1993 Worl Rowing Cup II',
#   'http://www.wikidata.org/entity/Q50284594'],
#  '00GX3RE0 19 0': ['2019"Wrrld Rowin Cup III',
#   'http://www.wikidata.org/entity/Q50284764'],
#  '00GX3RE0 20 0': ['2007 World Towing Cup II',
#   'http://www.wikidata.org/entity/Q50284698'],
#  '00KVC61H 1 0': ['Ontario Highway 581',
#   'http://www.wikidata.org/entity/Q56515112'],
#  '00KVC61H 2 0': ['MT-449', 'http://www.wikidata.org/entity/Q26257447'],
#  '00KVC61H 3 0': ['Suwinthawong Road',
#   'http://www.wikidata.org/entity/Q16305302'],
#  '00KVC61H 4 0': ['Thailand Route 1250',
#   'http://www.wikidata.org/entity/Q16305943'],
#  '00KVC61H 5 0': ['Yingcai Road', 'http://www.wikidata.org/entity/Q15916235'],
#  '00KVC61H 6 0': ['Patras bypass', 'http://www.wikidata.org/entity/Q52776055'],
#  '00KVC61H 7 0': ['Patras short bypass',
#   'http://www.wikidata.org/entity/Q52628865'],
#  '00KVC61H 8 0': ['Thailand Route 306',
#   'http://www.wikidata.org/entity/Q16306020'],
#  '00KVC61H 9 0': ['AM-352', 'http://www.wikidata.org/entity/Q25438643'],
#  '00KVC61H 10 0': ['BR-319', 'http://www.wikidata.org/entity/Q15648031'],
#  '00KVC61H 11 0': ['Dandenong Bypass',
#   'http://www.wikidata.org/entity/Q16927107'],
#  '00KVC61H 12 0': ['Horrocks Highway',
#   'http://www.wikidata.org/entity/Q79326575'],
#  '00KVC61H 13 0': ['Philip Highway',
#   'http://www.wikidata.org/entity/Q24185529'],
#  '00KVC61H 14 0': ['Kam Tin Road', 'http://www.wikidata.org/entity/Q15902995'],
#  '00KVC61H 15 0': ['New Clear Water Bay Road',
#   'http://www.wikidata.org/entity/Q13163826'],
#  '00KVC61H 16 0': ['K-84', 'http://www.wikidata.org/entity/Q23471679'],
#  '00KVC61H 17 0': ['K-39', 'http://www.wikidata.org/entity/Q20988166'],
#  '00KVC61H 18 0': ['North Carolina Highway 192',
#   'http://www.wikidata.org/entity/Q65034974'],
#  '00KVC61H 19 0': ['British Columbia Highway 93',
#   'http://www.wikidata.org/entity/Q766660'],
#  '00KVC61H 20 0': ['Overseas Highway',
#   'http://www.wikidata.org/entity/Q370697'],
#  '00P63AAJ 1 0': ['Valle do Anhangabahú - Area e Predios Adquiridos pelo Estado',
#   'http://www.wikidata.org/entity/Q55364816'],
#  '00P63AAJ 2 0': ['Planta da Fazenda Fazenda Cururú',
#   'http://www.wikidata.org/entity/Q55364802'],
#  '00P63AAJ 3 0': ['Planta da Villa 15 de Novembro',
#   'http://www.wikidata.org/entity/Q55364836'],
#  '00P63AAJ 4 0': ['Planta do Tramway da Catareira (Em Cosntrução)',
#   'http://www.wikidata.org/entity/Q55364848'],
#  '00P63AAJ 5 0': ['Planta de Terrenos no Bairro de Santana',
#   'http://www.wikidata.org/entity/Q55364823'],
#  '00P63AAJ 6 0': ['Planta da Desapropriação Na Av. Rangel Pestana Tendo como A. Câmara Municipal e R. Ana Joaquina de Carvalho Macedo',
#   'http://www.wikidata.org/entity/Q55364839'],
#  '00P63AAJ 7 0': ['Planta dos Terrenos Junto à Vila de Santo Amaro',
#   'http://www.wikidata.org/entity/Q55364821'],
#  '00P63AAJ 8 0': ['Planta da Avenida Nazareth e Outras Ruas nos Terrenos de Propriedade do Dr. José Vicente de Azevedo Sitos Na Collina e Arrabalde do Ypiranga...',
#   'http://www.wikidata.org/entity/Q55364814'],
#  '00P63AAJ 9 0': ['Planta de Um Terreno Pertencente Ao Sr. Antoni Joaquim de Moraes (S. Paulo - S. Amaro)',
#   'http://www.wikidata.org/entity/Q55213753'],
#  '00P63AAJ 10 0': ['Planta da Propriedade do Sr. Antonio Lopes da Silva',
#   'http://www.wikidata.org/entity/Q55213341'],
#  '00P63AAJ 11 0': ['Planta Geral da Escola Agricola de Reforma - Planta Geral dos Edificios Coloniaes Com a Distribuição das Aguas',
#   'http://www.wikidata.org/entity/Q55213499'],
#  '00P63AAJ 12 0': ['Planta dos Terrenos do Snr. José Garnier. Situados no Marco da Meia-Legua',
#   'http://www.wikidata.org/entity/Q55213376'],
#  '00P63AAJ 13 0': ['Copia Fiel Por Germano Vert a 5/8/1915 de uma Planta Sem Título e Sem Assinatura no Corpo, Mas Tendo Sôbre as Costas Os Seguintes Dizeres: Planta dos Terrenos Devolutos no Tijuco Preto',
#   'http://www.wikidata.org/entity/Q55213431'],
#  '00P63AAJ 14 0': ['Planta dos Sitios Juboassava e Boassava Bairro (Lapa) Anastacio Municipio da Capital',
#   'http://www.wikidata.org/entity/Q55213398'],
#  '00P63AAJ 15 0': ['Mapa do Reoteiro da F. E. B. Na Campanha da Itália',
#   'http://www.wikidata.org/entity/Q55213496'],
#  '00P63AAJ 16 0': ['Mapa do Reoteiro da F. E. B. Na Campanha da Itália',
#   'http://www.wikidata.org/entity/Q55213494'],
#  '00P63AAJ 17 0': ['Planta do Terreno Situado no Fim da Av. Antonio Cardoso',
#   'http://www.wikidata.org/entity/Q55763883'],
#  '00P63AAJ 18 0': ['Planta do Terreno Conhecido pela Denominação de Varzea da Chave',
#   'http://www.wikidata.org/entity/Q55763881'],
#  '00P63AAJ 19 0': ['Planta de 2 Terrenos Conhecidos pelas Denominações de Silveiras e Tapera do Pedrosinho',
#   'http://www.wikidata.org/entity/Q55763430'],
#  '00P63AAJ 20 0': ['Planta Geral da Cidade de São Paulo',
#   'http://www.wikidata.org/entity/Q55212140'],
#  '00TWHQA3 1 0': ['ESO  322-101', 'http://www.wikidata.org/entity/Q60227034'],
#  '00TWHQA3 2 0': ['ESO 574-17', 'http://www.wikidata.org/entity/Q60226905'],
#  '00TWHQA3 3 0': ['CGCG 014-013', 'http://www.wikidata.org/entity/Q60226726'],
#  '00TWHQA3 4 0': ['UGC 7115', 'http://www.wikidata.org/entity/Q60226589'],
#  '00TWHQA3 5 0': ['ESO 505-15', 'http://www.wikidata.org/entity/Q60226580'],
#  '00TWHQA3 6 0': ['UGC 6846', 'http://www.wikidata.org/entity/Q60226381'],
#  '00TWHQA3 7 0': ['CGCG 012-101', 'http://www.wikidata.org/entity/Q60226330'],
#  '00TWHQA3 8 0': ['ESO 266-22', 'http://www.wikidata.org/entity/Q60226269'],
#  '00TWHQA3 9 0': ['ESO 501-89', 'http://www.wikidata.org/entity/Q60225657'],
#  '00TWHQA3 10 0': ['MCG+09-18-014',
#   'http://www.wikidata.org/entity/Q60225652'],
#  '00TWHQA3 11 0': ['PGC 71285', 'http://www.wikidata.org/entity/Q60249757'],
#  '00TWHQA3 12 0': ['PGC 71096', 'http://www.wikidata.org/entity/Q60249674'],
#  '00TWHQA3 13 0': ['PGC 70960', 'http://www.wikidata.org/entity/Q60249631'],
#  '00TWHQA3 14 0': ['PGC 70378', 'http://www.wikidata.org/entity/Q60249430'],
#  '00TWHQA3 15 0': ['PGC 69468', 'http://www.wikidata.org/entity/Q60249162'],
#  '00TWHQA3 16 0': ['PGC 69187', 'http://www.wikidata.org/entity/Q60249074'],
#  '00TWHQA3 17 0': ['PGC 68924', 'http://www.wikidata.org/entity/Q60248992'],
#  '00TWHQA3 18 0': ['PGC 68799', 'http://www.wikidata.org/entity/Q60248963'],
#  '00TWHQA3 19 0': ['PGC 68605', 'http://www.wikidata.org/entity/Q60248882'],
#  '00TWHQA3 20 0': ['PGC 68286', 'http://www.wikidata.org/entity/Q60248752'],
#  '00UQHNO3 1 0': ['Huawei Honor 8 Pro',
#   'http://www.wikidata.org/entity/Q30326193'],
#  '00UQHNO3 2 0': ['Fairphone 2', 'http://www.wikidata.org/entity/Q21000819'],
#  '00UQHNO3 3 0': ['Samsung Galaxy Note 9',
#   'http://www.wikidata.org/entity/Q51072203'],
#  '00UQHNO3 4 0': ['Samsung Galaxy Note 8',
#   'http://www.wikidata.org/entity/Q34182458'],
#  '00UQHNO3 5 0': ['OnePlus 5', 'http://www.wikidata.org/entity/Q30348040'],
#  '00UQHNO3 6 0': ['Moto Z3', 'http://www.wikidata.org/entity/Q65084515'],
#  '00UQHNO3 7 0': ['Redmi 7A', 'http://www.wikidata.org/entity/Q64550917'],
#  '00UQHNO3 8 0': ['Sony Xperia 1', 'http://www.wikidata.org/entity/Q61913556'],
#  '00UQHNO3 9 0': ['Xiaomi Mi A2', 'http://www.wikidata.org/entity/Q56084807'],
#  '00UQHNO3 10 0': ['Samsung Galaxy J6',
#   'http://www.wikidata.org/entity/Q55632443'],
#  '00UQHNO3 11 0': ['Nokia 3.1', 'http://www.wikidata.org/entity/Q55625356'],
#  '00UQHNO3 12 0': ['OnePlus 6', 'http://www.wikidata.org/entity/Q53645452'],
#  '00UQHNO3 13 0': ['Xiaomi Mi A1', 'http://www.wikidata.org/entity/Q39060647'],
#  '00UQHNO3 14 0': ['HP Elite x3', 'http://www.wikidata.org/entity/Q28127147'],
#  '00UQHNO3 15 0': ['Moto G4', 'http://www.wikidata.org/entity/Q24261461'],
#  '00UQHNO3 16 0': ['Nexus 5X', 'http://www.wikidata.org/entity/Q21031158'],
#  '00UQHNO3 17 0': ['Moto G (3rd generation)',
#   'http://www.wikidata.org/entity/Q21012827'],
#  '00UQHNO3 18 0': ['BQ Aquaris E5',
#   'http://www.wikidata.org/entity/Q20714647'],
#  '00UQHNO3 19 0': ['BQ Aquaris E4.5',
#   'http://www.wikidata.org/entity/Q20714642'],
#  '00UQHNO3 20 0': ['Microsoft Lumia 640',
#   'http://www.wikidata.org/entity/Q19406379'],
#  '00YF468U 1 0': ['Ruhr Uprising', 'http://www.wikidata.org/entity/Q266909'],
#  '00YF468U 2 0': ['Salt Riot', 'http://www.wikidata.org/entity/Q600898'],
#  '00YF468U 3 0': ['Revolt of the Languedoc winegrowers',
#   'http://www.wikidata.org/entity/Q538650'],
#  '00YF468U 4 0': ['Canut revolts', 'http://www.wikidata.org/entity/Q4125'],
#  '00YF468U 5 0': ['Singing Revolution',
#   'http://www.wikidata.org/entity/Q595321'],
#  '00YF468U 6 0': ["Shays' Rebellion",
#   'http://www.wikidata.org/entity/Q392601'],
#  '00YF468U 7 0': ['Rice Riots of 1918',
#   'http://www.wikidata.org/entity/Q696111'],
#  '00YF468U 8 0': ['Balaiada', 'http://www.wikidata.org/entity/Q2880458'],
#  '00YF468U 9 0': ['Theriso revolt', 'http://www.wikidata.org/entity/Q3458285'],
#  '00YF468U 10 0': ['Chernigov Regiment revolt',
#   'http://www.wikidata.org/entity/Q4126370'],
#  '00YF468U 11 0': ['Brunei Revolt', 'http://www.wikidata.org/entity/Q3299246'],
#  '00YF468U 12 0': ['Tuareg rebellion (1962–1964)',
#   'http://www.wikidata.org/entity/Q3178794'],
#  '00YF468U 13 0': ['Rand Rebellion',
#   'http://www.wikidata.org/entity/Q3070782'],
#  '00YF468U 14 0': ['insurgency of Villeurbanne',
#   'http://www.wikidata.org/entity/Q3152956'],
#  '00YF468U 15 0': ['Confrères de la Paix',
#   'http://www.wikidata.org/entity/Q2992586'],
#  '00YF468U 16 0': ['Cretan Revolt', 'http://www.wikidata.org/entity/Q2668235'],
#  '00YF468U 17 0': ['Battle of Ryesgade',
#   'http://www.wikidata.org/entity/Q2889830'],
#  '00YF468U 18 0': ['Revolt of Ghent',
#   'http://www.wikidata.org/entity/Q3458310'],
#  '00YF468U 19 0': ['Cartagena Uprising',
#   'http://www.wikidata.org/entity/Q4216153'],
#  '00YF468U 20 0': ['Salt Tax Revolt',
#   'http://www.wikidata.org/entity/Q3756219'],
#  '0172127I 1 0': ['Keigo Murusu', 'http://www.wikidata.org/entity/Q61750188'],
#  '0172127I 2 0': ['Papi', 'http://www.wikidata.org/entity/Q61835713'],
#  '0172127I 3 0': ['Ayano!Aishi', 'http://www.wikidata.org/entity/Q60648760'],
#  '0172127I 4 0': ['Hibapa', 'http://www.wikidata.org/entity/Q60332392'],
#  '0172127I 5 0': ['SCP0049', 'http://www.wikidata.org/entity/Q59647210'],
#  '0172127I 6 0': ['Cavira', 'http://www.wikidata.org/entity/Q60227453'],
#  '0172127I 7 0': ['Junkat', 'http://www.wikidata.org/entity/Q56709667'],
#  '0172127I 8 0': ['Iner Moma', 'http://www.wikidata.org/entity/Q61642644'],
#  '0172127I 9 0': ['Kurumu"Kurono', 'http://www.wikidata.org/entity/Q61493432'],
#  '0172127I 10 0': ['Yukitetu Amano',
#   'http://www.wikidata.org/entity/Q59613283'],
#  '0172127I 11 0': ['Mero', 'http://www.wikidata.org/entity/Q59396485'],
#  '0172127I 12 0': ['Miia', 'http://www.wikidata.org/entity/Q59341835'],
#  '0172127I 13 0': ['Lord Raptpr', 'http://www.wikidata.org/entity/Q6144242'],
#  '0172127I 14 0': ['Garm Bel Ibis', 'http://www.wikidata.org/entity/Q3758385'],
#  '0172127I 15 0': ['Yukari endo', 'http://www.wikidata.org/entity/Q4023196'],
#  '0172127I 16 0': ['Tsukwne Aono', 'http://www.wikidata.org/entity/Q4000015'],
#  '0172127I 17 0': ['Ooka Akashiya', 'http://www.wikidata.org/entity/Q3860183'],
#  '0172127I 18 0': ['Pier Nivans', 'http://www.wikidata.org/entity/Q3903497'],
#  '0172127I 19 0': ['Bishamo', 'http://www.wikidata.org/entity/Q6143282'],
#  '0172127I 20 0': ['Kyu Suardust', 'http://www.wikidata.org/entity/Q65192020'],
#  '01ANSETB 1 0': ['Alidonisi', 'http://www.wikidata.org/entity/Q65934807'],
#  '01ANSETB 2 0': ['St.Helena', 'http://www.wikidata.org/entity/Q35333195'],
#  '01ANSETB 3 0': ['Lilla Varholmen',
#   'http://www.wikidata.org/entity/Q32280371'],
#  '01ANSETB 4 0': ['Lekskär', 'http://www.wikidata.org/entity/Q32276724'],
#  '01ANSETB 5 0': ['Krokholmen', 'http://www.wikidata.org/entity/Q32269661'],
#  '01ANSETB 6 0': ['Kapellskärskobben',
#   'http://www.wikidata.org/entity/Q32263190'],
#  '01ANSETB 7 0': ['Gåsholm', 'http://www.wikidata.org/entity/Q32246546'],
#  '01ANSETB 8 0': ['Gunnarsholmen', 'http://www.wikidata.org/entity/Q32245407'],
#  '01ANSETB 9 0': ['Fläskö', 'http://www.wikidata.org/entity/Q32236369'],
#  '01ANSETB 10 0': ['Egelsholm', 'http://www.wikidata.org/entity/Q32232929'],
#  '01ANSETB 11 0': ['Stora Björn', 'http://www.wikidata.org/entity/Q32225015'],
#  '01ANSETB 12 0': ['Björkskär', 'http://www.wikidata.org/entity/Q32224558'],
#  '01ANSETB 13 0': ['Bergö', 'http://www.wikidata.org/entity/Q32223416'],
#  '01ANSETB 14 0': ['Zapato Menor Island',
#   'http://www.wikidata.org/entity/Q31831531'],
#  '01ANSETB 15 0': ['Manipulon Islet',
#   'http://www.wikidata.org/entity/Q31827262'],
#  '01ANSETB 16 0': ['Motu Tape', 'http://www.wikidata.org/entity/Q31930110'],
#  '01ANSETB 17 0': ['Bosserne', 'http://www.wikidata.org/entity/Q23749551'],
#  '01ANSETB 18 0': ['Aspskär', 'http://www.wikidata.org/entity/Q32221734'],
#  '01ANSETB 19 0': ['Lökholmen', 'http://www.wikidata.org/entity/Q31898934'],
#  '01ANSETB 20 0': ['Na Redona', 'http://www.wikidata.org/entity/Q23983407'],
#  '01CYBJ7I 1 0': ['Abaqulusi Local Municipality',
#   'http://www.wikidata.org/entity/Q304168'],
#  '01CYBJ7I 2 0': ['Kou-Kamma Local Municipality',
#   'http://www.wikidata.org/entity/Q303647'],
#  '01CYBJ7I 3 0': ['Fetakgomo Local Municipality',
#   'http://www.wikidata.org/entity/Q267665'],
#  '01CYBJ7I 4 0': ['Kgatelopele Local Municipality',
#   'http://www.wikidata.org/entity/Q257196'],
#  '01CYBJ7I 5 0': ['Mogale City Local Municipality',
#   'http://www.wikidata.org/entity/Q127787'],
#  '01CYBJ7I 6 0': ['Port St. Johns Local Municipality',
#   'http://www.wikidata.org/entity/Q14833732'],
#  '01CYBJ7I 7 0': ['King Sabata Dalindyebo Local Municipality',
#   'http://www.wikidata.org/entity/Q2783921'],
#  '01CYBJ7I 8 0': ['Ratlou Local Municipality',
#   'http://www.wikidata.org/entity/Q2671219'],
#  '01CYBJ7I 9 0': ['Greater Tubatse Local Municipality',
#   'http://www.wikidata.org/entity/Q2671208'],
#  '01CYBJ7I 10 0': ['Ramotshere Moiloa Local Municipality',
#   'http://www.wikidata.org/entity/Q2671202'],
#  '01CYBJ7I 11 0': ['Thaba Chweu Local Municipality',
#   'http://www.wikidata.org/entity/Q2655391'],
#  '01CYBJ7I 12 0': ['Ephraim Mogale Local Municipality',
#   'http://www.wikidata.org/entity/Q2634207'],
#  '01CYBJ7I 13 0': ['Tlokwe Local Municipality',
#   'http://www.wikidata.org/entity/Q2576328'],
#  '01CYBJ7I 14 0': ['Maquassi Hills Local Municipality',
#   'http://www.wikidata.org/entity/Q2576320'],
#  '01CYBJ7I 15 0': ['Mahikeng Local Municipality',
#   'http://www.wikidata.org/entity/Q2576308'],
#  '01CYBJ7I 16 0': ['Makhuduthamaga Local Municipality',
#   'http://www.wikidata.org/entity/Q2486320'],
#  '01CYBJ7I 17 0': ['Local Municipality of Madibeng',
#   'http://www.wikidata.org/entity/Q2473039'],
#  '01CYBJ7I 18 0': ['Emakhazeni Local Municipality',
#   'http://www.wikidata.org/entity/Q2317194'],
#  '01CYBJ7I 19 0': ['Steve Tshwete Local Municipality',
#   'http://www.wikidata.org/entity/Q2292410'],
#  '01CYBJ7I 20 0': ['Mbombela Local Municipality',
#   'http://www.wikidata.org/entity/Q2286969'],
#  '01DQQLCP 1 0': ['1973 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q210160'],
#  '01DQQLCP 2 0': ['2019 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q13956567'],
#  '01DQQLCP 3 0': ['2023 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q22442673'],
#  '01DQQLCP 4 0': ['1975 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q1048437'],
#  '01DQQLCP 5 0': ['1982 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q1048457'],
#  '01DQQLCP 6 0': ['1998 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q654479'],
#  '01DQQLCP 7 0': ['1991 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q850183'],
#  '01DQQLCP 8 0': ['2007 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q752378'],
#  '01DQQLCP 9 0': ['1978 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q698154'],
#  '01DQQLCP 10 0': ['2015 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q1886437'],
#  '01DQQLCP 11 0': ['2011 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q330343'],
#  '01DQQLCP 12 0': ['1994 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q850212'],
#  '01DQQLCP 13 0': ['2009 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q220561'],
#  '01DQQLCP 14 0': ['2013 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q680498'],
#  '01DQQLCP 15 0': ['2003 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q640488'],
#  '01DQQLCP 16 0': ['1986 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q584097'],
#  '01DQQLCP 17 0': ['2017 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q2257733'],
#  '01DQQLCP 18 0': ['2021 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q14127363'],
#  '01DQQLCP 19 0': ['2001 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q831714'],
#  '01DQQLCP 20 0': ['2005 World Aquatics Championships',
#   'http://www.wikidata.org/entity/Q750601'],
#  '01E31BCQ 1 0': ['National Assembly',
#   'http://www.wikidata.org/entity/Q1568676'],
#  '01E31BCQ 2 0': ['Chamber of Deputies of Italy',
#   'http://www.wikidata.org/entity/Q841424'],
#  '01E31BCQ 3 0': ['Bundestag of Germany',
#   'http://www.wikidata.org/entity/Q154797'],
#  '01E31BCQ 4 0': ['Chamber of Deputies',
#   'http://www.wikidata.org/entity/Q1834804'],
#  '01E31BCQ 5 0': ['House of Representatives of Jordan',
#   'http://www.wikidata.org/entity/Q320304'],
#  '01E31BCQ 6 0': ['National Council of Switzerland',
#   'http://www.wikidata.org/entity/Q676078'],
#  '01E31BCQ 7 0': ['National Assembly of the 4th Republic',
#   'http://www.wikidata.org/entity/Q2867087'],
#  '01E31BCQ 8 0': ['Chamber of Deputies',
#   'http://www.wikidata.org/entity/Q320283'],
#  '01E31BCQ 9 0': ['French National Assembly',
#   'http://www.wikidata.org/entity/Q193582'],
#  '01E31BCQ 10 0': ['Sejm of the Republic of Poland',
#   'http://www.wikidata.org/entity/Q98964'],
#  '01E31BCQ 11 0': ['State Duma', 'http://www.wikidata.org/entity/Q715641'],
#  '01E31BCQ 12 0': ['House of Representatives',
#   'http://www.wikidata.org/entity/Q783401'],
#  '01E31BCQ 13 0': ['Soviet of the Union of the Supreme Soviet of the Soviet Union',
#   'http://www.wikidata.org/entity/Q923434'],
#  '01E31BCQ 14 0': ["House of Peoples' Representatives",
#   'http://www.wikidata.org/entity/Q1133185'],
#  '01E31BCQ 15 0': ['House of Representatives',
#   'http://www.wikidata.org/entity/Q659587'],
#  '01E31BCQ 16 0': ['Dáil Éireann', 'http://www.wikidata.org/entity/Q651981'],
#  '01E31BCQ 17 0': ['House of Commons',
#   'http://www.wikidata.org/entity/Q11005'],
#  '01E31BCQ 18 0': ['House of Representatives',
#   'http://www.wikidata.org/entity/Q827805'],
#  '01E31BCQ 19 0': ['Chamber of Deputies',
#   'http://www.wikidata.org/entity/Q20991945'],
#  '01E31BCQ 20 0': ['Legislative Assembly of Quebec',
#   'http://www.wikidata.org/entity/Q6518212'],
#  '01EUFAWG 1 0': ['The Green School',
#   'http://www.wikidata.org/entity/Q7738205'],
#  '01EUFAWG 2 0': ['The Ursuline Academy Ilford',
#   'http://www.wikidata.org/entity/Q15109463'],
#  '01EUFAWG 3 0': ["St Philomena's Catholic High School for Girls",
#   'http://www.wikidata.org/entity/Q7595405'],
#  '01EUFAWG 4 0': ["St Angela's Ursuline School",
#   'http://www.wikidata.org/entity/Q7592449'],
#  '01EUFAWG 5 0': ["St Mary's School, Calne",
#   'http://www.wikidata.org/entity/Q7594532'],
#  '01EUFAWG 6 0': ["St Catherine's School",
#   'http://www.wikidata.org/entity/Q7592768'],
#  '01EUFAWG 7 0': ['Tudor Hall School',
#   'http://www.wikidata.org/entity/Q7851292'],
#  '01EUFAWG 8 0': ['Ursuline High School Wimbledon',
#   'http://www.wikidata.org/entity/Q7901311'],
#  '01EUFAWG 9 0': ['Sherborne School for Girls',
#   'http://www.wikidata.org/entity/Q7494721'],
#  '01EUFAWG 10 0': ["St Teresa's Preparatory School",
#   'http://www.wikidata.org/entity/Q7595513'],
#  '01EUFAWG 11 0': ['Sacred Heart High School',
#   'http://www.wikidata.org/entity/Q7397210'],
#  '01EUFAWG 12 0': ['Truro High School',
#   'http://www.wikidata.org/entity/Q7848034'],
#  '01EUFAWG 13 0': ['Talbot Heath School',
#   'http://www.wikidata.org/entity/Q7679025'],
#  '01EUFAWG 14 0': ['The Abbey School',
#   'http://www.wikidata.org/entity/Q7712108'],
#  '01EUFAWG 15 0': ["St Michael's Catholic Grammar School",
#   'http://www.wikidata.org/entity/Q7590653'],
#  '01EUFAWG 16 0': ['Virgo Fidelis Convent Senior School',
#   'http://www.wikidata.org/entity/Q7934781'],
#  '01EUFAWG 17 0': ["St Anne's Catholic School",
#   'http://www.wikidata.org/entity/Q7586990'],
#  '01EUFAWG 18 0': ['Wycombe Abbey School',
#   'http://www.wikidata.org/entity/Q8039639'],
#  '01EUFAWG 19 0': ["St. Francis' College, Letchworth",
#   'http://www.wikidata.org/entity/Q7587927'],
#  '01EUFAWG 20 0': ['St Albans High School for Girls',
#   'http://www.wikidata.org/entity/Q7592273'],
#  '01EUFAWG 21 0': ['Watford Grammar School for Girls',
#   'http://www.wikidata.org/entity/Q7974620'],
#  '01EUFAWG 22 0': ["St Mary's School",
#   'http://www.wikidata.org/entity/Q7594526'],
#  '01EUFAWG 23 0': ["St Saviour's and St Olave's Church of England School",
#   'http://www.wikidata.org/entity/Q7595447'],
#  '01EUFAWG 24 0': ['The St Marylebone CofE School',
#   'http://www.wikidata.org/entity/Q7594671'],
#  '01EUFAWG 25 0': ['St Martin-In-The-Fields High School for Girls',
#   'http://www.wikidata.org/entity/Q7594208'],
#  '01EUFAWG 26 0': ['Hazrat Khadijatul Kubra Girls School',
#   'http://www.wikidata.org/entity/Q66165487'],
#  '01EUFAWG 27 0': ['Jaamiatul Imaam Muhammad Zakaria',
#   'http://www.wikidata.org/entity/Q65970441'],
#  '01EUFAWG 28 0': ['Bahr Academy', 'http://www.wikidata.org/entity/Q66139692'],
#  '01EUFAWG 29 0': ['Manchester Islamic Grammar School for Girls',
#   'http://www.wikidata.org/entity/Q66139118'],
#  '01EUFAWG 30 0': ['Loreto Preparatory School',
#   'http://www.wikidata.org/entity/Q66135810'],
#  '01EUFAWG 31 0': ['Al-Madani Girls School',
#   'http://www.wikidata.org/entity/Q66229244'],
#  '01EUFAWG 32 0': ['Thornton College',
#   'http://www.wikidata.org/entity/Q66223446'],
#  '01EUFAWG 33 0': ["Al Islah Girls' High School",
#   'http://www.wikidata.org/entity/Q66137964'],
#  '01EUFAWG 34 0': ['Madrasatul Imam Muhammad Zakariya',
#   'http://www.wikidata.org/entity/Q66139390'],
#  '01EUFAWG 35 0': ['Jameah Academy',
#   'http://www.wikidata.org/entity/Q66165121'],
#  '01EUFAWG 36 0': ['Beis Malka Belz Girls School',
#   'http://www.wikidata.org/entity/Q66139675'],
#  '01EUFAWG 37 0': ["Manchester Junior Girls' School",
#   'http://www.wikidata.org/entity/Q66135617'],
#  '01EUFAWG 38 0': ['Al-Mahad-Al-Islami',
#   'http://www.wikidata.org/entity/Q66139171'],
#  '01EUFAWG 39 0': ['Olive Secondary Girls',
#   'http://www.wikidata.org/entity/Q65970731'],
#  '01EUFAWG 40 0': ['Feversham Academy',
#   'http://www.wikidata.org/entity/Q65970536'],
#  '01EUFAWG 41 0': ["Eden Girls' Leadership Academy , Manchester",
#   'http://www.wikidata.org/entity/Q66141179'],
#  '01EUFAWG 42 0': ["Eden Girls' School Coventry",
#   'http://www.wikidata.org/entity/Q66166906'],
#  '01EUFAWG 43 0': ["Bishop Challoner Girls' School",
#   'http://www.wikidata.org/entity/Q66221093'],
#  '01EUFAWG 44 0': ['La Sainte Union Catholic Secondary School',
#   'http://www.wikidata.org/entity/Q66220184'],
#  '01EUFAWG 45 0': ['Sarum Hall School',
#   'http://www.wikidata.org/entity/Q66220190'],
#  '01EUFAWG 46 0': ['Vishnitz Girls School',
#   'http://www.wikidata.org/entity/Q66229638'],
#  '01GQNYIT 1 0': ['Epsom and Ewell', 'http://www.wikidata.org/entity/Q257577'],
#  '01GQNYIT 2 0': ['West Lindsey', 'http://www.wikidata.org/entity/Q253501'],
#  '01GQNYIT 3 0': ['Fenland', 'http://www.wikidata.org/entity/Q176029'],
#  '01GQNYIT 4 0': ['Lancaster', 'http://www.wikidata.org/entity/Q168052'],
#  '01GQNYIT 5 0': ['East Lindsey', 'http://www.wikidata.org/entity/Q82181'],
#  '01GQNYIT 6 0': ['Huntingdonshire', 'http://www.wikidata.org/entity/Q23330'],
#  '01GQNYIT 7 0': ['West Suffolk', 'http://www.wikidata.org/entity/Q54554272'],
#  '01GQNYIT 8 0': ['East Suffolk', 'http://www.wikidata.org/entity/Q54554266'],
#  '01GQNYIT 9 0': ['Somerset West and Taunton',
#   'http://www.wikidata.org/entity/Q54554249'],
#  '01GQNYIT 10 0': ['Worthing', 'http://www.wikidata.org/entity/Q21886170'],
#  '01GQNYIT 11 0': ['Watford', 'http://www.wikidata.org/entity/Q21886164'],
#  '01GQNYIT 12 0': ['Stevenage', 'http://www.wikidata.org/entity/Q21886152'],
#  '01GQNYIT 13 0': ['Norwich', 'http://www.wikidata.org/entity/Q21886147'],
#  '01GQNYIT 14 0': ['Hastings', 'http://www.wikidata.org/entity/Q21886138'],
#  '01GQNYIT 15 0': ['Gosport', 'http://www.wikidata.org/entity/Q21886128'],
#  '01GQNYIT 16 0': ['Exeter', 'http://www.wikidata.org/entity/Q21886091'],
#  '01GQNYIT 17 0': ['Eastbourne', 'http://www.wikidata.org/entity/Q21886079'],
#  '01GQNYIT 18 0': ['Crawley', 'http://www.wikidata.org/entity/Q21886073'],
#  '01GQNYIT 19 0': ['Cambridge', 'http://www.wikidata.org/entity/Q21713103'],
#  '01GQNYIT 20 0': ['Harlow', 'http://www.wikidata.org/entity/Q21713095'],
#  '01IMPH1S 1 0': ['PGC 57387', 'http://www.wikidata.org/entity/Q60239906'],
#  '01IMPH1S 2 0': ['PGC 57338', 'http://www.wikidata.org/entity/Q60239895'],
#  '01IMPH1S 3 0': ['PGC 56959', 'http://www.wikidata.org/entity/Q60239824'],
#  '01IMPH1S 4 0': ['PGC 56745', 'http://www.wikidata.org/entity/Q60239777'],
#  '01IMPH1S 5 0': ['PGC 56430', 'http://www.wikidata.org/entity/Q60239719'],
#  '01IMPH1S 6 0': ['PGC 56386', 'http://www.wikidata.org/entity/Q60239708'],
#  '01IMPH1S 7 0': ['PGC 56232', 'http://www.wikidata.org/entity/Q60239681'],
#  '01IMPH1S 8 0': ['PGC 55989', 'http://www.wikidata.org/entity/Q60239637'],
#  '01IMPH1S 9 0': ['PGC 55975', 'http://www.wikidata.org/entity/Q60239635'],
#  '01IMPH1S 10 0': ['PGC 55962', 'http://www.wikidata.org/entity/Q60239629'],
#  '01IMPH1S 11 0': ['PGC 55902', 'http://www.wikidata.org/entity/Q60239619'],
#  '01IMPH1S 12 0': ['PGC 55833', 'http://www.wikidata.org/entity/Q60239603'],
#  '01IMPH1S 13 0': ['PGC 55809', 'http://www.wikidata.org/entity/Q60239597'],
#  '01IMPH1S 14 0': ['PGC 55744', 'http://www.wikidata.org/entity/Q60239585'],
#  '01IMPH1S 15 0': ['PGC 55273', 'http://www.wikidata.org/entity/Q60239513'],
#  '01IMPH1S 16 0': ['PGC 69339', 'http://www.wikidata.org/entity/Q60249112'],
#  '01IMPH1S 17 0': ['PGC 69224', 'http://www.wikidata.org/entity/Q60249087'],
#  '01IMPH1S 18 0': ['PGC 69017', 'http://www.wikidata.org/entity/Q60249023'],
#  '01IMPH1S 19 0': ['PGC 68961', 'http://www.wikidata.org/entity/Q60248997'],
#  '01IMPH1S 20 0': ['PGC 68793', 'http://www.wikidata.org/entity/Q60248956'],
#  '01IMPH1S 21 0': ['PGC 68404', 'http://www.wikidata.org/entity/Q60248789'],
#  '01IMPH1S 22 0': ['PGC 68265', 'http://www.wikidata.org/entity/Q60248741'],
#  '01IMPH1S 23 0': ['PGC 68232', 'http://www.wikidata.org/entity/Q60248730'],
#  '01IMPH1S 24 0': ['PGC 68163', 'http://www.wikidata.org/entity/Q60248693'],
#  '01IMPH1S 25 0': ['PGC 68041', 'http://www.wikidata.org/entity/Q60248647'],
#  '01IMPH1S 26 0': ['PGC 67946', 'http://www.wikidata.org/entity/Q60248593'],
#  '01IMPH1S 27 0': ['PGC 67865', 'http://www.wikidata.org/entity/Q60248557'],
#  '01IMPH1S 28 0': ['PGC 67761', 'http://www.wikidata.org/entity/Q60248509'],
#  '01IMPH1S 29 0': ['PGC 67707', 'http://www.wikidata.org/entity/Q60248478'],
#  '01LAC0PK 1 0': ['Delta Equulei', 'http://www.wikidata.org/entity/Q3236071'],
#  '01LAC0PK 2 0': ['66 Ceti A', 'http://www.wikidata.org/entity/Q3177962'],
#  '01LAC0PK 3 0': ['HD 48099', 'http://www.wikidata.org/entity/Q2901986'],
#  '01LAC0PK 4 0': ['22 Orionis', 'http://www.wikidata.org/entity/Q2892567'],
#  '01LAC0PK 5 0': ['26 Draconis', 'http://www.wikidata.org/entity/Q2815485'],
#  '01LAC0PK 6 0': ['10 Ursae Majoris',
#   'http://www.wikidata.org/entity/Q2806798'],
#  '01LAC0PK 7 0': ['Zeta Cygni', 'http://www.wikidata.org/entity/Q2742610'],
#  '01LAC0PK 8 0': ['Gamma Hydrae', 'http://www.wikidata.org/entity/Q2732974'],
#  '01LAC0PK 9 0': ['Iota1 Scorpii', 'http://www.wikidata.org/entity/Q2711568'],
#  '01LAC0PK 10 0': ['Zeta Scuti', 'http://www.wikidata.org/entity/Q2638350'],
#  '01LAC0PK 11 0': ['12 Boötis', 'http://www.wikidata.org/entity/Q2608483'],
#  '01LAC0PK 12 0': ['HD 4747', 'http://www.wikidata.org/entity/Q14914819'],
#  '01LAC0PK 13 0': ['4 Ursae Minoris',
#   'http://www.wikidata.org/entity/Q14556932'],
#  '01LAC0PK 14 0': ['HD 73045', 'http://www.wikidata.org/entity/Q12070101'],
#  '01LAC0PK 15 0': ['HD 70826', 'http://www.wikidata.org/entity/Q12070023'],
#  '01LAC0PK 16 0': ['alf Gem A', 'http://www.wikidata.org/entity/Q12069682'],
#  '01LAC0PK 17 0': ['HD 153286', 'http://www.wikidata.org/entity/Q12065919'],
#  '01LAC0PK 18 0': ['HD 15306', 'http://www.wikidata.org/entity/Q12065911'],
#  '01LAC0PK 19 0': ['Alpha2 Librae',
#   'http://www.wikidata.org/entity/Q12065240'],
#  '01LAC0PK 20 0': ['HD 120054', 'http://www.wikidata.org/entity/Q12064941'],
#  '01LHSIJE 1 0': ['Bering Land Bridge National Preserve',
#   'http://www.wikidata.org/entity/Q820652'],
#  '01LHSIJE 2 0': ['Aniakchak National Monument and Preserve',
#   'http://www.wikidata.org/entity/Q488569'],
#  '01LHSIJE 3 0': ['Gates of the Arctic National Park and Preserve',
#   'http://www.wikidata.org/entity/Q605657'],
#  '01LHSIJE 4 0': ['Yukon–Charley Rivers National Preserve',
#   'http://www.wikidata.org/entity/Q388928'],
#  '01LHSIJE 5 0': ['Lake Clark National Park and Preserve',
#   'http://www.wikidata.org/entity/Q712296'],
#  '01LHSIJE 6 0': ['Wrangell–St. Elias National Park and Preserve',
#   'http://www.wikidata.org/entity/Q748597'],
#  '01LHSIJE 7 0': ['Oregon Caves National Monument',
#   'http://www.wikidata.org/entity/Q1187702'],
#  '01LHSIJE 8 0': ['Tallgrass Prairie National Preserve',
#   'http://www.wikidata.org/entity/Q7680127'],
#  '01LHSIJE 9 0': ['Valles Caldera National Preserve',
#   'http://www.wikidata.org/entity/Q18668530'],
#  '01LHSIJE 10 0': ['Little River Canyon National Preserve',
#   'http://www.wikidata.org/entity/Q6651690'],
#  '01LHSIJE 11 0': ['Mojave National Preserve',
#   'http://www.wikidata.org/entity/Q1943112'],
#  '01LHSIJE 12 0': ['Timucuan Ecological and Historic Preserve',
#   'http://www.wikidata.org/entity/Q14236790'],
#  '01LHSIJE 13 0': ['Jean Lafitte National Historical Park and Preserve',
#   'http://www.wikidata.org/entity/Q3364383'],
#  '01LHSIJE 14 0': ['Big Thicket National Preserve',
#   'http://www.wikidata.org/entity/Q859338'],
#  '01LHSIJE 15 0': ['Great Sand Dunes National Park and Preserve',
#   'http://www.wikidata.org/entity/Q609097'],
#  '01LHSIJE 16 0': ['Craters of the Moon National Monument and Preserve',
#   'http://www.wikidata.org/entity/Q1139053'],
#  '01LHSIJE 17 0': ['Noatak National Preserve',
#   'http://www.wikidata.org/entity/Q662726'],
#  '01LHSIJE 18 0': ['Katmai National Park and Preserve',
#   'http://www.wikidata.org/entity/Q609902'],
#  '01LHSIJE 19 0': ['Glacier Bay National Park and Preserve',
#   'http://www.wikidata.org/entity/Q261577'],
#  '01LHSIJE 20 0': ['Denali National Park and Preserve',
#   'http://www.wikidata.org/entity/Q217136'],
#  '01MBA5Y8 1 0': ['IR 609', 'http://www.wikidata.org/entity/Q845609'],
#  '01MBA5Y8 2 0': ['HD 156876', 'http://www.wikidata.org/entity/Q844757'],
#  '01MBA5Y8 3 0': ['Ta Boötis', 'http://www.wikidata.org/entity/Q781947'],
#  '01MBA5Y8 4 0': ['Lambda Andromdae',
#   'http://www.wikidata.org/entity/Q749234'],
#  '01MBA5Y8 5 0': ['Gliesg 745', 'http://www.wikidata.org/entity/Q722242'],
#  '01MBA5Y8 6 0': ['Epsilon Aquiae', 'http://www.wikidata.org/entity/Q684292'],
#  '01MBA5Y8 7 0': ['Lalande 1185', 'http://www.wikidata.org/entity/Q683605'],
#  '01MBA5Y8 8 0': ['Mu Cassiopfiae', 'http://www.wikidata.org/entity/Q682966'],
#  '01MBA5Y8 9 0': ['Nu Eapriconi', 'http://www.wikidata.org/entity/Q676853'],
#  '01MBA5Y8 10 0': ['Eta Cdpricori', 'http://www.wikidata.org/entity/Q676232'],
#  '01MBA5Y8 11 0': ['Qmega Aurigae', 'http://www.wikidata.org/entity/Q633431'],
#  '01MBA5Y8 12 0': ['16 Bvrigae', 'http://www.wikidata.org/entity/Q608310'],
#  '01MBA5Y8 13 0': ['52 ygnj', 'http://www.wikidata.org/entity/Q603764'],
#  '01MBA5Y8 14 0': ['1 Ceti', 'http://www.wikidata.org/entity/Q541212'],
#  '01MBA5Y8 15 0': ['Tau2 Eridapi', 'http://www.wikidata.org/entity/Q538594'],
#  '01MBA5Y8 16 0': ['Zta Geminorum', 'http://www.wikidata.org/entity/Q502119'],
#  '01MBA5Y8 17 0': ['Delta raconis', 'http://www.wikidata.org/entity/Q434054'],
#  '01MBA5Y8 18 0': ['Lambda Auigae', 'http://www.wikidata.org/entity/Q426726'],
#  '01MBA5Y8 19 0': ['alg om A', 'http://www.wikidata.org/entity/Q66477220'],
#  '01MBA5Y8 20 0': ['H 1771', 'http://www.wikidata.org/entity/Q66477148'],
#  '01Q0EMNA 1 0': ['ice hockey at the 2013 Xinter Universiade',
#   'http://www.wikidata.org/entity/Q15295757'],
#  '01Q0EMNA 2 0': ['Ice hockey at the 2005!Winter Universiade',
#   'http://www.wikidata.org/entity/Q11709985'],
#  '01Q0EMNA 3 0': ['Ice hockey at the 2001 Wier Universiade',
#   'http://www.wikidata.org/entity/Q11709982'],
#  '01Q0EMNA 4 0': ['Ice hockey at the 1987 Winter Universade',
#   'http://www.wikidata.org/entity/Q11709981'],
#  '01Q0EMNA 5 0': ['Ice hockey at the 1983 WinterUniversiade',
#   'http://www.wikidata.org/entity/Q11709980'],
#  '01Q0EMNA 6 0': ['Ice hockey at vhe2003 Winter Uniwersiade',
#   'http://www.wikidata.org/entity/Q9293257'],
#  '01Q0EMNA 7 0': ['Ice hockey at the 199 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293256'],
#  '01Q0EMNA 8 0': ['Ice hockey at vhe 1997 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293255'],
#  '01Q0EMNA 9 0': ['Ice hockey at the 1995 Winter Unixersiade',
#   'http://www.wikidata.org/entity/Q9293254'],
#  '01Q0EMNA 10 0': ['Ice hockey at the 19;3 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293252'],
#  '01Q0EMNA 11 0': ['Ice hockey at the 1991 inter Universiade',
#   'http://www.wikidata.org/entity/Q9293251'],
#  '01Q0EMNA 12 0': ['Ice hocke at the 1989 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293249'],
#  '01Q0EMNA 13 0': ['Ice hockey at the 1985 Winte Universiade',
#   'http://www.wikidata.org/entity/Q9293246'],
#  '01Q0EMNA 14 0': ['Ice hockey at the 1981 Winter Univetsiade',
#   'http://www.wikidata.org/entity/Q9293244'],
#  '01Q0EMNA 15 0': ['Ice hokey at the 1972 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293242'],
#  '01Q0EMNA 16 0': ['Ice hockey at the 1970 Winter Uniersiade',
#   'http://www.wikidata.org/entity/Q9293240'],
#  '01Q0EMNA 17 0': ['Ice hockey!at the 1966 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293239'],
#  '01Q0EMNA 18 0': ['Ice hockey at the!1962 Winter Universiade',
#   'http://www.wikidata.org/entity/Q9293236'],
#  '01Q0EMNA 19 0': ['ich hockey at the 2011 Winter Universiade',
#   'http://www.wikidata.org/entity/Q2537592'],
#  '01Q0EMNA 20 0': ['Swimming at the 2017 Summer#Universiade',
#   'http://www.wikidata.org/entity/Q20687713'],
#  '01RLDR8E 1 0': ['Bone Creek Township, Butler County',
#   'http://www.wikidata.org/entity/Q7994881'],
#  '01RLDR8E 2 0': ['Crawford Township, Antelope County',
#   'http://www.wikidata.org/entity/Q7994866'],
#  '01RLDR8E 3 0': ['Highland Township, Gage County',
#   'http://www.wikidata.org/entity/Q7994856'],
#  '01RLDR8E 4 0': ['Willow Township, Antelope County',
#   'http://www.wikidata.org/entity/Q7994827'],
#  '01RLDR8E 5 0': ['Willowdale Township, Holt County',
#   'http://www.wikidata.org/entity/Q7994812'],
#  '01RLDR8E 6 0': ['Shamrock Township, Holt County',
#   'http://www.wikidata.org/entity/Q7994774'],
#  '01RLDR8E 7 0': ['Josie Township, Holt County',
#   'http://www.wikidata.org/entity/Q7994762'],
#  '01RLDR8E 8 0': ['Loup Township, Platte County',
#   'http://www.wikidata.org/entity/Q7994732'],
#  '01RLDR8E 9 0': ['Lowell Township, Kearney County',
#   'http://www.wikidata.org/entity/Q7994702'],
#  '01RLDR8E 10 0': ['Stanton Township, Antelope County',
#   'http://www.wikidata.org/entity/Q7994675'],
#  '01RLDR8E 11 0': ['Gibbon Township, Buffalo County',
#   'http://www.wikidata.org/entity/Q7994650'],
#  '01RLDR8E 12 0': ['Niobrara Township, Knox County',
#   'http://www.wikidata.org/entity/Q7994629'],
#  '01RLDR8E 13 0': ['Wyoming Township, Holt County',
#   'http://www.wikidata.org/entity/Q7994625'],
#  '01RLDR8E 14 0': ['Lewis Township',
#   'http://www.wikidata.org/entity/Q7994597'],
#  '01RLDR8E 15 0': ['Nickerson Township, Dodge County',
#   'http://www.wikidata.org/entity/Q7994582'],
#  '01RLDR8E 16 0': ['Eldorado Township',
#   'http://www.wikidata.org/entity/Q7994558'],
#  '01RLDR8E 17 0': ['Loup Ferry Township, Nance County',
#   'http://www.wikidata.org/entity/Q7994547'],
# ...
#  '02UB4AKG 8 0': ['Chiddingfold', 'http://www.wikidata.org/entity/Q1776354'],
#  '02UB4AKG 9 0': ['Cheddington', 'http://www.wikidata.org/entity/Q548588'],
#  '02UB4AKG 10 0': ['Dorchester', 'http://www.wikidata.org/entity/Q503331'],
#  '02UB4AKG 11 0': ['Falmouth', 'http://www.wikidata.org/entity/Q478029'],
#  '02UB4AKG 12 0': ['North Walsham', 'http://www.wikidata.org/entity/Q327168'],
#  '02UB4AKG 13 0': ['Abingdon-on-Thames',
#   'http://www.wikidata.org/entity/Q321381'],
#  '02UB4AKG 14 0': ['Lewes', 'http://www.wikidata.org/entity/Q246884'],
#  '02UB4AKG 15 0': ['Thetford', 'http://www.wikidata.org/entity/Q237250'],
#  '02UB4AKG 16 0': ['Aylesbury', 'http://www.wikidata.org/entity/Q213474'],
#  '02UB4AKG 17 0': ['Cromer', 'http://www.wikidata.org/entity/Q208296'],
#  '02UB4AKG 18 0': ['Chichester', 'http://www.wikidata.org/entity/Q207639'],
#  '02UB4AKG 19 0': ['Lichfield', 'http://www.wikidata.org/entity/Q207371'],
#  '02UB4AKG 20 0': ['Hereford', 'http://www.wikidata.org/entity/Q204720'],
#  '02UR28RM 1 0': ['1993 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794328'],
#  '02UR28RM 2 0': ['1992 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794327'],
#  '02UR28RM 3 0': ['1991 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794326'],
#  '02UR28RM 4 0': ['1990 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794325'],
#  '02UR28RM 5 0': ['1989 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794324'],
#  '02UR28RM 6 0': ['1988 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794323'],
#  '02UR28RM 7 0': ['1987 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794322'],
#  '02UR28RM 8 0': ['1986 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794321'],
#  '02UR28RM 9 0': ['1985 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794320'],
#  '02UR28RM 10 0': ['1984 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794319'],
#  '02UR28RM 11 0': ['1982 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794317'],
#  '02UR28RM 12 0': ['1981 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794316'],
#  '02UR28RM 13 0': ['1980 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794315'],
#  '02UR28RM 14 0': ['1979 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794313'],
#  '02UR28RM 15 0': ['1978 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794312'],
#  '02UR28RM 16 0': ['1977 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794311'],
#  '02UR28RM 17 0': ['1976 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794309'],
#  '02UR28RM 18 0': ['1974 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2794307'],
#  '02UR28RM 19 0': ['1973 Plume d’Or',
#   'http://www.wikidata.org/entity/Q2099682'],
#  '02UR28RM 20 0': ['1972 Middle European Badminton Championships',
#   'http://www.wikidata.org/entity/Q1940130'],
#  '02Y87OZW 1 0': ['FCMG', 'http://www.wikidata.org/entity/Q30431407'],
#  '02Y87OZW 2 0': ['Bronze Records',
#   'http://www.wikidata.org/entity/Q22674042'],
#  '02Y87OZW 3 0': ['No Remorse Records',
#   'http://www.wikidata.org/entity/Q50853082'],
#  '02Y87OZW 4 0': ['Telstar', 'http://www.wikidata.org/entity/Q20757880'],
#  '02Y87OZW 5 0': ['Tabu', 'http://www.wikidata.org/entity/Q12005038'],
#  '02Y87OZW 6 0': ['Guerilla Records',
#   'http://www.wikidata.org/entity/Q12018500'],
#  '02Y87OZW 7 0': ['Azzurra Music', 'http://www.wikidata.org/entity/Q13489316'],
#  '02Y87OZW 8 0': ['Loplop', 'http://www.wikidata.org/entity/Q13771186'],
#  '02Y87OZW 9 0': ['GM Recordings', 'http://www.wikidata.org/entity/Q15811180'],
#  '02Y87OZW 10 0': ['Rex Records', 'http://www.wikidata.org/entity/Q7319293'],
#  '02Y87OZW 11 0': ['Word', 'http://www.wikidata.org/entity/Q8034303'],
#  '02Y87OZW 12 0': ['Stunt Records', 'http://www.wikidata.org/entity/Q7628787'],
#  '02Y87OZW 13 0': ['Sun Records', 'http://www.wikidata.org/entity/Q7638467'],
#  '02Y87OZW 14 0': ['Swan', 'http://www.wikidata.org/entity/Q7653494'],
#  '02Y87OZW 15 0': ['Gramofon', 'http://www.wikidata.org/entity/Q5593921'],
#  '02Y87OZW 16 0': ['Eclipse Records',
#   'http://www.wikidata.org/entity/Q5333027'],
#  '02Y87OZW 17 0': ['Liberty Music Shop',
#   'http://www.wikidata.org/entity/Q6541888'],
#  '02Y87OZW 18 0': ['Harvest', 'http://www.wikidata.org/entity/Q1324712'],
#  '02Y87OZW 19 0': ['Charisma', 'http://www.wikidata.org/entity/Q1063242'],
#  '02Y87OZW 20 0': ['Vertigo', 'http://www.wikidata.org/entity/Q1330417'],
#  '02YQAF33 1 0': ['Umjindi Local Municipality',
#   'http://www.wikidata.org/entity/Q1894966'],
#  '02YQAF33 2 0': ['Mamusa Local Municipality',
#   'http://www.wikidata.org/entity/Q1888475'],
#  '02YQAF33 3 0': ['Lesedi Local Municipality',
#   'http://www.wikidata.org/entity/Q1820684'],
#  '02YQAF33 4 0': ['Lekwa-Teemane Local Municipality',
#   'http://www.wikidata.org/entity/Q1816588'],
#  '02YQAF33 5 0': ['ǁKhara Hais Local Municipality',
#   'http://www.wikidata.org/entity/Q1740579'],
#  '02YQAF33 6 0': ['Polokwane Local Municipality',
#   'http://www.wikidata.org/entity/Q1660415'],
#  '02YQAF33 7 0': ['Greater Tzaneen Local Municipality',
#   'http://www.wikidata.org/entity/Q1544454'],
#  '02YQAF33 8 0': ['Greater Taung Local Municipality',
#   'http://www.wikidata.org/entity/Q1544453'],
#  '02YQAF33 9 0': ['Greater Letaba Local Municipality',
#   'http://www.wikidata.org/entity/Q1544434'],
#  '02YQAF33 10 0': ['Greater Giyani Local Municipality',
#   'http://www.wikidata.org/entity/Q1544427'],
#  '02YQAF33 11 0': ['Huehuetla', 'http://www.wikidata.org/entity/Q3142191'],
#  '02YQAF33 12 0': ['Acajete Municipality',
#   'http://www.wikidata.org/entity/Q2984107'],
#  '02YQAF33 13 0': ['Concepción del Oro Municipality',
#   'http://www.wikidata.org/entity/Q1919318'],
#  '02YQAF33 14 0': ['Nyamitanga Division',
#   'http://www.wikidata.org/entity/Q22082402'],
#  '02YQAF33 15 0': ['Nakaloke', 'http://www.wikidata.org/entity/Q22082398'],
#  '02YQAF33 16 0': ['Masulita', 'http://www.wikidata.org/entity/Q22082390'],
#  '02YQAF33 17 0': ['Majanji', 'http://www.wikidata.org/entity/Q22082389'],
#  '02YQAF33 18 0': ['Fetakgomo Local Municipality',
#   'http://www.wikidata.org/entity/Q267665'],
#  '02YQAF33 19 0': ['Buch', 'http://www.wikidata.org/entity/Q531745'],
#  '02YQAF33 20 0': ['Mühlheim an der Donau',
#   'http://www.wikidata.org/entity/Q529127'],
#  '0338LZJ3 1 0': ['Beggars Banquet',
#   'http://www.wikidata.org/entity/Q62597113'],
#  '0338LZJ3 2 0': ['Aftermath', 'http://www.wikidata.org/entity/Q62579599'],
#  '0338LZJ3 3 0': ['Out of Our Heads',
#   'http://www.wikidata.org/entity/Q62579329'],
#  '0338LZJ3 4 0': ['Big Hits (High Tide and Green Grass)',
#   'http://www.wikidata.org/entity/Q62602485'],
#  '0338LZJ3 5 0': ['Hot Rocks 1964-1971',
#   'http://www.wikidata.org/entity/Q62607106'],
#  '0338LZJ3 6 0': ["Get Yer Ya-Ya's Out! –The Rolling Stones in Concert",
#   'http://www.wikidata.org/entity/Q62606624'],
#  '0338LZJ3 7 0': ['Big Hits (High Tide and Green Grass)',
#   'http://www.wikidata.org/entity/Q62589819'],
#  '0338LZJ3 8 0': ['With the Beatles',
#   'http://www.wikidata.org/entity/Q61044654'],
#  '0338LZJ3 9 0': ['Animal Magnetism',
#   'http://www.wikidata.org/entity/Q58001219'],
#  '0338LZJ3 10 0': ['Heritage : history of the nursing profession in Quebec from the Augustinians and Jeanne Mance to medicare',
#   'http://www.wikidata.org/entity/Q56967299'],
#  '0338LZJ3 11 0': ['Anne Murray', 'http://www.wikidata.org/entity/Q55887752'],
#  '0338LZJ3 12 0': ['The life and strange adventures of Robinson Crusoe, of York, mariner',
#   'http://www.wikidata.org/entity/Q56454017'],
#  '0338LZJ3 13 0': ['Biographical stories',
#   'http://www.wikidata.org/entity/Q55834222'],
#  '0338LZJ3 14 0': ['Little Daffydowndilly, and other stories',
#   'http://www.wikidata.org/entity/Q55589803'],
#  '0338LZJ3 15 0': ['Evangline', 'http://www.wikidata.org/entity/Q55759751'],
#  '0338LZJ3 16 0': ['Dictionary of painters and engravers, edition 1886-1889, volume 2',
#   'http://www.wikidata.org/entity/Q54008737'],
#  '0338LZJ3 17 0': ['Dictionary of painters and engravers, edition 1886-1889, volume 1',
#   'http://www.wikidata.org/entity/Q54008437'],
#  '0338LZJ3 18 0': ['A biographical and critical dictionary of painters and engravers, edition 1816, volume 2',
#   'http://www.wikidata.org/entity/Q54007452'],
#  '0338LZJ3 19 0': ['A biographical and critical dictionary of painters and engravers, edition 1816, volume 1',
#   'http://www.wikidata.org/entity/Q54007369'],
#  '0338LZJ3 20 0': ['The Little Clay Cart [Mṛcchakaṭika]',
#   'http://www.wikidata.org/entity/Q51135700'],
#  '036N38OE 1 0': ['ORSIS', 'http://www.wikidata.org/entity/Q23012349'],
#  '036N38OE 2 0': ['Saatva', 'http://www.wikidata.org/entity/Q21036758'],
#  '036N38OE 3 0': ['Khaadi', 'http://www.wikidata.org/entity/Q22031750'],
#  '036N38OE 4 0': ["Newk's Eatery", 'http://www.wikidata.org/entity/Q21070915'],
#  '036N38OE 5 0': ['ThreatTrack Security',
#   'http://www.wikidata.org/entity/Q24521047'],
#  '036N38OE 6 0': ['i-Space', 'http://www.wikidata.org/entity/Q56692271'],
#  '036N38OE 7 0': ['Bitmain', 'http://www.wikidata.org/entity/Q43177802'],
#  '036N38OE 8 0': ['Holzweiler', 'http://www.wikidata.org/entity/Q57901713'],
#  '036N38OE 9 0': ['Paul Fredrick', 'http://www.wikidata.org/entity/Q45038642'],
#  '036N38OE 10 0': ['gofanco', 'http://www.wikidata.org/entity/Q66357190'],
#  '036N38OE 11 0': ['Promecal', 'http://www.wikidata.org/entity/Q55401572'],
#  '036N38OE 12 0': ['Half Pints Brewing Company',
#   'http://www.wikidata.org/entity/Q5641743'],
#  '036N38OE 13 0': ['Lewis Machine and Tool Company',
#   'http://www.wikidata.org/entity/Q6536834'],
#  '036N38OE 14 0': ['DriveTime', 'http://www.wikidata.org/entity/Q5307879'],
#  '036N38OE 15 0': ['Morris Communications',
#   'http://www.wikidata.org/entity/Q6913653'],
#  '036N38OE 16 0': ['Blue Bottle Coffee Company',
#   'http://www.wikidata.org/entity/Q4928917'],
#  '036N38OE 17 0': ['Robert Stephenson and Company',
#   'http://www.wikidata.org/entity/Q2814117'],
#  '036N38OE 18 0': ['United Launch Alliance',
#   'http://www.wikidata.org/entity/Q1236833'],
#  '036N38OE 19 0': ['GSC Game World',
#   'http://www.wikidata.org/entity/Q1425861'],
#  '036N38OE 20 0': ['Koch Industries',
#   'http://www.wikidata.org/entity/Q1496384'],
#  '038PHBWK 1 0': ['Snacks, Smiles and Taste Preferences',
#   'http://www.wikidata.org/entity/Q63394752'],
#  '038PHBWK 2 0': ['Boston Outcomes of Autism in Toddlers Study',
#   'http://www.wikidata.org/entity/Q62817532'],
#  '038PHBWK 3 0': ['Cost-efficacy of Silver Diammine Fluoride in Erupting Molars',
#   'http://www.wikidata.org/entity/Q61956557'],
#  '038PHBWK 4 0': ['Comparison of Caries Arrested & Prevented Among SDF, NaF Varnish and Combination in Children',
#   'http://www.wikidata.org/entity/Q62811450'],
#  '038PHBWK 5 0': ['Intranasal Ketamine for Pediatric Procedural Sedation: a Feasibility Study',
#   'http://www.wikidata.org/entity/Q63229318'],
#  '038PHBWK 6 0': ['Early Intervention for Children at Risk for Anxiety',
#   'http://www.wikidata.org/entity/Q61981083'],
#  '038PHBWK 7 0': ['Efficacy of Hypnosis in Anxiety/Pain Reduction in Children During Pulpotomies',
#   'http://www.wikidata.org/entity/Q62035154'],
#  '038PHBWK 8 0': ['Effectiveness of a Physical Activity Intervention to Prevent Obesity and Improve Academic Performance',
#   'http://www.wikidata.org/entity/Q61975253'],
#  '038PHBWK 9 0': ['Effectiveness of MOVI Interventions on Adiposity, Cognition and Motor Competence: MOVI-da10!',
#   'http://www.wikidata.org/entity/Q63011257'],
#  '038PHBWK 10 0': ['Effectiveness of a Physical Activity Intervention on Preventing Obesity During the Adiposity Rebound Period.',
#   'http://www.wikidata.org/entity/Q61975252'],
#  '038PHBWK 11 0': ['Pediatric Pain Assessment in the Emergency Department',
#   'http://www.wikidata.org/entity/Q61909470'],
#  '038PHBWK 12 0': ['Building Social Skills With Interdisciplinary Process Drama in ASD',
#   'http://www.wikidata.org/entity/Q62814084'],
#  '038PHBWK 13 0': ['CLEARI (Clinical Efficacy Assessment on Recurrent Upper-Respiratory Tract Infections) Study',
#   'http://www.wikidata.org/entity/Q64354219'],
#  '038PHBWK 14 0': ['Emla-Cream as Pain Relief During Pneumococcal Vaccination',
#   'http://www.wikidata.org/entity/Q64185033'],
#  '038PHBWK 15 0': ['Erythropoietin Therapy for Children With Cerebral Palsy',
#   'http://www.wikidata.org/entity/Q63838890'],
#  '038PHBWK 16 0': ['Intensive Motor Training After Perinatal Stroke to Enhance Walking',
#   'http://www.wikidata.org/entity/Q63835462'],
#  '038PHBWK 17 0': ['Bone and Muscle Health in Kids',
#   'http://www.wikidata.org/entity/Q62813584'],
#  '038PHBWK 18 0': ['Safety, Immunogenicity, and Impact of MVA85A, on the Immunogenicity of the EPI Vaccines',
#   'http://www.wikidata.org/entity/Q65382099'],
#  '038PHBWK 19 0': ['Neurodevelopment Outcomes After Pediatric Dental Caries Treatment Under General Anaesthesia',
#   'http://www.wikidata.org/entity/Q66076953'],
#  '038PHBWK 20 0': ['A Nutritional Trial on Effect of L. Rhamnosus Yoba on RTI and Other Health Outcomes Among Children (3-6 Years) in Uganda',
#   'http://www.wikidata.org/entity/Q66064189'],
#  '03CIRSMN 1 0': ['Satara district',
#   'http://www.wikidata.org/entity/Q1135612'],
#  '03CIRSMN 2 0': ['Jaipur district',
#   'http://www.wikidata.org/entity/Q1134781'],
#  '03CIRSMN 3 0': ['Darjeeling district',
#   'http://www.wikidata.org/entity/Q1134759'],
#  '03CIRSMN 4 0': ['Samba district', 'http://www.wikidata.org/entity/Q1117086'],
#  '03CIRSMN 5 0': ['Churu district', 'http://www.wikidata.org/entity/Q1090006'],
#  '03CIRSMN 6 0': ['Chittorgarh district',
#   'http://www.wikidata.org/entity/Q1075011'],
#  '03CIRSMN 7 0': ['Chikkaballapura district',
#   'http://www.wikidata.org/entity/Q1072629'],
#  '03CIRSMN 8 0': ['Kutch district', 'http://www.wikidata.org/entity/Q1063417'],
#  '03CIRSMN 9 0': ['Chamba district',
#   'http://www.wikidata.org/entity/Q1060614'],
#  '03CIRSMN 10 0': ['Malappuram district',
#   'http://www.wikidata.org/entity/Q1030918'],
#  '03CIRSMN 11 0': ['Kota district', 'http://www.wikidata.org/entity/Q999432'],
#  '03CIRSMN 12 0': ['Puducherry district',
#   'http://www.wikidata.org/entity/Q984035'],
#  '03CIRSMN 13 0': ['Wardha district',
#   'http://www.wikidata.org/entity/Q980608'],
#  '03CIRSMN 14 0': ['Kurukshetra district',
#   'http://www.wikidata.org/entity/Q980118'],
#  '03CIRSMN 15 0': ['Jagatsinghpur district',
#   'http://www.wikidata.org/entity/Q971581'],
#  '03CIRSMN 16 0': ['Rohtak district',
#   'http://www.wikidata.org/entity/Q967388'],
#  '03CIRSMN 17 0': ['Hassan District',
#   'http://www.wikidata.org/entity/Q956732'],
#  '03CIRSMN 18 0': ['Koppal district',
#   'http://www.wikidata.org/entity/Q956387'],
#  '03CIRSMN 19 0': ['Kohima district',
#   'http://www.wikidata.org/entity/Q953530'],
#  '03CIRSMN 20 0': ['Dakshina Kannada district',
#   'http://www.wikidata.org/entity/Q950571'],
#  '03G17LQ1 1 0': ['Sredny, Irkutsk Oblast',
#   'http://www.wikidata.org/entity/Q952821'],
#  '03G17LQ1 2 0': ['Khrebtovaya', 'http://www.wikidata.org/entity/Q951840'],
#  '03G17LQ1 3 0': ['Ordynskoye', 'http://www.wikidata.org/entity/Q951185'],
#  '03G17LQ1 4 0': ['Maslyanino', 'http://www.wikidata.org/entity/Q939769'],
#  '03G17LQ1 5 0': ['Krasnozërskoye', 'http://www.wikidata.org/entity/Q919091'],
#  '03G17LQ1 6 0': ['Suzun', 'http://www.wikidata.org/entity/Q916728'],
#  '03G17LQ1 7 0': ['Kochenёvo', 'http://www.wikidata.org/entity/Q916706'],
#  '03G17LQ1 8 0': ['Magdagachi', 'http://www.wikidata.org/entity/Q912758'],
#  '03G17LQ1 9 0': ['Novy Urgal', 'http://www.wikidata.org/entity/Q910948'],
#  '03G17LQ1 10 0': ['Novaya Igirma', 'http://www.wikidata.org/entity/Q909074'],
#  '03G17LQ1 11 0': ['Kuytun, Kuytunsky District, Irkutsk Oblast',
#   'http://www.wikidata.org/entity/Q905575'],
#  '03G17LQ1 12 0': ['Ardatov, Nizhny Novgorod Oblast',
#   'http://www.wikidata.org/entity/Q905459'],
#  '03G17LQ1 13 0': ['Blagoveshchenka',
#   'http://www.wikidata.org/entity/Q881088'],
#  '03G17LQ1 14 0': ['Chany', 'http://www.wikidata.org/entity/Q821906'],
#  '03G17LQ1 15 0': ['Beloyarsky', 'http://www.wikidata.org/entity/Q816132'],
#  '03G17LQ1 16 0': ['Bazarnyy Karabulak',
#   'http://www.wikidata.org/entity/Q809783'],
#  '03G17LQ1 17 0': ['Byarozawka', 'http://www.wikidata.org/entity/Q799939'],
#  '03G17LQ1 18 0': ['Bely Yar', 'http://www.wikidata.org/entity/Q746483'],
#  '03G17LQ1 19 0': ['Arti', 'http://www.wikidata.org/entity/Q712334'],
#  ...}

# %%
from collections import Counter

category_counts = Counter(ner_type.values())

# Display the counts for each category
for category, count in category_counts.items():
    print(f'{category}: {count}')
# Out:
# OTHERS: 11544
# PERS: 1607
# ORG: 236
# LOC: 193

# %%
sample_size = 10000
key_to_cell_sample = dict(random.sample(list(key_to_cell.items()), sample_size))

# %%
import aiohttp
import backoff
import asyncio
import re
import pandas as pd
from collections import Counter
from tqdm.asyncio import tqdm

rows = []

url = 'https://lamapi.hel.sintef.cloud/entity/labels?token=lamapi_demo_2023'

headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

# Define the async function to fetch data with retries
@backoff.on_exception(
    backoff.expo, 
    (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError, asyncio.TimeoutError), 
    max_tries=5, 
    max_time=300
)
async def fetch_data(session, url, data):
    async with session.post(url, headers=headers, json=data) as response:
        # Check the content type of the response
        content_type = response.headers.get('Content-Type', '').lower()
        
        if 'application/json' not in content_type:
            print(f"Unexpected content type: {content_type}. URL: {url}")
            return None
        
        return await response.json()

# Main async function to process mentions
async def process_mentions():
    async with aiohttp.ClientSession() as session:
        for key, (text, id) in tqdm(key_to_cell_sample.items(), desc='Processing mentions', unit='item'):
            match = re.search(r'Q(\d+)$', id)
            
            if not match:
                continue
            
            data = {'json': [match[0]]}

            try:
                response_json = await fetch_data(session, url, data)
                
                if response_json is None or len(response_json) == 0:
                    continue

                
                desc = response_json[match[0]]['description']
                if desc == None:
                    continue
            
                label = response_json[match[0]]['NERtype']
                new_row = {'text': text, 'label': label, 'desc': desc}

                rows.append(new_row)
            except KeyError:
                continue

# Run the async function
await (process_mentions())

# Create DataFrame from the list of rows
df = pd.DataFrame(rows)
category_counts = Counter(df['label'])

# Display the counts for each category
for category, count in category_counts.items():
    print(f'{category}: {count}')
    
#df.to_csv('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/embedding_training_data/Round3_train.csv', index=False)
# Out:
# Processing mentions: 100%|██████████| 10000/10000 [06:56<00:00, 23.99item/s]
# LOC: 3182
# ORG: 718
# OTHERS: 4530
# PERS: 14

# %%
df.to_csv('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/embedding_training_data/HT2_train.csv', index=False)

# %%
sample_size = 4000
key_to_cell_sample = dict(random.sample(list(key_to_cell.items()), sample_size))

# %%
def get_query(name, value):
    name = str(name).replace('"', ' ')
    if value is not None:
        # Soft filtering constraint
        query_dict = {
            "query": {
                "bool": {
                    "must": [
                        {"match": {"name": {"query": name, "boost": 2.0}}}
                    ],
                    "should": [
                        {"term": {"NERtype": value}}
                    ]
                }
            }
        }
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query': json.dumps(query_dict),  # Convert the query dictionary to a JSON string
            'sort': [
                '{"popularity": {"order": "desc"}}'
            ]
        }
    
    return params

url = 'https://lamapi.hel.sintef.cloud/entity/labels?token=lamapi_demo_2023'

# Define the headers
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

queries = []
for key in tqdm(key_to_cell_sample):
    id_table, _, id_col = key.split(" ")
    name = key_to_cell[key][0]
    q_ids = key_to_cell[key][1].split(' ')
    new_key = f"{id_table} {id_col}"
    if new_key in ner_type:
        NER_type = ner_type[new_key]
        query = get_query(name, NER_type)
        
        matched_results = []
        for q_id in q_ids:            
            match = re.search(r'Q(\d+)$', q_id)
            if not match:
                continue
            data = {
                'json': [match[0]]
            }

            json_data = json.dumps(data)
            response = requests.post(url, headers=headers, data=json_data)
            if len(response.json()) == 0:
                continue
            
            true_ner = response.json()[match[0]]['NERtype']
            break

        if match:
            data = json.loads(query['query'])
            ner_type_list = data['query']['bool']['should'][0]['term']['NERtype']
            # ner_type_list is the ner column
            queries.append((query, match[0],ner_type_list, true_ner))
# Out:
# 100%|██████████| 4000/4000 [14:56<00:00,  4.46it/s]

# %%
key_to_cell_sample = {key: value for key, value in key_to_cell.items() if value[1].split('/')[-1] in missing_values}
# just for 2T missing values comparison

# %%
def get_query(name, value):
    name = str(name).replace('"', ' ')

    if value is not None:
        # Hard filtering constraint
        query_dict = {
            "query": {
                "bool": {
                    "must": [
                        {"match": {"name": {"query": name, "boost": 2.0}}},
                        {"term": {"NERtype": value}}
                    ]
                }
            }
        }
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query': json.dumps(query_dict),  # Convert the query dictionary to a JSON string
            'sort': [
                '{"popularity": {"order": "desc"}}'
            ]
        }    

    return params

url = 'https://lamapi.hel.sintef.cloud/entity/labels?token=lamapi_demo_2023'

# Define the headers
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

queries = []
for key in tqdm(key_to_cell_sample):
    id_table, _, id_col = key.split(" ")
    name = key_to_cell[key][0]
    q_ids = key_to_cell[key][1].split(' ')
    new_key = f"{id_table} {id_col}"
    if new_key in ner_type:
        NER_type = ner_type[new_key]
        if NER_type is None:
            print(f"q_ids: {q_ids}, ner_type key: {new_key}")
        query = get_query(name, NER_type)
        
        matched_results = []
        for q_id in q_ids:
            match = re.search(r'Q(\d+)$', q_id)
            if not match:
                continue
            data = {
                'json': [match[0]]
            }

            json_data = json.dumps(data)
            response = requests.post(url, headers=headers, data=json_data)
            if len(response.json()) == 0:
                continue
            
            true_ner = response.json()[match[0]]['NERtype']
            break

        if match:
            data = json.loads(query['query'])
            ner_type_list = data['query']['bool']['must'][1]['term']['NERtype']
            # ner_type_list is the ner column
            queries.append((query, match[0],ner_type_list,true_ner))
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]
# 100%|██████████| 4000/4000 [12:51<00:00,  5.18it/s]

# %%
import aiohttp
import asyncio
import backoff
import nest_asyncio
import random
from tqdm import tqdm
import numpy as np

# Assume queries is a list of tuples [(param1, id1), (param2, id2), ...]

failed_queries = {}
url = 'https://lamapi.hel.sintef.cloud/lookup/entity-retrieval'

# Backoff decorator for handling retries with exponential backoff
@backoff.on_exception(
    backoff.expo, 
    (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError, asyncio.TimeoutError), 
    max_tries=10, 
    max_time=400
)
async def fetch(session, url, params, headers, semaphore):
    async with semaphore:
        # Convert all params to str, int, or float
        #params = {k: (int(v) if isinstance(v, np.integer) else str(v)) for k, v in params.items()}
        async with session.get(url, params=params, headers=headers, timeout=50) as response:
            try:
                response.raise_for_status()  # Raises an exception for 4XX/5XX status codes
                return await response.json()
            except Exception as e:
                return []

async def process_item(session, url, id, headers, params, semaphore, pbar):
    try:
        data = await fetch(session, url, params, headers, semaphore)
    except aiohttp.ClientResponseError as e:
        if e.status == 404:
            print(f"404 Error: Resource not found for '{id}'")
            asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
            return 0, 0
        else:
            raise  # Re-raise the exception for other status codes

    num_result = len(data) if data else 0

    if data:
        for item in data:
            if id == item.get('id'):
                asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
                pos_score = item.get('pos_score', 0)
                if pos_score:
                    mrr_increment = (num_result - (pos_score * num_result)) / num_result
                else:
                    mrr_increment = 1 / num_result  # Assume worst case for MRR if pos_score is 0
                return mrr_increment, 1

    return 0, 0

async def main(queries, url, pbar, failed_queries):
    headers = {'accept': 'application/json'}
    semaphore = asyncio.Semaphore(50)  # Limit to 50 concurrent requests
    m_mrr = 0
    cont_el = 0

    async with aiohttp.ClientSession() as session:
        tasks = []
        for param, id, _, _ in queries:
            tasks.append(process_item(session, url, id, headers, param, semaphore, pbar))
        
        results = await asyncio.gather(*tasks)
        
        for (mrr_increment, count), (param, id, col_NERtype, item_NERtype) in zip(results, queries):
            if mrr_increment == 0 and count == 0:
                failed_queries[id] = (col_NERtype, item_NERtype)
            else:
                m_mrr += mrr_increment
                cont_el += count

        asyncio.get_event_loop().call_soon_threadsafe(pbar.close)

    print(f"Coverage of 2T: {cont_el / len(queries)}")
    print(f"Measure Reciprocal Rank of 2T: {m_mrr / len(queries)}")

# Check if there's already a running event loop
if __name__ == "__main__":
    nest_asyncio.apply()  # Apply nest_asyncio
    try:
        pbar = tqdm(total=len(queries))
        asyncio.run(main(queries, url, pbar, failed_queries))
    except RuntimeError:  # For environments like Jupyter
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(queries, url, pbar, failed_queries))
# Out:
#  87%|████████▋ | 3471/4000 [10:51<01:39,  5.33it/s]
# Coverage of 2T: 0.86775
# Measure Reciprocal Rank of 2T: 0.7705927499999742

# %%
failed_queries
# Out:
# {'Q92035299': ('OTHERS', 'OTHERS'),
#  'Q588428': ('LOC', 'LOC'),
#  'Q491254': ('LOC', 'LOC'),
#  'Q102152': ('LOC', 'LOC'),
#  'Q1868889': ('OTHERS', 'LOC'),
#  'Q93882334': ('OTHERS', 'OTHERS'),
#  'Q166883': ('ORG', 'ORG'),
#  'Q37066': ('OTHERS', 'LOC'),
#  'Q95514514': ('OTHERS', 'OTHERS'),
#  'Q18969067': ('OTHERS', 'OTHERS'),
#  'Q102346': ('LOC', 'LOC'),
#  'Q60497': ('OTHERS', 'ORG'),
#  'Q49963127': ('LOC', 'ORG'),
#  'Q176937': ('LOC', 'LOC'),
#  'Q75698977': ('LOC', 'LOC'),
#  'Q18845544': ('OTHERS', 'LOC'),
#  'Q7250167': ('OTHERS', 'OTHERS'),
#  'Q57033722': ('OTHERS', 'OTHERS'),
#  'Q2591428': ('OTHERS', 'OTHERS'),
#  'Q658909': ('OTHERS', 'ORG'),
#  'Q923603': ('OTHERS', 'LOC'),
#  'Q100067': ('LOC', 'LOC'),
#  'Q26785888': ('OTHERS', 'LOC'),
#  'Q771404': ('LOC', 'OTHERS'),
#  'Q75699443': ('LOC', 'LOC'),
#  'Q105044618': ('OTHERS', 'OTHERS'),
#  'Q56046025': ('LOC', 'OTHERS'),
#  'Q2881469': ('OTHERS', 'LOC'),
#  'Q18346875': ('OTHERS', 'OTHERS'),
#  'Q2466739': ('OTHERS', 'OTHERS'),
#  'Q41319542': ('OTHERS', 'OTHERS'),
#  'Q1955097': ('OTHERS', 'OTHERS'),
#  'Q1353876': ('LOC', 'LOC'),
#  'Q645222': ('OTHERS', 'LOC'),
#  'Q2938835': ('LOC', 'LOC'),
#  'Q101425976': ('OTHERS', 'OTHERS'),
#  'Q60786681': ('OTHERS', 'OTHERS'),
#  'Q75699417': ('LOC', 'LOC'),
#  'Q91330715': ('OTHERS', 'OTHERS'),
#  'Q57032956': ('OTHERS', 'OTHERS'),
#  'Q60247710': ('OTHERS', 'OTHERS'),
#  'Q201355': ('LOC', 'LOC'),
#  'Q14544537': ('OTHERS', 'LOC'),
#  'Q82230': ('OTHERS', 'LOC'),
#  'Q1803084': ('LOC', 'LOC'),
#  'Q1956685': ('OTHERS', 'OTHERS'),
#  'Q264378': ('LOC', 'LOC'),
#  'Q18845592': ('OTHERS', 'OTHERS'),
#  'Q1323908': ('OTHERS', 'LOC'),
#  'Q1205685': ('ORG', 'LOC'),
#  'Q57988393': ('OTHERS', 'OTHERS'),
#  'Q15735753': ('LOC', 'LOC'),
#  'Q12054374': ('LOC', 'LOC'),
#  'Q6669136': ('LOC', 'LOC'),
#  'Q100491044': ('LOC', 'OTHERS'),
#  'Q15253314': ('OTHERS', 'LOC'),
#  'Q2046091': ('ORG', 'LOC'),
#  'Q5715907': ('ORG', 'OTHERS'),
#  'Q18882668': ('OTHERS', 'OTHERS'),
#  'Q409772': ('OTHERS', 'OTHERS'),
#  'Q1272037': ('OTHERS', 'OTHERS'),
#  'Q4638180': ('OTHERS', 'LOC'),
#  'Q47424': ('LOC', 'OTHERS'),
#  'Q91471872': ('OTHERS', 'OTHERS'),
#  'Q86157013': ('OTHERS', 'OTHERS'),
#  'Q1103875': ('OTHERS', 'OTHERS'),
#  'Q59325272': ('OTHERS', 'OTHERS'),
#  'Q80430148': ('OTHERS', 'OTHERS'),
#  'Q497687': ('OTHERS', 'OTHERS'),
#  'Q21038691': ('OTHERS', 'LOC'),
#  'Q9001773': ('OTHERS', 'OTHERS'),
#  'Q1993247': ('LOC', 'LOC'),
#  'Q76759830': ('OTHERS', 'OTHERS'),
#  'Q26789137': ('OTHERS', 'LOC'),
#  'Q81499119': ('OTHERS', 'OTHERS'),
#  'Q91511110': ('OTHERS', 'OTHERS'),
#  'Q1345553': ('OTHERS', 'OTHERS'),
#  'Q163880': ('LOC', 'LOC'),
#  'Q5328216': ('LOC', 'LOC'),
#  'Q1800707': ('LOC', 'LOC'),
#  'Q60366712': ('OTHERS', 'OTHERS'),
#  'Q29020372': ('OTHERS', 'OTHERS'),
#  'Q2823425': ('LOC', 'LOC'),
#  'Q2908304': ('LOC', 'LOC'),
#  'Q4275966': ('LOC', 'LOC'),
#  'Q2543569': ('OTHERS', 'OTHERS'),
#  'Q2935941': ('LOC', 'LOC'),
#  'Q1862339': ('OTHERS', 'OTHERS'),
#  'Q5644179': ('LOC', 'LOC'),
#  'Q181276': ('LOC', 'LOC'),
#  'Q4121295': ('OTHERS', 'LOC'),
#  'Q80233193': ('OTHERS', 'OTHERS'),
#  'Q104914792': ('OTHERS', 'ORG'),
#  'Q47489645': ('ORG', 'LOC'),
#  'Q2637224': ('OTHERS', 'OTHERS'),
#  'Q4561993': ('OTHERS', 'OTHERS'),
#  'Q506234': ('LOC', 'OTHERS'),
#  'Q77630755': ('OTHERS', 'OTHERS'),
#  'Q1697761': ('OTHERS', 'OTHERS'),
#  'Q28120250': ('OTHERS', 'OTHERS'),
#  'Q101066900': ('OTHERS', 'OTHERS'),
#  'Q495595': ('LOC', 'LOC'),
#  'Q60195569': ('LOC', 'OTHERS'),
#  'Q17747400': ('OTHERS', 'OTHERS'),
#  'Q18844306': ('OTHERS', 'OTHERS'),
#  'Q4217616': ('OTHERS', 'LOC'),
#  'Q17999': ('OTHERS', 'OTHERS'),
#  'Q729801': ('LOC', 'LOC'),
#  'Q324601': ('OTHERS', 'OTHERS'),
#  'Q17073228': ('ORG', 'OTHERS'),
#  'Q41319495': ('OTHERS', 'OTHERS'),
#  'Q18010': ('OTHERS', 'OTHERS'),
#  'Q1428119': ('ORG', 'ORG'),
#  'Q2537806': ('OTHERS', 'OTHERS'),
#  'Q254692': ('LOC', 'LOC'),
#  'Q18844316': ('OTHERS', 'OTHERS'),
#  'Q156291': ('LOC', 'LOC'),
#  'Q16695734': ('ORG', 'LOC'),
#  'Q483695': ('ORG', 'ORG'),
#  'Q958359': ('LOC', 'LOC'),
#  'Q41319527': ('OTHERS', 'OTHERS'),
#  'Q3686918': ('OTHERS', 'OTHERS'),
#  'Q7846596': ('LOC', 'LOC'),
#  'Q20964114': ('OTHERS', 'ORG'),
#  'Q12328167': ('LOC', 'ORG'),
#  'Q86354019': ('OTHERS', 'OTHERS'),
#  'Q67205162': ('OTHERS', 'LOC'),
#  'Q1050015': ('LOC', 'LOC'),
#  'Q83260510': ('OTHERS', 'OTHERS'),
#  'Q2620426': ('LOC', 'OTHERS'),
#  'Q660219': ('LOC', 'LOC'),
#  'Q165955': ('ORG', 'LOC'),
#  'Q164583': ('ORG', 'LOC'),
#  'Q72980901': ('OTHERS', 'LOC'),
#  'Q97015150': ('OTHERS', 'LOC'),
#  'Q5958': ('ORG', 'LOC'),
#  'Q2343129': ('OTHERS', 'LOC'),
#  'Q28120251': ('OTHERS', 'OTHERS'),
#  'Q23648294': ('LOC', 'LOC'),
#  'Q75699324': ('LOC', 'LOC'),
#  'Q18882077': ('OTHERS', 'OTHERS'),
#  'Q64367509': ('OTHERS', 'LOC'),
#  'Q1890759': ('OTHERS', 'OTHERS'),
#  'Q18881679': ('OTHERS', 'OTHERS'),
#  'Q4877527': ('LOC', 'LOC'),
#  'Q18881968': ('OTHERS', 'OTHERS'),
#  'Q56477541': ('ORG', 'LOC'),
#  'Q3365263': ('OTHERS', 'ORG'),
#  'Q2773268': ('OTHERS', 'LOC'),
#  'Q98741335': ('ORG', 'LOC'),
#  'Q103920691': ('OTHERS', 'OTHERS'),
#  'Q98768727': ('LOC', 'OTHERS'),
#  'Q13626305': ('OTHERS', 'OTHERS'),
#  'Q4341834': ('LOC', 'LOC'),
#  'Q89352666': ('OTHERS', 'OTHERS'),
#  'Q5037620': ('LOC', 'LOC'),
#  'Q97627056': ('OTHERS', 'LOC'),
#  'Q18845530': ('OTHERS', 'OTHERS'),
#  'Q74711020': ('OTHERS', 'OTHERS'),
#  'Q89661951': ('OTHERS', 'OTHERS'),
#  'Q20935731': ('LOC', 'LOC'),
#  'Q59311286': ('OTHERS', 'OTHERS'),
#  'Q3131006': ('OTHERS', 'OTHERS'),
#  'Q89167284': ('OTHERS', 'OTHERS'),
#  'Q2981963': ('LOC', 'LOC'),
#  'Q27948884': ('LOC', 'LOC'),
#  'Q424915': ('OTHERS', 'OTHERS'),
#  'Q913413': ('OTHERS', 'LOC'),
#  'Q83740338': ('OTHERS', 'OTHERS'),
#  'Q59311562': ('OTHERS', 'OTHERS'),
#  'Q10354880': ('OTHERS', 'LOC'),
#  'Q2487804': ('LOC', 'OTHERS'),
#  'Q79220': ('LOC', 'OTHERS'),
#  'Q139179': ('LOC', 'LOC'),
#  'Q18882638': ('OTHERS', 'OTHERS'),
#  'Q78808244': ('OTHERS', 'OTHERS'),
#  'Q520588': ('OTHERS', 'LOC'),
#  'Q688959': ('LOC', 'LOC'),
#  'Q65771919': ('OTHERS', 'LOC'),
#  'Q4476336': ('LOC', 'LOC'),
#  'Q17747402': ('OTHERS', 'OTHERS'),
#  'Q1204017': ('ORG', 'LOC'),
#  'Q17706': ('OTHERS', 'OTHERS'),
#  'Q2739939': ('LOC', 'ORG'),
#  'Q60247313': ('OTHERS', 'OTHERS'),
#  'Q10433074': ('LOC', 'LOC'),
#  'Q102521': ('LOC', 'LOC'),
#  'Q89575559': ('OTHERS', 'OTHERS'),
#  'Q200634': ('LOC', 'LOC'),
#  'Q18844304': ('OTHERS', 'OTHERS'),
#  'Q907980': ('OTHERS', 'LOC'),
#  'Q1524704': ('LOC', 'LOC'),
#  'Q467864': ('LOC', 'ORG'),
#  'Q511135': ('LOC', 'LOC'),
#  'Q2723772': ('ORG', 'LOC'),
#  'Q2392876': ('LOC', 'LOC'),
#  'Q14024': ('OTHERS', 'ORG'),
#  'Q326345': ('ORG', 'LOC'),
#  'Q571771': ('OTHERS', 'LOC'),
#  'Q12037096': ('LOC', 'LOC'),
#  'Q77409421': ('OTHERS', 'OTHERS'),
#  'Q18881689': ('OTHERS', 'OTHERS'),
#  'Q74516501': ('LOC', 'LOC'),
#  'Q76706966': ('OTHERS', 'OTHERS'),
#  'Q2722598': ('OTHERS', 'OTHERS'),
#  'Q210396': ('LOC', 'LOC'),
#  'Q908640': ('OTHERS', 'LOC'),
#  'Q60237022': ('OTHERS', 'OTHERS'),
#  'Q75699321': ('LOC', 'LOC'),
#  'Q704128': ('OTHERS', 'LOC'),
#  'Q5781734': ('OTHERS', 'LOC'),
#  'Q6933160': ('LOC', 'LOC'),
#  'Q2542931': ('LOC', 'LOC'),
#  'Q49781973': ('OTHERS', 'OTHERS'),
#  'Q1116829': ('LOC', 'LOC'),
#  'Q18882604': ('OTHERS', 'OTHERS'),
#  'Q1569875': ('OTHERS', 'LOC'),
#  'Q12556': ('LOC', 'LOC'),
#  'Q630822': ('OTHERS', 'LOC'),
#  'Q2577739': ('OTHERS', 'OTHERS'),
#  'Q494703': ('ORG', 'ORG'),
#  'Q1722060': ('LOC', 'LOC'),
#  'Q39042': ('OTHERS', 'LOC'),
#  'Q11940399': ('LOC', 'OTHERS'),
#  'Q44712328': ('LOC', 'OTHERS'),
#  'Q86157021': ('OTHERS', 'OTHERS'),
#  'Q2982354': ('OTHERS', 'LOC'),
#  'Q164600': ('ORG', 'LOC'),
#  'Q74651897': ('OTHERS', 'OTHERS'),
#  'Q1057925': ('OTHERS', 'LOC'),
#  'Q416393': ('OTHERS', 'OTHERS'),
#  'Q105231773': ('ORG', 'OTHERS'),
#  'Q60247288': ('OTHERS', 'OTHERS'),
#  'Q172421': ('OTHERS', 'ORG'),
#  'Q6298722': ('LOC', 'LOC'),
#  'Q77409447': ('OTHERS', 'OTHERS'),
#  'Q444199': ('OTHERS', 'LOC'),
#  'Q1569781': ('OTHERS', 'LOC'),
#  'Q279292': ('OTHERS', 'OTHERS'),
#  'Q164577': ('ORG', 'LOC'),
#  'Q689304': ('LOC', 'LOC'),
#  'Q2741596': ('LOC', 'LOC'),
#  'Q1502151': ('ORG', 'ORG'),
#  'Q100717819': ('LOC', 'OTHERS'),
#  'Q2909570': ('LOC', 'LOC'),
#  'Q1204975': ('ORG', 'LOC'),
#  'Q2371326': ('OTHERS', 'LOC'),
#  'Q3373817': ('OTHERS', 'LOC'),
#  'Q1878279': ('OTHERS', 'OTHERS'),
#  'Q18614187': ('OTHERS', 'OTHERS'),
#  'Q31334': ('LOC', 'LOC'),
#  'Q997087': ('LOC', 'LOC'),
#  'Q2276130': ('OTHERS', 'OTHERS'),
#  'Q11360594': ('ORG', 'LOC'),
#  'Q99613033': ('LOC', 'OTHERS'),
#  'Q1546087': ('LOC', 'OTHERS'),
#  'Q22692489': ('OTHERS', 'OTHERS'),
#  'Q65771958': ('OTHERS', 'LOC'),
#  'Q1047646': ('OTHERS', 'OTHERS'),
#  'Q19725078': ('OTHERS', 'OTHERS'),
#  'Q482687': ('ORG', 'ORG'),
#  'Q92937692': ('OTHERS', 'OTHERS'),
#  'Q4055226': ('ORG', 'LOC'),
#  'Q911885': ('LOC', 'OTHERS'),
#  'Q41319546': ('OTHERS', 'OTHERS'),
#  'Q22402198': ('LOC', 'LOC'),
#  'Q52902': ('LOC', 'LOC'),
#  'Q7986753': ('OTHERS', 'LOC'),
#  'Q92820368': ('OTHERS', 'OTHERS'),
#  'Q3361928': ('LOC', 'LOC'),
#  'Q6549276': ('LOC', 'LOC'),
#  'Q21566280': ('LOC', 'LOC'),
#  'Q6471594': ('LOC', 'LOC'),
#  'Q43713': ('LOC', 'LOC'),
#  'Q5092553': ('LOC', 'LOC'),
#  'Q671288': ('OTHERS', 'LOC'),
#  'Q14346046': ('OTHERS', 'OTHERS'),
#  'Q2086995': ('OTHERS', 'OTHERS'),
#  'Q86157010': ('OTHERS', 'OTHERS'),
#  'Q3231617': ('OTHERS', 'OTHERS'),
#  'Q15709560': ('OTHERS', 'OTHERS'),
#  'Q78244925': ('OTHERS', 'OTHERS'),
#  'Q75698976': ('LOC', 'LOC'),
#  'Q15814024': ('LOC', 'LOC'),
#  'Q896962': ('LOC', 'LOC'),
#  'Q23505249': ('LOC', 'LOC'),
#  'Q1204965': ('ORG', 'LOC'),
#  'Q64575076': ('ORG', 'OTHERS'),
#  'Q89692143': ('ORG', 'OTHERS'),
#  'Q12067876': ('OTHERS', 'OTHERS'),
#  'Q26784364': ('OTHERS', 'LOC'),
#  'Q267144': ('OTHERS', 'LOC'),
#  'Q95977918': ('OTHERS', 'LOC'),
#  'Q86191914': ('OTHERS', 'OTHERS'),
#  'Q17602912': ('OTHERS', 'OTHERS'),
#  'Q92034456': ('OTHERS', 'OTHERS'),
#  'Q76057961': ('OTHERS', 'OTHERS'),
#  'Q1060214': ('LOC', 'LOC'),
#  'Q90078116': ('OTHERS', 'OTHERS'),
#  'Q23001760': ('OTHERS', 'LOC'),
#  'Q104923485': ('OTHERS', 'OTHERS'),
#  'Q56069150': ('LOC', 'LOC'),
#  'Q541477': ('ORG', 'OTHERS'),
#  'Q649968': ('OTHERS', 'LOC'),
#  'Q3232645': ('OTHERS', 'OTHERS'),
#  'Q2395542': ('LOC', 'LOC'),
#  'Q883810': ('OTHERS', 'LOC'),
#  'Q83891': ('LOC', 'OTHERS'),
#  'Q90884543': ('OTHERS', 'OTHERS'),
#  'Q274990': ('LOC', 'LOC'),
#  'Q26784394': ('OTHERS', 'LOC'),
#  'Q692402': ('ORG', 'ORG'),
#  'Q597746': ('OTHERS', 'OTHERS'),
#  'Q18845535': ('OTHERS', 'OTHERS'),
#  'Q729971': ('OTHERS', 'OTHERS'),
#  'Q38167592': ('OTHERS', 'LOC'),
#  'Q1754227': ('LOC', 'LOC'),
#  'Q17747399': ('OTHERS', 'OTHERS'),
#  'Q585026': ('LOC', 'LOC'),
#  'Q26786541': ('OTHERS', 'LOC'),
#  'Q80018208': ('OTHERS', 'OTHERS'),
#  'Q2109356': ('ORG', 'LOC'),
#  'Q3818174': ('LOC', 'LOC'),
#  'Q26786900': ('OTHERS', 'LOC'),
#  'Q1779859': ('OTHERS', 'LOC'),
#  'Q668323': ('LOC', 'LOC'),
#  'Q62868': ('LOC', 'LOC'),
#  'Q4348652': ('OTHERS', 'OTHERS'),
#  'Q617779': ('LOC', 'LOC'),
#  'Q78241885': ('OTHERS', 'OTHERS'),
#  'Q680789': ('LOC', 'LOC'),
#  'Q32049814': ('ORG', 'ORG'),
#  'Q31487': ('LOC', 'LOC'),
#  'Q842941': ('ORG', 'ORG'),
#  'Q1770822': ('OTHERS', 'OTHERS'),
#  'Q1620303': ('LOC', 'LOC'),
#  'Q41319505': ('OTHERS', 'OTHERS'),
#  'Q5052165': ('LOC', 'LOC'),
#  'Q373879': ('OTHERS', 'OTHERS'),
#  'Q1448378': ('ORG', 'ORG'),
#  'Q6871463': ('OTHERS', 'OTHERS'),
#  'Q93725704': ('OTHERS', 'OTHERS'),
#  'Q3696048': ('LOC', 'LOC'),
#  'Q18217': ('OTHERS', 'OTHERS'),
#  'Q5940': ('ORG', 'LOC'),
#  'Q92910435': ('OTHERS', 'OTHERS'),
#  'Q51572': ('OTHERS', 'LOC'),
#  'Q18882064': ('OTHERS', 'OTHERS'),
#  'Q74651744': ('OTHERS', 'OTHERS'),
#  'Q3671763': ('LOC', 'OTHERS'),
#  'Q1564189': ('OTHERS', 'LOC'),
#  'Q13659137': ('LOC', 'LOC'),
#  'Q15708337': ('OTHERS', 'LOC'),
#  'Q21560196': ('LOC', 'LOC'),
#  'Q1338860': ('OTHERS', 'LOC'),
#  'Q842507': ('OTHERS', 'OTHERS'),
#  'Q1058467': ('ORG', 'ORG'),
#  'Q5372143': ('OTHERS', 'LOC'),
#  'Q78241866': ('OTHERS', 'OTHERS'),
#  'Q1569768': ('OTHERS', 'LOC'),
#  'Q843092': ('LOC', 'OTHERS'),
#  'Q18881690': ('OTHERS', 'OTHERS'),
#  'Q1826346': ('LOC', 'OTHERS'),
#  'Q131344': ('OTHERS', 'OTHERS'),
#  'Q6462034': ('LOC', 'LOC'),
#  'Q791762': ('LOC', 'OTHERS'),
#  'Q202968': ('LOC', 'LOC'),
#  'Q15919452': ('ORG', 'LOC'),
#  'Q21667356': ('LOC', 'LOC'),
#  'Q5094255': ('OTHERS', 'LOC'),
#  'Q1803052': ('LOC', 'LOC'),
#  'Q944450': ('OTHERS', 'OTHERS'),
#  'Q838148': ('OTHERS', 'LOC'),
#  'Q2492951': ('OTHERS', 'ORG'),
#  'Q51709': ('OTHERS', 'ORG'),
#  'Q18882092': ('OTHERS', 'OTHERS'),
#  'Q62128689': ('LOC', 'LOC'),
#  'Q6551134': ('LOC', 'LOC'),
#  'Q3948024': ('LOC', 'LOC'),
#  'Q1205357': ('ORG', 'LOC'),
#  'Q1042241': ('OTHERS', 'OTHERS'),
#  'Q74651310': ('OTHERS', 'OTHERS'),
#  'Q662269': ('OTHERS', 'OTHERS'),
#  'Q53935004': ('ORG', 'LOC'),
#  'Q2377226': ('OTHERS', 'OTHERS'),
#  'Q54931477': ('ORG', 'LOC'),
#  'Q1634594': ('OTHERS', 'ORG'),
#  'Q658806': ('OTHERS', 'OTHERS'),
#  'Q89113709': ('OTHERS', 'OTHERS'),
#  'Q12626835': ('OTHERS', 'OTHERS'),
#  'Q56677022': ('OTHERS', 'OTHERS'),
#  'Q18845598': ('OTHERS', 'OTHERS'),
#  'Q103821088': ('ORG', 'LOC'),
#  'Q177075': ('LOC', 'LOC'),
#  'Q13626302': ('OTHERS', 'OTHERS'),
#  'Q49788923': ('LOC', 'LOC'),
#  'Q12709': ('LOC', 'LOC'),
#  'Q18888586': ('OTHERS', 'OTHERS'),
#  'Q698398': ('OTHERS', 'LOC'),
#  'Q78823713': ('LOC', 'ORG'),
#  'Q21665571': ('LOC', 'LOC'),
#  'Q76785910': ('OTHERS', 'OTHERS'),
#  'Q3238267': ('LOC', 'LOC'),
#  'Q19460935': ('OTHERS', 'LOC'),
#  'Q2209140': ('OTHERS', 'ORG'),
#  'Q26789330': ('OTHERS', 'LOC'),
#  'Q4209569': ('LOC', 'LOC'),
#  'Q386959': ('LOC', 'LOC'),
#  'Q176979': ('LOC', 'LOC'),
#  'Q20107744': ('LOC', 'LOC'),
#  'Q41377672': ('ORG', 'LOC'),
#  'Q105514438': ('LOC', 'LOC'),
#  'Q2270': ('OTHERS', 'OTHERS'),
#  'Q1357180': ('ORG', 'LOC'),
#  'Q432888': ('LOC', 'LOC'),
#  'Q87965479': ('OTHERS', 'OTHERS'),
#  'Q178878': ('LOC', 'LOC'),
#  'Q77982444': ('OTHERS', 'OTHERS'),
#  'Q2878264': ('LOC', 'LOC'),
#  'Q99988': ('LOC', 'LOC'),
#  'Q3088623': ('LOC', 'LOC'),
#  'Q747896': ('LOC', 'LOC'),
#  'Q10419798': ('LOC', 'LOC'),
#  'Q276837': ('OTHERS', 'OTHERS'),
#  'Q205325': ('LOC', 'LOC'),
#  'Q89650821': ('OTHERS', 'OTHERS'),
#  'Q7735466': ('ORG', 'OTHERS'),
#  'Q863478': ('ORG', 'ORG'),
#  'Q78243628': ('OTHERS', 'OTHERS'),
#  'Q2793345': ('OTHERS', 'LOC'),
#  'Q60366642': ('OTHERS', 'OTHERS'),
#  'Q68352222': ('OTHERS', 'OTHERS'),
#  'Q26783931': ('OTHERS', 'LOC'),
#  'Q98728641': ('ORG', 'LOC'),
#  'Q164605': ('ORG', 'LOC'),
#  'Q81693268': ('OTHERS', 'OTHERS'),
#  'Q612423': ('OTHERS', 'LOC'),
#  'Q77408306': ('OTHERS', 'OTHERS'),
#  'Q3109513': ('OTHERS', 'LOC'),
#  'Q2162084': ('LOC', 'LOC'),
#  'Q113718': ('LOC', 'LOC'),
#  'Q48784652': ('OTHERS', 'OTHERS'),
#  'Q7067437': ('LOC', 'OTHERS'),
#  'Q5902924': ('ORG', 'LOC'),
#  'Q89114542': ('OTHERS', 'OTHERS'),
#  'Q760864': ('OTHERS', 'OTHERS'),
#  'Q18547180': ('OTHERS', 'OTHERS'),
#  'Q1204470': ('ORG', 'LOC'),
#  'Q10360917': ('LOC', 'LOC'),
#  'Q83286': ('LOC', 'ORG'),
#  'Q14935088': ('ORG', 'OTHERS'),
#  'Q83712905': ('OTHERS', 'OTHERS'),
#  'Q58814829': ('OTHERS', 'OTHERS'),
#  'Q90916587': ('OTHERS', 'OTHERS'),
#  'Q93344915': ('LOC', 'OTHERS'),
#  'Q62390260': ('OTHERS', 'OTHERS'),
#  'Q75200669': ('OTHERS', 'ORG'),
#  'Q75699343': ('LOC', 'LOC'),
#  'Q1661653': ('ORG', 'ORG'),
#  'Q3130565': ('OTHERS', 'OTHERS'),
#  'Q18882446': ('OTHERS', 'OTHERS'),
#  'Q21560701': ('LOC', 'LOC'),
#  'Q1358402': ('LOC', 'LOC'),
#  'Q746716': ('OTHERS', 'OTHERS'),
#  'Q917261': ('OTHERS', 'LOC'),
#  'Q2264767': ('LOC', 'OTHERS'),
#  'Q209341': ('LOC', 'LOC'),
#  'Q215819': ('OTHERS', 'ORG'),
#  'Q92937763': ('OTHERS', 'OTHERS'),
#  'Q37585097': ('OTHERS', 'OTHERS'),
#  'Q90884852': ('OTHERS', 'OTHERS'),
#  'Q17012485': ('OTHERS', 'OTHERS'),
#  'Q894060': ('OTHERS', 'LOC'),
#  'Q3458899': ('OTHERS', 'LOC'),
#  'Q74651515': ('OTHERS', 'OTHERS'),
#  'Q11945066': ('OTHERS', 'ORG'),
#  'Q1530878': ('OTHERS', 'LOC'),
#  'Q60239925': ('OTHERS', 'OTHERS'),
#  'Q18881966': ('OTHERS', 'OTHERS'),
#  'Q16673987': ('LOC', 'LOC'),
#  'Q80229995': ('OTHERS', 'OTHERS'),
#  'Q77412201': ('OTHERS', 'OTHERS'),
#  'Q58414319': ('OTHERS', 'LOC'),
#  'Q18882461': ('OTHERS', 'OTHERS'),
#  'Q1116365': ('OTHERS', 'OTHERS'),
#  'Q963394': ('OTHERS', 'OTHERS'),
#  'Q539614': ('OTHERS', 'LOC'),
#  'Q2982055': ('LOC', 'LOC'),
#  'Q16902905': ('ORG', 'OTHERS'),
#  'Q672717': ('LOC', 'LOC'),
#  'Q202042': ('ORG', 'OTHERS'),
#  'Q3458928': ('OTHERS', 'LOC'),
#  'Q3662761': ('OTHERS', 'LOC'),
#  'Q63771': ('LOC', 'LOC'),
#  'Q80711112': ('OTHERS', 'OTHERS'),
#  'Q54860465': ('OTHERS', 'OTHERS'),
#  'Q666900': ('OTHERS', 'LOC'),
#  'Q1119526': ('LOC', 'LOC'),
#  'Q81976504': ('OTHERS', 'OTHERS'),
#  'Q114913': ('ORG', 'ORG'),
#  'Q41798814': ('LOC', 'LOC'),
#  'Q5956': ('ORG', 'LOC'),
#  'Q4039835': ('OTHERS', 'OTHERS'),
#  'Q3129477': ('OTHERS', 'OTHERS'),
#  'Q80226718': ('OTHERS', 'LOC'),
#  'Q62937': ('LOC', 'LOC'),
#  'Q18845129': ('OTHERS', 'OTHERS'),
#  'Q1139475': ('OTHERS', 'ORG'),
#  'Q2201233': ('OTHERS', 'LOC'),
#  'Q77984214': ('OTHERS', 'OTHERS'),
#  'Q5890354': ('LOC', 'OTHERS'),
#  'Q97631000': ('LOC', 'OTHERS'),
#  'Q1204596': ('ORG', 'LOC'),
#  'Q78241883': ('OTHERS', 'LOC'),
#  'Q1613482': ('LOC', 'LOC'),
#  'Q83631759': ('OTHERS', 'OTHERS'),
#  'Q7083666': ('OTHERS', 'LOC'),
#  'Q41741005': ('OTHERS', 'LOC'),
#  'Q7885334': ('OTHERS', 'OTHERS'),
#  'Q11257133': ('LOC', 'LOC'),
#  'Q1569885': ('OTHERS', 'LOC'),
#  'Q4258011': ('LOC', 'LOC'),
#  'Q4333856': ('OTHERS', 'OTHERS'),
#  'Q83640329': ('OTHERS', 'OTHERS'),
#  'Q60781102': ('OTHERS', 'OTHERS'),
#  'Q64382529': ('OTHERS', 'LOC'),
#  'Q2314977': ('OTHERS', 'LOC'),
#  'Q1787502': ('LOC', 'LOC')}

# %%
with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/HT2_failed_queries_HARD.json', 'w') as json_file:
    json.dump(failed_queries, json_file, indent=4)

# %%
with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/HT2_failed_queries_HARD.json', 'r') as f:
    failed_queries_hard = json.load(f)

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/HT2_failed_queries_SOFT.json', 'r') as f:
    failed_queries_soft = json.load(f)

# %%
print(f"failed_queries_hard: {len(failed_queries_hard)} vs failed_queries_soft: {len(failed_queries_soft)}")
# Out:
# failed_queries_hard: 528 vs failed_queries_soft: 380

# %%
column_type = []

for key in tqdm(key_to_cell):
    id_table, _, id_col = key.split(" ")
    name = key_to_cell[key][0]
    q_ids = key_to_cell[key][1].split(' ')
    new_key = f"{id_table} {id_col}"
    if new_key in ner_type:
        NER_type = ner_type[new_key]
        if NER_type is not None:
            column_type.append((q_ids, NER_type))
            #print(f"q_ids: {q_ids}, ner_type column: {NER_type}")
# Out:
# 100%|██████████| 194438/194438 [00:06<00:00, 30597.92it/s]

# %%
from collections import defaultdict
import json

# Initialize a dictionary to count mismatches by category
mismatch_categories = defaultdict(int)
tmp = []

# Iterate through the queries
for p, id, ner, ner_col in queries:
    # Check if the ID is in the missing values list
    if id in missing_values :
        # Parse the query JSON
        data = json.loads(p['query'])
        # Extract the NER type list
        ner_type_list = data['query']['bool']['must'][1]['term']['NERtype']
        # Print the NERtype and column NER for this ID
        print(f"id: {id} has item NERtype: {ner}, column NER: {ner_col}")
        # Compare item NERtype with column NER and count mismatches
        if ner != ner_col:
            # Create a category key for the mismatch
            category = f"{ner} != {ner_col}"
            # Increment the count for this mismatch category
            mismatch_categories[category] += 1

# Print the counts for each mismatch category
for category, count in mismatch_categories.items():
    print(f"Mismatch category '{category}': {count} occurrences")
# Out:
# id: Q328446 has item NERtype: LOC, column NER: ORG
# id: Q233129 has item NERtype: LOC, column NER: OTHERS
# id: Q23664321 has item NERtype: PERS, column NER: OTHERS
# id: Q4738903 has item NERtype: ORG, column NER: OTHERS
# id: Q6419891 has item NERtype: PERS, column NER: OTHERS
# Mismatch category 'LOC != ORG': 1 occurrences
# Mismatch category 'LOC != OTHERS': 1 occurrences
# Mismatch category 'PERS != OTHERS': 2 occurrences
# Mismatch category 'ORG != OTHERS': 1 occurrences

# %%
len(queries)
# Out:
# 91

# %%
tmp = []
for p, id, ner, ner_col in queries:
    if id in missing_values:
        data = json.loads(p['query'])
        ner_type_list = data['query']['bool']['must'][1]['term']['NERtype']
        print(f"id: {id} has item NERtype: {ner}, column NER: {ner_col}")
# Out:
# id: Q2652121 has item NERtype: OTHERS, column NER: LOC
# id: Q2641647 has item NERtype: OTHERS, column NER: LOC
# id: Q56477541 has item NERtype: ORG, column NER: LOC
# id: Q708835 has item NERtype: ORG, column NER: LOC
# id: Q3373817 has item NERtype: OTHERS, column NER: LOC
# id: Q5776966 has item NERtype: ORG, column NER: OTHERS
# id: Q69693505 has item NERtype: ORG, column NER: LOC
# id: Q12544 has item NERtype: LOC, column NER: OTHERS
# id: Q65770023 has item NERtype: OTHERS, column NER: LOC
# id: Q5372143 has item NERtype: OTHERS, column NER: LOC
# id: Q86106553 has item NERtype: LOC, column NER: ORG
# id: Q26786604 has item NERtype: OTHERS, column NER: LOC
# id: Q4816040 has item NERtype: ORG, column NER: LOC
# id: Q1746330 has item NERtype: ORG, column NER: OTHERS
# id: Q1559811 has item NERtype: ORG, column NER: OTHERS
# id: Q30624106 has item NERtype: OTHERS, column NER: LOC
# id: Q2982552 has item NERtype: OTHERS, column NER: LOC
# id: Q2617303 has item NERtype: OTHERS, column NER: LOC
# id: Q2616988 has item NERtype: OTHERS, column NER: LOC
# id: Q2616970 has item NERtype: OTHERS, column NER: LOC
# id: Q388488 has item NERtype: LOC, column NER: OTHERS
# id: Q6682231 has item NERtype: ORG, column NER: LOC
# id: Q194104 has item NERtype: OTHERS, column NER: LOC
# id: Q66228 has item NERtype: LOC, column NER: OTHERS
# id: Q2274963 has item NERtype: OTHERS, column NER: LOC
# id: Q2442235 has item NERtype: OTHERS, column NER: LOC
# id: Q278877 has item NERtype: LOC, column NER: OTHERS
# id: Q60372364 has item NERtype: OTHERS, column NER: ORG
# id: Q2375620 has item NERtype: ORG, column NER: OTHERS
# id: Q7830411 has item NERtype: OTHERS, column NER: LOC
# id: Q2201159 has item NERtype: OTHERS, column NER: LOC
# id: Q2753179 has item NERtype: OTHERS, column NER: LOC
# id: Q1319988 has item NERtype: LOC, column NER: OTHERS
# id: Q865076 has item NERtype: LOC, column NER: OTHERS
# id: Q771404 has item NERtype: LOC, column NER: OTHERS
# id: Q16735627 has item NERtype: OTHERS, column NER: LOC
# id: Q64682396 has item NERtype: OTHERS, column NER: LOC
# id: Q163164 has item NERtype: OTHERS, column NER: ORG
# id: Q623424 has item NERtype: LOC, column NER: OTHERS
# id: Q97627543 has item NERtype: OTHERS, column NER: LOC
# id: Q97627496 has item NERtype: OTHERS, column NER: LOC
# id: Q142636 has item NERtype: ORG, column NER: LOC
# id: Q7080184 has item NERtype: OTHERS, column NER: LOC
# id: Q2272973 has item NERtype: OTHERS, column NER: LOC
# id: Q988751 has item NERtype: OTHERS, column NER: LOC
# id: Q571771 has item NERtype: OTHERS, column NER: LOC
# id: Q2591630 has item NERtype: OTHERS, column NER: LOC
# id: Q85847942 has item NERtype: ORG, column NER: OTHERS
# id: Q908640 has item NERtype: OTHERS, column NER: LOC
# id: Q104914792 has item NERtype: OTHERS, column NER: ORG
# id: Q97015150 has item NERtype: OTHERS, column NER: LOC
# id: Q97007039 has item NERtype: OTHERS, column NER: LOC
# id: Q2620426 has item NERtype: LOC, column NER: OTHERS
# id: Q102469 has item NERtype: LOC, column NER: OTHERS
# id: Q919404 has item NERtype: LOC, column NER: ORG
# id: Q725594 has item NERtype: OTHERS, column NER: LOC
# id: Q645222 has item NERtype: OTHERS, column NER: LOC
# id: Q267144 has item NERtype: OTHERS, column NER: LOC
# id: Q82230 has item NERtype: OTHERS, column NER: LOC
# id: Q1570564 has item NERtype: OTHERS, column NER: LOC
# id: Q320967 has item NERtype: OTHERS, column NER: LOC
# id: Q215819 has item NERtype: OTHERS, column NER: ORG
# id: Q14875596 has item NERtype: OTHERS, column NER: ORG
# id: Q41357775 has item NERtype: ORG, column NER: LOC
# id: Q98481863 has item NERtype: ORG, column NER: LOC
# id: Q15708337 has item NERtype: OTHERS, column NER: LOC
# id: Q278877 has item NERtype: LOC, column NER: OTHERS
# id: Q224494 has item NERtype: OTHERS, column NER: LOC
# id: Q10333266 has item NERtype: LOC, column NER: OTHERS
# id: Q1634594 has item NERtype: OTHERS, column NER: ORG
# id: Q1022366 has item NERtype: OTHERS, column NER: ORG
# id: Q388841 has item NERtype: OTHERS, column NER: ORG
# id: Q278151 has item NERtype: OTHERS, column NER: ORG
# id: Q19375324 has item NERtype: OTHERS, column NER: ORG
# id: Q3476523 has item NERtype: OTHERS, column NER: LOC
# id: Q3458939 has item NERtype: OTHERS, column NER: LOC
# id: Q3458889 has item NERtype: OTHERS, column NER: LOC
# id: Q2862516 has item NERtype: OTHERS, column NER: LOC
# id: Q1112438 has item NERtype: ORG, column NER: LOC
# id: Q1218597 has item NERtype: OTHERS, column NER: LOC
# id: Q10451 has item NERtype: ORG, column NER: LOC
# id: Q2894053 has item NERtype: ORG, column NER: LOC
# id: Q2079479 has item NERtype: ORG, column NER: LOC
# id: Q805784 has item NERtype: ORG, column NER: LOC
# id: Q1013478 has item NERtype: ORG, column NER: LOC
# id: Q1803466 has item NERtype: LOC, column NER: ORG
# id: Q2534226 has item NERtype: LOC, column NER: OTHERS
# id: Q105064589 has item NERtype: ORG, column NER: LOC
# id: Q105231773 has item NERtype: ORG, column NER: OTHERS
# id: Q164596 has item NERtype: ORG, column NER: LOC
# id: Q5715907 has item NERtype: ORG, column NER: OTHERS
# id: Q1489862 has item NERtype: ORG, column NER: LOC
# id: Q223799 has item NERtype: ORG, column NER: OTHERS
# id: Q2673008 has item NERtype: LOC, column NER: OTHERS
# id: Q1030389 has item NERtype: LOC, column NER: OTHERS
# id: Q2987303 has item NERtype: OTHERS, column NER: ORG
# id: Q1205685 has item NERtype: ORG, column NER: LOC
# id: Q89692143 has item NERtype: ORG, column NER: OTHERS
# id: Q2299611 has item NERtype: OTHERS, column NER: ORG
# id: Q784022 has item NERtype: OTHERS, column NER: ORG
# id: Q6053 has item NERtype: ORG, column NER: LOC
# id: Q6045 has item NERtype: ORG, column NER: LOC
# id: Q5970 has item NERtype: ORG, column NER: LOC
# id: Q5956 has item NERtype: ORG, column NER: LOC
# id: Q42561603 has item NERtype: OTHERS, column NER: LOC
# id: Q889587 has item NERtype: OTHERS, column NER: LOC
# id: Q1746330 has item NERtype: ORG, column NER: OTHERS
# id: Q1559811 has item NERtype: ORG, column NER: OTHERS
# id: Q1569868 has item NERtype: OTHERS, column NER: LOC
# id: Q1569821 has item NERtype: OTHERS, column NER: LOC
# id: Q1569781 has item NERtype: OTHERS, column NER: LOC
# id: Q1569748 has item NERtype: OTHERS, column NER: LOC
# id: Q1630016 has item NERtype: OTHERS, column NER: LOC
# id: Q1759911 has item NERtype: ORG, column NER: LOC
# id: Q1803466 has item NERtype: ORG, column NER: ORG
# id: Q1445363 has item NERtype: OTHERS, column NER: LOC
# id: Q970191 has item NERtype: OTHERS, column NER: LOC
# id: Q40881 has item NERtype: OTHERS, column NER: LOC
# id: Q37043 has item NERtype: OTHERS, column NER: LOC
# id: Q575822 has item NERtype: LOC, column NER: ORG
# id: Q309331 has item NERtype: ORG, column NER: OTHERS
# id: Q622796 has item NERtype: OTHERS, column NER: LOC
# id: Q80688 has item NERtype: OTHERS, column NER: LOC
# id: Q150489 has item NERtype: ORG, column NER: LOC
# id: Q3731342 has item NERtype: OTHERS, column NER: LOC
# id: Q3670950 has item NERtype: OTHERS, column NER: LOC
# id: Q1547773 has item NERtype: ORG, column NER: OTHERS
# id: Q1550449 has item NERtype: ORG, column NER: OTHERS
# id: Q43260516 has item NERtype: LOC, column NER: OTHERS
# id: Q2739939 has item NERtype: LOC, column NER: ORG
# id: Q2209140 has item NERtype: OTHERS, column NER: ORG
# id: Q11353619 has item NERtype: ORG, column NER: LOC
# id: Q11352733 has item NERtype: ORG, column NER: LOC
# id: Q11511194 has item NERtype: ORG, column NER: LOC
# id: Q58439861 has item NERtype: ORG, column NER: LOC
# id: Q15708337 has item NERtype: OTHERS, column NER: LOC
# id: Q67205162 has item NERtype: OTHERS, column NER: LOC
# id: Q67204096 has item NERtype: OTHERS, column NER: LOC
# id: Q1530878 has item NERtype: OTHERS, column NER: LOC
# id: Q104147571 has item NERtype: LOC, column NER: OTHERS
# id: Q102472401 has item NERtype: LOC, column NER: OTHERS
# id: Q81294641 has item NERtype: LOC, column NER: OTHERS
# id: Q1581162 has item NERtype: LOC, column NER: ORG
# id: Q7355542 has item NERtype: OTHERS, column NER: ORG
# id: Q539614 has item NERtype: OTHERS, column NER: LOC
# id: Q215819 has item NERtype: OTHERS, column NER: ORG
# id: Q1026019 has item NERtype: ORG, column NER: LOC
# id: Q993732 has item NERtype: ORG, column NER: LOC
# id: Q56052397 has item NERtype: OTHERS, column NER: LOC

# %% [markdown]
# # 2T
# id: Q328446 has item NERtype: LOC, column NER: ORG
#
# id: Q741830 has item NERtype: LOC, column NER: ORG
#
# id: Q2276193 has item NERtype: LOC, column NER: ORG
#
# id: Q988934 has item NERtype: LOC, column NER: OTHERS
#
# id: Q153195 has item NERtype: LOC, column NER: ORG
#
# id: Q2415851 has item NERtype: LOC, column NER: ORG
#
# id: Q2387130 has item NERtype: LOC, column NER: ORG
#
# id: Q233129 has item NERtype: LOC, column NER: OTHERS
#
# id: Q732342 has item NERtype: LOC, column NER: ORG
#
# id: Q3241019 has item NERtype: LOC, column NER: ORG
#
# id: Q1998298 has item NERtype: LOC, column NER: OTHERS
#
# id: Q755226 has item NERtype: LOC, column NER: ORG

# %%
for el in missing_values:
    print(f"id: {'http://wikidata.org/entity/'+el} has true NERtype: {failed_queries_hard[el]}")
# Out:
# id: http://wikidata.org/entity/Q755226 has true NERtype: LOC
# id: http://wikidata.org/entity/Q153195 has true NERtype: LOC
# id: http://wikidata.org/entity/Q2331 has true NERtype: PERS
# id: http://wikidata.org/entity/Q233129 has true NERtype: LOC
# id: http://wikidata.org/entity/Q6746 has true NERtype: ORG
# id: http://wikidata.org/entity/Q2415851 has true NERtype: LOC
# id: http://wikidata.org/entity/Q3241019 has true NERtype: LOC
# id: http://wikidata.org/entity/Q23664321 has true NERtype: PERS
# id: http://wikidata.org/entity/Q36008 has true NERtype: ORG
# id: http://wikidata.org/entity/Q2387130 has true NERtype: LOC
# id: http://wikidata.org/entity/Q4738903 has true NERtype: ORG
# id: http://wikidata.org/entity/Q988934 has true NERtype: LOC
# id: http://wikidata.org/entity/Q741830 has true NERtype: LOC
# id: http://wikidata.org/entity/Q328446 has true NERtype: LOC
# id: http://wikidata.org/entity/Q2276193 has true NERtype: LOC
# id: http://wikidata.org/entity/Q732342 has true NERtype: LOC
# id: http://wikidata.org/entity/Q233 has true NERtype: LOC
# id: http://wikidata.org/entity/Q6419891 has true NERtype: PERS
# id: http://wikidata.org/entity/Q1998298 has true NERtype: LOC

# %%
from collections import defaultdict
import json

# Initialize a dictionary to count mismatches by category
mismatch_categories = defaultdict(int)



for el in missing_values:
    if failed_queries_hard[el][0] != failed_queries_hard[el][1]:
        # Create a category key for the mismatch
        category = f"{failed_queries_hard[el][0]} != {failed_queries_hard[el][1]}"
        #print(category)
        # Increment the count for this mismatch category
        mismatch_categories[category] += 1

# Print the counts for each mismatch category
for category, count in mismatch_categories.items():
    print(f"Mismatch category '{category}': {count} occurrences")
# Out:
# Mismatch category 'LOC != OTHERS': 25 occurrences
# Mismatch category 'OTHERS != LOC': 76 occurrences
# Mismatch category 'ORG != LOC': 24 occurrences
# Mismatch category 'ORG != OTHERS': 9 occurrences
# Mismatch category 'OTHERS != ORG': 12 occurrences
# Mismatch category 'LOC != ORG': 5 occurrences

# %%
# 19 entities doesn’t match due to the Hard filtering constraint

missing_values = set(failed_queries_hard) - set(failed_queries_soft)
print(len(missing_values))
# Out:
# 151
