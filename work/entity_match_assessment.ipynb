# %%
import json
import random
import os
import pandas as pd
import re
import aiohttp
import asyncio
import backoff
import nest_asyncio
import time
from SPARQLWrapper import SPARQLWrapper, JSON
from requests import get
import numpy as np
import requests
from aiohttp import ClientResponseError
import logging
from tqdm import tqdm

# %%
####################
# READ THE JSON
#####################

json_file_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/2T_Round4_sorted_mentions.json"

# Load the JSON file
with open(json_file_path, "r") as file:
    R4_2T_sorted_mentions = json.load(file)


## Sample extraction
# SPLIT OVER THE QUARTILES

n = len(R4_2T_sorted_mentions)
q1_idx = n // 4
q2_idx = n // 2
q3_idx = 3 * n // 4

# Step 3: Split the list into quartiles
q1 = R4_2T_sorted_mentions[:q1_idx]
q2 = R4_2T_sorted_mentions[q1_idx:q2_idx]
q3 = R4_2T_sorted_mentions[q2_idx:q3_idx]
q4 = R4_2T_sorted_mentions[q3_idx:]

sample_size = 1000
R4_2T_sample_keys = []
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q1, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q2, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q3, sample_size)
R4_2T_sample_keys = R4_2T_sample_keys + random.sample(q4, sample_size)

q_ids = {item[1]['name']: item[1]['id'] for item in R4_2T_sample_keys}

# %%
len(R4_2T_sorted_mentions)
# Out:
# 65297

# %%
def get_wikidata_item_tree_item_idsSPARQL(root_items, forward_properties=None, backward_properties=None):
    """Return ids of WikiData items, which are in the tree spanned by the given root items and claims relating them
        to other items.

    :param root_items: iterable[int] One or multiple item entities that are the root elements of the tree
    :param forward_properties: iterable[int] | None property-claims to follow forward; that is, if root item R has
        a claim P:I, and P is in the list, the search will branch recursively to item I as well.
    :param backward_properties: iterable[int] | None property-claims to follow in reverse; that is, if (for a root
        item R) an item I has a claim P:R, and P is in the list, the search will branch recursively to item I as well.
    :return: iterable[int]: List with ids of WikiData items in the tree
    """

    query = '''PREFIX wikibase: <http://wikiba.se/ontology#>
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'''
    if forward_properties:
        query +='''SELECT ?WD_id WHERE {
                  # ?tree0 (wdt:P%s)* ?WD_id .
                  BIND (wd:%s AS ?tree0)
                  }'''%( ','.join(map(str, forward_properties)),','.join(map(str, root_items)))
    elif backward_properties:
        query+='''SELECT ?WD_id WHERE {
                    # ?WD_id (wdt:P%s)* wd:Q%s .
                    }'''%(','.join(map(str, backward_properties)), ','.join(map(str, root_items)))
    #print(query)

    url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
    data = get(url, params={'query': query, 'format': 'json'}).json()
    
    ids = []
    for item in data['results']['bindings']:
        this_id=item["WD_id"]["value"].split("/")[-1].lstrip("Q")
        #print(item)
        try:
            this_id = int(this_id)
            ids.append(this_id)
            #print(this_id)
        except ValueError:
            #print("exception")
            continue
    return ids


try:
    organization_subclass = get_wikidata_item_tree_item_idsSPARQL([43229], backward_properties=[279])
    #print(len(organization_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    country_subclass = get_wikidata_item_tree_item_idsSPARQL([6256], backward_properties=[279])
except json.decoder.JSONDecodeError:
    country_subclass = set()
    pass

try:
    city_subclass = get_wikidata_item_tree_item_idsSPARQL([515], backward_properties=[279])
except json.decoder.JSONDecodeError:
    city_subclass = set()
    pass

try:
    capitals_subclass = get_wikidata_item_tree_item_idsSPARQL([5119], backward_properties=[279])
except json.decoder.JSONDecodeError:
    capitals_subclass = set()
    pass

try:
    admTerr_subclass = get_wikidata_item_tree_item_idsSPARQL([15916867], backward_properties=[279])
except json.decoder.JSONDecodeError:
    admTerr_subclass = set()
    pass

try:
    family_subclass = get_wikidata_item_tree_item_idsSPARQL([17350442], backward_properties=[279])
except json.decoder.JSONDecodeError:
    family_subclass = set()
    pass

try:
    sportLeague_subclass = get_wikidata_item_tree_item_idsSPARQL([623109], backward_properties=[279])
except json.decoder.JSONDecodeError:
    sportLeague_subclass = set()
    pass

try:
    venue_subclass = get_wikidata_item_tree_item_idsSPARQL([8436], backward_properties=[279])
except json.decoder.JSONDecodeError:
    venue_subclass = set()
    pass
    
try:
    organization_subclass = list(set(organization_subclass) - set(country_subclass) - set(city_subclass) - set(capitals_subclass) - set(admTerr_subclass) - set(family_subclass) - set(sportLeague_subclass) - set(venue_subclass))
    #print(len(organization_subclass))
except json.decoder.JSONDecodeError:
    pass


try:
    geolocation_subclass = get_wikidata_item_tree_item_idsSPARQL([2221906], backward_properties=[279])
    #print(len(geolocation_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    food_subclass = get_wikidata_item_tree_item_idsSPARQL([2095], backward_properties=[279])
except json.decoder.JSONDecodeError:
    food_subclass = set()
    pass

try:
    edInst_subclass = get_wikidata_item_tree_item_idsSPARQL([2385804], backward_properties=[279])
except json.decoder.JSONDecodeError:
    edInst_subclass = set()
    pass

try:
    govAgency_subclass = get_wikidata_item_tree_item_idsSPARQL([327333], backward_properties=[279])
except json.decoder.JSONDecodeError:
    govAgency_subclass = set()
    pass

try:
    intOrg_subclass = get_wikidata_item_tree_item_idsSPARQL([484652], backward_properties=[279])
except json.decoder.JSONDecodeError:
    intOrg_subclass = set()
    pass

try:
    timeZone_subclass = get_wikidata_item_tree_item_idsSPARQL([12143], backward_properties=[279])
except json.decoder.JSONDecodeError:
    timeZone_subclass = set()
    pass
   
try:
    geolocation_subclass = list(set(geolocation_subclass) - set(food_subclass) - set(edInst_subclass) - set(govAgency_subclass) - set(intOrg_subclass) - set(timeZone_subclass))
    #print(len(geolocation_subclass))
except json.decoder.JSONDecodeError:
    pass

try:
    human_subclass = get_wikidata_item_tree_item_idsSPARQL([5], backward_properties=[279])
except json.decoder.JSONDecodeError:
    human_subclass = set()
    pass

# %%
table_files
# Out:
# ['C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/00E2H310.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/0AJSJYAL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/0D70DN48.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/0H1C2CNE.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/0IR0XIUW.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/1C7N45JA.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/1C9LFOKN.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/1MQL5T7F.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/24W5SSRB.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/29BNEL1Q.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/2BEBH437.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/2EZKB5RU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/2VRS31OV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/2XHMV76G.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3C3INQLM.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3DOM5NIW.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3JXMPC7N.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3LG8J4MX.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3N6S2FCX.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/3X6QY8Q0.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4EGV2QNO.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4FFI99VQ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4FW66XNV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4HP08FY9.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4J75OL3W.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/4WMC1B70.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/51MYHYDF.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/54S3KOBO.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/5DKX42VB.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/5HD27KI3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/5OLOTSKC.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/5RV7WRO1.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/60G94POT.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/64OJP4G3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/6I7ET24J.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/71SY0Z5S.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/7EVLH0DV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/7GOG4IKF.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/7QNYGYI7.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/7VVP9YIF.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/8D8CVBT0.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/8MKQXO18.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/8QA9EYPI.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/8R6ZM8HE.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/8YINKYDR.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9BGE5Y4L.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9CSNI7FS.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9HIRS45A.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9JA43FJL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9XAJBIJV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/9Y8MPU2Q.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/A5TITKIN.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/AN306FAH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/ASNHTAOS.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/AUU9A6KL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/B20WIQKU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/B38A9Q5R.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/B7ILPH0Y.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/BDH3WFGJ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/BID0NRU0.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/BLBITS6S.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/BN8FOG7F.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/CAF0E2JH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/CHZGO92A.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/CNQ5Z0BG.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/CQH26T15.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/CXBCCWXI.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/DRSJ0SOG.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/DXTA1MV8.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/E22XXKVQ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/E3ZK744Q.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/E45F8QW2.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/EQZ21058.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/ET9REW9Y.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/EV6LDIB8.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/F98SUVJH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/FF00TEZG.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/FVKKTA8O.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/FWSGRDQ3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/GINQPZQC.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/GNDO9OXJ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/GY7KNULP.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HB00DX4L.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HBKGJQEY.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HCLZSPEJ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HGIUTSCG.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HGYG2DVU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HLJ9HHEE.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HQCEC5NO.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HQRATPBV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/HTF6MVY9.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/I0ENR9U5.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/I6BBMPNU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/I847EKDH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/IP6ZRIGH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/IPTLCCCU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/IYZYF533.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/IZF82AX9.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/J9EJV2S3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/JA4L7KWX.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/JMNRCW4E.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/JN0T2O5I.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/JZ22O0DD.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/JZLRN9PL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/K2VEUQT0.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/K3X3L22Y.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/K71YYDXO.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/KOQM4YU9.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/KUGCH9I3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/L2MCKOWX.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/LV5N8XDB.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/M56G7E6D.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/MANO2PKR.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/MLRJYJ5K.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/MM6ZALRS.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/MSCT8MJD.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/MZ0BI8NN.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/N6QAC84T.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/N9SJK368.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/ND6V1CBE.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/NDSTZH1I.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/NPNYM0BA.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/NV4GY44T.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/NYFX4M8T.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/O0BECB72.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/O0UJJVBR.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OD9USH5H.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OHGI1JNY.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OIDIXPNZ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OKW6UUW5.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OP0PZIXY.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/ORPKCFRL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OUL0NHS5.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/OZYCQ769.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/P86ZJFXK.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/P8B3IAOY.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/P8JQV93S.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/PWNRGOJ5.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/PZXDACJ9.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QIW5EC2H.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QNP7O8L5.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QOAVEFGY.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QOL4ZIHL.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QPFX5Z8J.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/QW492LGU.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/RYTFLT5K.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/S7DQFOD4.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/S8UOQYBG.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/SFGT3EDA.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/SHV3ZSSV.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/SNUO09BH.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/SPPNJXB2.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/SRVLBA90.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/T7RPWH6N.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/TNI3UKH2.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/TW1HGRFI.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/U1FDHL7N.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/U30NUSS7.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/U5L6L4Q4.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/UEJEB27H.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/UN0JPGPF.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/UURPYBGQ.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/VGUZX5R3.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/VKWTT7F7.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/VLUAWPBO.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WH6JINCM.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WI5LYQ0H.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WRGS0WCX.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WRPAQPNC.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WWBIR8H6.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/WZL61XYS.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/X1LRVWSR.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/X23TMJ3R.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/X3RACWMT.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/XBHX2VRT.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/XZRRL5AE.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/Y85GTOSS.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/YCOUS57M.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/Z4M8AT89.csv',
#  'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/ZZNW93IV.csv']

# %%
import os
import pandas as pd
from tqdm import tqdm
import logging

tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cea.csv'
os.listdir(tables_path)
# Initialize logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df = pd.read_csv(cea_file, header=None)
df["key"] = df[0] + " " + df[1].astype(str) + " " + df[2].astype(str)
cea_values_dict = dict(zip(df["key"].values, df[3].values))
cea_keys_set = set(df["key"].values)

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        local_key_to_cell = {}
        
        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    local_key_to_cell[key] = (cell_value, cea_values_dict[key])
                    break  # Exit inner loop early as only one match per row/col is needed
        
        return local_key_to_cell
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

# List of table files
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)
# Out:
# Processing tables: 100%|██████████| 180/180 [00:08<00:00, 20.97it/s]

# %%
tables = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cea.csv'
cta_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/2T_Round4/gt/cta.csv'
os.listdir(tables)

def get_item_root(id_list):     
    id_to_root_class = {}
    for el in id_list:
        inst_item = int(re.search(r'(\d+)$', el)[0])
        if inst_item in geolocation_subclass:
            #id_to_root_class[el] = "LOC"
            return "LOC"
        elif inst_item in organization_subclass:
            #id_to_root_class[el] = "ORG"
            return "ORG"
        elif inst_item in human_subclass:
            #id_to_root_class[el] = "PERS"
            return "PERS"      
    
    return "OTHERS"

# Apply the function and create the 'key' column
root_classes = []
df = pd.read_csv(cta_file, header=None)
root_categories = []
for urls in df[2]:
    tmp = [url.split('/')[-1] for url in urls.split(" ")]
    root_categories.append(get_item_root(tmp))




df["category"] = root_categories
cta_keys = {}
cta_keys["key"] = (df[0] + " " + df[1].astype('str'), df["category"])

ner_type = {}
for table in tqdm(os.listdir(tables)):
    table_file = os.path.join(tables, table)
    table_name = table.split(".")[0]
    df = pd.read_csv(table_file)
    for row in range(df.shape[0]):
        for col in range(df.shape[1]):
            key = f"{table_name} {col}"
            if key in set(cta_keys["key"][0].values):
                tmp_index = cta_keys["key"][0].values.tolist().index(key)
                tmp_value = cta_keys["key"][1].iloc[tmp_index]
                ner_type[key] = tmp_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 26>()
#      26 for urls in df[2]:
#      27     tmp = [url.split('/')[-1] for url in urls.split(" ")]
# ---> 28     root_categories.append(get_item_root(tmp))
#      33 df["category"] = root_categories
#      34 cta_keys = {}
#
# Input In [6], in get_item_root(id_list)
#       8 for el in id_list:
#       9     inst_item = int(re.search(r'(\d+)$', el)[0])
# ---> 10     if inst_item in geolocation_subclass:
#      11         #id_to_root_class[el] = "LOC"
#      12         return "LOC"
#      13     elif inst_item in organization_subclass:
#      14         #id_to_root_class[el] = "ORG"
#
# NameError: name 'geolocation_subclass' is not defined

# %%
### in case you want HT2

tables_path = "C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/tables/"
cea_file = 'C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/Dataset/Dataset/HardTablesR2/gt/cea.csv'
os.listdir(tables_path)
# Initialize logging
#logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the cea_file and create a key-value dictionary
df = pd.read_csv(cea_file, header=None)
df["key"] = df[0] + " " + df[1].astype(str) + " " + df[2].astype(str)
cea_values_dict = dict(zip(df["key"].values, df[3].values))
cea_keys_set = set(df["key"].values)

# Function to process a single table file
def process_table_file(table_file):
    try:
        table_name = os.path.splitext(os.path.basename(table_file))[0]
        df = pd.read_csv(table_file)
        local_key_to_cell = {}
        
        for row in range(df.shape[0]):
            for col in range(df.shape[1]):
                key = f"{table_name} {row+1} {col}"
                if key in cea_keys_set:
                    cell_value = df.iloc[row, col]
                    local_key_to_cell[key] = (cell_value, cea_values_dict[key])
                    break  # Exit inner loop early as only one match per row/col is needed
        
        return local_key_to_cell
    except Exception as e:
        logging.error(f"Error processing {table_file}: {e}")
        return {}

pattern = r'^\.'

# Create a list of file paths, excluding files that start with a dot
table_files = [os.path.join(tables_path, table) for table in os.listdir(tables_path) if not re.match(pattern, table)]

# Process tables sequentially
key_to_cell = {}
for table_file in tqdm(table_files, desc="Processing tables"):
    local_key_to_cell = process_table_file(table_file)
    key_to_cell.update(local_key_to_cell)



with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/HT2_ner_type.json', 'r') as f:
    ner_type = json.load(f)
# Out:
# Processing tables: 100%|██████████| 1750/1750 [00:28<00:00, 60.43it/s]

# %%
### in case you want R4

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/R4_ner_type.json', 'r') as f:
    ner_type = json.load(f)

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/work/R4_key_to_cell.json', 'r') as f:
    key_to_cell = json.load(f)

# %%
sample_size = 4000
key_to_cell_sample = dict(random.sample(list(key_to_cell.items()), sample_size))

# %%
def get_query(name, value):
    name = name.replace('"', ' ')
    if value is not None:
        ### SOFT FILTERING CONSTRAINT
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query' : f'{{"query": {{"bool": {{"must": [{{"match": {{"name": {{"query": "{name}", "boost": 2.0}}}}}}], "should": [{{"term": {{"NERtype": "{value}"}}}}]}}}}}}',
            'sort': [
                f'''{{"popularity": {{"order": "desc"}}}}'''
            ]
        }

    else:
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query': f'''{{"query": {{"bool": {{"must": [{{"match": {{"name": {{"query": "{name}", "boost": 2.0}}}}}}]}}}}}}''',
            'sort': [
                f'''{{"popularity": {{"order": "desc"}}}}'''
            ]
        }
    return params


queries = []
for key in tqdm(key_to_cell_sample):
    id_table, _, id_col = key.split(" ")
    name = key_to_cell[key][0]
    q_id = key_to_cell[key][1]
    new_key = f"{id_table} {id_col}"
    if new_key in ner_type:
        NER_type = ner_type[new_key]
        query = get_query(name, NER_type)
        match = re.search(r'Q(\d+)$', q_id)
        if match:
            data = json.loads(query['query'])
            ner_type_list = data['query']['bool']['should'][0]['term']['NERtype']
            queries.append((query, match[0], ner_type_list))
# Out:
# 100%|██████████| 4000/4000 [00:00<00:00, 5766.16it/s]

# %%
def get_query(name, value):    
    name = name.replace('"', ' ')

    if value is not None:
        ### HARD FILTERING CONSTRAINT
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query': f'{{"query": {{"bool": {{"must": [{{"match": {{"name": {{"query": "{name}", "boost": 2.0}}}}}}, {{"term": {{"NERtype": "{value}"}}}}]}}}}}}',
            'sort': [
                f'''{{"popularity": {{"order": "desc"}}}}'''
            ]
        }

    else:
        params = {
            'name': name,
            'token': 'lamapi_demo_2023',
            'kg': 'wikidata',
            'limit': 1000,
            'query': f'''{{"query": {{"bool": {{"must": [{{"match": {{"name": {{"query": "{name}", "boost": 2.0}}}}}}]}}}}}}''',
            'sort': [
                f'''{{"popularity": {{"order": "desc"}}}}'''
            ]
        }
    return params


queries = []
for key in tqdm(key_to_cell_sample):
    id_table, _, id_col = key.split(" ")
    name = key_to_cell[key][0]
    q_id = key_to_cell[key][1]
    new_key = f"{id_table} {id_col}"
    if new_key in ner_type:
        NER_type = ner_type[new_key]
        query = get_query(name, NER_type)
        match = re.search(r'Q(\d+)$', q_id)
        if match:
            data = json.loads(query['query'])
            # Navigate through the dictionary to extract the value of "NERtype"
            ner_type_list = data['query']['bool']['must'][1]['term']['NERtype']
            queries.append((query, match[0],ner_type_list))
# Out:
# 100%|██████████| 4000/4000 [00:00<00:00, 18779.30it/s]

# %%
import aiohttp
import asyncio
import backoff
import nest_asyncio
import random
from tqdm import tqdm
import numpy as np

# Assume queries is a list of tuples [(param1, id1), (param2, id2), ...]

failed_queries = {}
url = 'https://lamapi.hel.sintef.cloud/lookup/entity-retrieval'

# Backoff decorator for handling retries with exponential backoff
@backoff.on_exception(
    backoff.expo, 
    (aiohttp.ClientError, aiohttp.http_exceptions.HttpProcessingError, asyncio.TimeoutError), 
    max_tries=10, 
    max_time=400
)
async def fetch(session, url, params, headers, semaphore):
    async with semaphore:
        # Convert all params to str, int, or float
        #params = {k: (int(v) if isinstance(v, np.integer) else str(v)) for k, v in params.items()}
        async with session.get(url, params=params, headers=headers, timeout=30) as response:
            try:
                response.raise_for_status()  # Raises an exception for 4XX/5XX status codes
                return await response.json()
            except Exception as e:
                return []

async def process_item(session, url, id, headers, params, semaphore, pbar):
    try:
        data = await fetch(session, url, params, headers, semaphore)
    except aiohttp.ClientResponseError as e:
        if e.status == 404:
            print(f"404 Error: Resource not found for '{id}'")
            asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
            return 0, 0
        else:
            raise  # Re-raise the exception for other status codes

    num_result = len(data) if data else 0

    if data:
        for item in data:
            if id == item.get('id'):
                asyncio.get_event_loop().call_soon_threadsafe(pbar.update, 1)
                pos_score = item.get('pos_score', 0)
                if pos_score:
                    mrr_increment = (num_result - (pos_score * num_result)) / num_result
                else:
                    mrr_increment = 1 / num_result  # Assume worst case for MRR if pos_score is 0
                return mrr_increment, 1

    return 0, 0

async def main(queries, url, pbar, failed_queries):
    headers = {'accept': 'application/json'}
    semaphore = asyncio.Semaphore(50)  # Limit to 50 concurrent requests
    m_mrr = 0
    cont_el = 0

    async with aiohttp.ClientSession() as session:
        tasks = []
        for param, id, _ in queries:
            tasks.append(process_item(session, url, id, headers, param, semaphore, pbar))
        
        results = await asyncio.gather(*tasks)
        
        for (mrr_increment, count), (param, id, NERtype) in zip(results, queries):
            if mrr_increment == 0 and count == 0:
                failed_queries[id] = NERtype
            else:
                m_mrr += mrr_increment
                cont_el += count

        asyncio.get_event_loop().call_soon_threadsafe(pbar.close)

    print(f"Coverage of 2T: {cont_el / len(queries)}")
    print(f"Measure Reciprocal Rank of 2T: {m_mrr / len(queries)}")

# Check if there's already a running event loop
if __name__ == "__main__":
    nest_asyncio.apply()  # Apply nest_asyncio
    try:
        pbar = tqdm(total=len(queries))
        asyncio.run(main(queries, url, pbar, failed_queries))
    except RuntimeError:  # For environments like Jupyter
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(queries, url, pbar, failed_queries))
# Out:
#  27%|██▋       | 1056/3979 [08:30<6:06:23,  7.52s/it]2024-08-02 13:30:19,522 - INFO - Backing off fetch(...) for 1.0s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,556 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,623 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,636 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,654 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,661 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,672 - INFO - Backing off fetch(...) for 0.8s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,678 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,689 - INFO - Backing off fetch(...) for 0.8s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,694 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,705 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,712 - INFO - Backing off fetch(...) for 0.8s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,726 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,745 - INFO - Backing off fetch(...) for 0.6s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,773 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,824 - INFO - Backing off fetch(...) for 0.2s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,903 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,907 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,912 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,917 - INFO - Backing off fetch(...) for 0.6s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,932 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:30:19,950 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
#  33%|███▎      | 1316/3979 [10:35<53:51,  1.21s/it]  2024-08-02 13:32:24,645 - INFO - Backing off fetch(...) for 0.6s (asyncio.exceptions.TimeoutError)
#  33%|███▎      | 1321/3979 [10:39<36:37,  1.21it/s]2024-08-02 13:32:28,640 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
#  34%|███▎      | 1334/3979 [10:51<33:01,  1.33it/s]2024-08-02 13:32:39,622 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1347/3979 [11:02<22:13,  1.97it/s]  2024-08-02 13:32:50,629 - INFO - Backing off fetch(...) for 0.2s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:32:50,632 - INFO - Backing off fetch(...) for 0.1s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1349/3979 [11:05<54:46,  1.25s/it]2024-08-02 13:32:54,644 - INFO - Backing off fetch(...) for 0.8s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1351/3979 [11:06<35:03,  1.25it/s]2024-08-02 13:32:55,626 - INFO - Backing off fetch(...) for 0.3s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1353/3979 [11:07<28:27,  1.54it/s]2024-08-02 13:32:56,633 - INFO - Backing off fetch(...) for 0.3s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1355/3979 [11:10<44:31,  1.02s/it]2024-08-02 13:32:59,631 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
#  34%|███▍      | 1364/3979 [11:20<1:16:04,  1.75s/it]2024-08-02 13:33:08,724 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:33:08,734 - INFO - Backing off fetch(...) for 0.3s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:33:08,737 - INFO - Backing off fetch(...) for 1.0s (asyncio.exceptions.TimeoutError)
#  35%|███▍      | 1387/3979 [11:22<10:25,  4.14it/s]  2024-08-02 13:33:11,629 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:33:11,629 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
#  35%|███▌      | 1403/3979 [11:27<10:15,  4.19it/s]2024-08-02 13:33:15,622 - INFO - Backing off fetch(...) for 0.7s (asyncio.exceptions.TimeoutError)
#  36%|███▌      | 1421/3979 [11:30<17:12,  2.48it/s]2024-08-02 13:33:19,636 - INFO - Backing off fetch(...) for 0.5s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:33:19,638 - INFO - Backing off fetch(...) for 0.4s (asyncio.exceptions.TimeoutError)
#  36%|███▌      | 1426/3979 [11:32<11:28,  3.71it/s]2024-08-02 13:33:20,620 - INFO - Backing off fetch(...) for 0.0s (asyncio.exceptions.TimeoutError)
# 2024-08-02 13:33:20,622 - INFO - Backing off fetch(...) for 0.0s (asyncio.exceptions.TimeoutError)
#  36%|███▋      | 1448/3979 [11:36<14:54,  2.83it/s]2024-08-02 13:33:25,628 - INFO - Backing off fetch(...) for 0.6s (asyncio.exceptions.TimeoutError)
#  37%|███▋      | 1477/3979 [11:44<06:39,  6.26it/s]2024-08-02 13:33:32,629 - INFO - Backing off fetch(...) for 0.6s (asyncio.exceptions.TimeoutError)
#  60%|██████    | 2404/3979 [14:08<09:15,  2.83it/s]
# Coverage of 2T: 0.6041719024880623
# Measure Reciprocal Rank of 2T: 0.5114646896205132

# %%
with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/2T_failed_queries_HARD.json', 'w') as json_file:
    json.dump(failed_queries, json_file, indent=4)

# %%
with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/2T_failed_queries_HARD.json', 'r') as f:
    failed_queries_hard = json.load(f)

with open('C:/ALESSANDRO/Università/MAGISTRALE/SINTEF_thesis/lamAPI/data/2T_failed_queries_SOFT.json', 'r') as f:
    failed_queries_soft = json.load(f)

# %%
len(set(failed_queries_hard.keys()) & set(failed_queries_soft.keys()))
# Out:
# 546

# %%
print(f"failed_queries_hard: {len(failed_queries_hard)} vs failed_queries_soft: {len(failed_queries_soft)}")
# Out:
# failed_queries_hard: 560 vs failed_queries_soft: 548

# %%
queries[0]
# Out:
# ({'name': 'Gene Harris',
#   'token': 'lamapi_demo_2023',
#   'kg': 'wikidata',
#   'limit': 1000,
#   'query': '{"query": {"bool": {"must": [{"match": {"name": {"query": "Gene Harris", "boost": 2.0}}}, {"term": {"NERtype": "PERS"}}]}}}',
#   'sort': ['{"popularity": {"order": "desc"}}']},
#  'Q5531253',
#  'PERS')

# %%
key_to_cell_sample
# Out:
# {'UEJEB27H 7354 0': ("Michael O'Neill",
#   'http://www.wikidata.org/entity/Q3308419'),
#  'KUGCH9I3 6701 0': ('Robert Harris',
#   'http://www.wikidata.org/entity/Q7345279'),
#  'X23TMJ3R 1476 0': ('Martin Gerschwitz',
#   'http://www.wikidata.org/entity/Q6775525'),
#  '7QNYGYI7 1791 0': ('RDM', 'http://www.wikidata.org/entity/Q2716240'),
#  'NPNYM0BA 3827 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'NPNYM0BA 6296 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '1C9LFOKN 839 0': ('Winston Salam',
#   'http://www.wikidata.org/entity/Q49227 http://www.wikidata.org/entity/Q13047861'),
#  '0IR0XIUW 378 0': ('Carllos Reutemann',
#   'http://www.wikidata.org/entity/Q173238'),
#  'KUGCH9I3 7793 0': ('Craig Robertson',
#   'http://www.wikidata.org/entity/Q5181380'),
#  '7QNYGYI7 1683 0': ('PW', 'http://www.wikidata.org/entity/Q3288207'),
#  'EQZ21058 241 0': ('Lake Cachuma', 'http://www.wikidata.org/entity/Q6475141'),
#  '9XAJBIJV 2073 0': ('Mickey Thomas',
#   'http://www.wikidata.org/entity/Q6838805'),
#  'X1LRVWSR 7675 0': ('Scarlett Joahnessen',
#   'http://www.wikidata.org/entity/Q34436'),
#  'NPNYM0BA 8525 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'Y85GTOSS 2 0': ('Zooey Deschanelle',
#   'http://www.wikidata.org/entity/Q191719'),
#  'GY7KNULP 349 0': ('Agatsuma Entertainment',
#   'http://www.wikidata.org/entity/Q11282741'),
#  '9CSNI7FS 6165 0': ('Bob Vance', 'http://www.wikidata.org/entity/Q18217599'),
#  '3N6S2FCX 6224 0': ('Alanis Morriserrtt',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'X23TMJ3R 376 0': ('Christoph Brüx', 'http://www.wikidata.org/entity/Q60119'),
#  '7QNYGYI7 1643 0': ('NickyKay', 'http://www.wikidata.org/entity/Q7026963'),
#  'O0UJJVBR 4572 0': ('Craig Johnson',
#   'http://www.wikidata.org/entity/Q3002021'),
#  '3N6S2FCX 3147 0': ('Shia Saide Lauboeuf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'N9SJK368 20 0': ('kentuky',
#   'http://www.wikidata.org/entity/Q1603 http://www.wikidata.org/entity/Q12919729 http://www.wikidata.org/entity/Q15646394 http://www.wikidata.org/entity/Q19746938 http://www.wikidata.org/entity/Q65297660 http://www.wikidata.org/entity/Q65454596'),
#  'UEJEB27H 2303 0': ('Bobby Bennettt',
#   'http://www.wikidata.org/entity/Q4934766'),
#  '9CSNI7FS 4880 0': ('Kenneth Hall',
#   'http://www.wikidata.org/entity/Q6390176'),
#  'JZ22O0DD 3 0': ('Luis Gonzalez',
#   'http://www.wikidata.org/entity/Q2737865 http://www.wikidata.org/entity/Q30907095'),
#  'GINQPZQC 101 0': ('Rezaul Karim', 'http://www.wikidata.org/entity/Q7319848'),
#  'NPNYM0BA 5411 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'O0UJJVBR 990 0': ('Charlie Moore',
#   'http://www.wikidata.org/entity/Q5085260'),
#  'QW492LGU 1056 0': ('Joe Byrd', 'http://www.wikidata.org/entity/Q15501981'),
#  'KUGCH9I3 3310 0': ('Brian Carpenter',
#   'http://www.wikidata.org/entity/Q4963296'),
#  'B20WIQKU 3060 0': ('Scarlett Johannes',
#   'http://www.wikidata.org/entity/Q34436'),
#  'ZZNW93IV 507 0': ('Hacienda Heights',
#   'http://www.wikidata.org/entity/Q577450 http://www.wikidata.org/entity/Q12947800'),
#  'PZXDACJ9 2961 0': ('Zachary Knight Galiafianazkis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'O0UJJVBR 4562 0': ('David Henderson',
#   'http://www.wikidata.org/entity/Q3703034 http://www.wikidata.org/entity/Q9142966'),
#  '00E2H310 11279 0': ('Chuck Panahliuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'NPNYM0BA 2901 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'UEJEB27H 7564 0': ('Daniel Davis',
#   'http://www.wikidata.org/entity/Q16214385'),
#  '00E2H310 4780 0': ('Mccali Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'PZXDACJ9 4613 0': ('Mauckuly Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'NPNYM0BA 351 0': ('Zooey Deschanel',
#   'http://www.wikidata.org/entity/Q191719'),
#  '64OJP4G3 802 0': ('Sarah Mcclouchlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'IZF82AX9 198 0': ('Texas',
#   'http://www.wikidata.org/entity/Q1439 http://www.wikidata.org/entity/Q13181477 http://www.wikidata.org/entity/Q19748264'),
#  'WZL61XYS 405 0': ('Marrysville',
#   'http://www.wikidata.org/entity/Q950966 http://www.wikidata.org/entity/Q12636417 http://www.wikidata.org/entity/Q12939152'),
#  '3C3INQLM 12162 0': ('Colin Rand Kaepernick',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'HCLZSPEJ 478 0': ('McMinnville', 'http://www.wikidata.org/entity/Q1208413'),
#  '3N6S2FCX 1995 0': ('Zachary Knight Ghalifinakas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'UEJEB27H 194 0': ('Richard Sanderss',
#   'http://www.wikidata.org/entity/Q7328879'),
#  '9HIRS45A 99 0': ('The Raave', 'http://www.wikidata.org/entity/Q2340588'),
#  'PZXDACJ9 10037 0': ('Chuck Paulinikk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'AN306FAH 7066 0': ('Larry Miller',
#   'http://www.wikidata.org/entity/Q16186374'),
#  'U5L6L4Q4 14 0': ('Brazil',
#   'http://www.wikidata.org/entity/Q155 http://www.wikidata.org/entity/Q19717706 http://www.wikidata.org/entity/Q19747272 http://www.wikidata.org/entity/Q25667480'),
#  'X1LRVWSR 4835 0': ('Alanis Morresett',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'X1LRVWSR 4650 0': ('Matthew Mcghoneghey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'NPNYM0BA 4624 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'NPNYM0BA 1080 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '00E2H310 2893 0': ('Zachary Knight Geofenakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'WI5LYQ0H 488 0': ('World', 'http://www.wikidata.org/entity/Q2252657'),
#  '9CSNI7FS 4836 0': ('George Morris',
#   'http://www.wikidata.org/entity/Q16017859'),
#  'PZXDACJ9 6743 0': ('Nicki Minae',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  'GY7KNULP 740 0': ('XING', 'http://www.wikidata.org/entity/Q681849'),
#  'AN306FAH 1673 0': ('Bob Bryant', 'http://www.wikidata.org/entity/Q17479015'),
#  'WZL61XYS 138 0': ('Clevland',
#   'http://www.wikidata.org/entity/Q37320 http://www.wikidata.org/entity/Q97261360'),
#  '3C3INQLM 8855 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'O0UJJVBR 3934 0': ('Tom Brown', 'http://www.wikidata.org/entity/Q7815099'),
#  'O0UJJVBR 7035 0': ('Cliff Young', 'http://www.wikidata.org/entity/Q5132805'),
#  'NPNYM0BA 6266 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '3N6S2FCX 4714 0': ('Matthew Mcaughaughy',
#   'http://www.wikidata.org/entity/Q188955'),
#  '29BNEL1Q 672 0': ('Héctor Baley', 'http://www.wikidata.org/entity/Q553084'),
#  'KUGCH9I3 612 0': ('Wesley Johnson',
#   'http://www.wikidata.org/entity/Q16844811'),
#  'QNP7O8L5 519 0': ('Christoph Brüx', 'http://www.wikidata.org/entity/Q60119'),
#  'NPNYM0BA 6559 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '3C3INQLM 4033 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '3C3INQLM 10644 0': ('Manoj Shyamalann',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'X23TMJ3R 1741 0': ('Thilo Hermann',
#   'http://www.wikidata.org/entity/Q7784187 http://www.wikidata.org/entity/Q7784190'),
#  '3N6S2FCX 5205 0': ('Matthew Mcconahyi',
#   'http://www.wikidata.org/entity/Q188955'),
#  'X1LRVWSR 7083 0': ('Chuck Palaoniak',
#   'http://www.wikidata.org/entity/Q268181'),
#  'KUGCH9I3 493 0': ('Walter Roberts',
#   'http://www.wikidata.org/entity/Q7965986'),
#  '8YINKYDR 12505 0': ('Chuck Paluahnik',
#   'http://www.wikidata.org/entity/Q268181'),
#  'UEJEB27H 518 0': ('John Woods', 'http://www.wikidata.org/entity/Q6264830'),
#  '64OJP4G3 5988 0': ('Pelaboo Street',
#   'http://www.wikidata.org/entity/Q10101'),
#  '8YINKYDR 12150 0': ('Chuck Palahniuc',
#   'http://www.wikidata.org/entity/Q268181'),
#  'PZXDACJ9 3953 0': ('Mackoly Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '3N6S2FCX 124 0': ('Zooey Deschenl',
#   'http://www.wikidata.org/entity/Q191719'),
#  '00E2H310 743 0': ('Zooey Daschenellr',
#   'http://www.wikidata.org/entity/Q191719'),
#  '3N6S2FCX 9233 0': ('Scarlett Johnsonn',
#   'http://www.wikidata.org/entity/Q34436'),
#  '64OJP4G3 5138 0': ('Colin Rand Kupertnic',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  '00E2H310 12176 0': ('Scarlett Jonahsson',
#   'http://www.wikidata.org/entity/Q34436'),
#  'PZXDACJ9 6677 0': ('Nicki Minjai',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  '8YINKYDR 3669 0': ('Zachary Knight Gaflakanis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '3N6S2FCX 2972 0': ('Shia Saide Labeoaf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'NPNYM0BA 14270 0': ('Chuck Palahniuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '00E2H310 715 0': ('Zooey Deshynau',
#   'http://www.wikidata.org/entity/Q191719'),
#  'Y85GTOSS 2754 0': ('Matthew Mcconnigeh',
#   'http://www.wikidata.org/entity/Q188955'),
#  'NPNYM0BA 2602 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'AN306FAH 6848 0': ('George Reed', 'http://www.wikidata.org/entity/Q5543766'),
#  'O0UJJVBR 5510 0': ('David Cobb', 'http://www.wikidata.org/entity/Q18249422'),
#  'UEJEB27H 6136 0': ('Michael Sauerr',
#   'http://www.wikidata.org/entity/Q526872'),
#  'HCLZSPEJ 132 0': ('Algona', 'http://www.wikidata.org/entity/Q646484'),
#  'PZXDACJ9 9505 0': ('Chuck Palluniak',
#   'http://www.wikidata.org/entity/Q268181'),
#  'GINQPZQC 80 0': ('James Walker', 'http://www.wikidata.org/entity/Q941459'),
#  'NPNYM0BA 11393 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '00E2H310 7146 0': ('Matthew Maconnehy',
#   'http://www.wikidata.org/entity/Q188955'),
#  '00E2H310 5937 0': ('Matthew Machonhey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '7QNYGYI7 2054 0': ('The Atomic Clock, The Human Drum Machine',
#   'http://www.wikidata.org/entity/Q514197'),
#  '64OJP4G3 970 0': ('Zachary Knight Galifanacas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'AN306FAH 2997 0': ('Judy Martin',
#   'http://www.wikidata.org/entity/Q15998126'),
#  'CXBCCWXI 51 0': ('United States',
#   'http://www.wikidata.org/entity/Q30 http://www.wikidata.org/entity/Q28064633 http://www.wikidata.org/entity/Q28064696 http://www.wikidata.org/entity/Q28089365 http://www.wikidata.org/entity/Q65453315'),
#  '9XAJBIJV 3361 0': ('John McCloskey',
#   'http://www.wikidata.org/entity/Q6247512'),
#  'NPNYM0BA 8601 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '00E2H310 2403 0': ('Zachary Knight Galaffiak',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '8YINKYDR 5033 0': ('Makulin Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '9CSNI7FS 6425 0': ('Mike Jacobs', 'http://www.wikidata.org/entity/Q6847378'),
#  'PZXDACJ9 1501 0': ('Zachary Knight Galifianiakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9XAJBIJV 7855 0': ('Tim Steele', 'http://www.wikidata.org/entity/Q7804331'),
#  '8YINKYDR 30 0': ('Zooey Deschnel', 'http://www.wikidata.org/entity/Q191719'),
#  '00E2H310 9502 0': ('Manoj Shyamylyam',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '3N6S2FCX 8876 0': ('Pikabou Street',
#   'http://www.wikidata.org/entity/Q10101'),
#  '00E2H310 4859 0': ('Maclauc Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'KUGCH9I3 6841 0': ('Gene Moore', 'http://www.wikidata.org/entity/Q5531357'),
#  'U1FDHL7N 351 0': ('Everglades National Park',
#   'http://www.wikidata.org/entity/Q274131 http://www.wikidata.org/entity/Q20403506'),
#  'IYZYF533 233 0': ('Lincoln Motor Company',
#   'http://www.wikidata.org/entity/Q216796'),
#  'QW492LGU 1472 0': ('Michael Saenz',
#   'http://www.wikidata.org/entity/Q3030346'),
#  '3C3INQLM 13850 0': ('Chuck Palahniuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'UEJEB27H 684 0': ('Adam Millerr', 'http://www.wikidata.org/entity/Q2823980'),
#  '3C3INQLM 4472 0': ('Zachary Knight Galifianakiss',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'PZXDACJ9 2718 0': ('Zachary Knight Gafalakinos',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '3C3INQLM 10724 0': ('Manoj SShyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'KUGCH9I3 2626 0': ('Curtis Johnson',
#   'http://www.wikidata.org/entity/Q3007808 http://www.wikidata.org/entity/Q27642901'),
#  '64OJP4G3 2381 0': ('Maceuley Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'O0UJJVBR 7761 0': ('Jonathan Nelson',
#   'http://www.wikidata.org/entity/Q6274000'),
#  '64OJP4G3 816 0': ('Sarah Mcglocklain',
#   'http://www.wikidata.org/entity/Q224650'),
#  '00E2H310 490 0': ('Zooey Doochaney',
#   'http://www.wikidata.org/entity/Q191719'),
#  '3C3INQLM 5518 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'KUGCH9I3 3961 0': ('Jonathan Johnson',
#   'http://www.wikidata.org/entity/Q6273493'),
#  '3C3INQLM 886 0': ('Zooey Deschanel',
#   'http://www.wikidata.org/entity/Q191719'),
#  'LV5N8XDB 112 0': ('George Kell', 'http://www.wikidata.org/entity/Q267760'),
#  '8YINKYDR 8301 0': ('Matthew Mcconaheig',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3C3INQLM 8753 0': ('Matthew McConaugheey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'B20WIQKU 1199 0': ('Mackauleym Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'B20WIQKU 1348 0': ('Macalui Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'JA4L7KWX 12 1': ('Bof America', 'http://www.wikidata.org/entity/Q487907'),
#  'B20WIQKU 1059 0': ('Macculey Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'NPNYM0BA 14318 0': ('Chuck Palahniuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '00E2H310 6602 0': ('Matthew Maconufay',
#   'http://www.wikidata.org/entity/Q188955'),
#  '9XAJBIJV 6581 0': ('Paul Miller',
#   'http://www.wikidata.org/entity/Q7152537 http://www.wikidata.org/entity/Q7152521'),
#  'Y85GTOSS 2965 0': ('Alanis Morisettem',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'CXBCCWXI 281 0': ('Costa Rica',
#   'http://www.wikidata.org/entity/Q800 http://www.wikidata.org/entity/Q19746648'),
#  '3N6S2FCX 6906 0': ('Manoj Shammenan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '8YINKYDR 11125 0': ('Colin Rand Kapperni',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  '64OJP4G3 399 0': ('Zooey Deschanneze',
#   'http://www.wikidata.org/entity/Q191719'),
#  'O0UJJVBR 3349 0': ('Thomas Scott',
#   'http://www.wikidata.org/entity/Q16043801'),
#  'KUGCH9I3 5642 0': ('Dick Scott', 'http://www.wikidata.org/entity/Q5273349'),
#  '3C3INQLM 12836 0': ('Mark McGwiire',
#   'http://www.wikidata.org/entity/Q462481'),
#  'QW492LGU 148 0': ('Anye Elite, Anye Ellis',
#   'http://www.wikidata.org/entity/Q4778244'),
#  'PZXDACJ9 3609 0': ('Maculey Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '9CSNI7FS 5860 0': ('Michael Murphy',
#   'http://www.wikidata.org/entity/Q15460198'),
#  'PZXDACJ9 10199 0': ('Chuck Pklonik',
#   'http://www.wikidata.org/entity/Q268181'),
#  '8YINKYDR 1592 0': ('Sarah Mcvauklin',
#   'http://www.wikidata.org/entity/Q224650'),
#  '00E2H310 8449 0': ('Manoj Shamalann',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'UEJEB27H 700 0': ('Terry Alllen',
#   'http://www.wikidata.org/entity/Q1279401 http://www.wikidata.org/entity/Q20200824'),
#  'PZXDACJ9 3828 0': ('Macaulghy Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'JN0T2O5I 830 0': ('Panama City Beach',
#   'http://www.wikidata.org/entity/Q1075852 http://www.wikidata.org/entity/Q12931068'),
#  'AN306FAH 2419 0': ('Randy Robbins',
#   'http://www.wikidata.org/entity/Q7292399'),
#  'JZ22O0DD 70 0': ('Cesar Cedeno', 'http://www.wikidata.org/entity/Q5202528'),
#  'O0UJJVBR 6744 0': ('Steve Stone', 'http://www.wikidata.org/entity/Q3499130'),
#  'PZXDACJ9 1225 0': ('Sarah Mcloggan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'X1LRVWSR 7557 0': ('Scarlett Joehansen',
#   'http://www.wikidata.org/entity/Q34436'),
#  '7QNYGYI7 2299 0': ('Tommy Sancton',
#   'http://www.wikidata.org/entity/Q7817458'),
#  'O0UJJVBR 1286 0': ('Kyle Davis',
#   'http://www.wikidata.org/entity/Q6451119 http://www.wikidata.org/entity/Q11751785'),
#  'WRPAQPNC 768 0': ('Valparaiso',
#   'http://www.wikidata.org/entity/Q868888 http://www.wikidata.org/entity/Q12452233'),
#  '3C3INQLM 13468 0': ('Chuck Palahniuuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '3N6S2FCX 6772 0': ('Manoj Shavalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '00E2H310 6746 0': ('Matthew Macchonahey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3C3INQLM 5017 0': ('Shia Saide LaBeouf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'PZXDACJ9 7346 0': ('Amy Poyhler', 'http://www.wikidata.org/entity/Q230203'),
#  'O0UJJVBR 7628 0': ('James Maxwell',
#   'http://www.wikidata.org/entity/Q15528164'),
#  '3C3INQLM 3099 0': ('Zachary Knight GGalifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'TNI3UKH2 66 0': ('37',
#   'http://www.wikidata.org/entity/Q7241106 http://www.wikidata.org/entity/Q1492843 http://www.wikidata.org/entity/Q2824568'),
#  'O0UJJVBR 765 0': ('Brad Walker', 'http://www.wikidata.org/entity/Q353619'),
#  'WRPAQPNC 667 0': ('Reno', 'http://www.wikidata.org/entity/Q49225'),
#  'Y85GTOSS 2032 0': ('Matthew Mcconahew',
#   'http://www.wikidata.org/entity/Q188955'),
#  'UEJEB27H 3710 0': ('Tinkk', 'http://www.wikidata.org/entity/Q20687394'),
#  '9XAJBIJV 4735 0': ('Ted Cook',
#   'http://www.wikidata.org/entity/Q7693086 http://www.wikidata.org/entity/Q21185207'),
#  'PZXDACJ9 831 0': ('Sarah Maclean', 'http://www.wikidata.org/entity/Q224650'),
#  '00E2H310 10161 0': ('Mark Mcguire',
#   'http://www.wikidata.org/entity/Q462481'),
#  'TNI3UKH2 77 0': ('44', 'http://www.wikidata.org/entity/Q1379733'),
#  'NPNYM0BA 5114 0': ('Shia Saide LaBeouf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'O0UJJVBR 2389 0': ('John McCarthy',
#   'http://www.wikidata.org/entity/Q6247448'),
#  'NPNYM0BA 6011 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '64OJP4G3 2815 0': ('Matthew Mccaugnehay',
#   'http://www.wikidata.org/entity/Q188955'),
#  'O0BECB72 204 0': ('Serbia',
#   'http://www.wikidata.org/entity/Q403 http://www.wikidata.org/entity/Q12944990 http://www.wikidata.org/entity/Q15722975 http://www.wikidata.org/entity/Q19747765 http://www.wikidata.org/entity/Q19750161 http://www.wikidata.org/entity/Q20087839'),
#  '3N6S2FCX 895 0': ('Sarah Mclauhan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '9XAJBIJV 1240 0': ('Joe Hastings',
#   'http://www.wikidata.org/entity/Q6210237'),
#  'NPNYM0BA 1019 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'K3X3L22Y 153 0': ('Faabrics',
#   'http://www.wikidata.org/entity/Q28823 http://www.wikidata.org/entity/Q1106512 http://www.wikidata.org/entity/Q11836851 http://www.wikidata.org/entity/Q12826869 http://www.wikidata.org/entity/Q13179828'),
#  'PZXDACJ9 5831 0': ('Matthew Mcconahiew',
#   'http://www.wikidata.org/entity/Q188955'),
#  '29BNEL1Q 1634 0': ('Vinay Singhh',
#   'http://www.wikidata.org/entity/Q7931387'),
#  'X1LRVWSR 241 0': ('Zooey Dashacnell',
#   'http://www.wikidata.org/entity/Q191719'),
#  '3N6S2FCX 297 0': ('Zooey Duchenell',
#   'http://www.wikidata.org/entity/Q191719'),
#  '64OJP4G3 1975 0': ('Shia Saide Laboufd',
#   'http://www.wikidata.org/entity/Q180942'),
#  'NPNYM0BA 4185 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9XAJBIJV 1663 0': ('Craig Robertson',
#   'http://www.wikidata.org/entity/Q5181380'),
#  '8YINKYDR 7818 0': ('Matthew Michonaghey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '64OJP4G3 3479 0': ('Matthew Mcouhnahey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '6I7ET24J 574 0': ('Malverrn',
#   'http://www.wikidata.org/entity/Q79694 http://www.wikidata.org/entity/Q12939563'),
#  'NPNYM0BA 6513 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'KUGCH9I3 7478 0': ('Billy Wright',
#   'http://www.wikidata.org/entity/Q18159247'),
#  '3C3INQLM 2370 0': ('Zachary Knight Galifianakiss',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '64OJP4G3 5737 0': ('Chuck Pahaulick',
#   'http://www.wikidata.org/entity/Q268181'),
#  'QNP7O8L5 283 0': ('Casper',
#   'http://www.wikidata.org/entity/Q324686 http://www.wikidata.org/entity/Q62701053'),
#  'UEJEB27H 2344 0': ('David Meltzerr',
#   'http://www.wikidata.org/entity/Q19664344'),
#  'O0UJJVBR 1382 0': ('Derek Anderson',
#   'http://www.wikidata.org/entity/Q4993894 http://www.wikidata.org/entity/Q18086320'),
#  'X1LRVWSR 1547 0': ('Zachary Knight Galafanakid',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'KUGCH9I3 7508 0': ('Steven Wright',
#   'http://www.wikidata.org/entity/Q7615401'),
#  '00E2H310 3803 0': ('Shia Saide Lbouf',
#   'http://www.wikidata.org/entity/Q180942'),
#  '8YINKYDR 12074 0': ('Chuck Pahleniuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '8YINKYDR 13990 0': ('Scarlett Johhannson',
#   'http://www.wikidata.org/entity/Q34436'),
#  'HCLZSPEJ 653 0': ('South Haven', 'http://www.wikidata.org/entity/Q953719'),
#  '1C9LFOKN 299 0': ('Greenvile',
#   'http://www.wikidata.org/entity/Q574192 http://www.wikidata.org/entity/Q61367980'),
#  'O0UJJVBR 6895 0': ('Larry Douglas',
#   'http://www.wikidata.org/entity/Q6490216'),
#  '8YINKYDR 6422 0': ('Matthew Mcconnahagh',
#   'http://www.wikidata.org/entity/Q188955'),
#  'MANO2PKR 1 0': ('Abkhazia',
#   'http://www.wikidata.org/entity/Q23334 http://www.wikidata.org/entity/Q19746241'),
#  '3C3INQLM 2622 0': ('Zachary Knight Galifianakiss',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'GINQPZQC 22 0': ('George Forbes', 'http://www.wikidata.org/entity/Q5539342'),
#  '9CSNI7FS 4987 0': ('Todd Richards',
#   'http://www.wikidata.org/entity/Q2438502'),
#  '64OJP4G3 2663 0': ('Mkculin Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'FF00TEZG 188 0': ('Texas',
#   'http://www.wikidata.org/entity/Q1439 http://www.wikidata.org/entity/Q13181477 http://www.wikidata.org/entity/Q19748264'),
#  'X1LRVWSR 658 0': ('Sarah Maclacen',
#   'http://www.wikidata.org/entity/Q224650'),
#  'X1LRVWSR 5871 0': ('Manoj Shamalyab',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'NPNYM0BA 9878 0': ('Alanis Morissette',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'KUGCH9I3 8199 0': ('Jack Perkins',
#   'http://www.wikidata.org/entity/Q2748009'),
#  'AN306FAH 6530 0': ('Jack Turner', 'http://www.wikidata.org/entity/Q3805671'),
#  '00E2H310 8256 0': ('Amy Poehlitz', 'http://www.wikidata.org/entity/Q230203'),
#  '3C3INQLM 11873 0': ('Manoj Shyamalann',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '64OJP4G3 2422 0': ('Maccughy Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '8YINKYDR 12774 0': ('Chuck Polahnuik',
#   'http://www.wikidata.org/entity/Q268181'),
#  'UEJEB27H 1511 0': ('Kevvvin McKee',
#   'http://www.wikidata.org/entity/Q19571843'),
#  'NPNYM0BA 11320 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'O0UJJVBR 3097 0': ('Richard Williams',
#   'http://www.wikidata.org/entity/Q14950382'),
#  '9XAJBIJV 5037 0': ('Neil Komadoski',
#   'http://www.wikidata.org/entity/Q6380589'),
#  'GY7KNULP 105 0': ('Crave Entertainment',
#   'http://www.wikidata.org/entity/Q3002349'),
#  '3N6S2FCX 1980 0': ('Zachary Knight Galafanackious',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9XAJBIJV 824 0': ('Mike Esposito',
#   'http://www.wikidata.org/entity/Q3313297'),
#  '8YINKYDR 4518 0': ('Shia Saide Lebeauxf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'UEJEB27H 5448 0': ('Michael Rothh',
#   'http://www.wikidata.org/entity/Q6833984'),
#  '8YINKYDR 13681 0': ('Scarlett Johaanson',
#   'http://www.wikidata.org/entity/Q34436'),
#  '3N6S2FCX 6897 0': ('Manoj Shamalock',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'UEJEB27H 7582 0': ('Carlos Roggerss',
#   'http://www.wikidata.org/entity/Q3660129'),
#  'B20WIQKU 297 0': ('Sarah Mclackand',
#   'http://www.wikidata.org/entity/Q224650'),
#  '8YINKYDR 13140 0': ('Chuck Pallenchuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '3C3INQLM 8783 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3C3INQLM 15186 0': ('Scarlett Johansson',
#   'http://www.wikidata.org/entity/Q34436'),
#  '8MKQXO18 152 0': ('Monaco',
#   'http://www.wikidata.org/entity/Q235 http://www.wikidata.org/entity/Q12939323 http://www.wikidata.org/entity/Q13171625 http://www.wikidata.org/entity/Q19719092 http://www.wikidata.org/entity/Q19747409 http://www.wikidata.org/entity/Q20599324 http://www.wikidata.org/entity/Q65453561'),
#  'B20WIQKU 1781 0': ('Matthew Mccanaughewm',
#   'http://www.wikidata.org/entity/Q188955'),
#  'OHGI1JNY 17 1': ('Tanganyika', 'http://www.wikidata.org/entity/Q5511'),
#  'KUGCH9I3 2523 0': ('Charles Davis',
#   'http://www.wikidata.org/entity/Q22958922'),
#  'PZXDACJ9 2619 0': ('Zachary Knight Galafrancis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'PZXDACJ9 8000 0': ('Manoj Shamahla',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'B20WIQKU 1631 0': ('Matthew Macconaughty',
#   'http://www.wikidata.org/entity/Q188955'),
#  'UEJEB27H 1747 0': ('Keith Robinson',
#   'http://www.wikidata.org/entity/Q1384231'),
#  'KUGCH9I3 1189 0': ('Sam Smith', 'http://www.wikidata.org/entity/Q3946359'),
#  'X1LRVWSR 2818 0': ('Micali Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'AN306FAH 1460 0': ('Flavio Tosi', 'http://www.wikidata.org/entity/Q5458113'),
#  'KUGCH9I3 5429 0': ('Don Patterson',
#   'http://www.wikidata.org/entity/Q5293284'),
#  'X1LRVWSR 6431 0': ('Mark Mcgueir', 'http://www.wikidata.org/entity/Q462481'),
#  '9XAJBIJV 2094 0': ('Mark Lee', 'http://www.wikidata.org/entity/Q6768535'),
#  'O0UJJVBR 5371 0': ('Perry Smith', 'http://www.wikidata.org/entity/Q7169891'),
#  '29BNEL1Q 194 0': ('AArtur Dyson', 'http://www.wikidata.org/entity/Q4801607'),
#  'NPNYM0BA 943 0': ('Zooey Deschanel',
#   'http://www.wikidata.org/entity/Q191719'),
#  '64OJP4G3 6133 0': ('Scarlett Jhoannson',
#   'http://www.wikidata.org/entity/Q34436'),
#  'KUGCH9I3 1808 0': ('Alan Campbell',
#   'http://www.wikidata.org/entity/Q9144120'),
#  '8YINKYDR 11959 0': ('Chuck Pahalinuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'LV5N8XDB 126 0': ('Bob Johnson', 'http://www.wikidata.org/entity/Q4932947'),
#  'O0UJJVBR 5581 0': ('Ted Prior', 'http://www.wikidata.org/entity/Q7693625'),
#  '8YINKYDR 9138 0': ('Alanis Morrissee',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'HQCEC5NO 633 0': ('Ocaen City', 'http://www.wikidata.org/entity/Q1017603'),
#  'UEJEB27H 3421 0': ('Mike Montgomery',
#   'http://www.wikidata.org/entity/Q6848082'),
#  '64OJP4G3 3778 0': ('Matthew Maccaunaghee',
#   'http://www.wikidata.org/entity/Q188955'),
#  'AN306FAH 830 0': ('John West',
#   'http://www.wikidata.org/entity/Q6263638 http://www.wikidata.org/entity/Q56612472'),
#  'X1LRVWSR 1648 0': ('Zachary Knight Galliffnakiss',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '00E2H310 10805 0': ('Chuck Pallahunick',
#   'http://www.wikidata.org/entity/Q268181'),
#  'NPNYM0BA 3337 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'PZXDACJ9 8530 0': ('Colin Rand Kappernak',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'X1LRVWSR 1582 0': ('Zachary Knight Galifnagis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '29BNEL1Q 868 0': ('Leonardo Figueroa',
#   'http://www.wikidata.org/entity/Q20015060'),
#  'X1LRVWSR 4594 0': ('Matthew Mackonaghey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '00E2H310 11321 0': ('Chuck Palagniuck',
#   'http://www.wikidata.org/entity/Q268181'),
#  'X23TMJ3R 1019 0': ('Hansi Kürsch', 'http://www.wikidata.org/entity/Q57752'),
#  'CAF0E2JH 78 0': ('44', 'http://www.wikidata.org/entity/Q1379733'),
#  'X1LRVWSR 3957 0': ('Matthew Macohnahe',
#   'http://www.wikidata.org/entity/Q188955'),
#  'UEJEB27H 6491 0': ('Charles Kingg',
#   'http://www.wikidata.org/entity/Q2959529'),
#  'X1LRVWSR 4996 0': ('Alanis Moruset',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'X1LRVWSR 746 0': ('Sarah Mcglauglain',
#   'http://www.wikidata.org/entity/Q224650'),
#  'O0UJJVBR 3510 0': ('Tom Scott', 'http://www.wikidata.org/entity/Q7817503'),
#  '3N6S2FCX 3987 0': ('Maccaulhy Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '2EZKB5RU 907 0': ('Matthew Mccanaughah',
#   'http://www.wikidata.org/entity/Q188955'),
#  '8YINKYDR 2487 0': ('Zachary Knight Goulfianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'X1LRVWSR 1266 0': ('Zachary Knight Galifeanakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '8YINKYDR 6777 0': ('Matthew Mcconhagey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'HQCEC5NO 811 0': ('Soildiers Grove',
#   'http://www.wikidata.org/entity/Q2574546'),
#  '3C3INQLM 1926 0': ('Sarah McLachlann',
#   'http://www.wikidata.org/entity/Q224650'),
#  'NPNYM0BA 1708 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '1C7N45JA 18 0': ('Watford',
#   'http://www.wikidata.org/entity/Q2714 http://www.wikidata.org/entity/Q13132230'),
#  'O0UJJVBR 2521 0': ('Tim Callahan',
#   'http://www.wikidata.org/entity/Q17626517'),
#  '00E2H310 8298 0': ('Amy Pohla', 'http://www.wikidata.org/entity/Q230203'),
#  'LV5N8XDB 10 0': ('Jeff Kent', 'http://www.wikidata.org/entity/Q3106533'),
#  'KUGCH9I3 6569 0': ('Jack Turner', 'http://www.wikidata.org/entity/Q3805671'),
#  '3C3INQLM 9591 0': ('Nicki Minaj',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  '0IR0XIUW 337 0': ('Maurice Trintignant',
#   'http://www.wikidata.org/entity/Q171438'),
#  'B20WIQKU 2620 0': ('Mark Mcguirrel',
#   'http://www.wikidata.org/entity/Q462481'),
#  'S8UOQYBG 282 0': ('Truemp koi-da', 'NIL'),
#  '8YINKYDR 7494 0': ('Matthew Mccoanghue',
#   'http://www.wikidata.org/entity/Q188955'),
#  '64OJP4G3 2052 0': ('Shia Saide Labaeof',
#   'http://www.wikidata.org/entity/Q180942'),
#  'PZXDACJ9 2655 0': ('Zachary Knight Galafinias',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'O0UJJVBR 3651 0': ('Phil Brown',
#   'http://www.wikidata.org/entity/Q325398 http://www.wikidata.org/entity/Q19947849'),
#  'UEJEB27H 5992 0': ('Alice Fischeerr',
#   'http://www.wikidata.org/entity/Q15997486'),
#  '7QNYGYI7 2071 0': ('The Blues Doctor',
#   'http://www.wikidata.org/entity/Q5307699'),
#  '9XAJBIJV 6871 0': ('Steve Forrest',
#   'http://www.wikidata.org/entity/Q1442301 http://www.wikidata.org/entity/Q5693096'),
#  'NPNYM0BA 345 0': ('Zooey Deschanel',
#   'http://www.wikidata.org/entity/Q191719'),
#  '9CSNI7FS 3515 0': ('Robert Arnold',
#   'http://www.wikidata.org/entity/Q18706436 http://www.wikidata.org/entity/Q18719279'),
#  'MSCT8MJD 40 0': ('the Czech Republic',
#   'http://www.wikidata.org/entity/Q213 http://www.wikidata.org/entity/Q19694991 http://www.wikidata.org/entity/Q19746786 http://www.wikidata.org/entity/Q55670153 http://www.wikidata.org/entity/Q65427001'),
#  '00E2H310 9046 0': ('Manoj Shemalen',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '3N6S2FCX 4709 0': ('Matthew Maconeoughy',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3C3INQLM 13776 0': ('Chuck Palahniuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'NPNYM0BA 11235 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'UEJEB27H 5203 0': ('George Jones',
#   'http://www.wikidata.org/entity/Q1291920'),
#  'AN306FAH 3656 0': ('Donald Cook', 'http://www.wikidata.org/entity/Q384062'),
#  'UEJEB27H 2428 0': ('Alan Baxterr',
#   'http://www.wikidata.org/entity/Q1346084'),
#  'UEJEB27H 3824 0': ('Brandon Joness',
#   'http://www.wikidata.org/entity/Q4251643'),
#  'UEJEB27H 1763 0': ('Frank Burns',
#   'http://www.wikidata.org/entity/Q16240907'),
#  'UEJEB27H 5911 0': ('Larrry Smith',
#   'http://www.wikidata.org/entity/Q1607746'),
#  '8YINKYDR 7072 0': ('Matthew Mccoughnuhey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'PZXDACJ9 6768 0': ('Nicki Mignag',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  'HTF6MVY9 405 0': ('Modesto', 'http://www.wikidata.org/entity/Q204561'),
#  'X1LRVWSR 2707 0': ('Mackay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'NPNYM0BA 9516 0': ('Nicki Minaj',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  '8YINKYDR 5804 0': ('Maccaulli Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '9XAJBIJV 7814 0': ('Chris Pappas',
#   'http://www.wikidata.org/entity/Q5107684'),
#  'NPNYM0BA 7154 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3N6S2FCX 1375 0': ('Zachary Knight Galafinkas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '3DOM5NIW 38 0': ('State of Qatar',
#   'http://www.wikidata.org/entity/Q846 http://www.wikidata.org/entity/Q12917542 http://www.wikidata.org/entity/Q19746525 http://www.wikidata.org/entity/Q20084404 http://www.wikidata.org/entity/Q21213165 http://www.wikidata.org/entity/Q65453610'),
#  '3C3INQLM 8317 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'PZXDACJ9 6545 0': ('Matthew Monoughy',
#   'http://www.wikidata.org/entity/Q188955'),
#  'Y85GTOSS 3402 0': ('Manoj Shadelay',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'X1LRVWSR 3145 0': ('Maccolcey Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'S8UOQYBG 190 0': ('Cke usevi, te stru', 'NIL'),
#  '8YINKYDR 5163 0': ('Mccoulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'WZL61XYS 9 0': ('Albertvile', 'http://www.wikidata.org/entity/Q79675'),
#  '9XAJBIJV 4392 0': ('Charles Hudson',
#   'http://www.wikidata.org/entity/Q1064907'),
#  '64OJP4G3 2004 0': ('Shia Saide Labefouf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'PZXDACJ9 4008 0': ('Micalli Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '00E2H310 4323 0': ('Maucaly Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '0D70DN48 361 0': ('Little Long Pond (Wareham, Massachusetts)',
#   'http://www.wikidata.org/entity/Q6650726'),
#  '9XAJBIJV 1198 0': ('Larry Beil', 'http://www.wikidata.org/entity/Q21176137'),
#  '3N6S2FCX 8812 0': ('Chuck Palenyek',
#   'http://www.wikidata.org/entity/Q268181'),
#  'KUGCH9I3 5111 0': ('Lawrence Johnson',
#   'http://www.wikidata.org/entity/Q937963'),
#  'NPNYM0BA 1791 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'AN306FAH 3796 0': ('Stan White', 'http://www.wikidata.org/entity/Q7597956'),
#  '64OJP4G3 3115 0': ('Matthew Macconaguey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'S8UOQYBG 558 0': ('He strug sle slio', 'NIL'),
#  'PZXDACJ9 5668 0': ('Matthew Maconachie',
#   'http://www.wikidata.org/entity/Q188955'),
#  '00E2H310 899 0': ('Sarah Mcglaughan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '29BNEL1Q 124 0': ('André Moreiraaa',
#   'http://www.wikidata.org/entity/Q18746588 http://www.wikidata.org/entity/Q18416534'),
#  '8YINKYDR 2583 0': ('Zachary Knight Ganafalakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9CSNI7FS 5793 0': ('Jack Conway', 'http://www.wikidata.org/entity/Q6111799'),
#  '7QNYGYI7 217 0': ('Benny Latimore',
#   'http://www.wikidata.org/entity/Q6496167'),
#  '3N6S2FCX 3942 0': ('Mackallin Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '2VRS31OV 712 0': ('Okeechobee', 'http://www.wikidata.org/entity/Q587146'),
#  'FWSGRDQ3 80 0': ('Movimento dei Comunisti Unitari',
#   'http://www.wikidata.org/entity/Q463318'),
#  'QW492LGU 1428 0': ('Metro',
#   'http://www.wikidata.org/entity/Q16235273 http://www.wikidata.org/entity/Q71474380'),
#  'UURPYBGQ 50 0': ('Mississippi',
#   'http://www.wikidata.org/entity/Q1494 http://www.wikidata.org/entity/Q13184917 http://www.wikidata.org/entity/Q19749788'),
#  'Y85GTOSS 1415 0': ('Zachary Knight Galfakianis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'WZL61XYS 107 0': ('Chadborn',
#   'http://www.wikidata.org/entity/Q2045194 http://www.wikidata.org/entity/Q34791288'),
#  'HQCEC5NO 213 0': ('Crested Bute',
#   'http://www.wikidata.org/entity/Q592729 http://www.wikidata.org/entity/Q12920698 http://www.wikidata.org/entity/Q49348039'),
#  '8YINKYDR 8615 0': ('Nicki Manag',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  '24W5SSRB 103 0': ('Crosby & Nash',
#   'http://www.wikidata.org/entity/Q5188022'),
#  'WZL61XYS 497 0': ('Oceechobee', 'http://www.wikidata.org/entity/Q587146'),
#  '9CSNI7FS 7343 0': ('Harvey Clark',
#   'http://www.wikidata.org/entity/Q3128025'),
#  'UEJEB27H 1920 0': ('Bobby Lutzz', 'http://www.wikidata.org/entity/Q4935309'),
#  'ZZNW93IV 683 0': ('Paterson', 'http://www.wikidata.org/entity/Q138391'),
#  'IZF82AX9 35 0': ('Florida',
#   'http://www.wikidata.org/entity/Q812 http://www.wikidata.org/entity/Q13183704 http://www.wikidata.org/entity/Q19749361'),
#  'KUGCH9I3 3405 0': ('Fred Davis', 'http://www.wikidata.org/entity/Q584174'),
#  'NPNYM0BA 9571 0': ('Nicki Minaj',
#   'http://www.wikidata.org/entity/Q162202 http://www.wikidata.org/entity/Q11846010 http://www.wikidata.org/entity/Q3480872 http://www.wikidata.org/entity/Q55416579 http://www.wikidata.org/entity/Q55416669 http://www.wikidata.org/entity/Q55417181 http://www.wikidata.org/entity/Q55417838 http://www.wikidata.org/entity/Q55417909 http://www.wikidata.org/entity/Q55424170 http://www.wikidata.org/entity/Q55424413 http://www.wikidata.org/entity/Q55739720 http://www.wikidata.org/entity/Q55739740 http://www.wikidata.org/entity/Q55739757 http://www.wikidata.org/entity/Q55739770 http://www.wikidata.org/entity/Q55739786 http://www.wikidata.org/entity/Q55739821 http://www.wikidata.org/entity/Q55739884'),
#  'O0UJJVBR 1128 0': ('William Moore',
#   'http://www.wikidata.org/entity/Q8015767'),
#  '00E2H310 11921 0': ('Pickabee Street',
#   'http://www.wikidata.org/entity/Q10101'),
#  'CXBCCWXI 238 0': ('Philippines',
#   'http://www.wikidata.org/entity/Q928 http://www.wikidata.org/entity/Q13055398 http://www.wikidata.org/entity/Q13177462 http://www.wikidata.org/entity/Q13196158 http://www.wikidata.org/entity/Q19747083 http://www.wikidata.org/entity/Q20086683 http://www.wikidata.org/entity/Q31467298'),
#  'MANO2PKR 232 0': ('Thailand',
#   'http://www.wikidata.org/entity/Q869 http://www.wikidata.org/entity/Q19746880 http://www.wikidata.org/entity/Q20086245 http://www.wikidata.org/entity/Q27943301'),
#  '9CSNI7FS 2490 0': ('Bob Bailey', 'http://www.wikidata.org/entity/Q2907577'),
#  'AN306FAH 7920 0': ('Chuck Smith', 'http://www.wikidata.org/entity/Q5115712'),
#  'X23TMJ3R 1505 0': ('Muhammed Suiçmez',
#   'http://www.wikidata.org/entity/Q3110485'),
#  '9XAJBIJV 1895 0': ('John Marshall',
#   'http://www.wikidata.org/entity/Q11727936 http://www.wikidata.org/entity/Q19664645'),
#  'PZXDACJ9 2772 0': ('Zachary Knight Galfynakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'NYFX4M8T 97 0': ('India',
#   'http://www.wikidata.org/entity/Q668 http://www.wikidata.org/entity/Q1117 http://www.wikidata.org/entity/Q20518472 http://www.wikidata.org/entity/Q65455195'),
#  'PZXDACJ9 6886 0': ('Alanis Moriss',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  '8YINKYDR 9983 0': ('Manoj Shylman',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '8YINKYDR 12667 0': ('Chuck Palonyuck',
#   'http://www.wikidata.org/entity/Q268181'),
#  'NPNYM0BA 1942 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '3N6S2FCX 182 0': ('Zooey Deyschannel',
#   'http://www.wikidata.org/entity/Q191719'),
#  '64OJP4G3 4716 0': ('Manoj Shamilae',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '3C3INQLM 6558 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '9CSNI7FS 425 0': ('David Thomas', 'http://www.wikidata.org/entity/Q3703350'),
#  'NPNYM0BA 1624 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '9CSNI7FS 1795 0': ('Brian Smith', 'http://www.wikidata.org/entity/Q4965328'),
#  'NPNYM0BA 6822 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '3C3INQLM 3277 0': ('Zachary Knight Galifianakiss',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9CSNI7FS 1287 0': ('Cornell Green',
#   'http://www.wikidata.org/entity/Q5171526'),
#  'AN306FAH 85 0': ('Adam Warren', 'http://www.wikidata.org/entity/Q901842'),
#  'NPNYM0BA 12379 0': ('Colin Rand Kaepernick',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'HTF6MVY9 386 0': ('McCloud', 'http://www.wikidata.org/entity/Q3306166'),
#  'UEJEB27H 621 0': ('Terry Jones', 'http://www.wikidata.org/entity/Q7704580'),
#  'AN306FAH 5380 0': ('Chris Stewart',
#   'http://www.wikidata.org/entity/Q4068880'),
#  '8YINKYDR 11186 0': ('Colin Rand Kapernicis',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'AN306FAH 4941 0': ('Paul Blair', 'http://www.wikidata.org/entity/Q7149398'),
#  'KUGCH9I3 6621 0': ('Chris Hanson',
#   'http://www.wikidata.org/entity/Q3675501'),
#  'UEJEB27H 2992 0': ('Dan Jenningss',
#   'http://www.wikidata.org/entity/Q5213751'),
#  '3C3INQLM 2494 0': ('Zachary Knight Galifianakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'PZXDACJ9 8022 0': ('Manoj Shayalm',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'KUGCH9I3 4300 0': ('Paul McDonald',
#   'http://www.wikidata.org/entity/Q4216674'),
#  'X23TMJ3R 1530 0': ('Oliver Palotai',
#   'http://www.wikidata.org/entity/Q2629091 http://www.wikidata.org/entity/Q15436753'),
#  'PZXDACJ9 8009 0': ('Manoj Shahalayan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'PZXDACJ9 8674 0': ('Colin Rand Kaepenikk',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  '3LG8J4MX 22 0': ('Labelle',
#   'http://www.wikidata.org/entity/Q1426945 http://www.wikidata.org/entity/Q6459598'),
#  'I0ENR9U5 125 0': ('Laos',
#   'http://www.wikidata.org/entity/Q819 http://www.wikidata.org/entity/Q19747558 http://www.wikidata.org/entity/Q20087423'),
#  'B20WIQKU 174 0': ('Zooey Dachinell',
#   'http://www.wikidata.org/entity/Q191719'),
#  '9XAJBIJV 2766 0': ('Brian McCann',
#   'http://www.wikidata.org/entity/Q1059152'),
#  '9CSNI7FS 4619 0': ('Henry Williams',
#   'http://www.wikidata.org/entity/Q5730257'),
#  'CHZGO92A 10 0': ('5',
#   'http://www.wikidata.org/entity/Q11815 http://www.wikidata.org/entity/Q12952065'),
#  'X1LRVWSR 7695 0': ('Scarlett Johanas',
#   'http://www.wikidata.org/entity/Q34436'),
#  'X1LRVWSR 3006 0': ('Mccahley Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '2EZKB5RU 1183 0': ('Manoj Shanamalan',
# ...
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '64OJP4G3 3668 0': ('Matthew Mccuagnhay',
#   'http://www.wikidata.org/entity/Q188955'),
#  'AN306FAH 2954 0': ('Roy Bennett',
#   'http://www.wikidata.org/entity/Q18684745'),
#  'KUGCH9I3 6508 0': ('Bill Brown', 'http://www.wikidata.org/entity/Q4908287'),
#  'UEJEB27H 2121 0': ('Jim Pederson',
#   'http://www.wikidata.org/entity/Q21176617'),
#  '3C3INQLM 5659 0': ('Macauulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'PZXDACJ9 3593 0': ('Shia Saide Lebeouph',
#   'http://www.wikidata.org/entity/Q180942'),
#  'EQZ21058 537 0': ('Stetson Pond (Pembroke, Massachusetts)',
#   'http://www.wikidata.org/entity/Q7348894'),
#  'PZXDACJ9 3042 0': ('Zachary Knight Galifynakas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'E45F8QW2 927 0': ('Maksim Igorevich Shvagirev',
#   'http://www.wikidata.org/entity/Q18171717'),
#  '8YINKYDR 10348 0': ('Manoj Shablun',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '00E2H310 3818 0': ('Shia Saide Lebeauof',
#   'http://www.wikidata.org/entity/Q180942'),
#  '3C3INQLM 8988 0': ('Matthew McConaugheyy',
#   'http://www.wikidata.org/entity/Q188955'),
#  '1C9LFOKN 989 0': ('Newburyport', 'http://www.wikidata.org/entity/Q54134'),
#  'NPNYM0BA 737 0': ('Zooey Deschanel',
#   'http://www.wikidata.org/entity/Q191719'),
#  'Y85GTOSS 3920 0': ('Mark Mcoure', 'http://www.wikidata.org/entity/Q462481'),
#  'Y85GTOSS 1485 0': ('Shia Saide Lebeaff',
#   'http://www.wikidata.org/entity/Q180942'),
#  'UEJEB27H 1780 0': ('Sylvia', 'http://www.wikidata.org/entity/Q2374156'),
#  'EQZ21058 310 0': ('Lake Nippenicket',
#   'http://www.wikidata.org/entity/Q6477115'),
#  'I0ENR9U5 215 0': ('South Africa',
#   'http://www.wikidata.org/entity/Q258 http://www.wikidata.org/entity/Q19711603 http://www.wikidata.org/entity/Q19746885 http://www.wikidata.org/entity/Q25662859 http://www.wikidata.org/entity/Q25704466 http://www.wikidata.org/entity/Q2760405 http://www.wikidata.org/entity/Q65450059'),
#  '9CSNI7FS 5634 0': ('Alan Jones', 'http://www.wikidata.org/entity/Q19831854'),
#  'NPNYM0BA 11863 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'AN306FAH 4156 0': ('Keith Williams',
#   'http://www.wikidata.org/entity/Q3194797'),
#  'KUGCH9I3 3033 0': ('Jeff Chapman',
#   'http://www.wikidata.org/entity/Q6173557'),
#  'X1LRVWSR 3483 0': ('Matthew Mccoughahey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'X1LRVWSR 7101 0': ('Chuck Palahainauk',
#   'http://www.wikidata.org/entity/Q268181'),
#  'S7DQFOD4 24 0': ('ibrophen',
#   'http://www.wikidata.org/entity/Q186969 http://www.wikidata.org/entity/Q25487880'),
#  'X23TMJ3R 1904 0': ('Zaytoven', 'http://www.wikidata.org/entity/Q8067580'),
#  'PZXDACJ9 8695 0': ('Colin Rand Kaburnuick',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  '8YINKYDR 3868 0': ('Zachary Knight Galiginafais',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '8YINKYDR 7755 0': ('Matthew Mcconuhegh',
#   'http://www.wikidata.org/entity/Q188955'),
#  'PZXDACJ9 2946 0': ('Zachary Knight Galadiniakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '3C3INQLM 8588 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'PZXDACJ9 1887 0': ('Zachary Knight Galiphinacks',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'PZXDACJ9 4905 0': ('Matthew Mcaughnhey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '8YINKYDR 3220 0': ('Zachary Knight Galifianiakkis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'MZ0BI8NN 20 0': ('Wolverhampton Wandererss',
#   'http://www.wikidata.org/entity/Q19500'),
#  'UEJEB27H 6338 0': ('TTom BBarrett',
#   'http://www.wikidata.org/entity/Q18684588'),
#  '3C3INQLM 11425 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '00E2H310 1505 0': ('Sarah Mglaughan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '00E2H310 9197 0': ('Manoj Shamolahn',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '8YINKYDR 4281 0': ('Shia Saide Lebeuff',
#   'http://www.wikidata.org/entity/Q180942'),
#  'NPNYM0BA 7541 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  'KUGCH9I3 5834 0': ('James Sanders',
#   'http://www.wikidata.org/entity/Q6142752'),
#  'OZYCQ769 41 1': ('Issyk-Kul',
#   'http://www.wikidata.org/entity/Q42191 http://www.wikidata.org/entity/Q56057537'),
#  'O0UJJVBR 5286 0': ('Mark Parkinson',
#   'http://www.wikidata.org/entity/Q881181 http://www.wikidata.org/entity/Q11776217'),
#  'O0UJJVBR 1703 0': ('Daniel Miller',
#   'http://www.wikidata.org/entity/Q17517226 http://www.wikidata.org/entity/Q97376130'),
#  'HTF6MVY9 395 0': ('Metropolis',
#   'http://www.wikidata.org/entity/Q304036 http://www.wikidata.org/entity/Q12636744 http://www.wikidata.org/entity/Q12939076'),
#  'UEJEB27H 7831 0': ('George Dawson',
#   'http://www.wikidata.org/entity/Q5538438'),
#  '00E2H310 11854 0': ('Pikabpo Street',
#   'http://www.wikidata.org/entity/Q10101'),
#  '2EZKB5RU 958 0': ('Matthew Mccauhne',
#   'http://www.wikidata.org/entity/Q188955'),
#  'UEJEB27H 5696 0': ('Jackie Leee',
#   'http://www.wikidata.org/entity/Q18637628'),
#  '3N6S2FCX 8301 0': ('Chuck Paullinick',
#   'http://www.wikidata.org/entity/Q268181'),
#  'X23TMJ3R 1070 0': ('Jeff Sipe', 'http://www.wikidata.org/entity/Q6174988'),
#  'HGYG2DVU 486 0': ('Richmend',
#   'http://www.wikidata.org/entity/Q43421 http://www.wikidata.org/entity/Q12940898 http://www.wikidata.org/entity/Q49278652 http://www.wikidata.org/entity/Q49298102'),
#  '8YINKYDR 1676 0': ('Sarah Mglochlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '9XAJBIJV 1083 0': ('Steve Davis', 'http://www.wikidata.org/entity/Q7612358'),
#  '9XAJBIJV 3744 0': ('Leon Brown',
#   'http://www.wikidata.org/entity/Q6524542 http://www.wikidata.org/entity/Q9021481'),
#  'HCLZSPEJ 104 0': ('Soux Falls', 'http://www.wikidata.org/entity/Q131335'),
#  '9CSNI7FS 3796 0': ('Henry Turner',
#   'http://www.wikidata.org/entity/Q2401592'),
#  'UEJEB27H 2274 0': ('John Wilkinson',
#   'http://www.wikidata.org/entity/Q6264051'),
#  '0D70DN48 427 0': ('Muddy Pond (Kingston, Massachusetts)',
#   'http://www.wikidata.org/entity/Q6931670'),
#  'UEJEB27H 987 0': ('Jim Thomas', 'http://www.wikidata.org/entity/Q16105233'),
#  '3C3INQLM 8038 0': ('Matthew McConaugheyy',
#   'http://www.wikidata.org/entity/Q188955'),
#  'B20WIQKU 2543 0': ('Colin Rand Kaperneac',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  '64OJP4G3 625 0': ('Sarah Mcglackfen',
#   'http://www.wikidata.org/entity/Q224650'),
#  '8YINKYDR 10665 0': ('Manoj Shamilaym',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '3C3INQLM 5923 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'X1LRVWSR 7642 0': ('Scarlett Jhoason',
#   'http://www.wikidata.org/entity/Q34436'),
#  '3N6S2FCX 7039 0': ('Manoj Syamalam',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'EV6LDIB8 76 0': ('John Tudor', 'http://www.wikidata.org/entity/Q6261365'),
#  '3C3INQLM 8242 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '8YINKYDR 9099 0': ('Alanis Morrissei',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  '8YINKYDR 4333 0': ('Shia Saide Lebou',
#   'http://www.wikidata.org/entity/Q180942'),
#  '3C3INQLM 12796 0': ('Colin Rand Kaepernickk',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'O0UJJVBR 8231 0': ('Bob Higgins', 'http://www.wikidata.org/entity/Q4932791'),
#  'Y85GTOSS 3788 0': ('Colin Rand Kasperniack',
#   'http://www.wikidata.org/entity/Q82496 http://www.wikidata.org/entity/Q27077447 http://www.wikidata.org/entity/Q29907670'),
#  'WI5LYQ0H 487 0': ('The Prince of Midair',
#   'http://www.wikidata.org/entity/Q2252657'),
#  '00E2H310 4432 0': ('Mccouly Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'B20WIQKU 1084 0': ('Mccalay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  '3N6S2FCX 2587 0': ('Zachary Knight Galapfiniakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9XAJBIJV 6533 0': ('William Miller',
#   'http://www.wikidata.org/entity/Q353723'),
#  '8YINKYDR 9470 0': ('Amy Paeler', 'http://www.wikidata.org/entity/Q230203'),
#  'AN306FAH 3563 0': ('James Street',
#   'http://www.wikidata.org/entity/Q6143750'),
#  'NPNYM0BA 9922 0': ('Alanis Morissette',
#   'http://www.wikidata.org/entity/Q130742 http://www.wikidata.org/entity/Q12682382'),
#  'PZXDACJ9 306 0': ('Zooey Dejunnel',
#   'http://www.wikidata.org/entity/Q191719'),
#  'UEJEB27H 3850 0': ('Bill Bakerrr', 'http://www.wikidata.org/entity/Q434482'),
#  'NPNYM0BA 5572 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'KUGCH9I3 3897 0': ('Gary Stewart',
#   'http://www.wikidata.org/entity/Q1494958'),
#  '3C3INQLM 10839 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '64OJP4G3 1518 0': ('Zachary Knight Galvafinakis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '8YINKYDR 12860 0': ('Chuck Panahliuk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '3N6S2FCX 7915 0': ('Mark Mcguaere',
#   'http://www.wikidata.org/entity/Q462481'),
#  '00E2H310 7004 0': ('Matthew Mcconenhay',
#   'http://www.wikidata.org/entity/Q188955'),
#  'PZXDACJ9 2951 0': ('Zachary Knight Galafackis',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '9HIRS45A 20 0': ('Big Dawg', 'http://www.wikidata.org/entity/Q527780'),
#  'QNP7O8L5 1620 0': ('Peter Baltes',
#   'http://www.wikidata.org/entity/Q70571 http://www.wikidata.org/entity/Q18371087'),
#  'NPNYM0BA 1063 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'NPNYM0BA 6684 0': ('Matthew McConaughey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '5HD27KI3 409 0': ('Zion National Park',
#   'http://www.wikidata.org/entity/Q205325 http://www.wikidata.org/entity/Q49584014'),
#  '00E2H310 898 0': ('Sarah Maclaighlin',
#   'http://www.wikidata.org/entity/Q224650'),
#  'B20WIQKU 2699 0': ('Chuck Pahulanick',
#   'http://www.wikidata.org/entity/Q268181'),
#  '64OJP4G3 6100 0': ('Scarlett Johannsoen',
#   'http://www.wikidata.org/entity/Q34436'),
#  '7QNYGYI7 1597 0': ('Mtume', 'http://www.wikidata.org/entity/Q504429'),
#  '8YINKYDR 4353 0': ('Shia Saide Liabeouf',
#   'http://www.wikidata.org/entity/Q180942'),
#  'X1LRVWSR 3416 0': ('Matthew Mcconahee',
#   'http://www.wikidata.org/entity/Q188955'),
#  'X23TMJ3R 1485 0': ('Marty Kristian',
#   'http://www.wikidata.org/entity/Q6777463'),
#  'O0UJJVBR 5704 0': ('Kent Williams',
#   'http://www.wikidata.org/entity/Q6391962'),
#  '64OJP4G3 2983 0': ('Matthew Mchonihay',
#   'http://www.wikidata.org/entity/Q188955'),
#  'NPNYM0BA 11531 0': ('Manoj Shyamalan',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'KUGCH9I3 6972 0': ('Phil Clark', 'http://www.wikidata.org/entity/Q7181784'),
#  'HQCEC5NO 517 0': ('Manhatan', 'http://www.wikidata.org/entity/Q856841'),
#  'QNP7O8L5 746 0': ('Florian Magnus Maier',
#   'http://www.wikidata.org/entity/Q20195257 http://www.wikidata.org/entity/Q2620121'),
#  'HGYG2DVU 359 0': ('Melborne',
#   'http://www.wikidata.org/entity/Q949779 http://www.wikidata.org/entity/Q12939173 http://www.wikidata.org/entity/Q35727710'),
#  'Y85GTOSS 4169 0': ('Chuck Palenauk',
#   'http://www.wikidata.org/entity/Q268181'),
#  '3C3INQLM 6166 0': ('Macaulay Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'HQCEC5NO 1032 0': ('Oklahoma City',
#   'http://www.wikidata.org/entity/Q34863 http://www.wikidata.org/entity/Q16037460 http://www.wikidata.org/entity/Q5671589'),
#  'NYFX4M8T 43 0': ('China',
#   'http://www.wikidata.org/entity/Q148 http://www.wikidata.org/entity/Q10545511 http://www.wikidata.org/entity/Q1579717 http://www.wikidata.org/entity/Q25688698 http://www.wikidata.org/entity/Q25706142 http://www.wikidata.org/entity/Q44541916 http://www.wikidata.org/entity/Q65436285'),
#  'O0UJJVBR 4188 0': ('Bobby Parker', 'http://www.wikidata.org/entity/Q690766'),
#  'NPNYM0BA 1358 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  'AN306FAH 6087 0': ('Jeremy Jordan',
#   'http://www.wikidata.org/entity/Q6181572'),
#  '9CSNI7FS 6206 0': ('George Howell',
#   'http://www.wikidata.org/entity/Q5540791'),
#  'NPNYM0BA 14975 0': ('Picabo Street',
#   'http://www.wikidata.org/entity/Q10101'),
#  'HQCEC5NO 408 0': ('Jameston',
#   'http://www.wikidata.org/entity/Q1052658 http://www.wikidata.org/entity/Q20597707'),
#  '64OJP4G3 4160 0': ('Amy Pohlere', 'http://www.wikidata.org/entity/Q230203'),
#  'UEJEB27H 6704 0': ('James Hurst', 'http://www.wikidata.org/entity/Q6136453'),
#  'AN306FAH 8284 0': ('Ron Casey', 'http://www.wikidata.org/entity/Q16019660'),
#  'UEJEB27H 2623 0': ('Scott Owens',
#   'http://www.wikidata.org/entity/Q17402885'),
#  '8YINKYDR 4860 0': ('Maculney Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'O0UJJVBR 4606 0': ('Greg Williams',
#   'http://www.wikidata.org/entity/Q5606430'),
#  'IPTLCCCU 132 0': ('LucasArts', 'http://www.wikidata.org/entity/Q216611'),
#  'DXTA1MV8 54 0': ('Republic of the Congo',
#   'http://www.wikidata.org/entity/Q971 http://www.wikidata.org/entity/Q12921491 http://www.wikidata.org/entity/Q13108961 http://www.wikidata.org/entity/Q13158776 http://www.wikidata.org/entity/Q16047193 http://www.wikidata.org/entity/Q25704065 http://www.wikidata.org/entity/Q65453607'),
#  '9CSNI7FS 3127 0': ('Chris Davis', 'http://www.wikidata.org/entity/Q1046188'),
#  '3N6S2FCX 5790 0': ('Matthew Mckohaghuey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '9CSNI7FS 1067 0': ('Ed Smith', 'http://www.wikidata.org/entity/Q5335426'),
#  'PZXDACJ9 2695 0': ('Zachary Knight Galifanigas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  'AN306FAH 5518 0': ('Paul Runge', 'http://www.wikidata.org/entity/Q7153357'),
#  '3N6S2FCX 7062 0': ('Manoj Shammler',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'AN306FAH 6725 0': ('Carl Jensen', 'http://www.wikidata.org/entity/Q5040374'),
#  'E45F8QW2 1299 0': ('Ravi Kumar', 'http://www.wikidata.org/entity/Q7296642'),
#  '8YINKYDR 13965 0': ('Scarlett Johjohanson',
#   'http://www.wikidata.org/entity/Q34436'),
#  'Y85GTOSS 3237 0': ('Manoj Shamelak',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  '3C3INQLM 1217 0': ('Sarah McLachlan',
#   'http://www.wikidata.org/entity/Q224650'),
#  '9CSNI7FS 3141 0': ('George Cox', 'http://www.wikidata.org/entity/Q5538182'),
#  'AN306FAH 4701 0': ('Scott Owens',
#   'http://www.wikidata.org/entity/Q17402885'),
#  'B20WIQKU 1131 0': ('Mackaulim Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  'GY7KNULP 523 0': ('Warner Bros. Interactive Entertainment',
#   'http://www.wikidata.org/entity/Q2319420'),
#  'UEJEB27H 1465 0': ('Tonny Fultonn',
#   'http://www.wikidata.org/entity/Q7822396'),
#  '00E2H310 2252 0': ('Zachary Knight Galfinicas',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '8YINKYDR 9688 0': ('Manoj Shymalen',
#   'http://www.wikidata.org/entity/Q51489 http://www.wikidata.org/entity/Q16043009'),
#  'QIW5EC2H 722 0': ('Meriden',
#   'http://www.wikidata.org/entity/Q54220 http://www.wikidata.org/entity/Q12939142'),
#  'B20WIQKU 1357 0': ('Matthew Mccaunahey',
#   'http://www.wikidata.org/entity/Q188955'),
#  '00E2H310 3261 0': ('Zachary Knight Galifichianaki',
#   'http://www.wikidata.org/entity/Q139325 http://www.wikidata.org/entity/Q25491362'),
#  '00E2H310 5196 0': ('Muckolly Carson Culkin',
#   'http://www.wikidata.org/entity/Q103578'),
#  ...}

# %%
for k, (p, id) in key_to_cell_sample.items():
    q_id = re.search(r'Q(\d+)$', id)[0]
    if q_id == 'Q10101':
        print(p)
# Out:
# Pelaboo Street
# Pikabou Street
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
#       1 for k, (p, id) in key_to_cell_sample.items():
# ----> 2     q_id = re.search(r'Q(\d+)$', id)[0]
#       3     if q_id == 'Q10101':
#       4         print(p)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
## CALL THE ENDPOINT TO SEE WHAT ARE THE ENTITIES THAT DOESN'T MATCH IN WIKIDATA

# Define the endpoint and token
url = 'https://lamapi.hel.sintef.cloud/entity/labels?token=lamapi_summer_school_romania_2024'

# Define the headers
headers = {
    'accept': 'application/json',
    'Content-Type': 'application/json'
}

# Define the data payload
data = {
    'json': list((set(failed_queries_hard).intersection(set(failed_queries_soft))))
}

# Convert the payload to a JSON string
json_data = json.dumps(data)

# Perform the POST request
response = requests.post(url, headers=headers, data=json_data)

# %%
missing_values = ((set(failed_queries_hard).intersection(set(failed_queries_soft))) - set(response.json().keys()))
print(len(missing_values))
# Out:
# 342
